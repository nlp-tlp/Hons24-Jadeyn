# %% [markdown]
# # Section 1: Preparing the Data

# %% [markdown]
# ## Import Statements

# %%
# !pip install tensorflow
# !pip install gensim
# !pip install tf-keras
# Out:
# Requirement already satisfied: tensorflow in /opt/miniconda3/lib/python3.12/site-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (4.25.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (1.65.5)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/miniconda3/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.41.2)
# Requirement already satisfied: rich in /opt/miniconda3/lib/python3.12/site-packages (from keras>=3.2.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /opt/miniconda3/lib/python3.12/site-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /opt/miniconda3/lib/python3.12/site-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/miniconda3/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/miniconda3/lib/python3.12/site-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/miniconda3/lib/python3.12/site-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/miniconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Requirement already satisfied: gensim in /opt/miniconda3/lib/python3.12/site-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /opt/miniconda3/lib/python3.12/site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /opt/miniconda3/lib/python3.12/site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/miniconda3/lib/python3.12/site-packages (from gensim) (7.0.4)
# Requirement already satisfied: wrapt in /opt/miniconda3/lib/python3.12/site-packages (from smart-open>=1.8.1->gensim) (1.16.0)
# Requirement already satisfied: tf-keras in /opt/miniconda3/lib/python3.12/site-packages (2.17.0)
# Requirement already satisfied: tensorflow<2.18,>=2.17 in /opt/miniconda3/lib/python3.12/site-packages (from tf-keras) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (3.3.0)
# Requirement already satisfied: packaging in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (4.25.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (2.31.0)
# Requirement already satisfied: setuptools in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.65.5)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (3.5.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/miniconda3/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow<2.18,>=2.17->tf-keras) (0.41.2)
# Requirement already satisfied: rich in /opt/miniconda3/lib/python3.12/site-packages (from keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (13.7.1)
# Requirement already satisfied: namex in /opt/miniconda3/lib/python3.12/site-packages (from keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (0.0.8)
# Requirement already satisfied: optree in /opt/miniconda3/lib/python3.12/site-packages (from keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.18,>=2.17->tf-keras) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.18,>=2.17->tf-keras) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.18,>=2.17->tf-keras) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.18,>=2.17->tf-keras) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard<2.18,>=2.17->tensorflow<2.18,>=2.17->tf-keras) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard<2.18,>=2.17->tensorflow<2.18,>=2.17->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard<2.18,>=2.17->tensorflow<2.18,>=2.17->tf-keras) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/miniconda3/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow<2.18,>=2.17->tf-keras) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/miniconda3/lib/python3.12/site-packages (from rich->keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/miniconda3/lib/python3.12/site-packages (from rich->keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/miniconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (0.1.2)

# %%
import tensorflow as tf

from gensim.models import Word2Vec
from gensim.models import LsiModel
import gensim

import numpy as np
import matplotlib.pyplot as plt

from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

from sentence_transformers import SentenceTransformer
import json
import contractions
import random

from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.metrics import silhouette_score
from sklearn.metrics import normalized_mutual_info_score

import copy
import statistics

# %% [markdown]
# ## Helper Functions for Preparing Data

# %%
def pad_sequence(dset, max_len=None):
    if not max_len:
        max_len = len(max(dset, key=len))
    print("max length of MWO:", max_len)
    for i in range(len(dset)):
        count = 0
        while len(dset[i]) < max_len:
            dset[i].append(dset[i][count])
            count+=1
    return dset

# %%
def clean_tokens(tokens):
    """cleans tokens by removing stopwords and expanding contractions"""
    stopwords =["<num>", "<id>", "-"]
    tokens = [i for i in tokens if i not in stopwords]
    tokens = contractions.fix(" ".join(tokens)).split()
    return tokens

# %%
def extract_function_from_entity_index(row, index, equipment_dict=None):
    """extracts the function from an PhysicalObject's index"""
    if equipment_dict:
        start = row["entities"][index]["start"]
        end = row["entities"][index]["end"]
        equipment = " ".join([row["tokens"][i] for i in range(start, end)])
        if equipment not in equipment_dict.keys():
            return None
        return equipment_dict[equipment][:-6].lower()
    types = row["entities"][index]["type"].split("/")
    if len(types) > 1:
        return types[1][:-6].lower()
    else:
        return None
    
def get_inherent_function(row, equipment_dict=None):
    """choose the most appropriate inherent function to do with the failure mode of a MWO"""
    # list of tuples of head and tail indices
    hasPart_heads = []
    hasPart_tails = []
    contains_heads =[]
    contains_tails =[]
    isA_relations_indices = []

    for r in row["relations"]:
        if r["type"] == "hasPart":
            hasPart_heads.append(r["head"])
            hasPart_tails.append(r["tail"])
        if r["type"] == "contains":
            contains_heads.append(r["head"])
            contains_tails.append(r["tail"])
        if r["type"] == "isA":
            isA_relations_indices.append((r["head"], r["tail"]))

    # remove any repeats
    hasPart_heads = list(set(hasPart_heads))
    hasPart_tails = list(set(hasPart_tails))
    
    # list of physical object indices not in a hasPart or isA relation
    physical_object_indices = []
    
    # get all physical object indices
    for i in range(len(row["entities"])):
        if row["entities"][i]["type"].split("/")[0] == "PhysicalObject" and (equipment_dict or len(row["entities"][i]["type"].split("/")) == 1 or (row["entities"][i]["type"].split("/")[1]  != "Substance")):
            physical_object_indices.append(i)
    
    inherent_function_index = []
    for i in hasPart_tails:
        # if tail is not a head of a hasPart relation
        if i not in hasPart_heads:
            inherent_function_index.append(i)
        # remove tail from the physical object indices
        if i in physical_object_indices:
            physical_object_indices.remove(i)
    
    for i in hasPart_heads:
        # remove head from the physical object indices
        if i in physical_object_indices:
            physical_object_indices.remove(i)

    for i in isA_relations_indices:
        # remove physical objects that are part of an isA relation
        if i[0] in physical_object_indices:
            physical_object_indices.remove(i[0])
        if i[1] in physical_object_indices:
            physical_object_indices.remove(i[1])

    # EXCEPTION 1: if there are physical objects that are not part of a hasPart or isA relation, and there is a hasPart relation
    if physical_object_indices and inherent_function_index:
        # in general, ignore additional physical objects 
        if len(inherent_function_index) ==1:
            isA_tails = [i[1] for i in isA_relations_indices]
            # if there is a more specific (head) object in an isA relation
            if inherent_function_index[0] in isA_tails:
                isA_head_index = isA_relations_indices[isA_tails.index(inherent_function_index[0])][0]
                func = extract_function_from_entity_index(row, isA_head_index, equipment_dict)
                return func
            else:
                func = extract_function_from_entity_index(row, inherent_function_index[0], equipment_dict)
                return func


    # EXCEPTION 2: if there is zero or more than one physical object and no hasPart relations
    if (len(inherent_function_index) == 0) and len(physical_object_indices)!=1 and not isA_relations_indices:
        # if there are no physical objects, remove the row
        if len(physical_object_indices) == 0:
            print("remove:",row, "\n")
            return None
        physical_object_not_substance = []
        for i in physical_object_indices:
            start = row["entities"][i]["start"]
            end = row["entities"][i]["end"]
            # if the physical object is not a substance
            if end == len(row["tokens"]) and " ".join(row["tokens"][start:]) != "oil":
                physical_object_not_substance.append(i)
            elif " ".join(row["tokens"][start:end]) != "oil":
                physical_object_not_substance.append(i)

        # if there is only one non-substance physical object, extract its function
        if len(physical_object_not_substance) == 1:
            func = extract_function_from_entity_index(row, physical_object_not_substance[0], equipment_dict)
            return func
        else:
            func = extract_function_from_entity_index(row, physical_object_indices[0], equipment_dict)
            return func
            
                

    # EXCEPTION 3: if there are more than one leftover tail from hasPart relations
    if (len(inherent_function_index) > 1):
        # manually assign inherent function
        if row["text"] == "replace unserviceable transmission screen and magnet":
            return "transforming"
        elif row["text"] == "pump drive box coupling and shaft unserviceable":
            return "driving"
        else:
            return None
    

    # get entities
    if len(inherent_function_index) == 1 and len(physical_object_indices) == 0:
        func = extract_function_from_entity_index(row, inherent_function_index[0], equipment_dict)
        return func
    elif len(inherent_function_index) == 0 and len(physical_object_indices) == 1:
        func = extract_function_from_entity_index(row, physical_object_indices[0], equipment_dict)
        return func
    elif all(i in [x for xs in isA_relations_indices for x in xs] for i in physical_object_indices):
        isA_heads = [i[0] for i in isA_relations_indices]
        isA_tails = [i[1] for i in isA_relations_indices]
        isA_specific_indices = []
        for i in isA_heads:
            if i not in isA_tails:
                isA_specific_indices.append(i)
        if len(isA_specific_indices) == 1:
            func = extract_function_from_entity_index(row, isA_specific_indices[0], equipment_dict)
            return func
        
        else:
            if row["text"] == "<id> park brake alarm fault":
                return "restricting"
            else:
                return None
               
    elif len(inherent_function_index)>1:
        return None
       
    else:
        return None
        
    
    

def get_gold_dataset(dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO):
    """get the gold dataset and its inherent function labels"""
    f = open("../data/gold_release.json", "r")
    # returns JSON object as a dictionary
    data = json.load(f)
    f.close()


    for datum in data:
        types = [e["type"].split("/")[0] for e in datum["entities"]]
        if ("State" in types or "Process" in types or "Property" in types) and "PhysicalObject" in types:
            inherent_function = get_inherent_function(datum)
            if not inherent_function:
                continue

            tokens = datum["tokens"].copy()

            # remove activity tokens
            if "Activity" in types:
                activity_indices = []
                for e in datum["entities"]:
                    if e["type"].split("/")[0] == "Activity":
                        for i in range(e["start"], e["end"]):
                            activity_indices.append(i)
                activity_indices = sorted(set(activity_indices), reverse=True)
                for i in activity_indices:
                    tokens.pop(i)
                

            tokens = clean_tokens(tokens)
            dataset.append(tokens)
            if inherent_function not in class_list:
                labels.append(len(class_list))
                class_list.append(inherent_function)
            else:
                labels.append(class_list.index(inherent_function))
            
            # add MWO tokens to dictionary with key inherent function
            if inherent_function in MWO_by_function:
                MWO_by_function[inherent_function].append(tokens)
            else:
                MWO_by_function[inherent_function] = [tokens]
            
            # add state, equipment, and inherent function to dictionary with key MWO
            mwo = " ".join(tokens)
            if mwo not in state_equipment_inherentfunction_by_MWO:
                states = []
                equip = []
                for i in range(len(types)):
                    if types[i] in ["State", "Process", "Property"]:
                        start = datum["entities"][i]["start"]
                        end = datum["entities"][i]["end"]
                        states.append(" ".join([datum["tokens"][j] for j in range(start, end)]))
                    elif types[i] == "PhysicalObject":
                        start = datum["entities"][i]["start"]
                        end = datum["entities"][i]["end"]
                        equip.append(" ".join([datum["tokens"][j] for j in range(start, end)]))
                state_equipment_inherentfunction_by_MWO[mwo]=[states, equip, inherent_function]

    print("Number of Inherent function clusters:", len(MWO_by_function.keys()))
    for i in MWO_by_function.keys():
        print(i, len(MWO_by_function[i]))
        if len(MWO_by_function[i]) == 1:
            print("   ", MWO_by_function[i])
    print()
    return dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO

# %%
def create_equipment_dictionary():
    """create a dictionary of known equipment and their inherent functions"""
    f = open("../data/gold_release.json", "r")
    # returns JSON object as a dictionary
    data = json.load(f)
    f.close()

    
    # exception multiple types for the same equipment
    ignored_equipment = {"auto-lube":"ProtectingObject", "axle":"GuidingObject", "drag":"MatterProcessingObject", "universal joint":"GuidingObject", "adaptor":"InterfacingObject", "batteries":"StoringObject", "carousel":"StoringObject", "window":"RestrictingObject", "shaft":"GuidingObject", "input shaft":"GuidingObject"}
    equipment = ignored_equipment.copy()
    
    for datum in data:
        for e in datum["entities"]:
            entity_type = e["type"].split("/")
            if entity_type[0] == "PhysicalObject" and len(entity_type) > 1 and entity_type[1] not in ["Substance", "Organism"]:
                start = int(e["start"])
                end = int(e["end"])
                equipment_text = " ".join([datum["tokens"][t] for t in range(start, end)])
                
                if equipment_text in ignored_equipment:
                    continue
                if equipment_text not in equipment:
                    equipment[equipment_text] = entity_type[1]
              
    return equipment

def get_synthetic_dataset(filename, dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO):
    """Get synthetic dataset and its inherent function labels"""
    import csv


    with open(filename, 'r') as csvfile:
        # creating a csv reader object
        csvreader = csv.reader(csvfile)
        counter = 0
        for row in csvreader:
            tokens = row[0].split()
            if len(row[1].split("/")) == 1 or row[1].split("/")[1] in ["Substance", "Organism", "GuidingObject","HoldingObject"] or "leak" in row[3]:
                counter+=1
                continue
            inherent_function = row[1].split("/")[1][:-6].lower()

            tokens = clean_tokens(tokens)
            dataset.append(tokens)
            if inherent_function not in class_list:
                labels.append(len(class_list))
                class_list.append(inherent_function)
            else:
                labels.append(class_list.index(inherent_function))
            
            # add MWO tokens to dictionary with key inherent function
            if inherent_function in MWO_by_function:
                MWO_by_function[inherent_function].append(tokens)
            else:
                MWO_by_function[inherent_function] = [tokens]
            
            mwo= " ".join(tokens)
            # add state, equipment, inherent function to dictionary with key tokens
            if mwo not in state_equipment_inherentfunction_by_MWO:
                states = []
                equip = []
                states.append(row[3])
                equip.append(row[2])
                state_equipment_inherentfunction_by_MWO[mwo]=[states, equip, inherent_function]

    print("Number of Inherent function clusters:", len(MWO_by_function.keys()))
    for i in MWO_by_function.keys():
        print(i, len(MWO_by_function[i]))
        if len(MWO_by_function[i]) == 1:
            print("   ", MWO_by_function[i])
    print()

    return dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO
            
    
def get_silver_dataset(dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO):
    """get the silver dataset and its inherent function labels"""
    equipment_dict = create_equipment_dictionary()
    
    f = open("../data/silver_release.json", "r")
    # returns JSON object as a dictionary
    data = json.load(f)
    f.close()

    for datum in data:
        types = [e["type"].split("/")[0] for e in datum["entities"]]
        if ("State" in types or "Process" in types or "Property" in types) and "PhysicalObject" in types:
            inherent_function = get_inherent_function(datum, equipment_dict)
            if not inherent_function:
                continue
            
            tokens = datum["tokens"].copy()

            # remove activity tokens
            if "Activity" in types:
                activity_indices = []
                for e in datum["entities"]:
                    if e["type"].split("/")[0] == "Activity":
                        for i in range(e["start"], e["end"]):
                            activity_indices.append(i)
                activity_indices = sorted(set(activity_indices), reverse=True)
                for i in activity_indices:
                    tokens.pop(i)
            
            tokens = clean_tokens(tokens)
            dataset.append(tokens)
            if inherent_function not in class_list:
                labels.append(len(class_list))
                class_list.append(inherent_function)
            else:
                labels.append(class_list.index(inherent_function))
            
            # add MWO tokens to dictionary with key inherent function
            if inherent_function in MWO_by_function:
                MWO_by_function[inherent_function].append(tokens)
            else:
                MWO_by_function[inherent_function] = [tokens]
            
            mwo= " ".join(tokens)
            # add state, equipment, inherent function to dictionary with key tokens
            if mwo not in state_equipment_inherentfunction_by_MWO:
                states = []
                equip = []
                for i in range(len(types)):
                    if types[i] in ["State", "Process", "Property"]:
                        start = datum["entities"][i]["start"]
                        end = datum["entities"][i]["end"]
                        states.append(" ".join([datum["tokens"][j] for j in range(start, end)]))
                    elif types[i] == "PhysicalObject":
                        start = datum["entities"][i]["start"]
                        end = datum["entities"][i]["end"]
                        equip.append(" ".join([datum["tokens"][j] for j in range(start, end)]))
                state_equipment_inherentfunction_by_MWO[mwo]=[states, equip, inherent_function]


    print("Number of Inherent function clusters:", len(MWO_by_function.keys()))
    for i in MWO_by_function.keys():
        print(i, len(MWO_by_function[i]))
        if len(MWO_by_function[i]) == 1:
            print("   ", MWO_by_function[i])
    print()
    return dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO

# %% [markdown]
# ## Create Dataset

# %%
def create_dataset():
    """create the dataset of gold, silver and synthetic data"""
    MWO_by_function = {}
    dataset = []
    labels = []
    class_list = []
    state_equipment_inherentfunction_by_MWO = {}

    dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO = get_gold_dataset(dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO)
    dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO = get_synthetic_dataset("../data/synthetic2.csv",dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO)
    dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO = get_silver_dataset(dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO)

    return dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO

# %%
dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO = create_dataset()

# remove information processing
for i in MWO_by_function["informationprocessing"]:
    if i in dataset:
        print("Removed")
        print(i)
        dataset.remove(i)
labels = [i for i in labels if i != 16] 

# divide dataset into training and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dataset, labels, random_state=42, shuffle=True, test_size=0.2)
y_train = np.array(y_train)
y_test = np.array(y_test)
X = X_train + X_test

print("training set length:",len( X_train))
print("test set length:", len(X_test))
print("dataset length:",len( dataset))
# Out:
# remove: {'text': '<id> air leak', 'tokens': ['<id>', 'air', 'leak'], 'entities': [{'start': 1, 'end': 2, 'type': 'PhysicalObject/Substance/Gas'}, {'start': 2, 'end': 3, 'type': 'Process/UndesirableProcess'}], 'relations': [{'head': 1, 'tail': 0, 'type': 'hasParticipant/hasPatient'}]}
#
# remove: {'text': '<id> - air leak', 'tokens': ['<id>', '-', 'air', 'leak'], 'entities': [{'start': 2, 'end': 3, 'type': 'PhysicalObject/Substance/Gas'}, {'start': 3, 'end': 4, 'type': 'Process/UndesirableProcess'}], 'relations': [{'head': 1, 'tail': 0, 'type': 'hasParticipant/hasPatient'}]}
#
# remove: {'text': '<id> - fuel leak', 'tokens': ['<id>', '-', 'fuel', 'leak'], 'entities': [{'start': 2, 'end': 3, 'type': 'PhysicalObject/Substance/Liquid'}, {'start': 3, 'end': 4, 'type': 'Process/UndesirableProcess'}], 'relations': [{'head': 1, 'tail': 0, 'type': 'hasParticipant/hasPatient'}]}
#
# remove: {'text': '<id> <id> replace hydraulic oil leak text', 'tokens': ['<id>', '<id>', 'replace', 'hydraulic', 'oil', 'leak', 'text'], 'entities': [{'start': 2, 'end': 3, 'type': 'Activity/MaintenanceActivity/Replace'}, {'start': 5, 'end': 6, 'type': 'Process/UndesirableProcess'}, {'start': 3, 'end': 5, 'type': 'PhysicalObject/Substance/Liquid'}], 'relations': [{'head': 1, 'tail': 2, 'type': 'hasParticipant/hasPatient'}, {'head': 0, 'tail': 2, 'type': 'hasParticipant/hasPatient'}]}
#
# Number of Inherent function clusters: 17
# sensing 30
# emitting 34
# matterprocessing 23
# presenting 28
# generating 35
# controlling 36
# guiding 98
# driving 35
# transforming 33
# protecting 45
# storing 19
# humaninteraction 10
# holding 61
# covering 20
# interfacing 11
# restricting 14
# informationprocessing 1
#     [['pilot', 'valve', 'leaking', 'oil']]
#
# Number of Inherent function clusters: 17
# sensing 85
# emitting 114
# matterprocessing 38
# presenting 48
# generating 115
# controlling 96
# guiding 98
# driving 50
# transforming 68
# protecting 175
# storing 54
# humaninteraction 20
# holding 61
# covering 50
# interfacing 36
# restricting 44
# informationprocessing 1
#     [['pilot', 'valve', 'leaking', 'oil']]
#
# Number of Inherent function clusters: 17
# sensing 117
# emitting 353
# matterprocessing 120
# presenting 69
# generating 262
# controlling 194
# guiding 462
# driving 199
# transforming 151
# protecting 324
# storing 112
# humaninteraction 40
# holding 408
# covering 130
# interfacing 87
# restricting 123
# informationprocessing 5
#
# Removed
# ['pilot', 'valve', 'leaking', 'oil']
# Removed
# ['unserviceable', 'starter', 'relay']
# Removed
# ['prelube', 'relay', 'shorted']
# Removed
# ['relay', 'faulty', 'to', 'be']
# Removed
# ['steering', 'pilot', 'valve', 'leaking']
# training set length: 2520
# test set length: 631
# dataset length: 3151

# %% [markdown]
# # Section 2: Creating Embeddings and Clustering Helper Functions

# %% [markdown]
# ## Create Word2Vec and SBERT Embeddings

# %%
def w2v_embed(xtrain,xtest, max_len):
    """get Word2Vec embeddings for the dataset"""
    # Word2Vec embeddings as input
    x_copy_train = copy.deepcopy(xtrain)
    x_copy_test = copy.deepcopy(xtest)
    padded_x_train = pad_sequence(x_copy_train, max_len)
    padded_x_test = pad_sequence(x_copy_test, max_len)
    padded_x = padded_x_train + padded_x_test

    w2vmodel = gensim.models.Word2Vec(padded_x, min_count=1, vector_size=100,
                                    window=5, sg=1)


    w2v_embeddings_train = []
    for sentence in padded_x_train:
        row = []
        for word in sentence:
            row.append(w2vmodel.wv[word])
        w2v_embeddings_train.append(row)
    w2v_embeddings_train = np.array(w2v_embeddings_train)

    w2v_embeddings_test = []
    for sentence in padded_x_test:
        row = []
        for word in sentence:
            row.append(w2vmodel.wv[word])
        w2v_embeddings_test.append(row)
    w2v_embeddings_test = np.array(w2v_embeddings_test)
    return w2v_embeddings_train, w2v_embeddings_test

max_len = len(max(dataset, key=len))
w2v_embeddings_X_train, w2v_embeddings_X_test = w2v_embed(X_train, X_test, max_len)

print(w2v_embeddings_X_train.shape)
print(w2v_embeddings_X_test.shape)
# Out:
# ['air', 'conditioner', 'thermostat', 'not', 'working']
# max length of MWO: 10
# max length of MWO: 10
# (2520, 10, 100)
# (631, 10, 100)
# ['air', 'conditioner', 'thermostat', 'not', 'working']

# %%
# SBERT embeddings
sbert = SentenceTransformer("all-mpnet-base-v2")
SBERT_embeddings_train = sbert.encode(X_train)
SBERT_embeddings_test = sbert.encode(X_test)

print(SBERT_embeddings_train.shape)
print(SBERT_embeddings_test.shape)
# Out:
# /opt/miniconda3/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# (2520, 768)
# (631, 768)

# %% [markdown]
# ## Clustering Helper Functions

# %%
def print_cluster_stats(all_inherentfunc_occurrences):
    """print statistics of the clusters"""
    # get top words    
    print()
    print()
    print("Ave number of documents per cluster:", sum([sum(i) for i in all_inherentfunc_occurrences])/len(all_inherentfunc_occurrences))
    print("Median number of documents per cluster:", statistics.median([sum(i) for i in all_inherentfunc_occurrences]))
    print("Min number of documents per cluster:", min([sum(i) for i in all_inherentfunc_occurrences]))
    print("Max number of documents per cluster:", max([sum(i) for i in all_inherentfunc_occurrences]))
    print()
    one_func = [i for i in all_inherentfunc_occurrences if i[0]/sum(i) >= 0.8]
    print("Percentage of clusters with 1 main Inherent function (80% of docs):", len(one_func)/len(all_inherentfunc_occurrences))

    two_three_func = [i for i in all_inherentfunc_occurrences if sum(i[:3])/sum(i) >= 0.8 and i[0]/sum(i) < 0.8]
    print("Percentage of clusters with 2 or 3 main Inherent functions (80% of docs):", len(two_three_func)/len(all_inherentfunc_occurrences))

    print("Percentage of documents in clusters with 1 main Inherent function (80% of docs):", sum(sum(one_func,[]))/len(dataset))
    print("Percentage of documents in clusters with 2 or 3 main Inherent functions (80% of docs):", sum(sum(two_three_func,[]))/len(dataset))

# %% [markdown]
# ### K-means Clustering

# %%
def perform_kmeans(cluster_embeddings):
    # PCA reduction
    pca = PCA(n_components=2)
    pca_embedding = pca.fit_transform(cluster_embeddings)
    plt.scatter(pca_embedding[:,0], pca_embedding[:,1])
    plt.title("PCA")
    plt.show()

    # tsne reduction
    tsne = TSNE(n_components=2).fit_transform(cluster_embeddings)
    plt.scatter(tsne[:,0], tsne[:,1])
    plt.title("TSNE")
    plt.show()


    # Perform kmean clustering
    silhouette_scores = []
    test_k = list(range(5, 30))
    for i in test_k:
        print(i, "/", 30)
        kmeans = KMeans(n_clusters=i, random_state=42, n_init=100).fit(cluster_embeddings)
        labels = kmeans.labels_
        silhouette_scores.append(silhouette_score(cluster_embeddings, labels))
        if i == 16:
            nmi = normalized_mutual_info_score(labels, y_train.tolist()+y_test.tolist())
    plt.plot(test_k, silhouette_scores)
    plt.title("Silhouette Scores")
    plt.show()
    
    print("NMI:",nmi)


def run_kmeans_best_k(k, cluster_embeddings):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=100).fit(cluster_embeddings)
    cluster_labels = kmeans.labels_
    all_inherentfunc_occurrences = []

    for i in range(1,k+1):
        print("Cluster",i,":")
        cluster_docs = []
        cluster_words = {}
        cluster_states={}
        cluster_equip={}
        cluster_inherentfunc={}
        for j in range(len(cluster_labels)):
            if cluster_labels[j]==(i-1):
                mwo = " ".join(X[j])
                cluster_docs.append(mwo)

                for word in X[j]:
                    if word in cluster_words:
                        cluster_words[word]+=1
                    else:
                        cluster_words[word]=1
                
                state_equip_inherfunc = state_equipment_inherentfunction_by_MWO[mwo]
                for state in state_equip_inherfunc[0]:
                    if state in cluster_states:
                        cluster_states[state]+=1
                    else:
                        cluster_states[state]=1
                for equip in state_equip_inherfunc[1]:
                    if equip in cluster_equip:
                        cluster_equip[equip]+=1
                    else:
                        cluster_equip[equip]=1
                if state_equip_inherfunc[2] in cluster_inherentfunc:
                    cluster_inherentfunc[state_equip_inherfunc[2]]+=1
                else:
                    cluster_inherentfunc[state_equip_inherfunc[2]]=1
        
        # get top words
        print("Cluster Size:=========", len(cluster_labels[cluster_labels==i-1]))
        print("Sample Docs:=========")
        if len(cluster_docs) > 0:
            for j in random.sample(cluster_docs, min(5, len(cluster_docs))):
                print(j)
        else:
            print("No docs")
        print()
        print("Top words:=========")
        sorted_cluster_words = sorted(cluster_words, key=cluster_words.get, reverse=True)
        for j in range(min(len(sorted_cluster_words), 5)):
            print(sorted_cluster_words[j])
        print()
        sorted_cluster_states = sorted(cluster_states, key=cluster_states.get, reverse=True)
        print("Top failure modes:=========")
        for j in range(min(len(sorted_cluster_states), 5)):
            print(sorted_cluster_states[j])
        print()

        sorted_cluster_equip = sorted(cluster_equip, key=cluster_equip.get, reverse=True)
        print("Top equipment:=========")
        for j in range(min(len(sorted_cluster_equip), 5)):
            print(sorted_cluster_equip[j])
        print()

        sorted_cluster_inherentfunc = sorted(cluster_inherentfunc, key=cluster_inherentfunc.get, reverse=True)
        inherentfunc_occurrences= []
        print("Inherent functions in order:")
        for j in range(len(sorted_cluster_inherentfunc)):
            sentence = sorted_cluster_inherentfunc[j] +" (" + str(cluster_inherentfunc[sorted_cluster_inherentfunc[j]]) +")"
            print(sentence)
            inherentfunc_occurrences.append(cluster_inherentfunc[sorted_cluster_inherentfunc[j]])
        all_inherentfunc_occurrences.append(inherentfunc_occurrences)
        print("==================================================\n")

    print_cluster_stats(all_inherentfunc_occurrences)

# %% [markdown]
# ### Hierarchical Clustering

# %%
def perform_hierarchical_clustering(cluster_embeddings, method):
    linkage_data = linkage(cluster_embeddings, method=method)
    fig = plt.figure(figsize=(25, 10))
    dn = dendrogram(linkage_data)
    plt.show()

    # calculate sihouette score on different k values
    silhouette_scores = []
    test_k = list(range(5, 30))
    nmi = 0
    for i in test_k:
        cluster_labels = fcluster(linkage_data, i, criterion='maxclust')
        silhouette_scores.append(silhouette_score(cluster_embeddings, cluster_labels))
        if i == 16:
            nmi = normalized_mutual_info_score(cluster_labels, y_train.tolist()+y_test.tolist())
    plt.plot(test_k, silhouette_scores, marker='o')
    plt.title("Silhouette Scores")
    plt.show()

    print("NMI:",nmi)

    return linkage_data


def get_hierarchical_clusters(k, linkage_data):
    cluster_labels = fcluster(linkage_data, k, criterion='maxclust')
    all_inherentfunc_occurrences = []
    for i in range(1,k+1):
        print("Cluster",i,":")
        cluster_docs = []
        cluster_words = {}
        cluster_states={}
        cluster_equip={}
        cluster_inherentfunc={}
        for j in range(len(cluster_labels)):
            if cluster_labels[j]==i:
                mwo = " ".join(X[j])
                cluster_docs.append(mwo)
                for word in X[j]:
                    if word in cluster_words:
                        cluster_words[word]+=1
                    else:
                        cluster_words[word]=1
        
                state_equip_inherfunc = state_equipment_inherentfunction_by_MWO[mwo]
                for state in state_equip_inherfunc[0]:
                    if state in cluster_states:
                        cluster_states[state]+=1
                    else:
                        cluster_states[state]=1
                for equip in state_equip_inherfunc[1]:
                    if equip in cluster_equip:
                        cluster_equip[equip]+=1
                    else:
                        cluster_equip[equip]=1
                if state_equip_inherfunc[2] in cluster_inherentfunc:
                    cluster_inherentfunc[state_equip_inherfunc[2]]+=1
                else:
                    cluster_inherentfunc[state_equip_inherfunc[2]]=1
        

        # get top words
        print("Cluster Size:=========", len(cluster_labels[cluster_labels==i]))
        print("Sample Docs:=========")
        if len(cluster_docs) > 0:
            for j in random.sample(cluster_docs, min(10, len(cluster_docs))):
                print(j)
        else:
            print("No docs")
        print()
        print("Top words:=========")
        sorted_cluster_words = sorted(cluster_words, key=cluster_words.get, reverse=True)
        for j in range(min(len(sorted_cluster_words), 5)):
            print(sorted_cluster_words[j])
        print()
        sorted_cluster_states = sorted(cluster_states, key=cluster_states.get, reverse=True)
        print("Top failure modes:=========")
        for j in range(min(len(sorted_cluster_states), 5)):
            print(sorted_cluster_states[j])
        print()

        sorted_cluster_equip = sorted(cluster_equip, key=cluster_equip.get, reverse=True)
        print("Top equipment:=========")
        for j in range(min(len(sorted_cluster_equip), 5)):
            print(sorted_cluster_equip[j])
        print()

        sorted_cluster_inherentfunc = sorted(cluster_inherentfunc, key=cluster_inherentfunc.get, reverse=True)
        inherentfunc_occurrences = []
        print("Inherent functions in order:")
        for j in range(len(sorted_cluster_inherentfunc)):
            sentence = sorted_cluster_inherentfunc[j] +" (" + str(cluster_inherentfunc[sorted_cluster_inherentfunc[j]]) +")"
            print(sentence)
            inherentfunc_occurrences.append(cluster_inherentfunc[sorted_cluster_inherentfunc[j]])
        all_inherentfunc_occurrences.append(inherentfunc_occurrences)
        print("==================================================\n")
    
    print_cluster_stats(all_inherentfunc_occurrences)

# %% [markdown]
# # Section 3: Performing Experiments

# %% [markdown]
# ## Approach 1: Word2Vec Clustering

# %%
w2v_embeddings_all = np.concatenate((w2v_embeddings_X_train, w2v_embeddings_X_test))
# get average vector for each sentence
w2v_embeddings_all = w2v_embeddings_all.mean(axis=1)
print(w2v_embeddings_all.shape)
# Out:
# (3151, 100)

# %% [markdown]
# ### K-means Clustering

# %%
perform_kmeans(w2v_embeddings_all)
# Out:
# 5 / 30
# 6 / 30
# 7 / 30
# 8 / 30
# 9 / 30
# 10 / 30
# 11 / 30
# 12 / 30
# 13 / 30
# 14 / 30
# 15 / 30
# 16 / 30
# 17 / 30
# 18 / 30
# 19 / 30
# 20 / 30
# 21 / 30
# 22 / 30
# 23 / 30
# 24 / 30
# 25 / 30
# 26 / 30
# 27 / 30
# 28 / 30
# 29 / 30
# NMI: 0.24528370148789036

# %%
run_kmeans_best_k(13, w2v_embeddings_all)
# Out:
# Cluster 1 :
# Cluster Size:========= 495
# Sample Docs:=========
# engine fan speed resistor failure
# control valve is falling off
# turbo pressure PSI constant
# lube system failure
# radiator blocked by grass
#
# Top words:=========
# unserviceable
# pump
# leaking
# on
# air
#
# Top failure modes:=========
# unserviceable
# leaking
# failed
# not working
# faulty
#
# Top equipment:=========
# pump
# PTO
# seal
# shaft
# engine
#
# Inherent functions in order:
# generating (62)
# guiding (55)
# protecting (53)
# controlling (45)
# sensing (43)
# transforming (41)
# holding (39)
# covering (30)
# driving (28)
# emitting (24)
# interfacing (23)
# presenting (22)
# matterprocessing (12)
# storing (9)
# restricting (6)
# humaninteraction (3)
# ==================================================
#
# Cluster 2 :
# Cluster Size:========= 205
# Sample Docs:=========
# replacing needed for auto-greaser door window
# window frame needs
# drivers door hinges worn out
# faulty seat
# drivers window has a fault
#
# Top words:=========
# window
# cabin
# door
# broken
# seat
#
# Top failure modes:=========
# broken
# damaged
# cracked
# unserviceable
# faulty
#
# Top equipment:=========
# window
# door
# cabin
# cabin seat
# seat
#
# Inherent functions in order:
# controlling (60)
# storing (27)
# restricting (23)
# holding (22)
# protecting (15)
# covering (11)
# transforming (10)
# emitting (8)
# humaninteraction (8)
# interfacing (7)
# guiding (6)
# generating (5)
# driving (1)
# sensing (1)
# presenting (1)
# ==================================================
#
# Cluster 3 :
# Cluster Size:========= 483
# Sample Docs:=========
# right hand side adaptor broken
# broken drag chain dragline
# headlight bracket broken
# missing GET pin
# grease lines broken on quick hitch
#
# Top words:=========
# hand
# broken
# right
# missing
# left
#
# Top failure modes:=========
# broken
# missing
# loose
# unserviceable
# bent
#
# Top equipment:=========
# bolts
# pin
# bolt
# bucket
# cylinder
#
# Inherent functions in order:
# holding (220)
# guiding (73)
# matterprocessing (35)
# protecting (31)
# covering (24)
# emitting (24)
# controlling (22)
# driving (16)
# interfacing (12)
# storing (12)
# humaninteraction (6)
# presenting (4)
# restricting (2)
# generating (1)
# sensing (1)
# ==================================================
#
# Cluster 4 :
# Cluster Size:========= 196
# Sample Docs:=========
# x front lights missing
# lights power out
# tray light out
# left hand boom light broken
# dash lights not working
#
# Top words:=========
# light
# lights
# out
# not
# on
#
# Top failure modes:=========
# out
# not working
# unserviceable
# blown
# fault
#
# Top equipment:=========
# light
# lights
# boom
# A-frame
# house
#
# Inherent functions in order:
# emitting (157)
# holding (10)
# guiding (8)
# protecting (4)
# interfacing (3)
# presenting (3)
# humaninteraction (3)
# controlling (2)
# covering (1)
# storing (1)
# restricting (1)
# transforming (1)
# driving (1)
# sensing (1)
# ==================================================
#
# Cluster 5 :
# Cluster Size:========= 253
# Sample Docs:=========
# steering rock damage
# leaking radiator seals
# hydraulic lift cylinder making noise
# position brake cooler hose minor leak
# blown hydraulic cooler hose
#
# Top words:=========
# hose
# blown
# leaking
# steering
# cylinder
#
# Top failure modes:=========
# blown
# leaking
# unserviceable
# failed
# noisy
#
# Top equipment:=========
# hose
# cylinder
# steering
# brake
# hydraulic hose
#
# Inherent functions in order:
# guiding (162)
# covering (39)
# driving (20)
# generating (9)
# controlling (6)
# transforming (5)
# holding (4)
# emitting (4)
# storing (2)
# matterprocessing (1)
# protecting (1)
# ==================================================
#
# Cluster 6 :
# Cluster Size:========= 388
# Sample Docs:=========
# seized air conditioner control cable
# brakes will not release
# air conditioner compressor found not working
# not working parts washer pump pressure gauge
# ladder not operating
#
# Top words:=========
# air
# conditioner
# not
# unserviceable
# working
#
# Top failure modes:=========
# unserviceable
# not working
# faulty
# fault
# keeps blowing
#
# Top equipment:=========
# air conditioner
# compressor
# horn
# engine air conditioner
# air horn
#
# Inherent functions in order:
# emitting (114)
# generating (74)
# sensing (42)
# protecting (41)
# presenting (27)
# controlling (20)
# guiding (17)
# driving (12)
# matterprocessing (10)
# covering (8)
# restricting (6)
# interfacing (5)
# transforming (5)
# holding (3)
# storing (3)
# humaninteraction (1)
# ==================================================
#
# Cluster 7 :
# Cluster Size:========= 97
# Sample Docs:=========
# position aftercooler hose unserviceable
# worn position tyre
# position strut pins removed
# damaged position rim
# position guards damaged
#
# Top words:=========
# position
# tyre
# damaged
# damage
# flat
#
# Top failure modes:=========
# damaged
# damage
# flat
# unserviceable
# blown
#
# Top equipment:=========
# tyre
# turbo
# guard
# hoses
# rim
#
# Inherent functions in order:
# guiding (66)
# holding (9)
# protecting (9)
# generating (8)
# restricting (2)
# transforming (1)
# emitting (1)
# sensing (1)
# ==================================================
#
# Cluster 8 :
# Cluster Size:========= 265
# Sample Docs:=========
# oil leak
# oil leak at pony drive pinion drag
# engine coolant leak
# coolant leak transmission cooler
# oil leak at air compressor
#
# Top words:=========
# leak
# oil
# engine
# coolant
# at
#
# Top failure modes:=========
# leak
# leaks
# leaking
# found
# plugged
#
# Top equipment:=========
# oil
# engine
# coolant
# differential
# pump
#
# Inherent functions in order:
# protecting (81)
# driving (37)
# transforming (35)
# generating (19)
# guiding (18)
# controlling (17)
# matterprocessing (16)
# holding (13)
# storing (9)
# interfacing (9)
# emitting (6)
# covering (4)
# presenting (1)
# ==================================================
#
# Cluster 9 :
# Cluster Size:========= 220
# Sample Docs:=========
# drag motor noisy sparking
# hoist drag brake out of adjustment
# swing resolver not counting
# worn hoist brake filter
# walk motor brake fault
#
# Top words:=========
# brake
# hoist
# fault
# drag
# motor
#
# Top failure modes:=========
# fault
# temperature error
# error
# out of adjustment
# need cleaning
#
# Top equipment:=========
# brake
# hoist
# drag
# swing
# motor
#
# Inherent functions in order:
# restricting (74)
# generating (29)
# sensing (21)
# driving (16)
# humaninteraction (12)
# holding (12)
# transforming (11)
# matterprocessing (10)
# presenting (8)
# protecting (7)
# emitting (7)
# guiding (4)
# interfacing (3)
# controlling (2)
# storing (2)
# covering (2)
# ==================================================
#
# Cluster 10 :
# Cluster Size:========= 63
# Sample Docs:=========
# batteries have no charge
# replace blower inverter batteries with no charge
# no power in cabin
# blower inverter batteries show no charge
# drag blower inverter has earthing out
#
# Top words:=========
# batteries
# inverter
# no
# charge
# blower
#
# Top failure modes:=========
# no charge
# earthing out
# no
# dropped cell
# unserviceable
#
# Top equipment:=========
# batteries
# inverter batteries
# blower inverter batteries
# inverter
# drag blower inverter
#
# Inherent functions in order:
# generating (37)
# transforming (12)
# storing (8)
# holding (2)
# emitting (1)
# protecting (1)
# restricting (1)
# sensing (1)
# ==================================================
#
# Cluster 11 :
# Cluster Size:========= 184
# Sample Docs:=========
# liner has a crack
# lost power in the cabin
# crack in fuel tank
# cracked fuel tank
# cracked steering tank mo
#
# Top words:=========
# cracked
# crack
# in
# fuel
# cracks
#
# Top failure modes:=========
# crack
# cracked
# cracks
# broken
# missing
#
# Top equipment:=========
# fuel tank
# tank
# mud bucket
# liner
# exhaust shield
#
# Inherent functions in order:
# protecting (54)
# storing (36)
# holding (24)
# controlling (16)
# interfacing (13)
# matterprocessing (11)
# covering (10)
# guiding (7)
# generating (4)
# transforming (3)
# driving (3)
# restricting (1)
# presenting (1)
# emitting (1)
# ==================================================
#
# Cluster 12 :
# Cluster Size:========= 131
# Sample Docs:=========
# compressor pipe worn through
# worn out controller filter
# damaged bearing housing
# worn bucket teeth
# cutting edge needs
#
# Top words:=========
# worn
# pulley
# number
# bearing
# out
#
# Top failure modes:=========
# worn
# noisy
# worn out
# unserviceable
# need
#
# Top equipment:=========
# pulley
# bearing
# bearings
# bucket
# cutting edges
#
# Inherent functions in order:
# holding (44)
# guiding (36)
# matterprocessing (25)
# protecting (8)
# interfacing (4)
# generating (4)
# storing (3)
# transforming (3)
# controlling (1)
# driving (1)
# restricting (1)
# covering (1)
# ==================================================
#
# Cluster 13 :
# Cluster Size:========= 171
# Sample Docs:=========
# fire system fault
# engine shutdown fault
# engine shutdown fault
# engine derate faults
# transmission level
#
# Top words:=========
# fault
# engine
# transmission
# in
# overheating
#
# Top failure modes:=========
# fault
# overheating
# vibration
# slipping fault
# shutdown fault
#
# Top equipment:=========
# engine
# transmission
# propel
# Tele-Remote
# ladder
#
# Inherent functions in order:
# driving (64)
# transforming (26)
# protecting (19)
# generating (9)
# interfacing (8)
# guiding (8)
# controlling (7)
# humaninteraction (7)
# sensing (6)
# emitting (6)
# holding (6)
# restricting (2)
# presenting (2)
# storing (1)
# ==================================================
#
#
#
# Ave number of documents per cluster: 242.3846153846154
# Median number of documents per cluster: 205
# Min number of documents per cluster: 63
# Max number of documents per cluster: 495
#
# Percentage of clusters with 1 main Inherent function (80% of docs): 0.07692307692307693
# Percentage of clusters with 2 or 3 main Inherent functions (80% of docs): 0.3076923076923077
# Percentage of documents in clusters with 1 main Inherent function (80% of docs): 0.06220247540463345
# Percentage of documents in clusters with 2 or 3 main Inherent functions (80% of docs): 0.17264360520469693

# %%
run_kmeans_best_k(13, w2v_embeddings_all)
# Out:
# Cluster 1 :
# Cluster Size:========= 495
# Sample Docs:=========
# broken bolt on brake pump
# PTO shaft snapped PO
# check movement in steering column
# air conditioner drive leaking oil
# engine is vibrating
#
# Top words:=========
# unserviceable
# pump
# leaking
# on
# air
#
# Top failure modes:=========
# unserviceable
# leaking
# failed
# not working
# faulty
#
# Top equipment:=========
# pump
# PTO
# seal
# shaft
# engine
#
# Inherent functions in order:
# generating (62)
# guiding (55)
# protecting (53)
# controlling (45)
# sensing (43)
# transforming (41)
# holding (39)
# covering (30)
# driving (28)
# emitting (24)
# interfacing (23)
# presenting (22)
# matterprocessing (12)
# storing (9)
# restricting (6)
# humaninteraction (3)
# ==================================================
#
# Cluster 2 :
# Cluster Size:========= 205
# Sample Docs:=========
# needs guard around windscreen wiper mechanical
# cabin seat requires replacing
# broken auto-greaser door window
# cracked door window
# cabin controls seat unserviceable
#
# Top words:=========
# window
# cabin
# door
# broken
# seat
#
# Top failure modes:=========
# broken
# damaged
# cracked
# unserviceable
# faulty
#
# Top equipment:=========
# window
# door
# cabin
# cabin seat
# seat
#
# Inherent functions in order:
# controlling (60)
# storing (27)
# restricting (23)
# holding (22)
# protecting (15)
# covering (11)
# transforming (10)
# emitting (8)
# humaninteraction (8)
# interfacing (7)
# guiding (6)
# generating (5)
# driving (1)
# sensing (1)
# presenting (1)
# ==================================================
#
# Cluster 3 :
# Cluster Size:========= 483
# Sample Docs:=========
# missing rock bucket bolt
# right hand door requires
# left hand track frame bolt broken
# right hand front air tank loose
# wheel chock bracket bent
#
# Top words:=========
# hand
# broken
# right
# missing
# left
#
# Top failure modes:=========
# broken
# missing
# loose
# unserviceable
# bent
#
# Top equipment:=========
# bolts
# pin
# bolt
# bucket
# cylinder
#
# Inherent functions in order:
# holding (220)
# guiding (73)
# matterprocessing (35)
# protecting (31)
# covering (24)
# emitting (24)
# controlling (22)
# driving (16)
# interfacing (12)
# storing (12)
# humaninteraction (6)
# presenting (4)
# restricting (2)
# generating (1)
# sensing (1)
# ==================================================
#
# Cluster 4 :
# Cluster Size:========= 196
# Sample Docs:=========
# house lights not working
# unserviceable cabin light
# VIMS keypad light out
# brake lights unserviceable
# both A-frame upper lights out
#
# Top words:=========
# light
# lights
# out
# not
# on
#
# Top failure modes:=========
# out
# not working
# unserviceable
# blown
# fault
#
# Top equipment:=========
# light
# lights
# boom
# A-frame
# house
#
# Inherent functions in order:
# emitting (157)
# holding (10)
# guiding (8)
# protecting (4)
# interfacing (3)
# presenting (3)
# humaninteraction (3)
# controlling (2)
# covering (1)
# storing (1)
# restricting (1)
# transforming (1)
# driving (1)
# sensing (1)
# ==================================================
#
# Cluster 5 :
# Cluster Size:========= 253
# Sample Docs:=========
# leaking differential cooling hose
# blown o-ring on steering pump
# HMU hose weeping
# blown steering hose in Artic
# CW leaking fan pump
#
# Top words:=========
# hose
# blown
# leaking
# steering
# cylinder
#
# Top failure modes:=========
# blown
# leaking
# unserviceable
# failed
# noisy
#
# Top equipment:=========
# hose
# cylinder
# steering
# brake
# hydraulic hose
#
# Inherent functions in order:
# guiding (162)
# covering (39)
# driving (20)
# generating (9)
# controlling (6)
# transforming (5)
# holding (4)
# emitting (4)
# storing (2)
# matterprocessing (1)
# protecting (1)
# ==================================================
#
# Cluster 6 :
# Cluster Size:========= 388
# Sample Docs:=========
# replace unserviceable cabin air conditioner thermostat
# dragline air conditioner fuse blowing repeatedly
# air conditioner not cold
# compressor is not working
# air conditioner unserviceable
#
# Top words:=========
# air
# conditioner
# not
# unserviceable
# working
#
# Top failure modes:=========
# unserviceable
# not working
# faulty
# fault
# keeps blowing
#
# Top equipment:=========
# air conditioner
# compressor
# horn
# engine air conditioner
# air horn
#
# Inherent functions in order:
# emitting (114)
# generating (74)
# sensing (42)
# protecting (41)
# presenting (27)
# controlling (20)
# guiding (17)
# driving (12)
# matterprocessing (10)
# covering (8)
# restricting (6)
# interfacing (5)
# transforming (5)
# holding (3)
# storing (3)
# humaninteraction (1)
# ==================================================
#
# Cluster 7 :
# Cluster Size:========= 97
# Sample Docs:=========
# position tyre under inflated
# position tyre flat
# blown position tyre
# damaged position guard
# heat separated position tyre
#
# Top words:=========
# position
# tyre
# damaged
# damage
# flat
#
# Top failure modes:=========
# damaged
# damage
# flat
# unserviceable
# blown
#
# Top equipment:=========
# tyre
# turbo
# guard
# hoses
# rim
#
# Inherent functions in order:
# guiding (66)
# holding (9)
# protecting (9)
# generating (8)
# restricting (2)
# transforming (1)
# emitting (1)
# sensing (1)
# ==================================================
#
# Cluster 8 :
# Cluster Size:========= 265
# Sample Docs:=========
# oil leak
# coolant leak at heater
# minor oil leak in engine bay
# engine oil in radiator
# coolant leak
#
# Top words:=========
# leak
# oil
# engine
# coolant
# at
#
# Top failure modes:=========
# leak
# leaks
# leaking
# found
# plugged
#
# Top equipment:=========
# oil
# engine
# coolant
# differential
# pump
#
# Inherent functions in order:
# protecting (81)
# driving (37)
# transforming (35)
# generating (19)
# guiding (18)
# controlling (17)
# matterprocessing (16)
# holding (13)
# storing (9)
# interfacing (9)
# emitting (6)
# covering (4)
# presenting (1)
# ==================================================
#
# Cluster 9 :
# Cluster Size:========= 220
# Sample Docs:=========
# wiring for swing motor rtd incorrect
# drag motor screaming
# drag motor lube shows fault
# flowmeter swing number leaking
# number hoist generator flashed over
#
# Top words:=========
# brake
# hoist
# fault
# drag
# motor
#
# Top failure modes:=========
# fault
# temperature error
# error
# out of adjustment
# need cleaning
#
# Top equipment:=========
# brake
# hoist
# drag
# swing
# motor
#
# Inherent functions in order:
# restricting (74)
# generating (29)
# sensing (21)
# driving (16)
# humaninteraction (12)
# holding (12)
# transforming (11)
# matterprocessing (10)
# presenting (8)
# protecting (7)
# emitting (7)
# guiding (4)
# interfacing (3)
# controlling (2)
# storing (2)
# covering (2)
# ==================================================
#
# Cluster 10 :
# Cluster Size:========= 63
# Sample Docs:=========
# batteries have no charge
# batteries unserviceable
# replace inverter batteries with no charge
# batteries have no charge
# no charge in inverter batteries
#
# Top words:=========
# batteries
# inverter
# no
# charge
# blower
#
# Top failure modes:=========
# no charge
# earthing out
# no
# dropped cell
# unserviceable
#
# Top equipment:=========
# batteries
# inverter batteries
# blower inverter batteries
# inverter
# drag blower inverter
#
# Inherent functions in order:
# generating (37)
# transforming (12)
# storing (8)
# holding (2)
# emitting (1)
# protecting (1)
# restricting (1)
# sensing (1)
# ==================================================
#
# Cluster 11 :
# Cluster Size:========= 184
# Sample Docs:=========
# chassis cracked
# crack in headboard
# cable gantry crack
# cracks in mud bucket
# fuel tank module cracked
#
# Top words:=========
# cracked
# crack
# in
# fuel
# cracks
#
# Top failure modes:=========
# crack
# cracked
# cracks
# broken
# missing
#
# Top equipment:=========
# fuel tank
# tank
# mud bucket
# liner
# exhaust shield
#
# Inherent functions in order:
# protecting (54)
# storing (36)
# holding (24)
# controlling (16)
# interfacing (13)
# matterprocessing (11)
# covering (10)
# guiding (7)
# generating (4)
# transforming (3)
# driving (3)
# restricting (1)
# presenting (1)
# emitting (1)
# ==================================================
#
# Cluster 12 :
# Cluster Size:========= 131
# Sample Docs:=========
# cutting edges need
# worn controller filter
# steering worn
# compressor number tripped out
# worn pulley number
#
# Top words:=========
# worn
# pulley
# number
# bearing
# out
#
# Top failure modes:=========
# worn
# noisy
# worn out
# unserviceable
# need
#
# Top equipment:=========
# pulley
# bearing
# bearings
# bucket
# cutting edges
#
# Inherent functions in order:
# holding (44)
# guiding (36)
# matterprocessing (25)
# protecting (8)
# interfacing (4)
# generating (4)
# storing (3)
# transforming (3)
# controlling (1)
# driving (1)
# restricting (1)
# covering (1)
# ==================================================
#
# Cluster 13 :
# Cluster Size:========= 171
# Sample Docs:=========
# transmission experiencing slipping fault
# transmission slipping fault
# engine overheating text
# erratic engine misfire
# transmission overheating fault
#
# Top words:=========
# fault
# engine
# transmission
# in
# overheating
#
# Top failure modes:=========
# fault
# overheating
# vibration
# slipping fault
# shutdown fault
#
# Top equipment:=========
# engine
# transmission
# propel
# Tele-Remote
# ladder
#
# Inherent functions in order:
# driving (64)
# transforming (26)
# protecting (19)
# generating (9)
# interfacing (8)
# guiding (8)
# controlling (7)
# humaninteraction (7)
# sensing (6)
# emitting (6)
# holding (6)
# restricting (2)
# presenting (2)
# storing (1)
# ==================================================
#
#
#
# Ave number of documents per cluster: 242.3846153846154
# Median number of documents per cluster: 205
# Min number of documents per cluster: 63
# Max number of documents per cluster: 495
#
# Percentage of clusters with 1 main Inherent function (80% of docs): 0.07692307692307693
# Percentage of clusters with 2 or 3 main Inherent functions (80% of docs): 0.3076923076923077
# Percentage of documents in clusters with 1 main Inherent function (80% of docs): 0.06220247540463345
# Percentage of documents in clusters with 2 or 3 main Inherent functions (80% of docs): 0.17264360520469693

# %% [markdown]
# ### Average Hierarchical Clustering

# %%
linkage_data_ave = perform_hierarchical_clustering(w2v_embeddings_all, "average")
# Out:
# NMI: 0.18302476309577487

# %%
get_hierarchical_clusters(18, linkage_data_ave)
# Out:
# Cluster 1 :
# Cluster Size:========= 13
# Sample Docs:=========
# engine overheating
# engine overheating
# engine overheating
# engine overheating
# engine overheating
# transmission overheating
# engine overheating
# engine overheating text
# overheating engine fault
# transmission overheating fault
#
# Top words:=========
# overheating
# engine
# transmission
# fault
# text
#
# Top failure modes:=========
# overheating
# fault
# overheating fault
#
# Top equipment:=========
# engine
# transmission
#
# Inherent functions in order:
# driving (10)
# transforming (3)
# ==================================================
#
# Cluster 2 :
# Cluster Size:========= 4
# Sample Docs:=========
# starter isolator seized
# seized isolator
# starter isolator seized
# seized isolator
#
# Top words:=========
# isolator
# seized
# starter
#
# Top failure modes:=========
# seized
#
# Top equipment:=========
# isolator
# starter
#
# Inherent functions in order:
# controlling (4)
# ==================================================
#
# Cluster 3 :
# Cluster Size:========= 60
# Sample Docs:=========
# batteries need charging
# no charge in batteries
# inverter batteries are not charged
# inverter earthing out
# batteries have no charge
# no charge in batteries
# drag blower inverter has earthing out
# batteries out of service
# inverter batteries showing no charge
# blower inverter batteries show no charge
#
# Top words:=========
# batteries
# inverter
# no
# charge
# blower
#
# Top failure modes:=========
# no charge
# earthing out
# no
# unserviceable
# no power
#
# Top equipment:=========
# batteries
# inverter batteries
# blower inverter batteries
# inverter
# drag blower inverter
#
# Inherent functions in order:
# generating (34)
# transforming (12)
# storing (8)
# holding (2)
# emitting (2)
# restricting (1)
# sensing (1)
# ==================================================
#
# Cluster 4 :
# Cluster Size:========= 80
# Sample Docs:=========
# position tyre damage text
# position damaged tyre
# tyre to be under damage
# blown position tyre
# damages position tyre
# worn position tyre
# worn damaged hose
# damaged position guard
# blown position tyre
# position tyre damaged
#
# Top words:=========
# position
# tyre
# damaged
# damage
# worn
#
# Top failure modes:=========
# damaged
# damage
# flat
# worn
# blown
#
# Top equipment:=========
# tyre
# guard
# hoses
# tyres
# rim
#
# Inherent functions in order:
# guiding (65)
# protecting (8)
# holding (5)
# controlling (2)
# ==================================================
#
# Cluster 5 :
# Cluster Size:========= 34
# Sample Docs:=========
# axle temperature fault
# VIMS error
# engine prelube error
# brake temperature error
# position brake temperature error
# brake temperature error
# brake has temperature error
# bearing temperature
# brake temperature warning fault
# temperature error in brake
#
# Top words:=========
# error
# temperature
# brake
# fault
# hoist
#
# Top failure modes:=========
# temperature error
# error
# fault
# temperature fault
# temperature warning fault
#
# Top equipment:=========
# brake
# hoist brake
# prelube
# axle
# engine
#
# Inherent functions in order:
# restricting (17)
# transforming (5)
# protecting (3)
# generating (3)
# emitting (2)
# holding (2)
# presenting (1)
# sensing (1)
# ==================================================
#
# Cluster 6 :
# Cluster Size:========= 24
# Sample Docs:=========
# leaking radiator
# leaking radiator
# leaking radiator hose
# radiator is blocked with grass
# CW radiator core leak
# blocked radiator due to grass
# radiator blocked with grass
# damaged radiator
# blocked dryer
# clear grass from radiator
#
# Top words:=========
# radiator
# grass
# blocked
# leaking
# by
#
# Top failure modes:=========
# blocked grass
# leaking
# blocked
# leak
# damaged
#
# Top equipment:=========
# radiator
# dryer
# engine
# grass
# spray nozzles
#
# Inherent functions in order:
# emitting (17)
# matterprocessing (1)
# transforming (1)
# restricting (1)
# controlling (1)
# covering (1)
# guiding (1)
# presenting (1)
# ==================================================
#
# Cluster 7 :
# Cluster Size:========= 562
# Sample Docs:=========
# seized air conditioner control cable
# minor torque converter oil leak
# minor oil leak hub
# missing steering cylinder pin
# oil leak at the front of engine
# missing lift cylinder pins
# right hand stick cylinder weeping
# failed servo hose
# oil leak on pump
# coolant leak at heater
#
# Top words:=========
# leak
# hose
# oil
# leaking
# blown
#
# Top failure modes:=========
# leak
# leaking
# blown
# leaks
# unserviceable
#
# Top equipment:=========
# hose
# oil
# cylinder
# engine
# pump
#
# Inherent functions in order:
# guiding (184)
# protecting (81)
# driving (71)
# transforming (46)
# controlling (45)
# covering (41)
# generating (36)
# holding (21)
# matterprocessing (14)
# interfacing (10)
# storing (5)
# emitting (4)
# restricting (3)
# presenting (1)
# ==================================================
#
# Cluster 8 :
# Cluster Size:========= 18
# Sample Docs:=========
# ladder controller unserviceable
# ladder not raise
# ladder issue
# ladder unserviceable
# ladder mirror loose
# ladder not working
# damaged ladder
# ladder fault
# ladder fault
# ladder not operating
#
# Top words:=========
# ladder
# not
# fault
# working
# faulty
#
# Top failure modes:=========
# fault
# not working
# faulty
# issue
# unserviceable
#
# Top equipment:=========
# ladder
# boarding ladder
# mirror
# controller
#
# Inherent functions in order:
# interfacing (16)
# guiding (1)
# controlling (1)
# ==================================================
#
# Cluster 9 :
# Cluster Size:========= 17
# Sample Docs:=========
# alternator failed
# faulty alternator
# bolt missing from alternator
# alternator not charging
# alternator drive leaking
# alternator not charging
# alternator fault
# damaged alternator
# alternator belt missing
# alternator fault
#
# Top words:=========
# alternator
# fault
# not
# charging
# bolt
#
# Top failure modes:=========
# fault
# not charging
# missing
# overcharging
# overcharged
#
# Top equipment:=========
# alternator
# bolt
# light
# belt
# drive
#
# Inherent functions in order:
# generating (11)
# holding (2)
# guiding (2)
# emitting (1)
# driving (1)
# ==================================================
#
# Cluster 10 :
# Cluster Size:========= 15
# Sample Docs:=========
# all brakes require
# brakes locked on
# dragging brakes
# brakes dragging
# hoist brakes faulty
# brakes will not release
# swing brakes not holding
# brakes not releasing
# brakes locked on
# brakes dragging
#
# Top words:=========
# brakes
# not
# holding
# dragging
# hoist
#
# Top failure modes:=========
# not holding
# dragging
# require
# locked on
# won't release
#
# Top equipment:=========
# brakes
# hoist
# swing
#
# Inherent functions in order:
# restricting (15)
# ==================================================
#
# Cluster 11 :
# Cluster Size:========= 18
# Sample Docs:=========
# replace battery with dropped cell
# battery unserviceable dropped cell
# battery dropped cell
# battery cell is dropped
# battery cover hinges seized
# fire suppression controller battery flat
# battery needs replacement for dropped cell
# flat battery
# engine battery light faulty
# battery with dropped cell
#
# Top words:=========
# battery
# dropped
# cell
# with
# replace
#
# Top failure modes:=========
# dropped cell
# unserviceable
# flat
# power
# seized
#
# Top equipment:=========
# battery
# fire suppression controller
# flow battery
# cover
# hinges
#
# Inherent functions in order:
# generating (14)
# storing (2)
# holding (1)
# emitting (1)
# ==================================================
#
# Cluster 12 :
# Cluster Size:========= 79
# Sample Docs:=========
# grease lines broken on quick hitch
# system grease leak
# lube system failure
# grease system fuel system faults
# reported grease system unserviceable
# lube system faults
# grease lines at bucket damaged
# PA system speaker crackling
# broken grease lines on H-link
# grease leak on boom
#
# Top words:=========
# grease
# system
# fire
# lines
# broken
#
# Top failure modes:=========
# broken
# faults
# fault
# leak
# damaged
#
# Top equipment:=========
# lines
# grease lines
# grease system
# fire system
# grease
#
# Inherent functions in order:
# protecting (41)
# guiding (19)
# generating (7)
# holding (6)
# controlling (3)
# emitting (2)
# presenting (1)
# ==================================================
#
# Cluster 13 :
# Cluster Size:========= 101
# Sample Docs:=========
# transmission has slipping fault
# transmission fault
# engine shutdown fault
# drag iov has a fault
# fix the fault in propel
# solenoid lock up fault
# Tele-Remote fault
# transmission temperature fault
# compressor shutdown fault
# rear light fault
#
# Top words:=========
# fault
# transmission
# engine
# in
# propel
#
# Top failure modes:=========
# fault
# slipping fault
# shutdown fault
# electrical fault
# ground fault
#
# Top equipment:=========
# transmission
# engine
# propel
# Tele-Remote
# light
#
# Inherent functions in order:
# driving (25)
# transforming (20)
# emitting (9)
# guiding (8)
# generating (7)
# controlling (7)
# humaninteraction (7)
# presenting (6)
# sensing (4)
# holding (4)
# protecting (3)
# restricting (1)
# ==================================================
#
# Cluster 14 :
# Cluster Size:========= 450
# Sample Docs:=========
# rear camera not working
# unserviceable engine air conditioner
# fan filters plugged
# faulty isolator
# isolator left on
# air conditioner not cold
# main isolator not working
# thermostat needs replacement unserviceable
# air conditioner fans not working
# airhorn not working
#
# Top words:=========
# air
# conditioner
# not
# unserviceable
# working
#
# Top failure modes:=========
# unserviceable
# not working
# faulty
# fault
# keeps blowing
#
# Top equipment:=========
# air conditioner
# compressor
# horn
# engine air conditioner
# lights
#
# Inherent functions in order:
# emitting (140)
# generating (73)
# sensing (46)
# protecting (43)
# presenting (27)
# driving (23)
# guiding (21)
# controlling (19)
# matterprocessing (15)
# interfacing (11)
# covering (8)
# restricting (7)
# transforming (7)
# storing (7)
# holding (2)
# humaninteraction (1)
# ==================================================
#
# Cluster 15 :
# Cluster Size:========= 1342
# Sample Docs:=========
# worn hoist brake filter
# slew pump cavity low
# air leak near side of door
# wear plate bolts missing
# broken bolt see text
# worn filter for hoist brake
# no excitation on hoist
# cutting edges need
# seat belt not retracting correctly
# right hand cam frame rear joint bolts loose
#
# Top words:=========
# hand
# unserviceable
# out
# right
# broken
#
# Top failure modes:=========
# unserviceable
# broken
# missing
# out
# leaking
#
# Top equipment:=========
# light
# brake
# engine
# bolts
# cabin
#
# Inherent functions in order:
# holding (320)
# emitting (174)
# guiding (148)
# protecting (82)
# generating (73)
# sensing (65)
# driving (65)
# covering (62)
# transforming (57)
# matterprocessing (57)
# restricting (55)
# controlling (52)
# storing (46)
# interfacing (31)
# presenting (28)
# humaninteraction (27)
# ==================================================
#
# Cluster 16 :
# Cluster Size:========= 35
# Sample Docs:=========
# bucket requested
# adaptor tooth fell off
# ripper pin missing
# broken tooth adaptor
# another tooth adaptor fell off
# broken tooth
# ripper boot missing pin
# missing tooth lock
# missing ripper tooth pin
# mirror missing
#
# Top words:=========
# missing
# tooth
# bucket
# ripper
# pin
#
# Top failure modes:=========
# missing
# broken
# fell off
# incorrect
# came off
#
# Top equipment:=========
# tooth
# bucket
# pin
# adaptor
# bolts
#
# Inherent functions in order:
# matterprocessing (19)
# holding (10)
# interfacing (2)
# storing (2)
# guiding (1)
# controlling (1)
# ==================================================
#
# Cluster 17 :
# Cluster Size:========= 94
# Sample Docs:=========
# replace broken cabin window
# replace drivers window fault
# auto-greaser door window found broken
# repair broken window
# broken window
# auto-greaser unserviceable
# damaged door window
# repair broken auto-greaser door window
# drivers door seal unserviceable
# broken cabin window
#
# Top words:=========
# window
# broken
# door
# drivers
# cracked
#
# Top failure modes:=========
# broken
# cracked
# damaged
# fault
# unserviceable
#
# Top equipment:=========
# window
# door
# drivers window
# auto-greaser door window
# handrail
#
# Inherent functions in order:
# controlling (45)
# restricting (18)
# covering (10)
# protecting (6)
# humaninteraction (4)
# holding (3)
# generating (3)
# interfacing (2)
# guiding (1)
# driving (1)
# presenting (1)
# ==================================================
#
# Cluster 18 :
# Cluster Size:========= 205
# Sample Docs:=========
# crack in rock deflector
# cracks found in mud bucket
# fuel lines split hose
# cracks ID cable tray supports
# cracks in tray
# cracks in mud bucket
# backhoe windscreen to be fixed
# cracks in stick
# crack found in fuel tank
# exhaust shield is cracked
#
# Top words:=========
# cracked
# crack
# in
# fuel
# tank
#
# Top failure modes:=========
# crack
# cracked
# cracks
# missing
# broken
#
# Top equipment:=========
# fuel tank
# tank
# bucket
# mud bucket
# handrail
#
# Inherent functions in order:
# protecting (57)
# storing (43)
# holding (30)
# controlling (18)
# interfacing (15)
# matterprocessing (14)
# guiding (9)
# covering (8)
# presenting (3)
# driving (3)
# transforming (2)
# restricting (1)
# emitting (1)
# humaninteraction (1)
# ==================================================
#
#
#
# Ave number of documents per cluster: 175.05555555555554
# Median number of documents per cluster: 47.5
# Min number of documents per cluster: 4
# Max number of documents per cluster: 1342
#
# Percentage of clusters with 1 main Inherent function (80% of docs): 0.2222222222222222
# Percentage of clusters with 2 or 3 main Inherent functions (80% of docs): 0.3333333333333333
# Percentage of documents in clusters with 1 main Inherent function (80% of docs): 0.037131069501745474
# Percentage of documents in clusters with 2 or 3 main Inherent functions (80% of docs): 0.07045382418279911

# %% [markdown]
# ### Ward Heirarchical Clustering

# %%
linkage_data_ward = perform_hierarchical_clustering(w2v_embeddings_all, "ward")
# Out:
# NMI: 0.24204393150383777

# %%
get_hierarchical_clusters(13, linkage_data_ward)
# Out:
# Cluster 1 :
# Cluster Size:========= 73
# Sample Docs:=========
# damaged tyre position
# damage to position tyre
# position tyre unserviceable
# position flat tyre
# blown position tyre
# position tyre blown
# flat tyre
# damaged position guard
# position guard damage
# position tyre under inflated
#
# Top words:=========
# position
# tyre
# damaged
# damage
# flat
#
# Top failure modes:=========
# damaged
# damage
# flat
# blown
# worn
#
# Top equipment:=========
# tyre
# guard
# tyres
# rim
# hub
#
# Inherent functions in order:
# guiding (60)
# protecting (8)
# holding (5)
# ==================================================
#
# Cluster 2 :
# Cluster Size:========= 202
# Sample Docs:=========
# coolant leaks
# minor leak differential housing filter
# steering oil leakage
# minor transmission oil leak
# oil leak from differential filter
# oil leak pilot filter text
# coolant leak near engine front
# position inside oil leak
# oil leak at pony drive pinion drag
# oil leak
#
# Top words:=========
# leak
# oil
# engine
# coolant
# minor
#
# Top failure modes:=========
# leak
# leaks
# leaking
# found
# transferring
#
# Top equipment:=========
# oil
# engine
# coolant
# pump
# differential
#
# Inherent functions in order:
# protecting (65)
# driving (29)
# transforming (29)
# generating (14)
# controlling (14)
# holding (12)
# guiding (11)
# matterprocessing (9)
# interfacing (8)
# emitting (4)
# covering (4)
# storing (2)
# presenting (1)
# ==================================================
#
# Cluster 3 :
# Cluster Size:========= 182
# Sample Docs:=========
# blown coolant hose
# blown steering hose
# blown hose
# CW left hand hoist cylinder leaking plug
# blown transmission hose o-ring
# bonnet lift cylinder unserviceable
# blown coolant hose
# right hand ripper tilt cylinder hose damaged
# blown air conditioner hose
# leaking steering cylinder
#
# Top words:=========
# hose
# blown
# cylinder
# steering
# o-ring
#
# Top failure modes:=========
# blown
# leaking
# noisy
# unserviceable
# movement
#
# Top equipment:=========
# hose
# cylinder
# steering
# lift cylinder
# o-ring
#
# Inherent functions in order:
# guiding (93)
# covering (35)
# driving (31)
# holding (10)
# transforming (8)
# controlling (2)
# protecting (2)
# storing (1)
# ==================================================
#
# Cluster 4 :
# Cluster Size:========= 402
# Sample Docs:=========
# radiator blocked
# implement valve fault
# rear steering accumulator leak
# centrifugal oil filter fault
# leaking heater taps
# adaptor leaking at implement valve
# pump drive universal joints noise
# bottom differential rods requires
# differential lube pump leaking
# leaking implement pump
#
# Top words:=========
# leaking
# hose
# unserviceable
# pump
# valve
#
# Top failure modes:=========
# leaking
# unserviceable
# leak
# failed
# blocked
#
# Top equipment:=========
# hose
# pump
# brake
# differential
# radiator
#
# Inherent functions in order:
# guiding (120)
# generating (45)
# controlling (43)
# covering (34)
# transforming (32)
# matterprocessing (26)
# holding (24)
# emitting (23)
# protecting (19)
# storing (14)
# driving (8)
# sensing (5)
# restricting (4)
# presenting (3)
# interfacing (2)
# ==================================================
#
# Cluster 5 :
# Cluster Size:========= 166
# Sample Docs:=========
# cracks in mud bucket
# repair cracked exhaust shield
# blade skin cracked
# fuel tank crack
# repair crack on backhoe windscreen
# crack in radiator guard
# crack in blade liner left hand side
# crack in rock deflector
# rock deflector is cracked
# repair crack in blade liner
#
# Top words:=========
# crack
# cracked
# in
# cracks
# repair
#
# Top failure modes:=========
# crack
# cracked
# cracks
# broken
# no power
#
# Top equipment:=========
# fuel tank
# mud bucket
# tank
# liner
# exhaust shield
#
# Inherent functions in order:
# protecting (56)
# storing (35)
# holding (28)
# controlling (19)
# interfacing (13)
# guiding (5)
# covering (3)
# driving (3)
# restricting (1)
# presenting (1)
# matterprocessing (1)
# sensing (1)
# ==================================================
#
# Cluster 6 :
# Cluster Size:========= 174
# Sample Docs:=========
# cabin seat needs loctite application
# operators seat failure
# drivers door hinge unserviceable
# AM FM radio needs new aerial
# lighting needs to be tagged
# cabin light cover missing
# bent cabin door
# joystick needs
# cabin door sticking
# cabin seat requires replacing
#
# Top words:=========
# window
# cabin
# needs
# door
# seat
#
# Top failure modes:=========
# broken
# unserviceable
# needs replacing
# fault
# damaged
#
# Top equipment:=========
# window
# cabin
# door
# seat
# cabin seat
#
# Inherent functions in order:
# controlling (51)
# storing (27)
# restricting (18)
# emitting (15)
# holding (14)
# protecting (12)
# transforming (11)
# covering (8)
# humaninteraction (5)
# generating (4)
# guiding (3)
# sensing (3)
# driving (1)
# interfacing (1)
# presenting (1)
# ==================================================
#
# Cluster 7 :
# Cluster Size:========= 682
# Sample Docs:=========
# chain snapped
# A-frame lights out
# boom lights out fault
# damaged handrails
# pin come out bucket GET
# right hand scoreboard not working
# belly plate bolt missing
# emergency gate latch broken
# outer left hand tooth missing
# windrow light out
#
# Top words:=========
# hand
# broken
# right
# left
# out
#
# Top failure modes:=========
# broken
# missing
# out
# loose
# unserviceable
#
# Top equipment:=========
# light
# bolts
# pin
# lights
# bucket
#
# Inherent functions in order:
# holding (239)
# emitting (155)
# guiding (82)
# protecting (39)
# covering (34)
# matterprocessing (33)
# controlling (30)
# interfacing (16)
# storing (14)
# humaninteraction (11)
# presenting (7)
# generating (7)
# restricting (6)
# driving (5)
# transforming (2)
# sensing (2)
# ==================================================
#
# Cluster 8 :
# Cluster Size:========= 53
# Sample Docs:=========
# inverter earthing out
# no charge in batteries
# drag blower inverter earthing out
# replace blower inverter batteries with no charge
# blower inverter batteries have no charge
# no charge in inverter batteries
# replace batteries with no charge
# inverter batteries have no charge
# batteries are no charge
# earthing issue with inverter
#
# Top words:=========
# batteries
# inverter
# charge
# no
# blower
#
# Top failure modes:=========
# no charge
# earthing out
# no
# unserviceable
# charge
#
# Top equipment:=========
# batteries
# inverter batteries
# blower inverter batteries
# inverter
# drag blower inverter
#
# Inherent functions in order:
# generating (34)
# transforming (11)
# storing (7)
# restricting (1)
# ==================================================
#
# Cluster 9 :
# Cluster Size:========= 184
# Sample Docs:=========
# hoist brake number position out of adjustment
# rear axle overheating
# swing motor unbalance fault
# address brake temperature error
# drag generator fault
# torque converter temperature error
# drag chain fault
# brake ECM errors
# drag generator drive fault
# clean walk motor brake switches needed
#
# Top words:=========
# brake
# fault
# hoist
# motor
# drag
#
# Top failure modes:=========
# fault
# temperature error
# error
# out of adjustment
# need cleaning
#
# Top equipment:=========
# brake
# hoist
# drag
# swing
# motor
#
# Inherent functions in order:
# restricting (57)
# generating (23)
# sensing (18)
# driving (15)
# transforming (14)
# humaninteraction (12)
# protecting (9)
# emitting (8)
# guiding (7)
# matterprocessing (5)
# presenting (5)
# holding (5)
# interfacing (3)
# storing (2)
# covering (1)
# ==================================================
#
# Cluster 10 :
# Cluster Size:========= 117
# Sample Docs:=========
# worn pulley number
# worn number pulley
# worn out bearings
# cutting edges worn out
# worn out engine fan belt
# controller filter is worn
# bonnet mounts worn
# evaporator fans getting noisy
# pulley number failed bearings
# bearing noisy
#
# Top words:=========
# worn
# pulley
# bearing
# number
# cutting
#
# Top failure modes:=========
# worn
# unserviceable
# noisy
# worn out
# found
#
# Top equipment:=========
# pulley
# bearing
# bearings
# cutting edges
# bucket
#
# Inherent functions in order:
# holding (37)
# matterprocessing (33)
# guiding (29)
# protecting (11)
# interfacing (3)
# generating (3)
# restricting (1)
# ==================================================
#
# Cluster 11 :
# Cluster Size:========= 323
# Sample Docs:=========
# wiper fuse is blowing
# air conditioner compressor is tripping out
# spray faults
# auto-greaser not working
# reverse camera not working
# dragline air conditioner requires change out
# compressor lost power
# air horn fault
# air conditioner inoperative
# compressor tripping out
#
# Top words:=========
# air
# conditioner
# not
# working
# compressor
#
# Top failure modes:=========
# not working
# unserviceable
# fault
# keeps blowing
# faults
#
# Top equipment:=========
# air conditioner
# compressor
# horn
# engine air conditioner
# air horn
#
# Inherent functions in order:
# emitting (121)
# generating (64)
# protecting (35)
# sensing (26)
# presenting (23)
# guiding (13)
# covering (9)
# controlling (7)
# transforming (6)
# driving (5)
# storing (4)
# holding (4)
# restricting (3)
# matterprocessing (2)
# humaninteraction (1)
# ==================================================
#
# Cluster 12 :
# Cluster Size:========= 343
# Sample Docs:=========
# unserviceable box coupling
# lube system in alarm
# pto pump contamination switch remains on
# battery dropped cell
# pressure compensator is weeping
# tripping main circuit breaker
# lube system failure
# synchronous motor trip
# faulty starter motor
# replace weeping pressure compensator
#
# Top words:=========
# unserviceable
# pump
# not
# on
# system
#
# Top failure modes:=========
# unserviceable
# faulty
# not working
# on
# fault
#
# Top equipment:=========
# motor
# battery
# pump
# brakes
# grease system
#
# Inherent functions in order:
# sensing (57)
# protecting (49)
# generating (41)
# driving (26)
# controlling (24)
# interfacing (23)
# presenting (23)
# holding (21)
# restricting (20)
# guiding (14)
# emitting (14)
# transforming (13)
# storing (6)
# matterprocessing (6)
# humaninteraction (4)
# covering (2)
# ==================================================
#
# Cluster 13 :
# Cluster Size:========= 250
# Sample Docs:=========
# transmission fault
# engine low power fault
# engine shutdown
# overheating engine fault
# front ladder requires
# Tele-Remote bogging
# engine stalling
# engine smokey
# engine will not start
# engine overheating
#
# Top words:=========
# fault
# engine
# transmission
# oil
# not
#
# Top failure modes:=========
# fault
# overheating
# leak
# leaking
# vibration
#
# Top equipment:=========
# engine
# transmission
# ladder
# oil
# alternator
#
# Inherent functions in order:
# driving (76)
# transforming (27)
# generating (26)
# guiding (23)
# protecting (19)
# interfacing (18)
# emitting (13)
# holding (9)
# restricting (8)
# controlling (8)
# humaninteraction (7)
# matterprocessing (5)
# sensing (5)
# presenting (5)
# storing (1)
# ==================================================
#
#
#
# Ave number of documents per cluster: 242.3846153846154
# Median number of documents per cluster: 184
# Min number of documents per cluster: 53
# Max number of documents per cluster: 682
#
# Percentage of clusters with 1 main Inherent function (80% of docs): 0.07692307692307693
# Percentage of clusters with 2 or 3 main Inherent functions (80% of docs): 0.23076923076923078
# Percentage of documents in clusters with 1 main Inherent function (80% of docs): 0.02316724849254205
# Percentage of documents in clusters with 2 or 3 main Inherent functions (80% of docs): 0.11171056807362742

# %% [markdown]
# ## Approach 2: SBERT Clustering

# %%
SBERT_embeddings_all = sbert.encode(X_train+X_test)

# %% [markdown]
# ### K-means Clustering

# %%
perform_kmeans(SBERT_embeddings_all)
# Out:
# 5 / 30
# 6 / 30
# 7 / 30
# 8 / 30
# 9 / 30
# 10 / 30
# 11 / 30
# 12 / 30
# 13 / 30
# 14 / 30
# 15 / 30
# 16 / 30
# 17 / 30
# 18 / 30
# 19 / 30
# 20 / 30
# 21 / 30
# 22 / 30
# 23 / 30
# 24 / 30
# 25 / 30
# 26 / 30
# 27 / 30
# 28 / 30
# 29 / 30
# NMI: 0.14530974533454702

# %%
run_kmeans_best_k(15, SBERT_embeddings_all)
# Out:
# Cluster 1 :
# Cluster Size:========= 155
# Sample Docs:=========
# no power in cabin
# light fault
# dash lights keep staying on
# headlight out light
# roof lights not working
#
# Top words:=========
# lights
# out
# light
# on
# batteries
#
# Top failure modes:=========
# out
# not working
# no charge
# fault
# unserviceable
#
# Top equipment:=========
# lights
# light
# batteries
# battery
# boom
#
# Inherent functions in order:
# emitting (90)
# generating (24)
# holding (8)
# storing (8)
# protecting (6)
# sensing (5)
# controlling (4)
# presenting (2)
# humaninteraction (2)
# covering (2)
# guiding (2)
# restricting (1)
# transforming (1)
# ==================================================
#
# Cluster 2 :
# Cluster Size:========= 141
# Sample Docs:=========
# blown hydraulic hose on boom
# blow by fault on engine
# replace blown air conditioner hose o-ring
# blown hose
# air horn fault
#
# Top words:=========
# blown
# hose
# air
# o-ring
# on
#
# Top failure modes:=========
# blown
# not working
# missing
# needs replaced
# keeps blowing
#
# Top equipment:=========
# hose
# o-ring
# air conditioner
# horn
# air horn
#
# Inherent functions in order:
# guiding (71)
# covering (30)
# presenting (15)
# protecting (9)
# emitting (5)
# matterprocessing (4)
# generating (4)
# driving (2)
# holding (1)
# ==================================================
#
# Cluster 3 :
# Cluster Size:========= 197
# Sample Docs:=========
# grease fitting coupling unserviceable
# oil centrifuge gasket leaking right hand engine
# circuit grease pump unserviceable
# engine oil leak
# lube fault
#
# Top words:=========
# oil
# leak
# grease
# hydraulic
# pump
#
# Top failure modes:=========
# leak
# leaking
# unserviceable
# not working
# fault
#
# Top equipment:=========
# oil
# engine
# pump
# hose
# hydraulic oil
#
# Inherent functions in order:
# protecting (45)
# generating (30)
# guiding (28)
# driving (23)
# holding (14)
# controlling (13)
# matterprocessing (12)
# transforming (10)
# storing (5)
# sensing (5)
# presenting (4)
# covering (3)
# interfacing (2)
# humaninteraction (2)
# emitting (1)
# ==================================================
#
# Cluster 4 :
# Cluster Size:========= 348
# Sample Docs:=========
# weightometer not working
# hoist motor overtemperature
# swing pump contamination switch keeps staying on
# depth counter issue
# slew pump chip sensor is alarming
#
# Top words:=========
# drag
# swing
# hoist
# number
# fault
#
# Top failure modes:=========
# fault
# unserviceable
# leaking
# noisy
# broken
#
# Top equipment:=========
# pulley
# hoist
# drag
# swing
# bearing
#
# Inherent functions in order:
# holding (75)
# guiding (39)
# transforming (33)
# protecting (33)
# sensing (30)
# generating (27)
# driving (25)
# interfacing (21)
# covering (12)
# restricting (11)
# emitting (11)
# presenting (10)
# matterprocessing (7)
# controlling (6)
# humaninteraction (5)
# storing (3)
# ==================================================
#
# Cluster 5 :
# Cluster Size:========= 107
# Sample Docs:=========
# air conditioner not working low on gas
# air conditioner blowing hot when going uphill
# air conditioner hot cold
# air conditioner in PLC room not working
# air conditioner compressor tripping out
#
# Top words:=========
# air
# conditioner
# not
# working
# compressor
#
# Top failure modes:=========
# not working
# unserviceable
# fault
# leaking
# not cold
#
# Top equipment:=========
# air conditioner
# compressor
# belt
# drive
# fan
#
# Inherent functions in order:
# emitting (61)
# generating (18)
# guiding (8)
# covering (4)
# driving (4)
# sensing (3)
# matterprocessing (3)
# protecting (2)
# controlling (2)
# transforming (1)
# restricting (1)
# ==================================================
#
# Cluster 6 :
# Cluster Size:========= 215
# Sample Docs:=========
# bent belly plate
# centre hitch wear
# upper centre pin bolts broken
# position aftercooler hose unserviceable
# rear differential pinnion seal leaking
#
# Top words:=========
# position
# rear
# tyre
# front
# steering
#
# Top failure modes:=========
# unserviceable
# leaking
# leak
# damage
# missing
#
# Top equipment:=========
# tyre
# steering
# light
# door
# differential
#
# Inherent functions in order:
# guiding (50)
# holding (38)
# emitting (31)
# controlling (23)
# covering (13)
# transforming (10)
# protecting (8)
# sensing (8)
# restricting (7)
# storing (7)
# generating (6)
# interfacing (5)
# driving (4)
# matterprocessing (3)
# presenting (1)
# humaninteraction (1)
# ==================================================
#
# Cluster 7 :
# Cluster Size:========= 158
# Sample Docs:=========
# right hand steering cylinder leaking
# left hand cam frame rear joint bolts loose
# right hand reverse light right hand cabin light out
# right hand drag chain snapped at socket end
# right hand vertical fairlead roller bearing unserviceable
#
# Top words:=========
# hand
# right
# left
# side
# unserviceable
#
# Top failure modes:=========
# unserviceable
# broken
# leaking
# loose
# missing
#
# Top equipment:=========
# cylinder
# light
# headlight
# bolts
# chain
#
# Inherent functions in order:
# holding (48)
# guiding (25)
# emitting (25)
# driving (14)
# storing (8)
# controlling (8)
# interfacing (6)
# protecting (6)
# covering (6)
# matterprocessing (4)
# humaninteraction (3)
# sensing (2)
# generating (1)
# restricting (1)
# presenting (1)
# ==================================================
#
# Cluster 8 :
# Cluster Size:========= 196
# Sample Docs:=========
# grease leaks on H-link
# oil leak behind
# coolant leak at position turbo
# dust leak operators side window
# coolant leak on upper deck
#
# Top words:=========
# leak
# oil
# leaking
# at
# hose
#
# Top failure modes:=========
# leak
# leaking
# leaks
# leaky
#
# Top equipment:=========
# oil
# coolant
# hose
# pump
# engine
#
# Inherent functions in order:
# protecting (56)
# guiding (43)
# driving (15)
# generating (14)
# transforming (14)
# controlling (12)
# covering (10)
# emitting (7)
# holding (7)
# matterprocessing (6)
# interfacing (6)
# storing (5)
# restricting (1)
# ==================================================
#
# Cluster 9 :
# Cluster Size:========= 424
# Sample Docs:=========
# drivers window is faulty
# fire extinguisher out of date
# fire extinguisher missing
# compressor not working
# fuel filter plugged intermittently
#
# Top words:=========
# engine
# fault
# not
# unserviceable
# transmission
#
# Top failure modes:=========
# fault
# unserviceable
# leak
# leaking
# not working
#
# Top equipment:=========
# engine
# transmission
# pump
# compressor
# hose
#
# Inherent functions in order:
# driving (80)
# generating (76)
# protecting (53)
# guiding (43)
# emitting (35)
# transforming (30)
# controlling (20)
# holding (19)
# matterprocessing (18)
# sensing (16)
# storing (10)
# restricting (9)
# covering (8)
# presenting (6)
# interfacing (1)
# ==================================================
#
# Cluster 10 :
# Cluster Size:========= 281
# Sample Docs:=========
# broken window handle
# repair needed for engine air conditioner
# broken crowd cylinder guard
# blown steering hose in Artic
# bolts missing
#
# Top words:=========
# broken
# damaged
# faulty
# on
# fault
#
# Top failure modes:=========
# broken
# damaged
# faulty
# fault
# missing
#
# Top equipment:=========
# bolts
# window
# bolt
# steering
# hose
#
# Inherent functions in order:
# holding (63)
# guiding (53)
# controlling (29)
# protecting (26)
# emitting (15)
# humaninteraction (14)
# restricting (14)
# generating (12)
# interfacing (9)
# sensing (8)
# covering (7)
# transforming (7)
# matterprocessing (7)
# driving (6)
# presenting (6)
# storing (5)
# ==================================================
#
# Cluster 11 :
# Cluster Size:========= 93
# Sample Docs:=========
# unserviceable swing brake cylinder
# unserviceable head pulley
# auto-greaser unserviceable
# battery unserviceable
# horn unserviceable
#
# Top words:=========
# unserviceable
# air
# replace
# conditioner
# engine
#
# Top failure modes:=========
# unserviceable
# requires
# missing
# running hot
# dropped
#
# Top equipment:=========
# pulley
# hose
# cylinder
# compressor
# engine air conditioner
#
# Inherent functions in order:
# generating (16)
# emitting (16)
# guiding (15)
# sensing (10)
# holding (7)
# controlling (6)
# driving (6)
# interfacing (4)
# matterprocessing (4)
# presenting (3)
# covering (2)
# storing (2)
# transforming (1)
# protecting (1)
# ==================================================
#
# Cluster 12 :
# Cluster Size:========= 105
# Sample Docs:=========
# exhaust brake faulty
# park brake fault
# hoist brake filter is worn
# brake cooling hose leaking
# faulty brake sensor task
#
# Top words:=========
# brake
# fault
# park
# brakes
# hose
#
# Top failure modes:=========
# fault
# leaking
# temperature error
# blown
# not releasing
#
# Top equipment:=========
# brake
# park brake
# brakes
# hose
# cooling hose
#
# Inherent functions in order:
# restricting (58)
# guiding (19)
# emitting (6)
# presenting (5)
# humaninteraction (4)
# controlling (3)
# storing (2)
# matterprocessing (2)
# covering (2)
# sensing (2)
# interfacing (1)
# holding (1)
# ==================================================
#
# Cluster 13 :
# Cluster Size:========= 128
# Sample Docs:=========
# repair crack in liner
# cracked glass in entry door
# cracked suction tube
# crack left hand window frame
# cracks in headboard
#
# Top words:=========
# in
# cracked
# crack
# cracks
# repair
#
# Top failure modes:=========
# crack
# cracked
# cracks
# broken
# cracking
#
# Top equipment:=========
# fuel tank
# bucket
# tank
# liner
# mud bucket
#
# Inherent functions in order:
# protecting (32)
# holding (24)
# storing (23)
# controlling (15)
# interfacing (9)
# guiding (8)
# restricting (6)
# covering (4)
# driving (3)
# transforming (2)
# matterprocessing (2)
# ==================================================
#
# Cluster 14 :
# Cluster Size:========= 75
# Sample Docs:=========
# cabin seal may be worn
# left cabin air conditioner earth leakage fault
# cabin windows need
# cabin seat needs
# cabin air conditioner thermostat found unserviceable
#
# Top words:=========
# cabin
# air
# conditioner
# seat
# needs
#
# Top failure modes:=========
# unserviceable
# needs loctite
# broken
# needs
# needs replacing
#
# Top equipment:=========
# cabin
# cabin seat
# door
# seat
# cabin window
#
# Inherent functions in order:
# controlling (14)
# storing (14)
# emitting (9)
# holding (9)
# covering (9)
# protecting (5)
# sensing (5)
# generating (4)
# interfacing (3)
# restricting (1)
# humaninteraction (1)
# presenting (1)
# ==================================================
#
# Cluster 15 :
# Cluster Size:========= 528
# Sample Docs:=========
# boom point sheave bumper rubber cracked
# number pinion broken bolt
# no charge in batteries
# worn seat cover
# x failed condensor fans
#
# Top words:=========
# out
# worn
# missing
# on
# not
#
# Top failure modes:=========
# missing
# worn
# unserviceable
# fault
# out
#
# Top equipment:=========
# bucket
# pin
# PTO
# bolts
# latch
#
# Inherent functions in order:
# holding (94)
# guiding (56)
# matterprocessing (48)
# transforming (44)
# controlling (43)
# protecting (42)
# emitting (41)
# generating (29)
# sensing (23)
# storing (21)
# interfacing (20)
# covering (18)
# driving (17)
# presenting (15)
# restricting (9)
# humaninteraction (8)
# ==================================================
#
#
#
# Ave number of documents per cluster: 210.06666666666666
# Median number of documents per cluster: 158
# Min number of documents per cluster: 75
# Max number of documents per cluster: 528
#
# Percentage of clusters with 1 main Inherent function (80% of docs): 0.0
# Percentage of clusters with 2 or 3 main Inherent functions (80% of docs): 0.13333333333333333
# Percentage of documents in clusters with 1 main Inherent function (80% of docs): 0.0
# Percentage of documents in clusters with 2 or 3 main Inherent functions (80% of docs): 0.07870517296096477

# %% [markdown]
# ### Average Hierarchical Clustering

# %%
linkage_data_ave = perform_hierarchical_clustering(SBERT_embeddings_all, "average")
# Out:
# NMI: 0.0646007050087649

# %%
get_hierarchical_clusters(15, linkage_data_ave)
# Out:
# Cluster 1 :
# Cluster Size:========= 11
# Sample Docs:=========
# vims keypad light remains out
# VIMS keypad light out
# replace vims keypad light out
# vims keypad light found out
# VIMS keypad backlight blown
# vims keypad light needs cleaning out
# VIMS error
# vims keypad light needs clean out
# vims keypad light is out
# vims keypad light needs a clean out
#
# Top words:=========
# keypad
# light
# out
# vims
# VIMS
#
# Top failure modes:=========
# out
# needs clean out
# error
# blown
#
# Top equipment:=========
# vims keypad light
# VIMS
# keypad
# backlight
# light
#
# Inherent functions in order:
# emitting (10)
# presenting (1)
# ==================================================
#
# Cluster 2 :
# Cluster Size:========= 2
# Sample Docs:=========
# PCR room air conditioner fault
# PCR air conditioner wiring burnt out
#
# Top words:=========
# PCR
# air
# conditioner
# wiring
# burnt
#
# Top failure modes:=========
# burnt out
# fault
#
# Top equipment:=========
# air conditioner
# wiring
#
# Inherent functions in order:
# guiding (1)
# emitting (1)
# ==================================================
#
# Cluster 3 :
# Cluster Size:========= 4
# Sample Docs:=========
# controller filter worn out
# environmental filter fittings oil leaks
# number filter fan unserviceable
# controller filter is worn
#
# Top words:=========
# filter
# controller
# worn
# out
# number
#
# Top failure modes:=========
# worn
# unserviceable
# leaks
#
# Top equipment:=========
# controller filter
# filter
# fan
# environmental filter
# fittings
#
# Inherent functions in order:
# matterprocessing (2)
# generating (1)
# interfacing (1)
# ==================================================
#
# Cluster 4 :
# Cluster Size:========= 5
# Sample Docs:=========
# out of adjustment hoist brake
# end of line pressure switch playing up
# out of adjustment hoist drag brake
# cavity of slew pump low
# because of flat batteries again
#
# Top words:=========
# of
# out
# adjustment
# hoist
# brake
#
# Top failure modes:=========
# out of adjustment
# flat
# playing up
# low
#
# Top equipment:=========
# hoist brake
# batteries
# hoist drag brake
# line
# pressure switch
#
# Inherent functions in order:
# restricting (2)
# storing (1)
# sensing (1)
# interfacing (1)
# ==================================================
#
# Cluster 5 :
# Cluster Size:========= 3
# Sample Docs:=========
# lost arch anchor link pin
# at least the front rollers unserviceable
# lost all lights
#
# Top words:=========
# lost
# all
# lights
# at
# least
#
# Top failure modes:=========
# lost
# unserviceable
#
# Top equipment:=========
# lights
# rollers
# arch
# anchor link
# pin
#
# Inherent functions in order:
# holding (2)
# emitting (1)
# ==================================================
#
# Cluster 6 :
# Cluster Size:========= 16
# Sample Docs:=========
# beacon mount broken
# am/fm radio needs aerial replacement
# no reception on AM FM radio
# am/fm radio needs aerial
# aerial needed for am/fm radio
# tractor radio unserviceable
# beacon mount is broken
# beacon not working
# am fm radio needs an aerial
# aerial needed for am fm radio
#
# Top words:=========
# radio
# aerial
# am
# fm
# am/fm
#
# Top failure modes:=========
# needs aerial
# broken
# no reception
# unserviceable
# needs
#
# Top equipment:=========
# am / fm radio
# radio
# beacon
# AM / FM radio
# mount
#
# Inherent functions in order:
# transforming (13)
# holding (2)
# emitting (1)
# ==================================================
#
# Cluster 7 :
# Cluster Size:========= 26
# Sample Docs:=========
# boom creeping down
# power step control cable broken
# no charge in blower inverter batteries
# no charge in batteries
# no charge in inverter batteries
# no charge in inverter batteries
# will not start batteries unserviceable
# boom point light out
# no power in cabin
# creeping bucket
#
# Top words:=========
# no
# in
# batteries
# boom
# charge
#
# Top failure modes:=========
# no charge
# no power
# out
# not working
# no
#
# Top equipment:=========
# boom
# batteries
# boom point
# cabin
# blower inverter batteries
#
# Inherent functions in order:
# generating (8)
# holding (7)
# emitting (3)
# storing (2)
# covering (1)
# driving (1)
# humaninteraction (1)
# restricting (1)
# sensing (1)
# guiding (1)
# ==================================================
#
# Cluster 8 :
# Cluster Size:========= 34
# Sample Docs:=========
# Tele-Remote fault no data or pictures
# screen unserviceable
# mirrors right hand mirror missing bolt missing
# reverse camera very dark
# TV monitor has no signal
# camera monitor in cabin faulty
# faulty cameras
# reverse camera unserviceable
# Tele-Remote issues
# unserviceable screen
#
# Top words:=========
# Tele-Remote
# camera
# fault
# unserviceable
# mirror
#
# Top failure modes:=========
# fault
# unserviceable
# not working
# missing
# broken
#
# Top equipment:=========
# Tele-Remote
# camera
# mirror
# reverse camera
# screen
#
# Inherent functions in order:
# sensing (9)
# humaninteraction (9)
# guiding (6)
# matterprocessing (5)
# presenting (3)
# holding (1)
# transforming (1)
# ==================================================
#
# Cluster 9 :
# Cluster Size:========= 44
# Sample Docs:=========
# solenoid lock up fault
# missing pin
# mast locked indicator light unserviceable
# pin come out of dogbone
# locked steels
# ripper mount pin out
# pin out of equaliser bar
# pin coming out of brace
# no clevis pin grease
# alarm triggered by slew pump chip sensor
#
# Top words:=========
# pin
# out
# ripper
# missing
# of
#
# Top failure modes:=========
# missing
# out
# no
# unserviceable
# coming out
#
# Top equipment:=========
# pin
# clevis pin grease
# ripper
# dogbone
# bucket
#
# Inherent functions in order:
# holding (22)
# protecting (5)
# guiding (3)
# presenting (3)
# matterprocessing (3)
# emitting (2)
# sensing (2)
# driving (1)
# controlling (1)
# covering (1)
# interfacing (1)
# ==================================================
#
# Cluster 10 :
# Cluster Size:========= 9
# Sample Docs:=========
# gantry chain broken
# box coupling unserviceable
# coupling unserviceable
# box coupling is unserviceable
# Goanna Bar missing pin
# universal joint behind centre bearing has movement
# input seal into left hand walk gearbox is leaking
# duo-cone seals leaking number swing
# box coupling found unserviceable
#
# Top words:=========
# coupling
# unserviceable
# box
# is
# leaking
#
# Top failure modes:=========
# unserviceable
# leaking
# movement
# broken
# missing
#
# Top equipment:=========
# box coupling
# universal joint
# centre bearing
# bearing
# coupling
#
# Inherent functions in order:
# interfacing (4)
# guiding (2)
# covering (2)
# holding (1)
# ==================================================
#
# Cluster 11 :
# Cluster Size:========= 116
# Sample Docs:=========
# unserviceable left hand bucket cylinder hose
# unserviceable brake hose number propel
# seized isolator
# light unserviceable
# fix the fault in propel
# unserviceable air compressor
# unserviceable starter PO
# faulty isolator not turning
# unserviceable grease pump
# replace unserviceable pump contamination switch
#
# Top words:=========
# unserviceable
# air
# conditioner
# replace
# isolator
#
# Top failure modes:=========
# unserviceable
# seized
# not working
# failed
# faulty
#
# Top equipment:=========
# isolator
# pump
# siren
# hose
# cylinder
#
# Inherent functions in order:
# emitting (20)
# controlling (19)
# generating (17)
# guiding (14)
# sensing (11)
# driving (9)
# holding (8)
# transforming (4)
# restricting (3)
# protecting (2)
# covering (2)
# matterprocessing (2)
# storing (2)
# interfacing (2)
# presenting (1)
# ==================================================
#
# Cluster 12 :
# Cluster Size:========= 28
# Sample Docs:=========
# tracks loose
# watermeter lights sticking on %
# weightometer found not working
# sensor for walk motor brake not reading
# reported tracks loose
# flowmeter swing number leaking
# weightometer is not working
# speedometer not working
# speedometer has stopped working
# smart meter not communicating
#
# Top words:=========
# not
# working
# speedometer
# tracks
# weightometer
#
# Top failure modes:=========
# not working
# unserviceable
# leaking
# loose
# coming out
#
# Top equipment:=========
# speedometer
# tracks
# weightometer
# gauge
# flowmeter
#
# Inherent functions in order:
# sensing (15)
# guiding (6)
# presenting (4)
# holding (2)
# emitting (1)
# ==================================================
#
# Cluster 13 :
# Cluster Size:========= 62
# Sample Docs:=========
# needs right hand side fire extinguisher
# PTO drive shaft rear universal joint unserviceable
# needs new cutting edge
# PTO shaft requires
# dash broken
# needs new boot
# PTO shaft unserviceable PO
# mechanical PTO not meshing
# PTO shaft requires rear universal joint slip yoke
# need to worn rollers in dirt chute
#
# Top words:=========
# PTO
# CW
# pto
# shaft
# not
#
# Top failure modes:=========
# leaking
# failed
# unserviceable
# emptying
# on
#
# Top equipment:=========
# PTO
# shaft
# engine
# pto cavity
# turbo
#
# Inherent functions in order:
# transforming (12)
# guiding (10)
# driving (5)
# interfacing (5)
# holding (4)
# emitting (4)
# covering (4)
# generating (4)
# sensing (3)
# storing (3)
# protecting (2)
# matterprocessing (2)
# controlling (1)
# humaninteraction (1)
# presenting (1)
# restricting (1)
# ==================================================
#
# Cluster 14 :
# Cluster Size:========= 240
# Sample Docs:=========
# number input shaft seal leaking
# not meshing pto
# right hand drag rope clamp broken
# number drag motor input shaft seal leaking
# top left light cable broke on cabin
# right hand headlight out
# left hand outer door handle sloppy cabin
# right hand side front bonnet not locking in place
# left hand broken mirror
# right hand damaged dump rope
#
# Top words:=========
# hand
# left
# right
# side
# unserviceable
#
# Top failure modes:=========
# unserviceable
# broken
# leaking
# loose
# missing
#
# Top equipment:=========
# cylinder
# light
# headlight
# bolts
# chain
#
# Inherent functions in order:
# holding (59)
# emitting (40)
# guiding (34)
# driving (17)
# protecting (15)
# matterprocessing (15)
# controlling (11)
# covering (10)
# sensing (10)
# storing (9)
# interfacing (6)
# generating (4)
# transforming (3)
# humaninteraction (3)
# restricting (2)
# presenting (2)
# ==================================================
#
# Cluster 15 :
# Cluster Size:========= 2551
# Sample Docs:=========
# electrical fault brakes
# missing bolts in dirt sheave pedestal
# replace dragline air conditioner fuse blowing
# missing lamp cover
# crack on bucket
# brake pump pressure gauge is not working
# bent front wheel guards
# brake cooling return hose leaking
# worn padding
# repair broken handrail weld
#
# Top words:=========
# air
# leak
# oil
# conditioner
# hose
#
# Top failure modes:=========
# leak
# fault
# unserviceable
# leaking
# broken
#
# Top equipment:=========
# hose
# oil
# engine
# air conditioner
# brake
#
# Inherent functions in order:
# guiding (383)
# holding (300)
# protecting (300)
# emitting (270)
# generating (227)
# controlling (166)
# driving (166)
# transforming (120)
# restricting (110)
# covering (110)
# storing (96)
# matterprocessing (91)
# interfacing (67)
# sensing (65)
# presenting (54)
# humaninteraction (26)
# ==================================================
#
#
#
# Ave number of documents per cluster: 210.06666666666666
# Median number of documents per cluster: 26
# Min number of documents per cluster: 2
# Max number of documents per cluster: 2551
#
# Percentage of clusters with 1 main Inherent function (80% of docs): 0.13333333333333333
# Percentage of clusters with 2 or 3 main Inherent functions (80% of docs): 0.4
# Percentage of documents in clusters with 1 main Inherent function (80% of docs): 0.00856870834655665
# Percentage of documents in clusters with 2 or 3 main Inherent functions (80% of docs): 0.016185337987940335

# %% [markdown]
# ### Ward Hierarchical Clustering

# %%
linkage_data_ward = perform_hierarchical_clustering(SBERT_embeddings_all, "ward")
# Out:
# NMI: 0.12863992347025982

# %%
get_hierarchical_clusters(15, linkage_data_ward)
# Out:
# Cluster 1 :
# Cluster Size:========= 153
# Sample Docs:=========
# right hand stick cylinder weeping
# left hand exhaust manifold leak
# right hand centre tray light fail
# left hand side large air tank fitting leaking
# right hand scoreboard not working
# right hand dump rope snapped
# right hand side propel filter needs
# right hand side drag chain broken
# right hand front light blown
# left hand broken mirror
#
# Top words:=========
# hand
# right
# left
# side
# broken
#
# Top failure modes:=========
# broken
# unserviceable
# leaking
# loose
# missing
#
# Top equipment:=========
# cylinder
# light
# headlight
# bolts
# chain
#
# Inherent functions in order:
# holding (47)
# guiding (24)
# emitting (24)
# driving (13)
# controlling (8)
# storing (7)
# interfacing (6)
# protecting (6)
# covering (6)
# matterprocessing (4)
# humaninteraction (3)
# sensing (2)
# generating (1)
# restricting (1)
# presenting (1)
# ==================================================
#
# Cluster 2 :
# Cluster Size:========= 199
# Sample Docs:=========
# flat position tyre
# position oil leak inside hub
# position grease line plate missing
# position tyre damage
# top left light cable broke on cabin
# rear door jammed
# bottom position number shock absorber mounts loose
# seat loose
# depth counter issue
# rear air conditioner unserviceable
#
# Top words:=========
# position
# tyre
# rear
# left
# hand
#
# Top failure modes:=========
# unserviceable
# broken
# missing
# damaged
# leak
#
# Top equipment:=========
# tyre
# light
# seat
# headlight
# steering
#
# Inherent functions in order:
# guiding (64)
# holding (34)
# emitting (29)
# storing (13)
# controlling (10)
# protecting (10)
# sensing (10)
# restricting (7)
# interfacing (6)
# driving (6)
# covering (3)
# transforming (3)
# matterprocessing (2)
# presenting (1)
# generating (1)
# ==================================================
#
# Cluster 3 :
# Cluster Size:========= 78
# Sample Docs:=========
# park brake relay valve leaking
# brake shows temperature error
# brakes locked on
# faulty brake sensor task
# brake pump pressure gauge is not working
# position brake hose leak
# brakes stuck on
# park brake fault
# brake release fault
# emergency brake cover missing
#
# Top words:=========
# brake
# park
# fault
# brakes
# not
#
# Top failure modes:=========
# fault
# leaking
# temperature error
# blown
# leak
#
# Top equipment:=========
# brake
# park brake
# brakes
# hose
# accumulator
#
# Inherent functions in order:
# restricting (38)
# guiding (13)
# emitting (6)
# presenting (5)
# storing (4)
# humaninteraction (3)
# controlling (2)
# covering (2)
# sensing (2)
# holding (2)
# interfacing (1)
# ==================================================
#
# Cluster 4 :
# Cluster Size:========= 333
# Sample Docs:=========
# swing pump contamination switch keeps staying on
# drag motor lube is faulty
# engine speed sensor faults
# hoist drag fault
# swing coupling bolts loose number on
# engine vibration
# swing overvoltage
# gauges not working
# speed sensor fault
# hoist has hot spot
#
# Top words:=========
# steering
# hoist
# drag
# swing
# pulley
#
# Top failure modes:=========
# fault
# leaking
# unserviceable
# leak
# noisy
#
# Top equipment:=========
# hoist
# steering
# swing
# pulley
# drag
#
# Inherent functions in order:
# holding (69)
# guiding (43)
# transforming (33)
# generating (32)
# driving (27)
# sensing (25)
# restricting (24)
# controlling (20)
# protecting (16)
# covering (10)
# presenting (10)
# emitting (9)
# matterprocessing (8)
# storing (3)
# interfacing (3)
# humaninteraction (1)
# ==================================================
#
# Cluster 5 :
# Cluster Size:========= 242
# Sample Docs:=========
# damaged position wheel guard
# broken window
# cracks in back right hand side handrail
# crack on bucket
# repair engine vibration
# chain broken on the handrail
# repair cracks on mud bucket
# position damaged tyre
# rock damaged hoses
# replace drivers window with fault
#
# Top words:=========
# in
# broken
# crack
# cracked
# window
#
# Top failure modes:=========
# broken
# crack
# cracked
# damaged
# cracks
#
# Top equipment:=========
# window
# bolts
# bolt
# tyre
# drivers window
#
# Inherent functions in order:
# holding (57)
# protecting (37)
# controlling (37)
# guiding (22)
# storing (19)
# covering (14)
# restricting (14)
# interfacing (13)
# emitting (7)
# generating (5)
# humaninteraction (5)
# matterprocessing (4)
# driving (4)
# presenting (2)
# transforming (1)
# sensing (1)
# ==================================================
#
# Cluster 6 :
# Cluster Size:========= 72
# Sample Docs:=========
# cabin air conditioner thermostat unserviceable
# operator cabin air conditioner cover cracking
# cabin light unserviceable
# cabin seal may be worn
# cabin air conditioner fan is unserviceable
# cabin seals leaking dust PO
# cabin power point has crack
# cabin lights require
# cabin window requires
# cabin side A-frame light needs a ballast
#
# Top words:=========
# cabin
# air
# conditioner
# seat
# needs
#
# Top failure modes:=========
# unserviceable
# needs loctite
# broken
# needs
# cracked
#
# Top equipment:=========
# cabin
# cabin seat
# door
# cabin window
# seat
#
# Inherent functions in order:
# storing (13)
# controlling (12)
# covering (11)
# emitting (9)
# holding (8)
# sensing (5)
# generating (4)
# protecting (4)
# interfacing (4)
# restricting (1)
# presenting (1)
# ==================================================
#
# Cluster 7 :
# Cluster Size:========= 396
# Sample Docs:=========
# electric propel siren not working
# flow battery power
# all dash lights on
# isolator will not isolate
# boom lights flickering
# high voltage slip ring grease leak
# transmission sight glass leaks hose fitting
# house fan trip electrical leakage
# main isolator needs
# replace faulty air conditioner fuse
#
# Top words:=========
# fault
# transmission
# lights
# faulty
# not
#
# Top failure modes:=========
# fault
# faulty
# unserviceable
# broken
# out
#
# Top equipment:=========
# transmission
# lights
# light
# battery
# batteries
#
# Inherent functions in order:
# emitting (85)
# generating (69)
# transforming (42)
# guiding (37)
# protecting (36)
# holding (31)
# controlling (25)
# sensing (17)
# driving (16)
# storing (13)
# matterprocessing (5)
# restricting (5)
# humaninteraction (5)
# covering (4)
# presenting (4)
# interfacing (2)
# ==================================================
#
# Cluster 8 :
# Cluster Size:========= 64
# Sample Docs:=========
# unserviceable grease pump on system right hand
# light unserviceable
# replace unserviceable box coupling
# unserviceable starter motor
# unserviceable cabin air conditioner fan
# replace unserviceable cabin air conditioner thermostat
# unserviceable carbody light
# unserviceable left hand bucket cylinder hose
# month unserviceable pulley number
# unserviceable vent valve system
#
# Top words:=========
# unserviceable
# replace
# air
# conditioner
# engine
#
# Top failure modes:=========
# unserviceable
#
# Top equipment:=========
# hose
# cylinder
# engine air conditioner
# pump
# compressor
#
# Inherent functions in order:
# guiding (12)
# emitting (12)
# sensing (9)
# generating (8)
# driving (6)
# controlling (5)
# interfacing (3)
# covering (2)
# matterprocessing (2)
# holding (2)
# storing (1)
# transforming (1)
# protecting (1)
# ==================================================
#
# Cluster 9 :
# Cluster Size:========= 729
# Sample Docs:=========
# torques on generator bolts
# windrow light position not working
# rock deflector has a crack
# aerial needed for am/fm radio
# outside mudflap has worn
# damaged ladder
# cutting edge worn
# pto pump contamination switch remains on
# emergency gate latch faulty
# door will not open
#
# Top words:=========
# out
# unserviceable
# missing
# worn
# on
#
# Top failure modes:=========
# unserviceable
# missing
# worn
# fault
# broken
#
# Top equipment:=========
# bucket
# pin
# ladder
# PTO
# door
#
# Inherent functions in order:
# holding (127)
# protecting (73)
# emitting (70)
# guiding (69)
# matterprocessing (65)
# controlling (50)
# transforming (43)
# generating (38)
# interfacing (37)
# sensing (30)
# covering (27)
# storing (24)
# humaninteraction (23)
# driving (22)
# presenting (16)
# restricting (15)
# ==================================================
#
# Cluster 10 :
# Cluster Size:========= 106
# Sample Docs:=========
# air conditioner has faults
# air conditioner not operating
# air conditioner fault
# air conditioner blowing hot when going uphill
# air conditioner hot then cold
# air conditioner cut out fault
# air conditioner leaking
# air conditioner belt cover broken
# air conditioner not cooling
# air conditioner issue
#
# Top words:=========
# air
# conditioner
# not
# working
# compressor
#
# Top failure modes:=========
# not working
# unserviceable
# fault
# leaking
# not cold
#
# Top equipment:=========
# air conditioner
# compressor
# belt
# drive
# fan
#
# Inherent functions in order:
# emitting (61)
# generating (18)
# guiding (8)
# covering (4)
# driving (4)
# sensing (3)
# protecting (2)
# controlling (2)
# matterprocessing (2)
# transforming (1)
# restricting (1)
# ==================================================
#
# Cluster 11 :
# Cluster Size:========= 93
# Sample Docs:=========
# grease pump unserviceable
# rear lube bay door broken
# system grease pump needs
# loose lube module bolts
# auto-greaser door window needs a replacement
# grease hoses damaged fairlead
# loose lube module bolts
# grease lines broken
# grease gauges requires
# replace auto-greaser door window
#
# Top words:=========
# grease
# system
# lube
# broken
# auto-greaser
#
# Top failure modes:=========
# broken
# not working
# unserviceable
# fault
# leaking
#
# Top equipment:=========
# grease system
# pump
# grease lines
# lines
# grease pump
#
# Inherent functions in order:
# protecting (29)
# generating (26)
# guiding (16)
# controlling (10)
# holding (3)
# matterprocessing (3)
# driving (2)
# sensing (1)
# interfacing (1)
# presenting (1)
# covering (1)
# ==================================================
#
# Cluster 12 :
# Cluster Size:========= 128
# Sample Docs:=========
# oil leaks at hydraulic tank
# oil leak in rear hose cabinet
# oil leaking from front oil cooler tube
# leak at fuel tank
# oil leak bottom of mast
# air leak at number drag brake
# oil leak from right hand final drive
# oil leak top of differential
# oil leak position wheel end
# oil leak wheel end
#
# Top words:=========
# leak
# oil
# leaking
# at
# hose
#
# Top failure modes:=========
# leak
# leaking
# leaks
#
# Top equipment:=========
# oil
# hose
# pump
# differential
# engine
#
# Inherent functions in order:
# guiding (30)
# protecting (25)
# transforming (12)
# generating (11)
# driving (10)
# controlling (9)
# covering (8)
# holding (6)
# interfacing (6)
# matterprocessing (5)
# storing (4)
# emitting (1)
# restricting (1)
# ==================================================
#
# Cluster 13 :
# Cluster Size:========= 131
# Sample Docs:=========
# damaged fan
# radiator sight glasses unserviceable
# bearing temperature
# brake cooling hose leaking
# coolant leak at jacket water pump
# missing muffler mount bolt
# coolant leak front of engine
# cooler pump lube system experiencing faults
# aftercooler tank gauge broken
# coolant leak on upper deck
#
# Top words:=========
# coolant
# leak
# engine
# radiator
# hose
#
# Top failure modes:=========
# leak
# leaking
# unserviceable
# overheating
# fault
#
# Top equipment:=========
# coolant
# engine
# radiator
# hose
# heater
#
# Inherent functions in order:
# protecting (32)
# guiding (22)
# emitting (20)
# driving (12)
# generating (9)
# restricting (8)
# transforming (8)
# sensing (7)
# controlling (5)
# holding (4)
# presenting (2)
# matterprocessing (1)
# covering (1)
# ==================================================
#
# Cluster 14 :
# Cluster Size:========= 103
# Sample Docs:=========
# blown hydraulic hose
# transmission hoses oil leaks
# chaffing hoses
# blown right hand bucket cylinder hose
# blown ride control hose
# another blown hose
# blown hose
# blown hose
# blown o-ring on steering hose
# blown crowd hose
#
# Top words:=========
# blown
# hose
# o-ring
# on
# hoses
#
# Top failure modes:=========
# blown
# leaking
# keeps blowing
# leaks
# worn
#
# Top equipment:=========
# hose
# o-ring
# hoses
# cylinder
# steering
#
# Inherent functions in order:
# guiding (68)
# covering (26)
# protecting (4)
# emitting (2)
# transforming (2)
# driving (1)
# ==================================================
#
# Cluster 15 :
# Cluster Size:========= 324
# Sample Docs:=========
# engine shutdown
# hydraulic hose will not release
# air filters plugged
# engine oil leak left hand side several
# fuel system issue with
# engine derate faults
# fire system faulty
# pump driveshaft universal joint unserviceable
# minor oil leak front rear torque converter
# pump drive box coupling shaft unserviceable
#
# Top words:=========
# engine
# oil
# leak
# not
# unserviceable
#
# Top failure modes:=========
# leak
# unserviceable
# not working
# leaking
# fault
#
# Top equipment:=========
# engine
# oil
# compressor
# pump
# hose
#
# Inherent functions in order:
# driving (76)
# protecting (49)
# generating (39)
# guiding (32)
# presenting (26)
# matterprocessing (19)
# holding (18)
# emitting (18)
# storing (12)
# covering (11)
# transforming (7)
# interfacing (5)
# sensing (5)
# restricting (4)
# controlling (3)
# ==================================================
#
#
#
# Ave number of documents per cluster: 210.06666666666666
# Median number of documents per cluster: 131
# Min number of documents per cluster: 64
# Max number of documents per cluster: 729
#
# Percentage of clusters with 1 main Inherent function (80% of docs): 0.0
# Percentage of clusters with 2 or 3 main Inherent functions (80% of docs): 0.13333333333333333
# Percentage of documents in clusters with 1 main Inherent function (80% of docs): 0.0
# Percentage of documents in clusters with 2 or 3 main Inherent functions (80% of docs): 0.06632814979371628

# %% [markdown]
# ## Approach 3: Word2Vec Bi-LSTM Clustering

# %% [markdown]
# ### Create Word2Vec Bi-LSTM Embeddings

# %%
w2v_if_model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(10,100)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(64, activation='relu'), 
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(units=16, activation="softmax")
])

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

w2v_if_model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])
early_stopping = tf.keras.callbacks.EarlyStopping(patience=20, monitor='val_loss', restore_best_weights=True)
history = w2v_if_model.fit(w2v_embeddings_X_train, y_train, epochs=200, validation_data=(w2v_embeddings_X_test, y_test), callbacks=[early_stopping])

# run predictions
pred_train = w2v_if_model.predict(w2v_embeddings_X_train)
pred_train = pred_train.argmax(axis=-1)
print("Final train accuracy:", w2v_if_model.evaluate(w2v_embeddings_X_train, y_train)[1])

pred_test = w2v_if_model.predict(w2v_embeddings_X_test)
pred_test = pred_test.argmax(axis=-1)
print("Final test accuracy:", w2v_if_model.evaluate(w2v_embeddings_X_test, y_test)[1])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy TF-Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/200
# 79/79 [==============================] - 5s 15ms/step - loss: 0.2045 - accuracy: 0.1885 - val_loss: 2.3158 - val_accuracy: 0.3645
# Epoch 2/200
# 79/79 [==============================] - 1s 6ms/step - loss: 0.1395 - accuracy: 0.3972 - val_loss: 2.0567 - val_accuracy: 0.4057
# Epoch 3/200
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1172 - accuracy: 0.4556 - val_loss: 2.0425 - val_accuracy: 0.4263
# Epoch 4/200
# 79/79 [==============================] - 1s 6ms/step - loss: 0.1053 - accuracy: 0.4948 - val_loss: 1.8869 - val_accuracy: 0.4612
# Epoch 5/200
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0970 - accuracy: 0.5306 - val_loss: 1.7466 - val_accuracy: 0.5055
# Epoch 6/200
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0885 - accuracy: 0.5623 - val_loss: 1.7274 - val_accuracy: 0.5087
# Epoch 7/200
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0812 - accuracy: 0.6063 - val_loss: 1.7320 - val_accuracy: 0.5119
# Epoch 8/200
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0765 - accuracy: 0.6218 - val_loss: 1.6689 - val_accuracy: 0.5531
# Epoch 9/200
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0703 - accuracy: 0.6429 - val_loss: 1.6300 - val_accuracy: 0.5436
# Epoch 10/200
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0662 - accuracy: 0.6595 - val_loss: 1.5667 - val_accuracy: 0.5737
# Epoch 11/200
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0623 - accuracy: 0.6714 - val_loss: 1.4807 - val_accuracy: 0.5848
# Epoch 12/200
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0586 - accuracy: 0.6865 - val_loss: 1.5269 - val_accuracy: 0.5895
# Epoch 13/200
# 79/79 [==============================] - 1s 14ms/step - loss: 0.0548 - accuracy: 0.7028 - val_loss: 1.5467 - val_accuracy: 0.5705
# Epoch 14/200
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0552 - accuracy: 0.6988 - val_loss: 1.5357 - val_accuracy: 0.5895
# Epoch 15/200
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0493 - accuracy: 0.7290 - val_loss: 1.4642 - val_accuracy: 0.6101
# Epoch 16/200
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0500 - accuracy: 0.7329 - val_loss: 1.4756 - val_accuracy: 0.6101
# Epoch 17/200
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0447 - accuracy: 0.7488 - val_loss: 1.4860 - val_accuracy: 0.5975
# Epoch 18/200
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0414 - accuracy: 0.7583 - val_loss: 1.5485 - val_accuracy: 0.6165
# Epoch 19/200
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0411 - accuracy: 0.7643 - val_loss: 1.5548 - val_accuracy: 0.6197
# Epoch 20/200
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0415 - accuracy: 0.7655 - val_loss: 1.6448 - val_accuracy: 0.5975
# Epoch 21/200
# 79/79 [==============================] - 1s 6ms/step - loss: 0.0379 - accuracy: 0.7758 - val_loss: 1.4212 - val_accuracy: 0.6276
# Epoch 22/200
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0374 - accuracy: 0.7897 - val_loss: 1.4766 - val_accuracy: 0.6450
# Epoch 23/200
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0344 - accuracy: 0.8052 - val_loss: 1.4422 - val_accuracy: 0.6355
# Epoch 24/200
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0308 - accuracy: 0.8147 - val_loss: 1.4239 - val_accuracy: 0.6640
# Epoch 25/200
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0269 - accuracy: 0.8385 - val_loss: 1.5772 - val_accuracy: 0.6292
# Epoch 26/200
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0311 - accuracy: 0.8246 - val_loss: 1.4481 - val_accuracy: 0.6688
# Epoch 27/200
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0274 - accuracy: 0.8437 - val_loss: 1.5577 - val_accuracy: 0.6355
# Epoch 28/200
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0281 - accuracy: 0.8317 - val_loss: 1.5440 - val_accuracy: 0.6355
# Epoch 29/200
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0267 - accuracy: 0.8421 - val_loss: 1.4995 - val_accuracy: 0.6735
# Epoch 30/200
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0249 - accuracy: 0.8484 - val_loss: 1.6664 - val_accuracy: 0.6466
# Epoch 31/200
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0237 - accuracy: 0.8484 - val_loss: 1.4865 - val_accuracy: 0.6593
# Epoch 32/200
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0195 - accuracy: 0.8730 - val_loss: 1.6075 - val_accuracy: 0.6561
# Epoch 33/200
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0215 - accuracy: 0.8718 - val_loss: 1.5543 - val_accuracy: 0.6719
# Epoch 34/200
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0194 - accuracy: 0.8746 - val_loss: 1.6368 - val_accuracy: 0.6688
# Epoch 35/200
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0174 - accuracy: 0.8817 - val_loss: 1.5269 - val_accuracy: 0.6783
# Epoch 36/200
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0158 - accuracy: 0.8944 - val_loss: 1.5854 - val_accuracy: 0.6640
# Epoch 37/200
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0213 - accuracy: 0.8671 - val_loss: 1.7085 - val_accuracy: 0.6450
# Epoch 38/200
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0224 - accuracy: 0.8687 - val_loss: 1.7748 - val_accuracy: 0.6387
# Epoch 39/200
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0224 - accuracy: 0.8611 - val_loss: 1.6498 - val_accuracy: 0.6957
# Epoch 40/200
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0209 - accuracy: 0.8742 - val_loss: 1.6826 - val_accuracy: 0.6482
# Epoch 41/200
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0192 - accuracy: 0.8810 - val_loss: 1.7462 - val_accuracy: 0.6609
# 79/79 [==============================] - 1s 2ms/step
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6366 - accuracy: 0.8111
# Final train accuracy: 0.8111110925674438
# 20/20 [==============================] - 0s 2ms/step
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4212 - accuracy: 0.6276
# Final test accuracy: 0.6275752782821655

# %%
w2v_if_model_embedding = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(10,100)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(64, activation='relu'), 
    tf.keras.layers.Dense(10, activation='relu')
])

w2v_if_model_embedding.layers[0].set_weights(w2v_if_model.layers[0].get_weights())
w2v_if_model_embedding.layers[1].set_weights(w2v_if_model.layers[1].get_weights())
w2v_if_model_embedding.layers[2].set_weights(w2v_if_model.layers[2].get_weights())
w2v_if_model_embedding.layers[3].set_weights(w2v_if_model.layers[3].get_weights())

w2v_embeddings = np.concatenate((w2v_embeddings_X_train, w2v_embeddings_X_test))
cluster_embeddings = w2v_if_model_embedding.predict(w2v_embeddings)
print(cluster_embeddings.shape)
# Out:
# 99/99 [==============================] - 1s 2ms/step
# (3151, 10)

# %% [markdown]
# ### K-means Clustering

# %%
perform_kmeans(cluster_embeddings)
# Out:
# 5 / 30
# 6 / 30
# 7 / 30
# 8 / 30
# 9 / 30
# 10 / 30
# 11 / 30
# 12 / 30
# 13 / 30
# 14 / 30
# 15 / 30
# 16 / 30
# 17 / 30
# 18 / 30
# 19 / 30
# 20 / 30
# 21 / 30
# 22 / 30
# 23 / 30
# 24 / 30
# 25 / 30
# 26 / 30
# 27 / 30
# 28 / 30
# 29 / 30
# NMI: 0.527439360114432

# %%
run_kmeans_best_k(9, cluster_embeddings)
# Out:
# Cluster 1 :
# Cluster Size:========= 573
# Sample Docs:=========
# worn ripper tip ripper tip
# repair cracked exhaust shield
# right hand rear steering guard bracket broken
# cabin seals leaking dust bad
# emergency gate latch missing
#
# Top words:=========
# broken
# cracked
# window
# door
# crack
#
# Top failure modes:=========
# broken
# crack
# cracked
# worn
# leak
#
# Top equipment:=========
# door
# window
# cabin
# oil
# fuel tank
#
# Inherent functions in order:
# controlling (179)
# protecting (91)
# matterprocessing (73)
# covering (60)
# holding (48)
# storing (42)
# restricting (25)
# interfacing (24)
# humaninteraction (10)
# presenting (6)
# transforming (5)
# guiding (4)
# emitting (2)
# sensing (2)
# driving (1)
# generating (1)
# ==================================================
#
# Cluster 2 :
# Cluster Size:========= 167
# Sample Docs:=========
# blow by fault on engine
# engine oil leak text
# drive vibration
# engine speed sensor faults
# engine overheating
#
# Top words:=========
# engine
# oil
# cylinder
# leak
# hand
#
# Top failure modes:=========
# leak
# leaking
# fault
# noisy
# unserviceable
#
# Top equipment:=========
# engine
# oil
# cylinder
# lift cylinder
# motor
#
# Inherent functions in order:
# driving (141)
# guiding (6)
# generating (5)
# holding (4)
# protecting (3)
# sensing (2)
# covering (2)
# controlling (1)
# storing (1)
# emitting (1)
# matterprocessing (1)
# ==================================================
#
# Cluster 3 :
# Cluster Size:========= 317
# Sample Docs:=========
# damage to position tyre
# blown hose right hand final drive
# damaged cooling hose
# flat position tyre
# leaking hydraulic hose
#
# Top words:=========
# hose
# blown
# position
# tyre
# leaking
#
# Top failure modes:=========
# blown
# leaking
# damaged
# unserviceable
# leak
#
# Top equipment:=========
# hose
# tyre
# brake
# lines
# hoses
#
# Inherent functions in order:
# guiding (303)
# covering (6)
# holding (5)
# generating (2)
# protecting (1)
# ==================================================
#
# Cluster 4 :
# Cluster Size:========= 216
# Sample Docs:=========
# fault on fire system
# air conditioner fuse keeps blowing
# found in engine oil
# replace starter fuse keeps blowing
# lube fault
#
# Top words:=========
# leak
# oil
# fuse
# system
# grease
#
# Top failure modes:=========
# leak
# fault
# keeps blowing
# keep blowing
# leaks
#
# Top equipment:=========
# coolant
# oil
# engine
# grease system
# hydraulic oil
#
# Inherent functions in order:
# protecting (186)
# generating (7)
# emitting (6)
# holding (4)
# guiding (3)
# interfacing (2)
# transforming (2)
# driving (2)
# presenting (1)
# covering (1)
# sensing (1)
# controlling (1)
# ==================================================
#
# Cluster 5 :
# Cluster Size:========= 320
# Sample Docs:=========
# lighting faults
# no tray lights
# tray light out
# air conditioner fault
# front lights inoperative
#
# Top words:=========
# air
# conditioner
# light
# lights
# out
#
# Top failure modes:=========
# out
# unserviceable
# not working
# fault
# blown
#
# Top equipment:=========
# air conditioner
# light
# lights
# headlight
# boom
#
# Inherent functions in order:
# emitting (305)
# generating (4)
# guiding (4)
# driving (3)
# sensing (2)
# holding (1)
# protecting (1)
# ==================================================
#
# Cluster 6 :
# Cluster Size:========= 508
# Sample Docs:=========
# engine oil over full fuel in oil
# auto-greaser leaking oil
# heater not working
# park brake not releasing
# ladder issue
#
# Top words:=========
# not
# unserviceable
# brake
# working
# pump
#
# Top failure modes:=========
# unserviceable
# not working
# fault
# leaking
# faulty
#
# Top equipment:=========
# brake
# motor
# ladder
# swing
# hoist
#
# Inherent functions in order:
# sensing (103)
# restricting (80)
# presenting (49)
# interfacing (45)
# emitting (36)
# generating (34)
# driving (34)
# matterprocessing (26)
# humaninteraction (24)
# storing (21)
# covering (20)
# transforming (14)
# holding (9)
# controlling (7)
# protecting (5)
# guiding (1)
# ==================================================
#
# Cluster 7 :
# Cluster Size:========= 509
# Sample Docs:=========
# steering steering wheel bearings
# right hand track frame crack
# cracks top of bucket
# tail pulley bearings unserviceable
# new tyres damaged position
#
# Top words:=========
# hand
# broken
# missing
# pin
# right
#
# Top failure modes:=========
# broken
# missing
# loose
# unserviceable
# cracked
#
# Top equipment:=========
# pin
# bolts
# bolt
# pulley
# bearing
#
# Inherent functions in order:
# holding (308)
# guiding (88)
# covering (35)
# protecting (31)
# matterprocessing (13)
# storing (8)
# controlling (7)
# interfacing (7)
# presenting (4)
# transforming (3)
# restricting (2)
# humaninteraction (2)
# emitting (1)
# ==================================================
#
# Cluster 8 :
# Cluster Size:========= 230
# Sample Docs:=========
# position turbo failed
# drag generator field loss
# Tele-Remote cameras fault text
# grease pump compressor engine no go
# differential lube pump leaking
#
# Top words:=========
# compressor
# pump
# unserviceable
# batteries
# air
#
# Top failure modes:=========
# unserviceable
# no charge
# fault
# not working
# leak
#
# Top equipment:=========
# pump
# compressor
# air conditioner
# batteries
# generator
#
# Inherent functions in order:
# generating (192)
# guiding (10)
# storing (9)
# presenting (5)
# holding (4)
# driving (2)
# interfacing (2)
# sensing (2)
# restricting (1)
# emitting (1)
# transforming (1)
# controlling (1)
# ==================================================
#
# Cluster 9 :
# Cluster Size:========= 311
# Sample Docs:=========
# electrical harness fault
# hoist drum cracking on
# rollers unserviceable
# am/fm radio needs aerial replacement
# centre hitch oil leaks
#
# Top words:=========
# fault
# oil
# leak
# transmission
# seat
#
# Top failure modes:=========
# fault
# leak
# leaking
# unserviceable
# failed
#
# Top equipment:=========
# transmission
# oil
# PTO
# differential
# pump
#
# Inherent functions in order:
# transforming (128)
# guiding (41)
# storing (32)
# holding (25)
# driving (16)
# generating (16)
# restricting (11)
# matterprocessing (7)
# interfacing (7)
# covering (6)
# protecting (6)
# sensing (5)
# presenting (4)
# humaninteraction (4)
# controlling (2)
# emitting (1)
# ==================================================
#
#
#
# Ave number of documents per cluster: 350.1111111111111
# Median number of documents per cluster: 317
# Min number of documents per cluster: 167
# Max number of documents per cluster: 573
#
# Percentage of clusters with 1 main Inherent function (80% of docs): 0.5555555555555556
# Percentage of clusters with 2 or 3 main Inherent functions (80% of docs): 0.1111111111111111
# Percentage of documents in clusters with 1 main Inherent function (80% of docs): 0.3966994604887337
# Percentage of documents in clusters with 2 or 3 main Inherent functions (80% of docs): 0.16153602031101238

# %% [markdown]
# ### Average Hierarchical Clustering

# %%
linkage_data_ave = perform_hierarchical_clustering(cluster_embeddings, "average")
# Out:
# NMI: 0.5206493725750937

# %%
get_hierarchical_clusters(12, linkage_data_ave)
# Out:
# Cluster 1 :
# Cluster Size:========= 368
# Sample Docs:=========
# air conditioner experiencing faults
# a-frame light remains out
# right top light not working
# hydraulic motor engine air conditioner unserviceable
# cabin side A-frame light needs a ballast
# air conditioner units need
# headlight bracket broken
# engine air conditioner unserviceable
# operator cabin air conditioner cover cracking
# tray fault
#
# Top words:=========
# air
# conditioner
# light
# out
# lights
#
# Top failure modes:=========
# out
# unserviceable
# not working
# fault
# blown
#
# Top equipment:=========
# air conditioner
# light
# lights
# headlight
# boom
#
# Inherent functions in order:
# emitting (326)
# guiding (12)
# holding (7)
# storing (6)
# covering (6)
# controlling (3)
# generating (3)
# sensing (2)
# protecting (1)
# presenting (1)
# humaninteraction (1)
# ==================================================
#
# Cluster 2 :
# Cluster Size:========= 95
# Sample Docs:=========
# failed implement pump
# unserviceable bearing running hot
# position turbo failure
# coolant pump unserviceable
# faulty alternator
# unserviceable compressor
# coolant pump not working
# air conditioner fan unserviceable
# unserviceable diode bank air conditioner fans TBC
# grease pump compressor engine no go
#
# Top words:=========
# compressor
# unserviceable
# air
# conditioner
# not
#
# Top failure modes:=========
# unserviceable
# not working
# failed
# tripping out
# fault
#
# Top equipment:=========
# compressor
# air conditioner
# pump
# fans
# alternator
#
# Inherent functions in order:
# generating (83)
# holding (8)
# guiding (1)
# storing (1)
# driving (1)
# controlling (1)
# ==================================================
#
# Cluster 3 :
# Cluster Size:========= 132
# Sample Docs:=========
# TV monitor has no signal
# swing brakes coming on now then
# hoist brakes not holding
# number hoist generator flashed over
# hoist resolver fault
# fan motor running in reverse
# brakes stuck on
# number swing case oil level
# no charge in blower inverter batteries
# generator fault found
#
# Top words:=========
# batteries
# no
# inverter
# charge
# fault
#
# Top failure modes:=========
# no charge
# fault
# dropped cell
# earthing out
# sparking
#
# Top equipment:=========
# brakes
# generator
# batteries
# hoist
# swing
#
# Inherent functions in order:
# generating (80)
# restricting (21)
# transforming (15)
# storing (5)
# sensing (3)
# presenting (2)
# holding (2)
# matterprocessing (1)
# driving (1)
# guiding (1)
# protecting (1)
# ==================================================
#
# Cluster 4 :
# Cluster Size:========= 566
# Sample Docs:=========
# lube room I/O cabinet fan unserviceable
# issues with engine starting
# top steering box seal leaking
# pressure compensator leaking
# cabin air conditioner thermostat is unserviceable
# air horn not working
# contamination alarm on
# plugged air filters
# thermostat is unserviceable
# air horn working intermittently
#
# Top words:=========
# not
# unserviceable
# working
# pump
# leaking
#
# Top failure modes:=========
# unserviceable
# not working
# leaking
# fault
# faulty
#
# Top equipment:=========
# motor
# pump
# ladder
# fuel tank
# seal
#
# Inherent functions in order:
# sensing (105)
# generating (69)
# driving (60)
# storing (57)
# presenting (54)
# interfacing (50)
# matterprocessing (34)
# covering (32)
# humaninteraction (24)
# restricting (19)
# emitting (19)
# transforming (14)
# holding (12)
# protecting (12)
# controlling (5)
# ==================================================
#
# Cluster 5 :
# Cluster Size:========= 317
# Sample Docs:=========
# steering fault
# steering oil leak
# park brake fault
# all broken windows
# steering control valve leaking
# cabin door window cracked
# park brake staying on
# cabin door sticking
# bent cabin step
# broken hinge
#
# Top words:=========
# window
# brake
# door
# fault
# broken
#
# Top failure modes:=========
# fault
# broken
# unserviceable
# leaking
# temperature error
#
# Top equipment:=========
# brake
# window
# door
# steering
# control valve
#
# Inherent functions in order:
# controlling (152)
# restricting (72)
# storing (31)
# holding (16)
# humaninteraction (12)
# transforming (8)
# sensing (6)
# covering (5)
# interfacing (3)
# presenting (3)
# generating (3)
# protecting (3)
# emitting (2)
# matterprocessing (1)
# ==================================================
#
# Cluster 6 :
# Cluster Size:========= 117
# Sample Docs:=========
# rain water leaking into cabin
# brake pads leaking booster
# CW transmission failed
# minor transmission oil leak
# PTO not engaging all the time
# electrical PTO wiring problem
# CW PTO universal joint failed
# PTO shaft unserviceable PO
# driveline leaking park brake
# transmission fault
#
# Top words:=========
# transmission
# fault
# universal
# PTO
# joint
#
# Top failure modes:=========
# fault
# failed
# worn
# leak
# leaking
#
# Top equipment:=========
# transmission
# PTO
# universal joint
# shaft
# differential
#
# Inherent functions in order:
# transforming (76)
# guiding (23)
# matterprocessing (8)
# restricting (3)
# controlling (2)
# driving (2)
# holding (1)
# generating (1)
# storing (1)
# ==================================================
#
# Cluster 7 :
# Cluster Size:========= 183
# Sample Docs:=========
# oil leak on pump
# lube system not working
# coolant leak from heater
# oil leak implement pump
# pump oil found malfunctioning
# leak from grease pump
# CW coolant leak from radiator
# CW coolant leak from number cylinder
# hydraulic oil leak
# system grease pump needs
#
# Top words:=========
# leak
# oil
# fuse
# system
# coolant
#
# Top failure modes:=========
# leak
# fault
# keeps blowing
# keep blowing
# found
#
# Top equipment:=========
# oil
# coolant
# pump
# grease system
# hydraulic oil
#
# Inherent functions in order:
# protecting (158)
# generating (11)
# emitting (5)
# holding (3)
# transforming (2)
# matterprocessing (1)
# restricting (1)
# presenting (1)
# interfacing (1)
# ==================================================
#
# Cluster 8 :
# Cluster Size:========= 171
# Sample Docs:=========
# engine oil leak on left hand side
# lift cylinder leaking o-ring
# oil leaks
# noisy hydraulic lift cylinder
# lost drive noisy front drop box
# leaking steering cylinder
# starting fault solenoid
# propel ground fault
# repair engine vibration
# minor oil leak above rear of torque converter
#
# Top words:=========
# engine
# oil
# leak
# cylinder
# fault
#
# Top failure modes:=========
# leak
# leaking
# fault
# unserviceable
# leaks
#
# Top equipment:=========
# engine
# oil
# cylinder
# lift cylinder
# steering cylinder
#
# Inherent functions in order:
# driving (124)
# protecting (12)
# transforming (10)
# guiding (8)
# holding (7)
# covering (4)
# interfacing (3)
# matterprocessing (2)
# presenting (1)
# ==================================================
#
# Cluster 9 :
# Cluster Size:========= 532
# Sample Docs:=========
# handrail weld found broken
# hoist hose leaking
# damaged bearing housing
# broken lost teeth
# exhaust shield is cracked
# rock deflector is cracked
# cutting edge worn
# crack in right hand side of rear cross member
# oil leak inlet to oil burner cover plate
# rock deflector has a crack
#
# Top words:=========
# hand
# missing
# cracked
# leak
# oil
#
# Top failure modes:=========
# missing
# leak
# cracked
# crack
# worn
#
# Top equipment:=========
# oil
# bucket
# guard
# handrail
# tooth
#
# Inherent functions in order:
# holding (138)
# protecting (134)
# matterprocessing (72)
# covering (41)
# controlling (32)
# interfacing (29)
# guiding (26)
# transforming (25)
# storing (12)
# driving (8)
# generating (5)
# presenting (4)
# restricting (3)
# humaninteraction (2)
# sensing (1)
# ==================================================
#
# Cluster 10 :
# Cluster Size:========= 426
# Sample Docs:=========
# air conditioner belt missing
# replace position mismatched tyre
# leaking hydraulic hose at rockbreaker
# hydraulic system blown hose
# blown hydraulic cooler hose
# worn out air tank hose
# tracks need
# blown hose
# blown crowd cylinder hose
# grease lines at bucket damaged
#
# Top words:=========
# hose
# blown
# position
# leaking
# tyre
#
# Top failure modes:=========
# blown
# leaking
# unserviceable
# broken
# damaged
#
# Top equipment:=========
# hose
# tyre
# brake
# cylinder
# steering
#
# Inherent functions in order:
# guiding (370)
# covering (39)
# holding (5)
# driving (3)
# controlling (2)
# protecting (1)
# transforming (1)
# interfacing (1)
# presenting (1)
# generating (1)
# humaninteraction (1)
# emitting (1)
# ==================================================
#
# Cluster 11 :
# Cluster Size:========= 24
# Sample Docs:=========
# dropbox failure
# drag ropes failed <date>
# CW position turbo clamp unserviceable
# number drag brake cover damaged
# why fan belts seized should
# drag iov has a fault
# house fan trip electrical leakage
# engine fan fault overheating
# air conditioner fan unserviceable new
# noise in driveline
#
# Top words:=========
# unserviceable
# fan
# drag
# air
# conditioner
#
# Top failure modes:=========
# unserviceable
# fault
# damaged
# failed
# noise
#
# Top equipment:=========
# fan
# drag
# belts
# belt
# air conditioner
#
# Inherent functions in order:
# guiding (9)
# generating (5)
# holding (4)
# transforming (2)
# controlling (1)
# matterprocessing (1)
# presenting (1)
# covering (1)
# ==================================================
#
# Cluster 12 :
# Cluster Size:========= 220
# Sample Docs:=========
# PTO mount bolts loose
# damage pin coming out of H-link
# bucket pin walking out
# drag shackle pin walking out
# number pulley failed bearings
# broken lower right hand step
# snapped drag chain
# front sway bar bushes worn out
# broken bolt see text
# air conditioner belt cover broken
#
# Top words:=========
# broken
# bolts
# pin
# hand
# out
#
# Top failure modes:=========
# broken
# missing
# loose
# unserviceable
# noisy
#
# Top equipment:=========
# bolts
# pin
# bearing
# pulley
# bolt
#
# Inherent functions in order:
# holding (205)
# guiding (10)
# covering (2)
# protecting (2)
# presenting (1)
# ==================================================
#
#
#
# Ave number of documents per cluster: 262.5833333333333
# Median number of documents per cluster: 201.5
# Min number of documents per cluster: 24
# Max number of documents per cluster: 566
#
# Percentage of clusters with 1 main Inherent function (80% of docs): 0.4166666666666667
# Percentage of clusters with 2 or 3 main Inherent functions (80% of docs): 0.3333333333333333
# Percentage of documents in clusters with 1 main Inherent function (80% of docs): 0.4100285623611552
# Percentage of documents in clusters with 2 or 3 main Inherent functions (80% of docs): 0.2338940019041574

# %% [markdown]
# ### Ward Hierarchical Clustering

# %%
linkage_data_ward = perform_hierarchical_clustering(cluster_embeddings, "ward")
# Out:
# NMI: 0.5142873734303939

# %%
get_hierarchical_clusters(10, linkage_data_ward)
# Out:
# Cluster 1 :
# Cluster Size:========= 275
# Sample Docs:=========
# engine fan speed resistor is not working
# fault in drag iov
# compressor pin hole
# house fans shutdown
# house fan unserviceable
# grease pump unserviceable PO
# compressor shutdown fault
# replace inverter batteries with no charge
# batteries have no charge
# blower inverter batteries have no charge
#
# Top words:=========
# compressor
# unserviceable
# air
# pump
# not
#
# Top failure modes:=========
# unserviceable
# no charge
# not working
# fault
# leak
#
# Top equipment:=========
# compressor
# pump
# air conditioner
# fan
# generator
#
# Inherent functions in order:
# generating (206)
# transforming (15)
# holding (11)
# restricting (10)
# storing (7)
# protecting (5)
# guiding (5)
# presenting (4)
# emitting (3)
# sensing (3)
# driving (2)
# matterprocessing (1)
# covering (1)
# interfacing (1)
# controlling (1)
# ==================================================
#
# Cluster 2 :
# Cluster Size:========= 732
# Sample Docs:=========
# inside horn not working
# bucket teeth missing
# fuel cap missing
# armrest unserviceable
# quarter front windows cracked TBC
# loctite needed for cabin seat
# blocked radiator due to grass
# noisy brake on drag system
# radiator blocked
# rear steering accumulator leaking
#
# Top words:=========
# not
# unserviceable
# leaking
# working
# pump
#
# Top failure modes:=========
# unserviceable
# leaking
# not working
# fault
# worn
#
# Top equipment:=========
# motor
# bucket
# ladder
# fuel tank
# tank
#
# Inherent functions in order:
# sensing (110)
# matterprocessing (85)
# storing (84)
# driving (82)
# interfacing (59)
# presenting (55)
# emitting (40)
# covering (39)
# generating (38)
# protecting (35)
# transforming (31)
# humaninteraction (26)
# holding (19)
# restricting (12)
# controlling (12)
# guiding (5)
# ==================================================
#
# Cluster 3 :
# Cluster Size:========= 131
# Sample Docs:=========
# front shaft failure
# repair slipping fault in transmission
# locked steels
# oil leak over front differential
# noise in driveline
# brake pads leaking booster
# differential pinion oil leak
# minor differential oil leak
# left hand hoist cylinder fell off cylinder
# failed driveline component
#
# Top words:=========
# transmission
# fault
# PTO
# universal
# joint
#
# Top failure modes:=========
# fault
# failed
# worn
# leak
# leaking
#
# Top equipment:=========
# transmission
# PTO
# universal joint
# driveline
# shaft
#
# Inherent functions in order:
# transforming (82)
# guiding (26)
# matterprocessing (9)
# restricting (3)
# controlling (3)
# driving (2)
# holding (1)
# generating (1)
# humaninteraction (1)
# sensing (1)
# protecting (1)
# storing (1)
# ==================================================
#
# Cluster 4 :
# Cluster Size:========= 269
# Sample Docs:=========
# control valve is falling off
# emergency gate latch unserviceable
# cracked rear window
# middle air drain tap leaking
# control valve has fallen off
# window is broken
# brake accumulator fault
# dust entering cabin seals
# main isolator not working
# dust leak operators side window
#
# Top words:=========
# window
# brake
# door
# broken
# valve
#
# Top failure modes:=========
# fault
# broken
# unserviceable
# cracked
# temperature error
#
# Top equipment:=========
# brake
# window
# door
# brakes
# control valve
#
# Inherent functions in order:
# controlling (140)
# restricting (91)
# storing (6)
# covering (5)
# interfacing (5)
# holding (5)
# humaninteraction (5)
# transforming (3)
# generating (2)
# presenting (2)
# emitting (2)
# protecting (2)
# guiding (1)
# ==================================================
#
# Cluster 5 :
# Cluster Size:========= 405
# Sample Docs:=========
# faulty wiring at emergency-stop
# blown right hand bucket cylinder hose
# damaged hoses
# high wall chain broken
# transmission cooler lines leaking
# chain broken on the handrail
# unserviceable right hand clam cylinder hose
# position brake cooling hose leaking
# ladder mirror loose
# blown brake hose rear differential
#
# Top words:=========
# hose
# blown
# position
# leaking
# tyre
#
# Top failure modes:=========
# blown
# leaking
# unserviceable
# broken
# damaged
#
# Top equipment:=========
# hose
# tyre
# brake
# lines
# hydraulic hose
#
# Inherent functions in order:
# guiding (373)
# covering (12)
# holding (5)
# protecting (2)
# controlling (2)
# interfacing (2)
# driving (2)
# humaninteraction (2)
# storing (1)
# transforming (1)
# matterprocessing (1)
# presenting (1)
# emitting (1)
# ==================================================
#
# Cluster 6 :
# Cluster Size:========= 337
# Sample Docs:=========
# air conditioner fault
# top left light cable broke on cabin
# degreaser bath requires a light
# right hand boom lamp broken
# boom light out on first row from house
# no boom lights
# lost all lights
# needs repair for engine air conditioner
# air conditioner blowing warm
# engine air conditioner unserviceable
#
# Top words:=========
# air
# conditioner
# light
# out
# lights
#
# Top failure modes:=========
# out
# unserviceable
# not working
# fault
# blown
#
# Top equipment:=========
# air conditioner
# light
# lights
# headlight
# boom
#
# Inherent functions in order:
# emitting (303)
# guiding (12)
# covering (6)
# holding (5)
# storing (3)
# controlling (3)
# generating (2)
# protecting (1)
# presenting (1)
# sensing (1)
# ==================================================
#
# Cluster 7 :
# Cluster Size:========= 236
# Sample Docs:=========
# broken tugger winch bolt
# bearing noisy
# collapsed bearing west side
# bonnet hinge bushes unserviceable
# bolts missing right track
# right hand sheave retainer plate bolts broken
# south bearing has knock
# missing pin on ladder
# noisy lift arm pin
# bearings are shot
#
# Top words:=========
# broken
# bolts
# pin
# hand
# missing
#
# Top failure modes:=========
# broken
# missing
# loose
# unserviceable
# noisy
#
# Top equipment:=========
# bolts
# pin
# bearing
# pulley
# bolt
#
# Inherent functions in order:
# holding (221)
# guiding (9)
# covering (2)
# protecting (2)
# presenting (1)
# matterprocessing (1)
# ==================================================
#
# Cluster 8 :
# Cluster Size:========= 149
# Sample Docs:=========
# blown lift cylinder o-ring
# bottom left hand hoist cylinder leak
# engine shutdown fault
# fan motor hose leaking
# CW engine vibration
# engine prelube error constantly
# engine overheating
# derating engine
# transmission hose o-ring blown
# engine oil leak
#
# Top words:=========
# engine
# cylinder
# o-ring
# oil
# blown
#
# Top failure modes:=========
# blown
# leak
# leaking
# fault
# overheating
#
# Top equipment:=========
# engine
# cylinder
# oil
# lift cylinder
# o-ring
#
# Inherent functions in order:
# driving (94)
# covering (31)
# protecting (9)
# guiding (8)
# holding (5)
# matterprocessing (1)
# generating (1)
# ==================================================
#
# Cluster 9 :
# Cluster Size:========= 68
# Sample Docs:=========
# fire system faulty
# wiper fuse keeps blowing
# fire system trip
# fuse is blowing repeatedly
# fuse for dragline air conditioner keeps blowing
# reported grease system unserviceable
# grease system has intermittent fault
# dragline air conditioner fuse is blowing
# replace lights fuse fault
# blown air conditioner fuse
#
# Top words:=========
# fuse
# blowing
# grease
# system
# keeps
#
# Top failure modes:=========
# fault
# keeps blowing
# keep blowing
# leak
# unserviceable
#
# Top equipment:=========
# grease system
# coolant
# fuse
# operator cabin air conditioner fuse
# starter fuse
#
# Inherent functions in order:
# protecting (68)
# ==================================================
#
# Cluster 10 :
# Cluster Size:========= 549
# Sample Docs:=========
# broken lost teeth
# glass has a crack
# rock deflector is cracked
# steering oil leaks
# two-way handpiece chord stretched
# steering steering wheel bearings
# right hand side tooth adaptor missing
# fire suppression frame cracked
# minor oil leak hub
# repair crack in liner
#
# Top words:=========
# oil
# leak
# hand
# cracked
# in
#
# Top failure modes:=========
# leak
# crack
# cracked
# broken
# missing
#
# Top equipment:=========
# oil
# engine
# cabin
# handrail
# guard
#
# Inherent functions in order:
# protecting (199)
# holding (136)
# controlling (37)
# covering (34)
# matterprocessing (22)
# guiding (21)
# transforming (21)
# interfacing (20)
# driving (17)
# storing (11)
# generating (11)
# humaninteraction (6)
# presenting (5)
# emitting (4)
# restricting (3)
# sensing (2)
# ==================================================
#
#
#
# Ave number of documents per cluster: 315.1
# Median number of documents per cluster: 272.0
# Min number of documents per cluster: 68
# Max number of documents per cluster: 732
#
# Percentage of clusters with 1 main Inherent function (80% of docs): 0.4
# Percentage of clusters with 2 or 3 main Inherent functions (80% of docs): 0.4
# Percentage of documents in clusters with 1 main Inherent function (80% of docs): 0.3319581085369724
# Percentage of documents in clusters with 2 or 3 main Inherent functions (80% of docs): 0.2615042843541733

# %% [markdown]
# ## Approach 4: SBERT NN Clustering

# %% [markdown]
# ### Create SBERT NN Embeddings

# %%
sbert_if_model = tf.keras.Sequential([
    
    tf.keras.layers.Dense(units=128, activation="tanh", input_shape=(768,)),
    tf.keras.layers.Dense(units=64, activation="tanh"),
    tf.keras.layers.Dense(units=32, activation="tanh"),

    tf.keras.layers.Dense(units=10, activation="tanh"),
    tf.keras.layers.Dense(units=16, activation="softmax")
])

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

sbert_if_model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])
early_stopping = tf.keras.callbacks.EarlyStopping(patience=20, monitor='val_loss', restore_best_weights=True)
history = sbert_if_model.fit(SBERT_embeddings_train, y_train, epochs=200, validation_data=(SBERT_embeddings_test, y_test), callbacks=[early_stopping])

# do predictions
pred_train = sbert_if_model.predict(SBERT_embeddings_train)
pred_train = pred_train.argmax(axis=-1)
print("training accuracy", sbert_if_model.evaluate(SBERT_embeddings_train, y_train)[1])

pred_test = sbert_if_model.predict(SBERT_embeddings_test)
pred_test = pred_test.argmax(axis=-1)
print("test accuracy", sbert_if_model.evaluate(SBERT_embeddings_test, y_test)[1])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy TF-Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/200
# 79/79 [==============================] - 1s 4ms/step - loss: 0.1908 - accuracy: 0.2270 - val_loss: 2.4039 - val_accuracy: 0.2979
# Epoch 2/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.1595 - accuracy: 0.3266 - val_loss: 2.3204 - val_accuracy: 0.3185
# Epoch 3/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.1442 - accuracy: 0.3754 - val_loss: 2.1844 - val_accuracy: 0.3677
# Epoch 4/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.1320 - accuracy: 0.4282 - val_loss: 2.1569 - val_accuracy: 0.3867
# Epoch 5/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.1232 - accuracy: 0.4659 - val_loss: 2.1732 - val_accuracy: 0.3914
# Epoch 6/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.1172 - accuracy: 0.4901 - val_loss: 2.0797 - val_accuracy: 0.4342
# Epoch 7/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.1109 - accuracy: 0.5171 - val_loss: 2.0620 - val_accuracy: 0.4279
# Epoch 8/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.1068 - accuracy: 0.5270 - val_loss: 2.0557 - val_accuracy: 0.4437
# Epoch 9/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.1037 - accuracy: 0.5353 - val_loss: 2.0345 - val_accuracy: 0.4295
# Epoch 10/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.1015 - accuracy: 0.5468 - val_loss: 2.0430 - val_accuracy: 0.4247
# Epoch 11/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0985 - accuracy: 0.5647 - val_loss: 2.0144 - val_accuracy: 0.4517
# Epoch 12/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0966 - accuracy: 0.5659 - val_loss: 2.0205 - val_accuracy: 0.4548
# Epoch 13/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0946 - accuracy: 0.5810 - val_loss: 2.0148 - val_accuracy: 0.4612
# Epoch 14/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0922 - accuracy: 0.5917 - val_loss: 1.9530 - val_accuracy: 0.4643
# Epoch 15/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0894 - accuracy: 0.6000 - val_loss: 1.9442 - val_accuracy: 0.4691
# Epoch 16/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0890 - accuracy: 0.6063 - val_loss: 1.9584 - val_accuracy: 0.4754
# Epoch 17/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0870 - accuracy: 0.6131 - val_loss: 1.9364 - val_accuracy: 0.4770
# Epoch 18/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0848 - accuracy: 0.6202 - val_loss: 1.9812 - val_accuracy: 0.4707
# Epoch 19/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0836 - accuracy: 0.6159 - val_loss: 1.9421 - val_accuracy: 0.4739
# Epoch 20/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0825 - accuracy: 0.6206 - val_loss: 1.9344 - val_accuracy: 0.4849
# Epoch 21/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0812 - accuracy: 0.6310 - val_loss: 1.9412 - val_accuracy: 0.4913
# Epoch 22/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0803 - accuracy: 0.6325 - val_loss: 1.9424 - val_accuracy: 0.4913
# Epoch 23/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0786 - accuracy: 0.6393 - val_loss: 1.9375 - val_accuracy: 0.4913
# Epoch 24/200
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0775 - accuracy: 0.6361 - val_loss: 1.9174 - val_accuracy: 0.4913
# Epoch 25/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0763 - accuracy: 0.6468 - val_loss: 1.9439 - val_accuracy: 0.4992
# Epoch 26/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0757 - accuracy: 0.6480 - val_loss: 1.9536 - val_accuracy: 0.4881
# Epoch 27/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0751 - accuracy: 0.6476 - val_loss: 1.9199 - val_accuracy: 0.4913
# Epoch 28/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0735 - accuracy: 0.6611 - val_loss: 1.9245 - val_accuracy: 0.4992
# Epoch 29/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0734 - accuracy: 0.6595 - val_loss: 1.9492 - val_accuracy: 0.4865
# Epoch 30/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0722 - accuracy: 0.6683 - val_loss: 1.9369 - val_accuracy: 0.4929
# Epoch 31/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0723 - accuracy: 0.6766 - val_loss: 1.9687 - val_accuracy: 0.5008
# Epoch 32/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0709 - accuracy: 0.6698 - val_loss: 1.9834 - val_accuracy: 0.4913
# Epoch 33/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0707 - accuracy: 0.6718 - val_loss: 1.9265 - val_accuracy: 0.5071
# Epoch 34/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0697 - accuracy: 0.6774 - val_loss: 1.9624 - val_accuracy: 0.5008
# Epoch 35/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0688 - accuracy: 0.6817 - val_loss: 1.9677 - val_accuracy: 0.4976
# Epoch 36/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0694 - accuracy: 0.6825 - val_loss: 1.9653 - val_accuracy: 0.5040
# Epoch 37/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0675 - accuracy: 0.6845 - val_loss: 1.9957 - val_accuracy: 0.5008
# Epoch 38/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0666 - accuracy: 0.6877 - val_loss: 1.9880 - val_accuracy: 0.4913
# Epoch 39/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0667 - accuracy: 0.6877 - val_loss: 1.9945 - val_accuracy: 0.4849
# Epoch 40/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0678 - accuracy: 0.6806 - val_loss: 2.0518 - val_accuracy: 0.4913
# Epoch 41/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0665 - accuracy: 0.6921 - val_loss: 2.0299 - val_accuracy: 0.5071
# Epoch 42/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0650 - accuracy: 0.7004 - val_loss: 2.0289 - val_accuracy: 0.4913
# Epoch 43/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0645 - accuracy: 0.6937 - val_loss: 1.9947 - val_accuracy: 0.5119
# Epoch 44/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0638 - accuracy: 0.7040 - val_loss: 2.0338 - val_accuracy: 0.4945
# 79/79 [==============================] - 0s 579us/step
# 79/79 [==============================] - 0s 626us/step - loss: 1.2700 - accuracy: 0.6528
# training accuracy 0.6527777910232544
# 20/20 [==============================] - 0s 564us/step
# 20/20 [==============================] - 0s 590us/step - loss: 1.9174 - accuracy: 0.4913
# test accuracy 0.49128368496894836

# %%
# get hidden layer model 
sbert_if_model_embedding = tf.keras.Sequential([
    
    tf.keras.layers.Dense(units=128, activation="tanh", input_shape=(768,)),
    tf.keras.layers.Dense(units=64, activation="tanh"),
    tf.keras.layers.Dense(units=32, activation="tanh"),

    tf.keras.layers.Dense(units=10, activation="tanh"),
])


sbert_if_model_embedding.layers[0].set_weights(sbert_if_model.layers[0].get_weights())
sbert_if_model_embedding.layers[1].set_weights(sbert_if_model.layers[1].get_weights())
sbert_if_model_embedding.layers[2].set_weights(sbert_if_model.layers[2].get_weights())
sbert_if_model_embedding.layers[3].set_weights(sbert_if_model.layers[3].get_weights())


SBERT_embeddings = np.concatenate((SBERT_embeddings_train, SBERT_embeddings_test))
cluster_embeddings = sbert_if_model_embedding.predict(SBERT_embeddings)
print(cluster_embeddings.shape)
# Out:
# 99/99 [==============================] - 0s 581us/step
# (3151, 10)

# %% [markdown]
# ### K-means Clustering

# %%
perform_kmeans(cluster_embeddings)
# Out:
# 5 / 30
# 6 / 30
# 7 / 30
# 8 / 30
# 9 / 30
# 10 / 30
# 11 / 30
# 12 / 30
# 13 / 30
# 14 / 30
# 15 / 30
# 16 / 30
# 17 / 30
# 18 / 30
# 19 / 30
# 20 / 30
# 21 / 30
# 22 / 30
# 23 / 30
# 24 / 30
# 25 / 30
# 26 / 30
# 27 / 30
# 28 / 30
# 29 / 30
# NMI: 0.4132233902480067

# %%
run_kmeans_best_k(14, cluster_embeddings)
# Out:
# Cluster 1 :
# Cluster Size:========= 147
# Sample Docs:=========
# minor engine oil leaks at rear
# engine overheating
# engine overheating
# unserviceable swing brake cylinder
# unserviceable engine air conditioner
#
# Top words:=========
# engine
# fault
# unserviceable
# motor
# replace
#
# Top failure modes:=========
# fault
# unserviceable
# overheating
# leak
# vibration
#
# Top equipment:=========
# engine
# motor
# hoist
# oil
# propel
#
# Inherent functions in order:
# driving (93)
# protecting (12)
# emitting (9)
# sensing (6)
# generating (4)
# controlling (4)
# matterprocessing (1)
# covering (1)
# restricting (1)
# presenting (1)
# interfacing (1)
# guiding (1)
# transforming (1)
# holding (1)
# ==================================================
#
# Cluster 2 :
# Cluster Size:========= 167
# Sample Docs:=========
# cabin ladder light switch unserviceable
# dust leak operators side window
# small leak from sump gasket
# fuel tank crack
# issues with engine starting
#
# Top words:=========
# fuel
# ladder
# worn
# on
# o-ring
#
# Top failure modes:=========
# worn
# blown
# missing
# unserviceable
# cracked
#
# Top equipment:=========
# ladder
# fuel tank
# o-ring
# tank
# bucket
#
# Inherent functions in order:
# matterprocessing (41)
# covering (29)
# interfacing (23)
# storing (14)
# sensing (14)
# presenting (5)
# holding (4)
# protecting (4)
# transforming (2)
# generating (2)
# restricting (2)
# humaninteraction (2)
# driving (2)
# guiding (2)
# controlling (1)
# ==================================================
#
# Cluster 3 :
# Cluster Size:========= 395
# Sample Docs:=========
# hydraulic breakout has bent pin
# position grease line plate missing
# air tank safety valve is faulty
# replace position mismatched tyre
# coolant flow switch error
#
# Top words:=========
# position
# hydraulic
# air
# unserviceable
# leak
#
# Top failure modes:=========
# unserviceable
# leak
# leaking
# damaged
# missing
#
# Top equipment:=========
# hose
# hydraulic oil
# differential
# cooler
# fan
#
# Inherent functions in order:
# guiding (44)
# protecting (36)
# generating (23)
# holding (20)
# driving (11)
# matterprocessing (7)
# covering (4)
# sensing (4)
# emitting (4)
# restricting (4)
# controlling (3)
# storing (2)
# interfacing (2)
# presenting (1)
# transforming (1)
# humaninteraction (1)
# ==================================================
#
# Cluster 4 :
# Cluster Size:========= 363
# Sample Docs:=========
# rear jackshaft universal joint worn out
# split in back wall weld
# position tyre worn out
# requires new engine belts
# blown transmission hydraulic hose
#
# Top words:=========
# hose
# blown
# leaking
# position
# tyre
#
# Top failure modes:=========
# blown
# leaking
# unserviceable
# broken
# damaged
#
# Top equipment:=========
# hose
# tyre
# brake
# hydraulic hose
# lines
#
# Inherent functions in order:
# guiding (326)
# covering (21)
# driving (7)
# holding (6)
# transforming (6)
# generating (5)
# sensing (5)
# matterprocessing (4)
# controlling (4)
# emitting (3)
# restricting (3)
# protecting (2)
# humaninteraction (1)
# interfacing (1)
# storing (1)
# ==================================================
#
# Cluster 5 :
# Cluster Size:========= 232
# Sample Docs:=========
# headlight fault
# air conditioner fault
# cabin air conditioner fan is unserviceable
# house lights out
# unserviceable air compressor
#
# Top words:=========
# air
# conditioner
# light
# unserviceable
# out
#
# Top failure modes:=========
# unserviceable
# out
# not working
# fault
# blown
#
# Top equipment:=========
# air conditioner
# lights
# light
# compressor
# radiator
#
# Inherent functions in order:
# emitting (260)
# generating (30)
# guiding (13)
# sensing (12)
# covering (9)
# driving (8)
# controlling (6)
# protecting (6)
# storing (4)
# transforming (3)
# humaninteraction (3)
# presenting (3)
# matterprocessing (3)
# restricting (2)
# holding (1)
# ==================================================
#
# Cluster 6 :
# Cluster Size:========= 273
# Sample Docs:=========
# repair faults in cooler pump lube system
# grease system has intermittent fault
# pump oil found leaking
# grease system not working
# fuse for air conditioner keeps blowing
#
# Top words:=========
# fuse
# system
# grease
# coolant
# air
#
# Top failure modes:=========
# leak
# fault
# crack
# keeps blowing
# found
#
# Top equipment:=========
# coolant
# handrail
# grease system
# engine
# guard
#
# Inherent functions in order:
# protecting (186)
# covering (11)
# emitting (11)
# matterprocessing (6)
# generating (4)
# driving (3)
# sensing (2)
# restricting (2)
# guiding (2)
# presenting (2)
# controlling (1)
# storing (1)
# holding (1)
# ==================================================
#
# Cluster 7 :
# Cluster Size:========= 254
# Sample Docs:=========
# fault to front lights
# exhaust fan not running
# alternator not charging
# battery has dropped cell
# inside horn not working
#
# Top words:=========
# pump
# not
# working
# batteries
# unserviceable
#
# Top failure modes:=========
# not working
# unserviceable
# no charge
# fault
# failed
#
# Top equipment:=========
# pump
# compressor
# batteries
# generator
# horn
#
# Inherent functions in order:
# generating (176)
# presenting (23)
# sensing (15)
# covering (9)
# storing (9)
# holding (7)
# restricting (6)
# driving (5)
# interfacing (5)
# matterprocessing (4)
# transforming (4)
# guiding (4)
# protecting (3)
# controlling (2)
# emitting (1)
# ==================================================
#
# Cluster 8 :
# Cluster Size:========= 236
# Sample Docs:=========
# cracked steering tank mo
# mud bucket has cracks
# engine oil leak left hand side several
# fire extinguisher requires
# engine oil leak
#
# Top words:=========
# oil
# leak
# in
# crack
# cracked
#
# Top failure modes:=========
# leak
# crack
# cracked
# cracks
# unserviceable
#
# Top equipment:=========
# oil
# engine
# bucket
# mud bucket
# door
#
# Inherent functions in order:
# protecting (60)
# storing (38)
# driving (31)
# holding (30)
# controlling (20)
# transforming (16)
# matterprocessing (14)
# interfacing (13)
# restricting (10)
# guiding (8)
# covering (6)
# generating (3)
# humaninteraction (2)
# emitting (2)
# presenting (1)
# ==================================================
#
# Cluster 9 :
# Cluster Size:========= 181
# Sample Docs:=========
# belly plate bolts missing
# right hand side hoist rope jumped out of sheave
# right hand fairlead lower mount bolt loose
# reverse camera not working
# left side speaker unserviceable
#
# Top words:=========
# hand
# right
# left
# side
# broken
#
# Top failure modes:=========
# broken
# unserviceable
# leaking
# loose
# missing
#
# Top equipment:=========
# light
# cylinder
# headlight
# bolts
# door
#
# Inherent functions in order:
# holding (70)
# emitting (47)
# guiding (35)
# driving (20)
# controlling (11)
# covering (10)
# protecting (9)
# storing (8)
# interfacing (6)
# sensing (6)
# matterprocessing (4)
# presenting (3)
# restricting (3)
# humaninteraction (3)
# generating (1)
# ==================================================
#
# Cluster 10 :
# Cluster Size:========= 342
# Sample Docs:=========
# steering wheel cover missing
# rear window cracked
# auto-greaser door window requires replacing
# cabin windows cracked
# side windscreen damage
#
# Top words:=========
# window
# fault
# steering
# valve
# door
#
# Top failure modes:=========
# fault
# broken
# leak
# falling off
# leaking
#
# Top equipment:=========
# steering
# brake
# park brake
# door
# cabin
#
# Inherent functions in order:
# controlling (119)
# restricting (15)
# covering (7)
# holding (6)
# emitting (6)
# generating (5)
# storing (5)
# guiding (4)
# driving (4)
# protecting (2)
# presenting (2)
# interfacing (2)
# transforming (2)
# humaninteraction (1)
# sensing (1)
# ==================================================
#
# Cluster 11 :
# Cluster Size:========= 175
# Sample Docs:=========
# bolt missing right hand track
# broken prelube bracket
# bolts missing right track
# headboard supports bent
# worn bogie pads
#
# Top words:=========
# broken
# missing
# pin
# bolts
# on
#
# Top failure modes:=========
# broken
# missing
# loose
# unserviceable
# leaking
#
# Top equipment:=========
# pin
# bolts
# bolt
# bearing
# pulley
#
# Inherent functions in order:
# holding (251)
# interfacing (17)
# guiding (14)
# matterprocessing (12)
# transforming (11)
# controlling (11)
# covering (5)
# storing (4)
# presenting (3)
# restricting (3)
# protecting (3)
# humaninteraction (2)
# generating (2)
# emitting (2)
# driving (1)
# sensing (1)
# ==================================================
#
# Cluster 12 :
# Cluster Size:========= 110
# Sample Docs:=========
# transmission bell housing bolts missing
# rear driveline transmission leak
# hoist drum cracking
# front differential pinnion seal leaking
# transmission fault
#
# Top words:=========
# transmission
# fault
# differential
# leak
# not
#
# Top failure modes:=========
# fault
# leak
# needs aerial
# failed
# earthing out
#
# Top equipment:=========
# transmission
# differential
# PTO
# oil
# am / fm radio
#
# Inherent functions in order:
# transforming (100)
# presenting (13)
# covering (11)
# holding (8)
# interfacing (7)
# matterprocessing (7)
# guiding (5)
# driving (5)
# humaninteraction (5)
# sensing (5)
# controlling (4)
# generating (2)
# restricting (2)
# emitting (1)
# ==================================================
#
# Cluster 13 :
# Cluster Size:========= 140
# Sample Docs:=========
# faulty thermostat
# brakes will not release
# address brake temperature error
# swing brake disc warped
# speedometer not functioning
#
# Top words:=========
# brake
# not
# hoist
# brakes
# temperature
#
# Top failure modes:=========
# temperature error
# unserviceable
# fault
# not working
# broken
#
# Top equipment:=========
# brake
# brakes
# window
# hoist
# hoist brake
#
# Inherent functions in order:
# restricting (54)
# sensing (19)
# humaninteraction (13)
# controlling (7)
# matterprocessing (7)
# interfacing (4)
# presenting (3)
# covering (1)
# transforming (1)
# driving (1)
# ==================================================
#
# Cluster 14 :
# Cluster Size:========= 0
# Sample Docs:=========
# swing fault
# chip indicators ( leaking )
# swing motor number flashed
# input seal into left hand walk gearbox is leaking
# brake accumulator pressure
#
# Top words:=========
# brake
# cabin
# seat
# motor
# fault
#
# Top failure modes:=========
# fault
# needs loctite
# unserviceable
# on
# leak
#
# Top equipment:=========
# cabin seat
# swing
# brake
# resolver
# drag
#
# Inherent functions in order:
# sensing (27)
# storing (27)
# restricting (12)
# matterprocessing (10)
# presenting (9)
# driving (8)
# humaninteraction (7)
# emitting (7)
# transforming (6)
# covering (6)
# interfacing (6)
# controlling (5)
# generating (4)
# holding (3)
# guiding (2)
# protecting (1)
# ==================================================
#
#
#
# Ave number of documents per cluster: 225.07142857142858
# Median number of documents per cluster: 206.5
# Min number of documents per cluster: 110
# Max number of documents per cluster: 395
#
# Percentage of clusters with 1 main Inherent function (80% of docs): 0.14285714285714285
# Percentage of clusters with 2 or 3 main Inherent functions (80% of docs): 0.21428571428571427
# Percentage of documents in clusters with 1 main Inherent function (80% of docs): 0.19898444938114884
# Percentage of documents in clusters with 2 or 3 main Inherent functions (80% of docs): 0.2668993970168201

# %% [markdown]
# ### Average Hierachical Clustering

# %%
linkage_data_ave = perform_hierarchical_clustering(cluster_embeddings, "average")
# Out:
# NMI: 0.40977379976562084

# %%
get_hierarchical_clusters(16, linkage_data_ave)
# Out:
# Cluster 1 :
# Cluster Size:========= 126
# Sample Docs:=========
# engine will not run
# engine not starting all the time
# propel fault needs fixing
# engine fault
# synchronous motor left hand bearing overtemperature alarms
# replace engine bay light
# engine overheating
# engine shutdown cable unserviceable
# propel has a fault
# engine will not fire
#
# Top words:=========
# engine
# unserviceable
# fault
# motor
# replace
#
# Top failure modes:=========
# unserviceable
# fault
# overheating
# leak
# vibration
#
# Top equipment:=========
# engine
# motor
# engine air conditioner
# hoist
# oil
#
# Inherent functions in order:
# driving (87)
# emitting (10)
# sensing (8)
# generating (3)
# protecting (3)
# presenting (2)
# controlling (2)
# matterprocessing (2)
# restricting (2)
# covering (2)
# guiding (2)
# interfacing (1)
# storing (1)
# holding (1)
# ==================================================
#
# Cluster 2 :
# Cluster Size:========= 194
# Sample Docs:=========
# compressor found not working
# position turbo coolant leak
# alternator unserviceable
# faulty turbo
# coolant pump not working
# faulty alternator
# air compressor unserviceable
# no charge in blower inverter batteries
# exhaust fan not running
# CW number cylinder leaking coolant into
#
# Top words:=========
# batteries
# not
# pump
# compressor
# no
#
# Top failure modes:=========
# no charge
# unserviceable
# not working
# fault
# dropped cell
#
# Top equipment:=========
# pump
# compressor
# batteries
# generator
# battery
#
# Inherent functions in order:
# generating (157)
# storing (7)
# sensing (5)
# covering (5)
# driving (4)
# holding (4)
# matterprocessing (2)
# controlling (2)
# guiding (2)
# protecting (2)
# restricting (1)
# presenting (1)
# interfacing (1)
# emitting (1)
# ==================================================
#
# Cluster 3 :
# Cluster Size:========= 371
# Sample Docs:=========
# unserviceable lights
# roof light number out on left hand side of dragline
# air conditioning fans unserviceable
# air conditioner fault
# unserviceable siren
# air conditioner freezing up in cabin
# dash lights not working
# beacon not working
# all dash lights on
# aftercooler temperature error
#
# Top words:=========
# air
# conditioner
# light
# unserviceable
# out
#
# Top failure modes:=========
# unserviceable
# out
# not working
# fault
# blown
#
# Top equipment:=========
# air conditioner
# lights
# light
# compressor
# radiator
#
# Inherent functions in order:
# emitting (259)
# generating (31)
# guiding (16)
# sensing (11)
# driving (11)
# covering (9)
# protecting (7)
# controlling (6)
# restricting (5)
# storing (5)
# transforming (3)
# matterprocessing (3)
# humaninteraction (2)
# holding (2)
# presenting (1)
# ==================================================
#
# Cluster 4 :
# Cluster Size:========= 60
# Sample Docs:=========
# air horn fault
# unserviceable diode bank air conditioner fans TBC
# torque convertor charge hose leak
# not working compressor
# faulty horn
# airhorn is not working
# minor leak differential housing filter
# horn unserviceable
# tractor radio unserviceable
# number hoist generator flashed over
#
# Top words:=========
# horn
# working
# not
# air
# unserviceable
#
# Top failure modes:=========
# not working
# unserviceable
# leak
# fault
# missing
#
# Top equipment:=========
# horn
# air horn
# torque converter
# brake
# pump
#
# Inherent functions in order:
# presenting (21)
# generating (9)
# humaninteraction (6)
# guiding (5)
# transforming (5)
# matterprocessing (3)
# restricting (3)
# controlling (2)
# covering (2)
# driving (2)
# sensing (1)
# interfacing (1)
# ==================================================
#
# Cluster 5 :
# Cluster Size:========= 44
# Sample Docs:=========
# alarm from slew pump chip sensor
# environmental filter fittings oil leaks
# camera monitor in cabin faulty
# speedometer has stopped working
# camera fault
# alarm triggered by slew pump chip sensor
# cleaning needed for walk motor brake switches
# unserviceable thermostat
# chip indicators ( leaking )
# contamination switch for pto pump on
#
# Top words:=========
# not
# unserviceable
# for
# brake
# is
#
# Top failure modes:=========
# unserviceable
# not working
# on
# need cleaning
# faulty
#
# Top equipment:=========
# speedometer
# thermostat
# filter
# screen
# camera
#
# Inherent functions in order:
# sensing (29)
# matterprocessing (6)
# humaninteraction (4)
# presenting (3)
# covering (1)
# interfacing (1)
# ==================================================
#
# Cluster 6 :
# Cluster Size:========= 55
# Sample Docs:=========
# number slew pump contamination switch unserviceable
# blown o-ring on left hand lift cylinder
# blown o-ring on steering pump
# slew pump chip sensor is alarming
# blown o-ring in boom hose
# pump leak
# blown work lights
# blown o-ring off steering hose
# unserviceable pump contamination switch
# pto pump contamination switch is on
#
# Top words:=========
# pump
# blown
# o-ring
# unserviceable
# on
#
# Top failure modes:=========
# blown
# unserviceable
# not working
# on
# alarm
#
# Top equipment:=========
# o-ring
# pump
# steering
# pump contamination switch
# pto pump contamination switch
#
# Inherent functions in order:
# covering (20)
# sensing (16)
# presenting (5)
# generating (4)
# interfacing (3)
# emitting (2)
# matterprocessing (2)
# transforming (1)
# holding (1)
# guiding (1)
# ==================================================
#
# Cluster 7 :
# Cluster Size:========= 372
# Sample Docs:=========
# damaged position rim
# lube system in alarm
# hydraulic oil leak right hand pump
# air leak near side of door
# padding found worn
# cooler pump lube system is faulty
# lube system faults
# reported grease system unserviceable
# position grease line plate missing
# needs right hand side fire extinguisher
#
# Top words:=========
# leak
# air
# system
# coolant
# grease
#
# Top failure modes:=========
# leak
# fault
# unserviceable
# leaking
# damaged
#
# Top equipment:=========
# coolant
# cooler
# handrail
# guard
# grease system
#
# Inherent functions in order:
# protecting (222)
# guiding (28)
# generating (26)
# holding (22)
# driving (15)
# emitting (14)
# covering (9)
# matterprocessing (9)
# controlling (6)
# restricting (6)
# sensing (5)
# presenting (4)
# storing (3)
# transforming (2)
# interfacing (1)
# ==================================================
#
# Cluster 8 :
# Cluster Size:========= 358
# Sample Docs:=========
# worn seat cover
# GET worn cutting edges
# pressure control valve in cabin leaking
# oil leak at engine remote line
# drivers door seal unserviceable
# grease fitting coupling unserviceable
# repair crack in rock deflector
# fire extinguisher bracket on deck loose
# cracked steering tank suction tube
# drivers door hinge unserviceable
#
# Top words:=========
# oil
# leak
# in
# crack
# cracked
#
# Top failure modes:=========
# leak
# crack
# cracked
# cracks
# worn
#
# Top equipment:=========
# oil
# engine
# bucket
# fuel tank
# tank
#
# Inherent functions in order:
# protecting (71)
# storing (53)
# matterprocessing (50)
# holding (38)
# driving (35)
# controlling (23)
# transforming (19)
# interfacing (16)
# covering (16)
# guiding (10)
# restricting (9)
# emitting (6)
# generating (4)
# humaninteraction (3)
# presenting (3)
# sensing (2)
# ==================================================
#
# Cluster 9 :
# Cluster Size:========= 399
# Sample Docs:=========
# leaking injector
# position tyre damage
# cable required
# blown grease lines
# brake cooling hose leaking on right hand rear
# boom hose o-ring is blown
# broken grease lines
# leaking steering accumulator
# exhaust leak
# PTO shaft requires
#
# Top words:=========
# hose
# blown
# leaking
# position
# tyre
#
# Top failure modes:=========
# blown
# leaking
# unserviceable
# damaged
# broken
#
# Top equipment:=========
# hose
# tyre
# brake
# cylinder
# hydraulic hose
#
# Inherent functions in order:
# guiding (322)
# covering (23)
# driving (12)
# generating (6)
# transforming (6)
# matterprocessing (5)
# protecting (5)
# restricting (5)
# sensing (4)
# holding (4)
# emitting (3)
# controlling (1)
# interfacing (1)
# storing (1)
# humaninteraction (1)
# ==================================================
#
# Cluster 10 :
# Cluster Size:========= 627
# Sample Docs:=========
# track assembly idler pin coming out
# bottom position number shock absorber mounts loose
# left hand front cam frame bolts loose
# broken right hand headlight
# hole in door frame
# loose damaged GET
# right hand rear ladder bent
# hoist trunnion bushes are missing
# pulley bearing unserviceable
# right hand fuel tank crack
#
# Top words:=========
# hand
# right
# left
# broken
# missing
#
# Top failure modes:=========
# broken
# missing
# unserviceable
# loose
# leaking
#
# Top equipment:=========
# bolts
# pin
# bearing
# bolt
# pulley
#
# Inherent functions in order:
# holding (328)
# guiding (64)
# emitting (49)
# interfacing (26)
# controlling (21)
# matterprocessing (20)
# driving (20)
# covering (19)
# transforming (17)
# storing (16)
# protecting (11)
# sensing (10)
# presenting (7)
# generating (7)
# restricting (6)
# humaninteraction (6)
# ==================================================
#
# Cluster 11 :
# Cluster Size:========= 9
# Sample Docs:=========
# drag blower inverter is earthing out
# air filters plugged
# check movement in steering column
# drag blower inverter earthing out
# slip ring overgreasing
# air filter housing damaged a was
# drag blower inverter experiencing earthing out
# transmission breather oil leak TBC
# drag blower inverter has earthing out
#
# Top words:=========
# drag
# blower
# inverter
# earthing
# out
#
# Top failure modes:=========
# earthing out
# damaged
# overgreasing
# leak
# plugged
#
# Top equipment:=========
# drag blower inverter
# air filter
# filter
# housing
# slip ring
#
# Inherent functions in order:
# transforming (6)
# matterprocessing (2)
# holding (1)
# ==================================================
#
# Cluster 12 :
# Cluster Size:========= 124
# Sample Docs:=========
# swing overvoltage
# pto not meshing
# am fm radio needs aerial
# airhorn needs repair not working
# transmission fault
# low transmission level
# transmission overheating
# to swing plugging
# inverter earthing out
# minor transmission leak
#
# Top words:=========
# transmission
# fault
# differential
# PTO
# radio
#
# Top failure modes:=========
# fault
# needs aerial
# failed
# leak
# leaking
#
# Top equipment:=========
# transmission
# differential
# PTO
# am / fm radio
# oil
#
# Inherent functions in order:
# transforming (86)
# covering (8)
# presenting (8)
# guiding (5)
# interfacing (5)
# holding (3)
# matterprocessing (2)
# controlling (2)
# driving (1)
# humaninteraction (1)
# sensing (1)
# restricting (1)
# emitting (1)
# ==================================================
#
# Cluster 13 :
# Cluster Size:========= 145
# Sample Docs:=========
# ripper middle light blown
# need repair mast dust flap
# cracked windscreen
# damaged cabin glass
# control valve is unserviceable
# slow steering
# starter isolator seized
# cabin door damage
# top steering box seal leaking
# middle air drain tap leaking
#
# Top words:=========
# window
# valve
# door
# steering
# broken
#
# Top failure modes:=========
# broken
# fault
# leak
# faulty
# leaking
#
# Top equipment:=========
# steering
# isolator
# door
# cabin
# control valve
#
# Inherent functions in order:
# controlling (112)
# covering (7)
# generating (5)
# storing (4)
# driving (4)
# restricting (3)
# interfacing (3)
# holding (2)
# transforming (2)
# protecting (1)
# guiding (1)
# emitting (1)
# ==================================================
#
# Cluster 14 :
# Cluster Size:========= 114
# Sample Docs:=========
# brake temperature error present
# brakes dragging
# swing brakes coming on now then
# temperature error in hoist brake
# Tele-Remote faults
# reported hoist brakes not holding
# rear gate handrails bent
# key broken off in ignition
# park brake fault
# brake temperature error
#
# Top words:=========
# brake
# fault
# hoist
# park
# brakes
#
# Top failure modes:=========
# fault
# temperature error
# broken
# damaged
# not releasing
#
# Top equipment:=========
# brake
# park brake
# brakes
# window
# hoist
#
# Inherent functions in order:
# restricting (65)
# controlling (14)
# humaninteraction (13)
# matterprocessing (5)
# interfacing (5)
# presenting (4)
# emitting (3)
# guiding (2)
# sensing (2)
# transforming (1)
# ==================================================
#
# Cluster 15 :
# Cluster Size:========= 35
# Sample Docs:=========
# depth counter issue
# pressure gauge for brake pump not working
# damaged ladder
# ladder unserviceable
# ladder issue
# depth counter unserviceable
# ladder is stopping on the way down
# depth counter needs replacement unserviceable
# handrail weld found broken
# adjust hoist brake out of adjustment
#
# Top words:=========
# ladder
# not
# unserviceable
# depth
# counter
#
# Top failure modes:=========
# unserviceable
# not working
# worn
# fault
# issue
#
# Top equipment:=========
# ladder
# depth counter
# handrail weld
# controller filter
# parts washer pump pressure gauge
#
# Inherent functions in order:
# interfacing (18)
# sensing (7)
# covering (3)
# matterprocessing (2)
# presenting (2)
# restricting (2)
# humaninteraction (1)
# ==================================================
#
# Cluster 16 :
# Cluster Size:========= 118
# Sample Docs:=========
# leak at fuel tank
# fuel system keeps cutting out
# ripper shank broken
# swing motor number flashed
# walk motor brake sensor not functioning
# swing motor rtd is wired incorrectly
# hoist drag fault
# vibration in house fan number
# boarding gate latch not working
# spray system water pump leak PO
#
# Top words:=========
# cabin
# brake
# seat
# not
# fault
#
# Top failure modes:=========
# fault
# not working
# needs loctite
# leak
# unserviceable
#
# Top equipment:=========
# cabin seat
# swing
# resolver
# drag
# hoist
#
# Inherent functions in order:
# storing (23)
# sensing (16)
# restricting (11)
# generating (9)
# presenting (8)
# driving (8)
# matterprocessing (7)
# controlling (7)
# covering (6)
# transforming (5)
# interfacing (5)
# emitting (4)
# humaninteraction (3)
# protecting (2)
# guiding (2)
# holding (2)
# ==================================================
#
#
#
# Ave number of documents per cluster: 196.9375
# Median number of documents per cluster: 125.0
# Min number of documents per cluster: 9
# Max number of documents per cluster: 627
#
# Percentage of clusters with 1 main Inherent function (80% of docs): 0.125
# Percentage of clusters with 2 or 3 main Inherent functions (80% of docs): 0.5
# Percentage of documents in clusters with 1 main Inherent function (80% of docs): 0.18819422405585529
# Percentage of documents in clusters with 2 or 3 main Inherent functions (80% of docs): 0.3072040622024754

# %%
get_hierarchical_clusters(19, linkage_data_ave)
# Out:
# Cluster 1 :
# Cluster Size:========= 126
# Sample Docs:=========
# low engine power
# engine overheating
# engine will not run
# engine speed sensor faults
# synchronous motor not synchronising
# replace unserviceable box coupling
# VIMS error
# blow by fault on engine
# propel fault
# engine will not start
#
# Top words:=========
# engine
# unserviceable
# fault
# motor
# replace
#
# Top failure modes:=========
# unserviceable
# fault
# overheating
# leak
# vibration
#
# Top equipment:=========
# engine
# motor
# engine air conditioner
# hoist
# oil
#
# Inherent functions in order:
# driving (87)
# emitting (10)
# sensing (8)
# generating (3)
# protecting (3)
# presenting (2)
# controlling (2)
# matterprocessing (2)
# restricting (2)
# covering (2)
# guiding (2)
# interfacing (1)
# storing (1)
# holding (1)
# ==================================================
#
# Cluster 2 :
# Cluster Size:========= 194
# Sample Docs:=========
# drag generator overvoltage alarms
# inverter batteries are not charged
# no charge in inverter batteries
# alternator overcharged
# <num>W/<num> pump filters requires
# compressor safety valve leaking
# hydraulic pump leak
# drag generator overvoltage
# alternator fault
# generator fault found
#
# Top words:=========
# batteries
# not
# pump
# compressor
# no
#
# Top failure modes:=========
# no charge
# unserviceable
# not working
# fault
# dropped cell
#
# Top equipment:=========
# pump
# compressor
# batteries
# generator
# battery
#
# Inherent functions in order:
# generating (157)
# storing (7)
# sensing (5)
# covering (5)
# driving (4)
# holding (4)
# matterprocessing (2)
# controlling (2)
# guiding (2)
# protecting (2)
# restricting (1)
# presenting (1)
# interfacing (1)
# emitting (1)
# ==================================================
#
# Cluster 3 :
# Cluster Size:========= 371
# Sample Docs:=========
# A-frame lights out
# cabin lights require
# blown headlight
# air conditioner compressor keeps tripping out
# air conditioner cut out fault
# faulty air tank safety valve
# a-frame light remains out
# batteries charge rate
# lighting work lights unserviceable
# air conditioner compressor tripping out
#
# Top words:=========
# air
# conditioner
# light
# unserviceable
# out
#
# Top failure modes:=========
# unserviceable
# out
# not working
# fault
# blown
#
# Top equipment:=========
# air conditioner
# lights
# light
# compressor
# radiator
#
# Inherent functions in order:
# emitting (259)
# generating (31)
# guiding (16)
# sensing (11)
# driving (11)
# covering (9)
# protecting (7)
# controlling (6)
# restricting (5)
# storing (5)
# transforming (3)
# matterprocessing (3)
# humaninteraction (2)
# holding (2)
# presenting (1)
# ==================================================
#
# Cluster 4 :
# Cluster Size:========= 60
# Sample Docs:=========
# not working parts washer pump pressure gauge
# torque converter fan pump oil leak
# minor leak differential housing filter
# unserviceable differential drain plugs
# horn not working
# hoist pony drive motor stopped working
# Tele-Remote fault
# number hoist generator flashed over
# horn unserviceable
# air horn disconnected
#
# Top words:=========
# horn
# working
# not
# air
# unserviceable
#
# Top failure modes:=========
# not working
# unserviceable
# leak
# fault
# missing
#
# Top equipment:=========
# horn
# air horn
# torque converter
# brake
# pump
#
# Inherent functions in order:
# presenting (21)
# generating (9)
# humaninteraction (6)
# guiding (5)
# transforming (5)
# matterprocessing (3)
# restricting (3)
# controlling (2)
# covering (2)
# driving (2)
# sensing (1)
# interfacing (1)
# ==================================================
#
# Cluster 5 :
# Cluster Size:========= 44
# Sample Docs:=========
# contamination switch for pto pump on
# need cleaning for walk motor brake switches
# <sensitive> depth counter not working
# unserviceable thermostat
# unserviceable input shaft seal
# speedometer not working
# speedometer not working
# camera monitor in cabin faulty
# contamination switch for swing pump is on
# alarm from slew pump chip sensor
#
# Top words:=========
# not
# unserviceable
# for
# brake
# is
#
# Top failure modes:=========
# unserviceable
# not working
# on
# need cleaning
# faulty
#
# Top equipment:=========
# speedometer
# thermostat
# filter
# screen
# camera
#
# Inherent functions in order:
# sensing (29)
# matterprocessing (6)
# humaninteraction (4)
# presenting (3)
# covering (1)
# interfacing (1)
# ==================================================
#
# Cluster 6 :
# Cluster Size:========= 55
# Sample Docs:=========
# blown o-ring on left hand lift cylinder
# engine pump o-ring is blown
# cabin jacking cylinder ends unserviceable
# brake pump pressure gauge is not working
# empty cam lube drum
# blown o-ring on brake filter
# main pump leaking at face
# blown o-ring on steering hose
# unserviceable rotary o-ring seals PO
# pump leak
#
# Top words:=========
# pump
# blown
# o-ring
# unserviceable
# on
#
# Top failure modes:=========
# blown
# unserviceable
# not working
# on
# alarm
#
# Top equipment:=========
# o-ring
# pump
# steering
# pump contamination switch
# pto pump contamination switch
#
# Inherent functions in order:
# covering (20)
# sensing (16)
# presenting (5)
# generating (4)
# interfacing (3)
# emitting (2)
# matterprocessing (2)
# transforming (1)
# holding (1)
# guiding (1)
# ==================================================
#
# Cluster 7 :
# Cluster Size:========= 372
# Sample Docs:=========
# return idlers shaft spinning in mount
# air tank safety valve found faulty
# fault in drivers window
# clevis pin grease not present
# worn fan belts
# position inside hub oil leak
# air tank safety valve needs replacement faulty
# cracked blade liner
# fire system fault
# circuit grease pump unserviceable
#
# Top words:=========
# leak
# air
# system
# coolant
# grease
#
# Top failure modes:=========
# leak
# fault
# unserviceable
# leaking
# damaged
#
# Top equipment:=========
# coolant
# cooler
# handrail
# guard
# grease system
#
# Inherent functions in order:
# protecting (222)
# guiding (28)
# generating (26)
# holding (22)
# driving (15)
# emitting (14)
# covering (9)
# matterprocessing (9)
# controlling (6)
# restricting (6)
# sensing (5)
# presenting (4)
# storing (3)
# transforming (2)
# interfacing (1)
# ==================================================
#
# Cluster 8 :
# Cluster Size:========= 42
# Sample Docs:=========
# bucket teeth worn
# all worn bucket teeth
# bucket teeth missing
# tooth off bucket
# cutting edge bolts require
# worn seat
# cutting edge needs
# worn universal joints
# lost drive noisy front drop box
# creeping bucket
#
# Top words:=========
# worn
# cutting
# bucket
# edges
# teeth
#
# Top failure modes:=========
# worn
# cracked
# unserviceable
# missing
# leak
#
# Top equipment:=========
# bucket
# cutting edges
# teeth
# cutting edge
# transmission
#
# Inherent functions in order:
# matterprocessing (26)
# transforming (6)
# storing (4)
# interfacing (2)
# controlling (1)
# covering (1)
# driving (1)
# protecting (1)
# ==================================================
#
# Cluster 9 :
# Cluster Size:========= 316
# Sample Docs:=========
# engine mounts unserviceable
# mud bucket is cracked
# bucket cutting edges loose
# fuel tank module cracked
# oil leak around transmission
# oil leak rear of engine
# bonnet hinge bushes unserviceable
# oil leaking from dipstick pipe
# fire suppression fault
# fire extinguisher bracket unserviceable outside cabin
#
# Top words:=========
# oil
# leak
# in
# crack
# cracked
#
# Top failure modes:=========
# leak
# crack
# cracked
# cracks
# leaking
#
# Top equipment:=========
# oil
# engine
# fuel tank
# tank
# bucket
#
# Inherent functions in order:
# protecting (70)
# storing (49)
# holding (38)
# driving (34)
# matterprocessing (24)
# controlling (22)
# covering (15)
# interfacing (14)
# transforming (13)
# guiding (10)
# restricting (9)
# emitting (6)
# generating (4)
# humaninteraction (3)
# presenting (3)
# sensing (2)
# ==================================================
#
# Cluster 10 :
# Cluster Size:========= 399
# Sample Docs:=========
# heater hose in cabin roof unserviceable
# unserviceable cabin light
# brake cooling hose leaking on right hand rear
# blown brake hose
# broken crowd cylinder guard
# PTO shaft unserviceable PO
# position brake cooling hose unserviceable
# burst hose lube system
# split in back wall weld
# worn damaged hose
#
# Top words:=========
# hose
# blown
# leaking
# position
# tyre
#
# Top failure modes:=========
# blown
# leaking
# unserviceable
# damaged
# broken
#
# Top equipment:=========
# hose
# tyre
# brake
# cylinder
# hydraulic hose
#
# Inherent functions in order:
# guiding (322)
# covering (23)
# driving (12)
# generating (6)
# transforming (6)
# matterprocessing (5)
# protecting (5)
# restricting (5)
# sensing (4)
# holding (4)
# emitting (3)
# controlling (1)
# interfacing (1)
# storing (1)
# humaninteraction (1)
# ==================================================
#
# Cluster 11 :
# Cluster Size:========= 219
# Sample Docs:=========
# left hand upper mirror broken
# bent right hand side lift cylinder
# smashed left hand roof mirror
# left hand lower hoist chain worn on bucket
# right hand side tooth adaptor missing
# bottom right hand side headlight blown
# right front bonnet bracket broken
# right hand trammel all welds broken
# right hand side headlight requires
# left hand side front inner light unserviceable
#
# Top words:=========
# hand
# right
# left
# side
# broken
#
# Top failure modes:=========
# broken
# unserviceable
# leaking
# loose
# missing
#
# Top equipment:=========
# light
# cylinder
# headlight
# mirror
# door
#
# Inherent functions in order:
# holding (59)
# emitting (47)
# guiding (37)
# driving (17)
# controlling (11)
# covering (10)
# storing (8)
# protecting (8)
# interfacing (6)
# matterprocessing (4)
# presenting (3)
# restricting (3)
# humaninteraction (3)
# sensing (2)
# generating (1)
# ==================================================
#
# Cluster 12 :
# Cluster Size:========= 408
# Sample Docs:=========
# bolt missing off radiator grill
# bearing temperature
# missing centre pintle bolt
# broken bolts on swing pinion
# two-way handpiece chord stretched
# damage pin coming out of H-link
# head pulley knocking bearing
# tub hook bent
# bolts missing left right tracks
# minor oil leak around differential
#
# Top words:=========
# broken
# missing
# bolts
# pin
# on
#
# Top failure modes:=========
# broken
# missing
# loose
# unserviceable
# leaking
#
# Top equipment:=========
# bolts
# pin
# pulley
# bearing
# bolt
#
# Inherent functions in order:
# holding (269)
# guiding (27)
# interfacing (20)
# transforming (17)
# matterprocessing (16)
# controlling (10)
# covering (9)
# storing (8)
# sensing (8)
# generating (6)
# presenting (4)
# driving (3)
# humaninteraction (3)
# protecting (3)
# restricting (3)
# emitting (2)
# ==================================================
#
# Cluster 13 :
# Cluster Size:========= 9
# Sample Docs:=========
# drag blower inverter earthing out
# slip ring overgreasing
# transmission breather oil leak TBC
# check movement in steering column
# air filters plugged
# drag blower inverter has earthing out
# drag blower inverter experiencing earthing out
# drag blower inverter is earthing out
# air filter housing damaged a was
#
# Top words:=========
# drag
# blower
# inverter
# earthing
# out
#
# Top failure modes:=========
# earthing out
# damaged
# overgreasing
# leak
# plugged
#
# Top equipment:=========
# drag blower inverter
# air filter
# filter
# housing
# slip ring
#
# Inherent functions in order:
# transforming (6)
# matterprocessing (2)
# holding (1)
# ==================================================
#
# Cluster 14 :
# Cluster Size:========= 124
# Sample Docs:=========
# unserviceable transmission screen magnet
# minor transmission oil leak
# PTO input seal leaking
# front differential oil contaminated see text
# transmission slipping fault present
# pto is not meshing
# main transformer overload fault
# hoist drum cracking on
# electrical PTO will not engage
# transmission fault
#
# Top words:=========
# transmission
# fault
# differential
# PTO
# radio
#
# Top failure modes:=========
# fault
# needs aerial
# failed
# leak
# leaking
#
# Top equipment:=========
# transmission
# differential
# PTO
# am / fm radio
# oil
#
# Inherent functions in order:
# transforming (86)
# covering (8)
# presenting (8)
# guiding (5)
# interfacing (5)
# holding (3)
# matterprocessing (2)
# controlling (2)
# driving (1)
# humaninteraction (1)
# sensing (1)
# restricting (1)
# emitting (1)
# ==================================================
#
# Cluster 15 :
# Cluster Size:========= 145
# Sample Docs:=========
# steering fault ride control
# damaged windows
# repair fault in generator
# position wheel hub damaged
# ripper control valve falling off
# drivers window is faulty
# control valve found unserviceable
# steering oil leak
# steering control valve leaking from
# control valve is falling off
#
# Top words:=========
# window
# valve
# door
# steering
# broken
#
# Top failure modes:=========
# broken
# fault
# leak
# faulty
# leaking
#
# Top equipment:=========
# steering
# isolator
# door
# cabin
# control valve
#
# Inherent functions in order:
# controlling (112)
# covering (7)
# generating (5)
# storing (4)
# driving (4)
# restricting (3)
# interfacing (3)
# holding (2)
# transforming (2)
# protecting (1)
# guiding (1)
# emitting (1)
# ==================================================
#
# Cluster 16 :
# Cluster Size:========= 114
# Sample Docs:=========
# hoist brake filter worn
# park brake not releasing
# park brake fault
# damaged window door
# swing brakes coming on now then
# park brake relay valve leaking
# park brake light outside blown
# low slew pump cavity
# Tele-Remote faults
# low voltage alarms on VIMS
#
# Top words:=========
# brake
# fault
# hoist
# park
# brakes
#
# Top failure modes:=========
# fault
# temperature error
# broken
# damaged
# not releasing
#
# Top equipment:=========
# brake
# park brake
# brakes
# window
# hoist
#
# Inherent functions in order:
# restricting (65)
# controlling (14)
# humaninteraction (13)
# matterprocessing (5)
# interfacing (5)
# presenting (4)
# emitting (3)
# guiding (2)
# sensing (2)
# transforming (1)
# ==================================================
#
# Cluster 17 :
# Cluster Size:========= 35
# Sample Docs:=========
# worn filter for hoist brake
# ladder issue
# ladder issue
# depth counter is unserviceable
# ladder fault
# cabin ladder light switch unserviceable
# depth counter unserviceable
# ladder fault
# ladder getting stuck going down
# depth counter needs replacement unserviceable
#
# Top words:=========
# ladder
# not
# unserviceable
# depth
# counter
#
# Top failure modes:=========
# unserviceable
# not working
# worn
# fault
# issue
#
# Top equipment:=========
# ladder
# depth counter
# handrail weld
# controller filter
# parts washer pump pressure gauge
#
# Inherent functions in order:
# interfacing (18)
# sensing (7)
# covering (3)
# matterprocessing (2)
# presenting (2)
# restricting (2)
# humaninteraction (1)
# ==================================================
#
# Cluster 18 :
# Cluster Size:========= 32
# Sample Docs:=========
# drag temperature alarm
# drag motion trip
# auto-greaser not working
# differential lock broken
# swing need to brake
# auto-greaser fault
# drag stopped new bearing
# hoist drag brake is out of adjustment
# ladder controller unserviceable
# drag fault
#
# Top words:=========
# drag
# hoist
# fault
# brake
# to
#
# Top failure modes:=========
# fault
# broken
# vibration
# not working
# out of adjustment
#
# Top equipment:=========
# drag
# swing
# hoist drag brake
# hoist
# pinion
#
# Inherent functions in order:
# restricting (6)
# transforming (5)
# generating (5)
# matterprocessing (4)
# controlling (3)
# driving (3)
# presenting (2)
# covering (1)
# sensing (1)
# guiding (1)
# holding (1)
# ==================================================
#
# Cluster 19 :
# Cluster Size:========= 86
# Sample Docs:=========
# loctite needed for cabin seat
# fuel sender unserviceable light on dash
# cabin cover loose
# cabin seat requires loctite
# swing resolver fault
# fuel system issue with
# hoist resolver faults
# faulty fuel injectors
# cabin seat needs loctite
# because of flat batteries again
#
# Top words:=========
# cabin
# seat
# motor
# brake
# not
#
# Top failure modes:=========
# needs loctite
# fault
# leak
# unserviceable
# not working
#
# Top equipment:=========
# cabin seat
# resolver
# accumulator
# swing
# brake
#
# Inherent functions in order:
# storing (23)
# sensing (15)
# presenting (6)
# restricting (5)
# covering (5)
# interfacing (5)
# driving (5)
# generating (4)
# emitting (4)
# controlling (4)
# matterprocessing (3)
# humaninteraction (3)
# protecting (2)
# guiding (1)
# holding (1)
# ==================================================
#
#
#
# Ave number of documents per cluster: 165.8421052631579
# Median number of documents per cluster: 124
# Min number of documents per cluster: 9
# Max number of documents per cluster: 408
#
# Percentage of clusters with 1 main Inherent function (80% of docs): 0.10526315789473684
# Percentage of clusters with 2 or 3 main Inherent functions (80% of docs): 0.47368421052631576
# Percentage of documents in clusters with 1 main Inherent function (80% of docs): 0.18819422405585529
# Percentage of documents in clusters with 2 or 3 main Inherent functions (80% of docs): 0.32053316407489685

# %% [markdown]
# ### Ward Hierarchical Clustering

# %%
linkage_data_ward = perform_hierarchical_clustering(cluster_embeddings, "ward")
# Out:
# NMI: 0.39283098348271794

# %%
get_hierarchical_clusters(13, linkage_data_ward)
# Out:
# Cluster 1 :
# Cluster Size:========= 176
# Sample Docs:=========
# compressor lost power
# batteries show no charge
# differential lock broken
# no excitation on hoist
# alternator not charging
# compressor found not working
# replace inverter batteries with no charge
# drag generator fault
# hydraulic pump number bad leak
# swing generator overvoltage
#
# Top words:=========
# batteries
# not
# charge
# compressor
# no
#
# Top failure modes:=========
# no charge
# unserviceable
# not working
# fault
# failed
#
# Top equipment:=========
# compressor
# batteries
# generator
# pump
# battery
#
# Inherent functions in order:
# generating (143)
# storing (8)
# covering (4)
# driving (4)
# controlling (3)
# holding (3)
# matterprocessing (2)
# sensing (2)
# protecting (2)
# emitting (2)
# restricting (1)
# interfacing (1)
# guiding (1)
# ==================================================
#
# Cluster 2 :
# Cluster Size:========= 338
# Sample Docs:=========
# engine fan speed resistor is not working
# windrow light not working
# air conditioner compressor corroded
# air conditioner fan unserviceable new
# rear air conditioner unserviceable
# air conditioner warm
# engine air conditioner requires repair
# lost lights inside circuit breaker
# air conditioner fault
# unserviceable air separator
#
# Top words:=========
# air
# conditioner
# light
# lights
# out
#
# Top failure modes:=========
# unserviceable
# out
# not working
# fault
# blown
#
# Top equipment:=========
# air conditioner
# lights
# light
# radiator
# boom
#
# Inherent functions in order:
# emitting (245)
# generating (23)
# guiding (16)
# driving (10)
# covering (9)
# sensing (7)
# protecting (6)
# controlling (5)
# restricting (4)
# transforming (3)
# matterprocessing (3)
# humaninteraction (2)
# storing (2)
# holding (2)
# presenting (1)
# ==================================================
#
# Cluster 3 :
# Cluster Size:========= 158
# Sample Docs:=========
# unserviceable cabin air conditioner thermostat
# hoist resolver coupling fault
# main pump leaking at face
# engine is vibrating
# thermostat needs replacement unserviceable
# contamination alarm on
# faulty thermostat
# brake pump pressure gauge not working
# faulty level sensor
# cavity of slew pump low
#
# Top words:=========
# pump
# unserviceable
# not
# on
# working
#
# Top failure modes:=========
# unserviceable
# not working
# blown
# on
# fault
#
# Top equipment:=========
# pump
# o-ring
# depth counter
# resolver
# filter
#
# Inherent functions in order:
# sensing (69)
# covering (23)
# presenting (14)
# matterprocessing (12)
# generating (11)
# interfacing (7)
# humaninteraction (6)
# driving (4)
# emitting (3)
# controlling (2)
# restricting (2)
# guiding (2)
# holding (2)
# transforming (1)
# ==================================================
#
# Cluster 4 :
# Cluster Size:========= 153
# Sample Docs:=========
# PTO input seal leaking
# brake fault
# TV monitor does not turn on
# brakes not holding
# mirror is smashed
# TV monitor has no signal
# hoist brake control valve leaking
# front window roller blind broken
# horn unserviceable
# airhorn needs repair not working
#
# Top words:=========
# brake
# not
# hoist
# fault
# temperature
#
# Top failure modes:=========
# fault
# temperature error
# not working
# unserviceable
# broken
#
# Top equipment:=========
# brake
# horn
# brakes
# window
# air horn
#
# Inherent functions in order:
# restricting (55)
# presenting (25)
# humaninteraction (17)
# controlling (12)
# generating (9)
# transforming (8)
# matterprocessing (6)
# interfacing (5)
# guiding (5)
# covering (5)
# sensing (2)
# driving (2)
# emitting (1)
# holding (1)
# ==================================================
#
# Cluster 5 :
# Cluster Size:========= 161
# Sample Docs:=========
# drivers window fault
# repair broken air conditioner compressor earth terminal
# backhoe windscreen has a crack
# auto-greaser door window is broken
# main air brake isolator hard to adjust
# leak from transmission
# leak from bottom of hydraulic tank
# park brake fault pressure switch
# windscreen has a crack
# steering control valve has fallen off
#
# Top words:=========
# window
# valve
# fault
# door
# steering
#
# Top failure modes:=========
# fault
# broken
# leak
# leaking
# falling off
#
# Top equipment:=========
# brake
# park brake
# steering
# isolator
# control valve
#
# Inherent functions in order:
# controlling (113)
# restricting (12)
# covering (7)
# emitting (5)
# guiding (4)
# generating (4)
# driving (4)
# protecting (2)
# storing (2)
# interfacing (2)
# holding (2)
# transforming (2)
# sensing (1)
# presenting (1)
# ==================================================
#
# Cluster 6 :
# Cluster Size:========= 210
# Sample Docs:=========
# minor engine oil leak top rear engine
# engine over heating
# swing faults motor
# engine on grease pump not running
# starter motor solenoid unserviceable
# replace unserviceable control valve
# drag motor noisy sparking
# replace battery with dropped cell
# replace unserviceable cabin air conditioner thermostat
# engine will not fire
#
# Top words:=========
# engine
# air
# conditioner
# unserviceable
# fault
#
# Top failure modes:=========
# unserviceable
# fault
# overheating
# leak
# faulty
#
# Top equipment:=========
# engine
# motor
# propel
# air conditioner
# hoist
#
# Inherent functions in order:
# driving (94)
# emitting (31)
# protecting (28)
# generating (16)
# sensing (13)
# controlling (7)
# restricting (5)
# covering (4)
# presenting (4)
# matterprocessing (2)
# storing (2)
# interfacing (1)
# guiding (1)
# transforming (1)
# holding (1)
# ==================================================
#
# Cluster 7 :
# Cluster Size:========= 406
# Sample Docs:=========
# hydraulic hose will not release
# blown hose on boom
# blown air conditioner hose to radiator
# position tyre down to wire
# blown hose
# position tyre damaged
# leaking tilt cylinder hose
# cracked suction tube
# blown position tyre
# coolant hose leaking at right hand bottom
#
# Top words:=========
# hose
# blown
# leaking
# position
# tyre
#
# Top failure modes:=========
# blown
# leaking
# unserviceable
# damaged
# broken
#
# Top equipment:=========
# hose
# tyre
# brake
# cylinder
# hydraulic hose
#
# Inherent functions in order:
# guiding (326)
# covering (25)
# driving (15)
# matterprocessing (8)
# emitting (5)
# transforming (5)
# protecting (4)
# sensing (4)
# restricting (4)
# generating (3)
# holding (2)
# interfacing (2)
# controlling (1)
# storing (1)
# humaninteraction (1)
# ==================================================
#
# Cluster 8 :
# Cluster Size:========= 263
# Sample Docs:=========
# minor oil leak hub
# transmission electrical fault
# broken weld at mirror
# transmission charge filter housing leak
# worn dogbone shim
# all broken windows
# am fm radio needs an aerial
# stripped wheel studs
# minor oil leak in engine bay
# transmission cannot change gears
#
# Top words:=========
# transmission
# broken
# rear
# fault
# oil
#
# Top failure modes:=========
# broken
# leak
# fault
# missing
# worn
#
# Top equipment:=========
# transmission
# pulley
# oil
# differential
# PTO
#
# Inherent functions in order:
# transforming (95)
# holding (52)
# guiding (28)
# matterprocessing (17)
# interfacing (15)
# covering (11)
# controlling (10)
# sensing (7)
# presenting (5)
# restricting (4)
# driving (4)
# storing (4)
# generating (4)
# humaninteraction (3)
# protecting (3)
# emitting (1)
# ==================================================
#
# Cluster 9 :
# Cluster Size:========= 203
# Sample Docs:=========
# right hand track frame crack
# right hand dump rope due too damage
# broken right hand headlight
# right hand rear inner drive tyre needs
# left hand outer door handle sloppy cabin
# leaking radiator
# right hand tooth missing
# quick hitch oil leak
# right hand headlight out
# right hand boom lamp broken
#
# Top words:=========
# hand
# right
# left
# side
# broken
#
# Top failure modes:=========
# broken
# unserviceable
# leaking
# loose
# missing
#
# Top equipment:=========
# light
# cylinder
# headlight
# door
# rope
#
# Inherent functions in order:
# holding (54)
# emitting (44)
# guiding (30)
# driving (17)
# controlling (11)
# covering (10)
# storing (8)
# protecting (8)
# interfacing (6)
# matterprocessing (4)
# presenting (3)
# humaninteraction (3)
# restricting (2)
# sensing (2)
# generating (1)
# ==================================================
#
# Cluster 10 :
# Cluster Size:========= 277
# Sample Docs:=========
# missing bolts front house wall
# earth strap missing left hand front of cabin
# leak inside hub position
# house fan trip electrical leakage
# bonnet hinge bushes unserviceable
# parts washer pump pressure gauge is not working
# missing ripper tooth pin
# bolts sticking out of concrete
# dent in headboard
# broken shoe pin retainer bolts
#
# Top words:=========
# broken
# pin
# missing
# bolts
# out
#
# Top failure modes:=========
# broken
# missing
# unserviceable
# loose
# damaged
#
# Top equipment:=========
# pin
# bolts
# bolt
# bearing
# cabin
#
# Inherent functions in order:
# holding (225)
# generating (7)
# interfacing (7)
# presenting (6)
# guiding (5)
# storing (4)
# controlling (4)
# transforming (4)
# covering (4)
# protecting (3)
# matterprocessing (3)
# driving (1)
# humaninteraction (1)
# restricting (1)
# sensing (1)
# emitting (1)
# ==================================================
#
# Cluster 11 :
# Cluster Size:========= 347
# Sample Docs:=========
# pressure compensator has weeping
# damage to right hand rear platform
# coolant leak
# damaged position tyre rim
# air tank safety valve needs replacement faulty
# dust flap replacement needed
# hydraulic oil bypassing into transmission
# differential lube pump leaking PO
# faults in air conditioner
# blade skin cracked
#
# Top words:=========
# leak
# grease
# coolant
# system
# pump
#
# Top failure modes:=========
# leak
# unserviceable
# leaking
# fault
# damaged
#
# Top equipment:=========
# coolant
# pump
# cooler
# handrail
# hydraulic oil
#
# Inherent functions in order:
# protecting (202)
# generating (32)
# guiding (31)
# holding (25)
# covering (8)
# driving (8)
# matterprocessing (8)
# emitting (6)
# restricting (6)
# controlling (5)
# transforming (4)
# storing (4)
# sensing (3)
# presenting (3)
# interfacing (2)
# ==================================================
#
# Cluster 12 :
# Cluster Size:========= 195
# Sample Docs:=========
# fuel tank crack
# door alarm faulty
# drag fault
# faulty safety valve
# issue with air conditioner system
# bucket lowering fault
# wiper not working
# fuel tank leak
# dust entering cabin seals
# ladder unserviceable
#
# Top words:=========
# fuel
# cabin
# seat
# ladder
# tank
#
# Top failure modes:=========
# fault
# missing
# cracked
# needs loctite
# unserviceable
#
# Top equipment:=========
# ladder
# fuel tank
# cabin
# cabin seat
# tank
#
# Inherent functions in order:
# storing (48)
# interfacing (25)
# matterprocessing (23)
# restricting (15)
# holding (14)
# covering (14)
# transforming (12)
# emitting (7)
# sensing (6)
# generating (5)
# presenting (5)
# humaninteraction (5)
# driving (5)
# controlling (5)
# protecting (4)
# guiding (2)
# ==================================================
#
# Cluster 13 :
# Cluster Size:========= 264
# Sample Docs:=========
# replace cracked backhoe windscreen
# cracked window
# drivers door hinges worn out
# repair crack in blade liner
# bucket cracked in arch near cancelled
# engine oil spinner hose leaking
# oil leak from engine air compressor
# drivers door seal requires
# cutting edge unserviceable
# faulty seat
#
# Top words:=========
# oil
# leak
# in
# crack
# engine
#
# Top failure modes:=========
# leak
# crack
# cracked
# cracks
# worn
#
# Top equipment:=========
# oil
# engine
# bucket
# door
# window
#
# Inherent functions in order:
# protecting (62)
# matterprocessing (32)
# driving (31)
# storing (30)
# holding (25)
# controlling (20)
# transforming (18)
# interfacing (14)
# guiding (9)
# restricting (8)
# covering (6)
# generating (3)
# humaninteraction (2)
# emitting (2)
# presenting (2)
# ==================================================
#
#
#
# Ave number of documents per cluster: 242.3846153846154
# Median number of documents per cluster: 210
# Min number of documents per cluster: 153
# Max number of documents per cluster: 406
#
# Percentage of clusters with 1 main Inherent function (80% of docs): 0.23076923076923078
# Percentage of clusters with 2 or 3 main Inherent functions (80% of docs): 0.15384615384615385
# Percentage of documents in clusters with 1 main Inherent function (80% of docs): 0.2726118692478578
# Percentage of documents in clusters with 2 or 3 main Inherent functions (80% of docs): 0.1583624246271025

# %%
get_hierarchical_clusters(21, linkage_data_ward)
# Out:
# Cluster 1 :
# Cluster Size:========= 176
# Sample Docs:=========
# compressor needs replacement unserviceable
# battery dropped cell
# compressor not working
# air conditioning fans unserviceable
# drag generator fault
# alternator fault
# alternator unserviceable
# generator is faulty
# replace batteries with no charge
# unserviceable compressor
#
# Top words:=========
# batteries
# not
# charge
# compressor
# no
#
# Top failure modes:=========
# no charge
# unserviceable
# not working
# fault
# failed
#
# Top equipment:=========
# compressor
# batteries
# generator
# pump
# battery
#
# Inherent functions in order:
# generating (143)
# storing (8)
# covering (4)
# driving (4)
# controlling (3)
# holding (3)
# matterprocessing (2)
# sensing (2)
# protecting (2)
# emitting (2)
# restricting (1)
# interfacing (1)
# guiding (1)
# ==================================================
#
# Cluster 2 :
# Cluster Size:========= 116
# Sample Docs:=========
# engine bay light needs replacing
# dash lights are on
# lost lights inside circuit breaker
# VIMS keypad backlight blown
# dash backlight blown
# vims keypad light needs clean out
# rear lights not working
# roof lights not working
# dash lights remain on
# lighting x A-frame light out
#
# Top words:=========
# light
# lights
# out
# on
# unserviceable
#
# Top failure modes:=========
# out
# unserviceable
# not working
# blown
# fault
#
# Top equipment:=========
# lights
# light
# boom
# vims keypad light
# engine air conditioner
#
# Inherent functions in order:
# emitting (110)
# humaninteraction (2)
# covering (2)
# protecting (2)
# ==================================================
#
# Cluster 3 :
# Cluster Size:========= 222
# Sample Docs:=========
# A-frame lights not working
# unserviceable air separator
# unserviceable siren
# air conditioner inoperative
# air conditioner warm
# air conditioner freezing up in cabin
# air conditioner in operator cabin warm
# tray light out
# differential cooling system oil leak
# engine fan hose weeping
#
# Top words:=========
# air
# conditioner
# not
# unserviceable
# working
#
# Top failure modes:=========
# unserviceable
# not working
# out
# fault
# leaking
#
# Top equipment:=========
# air conditioner
# lights
# light
# compressor
# radiator
#
# Inherent functions in order:
# emitting (135)
# generating (23)
# guiding (16)
# driving (10)
# covering (7)
# sensing (7)
# controlling (5)
# restricting (4)
# protecting (4)
# transforming (3)
# matterprocessing (3)
# storing (2)
# holding (2)
# presenting (1)
# ==================================================
#
# Cluster 4 :
# Cluster Size:========= 71
# Sample Docs:=========
# not reading walk motor brake sensor
# low voltage alarms on VIMS
# screen unserviceable
# need cleaning for walk motor brake switches
# contamination switch for swing pump is on
# end of line pressure switch playing up
# controller filter worn out
# swing motor number flashed
# unserviceable depth counter
# speedometer not operational
#
# Top words:=========
# not
# unserviceable
# swing
# on
# motor
#
# Top failure modes:=========
# unserviceable
# not working
# on
# fault
# need cleaning
#
# Top equipment:=========
# resolver
# speedometer
# thermostat
# swing
# filter
#
# Inherent functions in order:
# sensing (39)
# matterprocessing (9)
# humaninteraction (6)
# presenting (5)
# driving (3)
# interfacing (3)
# controlling (2)
# covering (1)
# restricting (1)
# emitting (1)
# generating (1)
# ==================================================
#
# Cluster 5 :
# Cluster Size:========= 87
# Sample Docs:=========
# pressure gauge for brake pump not working
# brake pump pressure gauge is not working
# empty cam lube drum
# camera not working
# swing pump found broken
# transfer pump pressure sensor unserviceable
# blown o-ring in boom hose
# pump contamination switch is unserviceable
# not working weightometer
# unserviceable cabin mounts
#
# Top words:=========
# pump
# o-ring
# unserviceable
# blown
# on
#
# Top failure modes:=========
# unserviceable
# blown
# not working
# on
# broken
#
# Top equipment:=========
# pump
# o-ring
# steering
# depth counter
# pump contamination switch
#
# Inherent functions in order:
# sensing (30)
# covering (22)
# generating (10)
# presenting (9)
# interfacing (4)
# matterprocessing (3)
# emitting (2)
# guiding (2)
# holding (2)
# driving (1)
# restricting (1)
# transforming (1)
# ==================================================
#
# Cluster 6 :
# Cluster Size:========= 67
# Sample Docs:=========
# torque convertor charge hose leak
# air horn not working
# Tele-Remote camera fault
# inside horn not working
# unserviceable differential drain plugs
# switch not working
# unserviceable control valve
# airhorn found not working
# air horn too loud
# number hoist generator flashed over
#
# Top words:=========
# horn
# not
# working
# air
# unserviceable
#
# Top failure modes:=========
# not working
# unserviceable
# fault
# leak
# failed
#
# Top equipment:=========
# horn
# air horn
# torque converter
# airhorn
# pump
#
# Inherent functions in order:
# presenting (24)
# generating (9)
# transforming (7)
# humaninteraction (6)
# guiding (5)
# covering (4)
# matterprocessing (3)
# controlling (2)
# restricting (2)
# driving (2)
# interfacing (1)
# sensing (1)
# emitting (1)
# ==================================================
#
# Cluster 7 :
# Cluster Size:========= 86
# Sample Docs:=========
# brake fault see text
# brake fault
# replace brake pump pressure gauge not working
# door switches unserviceable
# brake number not releasing
# front window cracked
# hoist brakes faulty
# hoist brake not releasing
# broken window
# front window roller blind broken
#
# Top words:=========
# brake
# hoist
# temperature
# error
# brakes
#
# Top failure modes:=========
# temperature error
# fault
# broken
# damaged
# not holding
#
# Top equipment:=========
# brake
# brakes
# window
# hoist
# hoist brake
#
# Inherent functions in order:
# restricting (53)
# humaninteraction (11)
# controlling (10)
# interfacing (4)
# matterprocessing (3)
# presenting (1)
# covering (1)
# transforming (1)
# sensing (1)
# holding (1)
# ==================================================
#
# Cluster 8 :
# Cluster Size:========= 161
# Sample Docs:=========
# sub circuit breaker will not close
# steering oil leak
# steering oil leakage
# engine door broken PO
# door latch unserviceable
# park brake relay valve leaking
# damaged door wiper motor
# cabin window needs
# steering control valve leaking
# control valve is unserviceable
#
# Top words:=========
# window
# valve
# fault
# door
# steering
#
# Top failure modes:=========
# fault
# broken
# leak
# leaking
# falling off
#
# Top equipment:=========
# brake
# park brake
# steering
# isolator
# control valve
#
# Inherent functions in order:
# controlling (113)
# restricting (12)
# covering (7)
# emitting (5)
# guiding (4)
# generating (4)
# driving (4)
# protecting (2)
# storing (2)
# interfacing (2)
# holding (2)
# transforming (2)
# sensing (1)
# presenting (1)
# ==================================================
#
# Cluster 9 :
# Cluster Size:========= 71
# Sample Docs:=========
# operator cabin air conditioner cover cracking
# operator cabin air conditioner fuse fault
# repair faults in cooler pump lube system
# operator cabin air conditioner warm
# number input shaft seal leaking
# number air conditioner compressor leaking PO
# number air compressor leaking from oil cooler
# dragline air conditioner fuse blowing repeatedly
# repair auto-spray not working
# drag motor flash over
#
# Top words:=========
# air
# conditioner
# cabin
# fuse
# operator
#
# Top failure modes:=========
# fault
# unserviceable
# faulty
# keeps blowing
# keep blowing
#
# Top equipment:=========
# motor
# air conditioner
# drag
# operator cabin air conditioner fuse
# propel
#
# Inherent functions in order:
# protecting (22)
# generating (12)
# emitting (12)
# driving (9)
# sensing (5)
# restricting (4)
# covering (3)
# matterprocessing (1)
# storing (1)
# controlling (1)
# presenting (1)
# ==================================================
#
# Cluster 10 :
# Cluster Size:========= 139
# Sample Docs:=========
# replace engine bay light
# propel fault needs fixing
# engine overheating
# repair engine vibration
# high voltage room air conditioner needs
# replace unserviceable engine air conditioner
# fix the fault in propel
# replace unserviceable depth counter
# propel fault
# reported engine stopped
#
# Top words:=========
# engine
# unserviceable
# fault
# motor
# replace
#
# Top failure modes:=========
# unserviceable
# fault
# overheating
# leak
# vibration
#
# Top equipment:=========
# engine
# motor
# hoist
# oil
# propel
#
# Inherent functions in order:
# driving (85)
# emitting (19)
# sensing (8)
# controlling (6)
# protecting (6)
# generating (4)
# presenting (3)
# matterprocessing (1)
# storing (1)
# covering (1)
# restricting (1)
# interfacing (1)
# guiding (1)
# transforming (1)
# holding (1)
# ==================================================
#
# Cluster 11 :
# Cluster Size:========= 406
# Sample Docs:=========
# leaking centrifugal filter
# leaking steering hose
# axle temperature fault
# blown extension line from position
# worn tyres position with new
# blown brake hose
# flat position tyre
# leaking hydraulic hose
# position brake line leak
# worn position tyres
#
# Top words:=========
# hose
# blown
# leaking
# position
# tyre
#
# Top failure modes:=========
# blown
# leaking
# unserviceable
# damaged
# broken
#
# Top equipment:=========
# hose
# tyre
# brake
# cylinder
# hydraulic hose
#
# Inherent functions in order:
# guiding (326)
# covering (25)
# driving (15)
# matterprocessing (8)
# emitting (5)
# transforming (5)
# protecting (4)
# sensing (4)
# restricting (4)
# generating (3)
# holding (2)
# interfacing (2)
# controlling (1)
# storing (1)
# humaninteraction (1)
# ==================================================
#
# Cluster 12 :
# Cluster Size:========= 115
# Sample Docs:=========
# missing bucket bolts
# transmission oil leak text
# noisy pulley bearings condition monitoring to
# failed o-ring
# pulley number knocking noise
# drag chain fault
# missing bucket tooth
# seized pre-cleaner motor
# broken drag chain dragline
# differential pressure error
#
# Top words:=========
# pulley
# missing
# worn
# number
# broken
#
# Top failure modes:=========
# missing
# worn
# broken
# leak
# fault
#
# Top equipment:=========
# pulley
# oil
# hoist
# transmission
# swing
#
# Inherent functions in order:
# holding (37)
# transforming (24)
# interfacing (13)
# guiding (11)
# matterprocessing (10)
# presenting (5)
# covering (3)
# protecting (3)
# restricting (2)
# driving (2)
# controlling (2)
# generating (2)
# humaninteraction (1)
# ==================================================
#
# Cluster 13 :
# Cluster Size:========= 148
# Sample Docs:=========
# slow PTO operation
# position tooth missing
# main water pump unserviceable
# transmission level
# driveline vibration
# transmission filling with hydraulic oil
# reverse camera mounts unserviceable
# earth wire broken on bottom of radiator
# transmission electrical fault
# broken tooth
#
# Top words:=========
# transmission
# rear
# fault
# differential
# broken
#
# Top failure modes:=========
# fault
# broken
# leak
# unserviceable
# needs aerial
#
# Top equipment:=========
# transmission
# differential
# oil
# PTO
# am / fm radio
#
# Inherent functions in order:
# transforming (71)
# guiding (17)
# holding (15)
# covering (8)
# controlling (8)
# sensing (7)
# matterprocessing (7)
# storing (4)
# interfacing (2)
# humaninteraction (2)
# restricting (2)
# driving (2)
# generating (2)
# emitting (1)
# ==================================================
#
# Cluster 14 :
# Cluster Size:========= 203
# Sample Docs:=========
# right hand rev left hand position light unserviceable
# left hand chain guide unserviceable
# left hand air box mount bolts missing
# right rear indicator light blown
# left hand bearing unserviceable
# right hand bobbin roller unserviceable
# right hand damaged dump rope
# right hand side traction motor seal leaking
# right hand mudflap missing
# left hand boom cylinder hose leaking PO
#
# Top words:=========
# hand
# right
# left
# side
# broken
#
# Top failure modes:=========
# broken
# unserviceable
# leaking
# loose
# missing
#
# Top equipment:=========
# light
# cylinder
# headlight
# door
# rope
#
# Inherent functions in order:
# holding (54)
# emitting (44)
# guiding (30)
# driving (17)
# controlling (11)
# covering (10)
# storing (8)
# protecting (8)
# interfacing (6)
# matterprocessing (4)
# presenting (3)
# humaninteraction (3)
# restricting (2)
# sensing (2)
# generating (1)
# ==================================================
#
# Cluster 15 :
# Cluster Size:========= 277
# Sample Docs:=========
# steering steering wheel bearings
# broken cylinder head bolt front head
# rope clamp missing off hoist rope
# broken shoe pin retainer bolts
# broken bolts in right hand engine mount
# steering shaft mount under cabin unserviceable
# pin come out bucket GET
# bearing which is knocking
# swing blower motor fan has bolts missing
# missing muffler mount bolt
#
# Top words:=========
# broken
# pin
# missing
# bolts
# out
#
# Top failure modes:=========
# broken
# missing
# unserviceable
# loose
# damaged
#
# Top equipment:=========
# pin
# bolts
# bolt
# bearing
# cabin
#
# Inherent functions in order:
# holding (225)
# generating (7)
# interfacing (7)
# presenting (6)
# guiding (5)
# storing (4)
# controlling (4)
# transforming (4)
# covering (4)
# protecting (3)
# matterprocessing (3)
# driving (1)
# humaninteraction (1)
# restricting (1)
# sensing (1)
# emitting (1)
# ==================================================
#
# Cluster 16 :
# Cluster Size:========= 139
# Sample Docs:=========
# handrail needs crack repair
# grease leaks on bucket
# damper guard cover missing
# needs guard around windscreen wiper mechanical
# dust flap needs to be replaced
# seat pre-start unserviceable
# padding has worn areas
# dust flap replacement needed
# fuse keeps blowing
# blowing fuse needs replacement
#
# Top words:=========
# grease
# system
# handrail
# fuse
# has
#
# Top failure modes:=========
# crack
# found
# fault
# broken
# missing
#
# Top equipment:=========
# handrail
# grease system
# guard
# grease
# fuse
#
# Inherent functions in order:
# protecting (123)
# covering (3)
# holding (3)
# matterprocessing (3)
# generating (2)
# storing (2)
# sensing (1)
# controlling (1)
# presenting (1)
# ==================================================
#
# Cluster 17 :
# Cluster Size:========= 208
# Sample Docs:=========
# coolant leak
# coolant leak at heater
# compressor oil pressure switch unserviceable
# chord pressure fault
# coolant leak at jacket water pump
# coolant leak from heater
# cooler pump lube system is faulty
# damaged position rim
# auto-lube fault
# engine prelube error
#
# Top words:=========
# leak
# coolant
# position
# pump
# air
#
# Top failure modes:=========
# leak
# unserviceable
# leaking
# damaged
# fault
#
# Top equipment:=========
# coolant
# pump
# cooler
# hydraulic oil
# engine
#
# Inherent functions in order:
# protecting (79)
# guiding (31)
# generating (30)
# holding (22)
# driving (8)
# emitting (6)
# restricting (6)
# covering (5)
# matterprocessing (5)
# transforming (4)
# controlling (4)
# storing (2)
# sensing (2)
# interfacing (2)
# presenting (2)
# ==================================================
#
# Cluster 18 :
# Cluster Size:========= 49
# Sample Docs:=========
# swing need to pinion
# ladder fault
# brake accumulator pressure
# drive vibration
# swing fault
# inverter is earthing out
# ladder getting stuck going down
# brakes dragging
# repair slipping fault in transmission
# ladder not operating
#
# Top words:=========
# ladder
# brake
# fault
# drag
# hoist
#
# Top failure modes:=========
# fault
# out of adjustment
# dragging
# faulty
# unserviceable
#
# Top equipment:=========
# ladder
# brake
# drag
# hoist drag brake
# accumulator
#
# Inherent functions in order:
# interfacing (18)
# restricting (11)
# transforming (6)
# matterprocessing (4)
# storing (3)
# driving (1)
# humaninteraction (1)
# covering (1)
# generating (1)
# emitting (1)
# presenting (1)
# holding (1)
# ==================================================
#
# Cluster 19 :
# Cluster Size:========= 146
# Sample Docs:=========
# cabin seat needs replacing
# issue with air conditioner system
# broken fuel cooler
# drag blower inverter is earthing out
# fuel filter water separator housing broken
# fuel breather filter missing
# grease alarm on right hand propel
# cabin gets very dusty during shift
# apply loctite to cabin seat
# fuel tank crack
#
# Top words:=========
# fuel
# cabin
# seat
# tank
# cracked
#
# Top failure modes:=========
# missing
# cracked
# needs loctite
# leak
# leaking
#
# Top equipment:=========
# fuel tank
# cabin
# cabin seat
# tank
# bucket
#
# Inherent functions in order:
# storing (45)
# matterprocessing (19)
# holding (13)
# covering (13)
# interfacing (7)
# emitting (6)
# transforming (6)
# sensing (6)
# controlling (5)
# restricting (4)
# generating (4)
# presenting (4)
# humaninteraction (4)
# driving (4)
# protecting (4)
# guiding (2)
# ==================================================
#
# Cluster 20 :
# Cluster Size:========= 121
# Sample Docs:=========
# damaged front harness
# door will not open
# steering column movement
# repair crack in rock deflector
# repair crack in liner
# crack found in windscreen
# oil leaks
# cracked guards
# front upper window cracked
# rear wiper motor unserviceable
#
# Top words:=========
# in
# crack
# cracks
# cracked
# repair
#
# Top failure modes:=========
# crack
# cracks
# cracked
# leaks
# damaged
#
# Top equipment:=========
# door
# bucket
# tank
# fuel tank
# oil
#
# Inherent functions in order:
# protecting (37)
# storing (20)
# holding (19)
# controlling (15)
# interfacing (6)
# transforming (5)
# restricting (4)
# guiding (4)
# driving (4)
# covering (3)
# humaninteraction (2)
# presenting (1)
# emitting (1)
# ==================================================
#
# Cluster 21 :
# Cluster Size:========= 143
# Sample Docs:=========
# cutting edge unserviceable
# oil leak from power steering
# seat loose
# engine oil leak
# oil leak hydraulic
# oil leak on PTO
# oil leak around torque converter rear engine
# oil leak rear of engine
# cutting edges loose
# oil leak behind
#
# Top words:=========
# oil
# leak
# engine
# cracked
# cutting
#
# Top failure modes:=========
# leak
# worn
# cracked
# leaking
# unserviceable
#
# Top equipment:=========
# oil
# engine
# bucket
# cutting edges
# seat
#
# Inherent functions in order:
# matterprocessing (32)
# driving (27)
# protecting (25)
# transforming (13)
# storing (10)
# interfacing (8)
# holding (6)
# guiding (5)
# controlling (5)
# restricting (4)
# covering (3)
# generating (3)
# emitting (1)
# presenting (1)
# ==================================================
#
#
#
# Ave number of documents per cluster: 150.04761904761904
# Median number of documents per cluster: 139
# Min number of documents per cluster: 49
# Max number of documents per cluster: 406
#
# Percentage of clusters with 1 main Inherent function (80% of docs): 0.23809523809523808
# Percentage of clusters with 2 or 3 main Inherent functions (80% of docs): 0.14285714285714285
# Percentage of documents in clusters with 1 main Inherent function (80% of docs): 0.3535385591875595
# Percentage of documents in clusters with 2 or 3 main Inherent functions (80% of docs): 0.12250079339892098
