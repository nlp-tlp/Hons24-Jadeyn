# %% [markdown]
# ### imports

# %%
# !pip install tensorflow
# !pip install gensim
# !pip install tf-keras
# Out:
# Requirement already satisfied: tensorflow in /opt/miniconda3/lib/python3.12/site-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (4.25.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (1.65.5)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/miniconda3/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.41.2)
# Requirement already satisfied: rich in /opt/miniconda3/lib/python3.12/site-packages (from keras>=3.2.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /opt/miniconda3/lib/python3.12/site-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /opt/miniconda3/lib/python3.12/site-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/miniconda3/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/miniconda3/lib/python3.12/site-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/miniconda3/lib/python3.12/site-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/miniconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Requirement already satisfied: gensim in /opt/miniconda3/lib/python3.12/site-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /opt/miniconda3/lib/python3.12/site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /opt/miniconda3/lib/python3.12/site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/miniconda3/lib/python3.12/site-packages (from gensim) (7.0.4)
# Requirement already satisfied: wrapt in /opt/miniconda3/lib/python3.12/site-packages (from smart-open>=1.8.1->gensim) (1.16.0)
# Collecting tf-keras
#   Downloading tf_keras-2.17.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: tensorflow<2.18,>=2.17 in /opt/miniconda3/lib/python3.12/site-packages (from tf-keras) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (3.3.0)
# Requirement already satisfied: packaging in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (4.25.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (2.31.0)
# Requirement already satisfied: setuptools in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.65.5)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (3.5.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/miniconda3/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow<2.18,>=2.17->tf-keras) (0.41.2)
# Requirement already satisfied: rich in /opt/miniconda3/lib/python3.12/site-packages (from keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (13.7.1)
# Requirement already satisfied: namex in /opt/miniconda3/lib/python3.12/site-packages (from keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (0.0.8)
# Requirement already satisfied: optree in /opt/miniconda3/lib/python3.12/site-packages (from keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.18,>=2.17->tf-keras) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.18,>=2.17->tf-keras) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.18,>=2.17->tf-keras) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.18,>=2.17->tf-keras) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard<2.18,>=2.17->tensorflow<2.18,>=2.17->tf-keras) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard<2.18,>=2.17->tensorflow<2.18,>=2.17->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard<2.18,>=2.17->tensorflow<2.18,>=2.17->tf-keras) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/miniconda3/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow<2.18,>=2.17->tf-keras) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/miniconda3/lib/python3.12/site-packages (from rich->keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/miniconda3/lib/python3.12/site-packages (from rich->keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/miniconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (0.1.2)
# Downloading tf_keras-2.17.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 27.7 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: tf-keras
# Successfully installed tf-keras-2.17.0

# %%
import tensorflow as tf

from gensim.models import Word2Vec
from gensim.models import LsiModel
import gensim

import numpy as np
import matplotlib.pyplot as plt

from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

from sentence_transformers import SentenceTransformer

# %% [markdown]
# ### prepare dataset

# %%
import json
import contractions

def pad_sequence(dataset):
    max_len = len(max(dataset, key=len))
    print("max length of MWO:", max_len)
    for i in range(len(dataset)):
        count = 0
        while len(dataset[i]) < max_len:
            dataset[i].append(dataset[i][count])
            count+=1
    return dataset

def add_inherent_functions(row):
    for e in row["entities"]:
        tokens = row["tokens"]
        entity_type = e["type"].split("/")
        if entity_type[0] == "PhysicalObject":
            if len(entity_type) > 1 and entity_type[1] not in ["Substance", "Organism"]:
                if entity_type[1][:-6].lower() not in tokens:
                    tokens.append(entity_type[1][:-6].lower())
                # tokens.append(entity_type[1][-6:].lower())
    return tokens

    # BROKEN CODE
    # physical_object_indices = []
    # 
    # for e in row["entities"]:
    #     new_list = row["tokens"]
    #     entity_type = e["type"].split("/")
    #     if entity_type[0] == "PhysicalObject":
    #         if len(entity_type) > 1 and entity_type[1] not in ["Substance", "Organism"]:
    #             new_string = " ".join(new_list)
    #             if e["end"] == len(row["tokens"]):
    #                 replace_index = new_string.find(" ".join(row["tokens"][e["start"]:]))
    #                 new_string = new_string.replace(" ".join(row["tokens"][e["start"]:]))
    #             else:
    #                 replace_index = new_string.find(" ".join(row["tokens"][e["start"]:e["end"]]))
    #                 new_string = new_string.replace(" ".join(row["tokens"][e["start"]:e["end"]]), "")
    #             new_string = new_string[replace_index:]
    #             new_list = new_string.split()
    #             physical_object_indices.append((e["start"], e["end"], entity_type[1]))
    # for i in physical_object_indices:
    #     if i[1] == len(row["tokens"]):
    #         row["tokens"].append(i[2])
        

def clean_tokens(tokens):
    stopwords =["<num>", "<id>", "-"]
    tokens = [i for i in tokens if i not in stopwords]
    tokens = contractions.fix(" ".join(tokens)).split()
    return tokens

def prepare_dataset(filename):
    f = open(filename, "r")
    # returns JSON object as a dictionary
    data = json.load(f)

    dataset = []

    for datum in data:
        keep_indices = []
        for entity in datum["entities"]:
            if entity["type"].split("/")[0] not in ["PhysicalObject", "Activity"]:
                start = entity["start"]
                end = entity["end"]
                for i in range(start, end):
                    keep_indices.append(i)

        tokens = []
        for i in sorted(set(keep_indices)):
            tokens.append(datum["tokens"][i])
        
        tokens = clean_tokens(tokens)
        if tokens:
            dataset.append(" ".join(tokens))
    # dataset = pad_sequence(dataset)
    return dataset

def full_dataset(filename):
    f = open(filename, "r")
    # returns JSON object as a dictionary
    data = json.load(f)

    d = []

    for datum in data:
        types = [e["type"].split("/")[0] for e in datum["entities"]]
        if ("State" in types or "Process" in types or "Property" in types) and "PhysicalObject" in types:
            tokens = clean_tokens(datum["tokens"])
            # d.append(" ".join(tokens))
            d.append(tokens)
    # d = pad_sequence(dataset)
    return d

def full_dataset_append_inherent_functions(filename):
    f = open(filename, "r")
    # returns JSON object as a dictionary
    data = json.load(f)

    d = []

    for datum in data:
        types = [e["type"].split("/")[0] for e in datum["entities"]]
        if ("State" in types or "Process" in types or "Property" in types) and "PhysicalObject" in types:
            tokens = add_inherent_functions(datum)
            tokens = clean_tokens(tokens)
            # d.append(" ".join(tokens))
            d.append(tokens)
    return d

# %% [markdown]
# # OG dataset

# %% [markdown]
# ## CNN

# %%
dataset = full_dataset("../data/gold_release.json")
print(dataset)
pad_sequence(dataset)
print(len(dataset))
# Out:
# [['air', 'conditioner', 'thermostat', 'not', 'working'], ['air', 'conditioner', 'thermostat', 'unserviceable'], ['air', 'conditioner', 'unserviceable'], ['air', 'conditioner', 'unserviceable', 'when', 'stationary'], ['air', 'conditioner', 'warm'], ['air', 'filters', 'plugged'], ['air', 'horn', 'disconnected'], ['air', 'horn', 'does', 'not', 'work'], ['air', 'horn', 'fault'], ['air', 'horn', 'not', 'working'], ['air', 'horn', 'not', 'working', 'compressor', 'awaiting'], ['air', 'horn', 'stuck', 'on'], ['air', 'horn', 'unserviceable'], ['air', 'horn', 'working', 'intermittently'], ['air', 'leak'], ['air', 'leak', 'near', 'side', 'of', 'door'], ['air', 'leaking', 'from', 'line', 'outside'], ['airhorn', 'not', 'working'], ['alarm', 'on', 'VIMS', 'does', 'not', 'work'], ['all', 'dash', 'lights', 'on'], ['alternator', 'drive', 'leaking'], ['alternator', 'failed'], ['alternator', 'not', 'charging'], ['alternator', 'overcharge', 'fault'], ['alternator', 'overcharged'], ['analyse', 'failed', 'driveline', 'component'], ['and', 'lube', 'system', 'faults'], ['armrest', 'unserviceable'], ['auto-greaser', 'leaking', 'oil'], ['auto-greaser', 'unserviceable'], ['auto-lube', 'error', 'PO'], ['auto-spray', 'feature', 'not', 'working'], ['axle', 'temperature', 'fault'], ['axle', 'temperature', 'sensor', 'fault'], ['back', 'rest', 'unserviceable', 'handle', 'broken'], ['backhoe', 'windscreen', 'to', 'be', 'fixed'], ['backlight', 'on', 'dash', 'unserviceable'], ['backlights', 'on', 'dash', 'blown'], ['backup', 'alarm', 'not', 'working'], ['batteries', 'discharging'], ['batteries', 'out', 'of', 'service'], ['batteries', 'unserviceable'], ['battery', 'cover', 'hinges', 'seized'], ['beacon', 'mount', 'is', 'broken'], ['beacon', 'not', 'working'], ['beacon', 'unserviceable'], ['bearing', 'on', 'air', 'conditioner', 'compressor', 'unserviceable'], ['bearings', 'are', 'shot'], ['belly', 'plate', 'bolt', 'missing'], ['bent', 'belly', 'plate'], ['blade', 'light', 'blown', 'needs', 'replacing'], ['blade', 'skin', 'cracked'], ['blade', 'wear', 'plates', 'cracked', 'and', 'worn'], ['blown', 'air', 'conditioner', 'hose'], ['blown', 'air', 'conditioner', 'hose', 'to', 'radiator'], ['blown', 'brake', 'hose'], ['blown', 'crowd', 'cylinder', 'hose'], ['blown', 'extension', 'line', 'from', 'position'], ['blown', 'hose', 'in', 'hitch'], ['blown', 'hose', 'on', 'boom'], ['blown', 'lift', 'cylinder', 'o-ring'], ['blown', 'light', 'on', 'boom'], ['blown', 'o-ring', 'off', 'steering', 'hose'], ['blown', 'o-ring', 'on', 'left', 'hand', 'lift', 'cylinder'], ['blown', 'o-ring', 'on', 'steering', 'hose'], ['blown', 'oil', 'cooler', 'hose', 'x', 'metre'], ['blown', 'position', 'tyre'], ['blown', 'right', 'hand', 'bucket', 'cylinder', 'hose'], ['blown', 'steering', 'hose'], ['blown', 'steering', 'pump', 'hose'], ['boarding', 'gate', 'hinge', 'broken'], ['boarding', 'gate', 'latch', 'not', 'working'], ['boarding', 'ladder', 'not', 'working'], ['both', 'stick', 'cylinders', 'leaking'], ['brake', 'cooling', 'hose', 'leaking'], ['brake', 'cooling', 'hose', 'leaking', 'rear'], ['brake', 'cooling', 'return', 'hose', 'leaking'], ['brake', 'release', 'fault'], ['brake', 'temperature', 'error'], ['broken', 'air', 'conditioner', 'guard'], ['broken', 'clamp', 'on', 'crowd', 'cylinder', 'hose', 'TBC'], ['broken', 'fuel', 'cooler', 'mounts'], ['broken', 'grease', 'plug'], ['broken', 'hinge'], ['broken', 'joystick', 'PO'], ['broken', 'left', 'hand', 'side', 'mirror'], ['broken', 'mirror'], ['broken', 'right', 'hand', 'side', 'door', 'window'], ['broken', 'ripper', 'tooth'], ['broken', 'weld', 'on', 'handrail'], ['bucket', 'cracked', 'in', 'arch', 'near', 'cancelled'], ['cabin', 'door', 'window', 'cracked'], ['cabin', 'needs', 'resealing'], ['cabin', 'seals', 'leaking', 'dust', 'PO'], ['cabin', 'seals', 'leaking', 'dust', 'bad'], ['cabin', 'seat', 'needs', 'replacing'], ['cabin', 'window', 'needs', 'resealing'], ['camera', 'fault'], ['carousel', 'popped', 'bolt', 'needs', 'Loctite'], ['cen ...
# max length of MWO: 11
# 540

# %%
# SBERT embeddings
model = SentenceTransformer("all-MiniLM-L6-v2")
SBERT_embeddings = model.encode(dataset)
print(SBERT_embeddings.shape)
# Out:
# /opt/miniconda3/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# (540, 384)

# %%
# Word2Vec embeddings as input
w2vmodel = gensim.models.Word2Vec(dataset, min_count=1, vector_size=100,
                                window=5, sg=1)
w2v_embeddings = []
for sentence in dataset:
    row = []
    for word in sentence:
        row.append(w2vmodel.wv[word])
    w2v_embeddings.append(row)
w2v_embeddings = np.array(w2v_embeddings)

# %%
print(w2v_embeddings.shape)
shape = w2v_embeddings.shape
w2v_embeddings=w2v_embeddings.reshape(shape[0], shape[1], shape[2], 1)
print(w2v_embeddings.shape)
# Out:
# (540, 11, 100)
# (540, 11, 100, 1)

# %%
# LSI embeddings as output
dictionary = gensim.corpora.Dictionary(dataset)
doc_term_matrix = [dictionary.doc2bow(doc) for doc in dataset]
lsamodel = LsiModel(doc_term_matrix, num_topics=10, id2word = dictionary)  # train model
concepts = list(lsamodel[doc_term_matrix])
lsa_embeddings=[]
for i in concepts:
    row = []
    for j in i:
        row.append(j[1])
    lsa_embeddings.append(row)
lsa_embeddings = np.array(lsa_embeddings)

# %%
print(lsa_embeddings.shape)
print(lsa_embeddings)
# Out:
# (540, 10)
# [[-3.12078267 -2.08378619 -1.10216356 ...  0.46472956  0.55573425
#    1.02679058]
#  [-3.51358921 -2.00545559 -1.28014438 ... -0.69335445  0.04730249
#   -0.88969778]
#  [-4.66021229 -2.60432785 -1.70228548 ... -1.08454974  0.04890309
#   -1.36408451]
#  ...
#  [-0.61761684 -0.16548807 -0.39730111 ... -1.11531307  0.37381321
#   -0.77036742]
#  [-0.34267541  0.22844125  0.59734302 ...  0.09225076  1.65304702
#   -0.03309421]
#  [-0.62284981  0.00490436 -0.36731306 ... -1.71090679 -0.00474171
#   -1.92274028]]

# %%
model1 = tf.keras.Sequential([
    tf.keras.layers.Conv2D(16, (2, 2), activation='relu', padding="same", input_shape=(11,100,1)),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.Conv2D(8, (2, 2), activation='relu', padding="same"),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=384, activation="tanh"),
    tf.keras.layers.Dense(units=384, activation="tanh")
])

# %%
model1.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 11, 100, 16)       80
#
#  max_pooling2d_2 (MaxPoolin  (None, 5, 50, 16)         0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 5, 50, 8)          520
#
#  flatten_2 (Flatten)         (None, 2000)              0
#
#  dense_4 (Dense)             (None, 384)               768384
#
#  dense_5 (Dense)             (None, 384)               147840
#
# =================================================================
# Total params: 916824 (3.50 MB)
# Trainable params: 916824 (3.50 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)

opt = tf.keras.optimizers.Adam(learning_rate=0.001)

model1.compile(optimizer=opt,
              loss=tf.keras.losses.MeanSquaredLogarithmicError("sum_over_batch_size"),
              metrics=['accuracy'])

history = model1.fit(w2v_embeddings, SBERT_embeddings, epochs=200)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy TF-Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy TF-Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/200
# 17/17 [==============================] - 0s 8ms/step - loss: 8.9968e-04 - accuracy: 0.1037
# Epoch 2/200
# 17/17 [==============================] - 0s 8ms/step - loss: 7.9523e-04 - accuracy: 0.0556
# Epoch 3/200
# 17/17 [==============================] - 0s 7ms/step - loss: 7.7413e-04 - accuracy: 0.1852
# Epoch 4/200
# 17/17 [==============================] - 0s 9ms/step - loss: 7.6524e-04 - accuracy: 0.0778
# Epoch 5/200
# 17/17 [==============================] - 0s 8ms/step - loss: 7.5985e-04 - accuracy: 0.1611
# Epoch 6/200
# 17/17 [==============================] - 0s 7ms/step - loss: 7.5670e-04 - accuracy: 0.1130
# Epoch 7/200
# 17/17 [==============================] - 0s 8ms/step - loss: 7.5129e-04 - accuracy: 0.1685
# Epoch 8/200
# 17/17 [==============================] - 0s 8ms/step - loss: 7.4451e-04 - accuracy: 0.1574
# Epoch 9/200
# 17/17 [==============================] - 0s 7ms/step - loss: 7.3227e-04 - accuracy: 0.1667
# Epoch 10/200
# 17/17 [==============================] - 0s 7ms/step - loss: 7.2480e-04 - accuracy: 0.0981
# Epoch 11/200
# 17/17 [==============================] - 0s 7ms/step - loss: 7.1599e-04 - accuracy: 0.1833
# Epoch 12/200
# 17/17 [==============================] - 0s 8ms/step - loss: 7.1128e-04 - accuracy: 0.0981
# Epoch 13/200
# 17/17 [==============================] - 0s 8ms/step - loss: 7.0430e-04 - accuracy: 0.1685
# Epoch 14/200
# 17/17 [==============================] - 0s 9ms/step - loss: 6.8912e-04 - accuracy: 0.1185
# Epoch 15/200
# 17/17 [==============================] - 0s 16ms/step - loss: 6.7179e-04 - accuracy: 0.1870
# Epoch 16/200
# 17/17 [==============================] - 0s 10ms/step - loss: 6.6590e-04 - accuracy: 0.1093
# Epoch 17/200
# 17/17 [==============================] - 0s 8ms/step - loss: 6.4551e-04 - accuracy: 0.1556
# Epoch 18/200
# 17/17 [==============================] - 0s 7ms/step - loss: 6.3181e-04 - accuracy: 0.1500
# Epoch 19/200
# 17/17 [==============================] - 0s 7ms/step - loss: 6.1066e-04 - accuracy: 0.1500
# Epoch 20/200
# 17/17 [==============================] - 0s 7ms/step - loss: 6.0048e-04 - accuracy: 0.1463
# Epoch 21/200
# 17/17 [==============================] - 0s 7ms/step - loss: 5.9113e-04 - accuracy: 0.1704
# Epoch 22/200
# 17/17 [==============================] - 0s 8ms/step - loss: 5.8154e-04 - accuracy: 0.1500
# Epoch 23/200
# 17/17 [==============================] - 0s 6ms/step - loss: 5.6950e-04 - accuracy: 0.1593
# Epoch 24/200
# 17/17 [==============================] - 0s 7ms/step - loss: 5.6188e-04 - accuracy: 0.1519
# Epoch 25/200
# 17/17 [==============================] - 0s 6ms/step - loss: 5
# %%
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.metrics import silhouette_score


# PCA reduction
pca = PCA(n_components=2)
pca_embedding = pca.fit_transform(cluster_embeddings)
plt.scatter(pca_embedding[:,0], pca_embedding[:,1])
plt.title("PCA")
plt.show()

# tsne reduction
tsne = TSNE(n_components=2).fit_transform(cluster_embeddings)
plt.scatter(tsne[:,0], tsne[:,1])
plt.title("TSNE")
plt.show()


# # Perform kmean clustering
# silhouette_scores = []
# test_k = list(range(5, 105, 5))
# for i in test_k:
#     print(i, "/", 100)
#     kmeans = KMeans(n_clusters=i, random_state=42, n_init=100).fit(cluster_embeddings)
#     labels = kmeans.labels_
#     silhouette_scores.append(silhouette_score(cluster_embeddings, labels))
# plt.plot(test_k, silhouette_scores)
# plt.title("Silhouette Scores")
# plt.show()

# %%
dataset_not_padded = full_dataset("../data/gold_release.json")
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=8, random_state=42, n_init=100).fit(pca_embedding)
labels = kmeans.labels_
for i in range(15):
    print("Cluster ", i)
    for j in range(len(labels)):
        if labels[j] == i:
            print(dataset_not_padded[j])
# Out:
# Cluster  0
# ['alternator', 'drive', 'leaking']
# ['alternator', 'failed']
# ['alternator', 'overcharge', 'fault']
# ['alternator', 'overcharged']
# ['analyse', 'failed', 'driveline', 'component']
# ['auto-lube', 'error', 'PO']
# ['axle', 'temperature', 'fault']
# ['axle', 'temperature', 'sensor', 'fault']
# ['brake', 'temperature', 'error']
# ['cabin', 'needs', 'resealing']
# ['camera', 'fault']
# ['centrifugal', 'oil', 'filter', 'fault']
# ['centrifugal', 'oil', 'filter', 'leaking']
# ['contactor', 'fault']
# ['cords', 'cracked', 'at', 'and']
# ['cracked', 'suction', 'tube']
# ['crankcase', 'error']
# ['diagnose', '/', 'repair', 'slow', 'steering']
# ['diagnose', 'and', 'repair', 'spray', 'faults']
# ['diagnose', 'and', 'repair', 'torque', 'converter', 'temperature', 'error']
# ['diagnose', 'engine', 'fault']
# ['diagnose', 'transmission', 'overheat', 'fault']
# ['diagnose', 'transmission', 'slipping', 'fault']
# ['differential', 'oil', 'leak']
# ['hoist', 'motor', 'RTD', 'wired', 'incorrectly']
# ['oil', 'found', 'in', 'revolving', 'frame']
# ['repair', 'leaking', 'swing', 'pedestal', 'seals']
# ['investigate', '/', 'repair', 'no', 'gear', 'fault']
# ['investigate', 'engine', 'oil', 'leak']
# ['diagnose', 'and', 'repair', 'ladder', 'fault']
# ['ground', 'fault', 'welding', 'board']
# ['oil', 'leak', 'swingbox']
# ['ground', 'fault', 'in', 'propel']
# ['engine', 'oil', 'leaks', 'right', 'hand', 'side']
# ['walk', 'motor', 'brake', 'fault']
# ['tray', 'fault']
# ['repair', 'oil', 'leak', 'position', 'wheel', 'end']
# ['repair', 'gear', 'fault']
# ['investigate', '/', 'repair', 'joystick', 'needs', 'repair']
# ['diagnose', 'VIMS', 'error']
# ['repair', 'exhaust', 'leaks']
# ['CW', 'radiator', 'core', 'leak']
# ['Tele-Remote', 'camera', 'fault']
# ['Tele-Remote', 'fault']
# ['Tele-Remote', 'faults']
# ['Tele-Remote', 'issues']
# ['differential', 'oil', 'leak']
# ['engine', 'oil', 'leak']
# ['engine', 'oil', 'leak', 'inspection', 'plate']
# ['engine', 'overheating']
# ['engine', 'vibration', '<num>-<num>', 'RPM']
# ['fuel', 'leak']
# ['hydraulic', 'oil', 'leak', 'from', 'environmental']
# ['ladder', 'fault']
# ['lube', 'fault']
# ['repair', 'engine', 'oil', 'leak', 'and']
# ['repair', 'engine', 'oil', 'leaking']
# ['repair', 'leaking', 'centrifugal', 'filter']
# ['repair', 'transmission', 'fault']
# ['set-up', 'Tele-Remote', 'bogging']
# ['oil', 'leak', 'pilot', 'filter', 'text']
# ['repair', 'engine', 'oil', 'leak', 'text']
# ['repair', 'transmission', 'oil', 'leak', 'text']
# ['injector', 'error']
# ['CW', 'engine', 'oil', 'leaks', 'x']
# ['Tele-Remote', 'fault']
# ['VIMS', 'fuel', 'filter', 'plugged']
# ['aftercooler', 'temperature', 'error']
# ['constant', 'voltage', 'transformer', 'melted']
# ['contamination', 'alarm', 'coming', 'up']
# ['crack', 'repairs', 'left', 'hand', 'window', 'frame']
# ['diagnose', '/', 'repair', 'right', 'hand', 'scoreboard', 'not', 'working']
# ['engine', 'oil', 'blender', 'running', 'constantly']
# ['flow', 'battery', 'power']
# ['generator', 'flow', 'regulator', 'unserviceable']
# ['oil', 'leak', 'at', 'diverter', 'valve']
# ['oil', 'leak', 'inlet', 'to', 'oil', 'burner', 'cover', 'plate']
# ['repair', 'chassis', 'crack', 'at', 'right', 'hand', 'rear', 'cross', 'member']
# ['repair', 'leak', 'in', 'pilot', 'valve', 'solenoid']
# ['transformer', 'trip']
# ['wiper', 'fuse', 'unserviceable']
# Cluster  1
# ['change', 'out', 'blown', 'o-ring', 'on', 'steering', 'pump']
# ['change', 'out', 'blown', 'position', 'tyre']
# ['change', 'out', 'blown', 'steering', 'hose']
# ['change', 'out', 'broken', 'bolt', 'on', 'brake', 'pump']
# ['change', 'out', 'broken', 'prelube', 'bracket']
# ['change', 'out', 'broken', 'stabilizer', 'bar']
# ['change', 'out', 'cracked', 'pipe', 'on', 'valve', 'bank']
# ['change', 'out', 'cracked', 'position', 'adaptor', 'and', 'tooth']
# ['change', 'out', 'exhaust', 'clamp', 'broken', 'on', 'left', 'hand', 'side', '[t', '|]']
# ['change', 'out', 'front', 'upper', 'window', 'cracked']
# ['change', 'out', 'leak', 'slew', 'motor', 'hose']
# ['change', 'out', 'leaking', 'HMU', 'on', 'next']
# ['change', 'out', 'leaking', 'fan', 'hoses']
# ['change', 'out', 'leaking', 'heater', 'taps']
# ['change', 'out', 'leaking', 'hydraulic', 'hose']
# ['change', 'out', 'leaking', 'implement', 'pump']
# ['change', 'out', 'leaking', 'relay', 'valve']
# ['change', 'out', 'leaking', 'steering', 'hose']
# ['change', 'out', 'left', 'hand', 'steering', 'cylinder', 'leaking']
# ['change', 'out', 'position', 'and', 'tyre', 'worn', 'out']
# ['change', 'out', 'position', 'tyre', 'sensor', 'not', 'reading']
# ['change', 'out', 'position', 'tyre', 'damage']
# ['change', 'out', 'unserviceable', 'jacket', 'water', 'pump']
# ['change', 'out', 'unserviceable', 'left', 'hand', 'bucket', 'cylinder', 'hose']
# ['change', 'out', 'unserviceable', 'position', 'tyre']
# ['change', 'out', 'unserviceable', 'right', 'hand', 'clam', 'cylinder', 'hose']
# ['change', 'out', 'unserviceable', 'right', 'hand', 'tilt', 'cylinder']
# ['change', 'out', 'unserviceable', 'swing', 'brake', 'cylinder']
# ['change', 'out', 'weeping', 'boom', 'cylinder', 'hose']
# ['change', 'out', 'worn', 'position', 'tyre']
# ['change', 'out', 'leaking', 'transmission', 'hose']
# ['change', 'out', 'position', 'tyre', 'worn']
# ['change', 'out', 'blown', 'hose']
# ['change', 'out', 'broken', 'grease', 'lines']
# ['change', 'out', 'leaking', 'transmission', 'hose']
# ['change', 'out', 'number', 'faulty', 'injector', 'assembly']
# ['change', 'out', 'plugged', 'fuel', 'filters']
# ['change', 'out', 'worn', 'ripper', 'tip', 'ripper', 'tip']
# ['GET', 'change', 'out', 'worn', 'cutting', 'edges']
# Cluster  2
# ['broken', 'clamp', 'on', 'crowd', 'cylinder', 'hose', 'TBC']
# ['broken', 'fuel', 'cooler', 'mounts']
# ['broken', 'grease', 'plug']
# ['broken', 'hinge']
# ['broken', 'joystick', 'PO']
# ['broken', 'left', 'hand', 'side', 'mirror']
# ['broken', 'mirror']
# ['broken', 'right', 'hand', 'side', 'door', 'window']
# ['broken', 'ripper', 'tooth']
# ['broken', 'weld', 'on', 'handrail']
# ['bucket', 'cracked', 'in', 'arch', 'near', 'cancelled']
# ['crack', 'in', 'blade', 'liner', 'left', 'hand', 'side']
# ['crack', 'in', 'boom', 'chord']
# ['crack', 'in', 'fuel', 'tank']
# ['crack', 'in', 'headboard']
# ['crack', 'in', 'lower', 'centre', 'of', 'windscreen']
# ['crack', 'in', 'windscreen']
# ['cracked', 'front', 'window']
# ['cracked', 'fuel', 'tank']
# ['cracked', 'hydraulic', 'pipe']
# ['cracked', 'steering', 'tank', 'suction', 'tube']
# ['cracked', 'walkway', 'and', 'handrails']
# ['cracks', 'in', 'back', 'right', 'hand', 'side', 'handrail']
# ['cracks', 'in', 'decking']
# ['cracks', 'in', 'diagonal', 'braces', 'in', 'front']
# ['cracks', 'in', 'fire', 'suppression', 'mounts']
# ['cracks', 'in', 'headboard']
# ['cracks', 'in', 'the', 'dirt', 'chute']
# ['dash', 'broken']
# ['repair', 'cracks', 'in', 'mud', 'bucket']
# ['replace', 'faulty', 'brake', 'sensor', 'task']
# ['failed', 'PTO', 'and', 'auxiliary', 'drive', 'PO']
# ['replace', 'oil', 'leaks']
# ['IOV', 'fault', 'on', 'drag', 'package']
# ['replace', 'transmission', 'cracked']
# ['repair', 'cracks', 'on', 'stick']
# ['repair', 'boom', 'cracks', 'left', 'hand', 'side']
# ['replace', 'missing', 'cutting', 'edge']
# ['repair', 'brake', 'fault']
# ['repair', 'movement', 'in', 'left', 'hand', 'steering', 'pin']
# ['replace', 'cracked', 'transmission', 'dropbox']
# ['missing', 'poppet', 'valve']
# ['repair', 'cracked', 'steering', 'tank', 'mo']
# ['replace', 'blocked', 'dryer']
# ['replace', 'broken', 'onside', 'mirror']
# ['replace', 'cracked', 'exhaust', 'shield']
# ['stick', 'cracks']
# ['replace', 'hydraulic', 'oil', 'leak', 'text']
# ['broken', 'wire', 'on', 'speaker']
# ['collect', 'broken', 'tooth']
# ['cracked', 'power', 'point', 'in', 'cabin']
# ['flag', 'missing']
# ['ignition', 'switch', 'sticking']
# ['key', 'broken', 'in', 'ignition', 'switch']
# ['repair', 'crack', 'in', 'right', 'hand', 'side', 'of', 'rear', 'cross', 'member']
# ['repair', 'crack', 'in', 'rear', 'cross', 'member']
# ['repair', 'crack', 'on', 'left', 'hand', 'front', 'heat', 'shield']
# ['repair', 'cracked', 'baffle', 'in', 'hydraulic', 'tank']
# ['repair', 'cracked', 'roof', 'skin', 'left', 'hand', 'side', 'exhaust']
# ['repair', 'cracks', 'in', 'mast', 'cross', 'braces']
# ['repair', 'worn', 'centrifuge', 'filter']
# ['replace', 'broken', 'earth', 'terminal']
# ['replace', 'chip', 'indicators', '(', 'leaking', ')']
# ['replace', 'cracked', 'glass', 'in', 'entry', 'door']
# ['replace', 'cracked', 'water', 'separator']
# ['replace', 'seized', 'air', 'conditioner', 'control', 'cable']
# ['replace', 'shorted', 'diode', 'RPC']
# Cluster  3
# ['air', 'conditioner', 'thermostat', 'not', 'working']
# ['air', 'conditioner', 'thermostat', 'unserviceable']
# ['air', 'conditioner', 'unserviceable']
# ['air', 'conditioner', 'unserviceable', 'when', 'stationary']
# ['air', 'conditioner', 'warm']
# ['air', 'filters', 'plugged']
# ['air', 'horn', 'disconnected']
# ['air', 'horn', 'does', 'not', 'work']
# ['air', 'horn', 'fault']
# ['air', 'horn', 'not', 'working']
# ['air', 'horn', 'not', 'working', 'compressor', 'awaiting']
# ['air', 'horn', 'stuck', 'on']
# ['air', 'horn', 'unserviceable']
# ['air', 'horn', 'working', 'intermittently']
# ['air', 'leak']
# ['air', 'leak', 'near', 'side', 'of', 'door']
# ['auto-spray', 'feature', 'not', 'working']
# ['dragline', 'air', 'conditioner', 'units', 'need', 'cleaning']
# ['air', 'conditioner', 'compressor', 'corroded']
# ['air', 'conditioner', 'compressor', 'unserviceable']
# ['air', 'conditioner', 'fault']
# ['air', 'conditioner', 'no', 'good']
# ['air', 'conditioner', 'system', 'leaking']
# ['air', 'horn', 'not', 'working']
# ['air', 'leak']
# ['air', 'conditioner', 'accessory', 'drive', 'leaking', 'oil']
# ['air', 'conditioner', 'belt', 'broken']
# ['air', 'conditioner', 'compressor', 'not', 'working']
# ['air', 'conditioner', 'compressor', 'tripping', 'out']
# ['air', 'conditioner', 'drive', 'leaking']
# ['air', 'conditioner', 'drive', 'leaking', 'oil']
# ['air', 'conditioner', 'fan', 'unserviceable', 'fit', 'new']
# ['air', 'conditioner', 'fault']
# ['air', 'conditioner', 'needs', 'a', 'boost', 'not', 'cold']
# ['air', 'conditioner', 'not', 'cold', 'PO']
# ['air', 'conditioner', 'not', 'cold', 'electrical', 'faults']
# ['air', 'conditioner', 'pressure', 'switch', 'unserviceable']
# ['air', 'conditioner', 'fan', 'speed', 'resistor', 'not', 'working', 'and']
# ['cabin', 'smoke', 'detector', 'missing']
# Cluster  4
# ['back', 'rest', 'unserviceable', 'handle', 'broken']
# ['backhoe', 'windscreen', 'to', 'be', 'fixed']
# ['backlight', 'on', 'dash', 'unserviceable']
# ['backlights', 'on', 'dash', 'blown']
# ['blown', 'air', 'conditioner', 'hose']
# ['blown', 'air', 'conditioner', 'hose', 'to', 'radiator']
# ['blown', 'brake', 'hose']
# ['blown', 'crowd', 'cylinder', 'hose']
# ['blown', 'extension', 'line', 'from', 'position']
# ['blown', 'hose', 'in', 'hitch']
# ['blown', 'hose', 'on', 'boom']
# ['blown', 'lift', 'cylinder', 'o-ring']
# ['blown', 'o-ring', 'off', 'steering', 'hose']
# ['blown', 'o-ring', 'on', 'left', 'hand', 'lift', 'cylinder']
# ['blown', 'o-ring', 'on', 'steering', 'hose']
# ['blown', 'oil', 'cooler', 'hose', 'x', 'metre']
# ['blown', 'right', 'hand', 'bucket', 'cylinder', 'hose']
# ['blown', 'steering', 'hose']
# ['blown', 'steering', 'pump', 'hose']
# ['cooler', 'return', 'pipe', 'coupling', 'leak']
# ['cutting', 'edges', 'need', 'change', 'out']
# ['differential', 'pump', 'motor', 'hose', 'leaking']
# ['dogbone', 'pin', 'out']
# ['drill', 'out', 'broken', 'bolt', 'see', 'text']
# ['drivers', 'window', 'fault']
# ['front', 'revolving', 'light', 'not', 'working']
# ['rear', 'steering', 'accumulator', 'leak']
# ['all', 'lighting', 'requires', 'testing', 'and', 'tagging']
# ['front', 'right', 'hand', 'roller', 'need', 'to', 'be', 'fitted']
# ['system', 'pump', 'pressure', 'gauge', 'not', 'working']
# ['rear', 'door', 'struts', 'require', 'replacing']
# ['movement', 'on', 'steering', 'column']
# ['parts', 'washer', 'pump', 'broken']
# ['middle', 'air', 'drain', 'tap', 'leaking']
# ['bottom', 'steering', 'shaft', 'universal', 'joint', 'worn']
# ['right', 'hand', 'bobbin', 'roller', 'unserviceable']
# ['left', 'hand', 'side', 'pinion', 'change', 'out', 'cover', 'cracking']
# ['left', 'hand', 'rear', 'brake', 'cooling', 'hose', 'leaking']
# ['cabin', 'jacking', 'cylinder', 'ends', 'unserviceable']
# ['front', 'window', 'roller', 'blind', 'broken']
# ['HMU', 'hose', 'weeping']
# ['left', 'hand', 'boom', 'cylinder', 'hose', 'leaking', 'PO']
# ['left', 'hand', 'corner', 'bonnet', 'cracked']
# ['left', 'hand', 'side', 'boom', 'foot', 'crack', 'repair']
# ['lower', 'left', 'hand', 'headlight', 'blown']
# ['operators', 'seat', 'worn', 'padding']
# ['rear', 'steering', 'accumulator', 'leaking']
# ['chord', 'is', 'leaking', 'air', 'from', 'crack']
# ['steering', 'pin', 'no', 'grease', 'text']
# ['air', 'pressure', 'safety', 'valve', 'exhausting']
# ['blown', 'air', 'conditioner', 'fuse']
# ['centrifuge', 'hose', 'leaking', 'replace']
# ['depth', 'counter', 'unserviceable']
# ['front', 'lights', 'keep', 'blowing', 'fuse']
# ['heat', 'up', 'locked', 'steels']
# ['inverter', 'earthing', 'out']
# ['keeps', 'blowing', 'starter', '/', 'horn', 'fuse']
# ['left', 'hand', 'chain', 'guide', 'unserviceable']
# ['left', 'hand', 'chain', 'guide', 'worn', 'at', 'the', 'top']
# ['left', 'hand', 'PTO', 'pump', 'chip', 'sensor', 'harness', 'unserviceable']
# ['number', 'pump', 'contamination', 'switch', 'on']
# ['position', 'pressure', 'compensator', 'weeping']
# ['position', 'pump', 'cavity', 'low']
# ['pump', 'drive', 'box', 'coupling', 'and', 'shaft', 'unserviceable']
# ['right', 'hand', 'PTO', 'cavity', 'emptying']
# Cluster  5
# ['air', 'leaking', 'from', 'line', 'outside']
# ['airhorn', 'not', 'working']
# ['and', 'lube', 'system', 'faults']
# ['auto-greaser', 'leaking', 'oil']
# ['backup', 'alarm', 'not', 'working']
# ['battery', 'cover', 'hinges', 'seized']
# ['bearings', 'are', 'shot']
# ['belly', 'plate', 'bolt', 'missing']
# ['boarding', 'gate', 'hinge', 'broken']
# ['boarding', 'gate', 'latch', 'not', 'working']
# ['boarding', 'ladder', 'not', 'working']
# ['brake', 'cooling', 'hose', 'leaking']
# ['brake', 'cooling', 'hose', 'leaking', 'rear']
# ['brake', 'cooling', 'return', 'hose', 'leaking']
# ['cabin', 'door', 'window', 'cracked']
# ['cabin', 'seals', 'leaking', 'dust', 'PO']
# ['cabin', 'seals', 'leaking', 'dust', 'bad']
# ['cabin', 'seat', 'needs', 'replacing']
# ['cabin', 'window', 'needs', 'resealing']
# ['chord', 'leaking', 'air', 'found']
# ['chord', 'pressure', 'fault']
# ['compressor', 'oil', 'pressure', 'switch', 'unserviceable']
# ['control', 'valve', 'unserviceable', 'see', 'long', 'text']
# ['coolant', 'hose', 'leaking', 'at', 'right', 'hand', 'bottom']
# ['coolant', 'leak']
# ['coolant', 'leak', 'at', 'engine', 'oil', 'cooler']
# ['coolant', 'leak', 'at', 'jacket', 'water', 'pump']
# ['coolant', 'pipe', 'clamps', 'needs', 'fitting', 'TBC']
# ['crowd', 'cylinder', 'creeping', 'replace']
# ['differential', 'cooler', 'fan', 'hose', 'leaking']
# ['differential', 'cooler', 'hose', 'leaking']
# ['differential', 'cooler', 'pump', 'leaking']
# ['differential', 'leak']
# ['differential', 'lock', 'broken']
# ['differential', 'lube', 'pump', 'leaking']
# ['differential', 'lube', 'pump', 'leaking', 'PO']
# ['duo-cone', 'seals', 'leaking', 'number', 'swing']
# ['dust', 'leak', 'operators', 'side', 'window']
# ['electrical', 'harness', 'fault']
# ['speedometer', 'not', 'working']
# ['machine', 'will', 'not', 'start']
# ['possible', 'minor', 'leak', 'on', 'fuel', 'tank']
# ['crane', 'not', 'working']
# ['grease', 'pump', 'unserviceable']
# ['transmission', 'fill', '/', 'drain', 'plug', 'unserviceable']
# ['bearing', 'noisy']
# ['steering', 'cylinder', 'bearings', 'have', 'excess', 'play']
# ['rear', 'wiper', 'motor', 'unserviceable']
# ['main', 'isolator', 'needs', 'clean', 'out']
# ['grease', 'pump', 'is', 'bypassing', 'air']
# ['handrail', 'above', 'battery', 'box', 'cracked']
# ['grease', 'gauges', 'requires', 'replacing']
# ['fire', 'extinguisher', 'bracket', 'on', 'deck', 'loose']
# ['mechanical', 'PTO', 'not', 'meshing']
# ['oil', 'leak', 'at', 'air', 'compressor']
# ['coolant', 'leaking']
# ['tail', 'pulley', 'has', 'no', 'grease', 'lines']
# ['drag', 'generator', 'fault']
# ['grease', 'system', 'fault']
# ['investigate', 'auto-lube', 'fault']
# ['synchronous', 'motor', 'trip']
# ['steering', 'hub', 'caps', 'require', 'replacing']
# ['bulk', 'fuel', 'tank', 'cracked', 'and', 'leaking']
# ['swing', 'resolver', 'not', 'counting']
# ['repair', 'air', 'conditioner', 'and', 'wiring', 'fault']
# ['swing', 'resolver', 'fault']
# ['drag', 'chain', 'fault']
# ['headboard', 'welds', 'broken', '/', 'cracked']
# ['inspect', 'bad', 'engine', 'oil', 'leak']
# ['cabin', 'seat', 'unserviceable', 'needs', 'replacing']
# ['oil', 'leak', 'from', 'behind', 'water', 'pump']
# ['Tele-Remote', 'cameras', 'fault', 'text']
# ['coolant', 'leak']
# ['differential', 'lube', 'hose', 'leaking']
# ['engine', 'fan', 'hose', 'weeping']
# ['engine', 'shutdown', 'fault']
# ['exhaust', 'leak']
# ['fan', 'hose', 'leaking']
# ['fuel', 'breather', 'missing']
# ['fuel', 'cap', 'is', 'missing']
# ['grease', 'system', 'fail']
# ['grease', 'system', 'fault']
# ['hose', 'leak', 'developing']
# ['investigate', 'torque', 'converter', 'fan', 'pump', 'oil', 'leak']
# ['minor', 'transmission', 'oil', 'leak']
# ['park', 'brake', 'fault']
# ['radiator', 'relief', 'valves', 'leaking']
# ['transmission', 'charge', 'hose', 'leaking']
# ['engine', 'shutdown', 'fault']
# ['grease', 'system', 'has', 'intermittent', 'fault']
# ['transmission', 'temperature', 'fault']
# ['CW', 'engine', 'water', 'pump', 'snapped', 'shaft']
# ['CW', 'transmission', 'failed']
# ['air', 'brake', 'line', 'blown', 'requires', 'replacing']
# ['cabin', 'side', 'weightometer', 'not', 'working']
# ['compressor', 'safety', 'valve', 'leaking']
# ['dry', 'cell', 'not', 'working', 'properly']
# ['<sensitive>', 'depth', 'counter', 'not', 'working']
# ['electric', 'propel', 'siren', 'not', 'working']
# ['earth', 'wire', 'broken', 'on', 'bottom', 'of', 'radiator']
# ['grease', 'distributor', 'leaking']
# ['heater', 'hose', 'in', 'cabin', 'roof', 'unserviceable']
# ['high', 'voltage', 'slip', 'ring', 'inspection', 'grease', 'leak']
# ['investigate', 'main', 'transformer', 'overload', 'fault']
# ['microwave', 'oven', 'unserviceable']
# ['oil', 'centrifuge', 'gasket', 'leaking', 'right', 'hand', 'engine']
# ['pilot', 'valve', 'leaking', 'oil']
# ['pressure', 'compensator', 'leaking']
# ['pressure', 'control', 'valve', 'in', 'cabin', 'leaking']
# ['radiator', 'blocked', 'with', 'grass']
# ['radiator', 'sight', 'glasses', 'unserviceable']
# ['repair', 'air', 'leak', 'at', 'air', 'tank', 'safety', 'valve']
# ['start', 'motorvator', 'and', 'set', 'limits']
# ['troubleshoot', 'smart', 'meter', 'not', 'communicating']
# ['TV', 'monitor', 'does', 'not', 'turn', 'on']
# ['TV', 'monitor', 'has', 'no', 'signal']
# ['voltage', 'regulator', 'fuse', 'fault']
# ['weightometer', 'display', 'on', 'trailer', 'unserviceable']
# ['window', 'frame', 'needs', 'repair']
# Cluster  6
# ['batteries', 'out', 'of', 'service']
# ['blown', 'position', 'tyre']
# ['change', 'position', 'flat', 'tyre']
# ['change', 'position', 'tyre', 'damage', 'text']
# ['cutting', 'edges', 'loose']
# ['damage', 'to', 'position', 'tyre']
# ['damaged', 'position', 'tyre']
# ['damaged', 'position', 'tyre', 'and', 'rim']
# ['position', 'brake', 'temperature', 'error']
# ['replace', 'blown', 'implement', 'hose']
# ['replace', 'blown', 'right', 'hand', 'steering', 'hose']
# ['replace', 'unserviceable', 'differential', 'drain', 'plugs']
# ['replace', 'right', 'hand', 'lift', 'cylinder', 'leaking']
# ['replace', 'damaged', 'position', 'tyre', 'and', 'position']
# ['replace', 'x', 'cracked', 'windows']
# ['position', 'tyre', 'blown']
# ['replace', 'damaged', 'tyre', 'on', 'position']
# ['replace', 'blown', 'main', 'pump', 'hose']
# ['replace', 'position', 'tyre', 'damaged']
# ['replace', 'position', 'tyre', 'mismatched']
# ['repair', 'blown', 'air', 'conditioner', 'hose']
# ['repaired', 'x', 'broken', 'lines']
# ['replace', 'blown', 'hose']
# ['replace', 'blown', 'work', 'lights']
# ['position', 'chip', 'sensor', 'alarm']
# ['repair', 'left', 'hand', 'scoreboard', 'base', 'cracked']
# ['replace', 'unserviceable', 'grease', 'distributor']
# ['replace', 'unserviceable', 'chip', 'indicators']
# ['replace', 'unserviceable', 'transmission', 'screen', 'and', 'magnet']
# Cluster  7
# ['alarm', 'on', 'VIMS', 'does', 'not', 'work']
# ['all', 'dash', 'lights', 'on']
# ['alternator', 'not', 'charging']
# ['armrest', 'unserviceable']
# ['auto-greaser', 'unserviceable']
# ['batteries', 'discharging']
# ['batteries', 'unserviceable']
# ['beacon', 'mount', 'is', 'broken']
# ['beacon', 'not', 'working']
# ['beacon', 'unserviceable']
# ['bearing', 'on', 'air', 'conditioner', 'compressor', 'unserviceable']
# ['bent', 'belly', 'plate']
# ['blade', 'light', 'blown', 'needs', 'replacing']
# ['blade', 'skin', 'cracked']
# ['blade', 'wear', 'plates', 'cracked', 'and', 'worn']
# ['blown', 'light', 'on', 'boom']
# ['both', 'stick', 'cylinders', 'leaking']
# ['brake', 'release', 'fault']
# ['broken', 'air', 'conditioner', 'guard']
# ['carousel', 'popped', 'bolt', 'needs', 'Loctite']
# ['check', '/', 'repair', 'engine', 'oil', 'leak']
# ['crack', 'onside', 'rock', 'deflector']
# ["driver's", 'door', 'top', 'hinge', 'broken']
# ['ripper', 'control', 'valve', 'falling', 'off']
# ['cable', 'gantry', 'crack', 'repairs']
# ['replace', 'leaking', 'transfer', 'pipe']
# ['drag', 'tripped', 'on', 'electrical']
# ['fire', 'extinguisher', 'out', 'of', 'date']
# ['rear', 'through', 'shaft', 'universal', 'joint', 'unserviceable']
# ['movement', 'found', 'right', 'hand', 'engine', 'mount']
# ['investigate', 'and', 'repair', 'oil', 'leak']
# ['park', 'brake', 'alarm', 'sounds', 'continuously']
# ['repair', 'right', 'hand', 'fuel', 'tank', 'crack']
# ['park', 'brake', 'alarm', 'fault']
# ['front', 'window', 'cracked', 'replace']
# ['VIMS', 'keypad', 'light', 'out']
# ['swing', 'brake', 'pressure', 'fault']
# ['replace', 'leaking', 'scavenge', 'pump']
# ['brake', 'warning', 'light', 'on']
# ['leaking', 'brake', 'cooling', 'hose']
# ['faulty', 'fuel', 'pressure', 'sensor']
# ['fitting', 'leaking', 'out', 'of', 'main', 'air', 'tanks']
# ['repair', 'centre', 'hitch', 'oil', 'leaks']
# ['hydraulic', 'hose', 'leaking', 'in', 'centre', 'of', 'machine']
# ['replace', 'damage', 'auto-greaser', 'door']
# ['hoist', 'brake', 'switches', 'need', 'adjusting']
# ['park', 'brake', 'indicator', 'light', 'going', 'on', 'and', 'off']
# ['tracks', 'need', 'adjusting']
# ['no', 'excitation', 'on', 'hoist']
# ['stick', 'cylinder', 'leaking']
# ['hoist', 'brake', 'number', 'position', 'out', 'of', 'adjustment']
# ['PTO', 'shaft', 'requires', 'replacing']
# ['AM', '/', 'FM', 'radio', 'needs', 'new', 'aerial']
# ['CW', 'left', 'hand', 'hoist', 'cylinder', 'leaking', 'plug']
# ['CW', 'right', 'hand', 'hoist', 'cylinder', 'leaking']
# ['PTO', 'shaft', 'input', 'seal', 'leaking']
# ['brake', 'hose', 'needs', 'to', 'be', 'replaced']
# ['emergency', 'gate', 'latch', 'broken']
# ['engine', 'bay', 'light', 'blown']
# ['front', 'headlight', 'blown']
# ['hoist', 'drum', 'cracking']
# ['modular', 'does', 'not', 'self', 'assign']
# ['no', 'reception', 'on', 'AM', '/', 'FM', 'radio']
# ['noisy', 'hydraulic', 'lift', 'cylinder']
# ['repair', 'right', 'hand', 'track', 'frame', 'crack']
# ['replace', 'failed', 'air', 'conditioner', 'compressor']
# ['replace', 'leaking', 'steering', 'cylinder']
# ['replaced', 'leaking', 'steering', 'hose']
# ['ripper', 'shank', 'broken']
# ['Bradken', 'to', 'repair', 'broken', 'clam']
# ['CW', 'PTO', 'universal', 'joint', 'failed']
# ['CW', 'top', 'radiator', 'tank', 'leak', 'again']
# ['PTO', 'input', 'seal', 'leaking']
# ['adaptor', 'leaking', 'at', 'implement', 'valve']
# ['aftercooler', 'tank', 'gauge', 'broken']
# ['number', 'right', 'hand', 'air', 'brake', 'line', 'needs', 'replacing']
# ['[', 'shutdown', ']', 'vinyl', 'flooring', 'unserviceable']
# ['batteries', 'have', 'no', 'charge']
# ['battery', 'unserviceable', 'dropped', 'cell', 'replace']
# ['blade', 'control', 'cable', 'tight']
# ['broken', 'proximity', 'sensor', 'tag', 'carousel']
# ['contamination', 'alarm', 'on']
# ['dust', 'flap', 'on', 'cabin', 'side', 'of', 'mast', 'needs', 'extending']
# ['equipment', 'damaged', '(', 'terminal', 'box', ')']
# ['fuel', 'filter', 'water', 'separator', 'housing', 'broken']
# ['hole', 'in', 'door', 'frame']
# ['ignition', 'switch', 'broken', 'replace']
# ['number', 'slew', 'pump', 'contamination', 'switch', 'unserviceable']
# ['glass', 'window', 'has', 'large', 'crack']
# ['power', 'step', 'control', 'cable', 'broken']
# ['remove', 'unserviceable', 'air', 'separator']
# ['repair', 'faulty', 'safety', 'valve']
# ['replace', 'unserviceable', 'ignition', 'switch']
# ['rock', 'breaker', 'cracked']
# ['rock', 'breaker', 'in', 'bucket', 'cracked', 'at', 'base']
# ['safety', 'flag', 'missing']
# ['siren', 'unserviceable']
# ['slip', 'ring', 'overgreasing']
# ['water', 'separator', 'filter', 'leaking', 'see', 'photo']
# ['water', 'separator', 'leaking', 'fuel']
# ['will', 'not', 'start', 'batteries', 'unserviceable']
# Cluster  8
# Cluster  9
# Cluster  10
# Cluster  11
# Cluster  12
# Cluster  13
# Cluster  14

# %% [markdown]
# ## Hierachical Clustering

# %% [markdown]
# ### Average clustering

# %%
linkage_data = linkage(cluster_embeddings, method='average')
fig = plt.figure(figsize=(25, 10))
dn = dendrogram(linkage_data)
plt.show()

# %%
k=15
cluster_labels = fcluster(linkage_data, k, criterion='maxclust')
for i in range(1,k+1):
    print("Cluster",i,":")
    cluster_words = {}
    for j in range(len(cluster_labels)):
        if cluster_labels[j]==i:
            print(" ".join(dataset_not_padded[j]))
            for word in dataset_not_padded[j]:
                if word in cluster_words:
                    cluster_words[word]+=1
                else:
                    cluster_words[word]=1
    print("Top words:")
    sorted_cluster_words = sorted(cluster_words, key=cluster_words.get, reverse=True)
    for j in range(min(len(sorted_cluster_words), 5)):
        print(sorted_cluster_words[j])
    print()
# Out:
# Cluster 1 :
# change out broken prelube bracket
# change out broken stabilizer bar
# change out exhaust clamp broken on left hand side [t |]
# Top words:
# change
# out
# broken
# prelube
# bracket
#
# Cluster 2 :
# analyse failed driveline component
# ground fault welding board
# Top words:
# analyse
# failed
# driveline
# component
# ground
#
# Cluster 3 :
# cracks in fire suppression mounts
# cracks in the dirt chute
# Top words:
# cracks
# in
# fire
# suppression
# mounts
#
# Cluster 4 :
# hoist motor RTD wired incorrectly
# engine oil blender running constantly
# Top words:
# hoist
# motor
# RTD
# wired
# incorrectly
#
# Cluster 5 :
# air conditioner thermostat not working
# air conditioner thermostat unserviceable
# air conditioner unserviceable
# air conditioner unserviceable when stationary
# air conditioner warm
# air filters plugged
# air horn disconnected
# air horn does not work
# air horn fault
# air horn not working
# air horn not working compressor awaiting
# air horn stuck on
# air horn unserviceable
# air horn working intermittently
# air leak
# air leak near side of door
# air leaking from line outside
# airhorn not working
# alarm on VIMS does not work
# all dash lights on
# alternator drive leaking
# alternator failed
# alternator not charging
# alternator overcharge fault
# alternator overcharged
# and lube system faults
# armrest unserviceable
# auto-greaser leaking oil
# auto-greaser unserviceable
# auto-lube error PO
# axle temperature fault
# axle temperature sensor fault
# backhoe windscreen to be fixed
# backlight on dash unserviceable
# backlights on dash blown
# backup alarm not working
# batteries discharging
# batteries out of service
# batteries unserviceable
# battery cover hinges seized
# beacon mount is broken
# beacon not working
# beacon unserviceable
# bearing on air conditioner compressor unserviceable
# bearings are shot
# belly plate bolt missing
# bent belly plate
# blade light blown needs replacing
# blade skin cracked
# blown air conditioner hose
# blown air conditioner hose to radiator
# blown brake hose
# blown crowd cylinder hose
# blown extension line from position
# blown hose in hitch
# blown hose on boom
# blown lift cylinder o-ring
# blown light on boom
# blown o-ring off steering hose
# blown o-ring on left hand lift cylinder
# blown o-ring on steering hose
# blown oil cooler hose x metre
# blown position tyre
# blown right hand bucket cylinder hose
# blown steering hose
# blown steering pump hose
# boarding gate hinge broken
# boarding gate latch not working
# boarding ladder not working
# both stick cylinders leaking
# brake cooling hose leaking
# brake cooling hose leaking rear
# brake cooling return hose leaking
# brake release fault
# brake temperature error
# broken air conditioner guard
# broken clamp on crowd cylinder hose TBC
# broken fuel cooler mounts
# broken grease plug
# broken hinge
# broken joystick PO
# broken left hand side mirror
# broken mirror
# broken right hand side door window
# broken ripper tooth
# broken weld on handrail
# cabin door window cracked
# cabin needs resealing
# cabin seals leaking dust PO
# cabin seals leaking dust bad
# cabin seat needs replacing
# cabin window needs resealing
# camera fault
# carousel popped bolt needs Loctite
# centrifugal oil filter fault
# centrifugal oil filter leaking
# change out blown o-ring on steering pump
# change out blown position tyre
# change out blown steering hose
# change out broken bolt on brake pump
# change out cracked pipe on valve bank
# change out cracked position adaptor and tooth
# change out front upper window cracked
# change out leak slew motor hose
# change out leaking HMU on next
# change out leaking fan hoses
# change out leaking heater taps
# change out leaking hydraulic hose
# change out leaking implement pump
# change out leaking relay valve
# change out leaking steering hose
# change out left hand steering cylinder leaking
# change out position and tyre worn out
# change out position tyre sensor not reading
# change out position tyre damage
# change out unserviceable jacket water pump
# change out unserviceable left hand bucket cylinder hose
# change out unserviceable position tyre
# change out unserviceable right hand clam cylinder hose
# change out unserviceable right hand tilt cylinder
# change out unserviceable swing brake cylinder
# change out weeping boom cylinder hose
# change out worn position tyre
# change position flat tyre
# change position tyre damage text
# check / repair engine oil leak
# chord leaking air found
# chord pressure fault
# compressor oil pressure switch unserviceable
# contactor fault
# control valve unserviceable see long text
# coolant hose leaking at right hand bottom
# coolant leak
# coolant leak at engine oil cooler
# coolant leak at jacket water pump
# cooler return pipe coupling leak
# cords cracked at and
# crack in blade liner left hand side
# crack in boom chord
# crack in fuel tank
# crack in headboard
# crack in lower centre of windscreen
# crack in windscreen
# crack onside rock deflector
# cracked front window
# cracked fuel tank
# cracked hydraulic pipe
# cracked steering tank suction tube
# cracked suction tube
# cracked walkway and handrails
# cracks in back right hand side handrail
# cracks in decking
# cracks in diagonal braces in front
# cracks in headboard
# crankcase error
# crowd cylinder creeping replace
# cutting edges loose
# cutting edges need change out
# damage to position tyre
# damaged position tyre
# damaged position tyre and rim
# dash broken
# diagnose / repair slow steering
# diagnose and repair spray faults
# diagnose and repair torque converter temperature error
# diagnose engine fault
# diagnose transmission overheat fault
# diagnose transmission slipping fault
# differential cooler fan hose leaking
# differential cooler hose leaking
# differential cooler pump leaking
# differential leak
# differential lock broken
# differential lube pump leaking
# differential lube pump leaking PO
# differential oil leak
# differential pump motor hose leaking
# dogbone pin out
# dragline air conditioner units need cleaning
# drill out broken bolt see text
# driver's door top hinge broken
# drivers window fault
# duo-cone seals leaking number swing
# dust leak operators side window
# electrical harness fault
# ripper control valve falling off
# repair cracks in mud bucket
# replace faulty brake sensor task
# speedometer not working
# cable gantry crack repairs
# failed PTO and auxiliary drive PO
# replace leaking transfer pipe
# drag tripped on electrical
# position brake temperature error
# front revolving light not working
# fire extinguisher out of date
# machine will not start
# possible minor leak on fuel tank
# replace blown implement hose
# rear steering accumulator leak
# replace blown right hand steering hose
# crane not working
# grease pump unserviceable
# transmission fill / drain plug unserviceable
# bearing noisy
# oil found in revolving frame
# replace oil leaks
# rear through shaft universal joint unserviceable
# repair leaking swing pedestal seals
# all lighting requires testing and tagging
# steering cylinder bearings have excess play
# movement found right hand engine mount
# rear wiper motor unserviceable
# front right hand roller need to be fitted
# main isolator needs clean out
# replace transmission cracked
# investigate and repair oil leak
# park brake alarm sounds continuously
# system pump pressure gauge not working
# replace unserviceable differential drain plugs
# repair right hand fuel tank crack
# grease pump is bypassing air
# park brake alarm fault
# repair cracks on stick
# repair boom cracks left hand side
# investigate / repair no gear fault
# handrail above battery box cracked
# front window cracked replace
# VIMS keypad light out
# investigate engine oil leak
# replace right hand lift cylinder leaking
# diagnose and repair ladder fault
# replace damaged position tyre and position
# grease gauges requires replacing
# fire extinguisher bracket on deck loose
# rear door struts require replacing
# swing brake pressure fault
# oil leak at air compressor
# replace leaking scavenge pump
# coolant leaking
# change out leaking transmission hose
# tail pulley has no grease lines
# movement on steering column
# oil leak swingbox
# replace x cracked windows
# ground fault in propel
# drag generator fault
# parts washer pump broken
# middle air drain tap leaking
# engine oil leaks right hand side
# position tyre blown
# grease system fault
# investigate auto-lube fault
# brake warning light on
# leaking brake cooling hose
# faulty fuel pressure sensor
# bottom steering shaft universal joint worn
# right hand bobbin roller unserviceable
# replace damaged tyre on position
# repair brake fault
# synchronous motor trip
# left hand side pinion change out cover cracking
# walk motor brake fault
# tray fault
# left hand rear brake cooling hose leaking
# fitting leaking out of main air tanks
# repair centre hitch oil leaks
# repair oil leak position wheel end
# steering hub caps require replacing
# bulk fuel tank cracked and leaking
# hydraulic hose leaking in centre of machine
# swing resolver not counting
# repair gear fault
# repair air conditioner and wiring fault
# replace damage auto-greaser door
# swing resolver fault
# investigate / repair joystick needs repair
# drag chain fault
# headboard welds broken / cracked
# inspect bad engine oil leak
# hoist brake switches need adjusting
# change out position tyre worn
# cabin jacking cylinder ends unserviceable
# repair movement in left hand steering pin
# replace blown main pump hose
# park brake indicator light going on and off
# tracks need adjusting
# replace cracked transmission dropbox
# no excitation on hoist
# front window roller blind broken
# replace position tyre damaged
# cabin seat unserviceable needs replacing
# diagnose VIMS error
# oil leak from behind water pump
# replace position tyre mismatched
# repair exhaust leaks
# stick cylinder leaking
# hoist brake number position out of adjustment
# PTO shaft requires replacing
# missing poppet valve
# AM / FM radio needs new aerial
# CW left hand hoist cylinder leaking plug
# CW radiator core leak
# CW right hand hoist cylinder leaking
# HMU hose weeping
# PTO shaft input seal leaking
# Tele-Remote camera fault
# Tele-Remote cameras fault text
# Tele-Remote fault
# Tele-Remote faults
# Tele-Remote issues
# air conditioner compressor corroded
# air conditioner compressor unserviceable
# air conditioner fault
# air conditioner no good
# air conditioner system leaking
# air horn not working
# air leak
# brake hose needs to be replaced
# change out blown hose
# change out broken grease lines
# change out leaking transmission hose
# change out number faulty injector assembly
# change out plugged fuel filters
# change out worn ripper tip ripper tip
# coolant leak
# differential lube hose leaking
# differential oil leak
# emergency gate latch broken
# engine bay light blown
# engine fan hose weeping
# engine oil leak
# engine oil leak inspection plate
# engine overheating
# engine shutdown fault
# engine vibration <num>-<num> RPM
# exhaust leak
# fan hose leaking
# front headlight blown
# fuel breather missing
# fuel cap is missing
# fuel leak
# grease system fail
# grease system fault
# hoist drum cracking
# hose leak developing
# hydraulic oil leak from environmental
# investigate torque converter fan pump oil leak
# ladder fault
# left hand boom cylinder hose leaking PO
# left hand corner bonnet cracked
# left hand side boom foot crack repair
# lower left hand headlight blown
# lube fault
# minor transmission oil leak
# no reception on AM / FM radio
# noisy hydraulic lift cylinder
# operators seat worn padding
# park brake fault
# radiator relief valves leaking
# rear steering accumulator leaking
# repair blown air conditioner hose
# repair cracked steering tank mo
# repair engine oil leak and
# repair engine oil leaking
# repair leaking centrifugal filter
# repair right hand track frame crack
# repair transmission fault
# repaired x broken lines
# replace blocked dryer
# replace blown hose
# replace blown work lights
# replace broken onside mirror
# replace cracked exhaust shield
# replace failed air conditioner compressor
# replace leaking steering cylinder
# replaced leaking steering hose
# ripper shank broken
# set-up Tele-Remote bogging
# stick cracks
# transmission charge hose leaking
# chord is leaking air from crack
# engine shutdown fault
# grease system has intermittent fault
# oil leak pilot filter text
# repair engine oil leak text
# repair transmission oil leak text
# replace hydraulic oil leak text
# steering pin no grease text
# transmission temperature fault
# injector error
# Bradken to repair broken clam
# CW PTO universal joint failed
# CW engine oil leaks x
# CW engine water pump snapped shaft
# CW top radiator tank leak again
# CW transmission failed
# GET change out worn cutting edges
# PTO input seal leaking
# Tele-Remote fault
# VIMS fuel filter plugged
# adaptor leaking at implement valve
# aftercooler tank gauge broken
# aftercooler temperature error
# air conditioner accessory drive leaking oil
# air conditioner belt broken
# air conditioner compressor not working
# air conditioner compressor tripping out
# air conditioner drive leaking
# air conditioner drive leaking oil
# air conditioner fan unserviceable fit new
# air conditioner fault
# air conditioner needs a boost not cold
# air conditioner not cold PO
# air conditioner not cold electrical faults
# air conditioner pressure switch unserviceable
# number right hand air brake line needs replacing
# [ shutdown ] vinyl flooring unserviceable
# air conditioner fan speed resistor not working and
# air brake line blown requires replacing
# air pressure safety valve exhausting
# batteries have no charge
# battery unserviceable dropped cell replace
# blade control cable tight
# blown air conditioner fuse
# broken proximity sensor tag carousel
# broken wire on speaker
# cabin side weightometer not working
# cabin smoke detector missing
# centrifuge hose leaking replace
# collect broken tooth
# compressor safety valve leaking
# constant voltage transformer melted
# contamination alarm coming up
# contamination alarm on
# crack repairs left hand window frame
# cracked power point in cabin
# dry cell not working properly
# depth counter unserviceable
# diagnose / repair right hand scoreboard not working
# <sensitive> depth counter not working
# electric propel siren not working
# earth wire broken on bottom of radiator
# equipment damaged ( terminal box )
# flag missing
# flow battery power
# front lights keep blowing fuse
# fuel filter water separator housing broken
# generator flow regulator unserviceable
# grease distributor leaking
# heat up locked steels
# heater hose in cabin roof unserviceable
# hole in door frame
# high voltage slip ring inspection grease leak
# ignition switch broken replace
# ignition switch sticking
# inverter earthing out
# investigate main transformer overload fault
# keeps blowing starter / horn fuse
# key broken in ignition switch
# left hand chain guide unserviceable
# left hand chain guide worn at the top
# left hand PTO pump chip sensor harness unserviceable
# microwave oven unserviceable
# number pump contamination switch on
# number slew pump contamination switch unserviceable
# oil centrifuge gasket leaking right hand engine
# oil leak at diverter valve
# oil leak inlet to oil burner cover plate
# glass window has large crack
# position pressure compensator weeping
# position chip sensor alarm
# pilot valve leaking oil
# position pump cavity low
# power step control cable broken
# pressure compensator leaking
# pressure control valve in cabin leaking
# pump drive box coupling and shaft unserviceable
# right hand PTO cavity emptying
# radiator blocked with grass
# radiator sight glasses unserviceable
# remove unserviceable air separator
# repair crack in right hand side of rear cross member
# repair air leak at air tank safety valve
# repair chassis crack at right hand rear cross member
# repair crack in rear cross member
# repair crack on left hand front heat shield
# repair cracked baffle in hydraulic tank
# repair cracked roof skin left hand side exhaust
# repair cracks in mast cross braces
# repair faulty safety valve
# repair left hand scoreboard base cracked
# repair leak in pilot valve solenoid
# repair worn centrifuge filter
# replace broken earth terminal
# replace chip indicators ( leaking )
# replace cracked glass in entry door
# replace cracked water separator
# replace seized air conditioner control cable
# replace shorted diode RPC
# replace unserviceable grease distributor
# replace unserviceable chip indicators
# replace unserviceable ignition switch
# replace unserviceable transmission screen and magnet
# rock breaker cracked
# rock breaker in bucket cracked at base
# safety flag missing
# siren unserviceable
# slip ring overgreasing
# start motorvator and set limits
# troubleshoot smart meter not communicating
# transformer trip
# TV monitor does not turn on
# TV monitor has no signal
# voltage regulator fuse fault
# water separator filter leaking see photo
# water separator leaking fuel
# weightometer display on trailer unserviceable
# will not start batteries unserviceable
# window frame needs repair
# wiper fuse unserviceable
# Top words:
# leaking
# air
# unserviceable
# out
# hose
#
# Cluster 6 :
# dust flap on cabin side of mast needs extending
# Top words:
# dust
# flap
# on
# cabin
# side
#
# Cluster 7 :
# modular does not self assign
# Top words:
# modular
# does
# not
# self
# assign
#
# Cluster 8 :
# bucket cracked in arch near cancelled
# Top words:
# bucket
# cracked
# in
# arch
# near
#
# Cluster 9 :
# replace missing cutting edge
# Top words:
# replace
# missing
# cutting
# edge
#
# Cluster 10 :
# IOV fault on drag package
# Top words:
# IOV
# fault
# on
# drag
# package
#
# Cluster 11 :
# auto-spray feature not working
# Top words:
# auto-spray
# feature
# not
# working
#
# Cluster 12 :
# coolant pipe clamps needs fitting TBC
# Top words:
# coolant
# pipe
# clamps
# needs
# fitting
#
# Cluster 13 :
# mechanical PTO not meshing
# Top words:
# mechanical
# PTO
# not
# meshing
#
# Cluster 14 :
# back rest unserviceable handle broken
# Top words:
# back
# rest
# unserviceable
# handle
# broken
#
# Cluster 15 :
# blade wear plates cracked and worn
# Top words:
# blade
# wear
# plates
# cracked
# and

# %% [markdown]
# ### ward clustering

# %%
linkage_data = linkage(cluster_embeddings, method='ward')
fig = plt.figure(figsize=(25, 10))
dn = dendrogram(linkage_data)
plt.show()

# %%
k=8
cluster_labels = fcluster(linkage_data, k, criterion='maxclust')
for i in range(1,k+1):
    print("Cluster",i,":")
    cluster_words = {}
    for j in range(len(cluster_labels)):
        if cluster_labels[j]==i:
            print(" ".join(dataset_not_padded[j]))
            for word in dataset_not_padded[j]:
                if word in cluster_words:
                    cluster_words[word]+=1
                else:
                    cluster_words[word]=1
    print("Top words:")
    sorted_cluster_words = sorted(cluster_words, key=cluster_words.get, reverse=True)
    for j in range(min(len(sorted_cluster_words), 5)):
        print(sorted_cluster_words[j])
    print()
# Out:
# Cluster 1 :
# change out blown o-ring on steering pump
# change out blown position tyre
# change out blown steering hose
# change out broken bolt on brake pump
# change out broken prelube bracket
# change out broken stabilizer bar
# change out cracked pipe on valve bank
# change out cracked position adaptor and tooth
# change out front upper window cracked
# change out leak slew motor hose
# change out leaking HMU on next
# change out leaking fan hoses
# change out leaking heater taps
# change out leaking hydraulic hose
# change out leaking implement pump
# change out leaking relay valve
# change out leaking steering hose
# change out left hand steering cylinder leaking
# change out position and tyre worn out
# change out position tyre sensor not reading
# change out position tyre damage
# change out unserviceable jacket water pump
# change out unserviceable left hand bucket cylinder hose
# change out unserviceable position tyre
# change out unserviceable right hand clam cylinder hose
# change out unserviceable right hand tilt cylinder
# change out unserviceable swing brake cylinder
# change out weeping boom cylinder hose
# change out worn position tyre
# change out leaking transmission hose
# change out position tyre worn
# change out blown hose
# change out broken grease lines
# change out leaking transmission hose
# change out number faulty injector assembly
# change out plugged fuel filters
# change out worn ripper tip ripper tip
# GET change out worn cutting edges
# Top words:
# out
# change
# hose
# leaking
# position
#
# Cluster 2 :
# air conditioner thermostat not working
# air conditioner thermostat unserviceable
# air conditioner unserviceable
# air conditioner unserviceable when stationary
# air conditioner warm
# air horn disconnected
# air horn does not work
# air horn fault
# air horn not working
# air horn not working compressor awaiting
# air horn stuck on
# air horn unserviceable
# air horn working intermittently
# air conditioner compressor corroded
# air conditioner compressor unserviceable
# air conditioner fault
# air conditioner no good
# air conditioner system leaking
# air horn not working
# air conditioner accessory drive leaking oil
# air conditioner belt broken
# air conditioner compressor not working
# air conditioner compressor tripping out
# air conditioner drive leaking
# air conditioner drive leaking oil
# air conditioner fan unserviceable fit new
# air conditioner fault
# air conditioner needs a boost not cold
# air conditioner not cold PO
# air conditioner not cold electrical faults
# air conditioner fan speed resistor not working and
# Top words:
# air
# conditioner
# not
# horn
# working
#
# Cluster 3 :
# cords cracked at and
# crack in blade liner left hand side
# crack in boom chord
# crack in fuel tank
# crack in headboard
# crack in lower centre of windscreen
# crack in windscreen
# cracked front window
# cracked fuel tank
# cracked hydraulic pipe
# cracked steering tank suction tube
# cracked suction tube
# cracks in back right hand side handrail
# cracks in decking
# cracks in diagonal braces in front
# cracks in fire suppression mounts
# cracks in headboard
# cracks in the dirt chute
# diagnose / repair slow steering
# diagnose and repair spray faults
# diagnose and repair torque converter temperature error
# repair cracks in mud bucket
# investigate and repair oil leak
# repair right hand fuel tank crack
# repair cracks on stick
# repair boom cracks left hand side
# investigate / repair no gear fault
# front window cracked replace
# diagnose and repair ladder fault
# repair centre hitch oil leaks
# investigate / repair joystick needs repair
# repair movement in left hand steering pin
# repair cracked steering tank mo
# stick cracks
# crack repairs left hand window frame
# diagnose / repair right hand scoreboard not working
# hole in door frame
# repair crack in right hand side of rear cross member
# repair crack in rear cross member
# repair crack on left hand front heat shield
# repair cracked baffle in hydraulic tank
# repair cracked roof skin left hand side exhaust
# repair cracks in mast cross braces
# replace cracked glass in entry door
# replace cracked water separator
# Top words:
# repair
# in
# cracked
# crack
# cracks
#
# Cluster 4 :
# airhorn not working
# alternator drive leaking
# alternator failed
# alternator not charging
# alternator overcharge fault
# alternator overcharged
# blown position tyre
# broken air conditioner guard
# broken clamp on crowd cylinder hose TBC
# broken fuel cooler mounts
# broken grease plug
# broken hinge
# broken joystick PO
# broken left hand side mirror
# broken mirror
# broken right hand side door window
# broken ripper tooth
# broken weld on handrail
# change position flat tyre
# change position tyre damage text
# cracked walkway and handrails
# damage to position tyre
# damaged position tyre
# damaged position tyre and rim
# dash broken
# replace faulty brake sensor task
# speedometer not working
# replace blown implement hose
# replace blown right hand steering hose
# crane not working
# replace oil leaks
# main isolator needs clean out
# replace damaged position tyre and position
# replace missing cutting edge
# replace x cracked windows
# position tyre blown
# replace damaged tyre on position
# replace damage auto-greaser door
# replace blown main pump hose
# replace cracked transmission dropbox
# replace position tyre damaged
# replace position tyre mismatched
# missing poppet valve
# no reception on AM / FM radio
# repair blown air conditioner hose
# replace blocked dryer
# replace blown hose
# replace blown work lights
# replace broken onside mirror
# replace cracked exhaust shield
# replace failed air conditioner compressor
# replace hydraulic oil leak text
# broken proximity sensor tag carousel
# broken wire on speaker
# collect broken tooth
# cracked power point in cabin
# ignition switch broken replace
# ignition switch sticking
# investigate main transformer overload fault
# key broken in ignition switch
# replace broken earth terminal
# replace chip indicators ( leaking )
# replace seized air conditioner control cable
# replace shorted diode RPC
# weightometer display on trailer unserviceable
# Top words:
# replace
# broken
# position
# tyre
# blown
#
# Cluster 5 :
# air leak
# air leak near side of door
# air leaking from line outside
# centrifugal oil filter fault
# centrifugal oil filter leaking
# coolant leak
# coolant leak at engine oil cooler
# coolant leak at jacket water pump
# differential leak
# differential oil leak
# dust leak operators side window
# oil leak at air compressor
# coolant leaking
# oil leak swingbox
# engine oil leaks right hand side
# repair oil leak position wheel end
# oil leak from behind water pump
# air leak
# coolant leak
# differential oil leak
# engine oil leak
# engine oil leak inspection plate
# exhaust leak
# fuel leak
# hose leak developing
# hydraulic oil leak from environmental
# oil leak pilot filter text
# engine oil blender running constantly
# oil centrifuge gasket leaking right hand engine
# oil leak at diverter valve
# oil leak inlet to oil burner cover plate
# Top words:
# leak
# oil
# engine
# air
# coolant
#
# Cluster 6 :
# Tele-Remote camera fault
# Tele-Remote cameras fault text
# Tele-Remote fault
# Tele-Remote faults
# Tele-Remote issues
# set-up Tele-Remote bogging
# Tele-Remote fault
# Top words:
# Tele-Remote
# fault
# camera
# cameras
# text
#
# Cluster 7 :
# analyse failed driveline component
# back rest unserviceable handle broken
# backhoe windscreen to be fixed
# backlight on dash unserviceable
# backlights on dash blown
# battery cover hinges seized
# blade wear plates cracked and worn
# bucket cracked in arch near cancelled
# carousel popped bolt needs Loctite
# change out exhaust clamp broken on left hand side [t |]
# coolant pipe clamps needs fitting TBC
# dragline air conditioner units need cleaning
# drivers window fault
# failed PTO and auxiliary drive PO
# fire extinguisher out of date
# hoist motor RTD wired incorrectly
# IOV fault on drag package
# all lighting requires testing and tagging
# front right hand roller need to be fitted
# fire extinguisher bracket on deck loose
# rear door struts require replacing
# mechanical PTO not meshing
# movement on steering column
# parts washer pump broken
# right hand bobbin roller unserviceable
# left hand side pinion change out cover cracking
# left hand rear brake cooling hose leaking
# front window roller blind broken
# PTO shaft requires replacing
# CW left hand hoist cylinder leaking plug
# CW radiator core leak
# CW right hand hoist cylinder leaking
# PTO shaft input seal leaking
# engine vibration <num>-<num> RPM
# front headlight blown
# fuel cap is missing
# hoist drum cracking
# left hand boom cylinder hose leaking PO
# left hand corner bonnet cracked
# left hand side boom foot crack repair
# modular does not self assign
# radiator relief valves leaking
# repair right hand track frame crack
# repaired x broken lines
# Bradken to repair broken clam
# CW PTO universal joint failed
# CW engine oil leaks x
# CW engine water pump snapped shaft
# PTO input seal leaking
# cabin smoke detector missing
# constant voltage transformer melted
# dry cell not working properly
# dust flap on cabin side of mast needs extending
# earth wire broken on bottom of radiator
# flag missing
# front lights keep blowing fuse
# left hand chain guide unserviceable
# left hand chain guide worn at the top
# left hand PTO pump chip sensor harness unserviceable
# glass window has large crack
# right hand PTO cavity emptying
# radiator blocked with grass
# radiator sight glasses unserviceable
# repair left hand scoreboard base cracked
# safety flag missing
# troubleshoot smart meter not communicating
# TV monitor does not turn on
# TV monitor has no signal
# window frame needs repair
# Top words:
# hand
# left
# on
# PTO
# broken
#
# Cluster 8 :
# air filters plugged
# alarm on VIMS does not work
# all dash lights on
# and lube system faults
# armrest unserviceable
# auto-greaser leaking oil
# auto-greaser unserviceable
# auto-lube error PO
# auto-spray feature not working
# axle temperature fault
# axle temperature sensor fault
# backup alarm not working
# batteries discharging
# batteries out of service
# batteries unserviceable
# beacon mount is broken
# beacon not working
# beacon unserviceable
# bearing on air conditioner compressor unserviceable
# bearings are shot
# belly plate bolt missing
# bent belly plate
# blade light blown needs replacing
# blade skin cracked
# blown air conditioner hose
# blown air conditioner hose to radiator
# blown brake hose
# blown crowd cylinder hose
# blown extension line from position
# blown hose in hitch
# blown hose on boom
# blown lift cylinder o-ring
# blown light on boom
# blown o-ring off steering hose
# blown o-ring on left hand lift cylinder
# blown o-ring on steering hose
# blown oil cooler hose x metre
# blown right hand bucket cylinder hose
# blown steering hose
# blown steering pump hose
# boarding gate hinge broken
# boarding gate latch not working
# boarding ladder not working
# both stick cylinders leaking
# brake cooling hose leaking
# brake cooling hose leaking rear
# brake cooling return hose leaking
# brake release fault
# brake temperature error
# cabin door window cracked
# cabin needs resealing
# cabin seals leaking dust PO
# cabin seals leaking dust bad
# cabin seat needs replacing
# cabin window needs resealing
# camera fault
# check / repair engine oil leak
# chord leaking air found
# chord pressure fault
# compressor oil pressure switch unserviceable
# contactor fault
# control valve unserviceable see long text
# coolant hose leaking at right hand bottom
# cooler return pipe coupling leak
# crack onside rock deflector
# crankcase error
# crowd cylinder creeping replace
# cutting edges loose
# cutting edges need change out
# diagnose engine fault
# diagnose transmission overheat fault
# diagnose transmission slipping fault
# differential cooler fan hose leaking
# differential cooler hose leaking
# differential cooler pump leaking
# differential lock broken
# differential lube pump leaking
# differential lube pump leaking PO
# differential pump motor hose leaking
# dogbone pin out
# drill out broken bolt see text
# driver's door top hinge broken
# duo-cone seals leaking number swing
# electrical harness fault
# ripper control valve falling off
# cable gantry crack repairs
# replace leaking transfer pipe
# drag tripped on electrical
# position brake temperature error
# front revolving light not working
# machine will not start
# possible minor leak on fuel tank
# rear steering accumulator leak
# grease pump unserviceable
# transmission fill / drain plug unserviceable
# bearing noisy
# oil found in revolving frame
# rear through shaft universal joint unserviceable
# repair leaking swing pedestal seals
# steering cylinder bearings have excess play
# movement found right hand engine mount
# rear wiper motor unserviceable
# replace transmission cracked
# park brake alarm sounds continuously
# system pump pressure gauge not working
# replace unserviceable differential drain plugs
# grease pump is bypassing air
# park brake alarm fault
# handrail above battery box cracked
# VIMS keypad light out
# investigate engine oil leak
# replace right hand lift cylinder leaking
# ground fault welding board
# grease gauges requires replacing
# swing brake pressure fault
# replace leaking scavenge pump
# tail pulley has no grease lines
# ground fault in propel
# drag generator fault
# middle air drain tap leaking
# grease system fault
# investigate auto-lube fault
# brake warning light on
# leaking brake cooling hose
# faulty fuel pressure sensor
# bottom steering shaft universal joint worn
# repair brake fault
# synchronous motor trip
# walk motor brake fault
# tray fault
# fitting leaking out of main air tanks
# steering hub caps require replacing
# bulk fuel tank cracked and leaking
# hydraulic hose leaking in centre of machine
# swing resolver not counting
# repair gear fault
# repair air conditioner and wiring fault
# swing resolver fault
# drag chain fault
# headboard welds broken / cracked
# inspect bad engine oil leak
# hoist brake switches need adjusting
# cabin jacking cylinder ends unserviceable
# park brake indicator light going on and off
# tracks need adjusting
# no excitation on hoist
# cabin seat unserviceable needs replacing
# diagnose VIMS error
# repair exhaust leaks
# stick cylinder leaking
# hoist brake number position out of adjustment
# AM / FM radio needs new aerial
# HMU hose weeping
# brake hose needs to be replaced
# differential lube hose leaking
# emergency gate latch broken
# engine bay light blown
# engine fan hose weeping
# engine overheating
# engine shutdown fault
# fan hose leaking
# fuel breather missing
# grease system fail
# grease system fault
# investigate torque converter fan pump oil leak
# ladder fault
# lower left hand headlight blown
# lube fault
# minor transmission oil leak
# noisy hydraulic lift cylinder
# operators seat worn padding
# park brake fault
# rear steering accumulator leaking
# repair engine oil leak and
# repair engine oil leaking
# repair leaking centrifugal filter
# repair transmission fault
# replace leaking steering cylinder
# replaced leaking steering hose
# ripper shank broken
# transmission charge hose leaking
# chord is leaking air from crack
# engine shutdown fault
# grease system has intermittent fault
# repair engine oil leak text
# repair transmission oil leak text
# steering pin no grease text
# transmission temperature fault
# injector error
# CW top radiator tank leak again
# CW transmission failed
# VIMS fuel filter plugged
# adaptor leaking at implement valve
# aftercooler tank gauge broken
# aftercooler temperature error
# air conditioner pressure switch unserviceable
# number right hand air brake line needs replacing
# [ shutdown ] vinyl flooring unserviceable
# air brake line blown requires replacing
# air pressure safety valve exhausting
# batteries have no charge
# battery unserviceable dropped cell replace
# blade control cable tight
# blown air conditioner fuse
# cabin side weightometer not working
# centrifuge hose leaking replace
# compressor safety valve leaking
# contamination alarm coming up
# contamination alarm on
# depth counter unserviceable
# <sensitive> depth counter not working
# electric propel siren not working
# equipment damaged ( terminal box )
# flow battery power
# fuel filter water separator housing broken
# generator flow regulator unserviceable
# grease distributor leaking
# heat up locked steels
# heater hose in cabin roof unserviceable
# high voltage slip ring inspection grease leak
# inverter earthing out
# keeps blowing starter / horn fuse
# microwave oven unserviceable
# number pump contamination switch on
# number slew pump contamination switch unserviceable
# position pressure compensator weeping
# position chip sensor alarm
# pilot valve leaking oil
# position pump cavity low
# power step control cable broken
# pressure compensator leaking
# pressure control valve in cabin leaking
# pump drive box coupling and shaft unserviceable
# remove unserviceable air separator
# repair air leak at air tank safety valve
# repair chassis crack at right hand rear cross member
# repair faulty safety valve
# repair leak in pilot valve solenoid
# repair worn centrifuge filter
# replace unserviceable grease distributor
# replace unserviceable chip indicators
# replace unserviceable ignition switch
# replace unserviceable transmission screen and magnet
# rock breaker cracked
# rock breaker in bucket cracked at base
# siren unserviceable
# slip ring overgreasing
# start motorvator and set limits
# transformer trip
# voltage regulator fuse fault
# water separator filter leaking see photo
# water separator leaking fuel
# will not start batteries unserviceable
# wiper fuse unserviceable
# Top words:
# leaking
# fault
# unserviceable
# hose
# blown

# %% [markdown]
# ### centroid clustering

# %%
linkage_data = linkage(cluster_embeddings, method='centroid')
fig = plt.figure(figsize=(25, 10))
dn = dendrogram(linkage_data)
plt.show()

# %%
k=8
cluster_labels = fcluster(linkage_data, k, criterion='maxclust')
for i in range(1,k+1):
    print("Cluster",i,":")
    cluster_words = {}
    for j in range(len(cluster_labels)):
        if cluster_labels[j]==i:
            print(" ".join(dataset_not_padded[j]))
            for word in dataset_not_padded[j]:
                if word in cluster_words:
                    cluster_words[word]+=1
                else:
                    cluster_words[word]=1
    print("Top words:")
    sorted_cluster_words = sorted(cluster_words, key=cluster_words.get, reverse=True)
    for j in range(min(len(sorted_cluster_words), 5)):
        print(sorted_cluster_words[j])
    print()
# Out:
# Cluster 1 :
# air leak
# air leak
# Top words:
# air
# leak
#
# Cluster 2 :
# blown position tyre
# change out blown position tyre
# change out cracked position adaptor and tooth
# change out position and tyre worn out
# change out position tyre sensor not reading
# change out position tyre damage
# change out unserviceable position tyre
# change out worn position tyre
# change position flat tyre
# change position tyre damage text
# damage to position tyre
# damaged position tyre
# damaged position tyre and rim
# replace damaged position tyre and position
# position tyre blown
# replace damaged tyre on position
# change out position tyre worn
# replace position tyre damaged
# replace position tyre mismatched
# Top words:
# position
# tyre
# change
# out
# damaged
#
# Cluster 3 :
# change out broken prelube bracket
# change out broken stabilizer bar
# Top words:
# change
# out
# broken
# prelube
# bracket
#
# Cluster 4 :
# air conditioner thermostat not working
# air conditioner thermostat unserviceable
# air conditioner unserviceable
# air conditioner unserviceable when stationary
# air conditioner warm
# air filters plugged
# air horn disconnected
# air horn does not work
# air horn not working
# air horn not working compressor awaiting
# air horn stuck on
# air horn unserviceable
# air horn working intermittently
# bearing on air conditioner compressor unserviceable
# blown air conditioner hose
# broken air conditioner guard
# dragline air conditioner units need cleaning
# air conditioner compressor corroded
# air conditioner compressor unserviceable
# air conditioner no good
# air horn not working
# replace failed air conditioner compressor
# air conditioner belt broken
# air conditioner compressor not working
# air conditioner compressor tripping out
# air conditioner fan unserviceable fit new
# air conditioner needs a boost not cold
# air conditioner not cold PO
# air conditioner not cold electrical faults
# air conditioner pressure switch unserviceable
# air conditioner fan speed resistor not working and
# blown air conditioner fuse
# remove unserviceable air separator
# replace seized air conditioner control cable
# Top words:
# air
# conditioner
# not
# unserviceable
# horn
#
# Cluster 5 :
# air leak near side of door
# air leaking from line outside
# airhorn not working
# alarm on VIMS does not work
# all dash lights on
# alternator drive leaking
# alternator failed
# alternator not charging
# alternator overcharged
# analyse failed driveline component
# armrest unserviceable
# auto-greaser leaking oil
# auto-greaser unserviceable
# auto-lube error PO
# auto-spray feature not working
# back rest unserviceable handle broken
# backhoe windscreen to be fixed
# backlight on dash unserviceable
# backlights on dash blown
# backup alarm not working
# batteries discharging
# batteries out of service
# batteries unserviceable
# battery cover hinges seized
# beacon mount is broken
# beacon not working
# beacon unserviceable
# bearings are shot
# belly plate bolt missing
# bent belly plate
# blade light blown needs replacing
# blade skin cracked
# blade wear plates cracked and worn
# blown air conditioner hose to radiator
# blown brake hose
# blown crowd cylinder hose
# blown extension line from position
# blown hose in hitch
# blown hose on boom
# blown lift cylinder o-ring
# blown light on boom
# blown o-ring off steering hose
# blown o-ring on left hand lift cylinder
# blown o-ring on steering hose
# blown oil cooler hose x metre
# blown right hand bucket cylinder hose
# blown steering hose
# blown steering pump hose
# boarding gate hinge broken
# boarding gate latch not working
# boarding ladder not working
# both stick cylinders leaking
# brake cooling hose leaking
# brake cooling hose leaking rear
# brake cooling return hose leaking
# brake temperature error
# broken clamp on crowd cylinder hose TBC
# broken fuel cooler mounts
# broken grease plug
# broken hinge
# broken joystick PO
# broken left hand side mirror
# broken mirror
# broken right hand side door window
# broken ripper tooth
# broken weld on handrail
# bucket cracked in arch near cancelled
# cabin door window cracked
# cabin needs resealing
# cabin seals leaking dust PO
# cabin seals leaking dust bad
# cabin seat needs replacing
# cabin window needs resealing
# carousel popped bolt needs Loctite
# centrifugal oil filter fault
# centrifugal oil filter leaking
# change out blown o-ring on steering pump
# change out blown steering hose
# change out broken bolt on brake pump
# change out cracked pipe on valve bank
# change out exhaust clamp broken on left hand side [t |]
# change out front upper window cracked
# change out leak slew motor hose
# change out leaking HMU on next
# change out leaking fan hoses
# change out leaking heater taps
# change out leaking hydraulic hose
# change out leaking implement pump
# change out leaking relay valve
# change out leaking steering hose
# change out left hand steering cylinder leaking
# change out unserviceable jacket water pump
# change out unserviceable left hand bucket cylinder hose
# change out unserviceable right hand clam cylinder hose
# change out unserviceable right hand tilt cylinder
# change out unserviceable swing brake cylinder
# change out weeping boom cylinder hose
# check / repair engine oil leak
# chord leaking air found
# compressor oil pressure switch unserviceable
# control valve unserviceable see long text
# coolant hose leaking at right hand bottom
# coolant leak
# coolant leak at engine oil cooler
# coolant leak at jacket water pump
# coolant pipe clamps needs fitting TBC
# cooler return pipe coupling leak
# cords cracked at and
# crack in blade liner left hand side
# crack in boom chord
# crack in fuel tank
# crack in headboard
# crack in lower centre of windscreen
# crack in windscreen
# crack onside rock deflector
# cracked front window
# cracked fuel tank
# cracked hydraulic pipe
# cracked steering tank suction tube
# cracked suction tube
# cracked walkway and handrails
# cracks in back right hand side handrail
# cracks in decking
# cracks in diagonal braces in front
# cracks in fire suppression mounts
# cracks in headboard
# cracks in the dirt chute
# crankcase error
# crowd cylinder creeping replace
# cutting edges loose
# cutting edges need change out
# dash broken
# diagnose / repair slow steering
# diagnose and repair spray faults
# diagnose and repair torque converter temperature error
# differential cooler fan hose leaking
# differential cooler hose leaking
# differential cooler pump leaking
# differential leak
# differential lock broken
# differential lube pump leaking
# differential lube pump leaking PO
# differential oil leak
# differential pump motor hose leaking
# dogbone pin out
# drill out broken bolt see text
# driver's door top hinge broken
# duo-cone seals leaking number swing
# dust leak operators side window
# ripper control valve falling off
# repair cracks in mud bucket
# replace faulty brake sensor task
# speedometer not working
# cable gantry crack repairs
# failed PTO and auxiliary drive PO
# replace leaking transfer pipe
# drag tripped on electrical
# position brake temperature error
# front revolving light not working
# fire extinguisher out of date
# hoist motor RTD wired incorrectly
# machine will not start
# possible minor leak on fuel tank
# replace blown implement hose
# rear steering accumulator leak
# replace blown right hand steering hose
# crane not working
# grease pump unserviceable
# transmission fill / drain plug unserviceable
# bearing noisy
# oil found in revolving frame
# replace oil leaks
# IOV fault on drag package
# rear through shaft universal joint unserviceable
# repair leaking swing pedestal seals
# all lighting requires testing and tagging
# steering cylinder bearings have excess play
# movement found right hand engine mount
# rear wiper motor unserviceable
# front right hand roller need to be fitted
# main isolator needs clean out
# replace transmission cracked
# investigate and repair oil leak
# park brake alarm sounds continuously
# system pump pressure gauge not working
# replace unserviceable differential drain plugs
# repair right hand fuel tank crack
# grease pump is bypassing air
# park brake alarm fault
# repair cracks on stick
# repair boom cracks left hand side
# investigate / repair no gear fault
# handrail above battery box cracked
# front window cracked replace
# VIMS keypad light out
# investigate engine oil leak
# replace right hand lift cylinder leaking
# grease gauges requires replacing
# fire extinguisher bracket on deck loose
# rear door struts require replacing
# mechanical PTO not meshing
# oil leak at air compressor
# replace leaking scavenge pump
# coolant leaking
# change out leaking transmission hose
# tail pulley has no grease lines
# replace missing cutting edge
# movement on steering column
# oil leak swingbox
# replace x cracked windows
# parts washer pump broken
# middle air drain tap leaking
# engine oil leaks right hand side
# brake warning light on
# leaking brake cooling hose
# faulty fuel pressure sensor
# bottom steering shaft universal joint worn
# right hand bobbin roller unserviceable
# synchronous motor trip
# left hand side pinion change out cover cracking
# walk motor brake fault
# left hand rear brake cooling hose leaking
# fitting leaking out of main air tanks
# repair centre hitch oil leaks
# repair oil leak position wheel end
# steering hub caps require replacing
# bulk fuel tank cracked and leaking
# hydraulic hose leaking in centre of machine
# swing resolver not counting
# repair air conditioner and wiring fault
# replace damage auto-greaser door
# investigate / repair joystick needs repair
# headboard welds broken / cracked
# inspect bad engine oil leak
# hoist brake switches need adjusting
# cabin jacking cylinder ends unserviceable
# repair movement in left hand steering pin
# replace blown main pump hose
# park brake indicator light going on and off
# tracks need adjusting
# replace cracked transmission dropbox
# no excitation on hoist
# front window roller blind broken
# cabin seat unserviceable needs replacing
# diagnose VIMS error
# oil leak from behind water pump
# repair exhaust leaks
# stick cylinder leaking
# hoist brake number position out of adjustment
# PTO shaft requires replacing
# missing poppet valve
# AM / FM radio needs new aerial
# CW left hand hoist cylinder leaking plug
# CW radiator core leak
# CW right hand hoist cylinder leaking
# HMU hose weeping
# PTO shaft input seal leaking
# air conditioner system leaking
# brake hose needs to be replaced
# change out blown hose
# change out broken grease lines
# change out leaking transmission hose
# change out number faulty injector assembly
# change out plugged fuel filters
# change out worn ripper tip ripper tip
# coolant leak
# differential lube hose leaking
# differential oil leak
# emergency gate latch broken
# engine bay light blown
# engine fan hose weeping
# engine oil leak
# engine oil leak inspection plate
# engine overheating
# engine vibration <num>-<num> RPM
# exhaust leak
# fan hose leaking
# front headlight blown
# fuel breather missing
# fuel cap is missing
# fuel leak
# hoist drum cracking
# hydraulic oil leak from environmental
# investigate torque converter fan pump oil leak
# left hand boom cylinder hose leaking PO
# left hand corner bonnet cracked
# left hand side boom foot crack repair
# lower left hand headlight blown
# minor transmission oil leak
# modular does not self assign
# no reception on AM / FM radio
# noisy hydraulic lift cylinder
# operators seat worn padding
# radiator relief valves leaking
# rear steering accumulator leaking
# repair blown air conditioner hose
# repair cracked steering tank mo
# repair engine oil leak and
# repair engine oil leaking
# repair leaking centrifugal filter
# repair right hand track frame crack
# repaired x broken lines
# replace blocked dryer
# replace blown hose
# replace blown work lights
# replace broken onside mirror
# replace cracked exhaust shield
# replace leaking steering cylinder
# replaced leaking steering hose
# ripper shank broken
# stick cracks
# transmission charge hose leaking
# chord is leaking air from crack
# oil leak pilot filter text
# repair engine oil leak text
# repair transmission oil leak text
# replace hydraulic oil leak text
# steering pin no grease text
# injector error
# Bradken to repair broken clam
# CW PTO universal joint failed
# CW engine oil leaks x
# CW engine water pump snapped shaft
# CW top radiator tank leak again
# CW transmission failed
# GET change out worn cutting edges
# PTO input seal leaking
# VIMS fuel filter plugged
# adaptor leaking at implement valve
# aftercooler tank gauge broken
# aftercooler temperature error
# air conditioner accessory drive leaking oil
# air conditioner drive leaking
# air conditioner drive leaking oil
# number right hand air brake line needs replacing
# [ shutdown ] vinyl flooring unserviceable
# air brake line blown requires replacing
# air pressure safety valve exhausting
# batteries have no charge
# battery unserviceable dropped cell replace
# blade control cable tight
# broken proximity sensor tag carousel
# broken wire on speaker
# cabin side weightometer not working
# cabin smoke detector missing
# centrifuge hose leaking replace
# collect broken tooth
# compressor safety valve leaking
# constant voltage transformer melted
# contamination alarm coming up
# contamination alarm on
# crack repairs left hand window frame
# cracked power point in cabin
# dry cell not working properly
# depth counter unserviceable
# diagnose / repair right hand scoreboard not working
# <sensitive> depth counter not working
# dust flap on cabin side of mast needs extending
# electric propel siren not working
# earth wire broken on bottom of radiator
# engine oil blender running constantly
# equipment damaged ( terminal box )
# flag missing
# flow battery power
# front lights keep blowing fuse
# fuel filter water separator housing broken
# generator flow regulator unserviceable
# grease distributor leaking
# heat up locked steels
# heater hose in cabin roof unserviceable
# hole in door frame
# high voltage slip ring inspection grease leak
# ignition switch broken replace
# ignition switch sticking
# inverter earthing out
# investigate main transformer overload fault
# keeps blowing starter / horn fuse
# key broken in ignition switch
# left hand chain guide unserviceable
# left hand chain guide worn at the top
# left hand PTO pump chip sensor harness unserviceable
# microwave oven unserviceable
# number pump contamination switch on
# number slew pump contamination switch unserviceable
# oil centrifuge gasket leaking right hand engine
# oil leak at diverter valve
# oil leak inlet to oil burner cover plate
# glass window has large crack
# position pressure compensator weeping
# position chip sensor alarm
# pilot valve leaking oil
# position pump cavity low
# power step control cable broken
# pressure compensator leaking
# pressure control valve in cabin leaking
# pump drive box coupling and shaft unserviceable
# right hand PTO cavity emptying
# radiator blocked with grass
# radiator sight glasses unserviceable
# repair crack in right hand side of rear cross member
# repair air leak at air tank safety valve
# repair chassis crack at right hand rear cross member
# repair crack in rear cross member
# repair crack on left hand front heat shield
# repair cracked baffle in hydraulic tank
# repair cracked roof skin left hand side exhaust
# repair cracks in mast cross braces
# repair faulty safety valve
# repair left hand scoreboard base cracked
# repair leak in pilot valve solenoid
# repair worn centrifuge filter
# replace broken earth terminal
# replace chip indicators ( leaking )
# replace cracked glass in entry door
# replace cracked water separator
# replace shorted diode RPC
# replace unserviceable grease distributor
# replace unserviceable chip indicators
# replace unserviceable ignition switch
# replace unserviceable transmission screen and magnet
# rock breaker cracked
# rock breaker in bucket cracked at base
# safety flag missing
# siren unserviceable
# slip ring overgreasing
# start motorvator and set limits
# troubleshoot smart meter not communicating
# transformer trip
# TV monitor does not turn on
# TV monitor has no signal
# voltage regulator fuse fault
# water separator filter leaking see photo
# water separator leaking fuel
# weightometer display on trailer unserviceable
# will not start batteries unserviceable
# window frame needs repair
# wiper fuse unserviceable
# Top words:
# leaking
# hose
# hand
# repair
# leak
#
# Cluster 6 :
# air horn fault
# air conditioner fault
# air conditioner fault
# Top words:
# air
# fault
# conditioner
# horn
#
# Cluster 7 :
# alternator overcharge fault
# and lube system faults
# axle temperature fault
# axle temperature sensor fault
# brake release fault
# camera fault
# chord pressure fault
# contactor fault
# diagnose engine fault
# diagnose transmission overheat fault
# diagnose transmission slipping fault
# drivers window fault
# electrical harness fault
# diagnose and repair ladder fault
# ground fault welding board
# swing brake pressure fault
# ground fault in propel
# drag generator fault
# grease system fault
# investigate auto-lube fault
# repair brake fault
# tray fault
# repair gear fault
# swing resolver fault
# drag chain fault
# Tele-Remote camera fault
# Tele-Remote cameras fault text
# Tele-Remote fault
# Tele-Remote faults
# Tele-Remote issues
# engine shutdown fault
# grease system fail
# grease system fault
# ladder fault
# lube fault
# park brake fault
# repair transmission fault
# set-up Tele-Remote bogging
# engine shutdown fault
# grease system has intermittent fault
# transmission temperature fault
# Tele-Remote fault
# Top words:
# fault
# Tele-Remote
# system
# brake
# diagnose
#
# Cluster 8 :
# hose leak developing
# Top words:
# hose
# leak
# developing

# %% [markdown]
# # Inherent Function dataset

# %% [markdown]
# ## CNN

# %%
dataset2 = full_dataset_append_inherent_functions("../data/gold_release.json")
print(dataset2)
pad_sequence(dataset2)
print(len(dataset2))
# Out:
# [['air', 'conditioner', 'thermostat', 'not', 'working', 'emitting', 'sensing'], ['air', 'conditioner', 'thermostat', 'unserviceable', 'emitting', 'sensing'], ['air', 'conditioner', 'unserviceable', 'emitting'], ['air', 'conditioner', 'unserviceable', 'when', 'stationary', 'emitting'], ['air', 'conditioner', 'warm', 'emitting'], ['air', 'filters', 'plugged', 'matterprocessing'], ['air', 'horn', 'disconnected', 'presenting'], ['air', 'horn', 'does', 'not', 'work', 'presenting'], ['air', 'horn', 'fault', 'presenting'], ['air', 'horn', 'not', 'working', 'presenting'], ['air', 'horn', 'not', 'working', 'compressor', 'awaiting', 'presenting', 'generating'], ['air', 'horn', 'stuck', 'on', 'presenting'], ['air', 'horn', 'unserviceable', 'presenting'], ['air', 'horn', 'working', 'intermittently', 'presenting'], ['air', 'leak'], ['air', 'leak', 'near', 'side', 'of', 'door', 'controlling'], ['air', 'leaking', 'from', 'line', 'outside', 'guiding'], ['airhorn', 'not', 'working', 'presenting'], ['alarm', 'on', 'VIMS', 'does', 'not', 'work', 'presenting'], ['all', 'dash', 'lights', 'on', 'emitting'], ['alternator', 'drive', 'leaking', 'driving', 'generating'], ['alternator', 'failed', 'generating'], ['alternator', 'not', 'charging', 'generating'], ['alternator', 'overcharge', 'fault', 'generating'], ['alternator', 'overcharged', 'generating'], ['analyse', 'failed', 'driveline', 'component', 'transforming'], ['and', 'lube', 'system', 'faults', 'protecting'], ['armrest', 'unserviceable', 'storing'], ['auto-greaser', 'leaking', 'oil', 'generating', 'protecting'], ['auto-greaser', 'unserviceable', 'generating'], ['auto-lube', 'error', 'PO', 'generating'], ['auto-spray', 'feature', 'not', 'working', 'generating'], ['axle', 'temperature', 'fault', 'transforming'], ['axle', 'temperature', 'sensor', 'fault', 'sensing', 'transforming'], ['back', 'rest', 'unserviceable', 'handle', 'broken', 'humaninteraction', 'storing'], ['backhoe', 'windscreen', 'to', 'be', 'fixed', 'controlling', 'matterprocessing'], ['backlight', 'on', 'dash', 'unserviceable', 'emitting', 'presenting'], ['backlights', 'on', 'dash', 'blown', 'emitting', 'presenting'], ['backup', 'alarm', 'not', 'working', 'presenting'], ['batteries', 'discharging', 'generating'], ['batteries', 'out', 'of', 'service', 'generating'], ['batteries', 'unserviceable', 'generating'], ['battery', 'cover', 'hinges', 'seized', 'generating', 'covering', 'holding'], ['beacon', 'mount', 'is', 'broken', 'holding', 'emitting'], ['beacon', 'not', 'working', 'emitting'], ['beacon', 'unserviceable', 'emitting'], ['bearing', 'on', 'air', 'conditioner', 'compressor', 'unserviceable', 'holding', 'emitting', 'generating'], ['bearings', 'are', 'shot', 'holding'], ['belly', 'plate', 'bolt', 'missing', 'holding'], ['bent', 'belly', 'plate', 'holding'], ['blade', 'light', 'blown', 'needs', 'replacing', 'emitting', 'matterprocessing'], ['blade', 'skin', 'cracked', 'protecting', 'matterprocessing'], ['blade', 'wear', 'plates', 'cracked', 'and', 'worn', 'matterprocessing', 'protecting'], ['blown', 'air', 'conditioner', 'hose', 'emitting', 'guiding'], ['blown', 'air', 'conditioner', 'hose', 'to', 'radiator', 'emitting', 'guiding'], ['blown', 'brake', 'hose', 'restricting', 'guiding'], ['blown', 'crowd', 'cylinder', 'hose', 'driving', 'guiding'], ['blown', 'extension', 'line', 'from', 'position', 'guiding'], ['blown', 'hose', 'in', 'hitch', 'guiding', 'interfacing'], ['blown', 'hose', 'on', 'boom', 'guiding', 'holding'], ['blown', 'lift', 'cylinder', 'o-ring', 'driving', 'covering'], ['blown', 'light', 'on', 'boom', 'emitting', 'holding'], ['blown', 'o-ring', 'off', 'steering', 'hose', 'guiding', 'covering', 'controlling'], ['blown', 'o-ring', 'on', 'left', 'hand', 'lift', 'cylinder', 'driving', 'covering'], ['blown', 'o-ring', 'on', 'steering', 'hose', 'guiding', 'covering', 'controlling'], ['blown', 'oil', 'cooler', 'hose', 'x', 'metre', 'emitting', 'guiding'], ['blown', 'position', 'tyre', 'guiding'], ['blown', 'right', 'hand ...
# max length of MWO: 13
# 540

# %%
# Word2Vec embeddings as input
w2vmodel = gensim.models.Word2Vec(dataset2, min_count=1, vector_size=100,
                                window=5, sg=1)
w2v_embeddings = []
for sentence in dataset2:
    row = []
    for word in sentence:
        row.append(w2vmodel.wv[word])
    w2v_embeddings.append(row)
w2v_embeddings = np.array(w2v_embeddings)

# %%
print(w2v_embeddings.shape)
shape = w2v_embeddings.shape
w2v_embeddings=w2v_embeddings.reshape(shape[0], shape[1], shape[2], 1)
print(w2v_embeddings.shape)
# Out:
# (540, 13, 100)
# (540, 13, 100, 1)

# %%
# LSI embeddings as output
dictionary = gensim.corpora.Dictionary(dataset2)
doc_term_matrix = [dictionary.doc2bow(doc) for doc in dataset2]
lsamodel = LsiModel(doc_term_matrix, num_topics=10, id2word = dictionary)  # train model
concepts = list(lsamodel[doc_term_matrix])
lsa_embeddings=[]
for i in concepts:
    row = []
    for j in i:
        row.append(j[1])
    lsa_embeddings.append(row)
lsa_embeddings = np.array(lsa_embeddings)

# %%
print(lsa_embeddings.shape)
print(lsa_embeddings)
# Out:
# (540, 10)
# [[ 2.10364807e+00 -2.56512535e+00 -1.42459024e+00 ...  1.37429693e-03
#    1.12118309e-01  1.73611628e-01]
#  [ 2.65503843e+00 -2.94509307e+00 -1.62368501e+00 ... -3.93381669e-01
#   -4.44127283e-01  5.56356956e-01]
#  [ 3.59692754e+00 -4.02874286e+00 -2.32153931e+00 ... -2.47619951e-01
#   -6.66404144e-01  7.32072403e-01]
#  ...
#  [ 5.99200316e-01 -4.08415225e-01 -3.19278322e-01 ... -6.12760598e-01
#   -8.33024082e-01  3.54166374e-01]
#  [ 6.09743102e-01  2.23694414e-01  7.05402237e-01 ...  8.15732583e-01
#   -4.97529397e-01  7.42482719e-01]
#  [ 1.06821125e+00 -3.32858201e-01  6.76353584e-01 ... -1.07168947e+00
#   -9.72885835e-01  2.00783291e-01]]

# %%
dr = 10
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(16, (2, 2), activation='relu', padding="same", input_shape=(13,100,1)),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.Conv2D(8, (2, 2), activation='relu', padding="same"),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=dr, activation="tanh"),
    tf.keras.layers.Dense(units=10, activation="tanh")
])
# Out:
# /opt/miniconda3/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_20 (Conv2D)              │ (None, 13, 100, 16)    │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 6, 50, 16)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)              │ (None, 6, 50, 8)       │           520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_10 (Flatten)            │ (None, 2400)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None,
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.metrics import silhouette_score


# PCA reduction
pca = PCA(n_components=2)
pca_embedding = pca.fit_transform(cluster_embeddings)
plt.scatter(pca_embedding[:,0], pca_embedding[:,1])
plt.title("PCA")
plt.show()

# tsne reduction
tsne = TSNE(n_components=2).fit_transform(cluster_embeddings)
plt.scatter(tsne[:,0], tsne[:,1])
plt.title("TSNE")
plt.show()


# Perform kmean clustering
silhouette_scores = []
test_k = list(range(5, 105, 5))
for i in test_k:
    print(i, "/", 100)
    kmeans = KMeans(n_clusters=i, random_state=42, n_init=100).fit(cluster_embeddings)
    labels = kmeans.labels_
    silhouette_scores.append(silhouette_score(cluster_embeddings, labels))
plt.plot(test_k, silhouette_scores)
plt.title("Silhouette Scores")
plt.show()

# %%
# best k
k = 25
kmeans = KMeans(n_clusters=k, random_state=42, n_init=100).fit(cluster_embeddings)
labels = kmeans.labels_

for i in range(k):
    print("Cluster ", i)
    for j in range(len(labels)):
        if labels[j] == i:
            print(dataset_not_padded[j])
            
    print()
# Out:
# Cluster  0
# ['differential', 'leak']
# ['differential', 'oil', 'leak']
# ['replace', 'oil', 'leaks']
# ['oil', 'leak', 'swingbox']
# ['differential', 'oil', 'leak']
# ['fuel', 'leak']
# ['minor', 'transmission', 'oil', 'leak']
# ['oil', 'leak', 'pilot', 'filter', 'text']
# ['repair', 'transmission', 'oil', 'leak', 'text']
# ['replace', 'hydraulic', 'oil', 'leak', 'text']
# ['oil', 'leak', 'at', 'diverter', 'valve']
#
# Cluster  1
# ['all', 'dash', 'lights', 'on']
# ['backlight', 'on', 'dash', 'unserviceable']
# ['beacon', 'unserviceable']
# ['microwave', 'oven', 'unserviceable']
# ['radiator', 'sight', 'glasses', 'unserviceable']
# ['siren', 'unserviceable']
# ['weightometer', 'display', 'on', 'trailer', 'unserviceable']
#
# Cluster  2
# ['replace', 'broken', 'onside', 'mirror']
# ['replace', 'broken', 'earth', 'terminal']
#
# Cluster  3
# ['blade', 'skin', 'cracked']
# ['crack', 'onside', 'rock', 'deflector']
# ['dust', 'leak', 'operators', 'side', 'window']
# ['handrail', 'above', 'battery', 'box', 'cracked']
# ['faulty', 'fuel', 'pressure', 'sensor']
# ['fuel', 'cap', 'is', 'missing']
# ['steering', 'pin', 'no', 'grease', 'text']
# ['replace', 'unserviceable', 'grease', 'distributor']
# ['wiper', 'fuse', 'unserviceable']
#
# Cluster  4
# ['change', 'out', 'position', 'and', 'tyre', 'worn', 'out']
# ['change', 'out', 'position', 'tyre', 'sensor', 'not', 'reading']
# ['change', 'out', 'position', 'tyre', 'damage']
# ['change', 'out', 'unserviceable', 'position', 'tyre']
# ['change', 'out', 'worn', 'position', 'tyre']
# ['change', 'out', 'position', 'tyre', 'worn']
# ['change', 'out', 'blown', 'hose']
#
# Cluster  5
# ['crack', 'in', 'windscreen']
# ['cracks', 'in', 'back', 'right', 'hand', 'side', 'handrail']
# ['cracks', 'in', 'diagonal', 'braces', 'in', 'front']
# ['repair', 'cracks', 'in', 'mud', 'bucket']
# ['bearing', 'noisy']
# ['repair', 'boom', 'cracks', 'left', 'hand', 'side']
# ['repair', 'movement', 'in', 'left', 'hand', 'steering', 'pin']
# ['repair', 'right', 'hand', 'track', 'frame', 'crack']
# ['repair', 'crack', 'in', 'right', 'hand', 'side', 'of', 'rear', 'cross', 'member']
# ['repair', 'crack', 'in', 'rear', 'cross', 'member']
# ['repair', 'cracks', 'in', 'mast', 'cross', 'braces']
#
# Cluster  6
# ['alternator', 'drive', 'leaking']
# ['differential', 'pump', 'motor', 'hose', 'leaking']
# ['engine', 'fan', 'hose', 'weeping']
# ['CW', 'engine', 'water', 'pump', 'snapped', 'shaft']
#
# Cluster  7
# ['Tele-Remote', 'camera', 'fault']
# ['Tele-Remote', 'fault']
# ['Tele-Remote', 'faults']
# ['Tele-Remote', 'issues']
# ['set-up', 'Tele-Remote', 'bogging']
# ['Tele-Remote', 'fault']
#
# Cluster  8
# ['axle', 'temperature', 'fault']
# ['diagnose', 'transmission', 'overheat', 'fault']
# ['diagnose', 'transmission', 'slipping', 'fault']
# ['transmission', 'temperature', 'fault']
# ['investigate', 'main', 'transformer', 'overload', 'fault']
#
# Cluster  9
# ['front', 'headlight', 'blown']
#
# Cluster  10
# ['grease', 'system', 'fault']
# ['grease', 'system', 'fail']
# ['grease', 'system', 'fault']
# ['grease', 'system', 'has', 'intermittent', 'fault']
#
# Cluster  11
# ['battery', 'cover', 'hinges', 'seized']
# ['control', 'valve', 'unserviceable', 'see', 'long', 'text']
# ['failed', 'PTO', 'and', 'auxiliary', 'drive', 'PO']
# ['rear', 'wiper', 'motor', 'unserviceable']
# ['steering', 'hub', 'caps', 'require', 'replacing']
# ['AM', '/', 'FM', 'radio', 'needs', 'new', 'aerial']
# ['flow', 'battery', 'power']
# ['left', 'hand', 'PTO', 'pump', 'chip', 'sensor', 'harness', 'unserviceable']
# ['TV', 'monitor', 'has', 'no', 'signal']
#
# Cluster  12
# ['brake', 'temperature', 'error']
# ['position', 'brake', 'temperature', 'error']
# ['hoist', 'brake', 'number', 'position', 'out', 'of', 'adjustment']
#
# Cluster  13
# ['air', 'conditioner', 'system', 'leaking']
# ['air', 'conditioner', 'accessory', 'drive', 'leaking', 'oil']
# ['air', 'conditioner', 'drive', 'leaking']
# ['blown', 'air', 'conditioner', 'fuse']
#
# Cluster  14
# ['change', 'out', 'cracked', 'pipe', 'on', 'valve', 'bank']
# ['change', 'out', 'broken', 'grease', 'lines']
# ['change', 'out', 'plugged', 'fuel', 'filters']
# ['change', 'out', 'worn', 'ripper', 'tip', 'ripper', 'tip']
# ['GET', 'change', 'out', 'worn', 'cutting', 'edges']
# ['inverter', 'earthing', 'out']
#
# Cluster  15
# ['batteries', 'discharging']
# ['batteries', 'unserviceable']
# ['injector', 'error']
#
# Cluster  16
# ['blown', 'steering', 'pump', 'hose']
# ['bottom', 'steering', 'shaft', 'universal', 'joint', 'worn']
# ['replace', 'blown', 'main', 'pump', 'hose']
# ['tracks', 'need', 'adjusting']
#
# Cluster  17
# ['broken', 'clamp', 'on', 'crowd', 'cylinder', 'hose', 'TBC']
# ['broken', 'left', 'hand', 'side', 'mirror']
# ['coolant', 'pipe', 'clamps', 'needs', 'fitting', 'TBC']
# ['cracks', 'in', 'the', 'dirt', 'chute']
# ['heater', 'hose', 'in', 'cabin', 'roof', 'unserviceable']
# ['power', 'step', 'control', 'cable', 'broken']
#
# Cluster  18
# ['alternator', 'overcharge', 'fault']
# ['diagnose', 'and', 'repair', 'spray', 'faults']
# ['IOV', 'fault', 'on', 'drag', 'package']
# ['drag', 'generator', 'fault']
# ['synchronous', 'motor', 'trip']
# ['drag', 'chain', 'fault']
#
# Cluster  19
# ['broken', 'right', 'hand', 'side', 'door', 'window']
# ['crack', 'in', 'blade', 'liner', 'left', 'hand', 'side']
# ['crack', 'in', 'lower', 'centre', 'of', 'windscreen']
# ['cable', 'gantry', 'crack', 'repairs']
# ['repair', 'right', 'hand', 'fuel', 'tank', 'crack']
# ['left', 'hand', 'corner', 'bonnet', 'cracked']
# ['Bradken', 'to', 'repair', 'broken', 'clam']
# ['glass', 'window', 'has', 'large', 'crack']
# ['repair', 'chassis', 'crack', 'at', 'right', 'hand', 'rear', 'cross', 'member']
# ['repair', 'left', 'hand', 'scoreboard', 'base', 'cracked']
# ['rock', 'breaker', 'in', 'bucket', 'cracked', 'at', 'base']
#
# Cluster  20
# ['alarm', 'on', 'VIMS', 'does', 'not', 'work']
# ['auto-spray', 'feature', 'not', 'working']
# ['backup', 'alarm', 'not', 'working']
# ['modular', 'does', 'not', 'self', 'assign']
#
# Cluster  21
# ['analyse', 'failed', 'driveline', 'component']
# ['transmission', 'fill', '/', 'drain', 'plug', 'unserviceable']
# ['swing', 'resolver', 'fault']
# ['no', 'reception', 'on', 'AM', '/', 'FM', 'radio']
#
# Cluster  22
# ['replace', 'leaking', 'scavenge', 'pump']
# ['PTO', 'shaft', 'requires', 'replacing']
# ['PTO', 'shaft', 'input', 'seal', 'leaking']
# ['replace', 'chip', 'indicators', '(', 'leaking', ')']
# ['water', 'separator', 'filter', 'leaking', 'see', 'photo']
# ['water', 'separator', 'leaking', 'fuel']
#
# Cluster  23
# ['cooler', 'return', 'pipe', 'coupling', 'leak']
# ['fire', 'extinguisher', 'out', 'of', 'date']
# ['possible', 'minor', 'leak', 'on', 'fuel', 'tank']
# ['operators', 'seat', 'worn', 'padding']
# ['CW', 'top', 'radiator', 'tank', 'leak', 'again']
# ['front', 'lights', 'keep', 'blowing', 'fuse']
#
# Cluster  24
# ['axle', 'temperature', 'sensor', 'fault']
# ['camera', 'fault']
# ['contactor', 'fault']
# ['drivers', 'window', 'fault']
# ['swing', 'brake', 'pressure', 'fault']
# ['Tele-Remote', 'cameras', 'fault', 'text']

# %% [markdown]
# ## Hierachical Clustering

# %%
def silhouette(type, embeddings):
    silhouette_scores = []
    test_k = list(range(5, 105, 5))
    linkage_data = linkage(embeddings, method=type)
    for i in test_k:
        # print(i, "/", 100)
        cluster_labels = fcluster(linkage_data, i, criterion='maxclust')
        silhouette_scores.append(silhouette_score(embeddings, cluster_labels))
    plt.plot(test_k, silhouette_scores)
    plt.title("Silhouette Scores")
    plt.show()

# %% [markdown]
# ### Average clustering

# %%
silhouette('average', cluster_embeddings)

# %%
linkage_data = linkage(cluster_embeddings, method='average')
fig = plt.figure(figsize=(25, 10))
dn = dendrogram(linkage_data)
plt.show()

# %%
k
# engine oil leaks right hand side protecting driving engine oil leaks right hand
# repair oil leak position wheel end protecting repair oil leak position wheel end
# inspect bad engine oil leak protecting driving inspect bad engine oil leak protecting
# oil leak from behind water pump protecting generating oil leak from behind water
# air leak air leak air leak air leak air leak air leak air
# coolant leak protecting coolant leak protecting coolant leak protecting coolant leak protecting coolant
# differential oil leak protecting transforming differential oil leak protecting transforming differential oil leak
# engine oil leak protecting driving engine oil leak protecting driving engine oil leak
# engine oil leak inspection plate protecting driving presenting engine oil leak inspection plate
# fuel leak fuel leak fuel leak fuel leak fuel leak fuel leak fuel
# hydraulic oil leak from environmental protecting hydraulic oil leak from environmental protecting hydraulic
# investigate torque converter fan pump oil leak generating protecting transforming investigate torque converter
# minor transmission oil leak protecting transforming minor transmission oil leak protecting transforming minor
# repair engine oil leak and protecting driving repair engine oil leak and protecting
# repair engine oil leaking protecting driving repair engine oil leaking protecting driving repair
# oil leak pilot filter text matterprocessing protecting oil leak pilot filter text matterprocessing
# repair engine oil leak text protecting driving repair engine oil leak text protecting
# repair transmission oil leak text protecting transforming repair transmission oil leak text protecting
# replace hydraulic oil leak text replace hydraulic oil leak text replace hydraulic oil
# CW engine oil leaks x protecting driving CW engine oil leaks x protecting
# compressor safety valve leaking generating protecting compressor safety valve leaking generating protecting compressor
# grease distributor leaking protecting grease distributor leaking protecting grease distributor leaking protecting grease
# oil centrifuge gasket leaking right hand engine matterprocessing driving covering oil centrifuge gasket
# oil leak at diverter valve controlling protecting oil leak at diverter valve controlling
# oil leak inlet to oil burner cover plate covering protecting emitting oil leak
# pilot valve leaking oil protecting informationprocessing pilot valve leaking oil protecting informationprocessing pilot
# pressure compensator leaking protecting pressure compensator leaking protecting pressure compensator leaking protecting pressure
# Top words:
# protecting
# oil
# leak
# driving
# engine
#
# Cluster 6 :
# synchronous motor trip driving synchronous motor trip driving synchronous motor trip driving synchronous
# engine overheating driving engine overheating driving engine overheating driving engine overheating driving engine
# engine vibration <num>-<num> RPM driving engine vibration <num>-<num> RPM driving engine vibration <num>-<num>
# engine oil blender running constantly matterprocessing driving engine oil blender running constantly matterprocessing
# Top words:
# driving
# engine
# trip
# synchronous
# motor
#
# Cluster 7 :
# alternator overcharge fault generating alternator overcharge fault generating alternator overcharge fault generating alternator
# axle temperature fault transforming axle temperature fault transforming axle temperature fault transforming axle
# axle temperature sensor fault sensing transforming axle temperature sensor fault sensing transforming axle
# brake release fault restricting brake release fault restricting brake release fault restricting brake
# camera fault sensing camera fault sensing camera fault sensing camera fault sensing camera
# chord pressure fault holding chord pressure fault holding chord pressure fault holding chord
# contactor fault controlling contactor fault controlling contactor fault controlling contactor fault controlling contactor
# diagnose and repair spray faults generating diagnose and repair spray faults generating diagnose
# diagnose engine fault driving diagnose engine fault driving diagnose engine fault driving diagnose
# diagnose transmission overheat fault transforming diagnose transmission overheat fault transforming diagnose transmission overheat
# diagnose transmission slipping fault transforming diagnose transmission slipping fault transforming diagnose transmission slipping
# drivers window fault controlling drivers window fault controlling drivers window fault controlling drivers
# electrical harness fault holding electrical harness fault holding electrical harness fault holding electrical
# IOV fault on drag package generating presenting IOV fault on drag package generating
# park brake alarm fault restricting park brake alarm fault restricting park brake alarm
# diagnose and repair ladder fault interfacing diagnose and repair ladder fault interfacing diagnose
# ground fault welding board holding ground fault welding board holding ground fault welding
# swing brake pressure fault restricting transforming swing brake pressure fault restricting transforming swing
# ground fault in propel driving ground fault in propel driving ground fault in
# drag generator fault generating drag generator fault generating drag generator fault generating drag
# grease system fault protecting grease system fault protecting grease system fault protecting grease
# investigate auto-lube fault protecting investigate auto-lube fault protecting investigate auto-lube fault protecting investigate
# repair brake fault restricting repair brake fault restricting repair brake fault restricting repair
# walk motor brake fault driving restricting walk motor brake fault driving restricting walk
# tray fault holding tray fault holding tray fault holding tray fault holding tray
# repair gear fault transforming repair gear fault transforming repair gear fault transforming repair
# swing resolver fault transforming sensing swing resolver fault transforming sensing swing resolver fault
# drag chain fault guiding generating drag chain fault guiding generating drag chain fault
# Tele-Remote camera fault sensing humaninteraction Tele-Remote camera fault sensing humaninteraction Tele-Remote camera fault
# Tele-Remote cameras fault text sensing humaninteraction Tele-Remote cameras fault text sensing humaninteraction Tele-Remote
# Tele-Remote fault humaninteraction Tele-Remote fault humaninteraction Tele-Remote fault humaninteraction Tele-Remote fault humaninteraction Tele-Remote
# Tele-Remote faults humaninteraction Tele-Remote faults humaninteraction Tele-Remote faults humaninteraction Tele-Remote faults humaninteraction Tele-Remote
# Tele-Remote issues humaninteraction Tele-Remote issues humaninteraction Tele-Remote issues humaninteraction Tele-Remote issues humaninteraction Tele-Remote
# engine shutdown fault driving engine shutdown fault driving engine shutdown fault driving engine
# grease system fault protecting grease system fault protecting grease system fault protecting grease
# ladder fault interfacing ladder fault interfacing ladder fault interfacing ladder fault interfacing ladder
# lube fault protecting lube fault protecting lube fault protecting lube fault protecting lube
# park brake fault restricting park brake fault restricting park brake fault restricting park
# repair transmission fault transforming repair transmission fault transforming repair transmission fault transforming repair
# set-up Tele-Remote bogging humaninteraction set-up Tele-Remote bogging humaninteraction set-up Tele-Remote bogging humaninteraction set-up
# engine shutdown fault driving engine shutdown fault driving engine shutdown fault driving engine
# grease system has intermittent fault protecting grease system has intermittent fault protecting grease
# transmission temperature fault transforming transmission temperature fault transforming transmission temperature fault transforming transmission
# Tele-Remote fault humaninteraction Tele-Remote fault humaninteraction Tele-Remote fault humaninteraction Tele-Remote fault humaninteraction Tele-Remote
# investigate main transformer overload fault transforming investigate main transformer overload fault transforming investigate
# voltage regulator fuse fault protecting restricting voltage regulator fuse fault protecting restricting voltage
# Top words:
# fault
# transforming
# restricting
# humaninteraction
# Tele-Remote
#
# Cluster 8 :
# replace transmission cracked transforming replace transmission cracked transforming replace transmission cracked transforming replace
# replace cracked transmission dropbox transforming replace cracked transmission dropbox transforming replace cracked transmission
# replace cracked exhaust shield protecting replace cracked exhaust shield protecting replace cracked exhaust
# Top words:
# cracked
# replace
# transmission
# transforming
# dropbox
#
# Cluster 9 :
# air conditioner thermostat not working emitting sensing air conditioner thermostat not working emitting
# air conditioner thermostat unserviceable emitting sensing air conditioner thermostat unserviceable emitting sensing air
# air conditioner unserviceable emitting air conditioner unserviceable emitting air conditioner unserviceable emitting air
# air conditioner unserviceable when stationary emitting air conditioner unserviceable when stationary emitting air
# air conditioner warm emitting air conditioner warm emitting air conditioner warm emitting air
# air horn disconnected presenting air horn disconnected presenting air horn disconnected presenting air
# air horn does not work presenting air horn does not work presenting air
# air horn fault presenting air horn fault presenting air horn fault presenting air
# air horn not working presenting air horn not working presenting air horn not
# air horn not working compressor awaiting presenting generating air horn not working compressor
# air horn stuck on presenting air horn stuck on presenting air horn stuck
# air horn unserviceable presenting air horn unserviceable presenting air horn unserviceable presenting air
# air horn working intermittently presenting air horn working intermittently presenting air horn working
# air leak near side of door controlling air leak near side of door
# air leaking from line outside guiding air leaking from line outside guiding air
# airhorn not working presenting airhorn not working presenting airhorn not working presenting airhorn
# alarm on VIMS does not work presenting alarm on VIMS does not work
# all dash lights on emitting all dash lights on emitting all dash lights
# alternator drive leaking driving generating alternator drive leaking driving generating alternator drive leaking
# alternator failed generating alternator failed generating alternator failed generating alternator failed generating alternator
# alternator not charging generating alternator not charging generating alternator not charging generating alternator
# alternator overcharged generating alternator overcharged generating alternator overcharged generating alternator overcharged generating alternator
# analyse failed driveline component transforming analyse failed driveline component transforming analyse failed driveline
# and lube system faults protecting and lube system faults protecting and lube system
# armrest unserviceable storing armrest unserviceable storing armrest unserviceable storing armrest unserviceable storing armrest
# auto-greaser unserviceable generating auto-greaser unserviceable generating auto-greaser unserviceable generating auto-greaser unserviceable generating auto-greaser
# auto-lube error PO generating auto-lube error PO generating auto-lube error PO generating auto-lube
# auto-spray feature not working generating auto-spray feature not working generating auto-spray feature not
# back rest unserviceable handle broken humaninteraction storing back rest unserviceable handle broken humaninteraction
# backhoe windscreen to be fixed controlling matterprocessing backhoe windscreen to be fixed controlling
# backlight on dash unserviceable emitting presenting backlight on dash unserviceable emitting presenting backlight
# backlights on dash blown emitting presenting backlights on dash blown emitting presenting backlights
# backup alarm not working presenting backup alarm not working presenting backup alarm not
# batteries discharging generating batteries discharging generating batteries discharging generating batteries discharging generating batteries
# batteries unserviceable generating batteries unserviceable generating batteries unserviceable generating batteries unserviceable generating batteries
# battery cover hinges seized generating covering holding battery cover hinges seized generating covering
# beacon mount is broken holding emitting beacon mount is broken holding emitting beacon
# beacon not working emitting beacon not working emitting beacon not working emitting beacon
# beacon unserviceable emitting beacon unserviceable emitting beacon unserviceable emitting beacon unserviceable emitting beacon
# bearing on air conditioner compressor unserviceable holding emitting generating bearing on air conditioner
# bearings are shot holding bearings are shot holding bearings are shot holding bearings
# belly plate bolt missing holding belly plate bolt missing holding belly plate bolt
# bent belly plate holding bent belly plate holding bent belly plate holding bent
# blade light blown needs replacing emitting matterprocessing blade light blown needs replacing emitting
# blade skin cracked protecting matterprocessing blade skin cracked protecting matterprocessing blade skin cracked
# blade wear plates cracked and worn matterprocessing protecting blade wear plates cracked and
# blown air conditioner hose emitting guiding blown air conditioner hose emitting guiding blown
# blown air conditioner hose to radiator emitting guiding blown air conditioner hose to
# blown brake hose restricting guiding blown brake hose restricting guiding blown brake hose
# blown crowd cylinder hose driving guiding blown crowd cylinder hose driving guiding blown
# blown extension line from position guiding blown extension line from position guiding blown
# blown hose in hitch guiding interfacing blown hose in hitch guiding interfacing blown
# blown hose on boom guiding holding blown hose on boom guiding holding blown
# blown lift cylinder o-ring driving covering blown lift cylinder o-ring driving covering blown
# blown light on boom emitting holding blown light on boom emitting holding blown
# blown o-ring off steering hose guiding covering controlling blown o-ring off steering hose
# blown o-ring on left hand lift cylinder driving covering blown o-ring on left
# blown o-ring on steering hose guiding covering controlling blown o-ring on steering hose
# blown oil cooler hose x metre emitting guiding blown oil cooler hose x
# blown right hand bucket cylinder hose driving guiding blown right hand bucket cylinder
# blown steering hose guiding controlling blown steering hose guiding controlling blown steering hose
# blown steering pump hose generating guiding controlling blown steering pump hose generating guiding
# boarding gate hinge broken controlling holding boarding gate hinge broken controlling holding boarding
# boarding gate latch not working controlling boarding gate latch not working controlling boarding
# boarding ladder not working interfacing boarding ladder not working interfacing boarding ladder not
# both stick cylinders leaking driving both stick cylinders leaking driving both stick cylinders
# brake cooling hose leaking restricting guiding brake cooling hose leaking restricting guiding brake
# brake cooling hose leaking rear restricting guiding brake cooling hose leaking rear restricting
# brake cooling return hose leaking restricting guiding brake cooling return hose leaking restricting
# brake temperature error restricting brake temperature error restricting brake temperature error restricting brake
# broken air conditioner guard emitting protecting broken air conditioner guard emitting protecting broken
# broken clamp on crowd cylinder hose TBC holding driving guiding broken clamp on
# broken fuel cooler mounts emitting holding broken fuel cooler mounts emitting holding broken
# broken grease plug controlling broken grease plug controlling broken grease plug controlling broken
# broken hinge holding broken hinge holding broken hinge holding broken hinge holding broken
# broken left hand side mirror guiding broken left hand side mirror guiding broken
# broken mirror guiding broken mirror guiding broken mirror guiding broken mirror guiding broken
# broken right hand side door window controlling broken right hand side door window
# broken ripper tooth matterprocessing broken ripper tooth matterprocessing broken ripper tooth matterprocessing broken
# broken weld on handrail covering protecting broken weld on handrail covering protecting broken
# bucket cracked in arch near cancelled storing holding bucket cracked in arch near
# cabin door window cracked holding controlling cabin door window cracked holding controlling cabin
# cabin needs resealing holding cabin needs resealing holding cabin needs resealing holding cabin
# cabin seals leaking dust PO holding covering cabin seals leaking dust PO holding
# cabin seals leaking dust bad holding covering cabin seals leaking dust bad holding
# cabin seat needs replacing holding storing cabin seat needs replacing holding storing cabin
# cabin window needs resealing holding controlling cabin window needs resealing holding controlling cabin
# carousel popped bolt needs Loctite holding storing carousel popped bolt needs Loctite holding
# centrifugal oil filter fault matterprocessing centrifugal oil filter fault matterprocessing centrifugal oil filter
# change out blown o-ring on steering pump generating covering controlling change out blown
# change out broken bolt on brake pump holding restricting generating change out broken
# change out broken prelube bracket holding protecting change out broken prelube bracket holding
# change out broken stabilizer bar holding change out broken stabilizer bar holding change
# change out cracked pipe on valve bank guiding controlling change out cracked pipe
# change out cracked position adaptor and tooth matterprocessing holding change out cracked position
# change out exhaust clamp broken on left hand side [t |] guiding holding
# change out front upper window cracked controlling change out front upper window cracked
# differential lube pump leaking PO transforming generating differential lube pump leaking PO transforming
# differential pump motor hose leaking transforming generating driving guiding differential pump motor hose
# dogbone pin out holding interfacing dogbone pin out holding interfacing dogbone pin out
# dragline air conditioner units need cleaning emitting dragline air conditioner units need cleaning
# drill out broken bolt see text holding drill out broken bolt see text
# driver's door top hinge broken controlling holding driver's door top hinge broken controlling
# duo-cone seals leaking number swing covering duo-cone seals leaking number swing covering duo-cone
# dust leak operators side window controlling dust leak operators side window controlling dust
# ripper control valve falling off controlling ripper control valve falling off controlling ripper
# repair cracks in mud bucket storing repair cracks in mud bucket storing repair
# replace faulty brake sensor task restricting sensing replace faulty brake sensor task restricting
# speedometer not working sensing speedometer not working sensing speedometer not working sensing speedometer
# cable gantry crack repairs holding cable gantry crack repairs holding cable gantry crack
# failed PTO and auxiliary drive PO transforming failed PTO and auxiliary drive PO
# replace leaking transfer pipe guiding replace leaking transfer pipe guiding replace leaking transfer
# drag tripped on electrical generating drag tripped on electrical generating drag tripped on
# position brake temperature error restricting position brake temperature error restricting position brake temperature
# front revolving light not working emitting front revolving light not working emitting front
# fire extinguisher out of date protecting fire extinguisher out of date protecting fire
# hoist motor RTD wired incorrectly driving sensing generating hoist motor RTD wired incorrectly
# machine will not start machine will not start machine will not start machine
# possible minor leak on fuel tank storing possible minor leak on fuel tank
# replace blown implement hose guiding replace blown implement hose guiding replace blown implement
# rear steering accumulator leak storing controlling rear steering accumulator leak storing controlling rear
# replace blown right hand steering hose guiding controlling replace blown right hand steering
# crane not working generating crane not working generating crane not working generating crane
# grease pump unserviceable generating grease pump unserviceable generating grease pump unserviceable generating grease
# transmission fill / drain plug unserviceable transforming controlling transmission fill / drain plug
# bearing noisy holding bearing noisy holding bearing noisy holding bearing noisy holding bearing
# oil found in revolving frame protecting holding oil found in revolving frame protecting
# rear through shaft universal joint unserviceable guiding rear through shaft universal joint unserviceable
# repair leaking swing pedestal seals holding covering transforming repair leaking swing pedestal seals
# all lighting requires testing and tagging emitting all lighting requires testing and tagging
# steering cylinder bearings have excess play driving holding steering cylinder bearings have excess
# movement found right hand engine mount driving holding movement found right hand engine
# rear wiper motor unserviceable driving rear wiper motor unserviceable driving rear wiper motor
# front right hand roller need to be fitted holding front right hand roller
# main isolator needs clean out controlling main isolator needs clean out controlling main
# park brake alarm sounds continuously restricting presenting park brake alarm sounds continuously restricting
# system pump pressure gauge not working generating presenting system pump pressure gauge not
# replace unserviceable differential drain plugs transforming controlling replace unserviceable differential drain plugs transforming
# repair right hand fuel tank crack storing repair right hand fuel tank crack
# grease pump is bypassing air generating grease pump is bypassing air generating grease
# repair boom cracks left hand side holding repair boom cracks left hand side
# investigate / repair no gear fault transforming investigate / repair no gear fault
# handrail above battery box cracked protecting storing handrail above battery box cracked protecting
# front window cracked replace controlling front window cracked replace controlling front window cracked
# VIMS keypad light out presenting emitting humaninteraction VIMS keypad light out presenting emitting
# replace right hand lift cylinder leaking driving replace right hand lift cylinder leaking
# grease gauges requires replacing presenting grease gauges requires replacing presenting grease gauges requires
# fire extinguisher bracket on deck loose protecting holding fire extinguisher bracket on deck
# rear door struts require replacing controlling holding rear door struts require replacing controlling
# mechanical PTO not meshing transforming mechanical PTO not meshing transforming mechanical PTO not
# replace leaking scavenge pump generating replace leaking scavenge pump generating replace leaking scavenge
# change out leaking transmission hose transforming guiding change out leaking transmission hose transforming
# tail pulley has no grease lines guiding tail pulley has no grease lines
# replace missing cutting edge matterprocessing replace missing cutting edge matterprocessing replace missing cutting
# movement on steering column transforming controlling movement on steering column transforming controlling movement
# replace x cracked windows controlling replace x cracked windows controlling replace x cracked
# parts washer pump broken generating interfacing parts washer pump broken generating interfacing parts
# middle air drain tap leaking controlling interfacing middle air drain tap leaking controlling
# brake warning light on restricting emitting brake warning light on restricting emitting brake
# leaking brake cooling hose restricting guiding leaking brake cooling hose restricting guiding leaking
# faulty fuel pressure sensor sensing faulty fuel pressure sensor sensing faulty fuel pressure
# bottom steering shaft universal joint worn guiding controlling bottom steering shaft universal joint
# right hand bobbin roller unserviceable holding right hand bobbin roller unserviceable holding right
# left hand side pinion change out cover cracking transforming covering left hand side
# left hand rear brake cooling hose leaking restricting guiding left hand rear brake
# fitting leaking out of main air tanks interfacing storing fitting leaking out of
# repair centre hitch oil leaks interfacing protecting repair centre hitch oil leaks interfacing
# steering hub caps require replacing covering controlling steering hub caps require replacing covering
# bulk fuel tank cracked and leaking storing bulk fuel tank cracked and leaking
# hydraulic hose leaking in centre of machine guiding hydraulic hose leaking in centre
# swing resolver not counting transforming sensing swing resolver not counting transforming sensing swing
# repair air conditioner and wiring fault emitting guiding repair air conditioner and wiring
# replace damage auto-greaser door generating controlling replace damage auto-greaser door generating controlling replace
# investigate / repair joystick needs repair humaninteraction investigate / repair joystick needs repair
# headboard welds broken / cracked holding covering headboard welds broken / cracked holding
# hoist brake switches need adjusting restricting humaninteraction generating hoist brake switches need adjusting
# cabin jacking cylinder ends unserviceable holding driving cabin jacking cylinder ends unserviceable holding
# repair movement in left hand steering pin holding controlling repair movement in left
# replace blown main pump hose generating guiding replace blown main pump hose generating
# park brake indicator light going on and off restricting emitting park brake indicator
# tracks need adjusting guiding tracks need adjusting guiding tracks need adjusting guiding tracks
# no excitation on hoist generating no excitation on hoist generating no excitation on
# front window roller blind broken controlling restricting front window roller blind broken controlling
# cabin seat unserviceable needs replacing holding storing cabin seat unserviceable needs replacing holding
# diagnose VIMS error presenting diagnose VIMS error presenting diagnose VIMS error presenting diagnose
# repair exhaust leaks guiding repair exhaust leaks guiding repair exhaust leaks guiding repair
# stick cylinder leaking driving stick cylinder leaking driving stick cylinder leaking driving stick
# hoist brake number position out of adjustment generating restricting hoist brake number position
# PTO shaft requires replacing transforming guiding PTO shaft requires replacing transforming guiding PTO
# missing poppet valve controlling missing poppet valve controlling missing poppet valve controlling missing
# AM / FM radio needs new aerial transforming AM / FM radio needs
# CW left hand hoist cylinder leaking plug controlling driving CW left hand hoist
# CW radiator core leak emitting CW radiator core leak emitting CW radiator core
# CW right hand hoist cylinder leaking driving CW right hand hoist cylinder leaking
# HMU hose weeping guiding driving HMU hose weeping guiding driving HMU hose weeping
# steering pin no grease text holding protecting controlling steering pin no grease text
# injector error generating injector error generating injector error generating injector error generating injector
# Bradken to repair broken clam storing Bradken to repair broken clam storing Bradken
# CW PTO universal joint failed transforming CW PTO universal joint failed transforming CW
# CW engine water pump snapped shaft driving generating guiding CW engine water pump
# CW top radiator tank leak again storing CW top radiator tank leak again
# CW transmission failed transforming CW transmission failed transforming CW transmission failed transforming CW
# GET change out worn cutting edges matterprocessing GET change out worn cutting edges
# PTO input seal leaking covering transforming PTO input seal leaking covering transforming PTO
# VIMS fuel filter plugged matterprocessing presenting VIMS fuel filter plugged matterprocessing presenting VIMS
# adaptor leaking at implement valve controlling adaptor leaking at implement valve controlling adaptor
# aftercooler tank gauge broken emitting presenting storing aftercooler tank gauge broken emitting presenting
# aftercooler temperature error emitting aftercooler temperature error emitting aftercooler temperature error emitting aftercooler
# air conditioner accessory drive leaking oil emitting protecting transforming driving air conditioner accessory
# air conditioner belt broken emitting guiding air conditioner belt broken emitting guiding air
# air conditioner compressor not working emitting generating air conditioner compressor not working emitting
# air conditioner compressor tripping out emitting generating air conditioner compressor tripping out emitting
# air conditioner drive leaking emitting driving air conditioner drive leaking emitting driving air
# air conditioner drive leaking oil emitting protecting driving air conditioner drive leaking oil
# air conditioner fan unserviceable fit new emitting generating air conditioner fan unserviceable fit
# air conditioner fault emitting air conditioner fault emitting air conditioner fault emitting air
# air conditioner needs a boost not cold emitting air conditioner needs a boost
# air conditioner not cold PO emitting air conditioner not cold PO emitting air
# air conditioner not cold electrical faults emitting air conditioner not cold electrical faults
# air conditioner pressure switch unserviceable emitting sensing air conditioner pressure switch unserviceable emitting
# number right hand air brake line needs replacing controlling restricting guiding number right
# [ shutdown ] vinyl flooring unserviceable covering [ shutdown ] vinyl flooring unserviceable
# air conditioner fan speed resistor not working and emitting restricting generating air conditioner
# air brake line blown requires replacing controlling restricting guiding air brake line blown
# air pressure safety valve exhausting protecting air pressure safety valve exhausting protecting air
# batteries have no charge storing batteries have no charge storing batteries have no
# battery unserviceable dropped cell replace storing battery unserviceable dropped cell replace storing battery
# blade control cable tight matterprocessing guiding blade control cable tight matterprocessing guiding blade
# blown air conditioner fuse emitting protecting blown air conditioner fuse emitting protecting blown
# broken proximity sensor tag carousel sensing presenting holding broken proximity sensor tag carousel
# broken wire on speaker emitting guiding broken wire on speaker emitting guiding broken
# cabin side weightometer not working sensing cabin side weightometer not working sensing cabin
# cabin smoke detector missing holding sensing cabin smoke detector missing holding sensing cabin
# centrifuge hose leaking replace matterprocessing guiding centrifuge hose leaking replace matterprocessing guiding centrifuge
# collect broken tooth matterprocessing collect broken tooth matterprocessing collect broken tooth matterprocessing collect
# constant voltage transformer melted transforming constant voltage transformer melted transforming constant voltage transformer
# contamination alarm coming up sensing contamination alarm coming up sensing contamination alarm coming
# contamination alarm on sensing contamination alarm on sensing contamination alarm on sensing contamination
# crack repairs left hand window frame holding crack repairs left hand window frame
# cracked power point in cabin holding interfacing cracked power point in cabin holding
# dry cell not working properly storing dry cell not working properly storing dry
# depth counter unserviceable sensing depth counter unserviceable sensing depth counter unserviceable sensing depth
# diagnose / repair right hand scoreboard not working presenting diagnose / repair right
# <sensitive> depth counter not working sensing <sensitive> depth counter not working sensing <sensitive>
# dust flap on cabin side of mast needs extending protecting holding dust flap
# electric propel siren not working driving emitting electric propel siren not working driving
# earth wire broken on bottom of radiator controlling emitting earth wire broken on
# equipment damaged ( terminal box ) interfacing equipment damaged ( terminal box )
# flag missing presenting flag missing presenting flag missing presenting flag missing presenting flag
# flow battery power storing flow battery power storing flow battery power storing flow
# front lights keep blowing fuse protecting emitting front lights keep blowing fuse protecting
# fuel filter water separator housing broken matterprocessing holding fuel filter water separator housing
# generator flow regulator unserviceable restricting generating generator flow regulator unserviceable restricting generating generator
# heat up locked steels guiding heat up locked steels guiding heat up locked
# heater hose in cabin roof unserviceable holding emitting guiding covering heater hose in
# hole in door frame holding hole in door frame holding hole in door
# high voltage slip ring inspection grease leak protecting transforming high voltage slip ring
# ignition switch broken replace sensing ignition switch broken replace sensing ignition switch broken
# ignition switch sticking sensing ignition switch sticking sensing ignition switch sticking sensing ignition
# inverter earthing out transforming inverter earthing out transforming inverter earthing out transforming inverter
# keeps blowing starter / horn fuse protecting presenting driving keeps blowing starter /
# key broken in ignition switch sensing humaninteraction key broken in ignition switch sensing
# left hand chain guide unserviceable guiding left hand chain guide unserviceable guiding left
# left hand chain guide worn at the top guiding left hand chain guide
# left hand PTO pump chip sensor harness unserviceable sensing transforming generating holding left
# microwave oven unserviceable emitting microwave oven unserviceable emitting microwave oven unserviceable emitting microwave
# number pump contamination switch on sensing generating number pump contamination switch on sensing
# number slew pump contamination switch unserviceable sensing generating driving number slew pump contamination
# glass window has large crack restricting glass window has large crack restricting glass
# position chip sensor alarm sensing position chip sensor alarm sensing position chip sensor
# position pump cavity low interfacing generating position pump cavity low interfacing generating position
# power step control cable broken guiding holding power step control cable broken guiding
# pressure control valve in cabin leaking holding protecting pressure control valve in cabin
# pump drive box coupling and shaft unserviceable interfacing transforming generating driving pump drive
# right hand PTO cavity emptying interfacing transforming right hand PTO cavity emptying interfacing
# radiator blocked with grass transforming emitting radiator blocked with grass transforming emitting radiator
# radiator sight glasses unserviceable emitting presenting radiator sight glasses unserviceable emitting presenting radiator
# remove unserviceable air separator matterprocessing remove unserviceable air separator matterprocessing remove unserviceable air
# repair crack in right hand side of rear cross member holding repair crack
# repair air leak at air tank safety valve storing protecting repair air leak
# repair chassis crack at right hand rear cross member holding repair chassis crack
# repair crack in rear cross member holding repair crack in rear cross member
# repair crack on left hand front heat shield guiding repair crack on left
# repair cracked baffle in hydraulic tank controlling storing repair cracked baffle in hydraulic
# repair cracked roof skin left hand side exhaust guiding covering repair cracked roof
# repair cracks in mast cross braces holding repair cracks in mast cross braces
# repair faulty safety valve protecting repair faulty safety valve protecting repair faulty safety
# repair left hand scoreboard base cracked holding presenting repair left hand scoreboard base
# repair leak in pilot valve solenoid informationprocessing driving repair leak in pilot valve
# repair worn centrifuge filter matterprocessing repair worn centrifuge filter matterprocessing repair worn centrifuge
# replace broken earth terminal controlling replace broken earth terminal controlling replace broken earth
# replace chip indicators ( leaking ) sensing replace chip indicators ( leaking )
# replace cracked glass in entry door controlling interfacing replace cracked glass in entry
# replace cracked water separator matterprocessing replace cracked water separator matterprocessing replace cracked water
# replace seized air conditioner control cable emitting guiding replace seized air conditioner control
# replace shorted diode RPC restricting replace shorted diode RPC restricting replace shorted diode
# replace unserviceable grease distributor protecting replace unserviceable grease distributor protecting replace unserviceable grease
# replace unserviceable chip indicators sensing replace unserviceable chip indicators sensing replace unserviceable chip
# replace unserviceable ignition switch sensing replace unserviceable ignition switch sensing replace unserviceable ignition
# replace unserviceable transmission screen and magnet driving transforming matterprocessing replace unserviceable transmission screen
# rock breaker cracked matterprocessing rock breaker cracked matterprocessing rock breaker cracked matterprocessing rock
# rock breaker in bucket cracked at base holding storing matterprocessing rock breaker in
# safety flag missing presenting safety flag missing presenting safety flag missing presenting safety
# siren unserviceable emitting siren unserviceable emitting siren unserviceable emitting siren unserviceable emitting siren
# slip ring overgreasing transforming slip ring overgreasing transforming slip ring overgreasing transforming slip
# start motorvator and set limits start motorvator and set limits start motorvator and
# troubleshoot smart meter not communicating sensing troubleshoot smart meter not communicating sensing troubleshoot
# transformer trip transforming transformer trip transforming transformer trip transforming transformer trip transforming transformer
# TV monitor does not turn on presenting TV monitor does not turn on
# TV monitor has no signal presenting TV monitor has no signal presenting TV
# water separator filter leaking see photo matterprocessing water separator filter leaking see photo
# water separator leaking fuel matterprocessing water separator leaking fuel matterprocessing water separator leaking
# weightometer display on trailer unserviceable sensing presenting storing weightometer display on trailer unserviceable
# will not start batteries unserviceable storing will not start batteries unserviceable storing will
# window frame needs repair holding window frame needs repair holding window frame needs
# wiper fuse unserviceable protecting matterprocessing wiper fuse unserviceable protecting matterprocessing wiper fuse unserviceable
# Top words:
# guiding
# holding
# emitting
# leaking
# controlling
#
# Cluster 10 :
# air filters plugged matterprocessing air filters plugged matterprocessing air filters plugged matterprocessing air
# Top words:
# filters
# air
# plugged
# matterprocessing
#
# Cluster 11 :
# broken joystick PO humaninteraction broken joystick PO humaninteraction broken joystick PO humaninteraction broken
# Top words:
# PO
# broken
# humaninteraction
# joystick
#
# Cluster 12 :
# batteries out of service generating batteries out of service generating batteries out of
# Top words:
# of
# out
# service
# batteries
# generating

# %% [markdown]
# ### ward clustering

# %%
linkage_data = linkage(cluster_embeddings, method='ward')
fig = plt.figure(figsize=(25, 10))
dn = dendrogram(linkage_data)
plt.show()

# %%
k=6
cluster_labels = fcluster(linkage_data, k, criterion='maxclust')
for i in range(1,k+1):
    print("Cluster",i,":")
    cluster_words = {}
    for j in range(len(cluster_labels)):
        if cluster_labels[j]==i:
            print(" ".join(dataset_not_padded[j]))
            for word in dataset_not_padded[j]:
                if word in cluster_words:
                    cluster_words[word]+=1
                else:
                    cluster_words[word]=1
    print("Top words:")
    sorted_cluster_words = sorted(cluster_words, key=cluster_words.get, reverse=True)
    for j in range(min(len(sorted_cluster_words), 5)):
        print(sorted_cluster_words[j])
    print()
# Out:
# Cluster 1 :
# alternator drive leaking
# blown brake hose
# blown crowd cylinder hose
# blown extension line from position
# blown hose in hitch
# blown hose on boom
# blown lift cylinder o-ring
# blown o-ring off steering hose
# blown o-ring on left hand lift cylinder
# blown o-ring on steering hose
# blown oil cooler hose x metre
# blown position tyre
# blown right hand bucket cylinder hose
# blown steering hose
# blown steering pump hose
# both stick cylinders leaking
# brake cooling hose leaking
# brake cooling hose leaking rear
# brake cooling return hose leaking
# broken clamp on crowd cylinder hose TBC
# broken left hand side mirror
# broken mirror
# cabin seals leaking dust PO
# cabin seals leaking dust bad
# change out blown o-ring on steering pump
# change out blown position tyre
# change out blown steering hose
# change out broken bolt on brake pump
# change out broken prelube bracket
# change out broken stabilizer bar
# change out cracked pipe on valve bank
# change out cracked position adaptor and tooth
# change out exhaust clamp broken on left hand side [t |]
# change out front upper window cracked
# change out leak slew motor hose
# change out leaking HMU on next
# change out leaking fan hoses
# change out leaking heater taps
# change out leaking hydraulic hose
# change out leaking implement pump
# change out leaking relay valve
# change out leaking steering hose
# change out left hand steering cylinder leaking
# change out position and tyre worn out
# change out position tyre sensor not reading
# change out position tyre damage
# change out unserviceable jacket water pump
# change out unserviceable left hand bucket cylinder hose
# change out unserviceable position tyre
# change out unserviceable right hand clam cylinder hose
# change out unserviceable right hand tilt cylinder
# change out unserviceable swing brake cylinder
# change out weeping boom cylinder hose
# change out worn position tyre
# change position flat tyre
# change position tyre damage text
# coolant hose leaking at right hand bottom
# coolant pipe clamps needs fitting TBC
# cracked hydraulic pipe
# cracked suction tube
# cracks in the dirt chute
# cutting edges need change out
# damage to position tyre
# damaged position tyre
# damaged position tyre and rim
# differential cooler fan hose leaking
# differential cooler hose leaking
# differential cooler pump leaking
# differential lube pump leaking
# differential lube pump leaking PO
# differential pump motor hose leaking
# dogbone pin out
# drill out broken bolt see text
# duo-cone seals leaking number swing
# replace leaking transfer pipe
# position brake temperature error
# replace blown implement hose
# replace blown right hand steering hose
# repair leaking swing pedestal seals
# main isolator needs clean out
# replace right hand lift cylinder leaking
# replace damaged position tyre and position
# replace leaking scavenge pump
# change out leaking transmission hose
# position tyre blown
# leaking brake cooling hose
# bottom steering shaft universal joint worn
# replace damaged tyre on position
# synchronous motor trip
# left hand rear brake cooling hose leaking
# hydraulic hose leaking in centre of machine
# change out position tyre worn
# replace blown main pump hose
# tracks need adjusting
# replace position tyre damaged
# replace position tyre mismatched
# repair exhaust leaks
# stick cylinder leaking
# hoist brake number position out of adjustment
# CW left hand hoist cylinder leaking plug
# CW right hand hoist cylinder leaking
# HMU hose weeping
# PTO shaft input seal leaking
# brake hose needs to be replaced
# change out blown hose
# change out broken grease lines
# change out leaking transmission hose
# change out number faulty injector assembly
# change out plugged fuel filters
# change out worn ripper tip ripper tip
# differential lube hose leaking
# engine fan hose weeping
# exhaust leak
# fan hose leaking
# hose leak developing
# left hand boom cylinder hose leaking PO
# noisy hydraulic lift cylinder
# rear steering accumulator leaking
# repair leaking centrifugal filter
# repaired x broken lines
# replace blown hose
# replace broken onside mirror
# replace leaking steering cylinder
# replaced leaking steering hose
# transmission charge hose leaking
# CW engine water pump snapped shaft
# GET change out worn cutting edges
# PTO input seal leaking
# adaptor leaking at implement valve
# blade control cable tight
# centrifuge hose leaking replace
# heat up locked steels
# left hand chain guide unserviceable
# left hand chain guide worn at the top
# position pressure compensator weeping
# power step control cable broken
# repair crack on left hand front heat shield
# repair cracked roof skin left hand side exhaust
# repair worn centrifuge filter
# replace broken earth terminal
# water separator filter leaking see photo
# water separator leaking fuel
# Top words:
# leaking
# hose
# out
# change
# position
#
# Cluster 2 :
# auto-greaser leaking oil
# centrifugal oil filter fault
# centrifugal oil filter leaking
# check / repair engine oil leak
# coolant leak
# coolant leak at engine oil cooler
# coolant leak at jacket water pump
# differential leak
# differential oil leak
# rear steering accumulator leak
# replace oil leaks
# investigate and repair oil leak
# investigate engine oil leak
# oil leak at air compressor
# coolant leaking
# oil leak swingbox
# engine oil leaks right hand side
# repair centre hitch oil leaks
# repair oil leak position wheel end
# inspect bad engine oil leak
# oil leak from behind water pump
# coolant leak
# differential oil leak
# engine oil leak
# engine oil leak inspection plate
# engine overheating
# engine vibration <num>-<num> RPM
# fuel leak
# hydraulic oil leak from environmental
# investigate torque converter fan pump oil leak
# minor transmission oil leak
# repair engine oil leak and
# repair engine oil leaking
# oil leak pilot filter text
# repair engine oil leak text
# repair transmission oil leak text
# replace hydraulic oil leak text
# CW engine oil leaks x
# compressor safety valve leaking
# engine oil blender running constantly
# grease distributor leaking
# high voltage slip ring inspection grease leak
# oil centrifuge gasket leaking right hand engine
# oil leak at diverter valve
# oil leak inlet to oil burner cover plate
# pilot valve leaking oil
# pressure compensator leaking
# repair faulty safety valve
# Top words:
# oil
# leak
# engine
# leaking
# repair
#
# Cluster 3 :
# air conditioner thermostat not working
# air conditioner thermostat unserviceable
# air conditioner unserviceable
# air conditioner unserviceable when stationary
# air conditioner warm
# air horn disconnected
# air horn does not work
# air horn fault
# air horn not working
# air horn not working compressor awaiting
# air horn stuck on
# air horn unserviceable
# air horn working intermittently
# air leak
# air leak near side of door
# air leaking from line outside
# airhorn not working
# alarm on VIMS does not work
# all dash lights on
# auto-spray feature not working
# backlight on dash unserviceable
# backlights on dash blown
# backup alarm not working
# beacon not working
# beacon unserviceable
# bearing on air conditioner compressor unserviceable
# blown air conditioner hose
# blown air conditioner hose to radiator
# blown light on boom
# boarding gate latch not working
# boarding ladder not working
# brake temperature error
# broken air conditioner guard
# chord leaking air found
# dragline air conditioner units need cleaning
# speedometer not working
# front revolving light not working
# machine will not start
# crane not working
# park brake alarm sounds continuously
# VIMS keypad light out
# middle air drain tap leaking
# brake warning light on
# fitting leaking out of main air tanks
# repair air conditioner and wiring fault
# park brake indicator light going on and off
# air conditioner compressor corroded
# air conditioner compressor unserviceable
# air conditioner fault
# air conditioner no good
# air conditioner system leaking
# air horn not working
# air leak
# engine bay light blown
# front headlight blown
# lower left hand headlight blown
# modular does not self assign
# radiator relief valves leaking
# repair blown air conditioner hose
# replace failed air conditioner compressor
# chord is leaking air from crack
# air conditioner accessory drive leaking oil
# air conditioner belt broken
# air conditioner compressor not working
# air conditioner compressor tripping out
# air conditioner drive leaking
# air conditioner drive leaking oil
# air conditioner fan unserviceable fit new
# air conditioner fault
# air conditioner needs a boost not cold
# air conditioner not cold PO
# air conditioner not cold electrical faults
# air conditioner pressure switch unserviceable
# air conditioner fan speed resistor not working and
# air brake line blown requires replacing
# air pressure safety valve exhausting
# blown air conditioner fuse
# cabin side weightometer not working
# dry cell not working properly
# <sensitive> depth counter not working
# electric propel siren not working
# microwave oven unserviceable
# radiator sight glasses unserviceable
# remove unserviceable air separator
# repair air leak at air tank safety valve
# replace seized air conditioner control cable
# siren unserviceable
# TV monitor does not turn on
# weightometer display on trailer unserviceable
# Top words:
# air
# conditioner
# not
# working
# unserviceable
#
# Cluster 4 :
# beacon mount is broken
# bearings are shot
# belly plate bolt missing
# bent belly plate
# broken fuel cooler mounts
# broken hinge
# broken right hand side door window
# bucket cracked in arch near cancelled
# cabin door window cracked
# cabin needs resealing
# cabin seat needs replacing
# cabin window needs resealing
# carousel popped bolt needs Loctite
# cords cracked at and
# crack in blade liner left hand side
# crack in boom chord
# crack in fuel tank
# crack in headboard
# crack in lower centre of windscreen
# crack in windscreen
# cracked walkway and handrails
# cracks in back right hand side handrail
# cracks in decking
# cracks in diagonal braces in front
# cracks in headboard
# crankcase error
# repair cracks in mud bucket
# cable gantry crack repairs
# bearing noisy
# steering cylinder bearings have excess play
# movement found right hand engine mount
# front right hand roller need to be fitted
# repair right hand fuel tank crack
# repair cracks on stick
# repair boom cracks left hand side
# right hand bobbin roller unserviceable
# headboard welds broken / cracked
# cabin jacking cylinder ends unserviceable
# repair movement in left hand steering pin
# cabin seat unserviceable needs replacing
# left hand side boom foot crack repair
# repair right hand track frame crack
# stick cracks
# Bradken to repair broken clam
# broken proximity sensor tag carousel
# cabin smoke detector missing
# crack repairs left hand window frame
# cracked power point in cabin
# dust flap on cabin side of mast needs extending
# heater hose in cabin roof unserviceable
# hole in door frame
# repair crack in right hand side of rear cross member
# repair chassis crack at right hand rear cross member
# repair crack in rear cross member
# repair cracked baffle in hydraulic tank
# repair cracks in mast cross braces
# repair left hand scoreboard base cracked
# rock breaker in bucket cracked at base
# window frame needs repair
# Top words:
# in
# hand
# repair
# crack
# cabin
#
# Cluster 5 :
# alternator overcharge fault
# and lube system faults
# brake release fault
# camera fault
# chord pressure fault
# contactor fault
# diagnose engine fault
# drivers window fault
# electrical harness fault
# park brake alarm fault
# diagnose and repair ladder fault
# ground fault welding board
# swing brake pressure fault
# ground fault in propel
# drag generator fault
# grease system fault
# investigate auto-lube fault
# repair brake fault
# walk motor brake fault
# tray fault
# Tele-Remote camera fault
# Tele-Remote cameras fault text
# Tele-Remote fault
# Tele-Remote faults
# Tele-Remote issues
# engine shutdown fault
# grease system fail
# grease system fault
# ladder fault
# lube fault
# park brake fault
# set-up Tele-Remote bogging
# engine shutdown fault
# grease system has intermittent fault
# Tele-Remote fault
# voltage regulator fuse fault
# Top words:
# fault
# Tele-Remote
# brake
# system
# grease
#
# Cluster 6 :
# air filters plugged
# alternator failed
# alternator not charging
# alternator overcharged
# analyse failed driveline component
# armrest unserviceable
# auto-greaser unserviceable
# auto-lube error PO
# axle temperature fault
# axle temperature sensor fault
# back rest unserviceable handle broken
# backhoe windscreen to be fixed
# batteries discharging
# batteries out of service
# batteries unserviceable
# battery cover hinges seized
# blade light blown needs replacing
# blade skin cracked
# blade wear plates cracked and worn
# boarding gate hinge broken
# broken grease plug
# broken joystick PO
# broken ripper tooth
# broken weld on handrail
# compressor oil pressure switch unserviceable
# control valve unserviceable see long text
# cooler return pipe coupling leak
# crack onside rock deflector
# cracked front window
# cracked fuel tank
# cracked steering tank suction tube
# cracks in fire suppression mounts
# crowd cylinder creeping replace
# cutting edges loose
# dash broken
# diagnose / repair slow steering
# diagnose and repair spray faults
# diagnose and repair torque converter temperature error
# diagnose transmission overheat fault
# diagnose transmission slipping fault
# differential lock broken
# driver's door top hinge broken
# dust leak operators side window
# ripper control valve falling off
# replace faulty brake sensor task
# failed PTO and auxiliary drive PO
# drag tripped on electrical
# fire extinguisher out of date
# hoist motor RTD wired incorrectly
# possible minor leak on fuel tank
# grease pump unserviceable
# transmission fill / drain plug unserviceable
# oil found in revolving frame
# IOV fault on drag package
# rear through shaft universal joint unserviceable
# all lighting requires testing and tagging
# rear wiper motor unserviceable
# replace transmission cracked
# system pump pressure gauge not working
# replace unserviceable differential drain plugs
# grease pump is bypassing air
# investigate / repair no gear fault
# handrail above battery box cracked
# front window cracked replace
# grease gauges requires replacing
# fire extinguisher bracket on deck loose
# rear door struts require replacing
# mechanical PTO not meshing
# tail pulley has no grease lines
# replace missing cutting edge
# movement on steering column
# replace x cracked windows
# parts washer pump broken
# faulty fuel pressure sensor
# left hand side pinion change out cover cracking
# steering hub caps require replacing
# bulk fuel tank cracked and leaking
# swing resolver not counting
# repair gear fault
# replace damage auto-greaser door
# swing resolver fault
# investigate / repair joystick needs repair
# drag chain fault
# hoist brake switches need adjusting
# replace cracked transmission dropbox
# no excitation on hoist
# front window roller blind broken
# diagnose VIMS error
# PTO shaft requires replacing
# missing poppet valve
# AM / FM radio needs new aerial
# CW radiator core leak
# emergency gate latch broken
# fuel breather missing
# fuel cap is missing
# hoist drum cracking
# left hand corner bonnet cracked
# no reception on AM / FM radio
# operators seat worn padding
# repair cracked steering tank mo
# repair transmission fault
# replace blocked dryer
# replace blown work lights
# replace cracked exhaust shield
# ripper shank broken
# steering pin no grease text
# transmission temperature fault
# injector error
# CW PTO universal joint failed
# CW top radiator tank leak again
# CW transmission failed
# VIMS fuel filter plugged
# aftercooler tank gauge broken
# aftercooler temperature error
# number right hand air brake line needs replacing
# [ shutdown ] vinyl flooring unserviceable
# batteries have no charge
# battery unserviceable dropped cell replace
# broken wire on speaker
# collect broken tooth
# constant voltage transformer melted
# contamination alarm coming up
# contamination alarm on
# depth counter unserviceable
# diagnose / repair right hand scoreboard not working
# earth wire broken on bottom of radiator
# equipment damaged ( terminal box )
# flag missing
# flow battery power
# front lights keep blowing fuse
# fuel filter water separator housing broken
# generator flow regulator unserviceable
# ignition switch broken replace
# ignition switch sticking
# inverter earthing out
# investigate main transformer overload fault
# keeps blowing starter / horn fuse
# key broken in ignition switch
# left hand PTO pump chip sensor harness unserviceable
# number pump contamination switch on
# number slew pump contamination switch unserviceable
# glass window has large crack
# position chip sensor alarm
# position pump cavity low
# pressure control valve in cabin leaking
# pump drive box coupling and shaft unserviceable
# right hand PTO cavity emptying
# radiator blocked with grass
# repair leak in pilot valve solenoid
# replace chip indicators ( leaking )
# replace cracked glass in entry door
# replace cracked water separator
# replace shorted diode RPC
# replace unserviceable grease distributor
# replace unserviceable chip indicators
# replace unserviceable ignition switch
# replace unserviceable transmission screen and magnet
# rock breaker cracked
# safety flag missing
# slip ring overgreasing
# start motorvator and set limits
# troubleshoot smart meter not communicating
# transformer trip
# TV monitor has no signal
# will not start batteries unserviceable
# wiper fuse unserviceable
# Top words:
# unserviceable
# replace
# broken
# cracked
# fault

# %% [markdown]
# ### centroid clustering

# %%
linkage_data = linkage(cluster_embeddings, method='centroid')
fig = plt.figure(figsize=(25, 10))
dn = dendrogram(linkage_data)
plt.show()

# %%
k=5
cluster_labels = fcluster(linkage_data, k, criterion='maxclust')
for i in range(1,k+1):
    print("Cluster",i,":")
    cluster_words = {}
    for j in range(len(cluster_labels)):
        if cluster_labels[j]==i:
            print(" ".join(dataset_not_padded[j]))
            for word in dataset_not_padded[j]:
                if word in cluster_words:
                    cluster_words[word]+=1
                else:
                    cluster_words[word]=1
    print("Top words:")
    sorted_cluster_words = sorted(cluster_words, key=cluster_words.get, reverse=True)
    for j in range(min(len(sorted_cluster_words), 5)):
        print(sorted_cluster_words[j])
    print()
# Out:
# Cluster 1 :
# blown position tyre
# change out blown position tyre
# change out blown steering hose
# change out position and tyre worn out
# change out position tyre damage
# change out unserviceable position tyre
# change out worn position tyre
# change position flat tyre
# change position tyre damage text
# damage to position tyre
# damaged position tyre
# damaged position tyre and rim
# replace damaged position tyre and position
# position tyre blown
# replace damaged tyre on position
# change out position tyre worn
# replace position tyre damaged
# replace position tyre mismatched
# change out blown hose
# Top words:
# position
# tyre
# change
# out
# blown
#
# Cluster 2 :
# crack in boom chord
# crack in headboard
# cracks in decking
# cracks in headboard
# repair cracks on stick
# stick cracks
# Top words:
# in
# cracks
# crack
# headboard
# stick
#
# Cluster 3 :
# air leak
# auto-greaser leaking oil
# centrifugal oil filter leaking
# check / repair engine oil leak
# coolant leak
# coolant leak at engine oil cooler
# coolant leak at jacket water pump
# differential leak
# differential oil leak
# replace oil leaks
# investigate and repair oil leak
# investigate engine oil leak
# oil leak at air compressor
# coolant leaking
# oil leak swingbox
# engine oil leaks right hand side
# repair oil leak position wheel end
# inspect bad engine oil leak
# oil leak from behind water pump
# air leak
# coolant leak
# differential oil leak
# engine oil leak
# engine oil leak inspection plate
# exhaust leak
# fuel leak
# hose leak developing
# hydraulic oil leak from environmental
# investigate torque converter fan pump oil leak
# minor transmission oil leak
# repair engine oil leak and
# repair engine oil leaking
# oil leak pilot filter text
# repair engine oil leak text
# repair transmission oil leak text
# replace hydraulic oil leak text
# CW engine oil leaks x
# compressor safety valve leaking
# grease distributor leaking
# oil centrifuge gasket leaking right hand engine
# oil leak at diverter valve
# oil leak inlet to oil burner cover plate
# position pressure compensator weeping
# pilot valve leaking oil
# pressure compensator leaking
# Top words:
# leak
# oil
# engine
# leaking
# repair
#
# Cluster 4 :
# air conditioner thermostat not working
# air conditioner thermostat unserviceable
# air conditioner unserviceable
# air conditioner unserviceable when stationary
# air conditioner warm
# air filters plugged
# air horn disconnected
# air horn does not work
# air horn fault
# air horn not working
# air horn not working compressor awaiting
# air horn stuck on
# air horn unserviceable
# air horn working intermittently
# air leak near side of door
# air leaking from line outside
# airhorn not working
# alarm on VIMS does not work
# all dash lights on
# alternator drive leaking
# alternator failed
# alternator not charging
# alternator overcharge fault
# alternator overcharged
# analyse failed driveline component
# and lube system faults
# armrest unserviceable
# auto-greaser unserviceable
# auto-lube error PO
# auto-spray feature not working
# axle temperature fault
# axle temperature sensor fault
# back rest unserviceable handle broken
# backhoe windscreen to be fixed
# backlight on dash unserviceable
# backlights on dash blown
# backup alarm not working
# batteries discharging
# batteries unserviceable
# battery cover hinges seized
# beacon mount is broken
# beacon not working
# beacon unserviceable
# bearing on air conditioner compressor unserviceable
# bearings are shot
# belly plate bolt missing
# bent belly plate
# blade light blown needs replacing
# blade skin cracked
# blade wear plates cracked and worn
# blown air conditioner hose
# blown air conditioner hose to radiator
# blown brake hose
# blown crowd cylinder hose
# blown extension line from position
# blown hose in hitch
# blown hose on boom
# blown lift cylinder o-ring
# blown light on boom
# blown o-ring off steering hose
# blown o-ring on left hand lift cylinder
# blown o-ring on steering hose
# blown oil cooler hose x metre
# blown right hand bucket cylinder hose
# blown steering hose
# blown steering pump hose
# boarding gate hinge broken
# boarding gate latch not working
# boarding ladder not working
# both stick cylinders leaking
# brake cooling hose leaking
# brake cooling hose leaking rear
# brake cooling return hose leaking
# brake release fault
# brake temperature error
# broken air conditioner guard
# broken clamp on crowd cylinder hose TBC
# broken fuel cooler mounts
# broken grease plug
# broken hinge
# broken joystick PO
# broken left hand side mirror
# broken mirror
# broken right hand side door window
# broken ripper tooth
# broken weld on handrail
# bucket cracked in arch near cancelled
# cabin door window cracked
# cabin needs resealing
# cabin seals leaking dust PO
# cabin seals leaking dust bad
# cabin seat needs replacing
# cabin window needs resealing
# camera fault
# carousel popped bolt needs Loctite
# centrifugal oil filter fault
# change out blown o-ring on steering pump
# change out broken bolt on brake pump
# change out broken prelube bracket
# change out broken stabilizer bar
# change out cracked pipe on valve bank
# change out cracked position adaptor and tooth
# change out exhaust clamp broken on left hand side [t |]
# change out front upper window cracked
# change out leak slew motor hose
# change out leaking HMU on next
# change out leaking fan hoses
# change out leaking heater taps
# change out leaking hydraulic hose
# change out leaking implement pump
# change out leaking relay valve
# change out leaking steering hose
# change out left hand steering cylinder leaking
# change out position tyre sensor not reading
# change out unserviceable jacket water pump
# change out unserviceable left hand bucket cylinder hose
# change out unserviceable right hand clam cylinder hose
# change out unserviceable right hand tilt cylinder
# change out unserviceable swing brake cylinder
# change out weeping boom cylinder hose
# chord leaking air found
# chord pressure fault
# compressor oil pressure switch unserviceable
# contactor fault
# control valve unserviceable see long text
# coolant hose leaking at right hand bottom
# coolant pipe clamps needs fitting TBC
# cooler return pipe coupling leak
# cords cracked at and
# crack in blade liner left hand side
# crack in fuel tank
# crack in lower centre of windscreen
# crack in windscreen
# crack onside rock deflector
# cracked front window
# cracked fuel tank
# cracked hydraulic pipe
# cracked steering tank suction tube
# cracked suction tube
# cracked walkway and handrails
# cracks in back right hand side handrail
# cracks in diagonal braces in front
# cracks in fire suppression mounts
# cracks in the dirt chute
# crankcase error
# crowd cylinder creeping replace
# cutting edges loose
# cutting edges need change out
# dash broken
# diagnose / repair slow steering
# diagnose and repair spray faults
# diagnose and repair torque converter temperature error
# diagnose engine fault
# diagnose transmission overheat fault
# diagnose transmission slipping fault
# differential cooler fan hose leaking
# differential cooler hose leaking
# differential cooler pump leaking
# differential lock broken
# differential lube pump leaking
# differential lube pump leaking PO
# differential pump motor hose leaking
# dogbone pin out
# dragline air conditioner units need cleaning
# drill out broken bolt see text
# driver's door top hinge broken
# drivers window fault
# duo-cone seals leaking number swing
# dust leak operators side window
# electrical harness fault
# ripper control valve falling off
# repair cracks in mud bucket
# replace faulty brake sensor task
# speedometer not working
# cable gantry crack repairs
# failed PTO and auxiliary drive PO
# replace leaking transfer pipe
# drag tripped on electrical
# position brake temperature error
# front revolving light not working
# fire extinguisher out of date
# hoist motor RTD wired incorrectly
# machine will not start
# possible minor leak on fuel tank
# replace blown implement hose
# rear steering accumulator leak
# replace blown right hand steering hose
# crane not working
# grease pump unserviceable
# transmission fill / drain plug unserviceable
# bearing noisy
# oil found in revolving frame
# IOV fault on drag package
# rear through shaft universal joint unserviceable
# repair leaking swing pedestal seals
# all lighting requires testing and tagging
# steering cylinder bearings have excess play
# movement found right hand engine mount
# rear wiper motor unserviceable
# front right hand roller need to be fitted
# main isolator needs clean out
# replace transmission cracked
# park brake alarm sounds continuously
# system pump pressure gauge not working
# replace unserviceable differential drain plugs
# repair right hand fuel tank crack
# grease pump is bypassing air
# park brake alarm fault
# repair boom cracks left hand side
# investigate / repair no gear fault
# handrail above battery box cracked
# front window cracked replace
# VIMS keypad light out
# replace right hand lift cylinder leaking
# diagnose and repair ladder fault
# ground fault welding board
# grease gauges requires replacing
# fire extinguisher bracket on deck loose
# rear door struts require replacing
# mechanical PTO not meshing
# swing brake pressure fault
# replace leaking scavenge pump
# change out leaking transmission hose
# tail pulley has no grease lines
# replace missing cutting edge
# movement on steering column
# replace x cracked windows
# ground fault in propel
# drag generator fault
# parts washer pump broken
# middle air drain tap leaking
# grease system fault
# investigate auto-lube fault
# brake warning light on
# leaking brake cooling hose
# faulty fuel pressure sensor
# bottom steering shaft universal joint worn
# right hand bobbin roller unserviceable
# repair brake fault
# synchronous motor trip
# left hand side pinion change out cover cracking
# walk motor brake fault
# tray fault
# left hand rear brake cooling hose leaking
# fitting leaking out of main air tanks
# repair centre hitch oil leaks
# steering hub caps require replacing
# bulk fuel tank cracked and leaking
# hydraulic hose leaking in centre of machine
# swing resolver not counting
# repair gear fault
# repair air conditioner and wiring fault
# replace damage auto-greaser door
# swing resolver fault
# investigate / repair joystick needs repair
# drag chain fault
# headboard welds broken / cracked
# hoist brake switches need adjusting
# cabin jacking cylinder ends unserviceable
# repair movement in left hand steering pin
# replace blown main pump hose
# park brake indicator light going on and off
# tracks need adjusting
# replace cracked transmission dropbox
# no excitation on hoist
# front window roller blind broken
# cabin seat unserviceable needs replacing
# diagnose VIMS error
# repair exhaust leaks
# stick cylinder leaking
# hoist brake number position out of adjustment
# PTO shaft requires replacing
# missing poppet valve
# AM / FM radio needs new aerial
# CW left hand hoist cylinder leaking plug
# CW radiator core leak
# CW right hand hoist cylinder leaking
# HMU hose weeping
# PTO shaft input seal leaking
# Tele-Remote camera fault
# Tele-Remote cameras fault text
# Tele-Remote fault
# Tele-Remote faults
# Tele-Remote issues
# air conditioner compressor corroded
# air conditioner compressor unserviceable
# air conditioner fault
# air conditioner no good
# air conditioner system leaking
# air horn not working
# brake hose needs to be replaced
# change out broken grease lines
# change out leaking transmission hose
# change out number faulty injector assembly
# change out plugged fuel filters
# change out worn ripper tip ripper tip
# differential lube hose leaking
# emergency gate latch broken
# engine bay light blown
# engine fan hose weeping
# engine overheating
# engine shutdown fault
# engine vibration <num>-<num> RPM
# fan hose leaking
# front headlight blown
# fuel breather missing
# fuel cap is missing
# grease system fail
# grease system fault
# hoist drum cracking
# ladder fault
# left hand boom cylinder hose leaking PO
# left hand corner bonnet cracked
# left hand side boom foot crack repair
# lower left hand headlight blown
# lube fault
# modular does not self assign
# no reception on AM / FM radio
# noisy hydraulic lift cylinder
# operators seat worn padding
# park brake fault
# radiator relief valves leaking
# rear steering accumulator leaking
# repair blown air conditioner hose
# repair cracked steering tank mo
# repair leaking centrifugal filter
# repair right hand track frame crack
# repair transmission fault
# repaired x broken lines
# replace blocked dryer
# replace blown hose
# replace blown work lights
# replace broken onside mirror
# replace cracked exhaust shield
# replace failed air conditioner compressor
# replace leaking steering cylinder
# replaced leaking steering hose
# ripper shank broken
# set-up Tele-Remote bogging
# transmission charge hose leaking
# chord is leaking air from crack
# engine shutdown fault
# grease system has intermittent fault
# steering pin no grease text
# transmission temperature fault
# injector error
# Bradken to repair broken clam
# CW PTO universal joint failed
# CW engine water pump snapped shaft
# CW top radiator tank leak again
# CW transmission failed
# GET change out worn cutting edges
# PTO input seal leaking
# Tele-Remote fault
# VIMS fuel filter plugged
# adaptor leaking at implement valve
# aftercooler tank gauge broken
# aftercooler temperature error
# air conditioner accessory drive leaking oil
# air conditioner belt broken
# air conditioner compressor not working
# air conditioner compressor tripping out
# air conditioner drive leaking
# air conditioner drive leaking oil
# air conditioner fan unserviceable fit new
# air conditioner fault
# air conditioner needs a boost not cold
# air conditioner not cold PO
# air conditioner not cold electrical faults
# air conditioner pressure switch unserviceable
# number right hand air brake line needs replacing
# [ shutdown ] vinyl flooring unserviceable
# air conditioner fan speed resistor not working and
# air brake line blown requires replacing
# air pressure safety valve exhausting
# batteries have no charge
# battery unserviceable dropped cell replace
# blade control cable tight
# blown air conditioner fuse
# broken proximity sensor tag carousel
# broken wire on speaker
# cabin side weightometer not working
# cabin smoke detector missing
# centrifuge hose leaking replace
# collect broken tooth
# constant voltage transformer melted
# contamination alarm coming up
# contamination alarm on
# crack repairs left hand window frame
# cracked power point in cabin
# dry cell not working properly
# depth counter unserviceable
# diagnose / repair right hand scoreboard not working
# <sensitive> depth counter not working
# dust flap on cabin side of mast needs extending
# electric propel siren not working
# earth wire broken on bottom of radiator
# engine oil blender running constantly
# equipment damaged ( terminal box )
# flag missing
# flow battery power
# front lights keep blowing fuse
# fuel filter water separator housing broken
# generator flow regulator unserviceable
# heat up locked steels
# heater hose in cabin roof unserviceable
# hole in door frame
# high voltage slip ring inspection grease leak
# ignition switch broken replace
# ignition switch sticking
# inverter earthing out
# investigate main transformer overload fault
# keeps blowing starter / horn fuse
# key broken in ignition switch
# left hand chain guide unserviceable
# left hand chain guide worn at the top
# left hand PTO pump chip sensor harness unserviceable
# microwave oven unserviceable
# number pump contamination switch on
# number slew pump contamination switch unserviceable
# glass window has large crack
# position chip sensor alarm
# position pump cavity low
# power step control cable broken
# pressure control valve in cabin leaking
# pump drive box coupling and shaft unserviceable
# right hand PTO cavity emptying
# radiator blocked with grass
# radiator sight glasses unserviceable
# remove unserviceable air separator
# repair crack in right hand side of rear cross member
# repair air leak at air tank safety valve
# repair chassis crack at right hand rear cross member
# repair crack in rear cross member
# repair crack on left hand front heat shield
# repair cracked baffle in hydraulic tank
# repair cracked roof skin left hand side exhaust
# repair cracks in mast cross braces
# repair faulty safety valve
# repair left hand scoreboard base cracked
# repair leak in pilot valve solenoid
# repair worn centrifuge filter
# replace broken earth terminal
# replace chip indicators ( leaking )
# replace cracked glass in entry door
# replace cracked water separator
# replace seized air conditioner control cable
# replace shorted diode RPC
# replace unserviceable grease distributor
# replace unserviceable chip indicators
# replace unserviceable ignition switch
# replace unserviceable transmission screen and magnet
# rock breaker cracked
# rock breaker in bucket cracked at base
# safety flag missing
# siren unserviceable
# slip ring overgreasing
# start motorvator and set limits
# troubleshoot smart meter not communicating
# transformer trip
# TV monitor does not turn on
# TV monitor has no signal
# voltage regulator fuse fault
# water separator filter leaking see photo
# water separator leaking fuel
# weightometer display on trailer unserviceable
# will not start batteries unserviceable
# window frame needs repair
# wiper fuse unserviceable
# Top words:
# leaking
# air
# unserviceable
# fault
# hose
#
# Cluster 5 :
# batteries out of service
# Top words:
# batteries
# out
# of
# service

# %% [markdown]
# # maintIE inherent function clusters

# %%
def get_inherent_function(row):
    functions = []
    for e in row["entities"]:
        entity_type = e["type"].split("/")
        if entity_type[0] == "PhysicalObject":
            if len(entity_type) > 1 and entity_type[1] not in ["Substance", "Organism"]:
                if entity_type[1][:-6].lower() not in functions:
                    functions.append(entity_type[1][:-6].lower())
    functions = ",".join(sorted(functions))
    return functions

f = open("../data/gold_release.json", "r")
# returns JSON object as a dictionary
data = json.load(f)
f.close()

MWO_by_function = {}

for datum in data:
    types = [e["type"].split("/")[0] for e in datum["entities"]]
    if ("State" in types or "Process" in types or "Property" in types) and "PhysicalObject" in types:
        inherent_functions = get_inherent_function(datum)
        tokens = clean_tokens(datum["tokens"])
        if inherent_functions in MWO_by_function:
            MWO_by_function[inherent_functions].append(tokens)
        else:
            MWO_by_function[inherent_functions] = [tokens]

print(len(MWO_by_function.keys()))
for i in MWO_by_function.keys():
    print(i, len(MWO_by_function[i]))
    if len(MWO_by_function[i]) == 1:
        print("   ", MWO_by_function[i])
# Out:
# 121
# emitting,sensing 3
# emitting 23
# matterprocessing 21
# presenting 19
# generating,presenting 3
#  7
# controlling 22
# guiding 44
# driving,generating 1
#     [['alternator', 'drive', 'leaking']]
# generating 22
# transforming 23
# protecting 24
# storing 14
# generating,protecting 5
# sensing,transforming 3
# humaninteraction,storing 1
#     [['back', 'rest', 'unserviceable', 'handle', 'broken']]
# controlling,matterprocessing 1
#     [['backhoe', 'windscreen', 'to', 'be', 'fixed']]
# emitting,presenting 3
# covering,generating,holding 1
#     [['battery', 'cover', 'hinges', 'seized']]
# emitting,holding 4
# emitting,generating,holding 1
#     [['bearing', 'on', 'air', 'conditioner', 'compressor', 'unserviceable']]
# holding 34
# emitting,matterprocessing 1
#     [['blade', 'light', 'blown', 'needs', 'replacing']]
# matterprocessing,protecting 5
# emitting,guiding 8
# guiding,restricting 7
# driving,guiding 8
# guiding,interfacing 1
#     [['blown', 'hose', 'in', 'hitch']]
# guiding,holding 5
# covering,driving 2
# controlling,covering,guiding 2
# controlling,guiding 6
# controlling,generating,guiding 1
#     [['blown', 'steering', 'pump', 'hose']]
# controlling,holding 6
# interfacing 4
# driving 21
# restricting 8
# emitting,protecting 3
# driving,guiding,holding 1
#     [['broken', 'clamp', 'on', 'crowd', 'cylinder', 'hose', 'TBC']]
# humaninteraction 7
# covering,protecting 1
#     [['broken', 'weld', 'on', 'handrail']]
# holding,storing 4
# covering,holding 3
# sensing 15
# controlling,covering,generating 1
#     [['change', 'out', 'blown', 'o-ring', 'on', 'steering', 'pump']]
# generating,holding,restricting 1
#     [['change', 'out', 'broken', 'bolt', 'on', 'brake', 'pump']]
# holding,protecting 7
# holding,matterprocessing 2
# generating,guiding 4
# controlling,emitting 3
# guiding,sensing 1
#     [['change', 'out', 'position', 'tyre', 'sensor', 'not', 'reading']]
# driving,protecting 9
# generating,sensing 2
# driving,emitting,protecting 2
# emitting,guiding,interfacing 1
#     [['cooler', 'return', 'pipe', 'coupling', 'leak']]
# controlling,guiding,storing 1
#     [['cracked', 'steering', 'tank', 'suction', 'tube']]
# emitting,generating,guiding,transforming 1
#     [['differential', 'cooler', 'fan', 'hose', 'leaking']]
# emitting,guiding,transforming 1
#     [['differential', 'cooler', 'hose', 'leaking']]
# emitting,generating,transforming 1
#     [['differential', 'cooler', 'pump', 'leaking']]
# controlling,transforming 4
# generating,transforming 3
# protecting,transforming 6
# driving,generating,guiding,transforming 1
#     [['differential', 'pump', 'motor', 'hose', 'leaking']]
# holding,interfacing 2
# covering 4
# restricting,sensing 1
#     [['replace', 'faulty', 'brake', 'sensor', 'task']]
# driving,generating,sensing 2
# controlling,storing 4
# covering,holding,transforming 1
#     [['repair', 'leaking', 'swing', 'pedestal', 'seals']]
# driving,holding 3
# presenting,restricting 1
#     [['park', 'brake', 'alarm', 'sounds', 'continuously']]
# protecting,storing 3
# emitting,humaninteraction,presenting 1
#     [['VIMS', 'keypad', 'light', 'out']]
# restricting,transforming 1
#     [['swing', 'brake', 'pressure', 'fault']]
# guiding,transforming 5
# generating,interfacing 2
# controlling,interfacing 2
# emitting,restricting 2
# covering,transforming 2
# driving,restricting 1
#     [['walk', 'motor', 'brake', 'fault']]
# interfacing,storing 1
#     [['fitting', 'leaking', 'out', 'of', 'main', 'air', 'tanks']]
# interfacing,protecting 1
#     [['repair', 'centre', 'hitch', 'oil', 'leaks']]
# controlling,covering 1
#     [['steering', 'hub', 'caps', 'require', 'replacing']]
# controlling,generating 1
#     [['replace', 'damage', 'auto-greaser', 'door']]
# generating,humaninteraction,restricting 1
#     [['hoist', 'brake', 'switches', 'need', 'adjusting']]
# controlling,restricting 1
#     [['front', 'window', 'roller', 'blind', 'broken']]
# generating,restricting 2
# controlling,driving 1
#     [['CW', 'left', 'hand', 'hoist', 'cylinder', 'leaking', 'plug']]
# covering,guiding,transforming 1
#     [['PTO', 'shaft', 'input', 'seal', 'leaking']]
# humaninteraction,sensing 3
# emitting,generating 6
# driving,generating,guiding 2
# driving,presenting,protecting 2
# generating,protecting,transforming 1
#     [['investigate', 'torque', 'converter', 'fan', 'pump', 'oil', 'leak']]
# controlling,holding,protecting 1
#     [['steering', 'pin', 'no', 'grease', 'text']]
# matterprocessing,presenting 1
#     [['VIMS', 'fuel', 'filter', 'plugged']]
# emitting,presenting,storing 1
#     [['aftercooler', 'tank', 'gauge', 'broken']]
# driving,emitting,protecting,transforming 1
#     [['air', 'conditioner', 'accessory', 'drive', 'leaking', 'oil']]
# driving,emitting 2
# controlling,guiding,restricting 2
# emitting,generating,restricting 1
#     [['air', 'conditioner', 'fan', 'speed', 'resistor', 'not', 'working', 'and']]
# guiding,matterprocessing 2
# holding,presenting,sensing 1
#     [['broken', 'proximity', 'sensor', 'tag', 'carousel']]
# holding,sensing 1
#     [['cabin', 'smoke', 'detector', 'missing']]
# driving,matterprocessing 1
#     [['engine', 'oil', 'blender', 'running', 'constantly']]
# covering,emitting,guiding,holding 1
#     [['heater', 'hose', 'in', 'cabin', 'roof', 'unserviceable']]
# generating,holding,sensing,transforming 1
#     [['left', 'hand', 'PTO', 'pump', 'chip', 'sensor', 'harness', 'unserviceable']]
# covering,driving,matterprocessing 1
#     [['oil', 'centrifuge', 'gasket', 'leaking', 'right', 'hand', 'engine']]
# controlling,protecting 1
#     [['oil', 'leak', 'at', 'diverter', 'valve']]
# covering,emitting,protecting 1
#     [['oil', 'leak', 'inlet', 'to', 'oil', 'burner', 'cover', 'plate']]
# informationprocessing,protecting 1
#     [['pilot', 'valve', 'leaking', 'oil']]
# driving,generating,interfacing,transforming 1
#     [['pump', 'drive', 'box', 'coupling', 'and', 'shaft', 'unserviceable']]
# interfacing,transforming 1
#     [['right', 'hand', 'PTO', 'cavity', 'emptying']]
# emitting,transforming 1
#     [['radiator', 'blocked', 'with', 'grass']]
# covering,guiding 1
#     [['repair', 'cracked', 'roof', 'skin', 'left', 'hand', 'side', 'exhaust']]
# holding,presenting 1
#     [['repair', 'left', 'hand', 'scoreboard', 'base', 'cracked']]
# driving,informationprocessing 1
#     [['repair', 'leak', 'in', 'pilot', 'valve', 'solenoid']]
# driving,matterprocessing,transforming 1
#     [['replace', 'unserviceable', 'transmission', 'screen', 'and', 'magnet']]
# holding,matterprocessing,storing 1
#     [['rock', 'breaker', 'in', 'bucket', 'cracked', 'at', 'base']]
# protecting,restricting 1
#     [['voltage', 'regulator', 'fuse', 'fault']]
# presenting,sensing,storing 1
#     [['weightometer', 'display', 'on', 'trailer', 'unserviceable']]
