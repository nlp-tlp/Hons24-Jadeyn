# %% [markdown]
# ### imports

# %%
# !pip install tensorflow
# !pip install gensim
# !pip install tf-keras
# Out:
# Requirement already satisfied: tensorflow in /opt/miniconda3/lib/python3.12/site-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (4.25.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (1.65.5)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/miniconda3/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.41.2)
# Requirement already satisfied: rich in /opt/miniconda3/lib/python3.12/site-packages (from keras>=3.2.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /opt/miniconda3/lib/python3.12/site-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /opt/miniconda3/lib/python3.12/site-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/miniconda3/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/miniconda3/lib/python3.12/site-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/miniconda3/lib/python3.12/site-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/miniconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Requirement already satisfied: gensim in /opt/miniconda3/lib/python3.12/site-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /opt/miniconda3/lib/python3.12/site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /opt/miniconda3/lib/python3.12/site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/miniconda3/lib/python3.12/site-packages (from gensim) (7.0.4)
# Requirement already satisfied: wrapt in /opt/miniconda3/lib/python3.12/site-packages (from smart-open>=1.8.1->gensim) (1.16.0)
# Requirement already satisfied: tf-keras in /opt/miniconda3/lib/python3.12/site-packages (2.17.0)
# Requirement already satisfied: tensorflow<2.18,>=2.17 in /opt/miniconda3/lib/python3.12/site-packages (from tf-keras) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (3.3.0)
# Requirement already satisfied: packaging in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (4.25.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (2.31.0)
# Requirement already satisfied: setuptools in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.65.5)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (3.5.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/miniconda3/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow<2.18,>=2.17->tf-keras) (0.41.2)
# Requirement already satisfied: rich in /opt/miniconda3/lib/python3.12/site-packages (from keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (13.7.1)
# Requirement already satisfied: namex in /opt/miniconda3/lib/python3.12/site-packages (from keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (0.0.8)
# Requirement already satisfied: optree in /opt/miniconda3/lib/python3.12/site-packages (from keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.18,>=2.17->tf-keras) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.18,>=2.17->tf-keras) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.18,>=2.17->tf-keras) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.18,>=2.17->tf-keras) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard<2.18,>=2.17->tensorflow<2.18,>=2.17->tf-keras) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard<2.18,>=2.17->tensorflow<2.18,>=2.17->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/miniconda3/lib/python3.12/site-packages (from tensorboard<2.18,>=2.17->tensorflow<2.18,>=2.17->tf-keras) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/miniconda3/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow<2.18,>=2.17->tf-keras) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/miniconda3/lib/python3.12/site-packages (from rich->keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/miniconda3/lib/python3.12/site-packages (from rich->keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/miniconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (0.1.2)

# %%
import tensorflow as tf

from gensim.models import Word2Vec
from gensim.models import LsiModel
import gensim

import numpy as np
import matplotlib.pyplot as plt

from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

from sentence_transformers import SentenceTransformer
import json
import contractions
import random

from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.metrics import silhouette_score
from sklearn.metrics import normalized_mutual_info_score

import copy

# %% [markdown]
# ### prepare dataset

# %%
def pad_sequence(dset, max_len=None):
    if not max_len:
        max_len = len(max(dset, key=len))
    print("max length of MWO:", max_len)
    for i in range(len(dset)):
        count = 0
        while len(dset[i]) < max_len:
            dset[i].append(dset[i][count])
            count+=1
    return dset

def add_inherent_functions(row):
    for e in row["entities"]:
        tokens = row["tokens"]
        entity_type = e["type"].split("/")
        if entity_type[0] == "PhysicalObject":
            if len(entity_type) > 1 and entity_type[1] not in ["Substance", "Organism"]:
                if entity_type[1][:-6].lower() not in tokens:
                    tokens.append(entity_type[1][:-6].lower())
                # tokens.append(entity_type[1][-6:].lower())
    return tokens

    # BROKEN CODE
    # physical_object_indices = []
    # 
    # for e in row["entities"]:
    #     new_list = row["tokens"]
    #     entity_type = e["type"].split("/")
    #     if entity_type[0] == "PhysicalObject":
    #         if len(entity_type) > 1 and entity_type[1] not in ["Substance", "Organism"]:
    #             new_string = " ".join(new_list)
    #             if e["end"] == len(row["tokens"]):
    #                 replace_index = new_string.find(" ".join(row["tokens"][e["start"]:]))
    #                 new_string = new_string.replace(" ".join(row["tokens"][e["start"]:]))
    #             else:
    #                 replace_index = new_string.find(" ".join(row["tokens"][e["start"]:e["end"]]))
    #                 new_string = new_string.replace(" ".join(row["tokens"][e["start"]:e["end"]]), "")
    #             new_string = new_string[replace_index:]
    #             new_list = new_string.split()
    #             physical_object_indices.append((e["start"], e["end"], entity_type[1]))
    # for i in physical_object_indices:
    #     if i[1] == len(row["tokens"]):
    #         row["tokens"].append(i[2])
        

def clean_tokens(tokens):
    stopwords =["<num>", "<id>", "-", "/", "and"]
    tokens = [i for i in tokens if i not in stopwords]
    tokens = contractions.fix(" ".join(tokens)).split()
    return tokens

def prepare_dataset(filename):
    f = open(filename, "r")
    # returns JSON object as a dictionary
    data = json.load(f)

    dataset = []

    for datum in data:
        keep_indices = []
        for entity in datum["entities"]:
            if entity["type"].split("/")[0] not in ["PhysicalObject", "Activity"]:
                start = entity["start"]
                end = entity["end"]
                for i in range(start, end):
                    keep_indices.append(i)

        tokens = []
        for i in sorted(set(keep_indices)):
            tokens.append(datum["tokens"][i])
        
        tokens = clean_tokens(tokens)
        if tokens:
            dataset.append(" ".join(tokens))
    # dataset = pad_sequence(dataset)
    return dataset

def full_dataset(filename):
    f = open(filename, "r")
    # returns JSON object as a dictionary
    data = json.load(f)

    d = []

    for datum in data:
        types = [e["type"].split("/")[0] for e in datum["entities"]]
        if ("State" in types or "Process" in types or "Property" in types) and "PhysicalObject" in types:
            tokens = clean_tokens(datum["tokens"])
            # d.append(" ".join(tokens))
            d.append(tokens)
    # d = pad_sequence(dataset)
    return d

def full_dataset_append_inherent_functions(filename):
    f = open(filename, "r")
    # returns JSON object as a dictionary
    data = json.load(f)

    d = []

    for datum in data:
        types = [e["type"].split("/")[0] for e in datum["entities"]]
        if ("State" in types or "Process" in types or "Property" in types) and "PhysicalObject" in types:
            tokens = add_inherent_functions(datum)
            tokens = clean_tokens(tokens)
            # d.append(" ".join(tokens))
            d.append(tokens)
    return d

# %% [markdown]
# # OG dataset

# %% [markdown]
# ## CNN

# %%
dataset = full_dataset("../data/gold_release.json")
print(dataset)
# pad_sequence(dataset)
print(len(dataset))
# Out:
# [['air', 'conditioner', 'thermostat', 'not', 'working'], ['air', 'conditioner', 'thermostat', 'unserviceable'], ['air', 'conditioner', 'unserviceable'], ['air', 'conditioner', 'unserviceable', 'when', 'stationary'], ['air', 'conditioner', 'warm'], ['air', 'filters', 'plugged'], ['air', 'horn', 'disconnected'], ['air', 'horn', 'does', 'not', 'work'], ['air', 'horn', 'fault'], ['air', 'horn', 'not', 'working'], ['air', 'horn', 'not', 'working', 'compressor', 'awaiting'], ['air', 'horn', 'stuck', 'on'], ['air', 'horn', 'unserviceable'], ['air', 'horn', 'working', 'intermittently'], ['air', 'leak'], ['air', 'leak', 'near', 'side', 'of', 'door'], ['air', 'leaking', 'from', 'line', 'outside'], ['airhorn', 'not', 'working'], ['alarm', 'on', 'VIMS', 'does', 'not', 'work'], ['all', 'dash', 'lights', 'on'], ['alternator', 'drive', 'leaking'], ['alternator', 'failed'], ['alternator', 'not', 'charging'], ['alternator', 'overcharge', 'fault'], ['alternator', 'overcharged'], ['analyse', 'failed', 'driveline', 'component'], ['and', 'lube', 'system', 'faults'], ['armrest', 'unserviceable'], ['auto-greaser', 'leaking', 'oil'], ['auto-greaser', 'unserviceable'], ['auto-lube', 'error', 'PO'], ['auto-spray', 'feature', 'not', 'working'], ['axle', 'temperature', 'fault'], ['axle', 'temperature', 'sensor', 'fault'], ['back', 'rest', 'unserviceable', 'handle', 'broken'], ['backhoe', 'windscreen', 'to', 'be', 'fixed'], ['backlight', 'on', 'dash', 'unserviceable'], ['backlights', 'on', 'dash', 'blown'], ['backup', 'alarm', 'not', 'working'], ['batteries', 'discharging'], ['batteries', 'out', 'of', 'service'], ['batteries', 'unserviceable'], ['battery', 'cover', 'hinges', 'seized'], ['beacon', 'mount', 'is', 'broken'], ['beacon', 'not', 'working'], ['beacon', 'unserviceable'], ['bearing', 'on', 'air', 'conditioner', 'compressor', 'unserviceable'], ['bearings', 'are', 'shot'], ['belly', 'plate', 'bolt', 'missing'], ['bent', 'belly', 'plate'], ['blade', 'light', 'blown', 'needs', 'replacing'], ['blade', 'skin', 'cracked'], ['blade', 'wear', 'plates', 'cracked', 'and', 'worn'], ['blown', 'air', 'conditioner', 'hose'], ['blown', 'air', 'conditioner', 'hose', 'to', 'radiator'], ['blown', 'brake', 'hose'], ['blown', 'crowd', 'cylinder', 'hose'], ['blown', 'extension', 'line', 'from', 'position'], ['blown', 'hose', 'in', 'hitch'], ['blown', 'hose', 'on', 'boom'], ['blown', 'lift', 'cylinder', 'o-ring'], ['blown', 'light', 'on', 'boom'], ['blown', 'o-ring', 'off', 'steering', 'hose'], ['blown', 'o-ring', 'on', 'left', 'hand', 'lift', 'cylinder'], ['blown', 'o-ring', 'on', 'steering', 'hose'], ['blown', 'oil', 'cooler', 'hose', 'x', 'metre'], ['blown', 'position', 'tyre'], ['blown', 'right', 'hand', 'bucket', 'cylinder', 'hose'], ['blown', 'steering', 'hose'], ['blown', 'steering', 'pump', 'hose'], ['boarding', 'gate', 'hinge', 'broken'], ['boarding', 'gate', 'latch', 'not', 'working'], ['boarding', 'ladder', 'not', 'working'], ['both', 'stick', 'cylinders', 'leaking'], ['brake', 'cooling', 'hose', 'leaking'], ['brake', 'cooling', 'hose', 'leaking', 'rear'], ['brake', 'cooling', 'return', 'hose', 'leaking'], ['brake', 'release', 'fault'], ['brake', 'temperature', 'error'], ['broken', 'air', 'conditioner', 'guard'], ['broken', 'clamp', 'on', 'crowd', 'cylinder', 'hose', 'TBC'], ['broken', 'fuel', 'cooler', 'mounts'], ['broken', 'grease', 'plug'], ['broken', 'hinge'], ['broken', 'joystick', 'PO'], ['broken', 'left', 'hand', 'side', 'mirror'], ['broken', 'mirror'], ['broken', 'right', 'hand', 'side', 'door', 'window'], ['broken', 'ripper', 'tooth'], ['broken', 'weld', 'on', 'handrail'], ['bucket', 'cracked', 'in', 'arch', 'near', 'cancelled'], ['cabin', 'door', 'window', 'cracked'], ['cabin', 'needs', 'resealing'], ['cabin', 'seals', 'leaking', 'dust', 'PO'], ['cabin', 'seals', 'leaking', 'dust', 'bad'], ['cabin', 'seat', 'needs', 'replacing'], ['cabin', 'window', 'needs', 'resealing'], ['camera', 'fault'], ['carousel', 'popped', 'bolt', 'needs', 'Loctite'], ['cen ...
# 540

# %%
# SBERT embeddings
model = SentenceTransformer("all-MiniLM-L6-v2")
SBERT_embeddings = model.encode(dataset)
print(SBERT_embeddings.shape)
# Out:
# /opt/miniconda3/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# (540, 384)

# %%
# Word2Vec embeddings as input
w2vmodel = gensim.models.Word2Vec(dataset, min_count=1, vector_size=100,
                                window=5, sg=1)
w2v_embeddings = []
for sentence in dataset:
    row = []
    for word in sentence:
        row.append(w2vmodel.wv[word])
    w2v_embeddings.append(row)
w2v_embeddings = np.array(w2v_embeddings)

# %%
print(w2v_embeddings.shape)
shape = w2v_embeddings.shape
w2v_embeddings=w2v_embeddings.reshape(shape[0], shape[1], shape[2], 1)
print(w2v_embeddings.shape)
# Out:
# (540, 11, 100)
# (540, 11, 100, 1)

# %%
# LSI embeddings as output
dictionary = gensim.corpora.Dictionary(dataset)
doc_term_matrix = [dictionary.doc2bow(doc) for doc in dataset]
lsamodel = LsiModel(doc_term_matrix, num_topics=10, id2word = dictionary)  # train model
concepts = list(lsamodel[doc_term_matrix])
lsa_embeddings=[]
for i in concepts:
    row = []
    for j in i:
        row.append(j[1])
    lsa_embeddings.append(row)
lsa_embeddings = np.array(lsa_embeddings)

# %%
print(lsa_embeddings.shape)
print(lsa_embeddings)
# Out:
# (540, 10)
# [[-0.47431653 -1.2782885  -0.91834234 ... -0.61034892 -0.32856104
#    0.15590842]
#  [-0.54008579 -1.05384326 -0.7979275  ...  0.44503969  0.30655522
#    0.128419  ]
#  [-0.53286493 -1.02983923 -0.7778401  ...  0.44813846  0.30696067
#    0.1225257 ]
#  ...
#  [-0.24101968 -0.27974647 -0.30957513 ...  0.20217668 -0.01385001
#    0.39493835]
#  [-0.21375224 -0.21440266  0.45153458 ...  0.02019542 -0.16308668
#   -0.03343942]
#  [-0.17558381 -0.10463617 -0.14563296 ...  0.53721338  0.25043225
#    0.23397677]]

# %%
model1 = tf.keras.Sequential([
    tf.keras.layers.Dense(units=128, activation="relu", input_shape=(384,)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(units=128, activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(units=64, activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(units=10, activation="tanh"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(units=10, activation="tanh")
])

# %%
model1.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_32 (Dense)            (None, 128)               49280
#
#  batch_normalization_16 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dense_33 (Dense)            (None, 128)               16512
#
#  batch_normalization_17 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dense_34 (Dense)            (None, 64)                8256
#
#  batch_normalization_18 (Ba  (None, 64)                256
#  tchNormalization)
#
#  dense_35 (Dense)            (None, 10)                650
#
#  batch_normalization_19 (Ba  (None, 10)                40
#  tchNormalization)
#
#  dense_36 (Dense)            (None, 10)                110
#
# =================================================================
# Total params: 76128 (297.38 KB)
# Trainable params: 75468 (294.80 KB)
# Non-trainable params: 660 (2.58 KB)
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)

opt = tf.keras.optimizers.Adam(learning_rate=0.001)

model1.compile(optimizer=opt,
              loss=tf.keras.losses.MeanSquaredLogarithmicError("sum_over_batch_size"),
              metrics=['accuracy'])

history = model1.fit(SBERT_embeddings, lsa_embeddings, epochs=200)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy TF-Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy TF-Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/200
# 17/17 [==============================] - 1s 2ms/step - loss: 0.0885 - accuracy: 0.1574
# Epoch 2/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0651 - accuracy: 0.2130
# Epoch 3/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0509 - accuracy: 0.2556
# Epoch 4/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0415 - accuracy: 0.2833
# Epoch 5/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0324 - accuracy: 0.2981
# Epoch 6/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0262 - accuracy: 0.3352
# Epoch 7/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0223 - accuracy: 0.3685
# Epoch 8/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0194 - accuracy: 0.4148
# Epoch 9/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0173 - accuracy: 0.4167
# Epoch 10/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 0.4537
# Epoch 11/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0149 - accuracy: 0.4574
# Epoch 12/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0137 - accuracy: 0.5278
# Epoch 13/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0135 - accuracy: 0.5111
# Epoch 14/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0127 - accuracy: 0.5167
# Epoch 15/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0130 - accuracy: 0.5241
# Epoch 16/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0120 - accuracy: 0.5593
# Epoch 17/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0115 - accuracy: 0.5407
# Epoch 18/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0113 - accuracy: 0.5389
# Epoch 19/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0115 - accuracy: 0.5648
# Epoch 20/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0116 - accuracy: 0.5611
# Epoch 21/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0115 - accuracy: 0.5389
# Epoch 22/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0108 - accuracy: 0.5926
# Epoch 23/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0105 - accuracy: 0.5759
# Epoch 24/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0100 - accuracy: 0.6000
# Epoch 25/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0102 - accuracy: 0.6000
# Epoch 26/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0099 - accuracy: 0.6111
# Epoch 27/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0103 - accuracy: 0.6278
# Epoch 28/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0100 - accuracy: 0.6259
# Epoch 29/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0101 - accuracy: 0.6278
# Epoch 30/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0102 - accuracy: 0.6093
# Epoch 31/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0097 - accuracy: 0.5907
# Epoch 32/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0095 - accuracy: 0.6074
# Epoch 33/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0098 - accuracy: 0.6019
# Epoch 34/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0098 - accuracy: 0.6130
# Epoch 35/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0094 - accuracy: 0.6037
# Epoch 36/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0097 - accuracy: 0.6056
# Epoch 37/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0096 - accuracy: 0.5870
# Epoch 38/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0094 - accuracy: 0.6093
# Epoch 39/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0090 - accuracy: 0.6167
# Epoch 40/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0091 - accuracy: 0.6185
# Epoch 41/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0091 - accuracy: 0.6204
# Epoch 42/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0090 - accuracy: 0.6259
# Epoch 43/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0092 - accuracy: 0.6389
# Epoch 44/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0089 - accuracy: 0.6389
# Epoch 45/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0092 - accuracy: 0.6333
# Epoch 46/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0094 - accuracy: 0.6296
# Epoch 47/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0090 - accuracy: 0.6296
# Epoch 48/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0090 - accuracy: 0.6204
# Epoch 49/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0088 - accuracy: 0.6296
# Epoch 50/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0087 - accuracy: 0.6389
# Epoch 51/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0086 - accuracy: 0.6185
# Epoch 52/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0087 - accuracy: 0.6241
# Epoch 53/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0085 - accuracy: 0.6204
# Epoch 54/200
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0086 - accuracy: 0.6315
# Epoch 55/200
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0087 - accuracy: 0.6426
# Epoch 56/200
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0089 - accuracy: 0.6370
# Epoch 57/200
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0086 - accuracy: 0.6481
# Epoch 58/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0087 - accuracy: 0.6444
# Epoch 59/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0087 - accuracy: 0.6222
# Epoch 60/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0086 - accuracy: 0.6315
# Epoch 61/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0086 - accuracy: 0.6204
# Epoch 62/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0087 - accuracy: 0.6278
# Epoch 63/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0084 - accuracy: 0.6296
# Epoch 64/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0083 - accuracy: 0.6278
# Epoch 65/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0088 - accuracy: 0.6315
# Epoch 66/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0085 - accuracy: 0.6630
# Epoch 67/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0085 - accuracy: 0.6500
# Epoch 68/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0083 - accuracy: 0.6315
# Epoch 69/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0082 - accuracy: 0.6519
# Epoch 70/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0083 - accuracy: 0.6333
# Epoch 71/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0081 - accuracy: 0.6556
# Epoch 72/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0081 - accuracy: 0.6556
# Epoch 73/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0083 - accuracy: 0.6593
# Epoch 74/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0081 - accuracy: 0.6315
# Epoch 75/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0084 - accuracy: 0.6315
# Epoch 76/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0081 - accuracy: 0.6426
# Epoch 77/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0084 - accuracy: 0.6519
# Epoch 78/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0080 - accuracy: 0.6519
# Epoch 79/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0079 - accuracy: 0.6630
# Epoch 80/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0082 - accuracy: 0.6574
# Epoch 81/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0081 - accuracy: 0.6500
# Epoch 82/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 0.6648
# Epoch 83/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 0.6407
# Epoch 84/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0081 - accuracy: 0.6463
# Epoch 85/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0082 - accuracy: 0.6593
# Epoch 86/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0081 - accuracy: 0.6667
# Epoch 87/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0084 - accuracy: 0.6333
# Epoch 88/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 0.6778
# Epoch 89/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 0.6444
# Epoch 90/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0081 - accuracy: 0.6685
# Epoch 91/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 0.6722
# Epoch 92/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 0.6722
# Epoch 93/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 0.6463
# Epoch 94/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 0.6852
# Epoch 95/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 0.6444
# Epoch 96/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0082 - accuracy: 0.6481
# Epoch 97/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0079 - accuracy: 0.6704
# Epoch 98/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 0.6537
# Epoch 99/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 0.6648
# Epoch 100/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 0.6704
# Epoch 101/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 0.6648
# Epoch 102/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 0.6593
# Epoch 103/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0081 - accuracy: 0.6426
# Epoch 104/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 0.6500
# Epoch 105/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 0.6574
# Epoch 106/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0076 - accuracy: 0.6685
# Epoch 107/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0076 - accuracy: 0.6704
# Epoch 108/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0076 - accuracy: 0.6741
# Epoch 109/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0079 - accuracy: 0.6722
# Epoch 110/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0079 - accuracy: 0.6630
# Epoch 111/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 0.6574
# Epoch 112/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0075 - accuracy: 0.6556
# Epoch 113/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 0.6593
# Epoch 114/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0075 - accuracy: 0.6889
# Epoch 115/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 0.6519
# Epoch 116/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0077 - accuracy: 0.6593
# Epoch 117/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0077 - accuracy: 0.6759
# Epoch 118/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0075 - accuracy: 0.6778
# Epoch 119/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0077 - accuracy: 0.6815
# Epoch 120/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0075 - accuracy: 0.6667
# Epoch 121/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0073 - accuracy: 0.6852
# Epoch 122/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 0.7000
# Epoch 123/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0074 - accuracy: 0.6722
# Epoch 124/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 0.6500
# Epoch 125/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 0.6833
# Epoch 126/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 0.6833
# Epoch 127/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0071 - accuracy: 0.6796
# Epoch 128/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0073 - accuracy: 0.6685
# Epoch 129/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0071 - accuracy: 0.6667
# Epoch 130/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0073 - accuracy: 0.6593
# Epoch 131/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0075 - accuracy: 0.6815
# Epoch 132/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0071 - accuracy: 0.6944
# Epoch 133/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0073 - accuracy: 0.6648
# Epoch 134/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0070 - accuracy: 0.7111
# Epoch 135/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0068 - accuracy: 0.6815
# Epoch 136/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0071 - accuracy: 0.6796
# Epoch 137/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0072 - accuracy: 0.7000
# Epoch 138/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0075 - accuracy: 0.6833
# Epoch 139/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0070 - accuracy: 0.6852
# Epoch 140/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0073 - accuracy: 0.6815
# Epoch 141/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0073 - accuracy: 0.6852
# Epoch 142/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0073 - accuracy: 0.6778
# Epoch 143/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0071 - accuracy: 0.6611
# Epoch 144/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0071 - accuracy: 0.6963
# Epoch 145/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0071 - accuracy: 0.6889
# Epoch 146/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0070 - accuracy: 0.6907
# Epoch 147/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0070 - accuracy: 0.7111
# Epoch 148/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0071 - accuracy: 0.6759
# Epoch 149/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.7056
# Epoch 150/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 0.6870
# Epoch 151/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0070 - accuracy: 0.6815
# Epoch 152/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0070 - accuracy: 0.7130
# Epoch 153/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0067 - accuracy: 0.6833
# Epoch 154/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0066 - accuracy: 0.6852
# Epoch 155/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0069 - accuracy: 0.6815
# Epoch 156/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0068 - accuracy: 0.7259
# Epoch 157/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0068 - accuracy: 0.6889
# Epoch 158/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0069 - accuracy: 0.7167
# Epoch 159/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0065 - accuracy: 0.7074
# Epoch 160/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.6870
# Epoch 161/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0069 - accuracy: 0.6852
# Epoch 162/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0070 - accuracy: 0.6870
# Epoch 163/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.7037
# Epoch 164/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0069 - accuracy: 0.6667
# Epoch 165/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.6926
# Epoch 166/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0069 - accuracy: 0.7037
# Epoch 167/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0067 - accuracy: 0.6889
# Epoch 168/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0066 - accuracy: 0.7019
# Epoch 169/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0068 - accuracy: 0.7093
# Epoch 170/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0068 - accuracy: 0.7056
# Epoch 171/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0067 - accuracy: 0.7093
# Epoch 172/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0067 - accuracy: 0.7000
# Epoch 173/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0068 - accuracy: 0.6852
# Epoch 174/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0066 - accuracy: 0.7093
# Epoch 175/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0065 - accuracy: 0.7111
# Epoch 176/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0066 - accuracy: 0.7037
# Epoch 177/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0067 - accuracy: 0.7111
# Epoch 178/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0068 - accuracy: 0.6907
# Epoch 179/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0067 - accuracy: 0.7056
# Epoch 180/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0067 - accuracy: 0.7204
# Epoch 181/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0066 - accuracy: 0.7148
# Epoch 182/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0066 - accuracy: 0.7093
# Epoch 183/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0067 - accuracy: 0.7074
# Epoch 184/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.7000
# Epoch 185/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0064 - accuracy: 0.7130
# Epoch 186/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.6981
# Epoch 187/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.7093
# Epoch 188/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0067 - accuracy: 0.7185
# Epoch 189/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0065 - accuracy: 0.7315
# Epoch 190/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0064 - accuracy: 0.7056
# Epoch 191/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0064 - accuracy: 0.7204
# Epoch 192/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0065 - accuracy: 0.7204
# Epoch 193/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0065 - accuracy: 0.7056
# Epoch 194/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0064 - accuracy: 0.7333
# Epoch 195/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0065 - accuracy: 0.7037
# Epoch 196/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0065 - accuracy: 0.7093
# Epoch 197/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0066 - accuracy: 0.7204
# Epoch 198/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0064 - accuracy: 0.7148
# Epoch 199/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0064 - accuracy: 0.7093
# Epoch 200/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0065 - accuracy: 0.7167

# %%
acc = history.history['accuracy']
print(acc)
plt.plot(acc)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
# plt.ylim([0, 1])
# plt.legend(loc='lower right')
plt.show()
# Out:
# [0.15740740299224854, 0.21296297013759613, 0.25555557012557983, 0.28333333134651184, 0.29814815521240234, 0.3351851999759674, 0.36851853132247925, 0.4148148000240326, 0.4166666567325592, 0.45370370149612427, 0.4574074149131775, 0.5277777910232544, 0.5111111402511597, 0.5166666507720947, 0.5240740776062012, 0.5592592358589172, 0.5407407283782959, 0.5388888716697693, 0.5648148059844971, 0.5611110925674438, 0.5388888716697693, 0.5925925970077515, 0.5759259462356567, 0.6000000238418579, 0.6000000238418579, 0.6111111044883728, 0.6277777552604675, 0.6259258985519409, 0.6277777552604675, 0.6092592477798462, 0.5907407402992249, 0.6074073910713196, 0.6018518805503845, 0.6129629611968994, 0.6037036776542664, 0.605555534362793, 0.5870370268821716, 0.6092592477798462, 0.6166666746139526, 0.6185185313224792, 0.6203703880310059, 0.6259258985519409, 0.6388888955116272, 0.6388888955116272, 0.6333333253860474, 0.6296296119689941, 0.6296296119689941, 0.6203703880310059, 0.6296296119689941, 0.6388888955116272, 0.6185185313224792, 0.6240741014480591, 0.6203703880310059, 0.6314814686775208, 0.6425926089286804, 0.6370370388031006, 0.6481481194496155, 0.644444465637207, 0.6222222447395325, 0.6314814686775208, 0.6203703880310059, 0.6277777552604675, 0.6296296119689941, 0.6277777552604675, 0.6314814686775208, 0.6629629731178284, 0.6499999761581421, 0.6314814686775208, 0.6518518328666687, 0.6333333253860474, 0.6555555462837219, 0.6555555462837219, 0.6592592597007751, 0.6314814686775208, 0.6314814686775208, 0.6425926089286804, 0.6518518328666687, 0.6518518328666687, 0.6629629731178284, 0.6574074029922485, 0.6499999761581421, 0.664814829826355, 0.6407407522201538, 0.6462963223457336, 0.6592592597007751, 0.6666666865348816, 0.6333333253860474, 0.6777777671813965, 0.644444465637207, 0.6685185432434082, 0.6722221970558167, 0.6722221970558167, 0.6462963223457336, 0.6851851940155029, 0.644444465637207, 0.6481481194496155, 0.6703703999519348, 0.6537036895751953, 0.664814829826355, 0.6703703999519348, 0.664814829826355, 0.6592592597007751, 0.6425926089286804, 0.6499999761581421, 0.6574074029922485, 0.6685185432434082, 0.6703703999519348, 0.6740740537643433, 0.6722221970558167, 0.6629629731178284, 0.6574074029922485, 0.6555555462837219, 0.6592592597007751, 0.6888889074325562, 0.6518518328666687, 0.6592592597007751, 0.6759259104728699, 0.6777777671813965, 0.6814814805984497, 0.6666666865348816, 0.6851851940155029, 0.699999988079071, 0.6722221970558167, 0.6499999761581421, 0.6833333373069763, 0.6833333373069763, 0.6796296238899231, 0.6685185432434082, 0.6666666865348816, 0.6592592597007751, 0.6814814805984497, 0.6944444179534912, 0.664814829826355, 0.7111111283302307, 0.6814814805984497, 0.6796296238899231, 0.699999988079071, 0.6833333373069763, 0.6851851940155029, 0.6814814805984497, 0.6851851940155029, 0.6777777671813965, 0.6611111164093018, 0.6962962746620178, 0.6888889074325562, 0.6907407641410828, 0.7111111283302307, 0.6759259104728699, 0.7055555582046509, 0.6870370507240295, 0.6814814805984497, 0.7129629850387573, 0.6833333373069763, 0.6851851940155029, 0.6814814805984497, 0.7259259223937988, 0.6888889074325562, 0.7166666388511658, 0.7074074149131775, 0.6870370507240295, 0.6851851940155029, 0.6870370507240295, 0.7037037014961243, 0.6666666865348816, 0.6925926208496094, 0.7037037014961243, 0.6888889074325562, 0.7018518447875977, 0.7092592716217041, 0.7055555582046509, 0.7092592716217041, 0.699999988079071, 0.6851851940155029, 0.7092592716217041, 0.7111111283302307, 0.7037037014961243, 0.7111111283302307, 0.6907407641410828, 0.7055555582046509, 0.720370352268219, 0.7148148417472839, 0.7092592716217041, 0.7074074149131775, 0.699999988079071, 0.7129629850387573, 0.6981481313705444, 0.7092592716217041, 0.7185184955596924, 0.7314814925193787, 0.7055555582046509, 0.720370352268219, 0.720370352268219, 0.7055555582046509, 0.7333333492279053, 0.7037037014961243, 0.7092592716217041, 0.720370352268219, 0.7148148417472839, 0.7092592716217041, 0.7166666388511658]

# %%
model2 = tf.keras.Sequential([
    tf.keras.layers.Dense(units=128, activation="relu", input_shape=(384,)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(units=128, activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(units=64, activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(units=10, activation="tanh")
])

model2.layers[0].set_weights(model1.layers[0].get_weights())
model2.layers[2].set_weights(model1.layers[2].get_weights())
model2.layers[4].set_weights(model1.layers[4].get_weights())
model2.layers[6].set_weights(model1.layers[6].get_weights())

# %%
cluster_embeddings = model2.predict(SBERT_embeddings)
print(cluster_embeddings.shape)
# Out:
# 17/17 [==============================] - 0s 657us/step
# (540, 10)

# %% [markdown]
# ### k means + plotting cluster embeddings

# %%
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.metrics import silhouette_score


# PCA reduction
pca = PCA(n_components=2)
pca_embedding = pca.fit_transform(cluster_embeddings)
plt.scatter(pca_embedding[:,0], pca_embedding[:,1])
plt.title("PCA")
plt.show()

# tsne reduction
tsne = TSNE(n_components=2).fit_transform(cluster_embeddings)
plt.scatter(tsne[:,0], tsne[:,1])
plt.title("TSNE")
plt.show()


# # Perform kmean clustering
# silhouette_scores = []
# test_k = list(range(5, 105, 5))
# for i in test_k:
#     print(i, "/", 100)
#     kmeans = KMeans(n_clusters=i, random_state=42, n_init=100).fit(cluster_embeddings)
#     labels = kmeans.labels_
#     silhouette_scores.append(silhouette_score(cluster_embeddings, labels))
# plt.plot(test_k, silhouette_scores)
# plt.title("Silhouette Scores")
# plt.show()

# %%
dataset_not_padded = full_dataset("../data/gold_release.json")
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=15, random_state=42, n_init=100).fit(pca_embedding)
labels = kmeans.labels_
for i in range(15):
    print("Cluster ", i)
    for j in range(len(labels)):
        if labels[j] == i:
            print(dataset_not_padded[j])
# Out:
# Cluster  0
# ['change', 'out', 'blown', 'o-ring', 'on', 'steering', 'pump']
# ['change', 'out', 'blown', 'position', 'tyre']
# ['change', 'out', 'blown', 'steering', 'hose']
# ['change', 'out', 'broken', 'bolt', 'on', 'brake', 'pump']
# ['change', 'out', 'broken', 'prelube', 'bracket']
# ['change', 'out', 'broken', 'stabilizer', 'bar']
# ['change', 'out', 'cracked', 'pipe', 'on', 'valve', 'bank']
# ['change', 'out', 'cracked', 'position', 'adaptor', 'and', 'tooth']
# ['change', 'out', 'exhaust', 'clamp', 'broken', 'on', 'left', 'hand', 'side', '[t', '|]']
# ['change', 'out', 'front', 'upper', 'window', 'cracked']
# ['change', 'out', 'leak', 'slew', 'motor', 'hose']
# ['change', 'out', 'leaking', 'HMU', 'on', 'next']
# ['change', 'out', 'leaking', 'fan', 'hoses']
# ['change', 'out', 'leaking', 'heater', 'taps']
# ['change', 'out', 'leaking', 'hydraulic', 'hose']
# ['change', 'out', 'leaking', 'implement', 'pump']
# ['change', 'out', 'leaking', 'relay', 'valve']
# ['change', 'out', 'leaking', 'steering', 'hose']
# ['change', 'out', 'left', 'hand', 'steering', 'cylinder', 'leaking']
# ['change', 'out', 'position', 'and', 'tyre', 'worn', 'out']
# ['change', 'out', 'position', 'tyre', 'sensor', 'not', 'reading']
# ['change', 'out', 'position', 'tyre', 'damage']
# ['change', 'out', 'unserviceable', 'jacket', 'water', 'pump']
# ['change', 'out', 'unserviceable', 'left', 'hand', 'bucket', 'cylinder', 'hose']
# ['change', 'out', 'unserviceable', 'position', 'tyre']
# ['change', 'out', 'unserviceable', 'right', 'hand', 'clam', 'cylinder', 'hose']
# ['change', 'out', 'unserviceable', 'right', 'hand', 'tilt', 'cylinder']
# ['change', 'out', 'unserviceable', 'swing', 'brake', 'cylinder']
# ['change', 'out', 'weeping', 'boom', 'cylinder', 'hose']
# ['change', 'out', 'worn', 'position', 'tyre']
# ['replace', 'transmission', 'cracked']
# ['change', 'out', 'leaking', 'transmission', 'hose']
# ['drag', 'generator', 'fault']
# ['change', 'out', 'position', 'tyre', 'worn']
# ['change', 'out', 'blown', 'hose']
# ['change', 'out', 'broken', 'grease', 'lines']
# ['change', 'out', 'leaking', 'transmission', 'hose']
# ['change', 'out', 'number', 'faulty', 'injector', 'assembly']
# ['change', 'out', 'plugged', 'fuel', 'filters']
# ['change', 'out', 'worn', 'ripper', 'tip', 'ripper', 'tip']
# ['fan', 'hose', 'leaking']
# ['replace', 'hydraulic', 'oil', 'leak', 'text']
# ['GET', 'change', 'out', 'worn', 'cutting', 'edges']
# ['compressor', 'safety', 'valve', 'leaking']
# ['heater', 'hose', 'in', 'cabin', 'roof', 'unserviceable']
# Cluster  1
# ['air', 'horn', 'disconnected']
# ['air', 'horn', 'does', 'not', 'work']
# ['air', 'horn', 'fault']
# ['air', 'horn', 'not', 'working']
# ['air', 'horn', 'not', 'working', 'compressor', 'awaiting']
# ['air', 'horn', 'stuck', 'on']
# ['air', 'horn', 'unserviceable']
# ['air', 'horn', 'working', 'intermittently']
# ['diagnose', 'engine', 'fault']
# ['diagnose', 'transmission', 'overheat', 'fault']
# ['diagnose', 'transmission', 'slipping', 'fault']
# ['IOV', 'fault', 'on', 'drag', 'package']
# ['handrail', 'above', 'battery', 'box', 'cracked']
# ['ground', 'fault', 'welding', 'board']
# ['ground', 'fault', 'in', 'propel']
# ['brake', 'warning', 'light', 'on']
# ['repair', 'gear', 'fault']
# ['hoist', 'brake', 'switches', 'need', 'adjusting']
# ['tracks', 'need', 'adjusting']
# ['diagnose', 'VIMS', 'error']
# ['hoist', 'brake', 'number', 'position', 'out', 'of', 'adjustment']
# ['air', 'horn', 'not', 'working']
# ['engine', 'bay', 'light', 'blown']
# ['no', 'reception', 'on', 'AM', '/', 'FM', 'radio']
# ['earth', 'wire', 'broken', 'on', 'bottom', 'of', 'radiator']
# Cluster  2
# ['air', 'leak']
# ['air', 'leak', 'near', 'side', 'of', 'door']
# ['airhorn', 'not', 'working']
# ['and', 'lube', 'system', 'faults']
# ['armrest', 'unserviceable']
# ['back', 'rest', 'unserviceable', 'handle', 'broken']
# ['backhoe', 'windscreen', 'to', 'be', 'fixed']
# ['backlight', 'on', 'dash', 'unserviceable']
# ['backup', 'alarm', 'not', 'working']
# ['beacon', 'not', 'working']
# ['blown', 'air', 'conditioner', 'hose']
# ['blown', 'air', 'conditioner', 'hose', 'to', 'radiator']
# ['blown', 'crowd', 'cylinder', 'hose']
# ['blown', 'extension', 'line', 'from', 'position']
# ['blown', 'lift', 'cylinder', 'o-ring']
# ['blown', 'light', 'on', 'boom']
# ['blown', 'o-ring', 'off', 'steering', 'hose']
# ['blown', 'o-ring', 'on', 'left', 'hand', 'lift', 'cylinder']
# ['blown', 'o-ring', 'on', 'steering', 'hose']
# ['blown', 'position', 'tyre']
# ['blown', 'steering', 'hose']
# ['blown', 'steering', 'pump', 'hose']
# ['broken', 'ripper', 'tooth']
# ['cabin', 'door', 'window', 'cracked']
# ['cabin', 'seals', 'leaking', 'dust', 'PO']
# ['cabin', 'seals', 'leaking', 'dust', 'bad']
# ['cabin', 'window', 'needs', 'resealing']
# ['centrifugal', 'oil', 'filter', 'fault']
# ['centrifugal', 'oil', 'filter', 'leaking']
# ['change', 'position', 'flat', 'tyre']
# ['change', 'position', 'tyre', 'damage', 'text']
# ['cooler', 'return', 'pipe', 'coupling', 'leak']
# ['cracked', 'front', 'window']
# ['cracked', 'suction', 'tube']
# ['cracked', 'walkway', 'and', 'handrails']
# ['rear', 'steering', 'accumulator', 'leak']
# ['oil', 'found', 'in', 'revolving', 'frame']
# ['rear', 'through', 'shaft', 'universal', 'joint', 'unserviceable']
# ['rear', 'wiper', 'motor', 'unserviceable']
# ['system', 'pump', 'pressure', 'gauge', 'not', 'working']
# ['replace', 'unserviceable', 'differential', 'drain', 'plugs']
# ['VIMS', 'keypad', 'light', 'out']
# ['position', 'tyre', 'blown']
# ['headboard', 'welds', 'broken', '/', 'cracked']
# ['replace', 'cracked', 'transmission', 'dropbox']
# ['air', 'leak']
# ['hose', 'leak', 'developing']
# ['operators', 'seat', 'worn', 'padding']
# ['rear', 'steering', 'accumulator', 'leaking']
# ['replace', 'cracked', 'exhaust', 'shield']
# ['aftercooler', 'tank', 'gauge', 'broken']
# ['blown', 'air', 'conditioner', 'fuse']
# ['cabin', 'smoke', 'detector', 'missing']
# ['heat', 'up', 'locked', 'steels']
# ['key', 'broken', 'in', 'ignition', 'switch']
# ['number', 'slew', 'pump', 'contamination', 'switch', 'unserviceable']
# ['oil', 'centrifuge', 'gasket', 'leaking', 'right', 'hand', 'engine']
# ['glass', 'window', 'has', 'large', 'crack']
# ['pressure', 'compensator', 'leaking']
# ['pressure', 'control', 'valve', 'in', 'cabin', 'leaking']
# ['replace', 'cracked', 'glass', 'in', 'entry', 'door']
# ['replace', 'cracked', 'water', 'separator']
# ['replace', 'unserviceable', 'grease', 'distributor']
# ['replace', 'unserviceable', 'chip', 'indicators']
# ['replace', 'unserviceable', 'ignition', 'switch']
# ['replace', 'unserviceable', 'transmission', 'screen', 'and', 'magnet']
# Cluster  3
# ['bent', 'belly', 'plate']
# ['boarding', 'gate', 'hinge', 'broken']
# ['boarding', 'gate', 'latch', 'not', 'working']
# ['boarding', 'ladder', 'not', 'working']
# ['diagnose', 'and', 'repair', 'spray', 'faults']
# ['diagnose', 'and', 'repair', 'torque', 'converter', 'temperature', 'error']
# ['dogbone', 'pin', 'out']
# ['investigate', 'and', 'repair', 'oil', 'leak']
# ['diagnose', 'and', 'repair', 'ladder', 'fault']
# ['mechanical', 'PTO', 'not', 'meshing']
# ['middle', 'air', 'drain', 'tap', 'leaking']
# ['repair', 'centre', 'hitch', 'oil', 'leaks']
# ['repair', 'oil', 'leak', 'position', 'wheel', 'end']
# ['repair', 'movement', 'in', 'left', 'hand', 'steering', 'pin']
# ['CW', 'PTO', 'universal', 'joint', 'failed']
# ['CW', 'top', 'radiator', 'tank', 'leak', 'again']
# ['dust', 'flap', 'on', 'cabin', 'side', 'of', 'mast', 'needs', 'extending']
# ['hole', 'in', 'door', 'frame']
# ['troubleshoot', 'smart', 'meter', 'not', 'communicating']
# Cluster  4
# ['air', 'conditioner', 'thermostat', 'not', 'working']
# ['air', 'conditioner', 'thermostat', 'unserviceable']
# ['air', 'conditioner', 'unserviceable']
# ['air', 'conditioner', 'unserviceable', 'when', 'stationary']
# ['air', 'conditioner', 'warm']
# ['air', 'conditioner', 'compressor', 'corroded']
# ['air', 'conditioner', 'compressor', 'unserviceable']
# ['air', 'conditioner', 'fault']
# ['air', 'conditioner', 'no', 'good']
# ['air', 'conditioner', 'system', 'leaking']
# ['air', 'conditioner', 'accessory', 'drive', 'leaking', 'oil']
# ['air', 'conditioner', 'belt', 'broken']
# ['air', 'conditioner', 'compressor', 'not', 'working']
# ['air', 'conditioner', 'compressor', 'tripping', 'out']
# ['air', 'conditioner', 'drive', 'leaking']
# ['air', 'conditioner', 'drive', 'leaking', 'oil']
# ['air', 'conditioner', 'fan', 'unserviceable', 'fit', 'new']
# ['air', 'conditioner', 'fault']
# ['air', 'conditioner', 'needs', 'a', 'boost', 'not', 'cold']
# ['air', 'conditioner', 'not', 'cold', 'PO']
# ['air', 'conditioner', 'not', 'cold', 'electrical', 'faults']
# ['air', 'conditioner', 'pressure', 'switch', 'unserviceable']
# ['air', 'conditioner', 'fan', 'speed', 'resistor', 'not', 'working', 'and']
# Cluster  5
# ['alternator', 'not', 'charging']
# ['alternator', 'overcharged']
# ['broken', 'fuel', 'cooler', 'mounts']
# ['broken', 'joystick', 'PO']
# ['broken', 'mirror']
# ['camera', 'fault']
# ['damage', 'to', 'position', 'tyre']
# ['speedometer', 'not', 'working']
# ['cable', 'gantry', 'crack', 'repairs']
# ['drag', 'tripped', 'on', 'electrical']
# ['steering', 'cylinder', 'bearings', 'have', 'excess', 'play']
# ['tail', 'pulley', 'has', 'no', 'grease', 'lines']
# ['faulty', 'fuel', 'pressure', 'sensor']
# ['tray', 'fault']
# ['drag', 'chain', 'fault']
# ['engine', 'fan', 'hose', 'weeping']
# ['engine', 'overheating']
# ['engine', 'shutdown', 'fault']
# ['fuel', 'cap', 'is', 'missing']
# ['transmission', 'charge', 'hose', 'leaking']
# ['engine', 'shutdown', 'fault']
# ['transmission', 'temperature', 'fault']
# ['VIMS', 'fuel', 'filter', 'plugged']
# ['flag', 'missing']
# ['high', 'voltage', 'slip', 'ring', 'inspection', 'grease', 'leak']
# ['microwave', 'oven', 'unserviceable']
# ['radiator', 'sight', 'glasses', 'unserviceable']
# ['safety', 'flag', 'missing']
# ['start', 'motorvator', 'and', 'set', 'limits']
# ['transformer', 'trip']
# ['TV', 'monitor', 'does', 'not', 'turn', 'on']
# ['TV', 'monitor', 'has', 'no', 'signal']
# ['voltage', 'regulator', 'fuse', 'fault']
# ['weightometer', 'display', 'on', 'trailer', 'unserviceable']
# Cluster  6
# ['broken', 'left', 'hand', 'side', 'mirror']
# ['broken', 'right', 'hand', 'side', 'door', 'window']
# ['crack', 'onside', 'rock', 'deflector']
# ['diagnose', '/', 'repair', 'slow', 'steering']
# ['duo-cone', 'seals', 'leaking', 'number', 'swing']
# ['front', 'revolving', 'light', 'not', 'working']
# ['machine', 'will', 'not', 'start']
# ['possible', 'minor', 'leak', 'on', 'fuel', 'tank']
# ['repair', 'leaking', 'swing', 'pedestal', 'seals']
# ['front', 'right', 'hand', 'roller', 'need', 'to', 'be', 'fitted']
# ['investigate', '/', 'repair', 'no', 'gear', 'fault']
# ['grease', 'system', 'fault']
# ['investigate', 'auto-lube', 'fault']
# ['repair', 'air', 'conditioner', 'and', 'wiring', 'fault']
# ['investigate', '/', 'repair', 'joystick', 'needs', 'repair']
# ['PTO', 'shaft', 'requires', 'replacing']
# ['PTO', 'shaft', 'input', 'seal', 'leaking']
# ['grease', 'system', 'fail']
# ['grease', 'system', 'fault']
# ['modular', 'does', 'not', 'self', 'assign']
# ['repair', 'blown', 'air', 'conditioner', 'hose']
# ['repair', 'cracked', 'steering', 'tank', 'mo']
# ['repair', 'leaking', 'centrifugal', 'filter']
# ['stick', 'cracks']
# ['chord', 'is', 'leaking', 'air', 'from', 'crack']
# ['grease', 'system', 'has', 'intermittent', 'fault']
# ['Bradken', 'to', 'repair', 'broken', 'clam']
# ['PTO', 'input', 'seal', 'leaking']
# ['cabin', 'side', 'weightometer', 'not', 'working']
# ['diagnose', '/', 'repair', 'right', 'hand', 'scoreboard', 'not', 'working']
# ['repair', 'air', 'leak', 'at', 'air', 'tank', 'safety', 'valve']
# ['repair', 'cracked', 'baffle', 'in', 'hydraulic', 'tank']
# ['repair', 'cracked', 'roof', 'skin', 'left', 'hand', 'side', 'exhaust']
# ['repair', 'leak', 'in', 'pilot', 'valve', 'solenoid']
# ['will', 'not', 'start', 'batteries', 'unserviceable']
# ['window', 'frame', 'needs', 'repair']
# Cluster  7
# ['crack', 'in', 'blade', 'liner', 'left', 'hand', 'side']
# ['crack', 'in', 'boom', 'chord']
# ['crack', 'in', 'fuel', 'tank']
# ['crack', 'in', 'headboard']
# ['crack', 'in', 'lower', 'centre', 'of', 'windscreen']
# ['crack', 'in', 'windscreen']
# ['cracks', 'in', 'back', 'right', 'hand', 'side', 'handrail']
# ['cracks', 'in', 'decking']
# ['cracks', 'in', 'diagonal', 'braces', 'in', 'front']
# ['cracks', 'in', 'fire', 'suppression', 'mounts']
# ['cracks', 'in', 'headboard']
# ['cracks', 'in', 'the', 'dirt', 'chute']
# ['repair', 'cracks', 'in', 'mud', 'bucket']
# ['repair', 'right', 'hand', 'fuel', 'tank', 'crack']
# ['repair', 'cracks', 'on', 'stick']
# ['repair', 'boom', 'cracks', 'left', 'hand', 'side']
# ['CW', 'left', 'hand', 'hoist', 'cylinder', 'leaking', 'plug']
# ['CW', 'right', 'hand', 'hoist', 'cylinder', 'leaking']
# ['repair', 'right', 'hand', 'track', 'frame', 'crack']
# ['crack', 'repairs', 'left', 'hand', 'window', 'frame']
# ['repair', 'crack', 'in', 'right', 'hand', 'side', 'of', 'rear', 'cross', 'member']
# ['repair', 'chassis', 'crack', 'at', 'right', 'hand', 'rear', 'cross', 'member']
# ['repair', 'crack', 'in', 'rear', 'cross', 'member']
# ['repair', 'crack', 'on', 'left', 'hand', 'front', 'heat', 'shield']
# ['repair', 'cracks', 'in', 'mast', 'cross', 'braces']
# ['repair', 'left', 'hand', 'scoreboard', 'base', 'cracked']
# ['repair', 'worn', 'centrifuge', 'filter']
# Cluster  8
# ['alternator', 'overcharge', 'fault']
# ['axle', 'temperature', 'fault']
# ['axle', 'temperature', 'sensor', 'fault']
# ['batteries', 'discharging']
# ['batteries', 'out', 'of', 'service']
# ['battery', 'cover', 'hinges', 'seized']
# ['beacon', 'mount', 'is', 'broken']
# ['beacon', 'unserviceable']
# ['cabin', 'needs', 'resealing']
# ['compressor', 'oil', 'pressure', 'switch', 'unserviceable']
# ['control', 'valve', 'unserviceable', 'see', 'long', 'text']
# ['coolant', 'pipe', 'clamps', 'needs', 'fitting', 'TBC']
# ['cracked', 'fuel', 'tank']
# ['crankcase', 'error']
# ['cutting', 'edges', 'loose']
# ['cutting', 'edges', 'need', 'change', 'out']
# ['differential', 'cooler', 'fan', 'hose', 'leaking']
# ['differential', 'cooler', 'hose', 'leaking']
# ['differential', 'cooler', 'pump', 'leaking']
# ['ripper', 'control', 'valve', 'falling', 'off']
# ['replace', 'faulty', 'brake', 'sensor', 'task']
# ['fire', 'extinguisher', 'out', 'of', 'date']
# ['grease', 'pump', 'unserviceable']
# ['transmission', 'fill', '/', 'drain', 'plug', 'unserviceable']
# ['main', 'isolator', 'needs', 'clean', 'out']
# ['grease', 'pump', 'is', 'bypassing', 'air']
# ['front', 'window', 'cracked', 'replace']
# ['fire', 'extinguisher', 'bracket', 'on', 'deck', 'loose']
# ['parts', 'washer', 'pump', 'broken']
# ['bulk', 'fuel', 'tank', 'cracked', 'and', 'leaking']
# ['swing', 'resolver', 'not', 'counting']
# ['replace', 'damage', 'auto-greaser', 'door']
# ['swing', 'resolver', 'fault']
# ['cabin', 'jacking', 'cylinder', 'ends', 'unserviceable']
# ['front', 'window', 'roller', 'blind', 'broken']
# ['AM', '/', 'FM', 'radio', 'needs', 'new', 'aerial']
# ['Tele-Remote', 'camera', 'fault']
# ['Tele-Remote', 'cameras', 'fault', 'text']
# ['fuel', 'breather', 'missing']
# ['replace', 'blocked', 'dryer']
# ['injector', 'error']
# ['[', 'shutdown', ']', 'vinyl', 'flooring', 'unserviceable']
# ['collect', 'broken', 'tooth']
# ['depth', 'counter', 'unserviceable']
# ['flow', 'battery', 'power']
# ['fuel', 'filter', 'water', 'separator', 'housing', 'broken']
# ['generator', 'flow', 'regulator', 'unserviceable']
# ['keeps', 'blowing', 'starter', '/', 'horn', 'fuse']
# ['position', 'pressure', 'compensator', 'weeping']
# ['pilot', 'valve', 'leaking', 'oil']
# ['position', 'pump', 'cavity', 'low']
# ['remove', 'unserviceable', 'air', 'separator']
# ['siren', 'unserviceable']
# ['wiper', 'fuse', 'unserviceable']
# Cluster  9
# ['backlights', 'on', 'dash', 'blown']
# ['blade', 'light', 'blown', 'needs', 'replacing']
# ['blade', 'wear', 'plates', 'cracked', 'and', 'worn']
# ['brake', 'cooling', 'hose', 'leaking']
# ['brake', 'cooling', 'hose', 'leaking', 'rear']
# ['brake', 'cooling', 'return', 'hose', 'leaking']
# ['broken', 'grease', 'plug']
# ['broken', 'hinge']
# ['broken', 'weld', 'on', 'handrail']
# ['cracked', 'steering', 'tank', 'suction', 'tube']
# ['crowd', 'cylinder', 'creeping', 'replace']
# ['damaged', 'position', 'tyre']
# ['damaged', 'position', 'tyre', 'and', 'rim']
# ['dash', 'broken']
# ['dragline', 'air', 'conditioner', 'units', 'need', 'cleaning']
# ['drivers', 'window', 'fault']
# ['position', 'brake', 'temperature', 'error']
# ['replace', 'damaged', 'position', 'tyre', 'and', 'position']
# ['grease', 'gauges', 'requires', 'replacing']
# ['replace', 'damaged', 'tyre', 'on', 'position']
# ['repair', 'exhaust', 'leaks']
# ['Tele-Remote', 'faults']
# ['emergency', 'gate', 'latch', 'broken']
# ['exhaust', 'leak']
# ['front', 'headlight', 'blown']
# ['ladder', 'fault']
# ['lube', 'fault']
# ['noisy', 'hydraulic', 'lift', 'cylinder']
# ['repaired', 'x', 'broken', 'lines']
# ['set-up', 'Tele-Remote', 'bogging']
# ['batteries', 'have', 'no', 'charge']
# ['broken', 'proximity', 'sensor', 'tag', 'carousel']
# ['ignition', 'switch', 'broken', 'replace']
# ['ignition', 'switch', 'sticking']
# ['slip', 'ring', 'overgreasing']
# Cluster  10
# ['all', 'dash', 'lights', 'on']
# ['belly', 'plate', 'bolt', 'missing']
# ['blade', 'skin', 'cracked']
# ['differential', 'lock', 'broken']
# ["driver's", 'door', 'top', 'hinge', 'broken']
# ['failed', 'PTO', 'and', 'auxiliary', 'drive', 'PO']
# ['investigate', 'engine', 'oil', 'leak']
# ['rear', 'door', 'struts', 'require', 'replacing']
# ['swing', 'brake', 'pressure', 'fault']
# ['engine', 'oil', 'leaks', 'right', 'hand', 'side']
# ['repair', 'brake', 'fault']
# ['synchronous', 'motor', 'trip']
# ['inspect', 'bad', 'engine', 'oil', 'leak']
# ['CW', 'radiator', 'core', 'leak']
# ['Tele-Remote', 'issues']
# ['engine', 'oil', 'leak']
# ['engine', 'oil', 'leak', 'inspection', 'plate']
# ['fuel', 'leak']
# ['hoist', 'drum', 'cracking']
# ['investigate', 'torque', 'converter', 'fan', 'pump', 'oil', 'leak']
# ['minor', 'transmission', 'oil', 'leak']
# ['repair', 'engine', 'oil', 'leak', 'and']
# ['repair', 'engine', 'oil', 'leaking']
# ['repair', 'engine', 'oil', 'leak', 'text']
# ['CW', 'engine', 'oil', 'leaks', 'x']
# ['CW', 'engine', 'water', 'pump', 'snapped', 'shaft']
# ['air', 'brake', 'line', 'blown', 'requires', 'replacing']
# ['engine', 'oil', 'blender', 'running', 'constantly']
# ['investigate', 'main', 'transformer', 'overload', 'fault']
# ['repair', 'faulty', 'safety', 'valve']
# Cluster  11
# ['air', 'leaking', 'from', 'line', 'outside']
# ['auto-greaser', 'leaking', 'oil']
# ['auto-spray', 'feature', 'not', 'working']
# ['blown', 'right', 'hand', 'bucket', 'cylinder', 'hose']
# ['both', 'stick', 'cylinders', 'leaking']
# ['bucket', 'cracked', 'in', 'arch', 'near', 'cancelled']
# ['cabin', 'seat', 'needs', 'replacing']
# ['chord', 'leaking', 'air', 'found']
# ['crane', 'not', 'working']
# ['replace', 'right', 'hand', 'lift', 'cylinder', 'leaking']
# ['coolant', 'leaking']
# ['right', 'hand', 'bobbin', 'roller', 'unserviceable']
# ['left', 'hand', 'side', 'pinion', 'change', 'out', 'cover', 'cracking']
# ['left', 'hand', 'rear', 'brake', 'cooling', 'hose', 'leaking']
# ['fitting', 'leaking', 'out', 'of', 'main', 'air', 'tanks']
# ['cabin', 'seat', 'unserviceable', 'needs', 'replacing']
# ['left', 'hand', 'boom', 'cylinder', 'hose', 'leaking', 'PO']
# ['left', 'hand', 'corner', 'bonnet', 'cracked']
# ['left', 'hand', 'side', 'boom', 'foot', 'crack', 'repair']
# ['lower', 'left', 'hand', 'headlight', 'blown']
# ['adaptor', 'leaking', 'at', 'implement', 'valve']
# ['number', 'right', 'hand', 'air', 'brake', 'line', 'needs', 'replacing']
# ['cracked', 'power', 'point', 'in', 'cabin']
# ['dry', 'cell', 'not', 'working', 'properly']
# ['<sensitive>', 'depth', 'counter', 'not', 'working']
# ['grease', 'distributor', 'leaking']
# ['left', 'hand', 'chain', 'guide', 'unserviceable']
# ['left', 'hand', 'chain', 'guide', 'worn', 'at', 'the', 'top']
# ['left', 'hand', 'PTO', 'pump', 'chip', 'sensor', 'harness', 'unserviceable']
# ['right', 'hand', 'PTO', 'cavity', 'emptying']
# Cluster  12
# ['air', 'filters', 'plugged']
# ['alternator', 'drive', 'leaking']
# ['auto-greaser', 'unserviceable']
# ['batteries', 'unserviceable']
# ['bearing', 'on', 'air', 'conditioner', 'compressor', 'unserviceable']
# ['blown', 'hose', 'in', 'hitch']
# ['blown', 'hose', 'on', 'boom']
# ['blown', 'oil', 'cooler', 'hose', 'x', 'metre']
# ['carousel', 'popped', 'bolt', 'needs', 'Loctite']
# ['coolant', 'hose', 'leaking', 'at', 'right', 'hand', 'bottom']
# ['cracked', 'hydraulic', 'pipe']
# ['differential', 'lube', 'pump', 'leaking']
# ['differential', 'lube', 'pump', 'leaking', 'PO']
# ['differential', 'pump', 'motor', 'hose', 'leaking']
# ['drill', 'out', 'broken', 'bolt', 'see', 'text']
# ['replace', 'leaking', 'transfer', 'pipe']
# ['replace', 'blown', 'implement', 'hose']
# ['replace', 'blown', 'right', 'hand', 'steering', 'hose']
# ['replace', 'oil', 'leaks']
# ['replace', 'leaking', 'scavenge', 'pump']
# ['replace', 'missing', 'cutting', 'edge']
# ['replace', 'x', 'cracked', 'windows']
# ['hydraulic', 'hose', 'leaking', 'in', 'centre', 'of', 'machine']
# ['replace', 'blown', 'main', 'pump', 'hose']
# ['replace', 'position', 'tyre', 'damaged']
# ['replace', 'position', 'tyre', 'mismatched']
# ['stick', 'cylinder', 'leaking']
# ['missing', 'poppet', 'valve']
# ['HMU', 'hose', 'weeping']
# ['differential', 'lube', 'hose', 'leaking']
# ['radiator', 'relief', 'valves', 'leaking']
# ['replace', 'blown', 'hose']
# ['replace', 'blown', 'work', 'lights']
# ['replace', 'broken', 'onside', 'mirror']
# ['replace', 'failed', 'air', 'conditioner', 'compressor']
# ['replace', 'leaking', 'steering', 'cylinder']
# ['replaced', 'leaking', 'steering', 'hose']
# ['aftercooler', 'temperature', 'error']
# ['battery', 'unserviceable', 'dropped', 'cell', 'replace']
# ['centrifuge', 'hose', 'leaking', 'replace']
# ['contamination', 'alarm', 'coming', 'up']
# ['contamination', 'alarm', 'on']
# ['number', 'pump', 'contamination', 'switch', 'on']
# ['pump', 'drive', 'box', 'coupling', 'and', 'shaft', 'unserviceable']
# ['replace', 'broken', 'earth', 'terminal']
# ['replace', 'chip', 'indicators', '(', 'leaking', ')']
# ['replace', 'seized', 'air', 'conditioner', 'control', 'cable']
# ['replace', 'shorted', 'diode', 'RPC']
# ['water', 'separator', 'filter', 'leaking', 'see', 'photo']
# ['water', 'separator', 'leaking', 'fuel']
# Cluster  13
# ['alternator', 'failed']
# ['analyse', 'failed', 'driveline', 'component']
# ['brake', 'release', 'fault']
# ['brake', 'temperature', 'error']
# ['broken', 'clamp', 'on', 'crowd', 'cylinder', 'hose', 'TBC']
# ['contactor', 'fault']
# ['electrical', 'harness', 'fault']
# ['hoist', 'motor', 'RTD', 'wired', 'incorrectly']
# ['bearing', 'noisy']
# ['all', 'lighting', 'requires', 'testing', 'and', 'tagging']
# ['park', 'brake', 'alarm', 'sounds', 'continuously']
# ['park', 'brake', 'alarm', 'fault']
# ['bottom', 'steering', 'shaft', 'universal', 'joint', 'worn']
# ['walk', 'motor', 'brake', 'fault']
# ['steering', 'hub', 'caps', 'require', 'replacing']
# ['park', 'brake', 'indicator', 'light', 'going', 'on', 'and', 'off']
# ['no', 'excitation', 'on', 'hoist']
# ['Tele-Remote', 'fault']
# ['brake', 'hose', 'needs', 'to', 'be', 'replaced']
# ['engine', 'vibration', '<num>-<num>', 'RPM']
# ['park', 'brake', 'fault']
# ['repair', 'transmission', 'fault']
# ['repair', 'transmission', 'oil', 'leak', 'text']
# ['steering', 'pin', 'no', 'grease', 'text']
# ['CW', 'transmission', 'failed']
# ['Tele-Remote', 'fault']
# ['blade', 'control', 'cable', 'tight']
# ['broken', 'wire', 'on', 'speaker']
# ['constant', 'voltage', 'transformer', 'melted']
# ['electric', 'propel', 'siren', 'not', 'working']
# ['equipment', 'damaged', '(', 'terminal', 'box', ')']
# ['front', 'lights', 'keep', 'blowing', 'fuse']
# ['inverter', 'earthing', 'out']
# ['radiator', 'blocked', 'with', 'grass']
# Cluster  14
# ['alarm', 'on', 'VIMS', 'does', 'not', 'work']
# ['auto-lube', 'error', 'PO']
# ['bearings', 'are', 'shot']
# ['blown', 'brake', 'hose']
# ['broken', 'air', 'conditioner', 'guard']
# ['check', '/', 'repair', 'engine', 'oil', 'leak']
# ['chord', 'pressure', 'fault']
# ['coolant', 'leak']
# ['coolant', 'leak', 'at', 'engine', 'oil', 'cooler']
# ['coolant', 'leak', 'at', 'jacket', 'water', 'pump']
# ['cords', 'cracked', 'at', 'and']
# ['differential', 'leak']
# ['differential', 'oil', 'leak']
# ['dust', 'leak', 'operators', 'side', 'window']
# ['movement', 'found', 'right', 'hand', 'engine', 'mount']
# ['oil', 'leak', 'at', 'air', 'compressor']
# ['movement', 'on', 'steering', 'column']
# ['oil', 'leak', 'swingbox']
# ['leaking', 'brake', 'cooling', 'hose']
# ['oil', 'leak', 'from', 'behind', 'water', 'pump']
# ['coolant', 'leak']
# ['differential', 'oil', 'leak']
# ['hydraulic', 'oil', 'leak', 'from', 'environmental']
# ['ripper', 'shank', 'broken']
# ['oil', 'leak', 'pilot', 'filter', 'text']
# ['air', 'pressure', 'safety', 'valve', 'exhausting']
# ['oil', 'leak', 'at', 'diverter', 'valve']
# ['oil', 'leak', 'inlet', 'to', 'oil', 'burner', 'cover', 'plate']
# ['position', 'chip', 'sensor', 'alarm']
# ['power', 'step', 'control', 'cable', 'broken']
# ['rock', 'breaker', 'cracked']
# ['rock', 'breaker', 'in', 'bucket', 'cracked', 'at', 'base']

# %% [markdown]
# ## Hierachical Clustering

# %% [markdown]
# ### Average clustering

# %%
linkage_data = linkage(cluster_embeddings, method='average')
fig = plt.figure(figsize=(25, 10))
dn = dendrogram(linkage_data)
plt.show()

# %%
k=8
cluster_labels = fcluster(linkage_data, k, criterion='maxclust')
for i in range(1,k+1):
    print("Cluster",i,":")
    cluster_words = {}
    for j in range(len(cluster_labels)):
        if cluster_labels[j]==i:
            print(" ".join(dataset_not_padded[j]))
            for word in dataset_not_padded[j]:
                if word in cluster_words:
                    cluster_words[word]+=1
                else:
                    cluster_words[word]=1
    print("Top words:")
    sorted_cluster_words = sorted(cluster_words, key=cluster_words.get, reverse=True)
    for j in range(min(len(sorted_cluster_words), 5)):
        print(sorted_cluster_words[j])
    print()
# Out:
# Cluster 1 :
# air conditioner thermostat not working
# air conditioner thermostat unserviceable
# air conditioner unserviceable
# air conditioner unserviceable when stationary
# air conditioner warm
# air conditioner compressor corroded
# air conditioner compressor unserviceable
# air conditioner fault
# air conditioner no good
# air conditioner system leaking
# air conditioner accessory drive leaking oil
# air conditioner belt broken
# air conditioner compressor not working
# air conditioner compressor tripping out
# air conditioner drive leaking
# air conditioner drive leaking oil
# air conditioner fan unserviceable fit new
# air conditioner fault
# air conditioner needs a boost not cold
# air conditioner not cold PO
# air conditioner not cold electrical faults
# air conditioner pressure switch unserviceable
# air conditioner fan speed resistor not working and
# Top words:
# air
# conditioner
# not
# unserviceable
# compressor
#
# Cluster 2 :
# air filters plugged
# air leak
# air leak near side of door
# air leaking from line outside
# airhorn not working
# alarm on VIMS does not work
# all dash lights on
# alternator drive leaking
# and lube system faults
# auto-greaser leaking oil
# auto-lube error PO
# auto-spray feature not working
# back rest unserviceable handle broken
# backhoe windscreen to be fixed
# backlight on dash unserviceable
# backlights on dash blown
# backup alarm not working
# batteries out of service
# battery cover hinges seized
# beacon not working
# bearing on air conditioner compressor unserviceable
# belly plate bolt missing
# bent belly plate
# blade light blown needs replacing
# blade skin cracked
# blade wear plates cracked and worn
# blown air conditioner hose
# blown air conditioner hose to radiator
# blown brake hose
# blown crowd cylinder hose
# blown extension line from position
# blown hose in hitch
# blown hose on boom
# blown lift cylinder o-ring
# blown light on boom
# blown o-ring off steering hose
# blown o-ring on left hand lift cylinder
# blown o-ring on steering hose
# blown oil cooler hose x metre
# blown position tyre
# blown right hand bucket cylinder hose
# blown steering hose
# blown steering pump hose
# boarding gate hinge broken
# boarding gate latch not working
# boarding ladder not working
# both stick cylinders leaking
# broken air conditioner guard
# broken grease plug
# broken hinge
# broken left hand side mirror
# broken right hand side door window
# broken ripper tooth
# broken weld on handrail
# bucket cracked in arch near cancelled
# cabin door window cracked
# cabin needs resealing
# cabin seals leaking dust PO
# cabin seals leaking dust bad
# cabin seat needs replacing
# cabin window needs resealing
# carousel popped bolt needs Loctite
# change position flat tyre
# change position tyre damage text
# check / repair engine oil leak
# chord leaking air found
# chord pressure fault
# cooler return pipe coupling leak
# cords cracked at and
# crack onside rock deflector
# cracked front window
# cracked fuel tank
# cracked hydraulic pipe
# cracked steering tank suction tube
# cracked suction tube
# cracked walkway and handrails
# crankcase error
# crowd cylinder creeping replace
# cutting edges loose
# cutting edges need change out
# dash broken
# diagnose / repair slow steering
# diagnose and repair spray faults
# diagnose and repair torque converter temperature error
# differential cooler fan hose leaking
# differential cooler hose leaking
# differential cooler pump leaking
# differential lube pump leaking
# differential lube pump leaking PO
# differential pump motor hose leaking
# dogbone pin out
# dragline air conditioner units need cleaning
# driver's door top hinge broken
# duo-cone seals leaking number swing
# dust leak operators side window
# ripper control valve falling off
# replace faulty brake sensor task
# failed PTO and auxiliary drive PO
# replace leaking transfer pipe
# front revolving light not working
# fire extinguisher out of date
# machine will not start
# possible minor leak on fuel tank
# replace blown implement hose
# rear steering accumulator leak
# replace blown right hand steering hose
# crane not working
# oil found in revolving frame
# replace oil leaks
# rear through shaft universal joint unserviceable
# all lighting requires testing and tagging
# rear wiper motor unserviceable
# front right hand roller need to be fitted
# main isolator needs clean out
# replace transmission cracked
# system pump pressure gauge not working
# replace unserviceable differential drain plugs
# investigate / repair no gear fault
# handrail above battery box cracked
# front window cracked replace
# VIMS keypad light out
# replace right hand lift cylinder leaking
# diagnose and repair ladder fault
# grease gauges requires replacing
# fire extinguisher bracket on deck loose
# rear door struts require replacing
# mechanical PTO not meshing
# replace leaking scavenge pump
# coolant leaking
# replace missing cutting edge
# movement on steering column
# replace x cracked windows
# middle air drain tap leaking
# position tyre blown
# grease system fault
# investigate auto-lube fault
# right hand bobbin roller unserviceable
# left hand side pinion change out cover cracking
# left hand rear brake cooling hose leaking
# fitting leaking out of main air tanks
# bulk fuel tank cracked and leaking
# investigate / repair joystick needs repair
# headboard welds broken / cracked
# inspect bad engine oil leak
# replace blown main pump hose
# replace cracked transmission dropbox
# front window roller blind broken
# replace position tyre damaged
# cabin seat unserviceable needs replacing
# replace position tyre mismatched
# repair exhaust leaks
# stick cylinder leaking
# PTO shaft requires replacing
# missing poppet valve
# AM / FM radio needs new aerial
# CW radiator core leak
# HMU hose weeping
# PTO shaft input seal leaking
# Tele-Remote issues
# air leak
# differential lube hose leaking
# emergency gate latch broken
# front headlight blown
# fuel cap is missing
# grease system fail
# grease system fault
# hoist drum cracking
# left hand boom cylinder hose leaking PO
# left hand corner bonnet cracked
# left hand side boom foot crack repair
# lower left hand headlight blown
# modular does not self assign
# operators seat worn padding
# radiator relief valves leaking
# rear steering accumulator leaking
# repair blown air conditioner hose
# repaired x broken lines
# replace blocked dryer
# replace blown hose
# replace blown work lights
# replace broken onside mirror
# replace cracked exhaust shield
# replace failed air conditioner compressor
# replace leaking steering cylinder
# replaced leaking steering hose
# ripper shank broken
# set-up Tele-Remote bogging
# stick cracks
# chord is leaking air from crack
# grease system has intermittent fault
# replace hydraulic oil leak text
# Bradken to repair broken clam
# CW PTO universal joint failed
# CW engine oil leaks x
# CW engine water pump snapped shaft
# CW top radiator tank leak again
# PTO input seal leaking
# adaptor leaking at implement valve
# aftercooler tank gauge broken
# aftercooler temperature error
# number right hand air brake line needs replacing
# air pressure safety valve exhausting
# batteries have no charge
# blown air conditioner fuse
# broken proximity sensor tag carousel
# cabin side weightometer not working
# cabin smoke detector missing
# centrifuge hose leaking replace
# collect broken tooth
# compressor safety valve leaking
# contamination alarm coming up
# contamination alarm on
# cracked power point in cabin
# dry cell not working properly
# diagnose / repair right hand scoreboard not working
# <sensitive> depth counter not working
# dust flap on cabin side of mast needs extending
# flow battery power
# front lights keep blowing fuse
# fuel filter water separator housing broken
# grease distributor leaking
# heat up locked steels
# hole in door frame
# keeps blowing starter / horn fuse
# key broken in ignition switch
# left hand chain guide unserviceable
# left hand chain guide worn at the top
# left hand PTO pump chip sensor harness unserviceable
# number pump contamination switch on
# number slew pump contamination switch unserviceable
# glass window has large crack
# position pressure compensator weeping
# position chip sensor alarm
# power step control cable broken
# pressure compensator leaking
# pressure control valve in cabin leaking
# pump drive box coupling and shaft unserviceable
# right hand PTO cavity emptying
# replace broken earth terminal
# replace chip indicators ( leaking )
# replace cracked glass in entry door
# replace cracked water separator
# replace seized air conditioner control cable
# replace shorted diode RPC
# replace unserviceable grease distributor
# replace unserviceable chip indicators
# replace unserviceable ignition switch
# replace unserviceable transmission screen and magnet
# rock breaker cracked
# rock breaker in bucket cracked at base
# safety flag missing
# slip ring overgreasing
# troubleshoot smart meter not communicating
# water separator filter leaking see photo
# water separator leaking fuel
# will not start batteries unserviceable
# window frame needs repair
# Top words:
# leaking
# replace
# blown
# hose
# broken
#
# Cluster 3 :
# armrest unserviceable
# auto-greaser unserviceable
# batteries discharging
# batteries unserviceable
# beacon mount is broken
# beacon unserviceable
# bearings are shot
# centrifugal oil filter fault
# centrifugal oil filter leaking
# compressor oil pressure switch unserviceable
# control valve unserviceable see long text
# coolant leak
# coolant leak at engine oil cooler
# coolant leak at jacket water pump
# coolant pipe clamps needs fitting TBC
# differential leak
# differential oil leak
# grease pump unserviceable
# transmission fill / drain plug unserviceable
# bearing noisy
# movement found right hand engine mount
# investigate and repair oil leak
# grease pump is bypassing air
# investigate engine oil leak
# oil leak at air compressor
# oil leak swingbox
# parts washer pump broken
# engine oil leaks right hand side
# synchronous motor trip
# cabin jacking cylinder ends unserviceable
# oil leak from behind water pump
# coolant leak
# differential oil leak
# engine fan hose weeping
# engine oil leak
# engine oil leak inspection plate
# engine vibration <num>-<num> RPM
# exhaust leak
# fuel breather missing
# fuel leak
# hose leak developing
# hydraulic oil leak from environmental
# investigate torque converter fan pump oil leak
# noisy hydraulic lift cylinder
# oil leak pilot filter text
# injector error
# [ shutdown ] vinyl flooring unserviceable
# battery unserviceable dropped cell replace
# constant voltage transformer melted
# depth counter unserviceable
# electric propel siren not working
# engine oil blender running constantly
# generator flow regulator unserviceable
# ignition switch broken replace
# ignition switch sticking
# inverter earthing out
# microwave oven unserviceable
# oil centrifuge gasket leaking right hand engine
# oil leak at diverter valve
# oil leak inlet to oil burner cover plate
# pilot valve leaking oil
# position pump cavity low
# remove unserviceable air separator
# siren unserviceable
# transformer trip
# weightometer display on trailer unserviceable
# wiper fuse unserviceable
# Top words:
# oil
# leak
# unserviceable
# engine
# pump
#
# Cluster 4 :
# air horn disconnected
# air horn does not work
# air horn fault
# air horn not working
# air horn not working compressor awaiting
# air horn stuck on
# air horn unserviceable
# air horn working intermittently
# alternator failed
# alternator not charging
# alternator overcharged
# analyse failed driveline component
# axle temperature fault
# axle temperature sensor fault
# brake cooling hose leaking
# brake cooling hose leaking rear
# brake cooling return hose leaking
# brake release fault
# brake temperature error
# broken clamp on crowd cylinder hose TBC
# broken fuel cooler mounts
# broken joystick PO
# broken mirror
# camera fault
# contactor fault
# damage to position tyre
# damaged position tyre
# damaged position tyre and rim
# diagnose engine fault
# diagnose transmission overheat fault
# diagnose transmission slipping fault
# differential lock broken
# drivers window fault
# electrical harness fault
# speedometer not working
# cable gantry crack repairs
# drag tripped on electrical
# position brake temperature error
# hoist motor RTD wired incorrectly
# IOV fault on drag package
# steering cylinder bearings have excess play
# park brake alarm sounds continuously
# park brake alarm fault
# replace damaged position tyre and position
# ground fault welding board
# swing brake pressure fault
# tail pulley has no grease lines
# ground fault in propel
# brake warning light on
# leaking brake cooling hose
# faulty fuel pressure sensor
# bottom steering shaft universal joint worn
# replace damaged tyre on position
# walk motor brake fault
# tray fault
# steering hub caps require replacing
# replace damage auto-greaser door
# hoist brake switches need adjusting
# park brake indicator light going on and off
# tracks need adjusting
# no excitation on hoist
# diagnose VIMS error
# hoist brake number position out of adjustment
# Tele-Remote fault
# Tele-Remote faults
# air horn not working
# brake hose needs to be replaced
# engine bay light blown
# engine overheating
# engine shutdown fault
# ladder fault
# lube fault
# minor transmission oil leak
# no reception on AM / FM radio
# park brake fault
# transmission charge hose leaking
# engine shutdown fault
# steering pin no grease text
# transmission temperature fault
# CW transmission failed
# Tele-Remote fault
# VIMS fuel filter plugged
# air brake line blown requires replacing
# blade control cable tight
# broken wire on speaker
# earth wire broken on bottom of radiator
# equipment damaged ( terminal box )
# flag missing
# high voltage slip ring inspection grease leak
# investigate main transformer overload fault
# radiator blocked with grass
# radiator sight glasses unserviceable
# start motorvator and set limits
# TV monitor does not turn on
# TV monitor has no signal
# voltage regulator fuse fault
# Top words:
# fault
# brake
# on
# air
# horn
#
# Cluster 5 :
# change out blown o-ring on steering pump
# change out blown position tyre
# change out blown steering hose
# change out broken bolt on brake pump
# change out broken prelube bracket
# change out broken stabilizer bar
# change out cracked pipe on valve bank
# change out cracked position adaptor and tooth
# change out exhaust clamp broken on left hand side [t |]
# change out front upper window cracked
# change out leak slew motor hose
# change out leaking HMU on next
# change out leaking fan hoses
# change out leaking heater taps
# change out leaking hydraulic hose
# change out leaking implement pump
# change out leaking relay valve
# change out leaking steering hose
# change out left hand steering cylinder leaking
# change out position and tyre worn out
# change out position tyre sensor not reading
# change out position tyre damage
# change out unserviceable jacket water pump
# change out unserviceable left hand bucket cylinder hose
# change out unserviceable position tyre
# change out unserviceable right hand clam cylinder hose
# change out unserviceable right hand tilt cylinder
# change out unserviceable swing brake cylinder
# change out weeping boom cylinder hose
# change out worn position tyre
# drill out broken bolt see text
# change out leaking transmission hose
# change out position tyre worn
# change out blown hose
# change out broken grease lines
# change out leaking transmission hose
# change out number faulty injector assembly
# change out plugged fuel filters
# change out worn ripper tip ripper tip
# GET change out worn cutting edges
# Top words:
# out
# change
# hose
# leaking
# position
#
# Cluster 6 :
# alternator overcharge fault
# coolant hose leaking at right hand bottom
# drag generator fault
# hydraulic hose leaking in centre of machine
# swing resolver not counting
# swing resolver fault
# drag chain fault
# Tele-Remote camera fault
# Tele-Remote cameras fault text
# fan hose leaking
# heater hose in cabin roof unserviceable
# Top words:
# fault
# hose
# leaking
# drag
# in
#
# Cluster 7 :
# crack in blade liner left hand side
# crack in boom chord
# crack in fuel tank
# crack in headboard
# crack in lower centre of windscreen
# crack in windscreen
# cracks in back right hand side handrail
# cracks in decking
# cracks in diagonal braces in front
# cracks in fire suppression mounts
# cracks in headboard
# cracks in the dirt chute
# repair cracks in mud bucket
# repair leaking swing pedestal seals
# repair right hand fuel tank crack
# repair cracks on stick
# repair boom cracks left hand side
# repair centre hitch oil leaks
# repair oil leak position wheel end
# repair air conditioner and wiring fault
# repair movement in left hand steering pin
# CW left hand hoist cylinder leaking plug
# CW right hand hoist cylinder leaking
# repair cracked steering tank mo
# repair leaking centrifugal filter
# repair right hand track frame crack
# crack repairs left hand window frame
# repair crack in right hand side of rear cross member
# repair air leak at air tank safety valve
# repair chassis crack at right hand rear cross member
# repair crack in rear cross member
# repair crack on left hand front heat shield
# repair cracked baffle in hydraulic tank
# repair cracked roof skin left hand side exhaust
# repair cracks in mast cross braces
# repair faulty safety valve
# repair left hand scoreboard base cracked
# repair leak in pilot valve solenoid
# repair worn centrifuge filter
# Top words:
# repair
# in
# hand
# crack
# cracks
#
# Cluster 8 :
# repair brake fault
# repair gear fault
# repair engine oil leak and
# repair engine oil leaking
# repair transmission fault
# repair engine oil leak text
# repair transmission oil leak text
# Top words:
# repair
# oil
# fault
# engine
# leak

# %% [markdown]
# ### ward clustering

# %%
linkage_data = linkage(cluster_embeddings, method='ward')
fig = plt.figure(figsize=(25, 10))
dn = dendrogram(linkage_data)
plt.show()

# %%
k=7
cluster_labels = fcluster(linkage_data, k, criterion='maxclust')
for i in range(1,k+1):
    print("Cluster",i,":")
    cluster_words = {}
    for j in range(len(cluster_labels)):
        if cluster_labels[j]==i:
            print(" ".join(dataset_not_padded[j]))
            for word in dataset_not_padded[j]:
                if word in cluster_words:
                    cluster_words[word]+=1
                else:
                    cluster_words[word]=1
    print("Top words:")
    sorted_cluster_words = sorted(cluster_words, key=cluster_words.get, reverse=True)
    for j in range(min(len(sorted_cluster_words), 5)):
        print(sorted_cluster_words[j])
    print()
# Out:
# Cluster 1 :
# change out blown o-ring on steering pump
# change out blown position tyre
# change out blown steering hose
# change out broken bolt on brake pump
# change out broken prelube bracket
# change out broken stabilizer bar
# change out cracked pipe on valve bank
# change out cracked position adaptor and tooth
# change out exhaust clamp broken on left hand side [t |]
# change out front upper window cracked
# change out leak slew motor hose
# change out leaking HMU on next
# change out leaking fan hoses
# change out leaking heater taps
# change out leaking hydraulic hose
# change out leaking implement pump
# change out leaking relay valve
# change out leaking steering hose
# change out left hand steering cylinder leaking
# change out position and tyre worn out
# change out position tyre sensor not reading
# change out position tyre damage
# change out unserviceable jacket water pump
# change out unserviceable left hand bucket cylinder hose
# change out unserviceable position tyre
# change out unserviceable right hand clam cylinder hose
# change out unserviceable right hand tilt cylinder
# change out unserviceable swing brake cylinder
# change out weeping boom cylinder hose
# change out worn position tyre
# change out leaking transmission hose
# change out position tyre worn
# change out blown hose
# change out broken grease lines
# change out leaking transmission hose
# change out number faulty injector assembly
# change out plugged fuel filters
# change out worn ripper tip ripper tip
# Top words:
# out
# change
# hose
# leaking
# position
#
# Cluster 2 :
# air conditioner thermostat not working
# air conditioner thermostat unserviceable
# air conditioner unserviceable
# air conditioner unserviceable when stationary
# air conditioner warm
# air filters plugged
# air horn disconnected
# air horn does not work
# air horn fault
# air horn not working
# air horn not working compressor awaiting
# air horn stuck on
# air horn unserviceable
# air horn working intermittently
# air leak
# air leak near side of door
# air leaking from line outside
# batteries out of service
# blown air conditioner hose
# blown air conditioner hose to radiator
# broken air conditioner guard
# dragline air conditioner units need cleaning
# dust leak operators side window
# middle air drain tap leaking
# repair air conditioner and wiring fault
# air conditioner compressor corroded
# air conditioner compressor unserviceable
# air conditioner fault
# air conditioner no good
# air conditioner system leaking
# air horn not working
# air leak
# exhaust leak
# fuel leak
# CW top radiator tank leak again
# GET change out worn cutting edges
# air conditioner accessory drive leaking oil
# air conditioner belt broken
# air conditioner compressor not working
# air conditioner compressor tripping out
# air conditioner drive leaking
# air conditioner drive leaking oil
# air conditioner fan unserviceable fit new
# air conditioner fault
# air conditioner needs a boost not cold
# air conditioner not cold PO
# air conditioner not cold electrical faults
# air conditioner pressure switch unserviceable
# air conditioner fan speed resistor not working and
# air pressure safety valve exhausting
# blown air conditioner fuse
# repair air leak at air tank safety valve
# Top words:
# air
# conditioner
# not
# horn
# leak
#
# Cluster 3 :
# check / repair engine oil leak
# crack in blade liner left hand side
# crack in boom chord
# crack in fuel tank
# crack in headboard
# crack in lower centre of windscreen
# crack in windscreen
# cracks in back right hand side handrail
# cracks in decking
# cracks in diagonal braces in front
# cracks in fire suppression mounts
# cracks in headboard
# cracks in the dirt chute
# diagnose / repair slow steering
# diagnose and repair spray faults
# diagnose and repair torque converter temperature error
# repair cracks in mud bucket
# repair leaking swing pedestal seals
# investigate and repair oil leak
# repair right hand fuel tank crack
# repair cracks on stick
# repair boom cracks left hand side
# investigate / repair no gear fault
# diagnose and repair ladder fault
# repair centre hitch oil leaks
# investigate / repair joystick needs repair
# repair movement in left hand steering pin
# repair exhaust leaks
# repair cracked steering tank mo
# repair engine oil leak and
# repair engine oil leaking
# repair leaking centrifugal filter
# repair right hand track frame crack
# repair transmission fault
# repair engine oil leak text
# repair transmission oil leak text
# diagnose / repair right hand scoreboard not working
# repair crack in right hand side of rear cross member
# repair chassis crack at right hand rear cross member
# repair crack in rear cross member
# repair crack on left hand front heat shield
# repair cracked baffle in hydraulic tank
# repair cracked roof skin left hand side exhaust
# repair cracks in mast cross braces
# repair faulty safety valve
# repair left hand scoreboard base cracked
# repair leak in pilot valve solenoid
# repair worn centrifuge filter
# Top words:
# repair
# in
# crack
# hand
# cracks
#
# Cluster 4 :
# airhorn not working
# alarm on VIMS does not work
# all dash lights on
# alternator drive leaking
# alternator failed
# alternator not charging
# alternator overcharge fault
# alternator overcharged
# analyse failed driveline component
# and lube system faults
# auto-lube error PO
# auto-spray feature not working
# axle temperature fault
# axle temperature sensor fault
# backhoe windscreen to be fixed
# backlights on dash blown
# backup alarm not working
# batteries discharging
# battery cover hinges seized
# beacon not working
# bearing on air conditioner compressor unserviceable
# bearings are shot
# belly plate bolt missing
# bent belly plate
# blade light blown needs replacing
# blade skin cracked
# blade wear plates cracked and worn
# blown oil cooler hose x metre
# boarding ladder not working
# both stick cylinders leaking
# brake release fault
# brake temperature error
# bucket cracked in arch near cancelled
# cabin door window cracked
# cabin needs resealing
# cabin seat needs replacing
# cabin window needs resealing
# camera fault
# carousel popped bolt needs Loctite
# chord leaking air found
# chord pressure fault
# contactor fault
# control valve unserviceable see long text
# coolant pipe clamps needs fitting TBC
# cooler return pipe coupling leak
# cords cracked at and
# crack onside rock deflector
# cracked front window
# cracked fuel tank
# cracked hydraulic pipe
# cracked steering tank suction tube
# cracked suction tube
# cracked walkway and handrails
# crankcase error
# cutting edges loose
# cutting edges need change out
# diagnose engine fault
# diagnose transmission overheat fault
# diagnose transmission slipping fault
# differential lock broken
# drivers window fault
# electrical harness fault
# ripper control valve falling off
# speedometer not working
# cable gantry crack repairs
# failed PTO and auxiliary drive PO
# drag tripped on electrical
# front revolving light not working
# fire extinguisher out of date
# hoist motor RTD wired incorrectly
# machine will not start
# possible minor leak on fuel tank
# rear steering accumulator leak
# crane not working
# grease pump unserviceable
# transmission fill / drain plug unserviceable
# bearing noisy
# IOV fault on drag package
# rear through shaft universal joint unserviceable
# all lighting requires testing and tagging
# movement found right hand engine mount
# rear wiper motor unserviceable
# main isolator needs clean out
# park brake alarm sounds continuously
# system pump pressure gauge not working
# grease pump is bypassing air
# park brake alarm fault
# handrail above battery box cracked
# front window cracked replace
# VIMS keypad light out
# investigate engine oil leak
# ground fault welding board
# grease gauges requires replacing
# fire extinguisher bracket on deck loose
# rear door struts require replacing
# mechanical PTO not meshing
# swing brake pressure fault
# tail pulley has no grease lines
# movement on steering column
# ground fault in propel
# drag generator fault
# grease system fault
# investigate auto-lube fault
# brake warning light on
# faulty fuel pressure sensor
# bottom steering shaft universal joint worn
# repair brake fault
# synchronous motor trip
# walk motor brake fault
# tray fault
# steering hub caps require replacing
# bulk fuel tank cracked and leaking
# swing resolver not counting
# repair gear fault
# swing resolver fault
# drag chain fault
# inspect bad engine oil leak
# hoist brake switches need adjusting
# cabin jacking cylinder ends unserviceable
# park brake indicator light going on and off
# tracks need adjusting
# front window roller blind broken
# cabin seat unserviceable needs replacing
# diagnose VIMS error
# hoist brake number position out of adjustment
# PTO shaft requires replacing
# missing poppet valve
# AM / FM radio needs new aerial
# CW left hand hoist cylinder leaking plug
# CW radiator core leak
# CW right hand hoist cylinder leaking
# HMU hose weeping
# PTO shaft input seal leaking
# Tele-Remote camera fault
# Tele-Remote cameras fault text
# Tele-Remote fault
# Tele-Remote faults
# Tele-Remote issues
# brake hose needs to be replaced
# engine bay light blown
# engine fan hose weeping
# engine overheating
# engine shutdown fault
# engine vibration <num>-<num> RPM
# front headlight blown
# fuel breather missing
# fuel cap is missing
# grease system fail
# grease system fault
# hoist drum cracking
# hose leak developing
# investigate torque converter fan pump oil leak
# ladder fault
# lube fault
# minor transmission oil leak
# modular does not self assign
# noisy hydraulic lift cylinder
# operators seat worn padding
# park brake fault
# rear steering accumulator leaking
# set-up Tele-Remote bogging
# stick cracks
# transmission charge hose leaking
# chord is leaking air from crack
# engine shutdown fault
# grease system has intermittent fault
# steering pin no grease text
# transmission temperature fault
# injector error
# CW PTO universal joint failed
# CW engine oil leaks x
# CW engine water pump snapped shaft
# CW transmission failed
# PTO input seal leaking
# Tele-Remote fault
# VIMS fuel filter plugged
# aftercooler temperature error
# number right hand air brake line needs replacing
# [ shutdown ] vinyl flooring unserviceable
# batteries have no charge
# blade control cable tight
# cabin side weightometer not working
# cabin smoke detector missing
# constant voltage transformer melted
# contamination alarm coming up
# contamination alarm on
# crack repairs left hand window frame
# cracked power point in cabin
# dry cell not working properly
# <sensitive> depth counter not working
# dust flap on cabin side of mast needs extending
# electric propel siren not working
# equipment damaged ( terminal box )
# flag missing
# front lights keep blowing fuse
# fuel filter water separator housing broken
# generator flow regulator unserviceable
# heat up locked steels
# heater hose in cabin roof unserviceable
# hole in door frame
# high voltage slip ring inspection grease leak
# inverter earthing out
# investigate main transformer overload fault
# keeps blowing starter / horn fuse
# number pump contamination switch on
# number slew pump contamination switch unserviceable
# glass window has large crack
# pressure control valve in cabin leaking
# pump drive box coupling and shaft unserviceable
# radiator blocked with grass
# radiator sight glasses unserviceable
# rock breaker cracked
# rock breaker in bucket cracked at base
# safety flag missing
# slip ring overgreasing
# start motorvator and set limits
# troubleshoot smart meter not communicating
# transformer trip
# TV monitor does not turn on
# TV monitor has no signal
# voltage regulator fuse fault
# weightometer display on trailer unserviceable
# window frame needs repair
# Top words:
# fault
# not
# cracked
# on
# unserviceable
#
# Cluster 5 :
# armrest unserviceable
# auto-greaser unserviceable
# back rest unserviceable handle broken
# backlight on dash unserviceable
# batteries unserviceable
# beacon mount is broken
# beacon unserviceable
# blown brake hose
# blown crowd cylinder hose
# blown extension line from position
# blown hose in hitch
# blown hose on boom
# blown lift cylinder o-ring
# blown light on boom
# blown o-ring off steering hose
# blown o-ring on left hand lift cylinder
# blown o-ring on steering hose
# blown position tyre
# blown right hand bucket cylinder hose
# blown steering hose
# blown steering pump hose
# boarding gate hinge broken
# boarding gate latch not working
# broken clamp on crowd cylinder hose TBC
# broken fuel cooler mounts
# broken grease plug
# broken hinge
# broken joystick PO
# broken left hand side mirror
# broken mirror
# broken right hand side door window
# broken ripper tooth
# broken weld on handrail
# change position flat tyre
# change position tyre damage text
# damage to position tyre
# damaged position tyre
# damaged position tyre and rim
# dash broken
# dogbone pin out
# drill out broken bolt see text
# driver's door top hinge broken
# position brake temperature error
# parts washer pump broken
# position tyre blown
# headboard welds broken / cracked
# no excitation on hoist
# emergency gate latch broken
# no reception on AM / FM radio
# repair blown air conditioner hose
# repaired x broken lines
# ripper shank broken
# Bradken to repair broken clam
# aftercooler tank gauge broken
# air brake line blown requires replacing
# battery unserviceable dropped cell replace
# broken proximity sensor tag carousel
# broken wire on speaker
# collect broken tooth
# depth counter unserviceable
# earth wire broken on bottom of radiator
# flow battery power
# ignition switch broken replace
# ignition switch sticking
# key broken in ignition switch
# microwave oven unserviceable
# position pressure compensator weeping
# position chip sensor alarm
# position pump cavity low
# power step control cable broken
# remove unserviceable air separator
# siren unserviceable
# will not start batteries unserviceable
# wiper fuse unserviceable
# Top words:
# broken
# blown
# unserviceable
# position
# on
#
# Cluster 6 :
# replace faulty brake sensor task
# replace leaking transfer pipe
# replace blown implement hose
# replace blown right hand steering hose
# replace transmission cracked
# replace unserviceable differential drain plugs
# replace right hand lift cylinder leaking
# replace damaged position tyre and position
# replace leaking scavenge pump
# replace missing cutting edge
# replace x cracked windows
# replace damaged tyre on position
# replace damage auto-greaser door
# replace blown main pump hose
# replace cracked transmission dropbox
# replace position tyre damaged
# replace position tyre mismatched
# replace blocked dryer
# replace blown hose
# replace blown work lights
# replace broken onside mirror
# replace cracked exhaust shield
# replace failed air conditioner compressor
# replace leaking steering cylinder
# replace hydraulic oil leak text
# replace broken earth terminal
# replace chip indicators ( leaking )
# replace cracked glass in entry door
# replace cracked water separator
# replace seized air conditioner control cable
# replace shorted diode RPC
# replace unserviceable grease distributor
# replace unserviceable chip indicators
# replace unserviceable ignition switch
# replace unserviceable transmission screen and magnet
# Top words:
# replace
# cracked
# leaking
# blown
# unserviceable
#
# Cluster 7 :
# auto-greaser leaking oil
# brake cooling hose leaking
# brake cooling hose leaking rear
# brake cooling return hose leaking
# cabin seals leaking dust PO
# cabin seals leaking dust bad
# centrifugal oil filter fault
# centrifugal oil filter leaking
# compressor oil pressure switch unserviceable
# coolant hose leaking at right hand bottom
# coolant leak
# coolant leak at engine oil cooler
# coolant leak at jacket water pump
# crowd cylinder creeping replace
# differential cooler fan hose leaking
# differential cooler hose leaking
# differential cooler pump leaking
# differential leak
# differential lube pump leaking
# differential lube pump leaking PO
# differential oil leak
# differential pump motor hose leaking
# duo-cone seals leaking number swing
# oil found in revolving frame
# replace oil leaks
# steering cylinder bearings have excess play
# front right hand roller need to be fitted
# oil leak at air compressor
# coolant leaking
# oil leak swingbox
# engine oil leaks right hand side
# leaking brake cooling hose
# right hand bobbin roller unserviceable
# left hand side pinion change out cover cracking
# left hand rear brake cooling hose leaking
# fitting leaking out of main air tanks
# repair oil leak position wheel end
# hydraulic hose leaking in centre of machine
# oil leak from behind water pump
# stick cylinder leaking
# coolant leak
# differential lube hose leaking
# differential oil leak
# engine oil leak
# engine oil leak inspection plate
# fan hose leaking
# hydraulic oil leak from environmental
# left hand boom cylinder hose leaking PO
# left hand corner bonnet cracked
# left hand side boom foot crack repair
# lower left hand headlight blown
# radiator relief valves leaking
# replaced leaking steering hose
# oil leak pilot filter text
# adaptor leaking at implement valve
# centrifuge hose leaking replace
# compressor safety valve leaking
# engine oil blender running constantly
# grease distributor leaking
# left hand chain guide unserviceable
# left hand chain guide worn at the top
# left hand PTO pump chip sensor harness unserviceable
# oil centrifuge gasket leaking right hand engine
# oil leak at diverter valve
# oil leak inlet to oil burner cover plate
# pilot valve leaking oil
# pressure compensator leaking
# right hand PTO cavity emptying
# water separator filter leaking see photo
# water separator leaking fuel
# Top words:
# leaking
# oil
# leak
# hose
# hand

# %% [markdown]
# ### centroid clustering

# %%
linkage_data = linkage(cluster_embeddings, method='centroid')
fig = plt.figure(figsize=(25, 10))
dn = dendrogram(linkage_data)
plt.show()

# %%
k=8
cluster_labels = fcluster(linkage_data, k, criterion='maxclust')
for i in range(1,k+1):
    print("Cluster",i,":")
    cluster_words = {}
    for j in range(len(cluster_labels)):
        if cluster_labels[j]==i:
            print(" ".join(dataset_not_padded[j]))
            for word in dataset_not_padded[j]:
                if word in cluster_words:
                    cluster_words[word]+=1
                else:
                    cluster_words[word]=1
    print("Top words:")
    sorted_cluster_words = sorted(cluster_words, key=cluster_words.get, reverse=True)
    for j in range(min(len(sorted_cluster_words), 5)):
        print(sorted_cluster_words[j])
    print()
# Out:
# Cluster 1 :
# front right hand roller need to be fitted
# right hand bobbin roller unserviceable
# left hand side pinion change out cover cracking
# left hand rear brake cooling hose leaking
# left hand boom cylinder hose leaking PO
# left hand corner bonnet cracked
# left hand side boom foot crack repair
# lower left hand headlight blown
# left hand chain guide unserviceable
# left hand chain guide worn at the top
# left hand PTO pump chip sensor harness unserviceable
# right hand PTO cavity emptying
# Top words:
# hand
# left
# right
# unserviceable
# roller
#
# Cluster 2 :
# replace faulty brake sensor task
# replace leaking transfer pipe
# replace oil leaks
# replace transmission cracked
# replace unserviceable differential drain plugs
# replace right hand lift cylinder leaking
# replace damaged position tyre and position
# replace leaking scavenge pump
# replace missing cutting edge
# replace x cracked windows
# replace damaged tyre on position
# replace damage auto-greaser door
# replace cracked transmission dropbox
# replace position tyre damaged
# replace position tyre mismatched
# replace blocked dryer
# replace broken onside mirror
# replace cracked exhaust shield
# replace failed air conditioner compressor
# replace leaking steering cylinder
# replace hydraulic oil leak text
# replace broken earth terminal
# replace chip indicators ( leaking )
# replace cracked glass in entry door
# replace cracked water separator
# replace seized air conditioner control cable
# replace shorted diode RPC
# replace unserviceable grease distributor
# replace unserviceable chip indicators
# replace unserviceable ignition switch
# replace unserviceable transmission screen and magnet
# Top words:
# replace
# cracked
# leaking
# unserviceable
# position
#
# Cluster 3 :
# airhorn not working
# alarm on VIMS does not work
# all dash lights on
# alternator drive leaking
# alternator failed
# alternator not charging
# alternator overcharge fault
# alternator overcharged
# analyse failed driveline component
# and lube system faults
# armrest unserviceable
# auto-greaser leaking oil
# auto-greaser unserviceable
# auto-lube error PO
# auto-spray feature not working
# axle temperature fault
# axle temperature sensor fault
# back rest unserviceable handle broken
# backhoe windscreen to be fixed
# backlight on dash unserviceable
# backlights on dash blown
# backup alarm not working
# batteries discharging
# batteries out of service
# batteries unserviceable
# battery cover hinges seized
# beacon mount is broken
# beacon not working
# beacon unserviceable
# bearing on air conditioner compressor unserviceable
# bearings are shot
# belly plate bolt missing
# bent belly plate
# blade light blown needs replacing
# blade skin cracked
# blade wear plates cracked and worn
# blown brake hose
# blown crowd cylinder hose
# blown extension line from position
# blown hose in hitch
# blown hose on boom
# blown lift cylinder o-ring
# blown light on boom
# blown o-ring off steering hose
# blown o-ring on left hand lift cylinder
# blown o-ring on steering hose
# blown oil cooler hose x metre
# blown position tyre
# blown right hand bucket cylinder hose
# blown steering hose
# blown steering pump hose
# boarding gate hinge broken
# boarding gate latch not working
# boarding ladder not working
# both stick cylinders leaking
# brake cooling hose leaking
# brake cooling hose leaking rear
# brake cooling return hose leaking
# brake release fault
# brake temperature error
# broken clamp on crowd cylinder hose TBC
# broken fuel cooler mounts
# broken grease plug
# broken hinge
# broken joystick PO
# broken left hand side mirror
# broken mirror
# broken right hand side door window
# broken ripper tooth
# broken weld on handrail
# bucket cracked in arch near cancelled
# cabin door window cracked
# cabin needs resealing
# cabin seals leaking dust PO
# cabin seals leaking dust bad
# cabin seat needs replacing
# cabin window needs resealing
# camera fault
# carousel popped bolt needs Loctite
# centrifugal oil filter fault
# centrifugal oil filter leaking
# change position flat tyre
# change position tyre damage text
# check / repair engine oil leak
# chord leaking air found
# chord pressure fault
# compressor oil pressure switch unserviceable
# contactor fault
# control valve unserviceable see long text
# coolant hose leaking at right hand bottom
# coolant leak
# coolant leak at engine oil cooler
# coolant leak at jacket water pump
# coolant pipe clamps needs fitting TBC
# cooler return pipe coupling leak
# cords cracked at and
# crack in blade liner left hand side
# crack in boom chord
# crack in fuel tank
# crack in headboard
# crack in lower centre of windscreen
# crack in windscreen
# crack onside rock deflector
# cracked front window
# cracked fuel tank
# cracked hydraulic pipe
# cracked steering tank suction tube
# cracked suction tube
# cracked walkway and handrails
# cracks in back right hand side handrail
# cracks in decking
# cracks in diagonal braces in front
# cracks in fire suppression mounts
# cracks in headboard
# cracks in the dirt chute
# crankcase error
# crowd cylinder creeping replace
# cutting edges loose
# cutting edges need change out
# damage to position tyre
# damaged position tyre
# damaged position tyre and rim
# dash broken
# diagnose / repair slow steering
# diagnose and repair spray faults
# diagnose and repair torque converter temperature error
# diagnose engine fault
# diagnose transmission overheat fault
# diagnose transmission slipping fault
# differential cooler fan hose leaking
# differential cooler hose leaking
# differential cooler pump leaking
# differential leak
# differential lock broken
# differential lube pump leaking
# differential lube pump leaking PO
# differential oil leak
# differential pump motor hose leaking
# dogbone pin out
# drill out broken bolt see text
# driver's door top hinge broken
# drivers window fault
# duo-cone seals leaking number swing
# dust leak operators side window
# electrical harness fault
# ripper control valve falling off
# repair cracks in mud bucket
# speedometer not working
# cable gantry crack repairs
# failed PTO and auxiliary drive PO
# drag tripped on electrical
# position brake temperature error
# front revolving light not working
# fire extinguisher out of date
# hoist motor RTD wired incorrectly
# machine will not start
# possible minor leak on fuel tank
# replace blown implement hose
# rear steering accumulator leak
# replace blown right hand steering hose
# crane not working
# grease pump unserviceable
# transmission fill / drain plug unserviceable
# bearing noisy
# oil found in revolving frame
# IOV fault on drag package
# rear through shaft universal joint unserviceable
# repair leaking swing pedestal seals
# all lighting requires testing and tagging
# steering cylinder bearings have excess play
# movement found right hand engine mount
# rear wiper motor unserviceable
# main isolator needs clean out
# investigate and repair oil leak
# park brake alarm sounds continuously
# system pump pressure gauge not working
# repair right hand fuel tank crack
# grease pump is bypassing air
# park brake alarm fault
# repair cracks on stick
# repair boom cracks left hand side
# investigate / repair no gear fault
# handrail above battery box cracked
# front window cracked replace
# VIMS keypad light out
# investigate engine oil leak
# diagnose and repair ladder fault
# ground fault welding board
# grease gauges requires replacing
# fire extinguisher bracket on deck loose
# rear door struts require replacing
# mechanical PTO not meshing
# swing brake pressure fault
# oil leak at air compressor
# coolant leaking
# tail pulley has no grease lines
# movement on steering column
# oil leak swingbox
# ground fault in propel
# drag generator fault
# parts washer pump broken
# engine oil leaks right hand side
# position tyre blown
# grease system fault
# investigate auto-lube fault
# brake warning light on
# leaking brake cooling hose
# faulty fuel pressure sensor
# bottom steering shaft universal joint worn
# repair brake fault
# synchronous motor trip
# walk motor brake fault
# tray fault
# fitting leaking out of main air tanks
# repair centre hitch oil leaks
# repair oil leak position wheel end
# steering hub caps require replacing
# bulk fuel tank cracked and leaking
# hydraulic hose leaking in centre of machine
# swing resolver not counting
# repair gear fault
# swing resolver fault
# investigate / repair joystick needs repair
# drag chain fault
# headboard welds broken / cracked
# inspect bad engine oil leak
# hoist brake switches need adjusting
# cabin jacking cylinder ends unserviceable
# repair movement in left hand steering pin
# replace blown main pump hose
# park brake indicator light going on and off
# tracks need adjusting
# no excitation on hoist
# front window roller blind broken
# cabin seat unserviceable needs replacing
# diagnose VIMS error
# oil leak from behind water pump
# repair exhaust leaks
# stick cylinder leaking
# hoist brake number position out of adjustment
# PTO shaft requires replacing
# missing poppet valve
# AM / FM radio needs new aerial
# CW left hand hoist cylinder leaking plug
# CW radiator core leak
# CW right hand hoist cylinder leaking
# HMU hose weeping
# PTO shaft input seal leaking
# Tele-Remote camera fault
# Tele-Remote cameras fault text
# Tele-Remote fault
# Tele-Remote faults
# Tele-Remote issues
# brake hose needs to be replaced
# coolant leak
# differential lube hose leaking
# differential oil leak
# emergency gate latch broken
# engine bay light blown
# engine fan hose weeping
# engine oil leak
# engine oil leak inspection plate
# engine overheating
# engine shutdown fault
# engine vibration <num>-<num> RPM
# exhaust leak
# fan hose leaking
# front headlight blown
# fuel breather missing
# fuel cap is missing
# fuel leak
# grease system fail
# grease system fault
# hoist drum cracking
# hose leak developing
# hydraulic oil leak from environmental
# investigate torque converter fan pump oil leak
# ladder fault
# lube fault
# minor transmission oil leak
# modular does not self assign
# no reception on AM / FM radio
# noisy hydraulic lift cylinder
# operators seat worn padding
# park brake fault
# radiator relief valves leaking
# rear steering accumulator leaking
# repair blown air conditioner hose
# repair cracked steering tank mo
# repair engine oil leak and
# repair engine oil leaking
# repair leaking centrifugal filter
# repair right hand track frame crack
# repair transmission fault
# repaired x broken lines
# replace blown hose
# replace blown work lights
# replaced leaking steering hose
# ripper shank broken
# set-up Tele-Remote bogging
# stick cracks
# transmission charge hose leaking
# chord is leaking air from crack
# engine shutdown fault
# grease system has intermittent fault
# oil leak pilot filter text
# repair engine oil leak text
# repair transmission oil leak text
# steering pin no grease text
# transmission temperature fault
# injector error
# Bradken to repair broken clam
# CW PTO universal joint failed
# CW engine oil leaks x
# CW engine water pump snapped shaft
# CW top radiator tank leak again
# CW transmission failed
# PTO input seal leaking
# Tele-Remote fault
# VIMS fuel filter plugged
# adaptor leaking at implement valve
# aftercooler tank gauge broken
# aftercooler temperature error
# number right hand air brake line needs replacing
# [ shutdown ] vinyl flooring unserviceable
# batteries have no charge
# battery unserviceable dropped cell replace
# blade control cable tight
# broken proximity sensor tag carousel
# broken wire on speaker
# cabin side weightometer not working
# cabin smoke detector missing
# collect broken tooth
# compressor safety valve leaking
# constant voltage transformer melted
# contamination alarm coming up
# contamination alarm on
# crack repairs left hand window frame
# cracked power point in cabin
# dry cell not working properly
# depth counter unserviceable
# diagnose / repair right hand scoreboard not working
# <sensitive> depth counter not working
# dust flap on cabin side of mast needs extending
# electric propel siren not working
# earth wire broken on bottom of radiator
# engine oil blender running constantly
# equipment damaged ( terminal box )
# flag missing
# flow battery power
# front lights keep blowing fuse
# fuel filter water separator housing broken
# generator flow regulator unserviceable
# grease distributor leaking
# heat up locked steels
# heater hose in cabin roof unserviceable
# hole in door frame
# high voltage slip ring inspection grease leak
# ignition switch broken replace
# ignition switch sticking
# inverter earthing out
# investigate main transformer overload fault
# keeps blowing starter / horn fuse
# key broken in ignition switch
# microwave oven unserviceable
# number pump contamination switch on
# number slew pump contamination switch unserviceable
# oil centrifuge gasket leaking right hand engine
# oil leak at diverter valve
# oil leak inlet to oil burner cover plate
# glass window has large crack
# position pressure compensator weeping
# position chip sensor alarm
# pilot valve leaking oil
# position pump cavity low
# power step control cable broken
# pressure compensator leaking
# pressure control valve in cabin leaking
# pump drive box coupling and shaft unserviceable
# radiator blocked with grass
# radiator sight glasses unserviceable
# repair crack in right hand side of rear cross member
# repair chassis crack at right hand rear cross member
# repair crack in rear cross member
# repair crack on left hand front heat shield
# repair cracked baffle in hydraulic tank
# repair cracked roof skin left hand side exhaust
# repair cracks in mast cross braces
# repair faulty safety valve
# repair left hand scoreboard base cracked
# repair leak in pilot valve solenoid
# repair worn centrifuge filter
# rock breaker cracked
# rock breaker in bucket cracked at base
# safety flag missing
# siren unserviceable
# slip ring overgreasing
# start motorvator and set limits
# troubleshoot smart meter not communicating
# transformer trip
# TV monitor does not turn on
# TV monitor has no signal
# voltage regulator fuse fault
# water separator filter leaking see photo
# water separator leaking fuel
# weightometer display on trailer unserviceable
# will not start batteries unserviceable
# window frame needs repair
# wiper fuse unserviceable
# Top words:
# leaking
# fault
# repair
# leak
# oil
#
# Cluster 4 :
# repair air conditioner and wiring fault
# repair air leak at air tank safety valve
# Top words:
# air
# repair
# conditioner
# and
# wiring
#
# Cluster 5 :
# air conditioner thermostat not working
# air conditioner thermostat unserviceable
# air conditioner unserviceable
# air conditioner unserviceable when stationary
# air conditioner warm
# air filters plugged
# air horn disconnected
# air horn does not work
# air horn fault
# air horn not working
# air horn not working compressor awaiting
# air horn stuck on
# air horn unserviceable
# air horn working intermittently
# air leak
# air leak near side of door
# air leaking from line outside
# blown air conditioner hose
# blown air conditioner hose to radiator
# dragline air conditioner units need cleaning
# middle air drain tap leaking
# air conditioner compressor corroded
# air conditioner compressor unserviceable
# air conditioner fault
# air conditioner no good
# air conditioner system leaking
# air horn not working
# air leak
# air conditioner accessory drive leaking oil
# air conditioner belt broken
# air conditioner compressor not working
# air conditioner compressor tripping out
# air conditioner drive leaking
# air conditioner drive leaking oil
# air conditioner fan unserviceable fit new
# air conditioner fault
# air conditioner needs a boost not cold
# air conditioner not cold PO
# air conditioner not cold electrical faults
# air conditioner pressure switch unserviceable
# air conditioner fan speed resistor not working and
# air brake line blown requires replacing
# air pressure safety valve exhausting
# blown air conditioner fuse
# Top words:
# air
# conditioner
# not
# horn
# working
#
# Cluster 6 :
# broken air conditioner guard
# change out blown o-ring on steering pump
# change out blown position tyre
# change out blown steering hose
# change out broken bolt on brake pump
# change out broken prelube bracket
# change out broken stabilizer bar
# change out cracked pipe on valve bank
# change out cracked position adaptor and tooth
# change out exhaust clamp broken on left hand side [t |]
# change out front upper window cracked
# change out leak slew motor hose
# change out leaking HMU on next
# change out leaking fan hoses
# change out leaking heater taps
# change out leaking hydraulic hose
# change out leaking implement pump
# change out leaking relay valve
# change out leaking steering hose
# change out left hand steering cylinder leaking
# change out position and tyre worn out
# change out position tyre sensor not reading
# change out position tyre damage
# change out unserviceable jacket water pump
# change out unserviceable left hand bucket cylinder hose
# change out unserviceable position tyre
# change out unserviceable right hand clam cylinder hose
# change out unserviceable right hand tilt cylinder
# change out unserviceable swing brake cylinder
# change out weeping boom cylinder hose
# change out worn position tyre
# change out leaking transmission hose
# change out position tyre worn
# change out blown hose
# change out broken grease lines
# change out leaking transmission hose
# change out number faulty injector assembly
# change out plugged fuel filters
# change out worn ripper tip ripper tip
# GET change out worn cutting edges
# Top words:
# out
# change
# hose
# leaking
# position
#
# Cluster 7 :
# remove unserviceable air separator
# Top words:
# remove
# unserviceable
# air
# separator
#
# Cluster 8 :
# centrifuge hose leaking replace
# Top words:
# centrifuge
# hose
# leaking
# replace

# %% [markdown]
# # Inherent Function dataset

# %% [markdown]
# ## CNN

# %%
dataset2 = full_dataset_append_inherent_functions("../data/gold_release.json")
print(dataset2)
# pad_sequence(dataset2)
print(len(dataset2))
# Out:
# [['air', 'conditioner', 'thermostat', 'not', 'working', 'emitting', 'sensing'], ['air', 'conditioner', 'thermostat', 'unserviceable', 'emitting', 'sensing'], ['air', 'conditioner', 'unserviceable', 'emitting'], ['air', 'conditioner', 'unserviceable', 'when', 'stationary', 'emitting'], ['air', 'conditioner', 'warm', 'emitting'], ['air', 'filters', 'plugged', 'matterprocessing'], ['air', 'horn', 'disconnected', 'presenting'], ['air', 'horn', 'does', 'not', 'work', 'presenting'], ['air', 'horn', 'fault', 'presenting'], ['air', 'horn', 'not', 'working', 'presenting'], ['air', 'horn', 'not', 'working', 'compressor', 'awaiting', 'presenting', 'generating'], ['air', 'horn', 'stuck', 'on', 'presenting'], ['air', 'horn', 'unserviceable', 'presenting'], ['air', 'horn', 'working', 'intermittently', 'presenting'], ['air', 'leak'], ['air', 'leak', 'near', 'side', 'of', 'door', 'controlling'], ['air', 'leaking', 'from', 'line', 'outside', 'guiding'], ['airhorn', 'not', 'working', 'presenting'], ['alarm', 'on', 'VIMS', 'does', 'not', 'work', 'presenting'], ['all', 'dash', 'lights', 'on', 'emitting'], ['alternator', 'drive', 'leaking', 'driving', 'generating'], ['alternator', 'failed', 'generating'], ['alternator', 'not', 'charging', 'generating'], ['alternator', 'overcharge', 'fault', 'generating'], ['alternator', 'overcharged', 'generating'], ['analyse', 'failed', 'driveline', 'component', 'transforming'], ['and', 'lube', 'system', 'faults', 'protecting'], ['armrest', 'unserviceable', 'storing'], ['auto-greaser', 'leaking', 'oil', 'generating', 'protecting'], ['auto-greaser', 'unserviceable', 'generating'], ['auto-lube', 'error', 'PO', 'generating'], ['auto-spray', 'feature', 'not', 'working', 'generating'], ['axle', 'temperature', 'fault', 'transforming'], ['axle', 'temperature', 'sensor', 'fault', 'sensing', 'transforming'], ['back', 'rest', 'unserviceable', 'handle', 'broken', 'humaninteraction', 'storing'], ['backhoe', 'windscreen', 'to', 'be', 'fixed', 'controlling', 'matterprocessing'], ['backlight', 'on', 'dash', 'unserviceable', 'emitting', 'presenting'], ['backlights', 'on', 'dash', 'blown', 'emitting', 'presenting'], ['backup', 'alarm', 'not', 'working', 'presenting'], ['batteries', 'discharging', 'generating'], ['batteries', 'out', 'of', 'service', 'generating'], ['batteries', 'unserviceable', 'generating'], ['battery', 'cover', 'hinges', 'seized', 'generating', 'covering', 'holding'], ['beacon', 'mount', 'is', 'broken', 'holding', 'emitting'], ['beacon', 'not', 'working', 'emitting'], ['beacon', 'unserviceable', 'emitting'], ['bearing', 'on', 'air', 'conditioner', 'compressor', 'unserviceable', 'holding', 'emitting', 'generating'], ['bearings', 'are', 'shot', 'holding'], ['belly', 'plate', 'bolt', 'missing', 'holding'], ['bent', 'belly', 'plate', 'holding'], ['blade', 'light', 'blown', 'needs', 'replacing', 'emitting', 'matterprocessing'], ['blade', 'skin', 'cracked', 'protecting', 'matterprocessing'], ['blade', 'wear', 'plates', 'cracked', 'and', 'worn', 'matterprocessing', 'protecting'], ['blown', 'air', 'conditioner', 'hose', 'emitting', 'guiding'], ['blown', 'air', 'conditioner', 'hose', 'to', 'radiator', 'emitting', 'guiding'], ['blown', 'brake', 'hose', 'restricting', 'guiding'], ['blown', 'crowd', 'cylinder', 'hose', 'driving', 'guiding'], ['blown', 'extension', 'line', 'from', 'position', 'guiding'], ['blown', 'hose', 'in', 'hitch', 'guiding', 'interfacing'], ['blown', 'hose', 'on', 'boom', 'guiding', 'holding'], ['blown', 'lift', 'cylinder', 'o-ring', 'driving', 'covering'], ['blown', 'light', 'on', 'boom', 'emitting', 'holding'], ['blown', 'o-ring', 'off', 'steering', 'hose', 'guiding', 'covering', 'controlling'], ['blown', 'o-ring', 'on', 'left', 'hand', 'lift', 'cylinder', 'driving', 'covering'], ['blown', 'o-ring', 'on', 'steering', 'hose', 'guiding', 'covering', 'controlling'], ['blown', 'oil', 'cooler', 'hose', 'x', 'metre', 'emitting', 'guiding'], ['blown', 'position', 'tyre', 'guiding'], ['blown', 'right', 'hand ...
# 540

# %%
# SBERT embeddings
model = SentenceTransformer("all-MiniLM-L6-v2")
SBERT_embeddings2 = model.encode(dataset2)
print(SBERT_embeddings2.shape)
# Out:
# /opt/miniconda3/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# (540, 384)

# %%
# # Word2Vec embeddings as input
# w2vmodel2 = gensim.models.Word2Vec(dataset2, min_count=1, vector_size=100,
#                                 window=5, sg=1)
# w2v_embeddings2 = []
# for sentence in dataset2:
#     row = []
#     for word in sentence:
#         row.append(w2vmodel2.wv[word])
#     w2v_embeddings2.append(row)
# w2v_embeddings2 = np.array(w2v_embeddings2)

# %%
# print(w2v_embeddings2.shape)
# shape = w2v_embeddings2.shape
# w2v_embeddings2=w2v_embeddings2.reshape(shape[0], shape[1], shape[2], 1)
# print(w2v_embeddings2.shape)

# %%
# LSI embeddings as output
dictionary = gensim.corpora.Dictionary(dataset2)
doc_term_matrix = [dictionary.doc2bow(doc) for doc in dataset2]
lsamodel2 = LsiModel(doc_term_matrix, num_topics=10, id2word = dictionary)  # train model
concepts = list(lsamodel2[doc_term_matrix])
lsa_embeddings2=[]
for i in concepts:
    row = []
    for j in i:
        row.append(j[1])
    lsa_embeddings2.append(row)
lsa_embeddings2 = np.array(lsa_embeddings2)

# %%
print(lsa_embeddings2.shape)
print(lsa_embeddings2)
# Out:
# (540, 10)
# [[-0.64968048  0.95560484 -1.48770747 ...  0.02814566 -0.17423918
#    0.43317416]
#  [-0.69425419  0.87491569 -1.33235044 ...  0.04088295  0.00234487
#    0.31310629]
#  [-0.64068143  0.81189102 -1.25515632 ...  0.14251387  0.16536157
#    0.24972655]
#  ...
#  [-0.22972407  0.22591919 -0.22538342 ...  0.09190645 -0.45596354
#    0.10164684]
#  [-0.35253077  0.21611752  0.48402525 ... -0.32991734  0.12723265
#    0.00656433]
#  [-0.37288439  0.56150173  0.26740807 ...  0.01095912 -0.00151993
#   -0.00665223]]

# %%
# model3 = tf.keras.Sequential([
#     tf.keras.layers.Dense(units=128, activation="relu", input_shape=(384,)),
#     tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.Dense(units=128, activation="relu"),
#     tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.Dense(units=64, activation="relu"),
#     tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.Dense(units=10, activation="tanh"),
#     tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.Dense(units=10, activation="tanh")
# ])
# Out:
# /opt/miniconda3/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model1.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_32 (Dense)            (None, 128)               49280
#
#  batch_normalization_16 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dense_33 (Dense)            (None, 128)               16512
#
#  batch_normalization_17 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dense_34 (Dense)            (None, 64)                8256
#
#  batch_normalization_18 (Ba  (None, 64)                256
#  tchNormalization)
#
#  dense_35 (Dense)            (None, 10)                650
#
#  batch_normalization_19 (Ba  (None, 10)                40
#  tchNormalization)
#
#  dense_36 (Dense)            (None, 10)                110
#
# =================================================================
# Total params: 76128 (297.38 KB)
# Trainable params: 75468 (294.80 KB)
# Non-trainable params: 660 (2.58 KB)
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)

opt = tf.keras.optimizers.Adam(learning_rate=0.001)

model1.compile(optimizer=opt,
              loss=tf.keras.losses.MeanSquaredLogarithmicError("sum_over_batch_size"),
              metrics=['accuracy'])

history = model1.fit(SBERT_embeddings2, lsa_embeddings2, epochs=200)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy TF-Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy TF-Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/200
# 17/17 [==============================] - 1s 2ms/step - loss: 0.0475 - accuracy: 0.0667
# Epoch 2/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0389 - accuracy: 0.1519
# Epoch 3/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0357 - accuracy: 0.2148
# Epoch 4/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0330 - accuracy: 0.2296
# Epoch 5/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0302 - accuracy: 0.2926
# Epoch 6/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0281 - accuracy: 0.3222
# Epoch 7/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0263 - accuracy: 0.3833
# Epoch 8/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0241 - accuracy: 0.4148
# Epoch 9/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0229 - accuracy: 0.4426
# Epoch 10/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0220 - accuracy: 0.4759
# Epoch 11/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0213 - accuracy: 0.4704
# Epoch 12/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0204 - accuracy: 0.4796
# Epoch 13/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0196 - accuracy: 0.5037
# Epoch 14/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0193 - accuracy: 0.5111
# Epoch 15/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0190 - accuracy: 0.5019
# Epoch 16/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 0.5019
# Epoch 17/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0180 - accuracy: 0.5241
# Epoch 18/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0182 - accuracy: 0.5444
# Epoch 19/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0182 - accuracy: 0.5259
# Epoch 20/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0176 - accuracy: 0.5333
# Epoch 21/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0175 - accuracy: 0.5500
# Epoch 22/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0172 - accuracy: 0.5463
# Epoch 23/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0173 - accuracy: 0.5519
# Epoch 24/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0169 - accuracy: 0.5500
# Epoch 25/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0165 - accuracy: 0.5648
# Epoch 26/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0169 - accuracy: 0.5611
# Epoch 27/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 0.5500
# Epoch 28/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 0.5704
# Epoch 29/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 0.5704
# Epoch 30/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 0.5833
# Epoch 31/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 0.5611
# Epoch 32/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0157 - accuracy: 0.5519
# Epoch 33/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0158 - accuracy: 0.5722
# Epoch 34/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0155 - accuracy: 0.5944
# Epoch 35/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0152 - accuracy: 0.5981
# Epoch 36/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0151 - accuracy: 0.5815
# Epoch 37/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0147 - accuracy: 0.5889
# Epoch 38/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0148 - accuracy: 0.6000
# Epoch 39/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0143 - accuracy: 0.5981
# Epoch 40/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0146 - accuracy: 0.5796
# Epoch 41/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0144 - accuracy: 0.6000
# Epoch 42/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0143 - accuracy: 0.6111
# Epoch 43/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 0.5852
# Epoch 44/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0145 - accuracy: 0.5981
# Epoch 45/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0142 - accuracy: 0.5833
# Epoch 46/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0141 - accuracy: 0.5907
# Epoch 47/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0139 - accuracy: 0.6056
# Epoch 48/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0135 - accuracy: 0.6185
# Epoch 49/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0131 - accuracy: 0.6315
# Epoch 50/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0132 - accuracy: 0.6315
# Epoch 51/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0128 - accuracy: 0.6426
# Epoch 52/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0124 - accuracy: 0.6519
# Epoch 53/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0130 - accuracy: 0.6130
# Epoch 54/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0126 - accuracy: 0.6167
# Epoch 55/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0127 - accuracy: 0.6074
# Epoch 56/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0120 - accuracy: 0.6593
# Epoch 57/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0119 - accuracy: 0.6704
# Epoch 58/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0120 - accuracy: 0.6500
# Epoch 59/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0119 - accuracy: 0.6648
# Epoch 60/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0125 - accuracy: 0.6407
# Epoch 61/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0119 - accuracy: 0.6704
# Epoch 62/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0119 - accuracy: 0.6722
# Epoch 63/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0120 - accuracy: 0.6648
# Epoch 64/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0118 - accuracy: 0.6593
# Epoch 65/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 0.6519
# Epoch 66/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0119 - accuracy: 0.6722
# Epoch 67/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0117 - accuracy: 0.6741
# Epoch 68/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0117 - accuracy: 0.6704
# Epoch 69/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0115 - accuracy: 0.6537
# Epoch 70/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0114 - accuracy: 0.6778
# Epoch 71/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0117 - accuracy: 0.6778
# Epoch 72/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0118 - accuracy: 0.6759
# Epoch 73/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0116 - accuracy: 0.6704
# Epoch 74/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0112 - accuracy: 0.6759
# Epoch 75/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0114 - accuracy: 0.6870
# Epoch 76/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0111 - accuracy: 0.6796
# Epoch 77/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0113 - accuracy: 0.6519
# Epoch 78/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0111 - accuracy: 0.6778
# Epoch 79/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0108 - accuracy: 0.6944
# Epoch 80/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0111 - accuracy: 0.6926
# Epoch 81/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0111 - accuracy: 0.6926
# Epoch 82/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0110 - accuracy: 0.6685
# Epoch 83/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0107 - accuracy: 0.6648
# Epoch 84/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0109 - accuracy: 0.6704
# Epoch 85/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0110 - accuracy: 0.6944
# Epoch 86/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0112 - accuracy: 0.6704
# Epoch 87/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0109 - accuracy: 0.6796
# Epoch 88/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0112 - accuracy: 0.6889
# Epoch 89/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0109 - accuracy: 0.6685
# Epoch 90/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0107 - accuracy: 0.6667
# Epoch 91/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0107 - accuracy: 0.6796
# Epoch 92/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0108 - accuracy: 0.6907
# Epoch 93/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0105 - accuracy: 0.6815
# Epoch 94/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0109 - accuracy: 0.6981
# Epoch 95/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0111 - accuracy: 0.6648
# Epoch 96/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0107 - accuracy: 0.6870
# Epoch 97/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0104 - accuracy: 0.6870
# Epoch 98/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0107 - accuracy: 0.6852
# Epoch 99/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0104 - accuracy: 0.7037
# Epoch 100/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0105 - accuracy: 0.7019
# Epoch 101/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0103 - accuracy: 0.6963
# Epoch 102/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0106 - accuracy: 0.6981
# Epoch 103/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0106 - accuracy: 0.6981
# Epoch 104/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0103 - accuracy: 0.6833
# Epoch 105/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0106 - accuracy: 0.6963
# Epoch 106/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0103 - accuracy: 0.7111
# Epoch 107/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0107 - accuracy: 0.6907
# Epoch 108/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0105 - accuracy: 0.7019
# Epoch 109/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0107 - accuracy: 0.7000
# Epoch 110/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0102 - accuracy: 0.6722
# Epoch 111/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0101 - accuracy: 0.7019
# Epoch 112/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0102 - accuracy: 0.6981
# Epoch 113/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0104 - accuracy: 0.7000
# Epoch 114/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0103 - accuracy: 0.6944
# Epoch 115/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0104 - accuracy: 0.6741
# Epoch 116/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0102 - accuracy: 0.6926
# Epoch 117/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0105 - accuracy: 0.6944
# Epoch 118/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0102 - accuracy: 0.6889
# Epoch 119/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0101 - accuracy: 0.6963
# Epoch 120/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0102 - accuracy: 0.6870
# Epoch 121/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0105 - accuracy: 0.6981
# Epoch 122/200
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0103 - accuracy: 0.7037
# Epoch 123/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0103 - accuracy: 0.7222
# Epoch 124/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0105 - accuracy: 0.7037
# Epoch 125/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0104 - accuracy: 0.6944
# Epoch 126/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0103 - accuracy: 0.6722
# Epoch 127/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0101 - accuracy: 0.7167
# Epoch 128/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0101 - accuracy: 0.7093
# Epoch 129/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0101 - accuracy: 0.6870
# Epoch 130/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0103 - accuracy: 0.6870
# Epoch 131/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0103 - accuracy: 0.6870
# Epoch 132/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0102 - accuracy: 0.6944
# Epoch 133/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0102 - accuracy: 0.7056
# Epoch 134/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0101 - accuracy: 0.7074
# Epoch 135/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0101 - accuracy: 0.7204
# Epoch 136/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0098 - accuracy: 0.7037
# Epoch 137/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0101 - accuracy: 0.6963
# Epoch 138/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0103 - accuracy: 0.7148
# Epoch 139/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0102 - accuracy: 0.6981
# Epoch 140/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0101 - accuracy: 0.7111
# Epoch 141/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0104 - accuracy: 0.6685
# Epoch 142/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0098 - accuracy: 0.7130
# Epoch 143/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0100 - accuracy: 0.7056
# Epoch 144/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0099 - accuracy: 0.7167
# Epoch 145/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0100 - accuracy: 0.6981
# Epoch 146/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0100 - accuracy: 0.7074
# Epoch 147/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0098 - accuracy: 0.7167
# Epoch 148/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0100 - accuracy: 0.7222
# Epoch 149/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0101 - accuracy: 0.7148
# Epoch 150/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0102 - accuracy: 0.7185
# Epoch 151/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0097 - accuracy: 0.7093
# Epoch 152/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0099 - accuracy: 0.7185
# Epoch 153/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0099 - accuracy: 0.7093
# Epoch 154/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0101 - accuracy: 0.7204
# Epoch 155/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0097 - accuracy: 0.7241
# Epoch 156/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0100 - accuracy: 0.7296
# Epoch 157/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0101 - accuracy: 0.7130
# Epoch 158/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0100 - accuracy: 0.6815
# Epoch 159/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0099 - accuracy: 0.7185
# Epoch 160/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0102 - accuracy: 0.7019
# Epoch 161/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0098 - accuracy: 0.7167
# Epoch 162/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0098 - accuracy: 0.7204
# Epoch 163/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0097 - accuracy: 0.7093
# Epoch 164/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0100 - accuracy: 0.6870
# Epoch 165/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0096 - accuracy: 0.7352
# Epoch 166/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0099 - accuracy: 0.7130
# Epoch 167/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0099 - accuracy: 0.7259
# Epoch 168/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0098 - accuracy: 0.7241
# Epoch 169/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0100 - accuracy: 0.6981
# Epoch 170/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0097 - accuracy: 0.7111
# Epoch 171/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0098 - accuracy: 0.7185
# Epoch 172/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0099 - accuracy: 0.7148
# Epoch 173/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0097 - accuracy: 0.7352
# Epoch 174/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0096 - accuracy: 0.7093
# Epoch 175/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0097 - accuracy: 0.7296
# Epoch 176/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0097 - accuracy: 0.7185
# Epoch 177/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0096 - accuracy: 0.7167
# Epoch 178/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0094 - accuracy: 0.7370
# Epoch 179/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0095 - accuracy: 0.7370
# Epoch 180/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0096 - accuracy: 0.7056
# Epoch 181/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0095 - accuracy: 0.7204
# Epoch 182/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0097 - accuracy: 0.7222
# Epoch 183/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0098 - accuracy: 0.7278
# Epoch 184/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0094 - accuracy: 0.7130
# Epoch 185/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0098 - accuracy: 0.7056
# Epoch 186/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0095 - accuracy: 0.7167
# Epoch 187/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0095 - accuracy: 0.7389
# Epoch 188/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0095 - accuracy: 0.7037
# Epoch 189/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0097 - accuracy: 0.7111
# Epoch 190/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0098 - accuracy: 0.7259
# Epoch 191/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0096 - accuracy: 0.7315
# Epoch 192/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0098 - accuracy: 0.6981
# Epoch 193/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0097 - accuracy: 0.7296
# Epoch 194/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0098 - accuracy: 0.7074
# Epoch 195/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0097 - accuracy: 0.7037
# Epoch 196/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0096 - accuracy: 0.7241
# Epoch 197/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0095 - accuracy: 0.7389
# Epoch 198/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0098 - accuracy: 0.7019
# Epoch 199/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0096 - accuracy: 0.7167
# Epoch 200/200
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0096 - accuracy: 0.7389

# %%
acc = history.history['accuracy']
print(acc)
plt.plot(acc)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
# plt.ylim([0, 1])
# plt.legend(loc='lower right')
plt.show()
# Out:
# [0.06666667014360428, 0.1518518477678299, 0.21481481194496155, 0.22962963581085205, 0.2925925850868225, 0.3222222328186035, 0.38333332538604736, 0.4148148000240326, 0.442592591047287, 0.47592592239379883, 0.4703703820705414, 0.47962963581085205, 0.5037037134170532, 0.5111111402511597, 0.5018518567085266, 0.5018518567085266, 0.5240740776062012, 0.5444444417953491, 0.5259259343147278, 0.5333333611488342, 0.550000011920929, 0.5462962985038757, 0.5518518686294556, 0.550000011920929, 0.5648148059844971, 0.5611110925674438, 0.550000011920929, 0.5703703761100769, 0.5703703761100769, 0.5833333134651184, 0.5611110925674438, 0.5518518686294556, 0.5722222328186035, 0.5944444537162781, 0.5981481671333313, 0.5814814567565918, 0.5888888835906982, 0.6000000238418579, 0.5981481671333313, 0.5796296000480652, 0.6000000238418579, 0.6111111044883728, 0.585185170173645, 0.5981481671333313, 0.5833333134651184, 0.5907407402992249, 0.605555534362793, 0.6185185313224792, 0.6314814686775208, 0.6314814686775208, 0.6425926089286804, 0.6518518328666687, 0.6129629611968994, 0.6166666746139526, 0.6074073910713196, 0.6592592597007751, 0.6703703999519348, 0.6499999761581421, 0.664814829826355, 0.6407407522201538, 0.6703703999519348, 0.6722221970558167, 0.664814829826355, 0.6592592597007751, 0.6518518328666687, 0.6722221970558167, 0.6740740537643433, 0.6703703999519348, 0.6537036895751953, 0.6777777671813965, 0.6777777671813965, 0.6759259104728699, 0.6703703999519348, 0.6759259104728699, 0.6870370507240295, 0.6796296238899231, 0.6518518328666687, 0.6777777671813965, 0.6944444179534912, 0.6925926208496094, 0.6925926208496094, 0.6685185432434082, 0.664814829826355, 0.6703703999519348, 0.6944444179534912, 0.6703703999519348, 0.6796296238899231, 0.6888889074325562, 0.6685185432434082, 0.6666666865348816, 0.6796296238899231, 0.6907407641410828, 0.6814814805984497, 0.6981481313705444, 0.664814829826355, 0.6870370507240295, 0.6870370507240295, 0.6851851940155029, 0.7037037014961243, 0.7018518447875977, 0.6962962746620178, 0.6981481313705444, 0.6981481313705444, 0.6833333373069763, 0.6962962746620178, 0.7111111283302307, 0.6907407641410828, 0.7018518447875977, 0.699999988079071, 0.6722221970558167, 0.7018518447875977, 0.6981481313705444, 0.699999988079071, 0.6944444179534912, 0.6740740537643433, 0.6925926208496094, 0.6944444179534912, 0.6888889074325562, 0.6962962746620178, 0.6870370507240295, 0.6981481313705444, 0.7037037014961243, 0.7222222089767456, 0.7037037014961243, 0.6944444179534912, 0.6722221970558167, 0.7166666388511658, 0.7092592716217041, 0.6870370507240295, 0.6870370507240295, 0.6870370507240295, 0.6944444179534912, 0.7055555582046509, 0.7074074149131775, 0.720370352268219, 0.7037037014961243, 0.6962962746620178, 0.7148148417472839, 0.6981481313705444, 0.7111111283302307, 0.6685185432434082, 0.7129629850387573, 0.7055555582046509, 0.7166666388511658, 0.6981481313705444, 0.7074074149131775, 0.7166666388511658, 0.7222222089767456, 0.7148148417472839, 0.7185184955596924, 0.7092592716217041, 0.7185184955596924, 0.7092592716217041, 0.720370352268219, 0.7240740656852722, 0.729629635810852, 0.7129629850387573, 0.6814814805984497, 0.7185184955596924, 0.7018518447875977, 0.7166666388511658, 0.720370352268219, 0.7092592716217041, 0.6870370507240295, 0.7351852059364319, 0.7129629850387573, 0.7259259223937988, 0.7240740656852722, 0.6981481313705444, 0.7111111283302307, 0.7185184955596924, 0.7148148417472839, 0.7351852059364319, 0.7092592716217041, 0.729629635810852, 0.7185184955596924, 0.7166666388511658, 0.7370370626449585, 0.7370370626449585, 0.7055555582046509, 0.720370352268219, 0.7222222089767456, 0.7277777791023254, 0.7129629850387573, 0.7055555582046509, 0.7166666388511658, 0.7388888597488403, 0.7037037014961243, 0.7111111283302307, 0.7259259223937988, 0.7314814925193787, 0.6981481313705444, 0.729629635810852, 0.7074074149131775, 0.7037037014961243, 0.7240740656852722, 0.7388888597488403, 0.7018518447875977, 0.7166666388511658, 0.7388888597488403]

# %%
model3 = tf.keras.Sequential([
    tf.keras.layers.Dense(units=128, activation="relu", input_shape=(384,)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(units=128, activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(units=64, activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(units=10, activation="tanh")
])

model3.layers[0].set_weights(model1.layers[0].get_weights())
model3.layers[2].set_weights(model1.layers[2].get_weights())
model3.layers[4].set_weights(model1.layers[4].get_weights())
model3.layers[6].set_weights(model1.layers[6].get_weights())

# %%
cluster_embeddings = model3.predict(SBERT_embeddings)
print(cluster_embeddings.shape)
# Out:
# 17/17 [==============================] - 0s 596us/step
# (540, 10)

# %%
dataset_not_padded = full_dataset("../data/gold_release.json")

from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.metrics import silhouette_score


# PCA reduction
pca = PCA(n_components=2)
pca_embedding = pca.fit_transform(cluster_embeddings)
plt.scatter(pca_embedding[:,0], pca_embedding[:,1])
plt.title("PCA")
plt.show()

# tsne reduction
tsne = TSNE(n_components=2).fit_transform(cluster_embeddings)
plt.scatter(tsne[:,0], tsne[:,1])
plt.title("TSNE")
plt.show()


# Perform kmean clustering
silhouette_scores = []
test_k = list(range(5, 105, 5))
for i in test_k:
    print(i, "/", 100)
    kmeans = KMeans(n_clusters=i, random_state=42, n_init=100).fit(cluster_embeddings)
    labels = kmeans.labels_
    silhouette_scores.append(silhouette_score(cluster_embeddings, labels))
plt.plot(test_k, silhouette_scores)
plt.title("Silhouette Scores")
plt.show()
# Out:
# 5 / 100
# 10 / 100
# 15 / 100
# 20 / 100
# 25 / 100
# 30 / 100
# 35 / 100
# 40 / 100
# 45 / 100
# 50 / 100
# 55 / 100
# 60 / 100
# 65 / 100
# 70 / 100
# 75 / 100
# 80 / 100
# 85 / 100
# 90 / 100
# 95 / 100
# 100 / 100

# %%
# best k
k = 20
kmeans = KMeans(n_clusters=k, random_state=42, n_init=100).fit(cluster_embeddings)

for i in range(k):
    print("Cluster ", i)
    for j in range(len(labels)):
        if labels[j] == i:
            print(dataset_not_padded[j])
            
    print()
# Out:
# Cluster  0
# ['armrest', 'unserviceable']
# ['both', 'stick', 'cylinders', 'leaking']
# ['cabin', 'jacking', 'cylinder', 'ends', 'unserviceable']
# ['stick', 'cylinder', 'leaking']
# ['stick', 'cracks']
#
# Cluster  1
# ['damage', 'to', 'position', 'tyre']
# ['replace', 'damaged', 'position', 'tyre', 'and', 'position']
# ['tail', 'pulley', 'has', 'no', 'grease', 'lines']
# ['replace', 'damaged', 'tyre', 'on', 'position']
# ['exhaust', 'leak']
#
# Cluster  2
# ['air', 'conditioner', 'thermostat', 'not', 'working']
# ['air', 'conditioner', 'thermostat', 'unserviceable']
# ['air', 'conditioner', 'unserviceable']
# ['air', 'conditioner', 'unserviceable', 'when', 'stationary']
# ['air', 'conditioner', 'warm']
# ['air', 'conditioner', 'compressor', 'corroded']
# ['air', 'conditioner', 'compressor', 'unserviceable']
# ['air', 'conditioner', 'fault']
# ['air', 'conditioner', 'no', 'good']
# ['air', 'conditioner', 'system', 'leaking']
# ['air', 'conditioner', 'accessory', 'drive', 'leaking', 'oil']
# ['air', 'conditioner', 'belt', 'broken']
# ['air', 'conditioner', 'compressor', 'not', 'working']
# ['air', 'conditioner', 'compressor', 'tripping', 'out']
# ['air', 'conditioner', 'drive', 'leaking']
# ['air', 'conditioner', 'drive', 'leaking', 'oil']
# ['air', 'conditioner', 'fan', 'unserviceable', 'fit', 'new']
# ['air', 'conditioner', 'fault']
# ['air', 'conditioner', 'needs', 'a', 'boost', 'not', 'cold']
# ['air', 'conditioner', 'not', 'cold', 'PO']
# ['air', 'conditioner', 'not', 'cold', 'electrical', 'faults']
# ['air', 'conditioner', 'pressure', 'switch', 'unserviceable']
# ['air', 'conditioner', 'fan', 'speed', 'resistor', 'not', 'working', 'and']
#
# Cluster  3
# ['change', 'out', 'blown', 'o-ring', 'on', 'steering', 'pump']
# ['change', 'out', 'blown', 'position', 'tyre']
# ['change', 'out', 'blown', 'steering', 'hose']
# ['change', 'out', 'broken', 'bolt', 'on', 'brake', 'pump']
# ['change', 'out', 'broken', 'prelube', 'bracket']
# ['change', 'out', 'broken', 'stabilizer', 'bar']
# ['change', 'out', 'cracked', 'pipe', 'on', 'valve', 'bank']
# ['change', 'out', 'cracked', 'position', 'adaptor', 'and', 'tooth']
# ['change', 'out', 'exhaust', 'clamp', 'broken', 'on', 'left', 'hand', 'side', '[t', '|]']
# ['change', 'out', 'front', 'upper', 'window', 'cracked']
# ['change', 'out', 'leak', 'slew', 'motor', 'hose']
# ['change', 'out', 'leaking', 'HMU', 'on', 'next']
# ['change', 'out', 'leaking', 'fan', 'hoses']
# ['change', 'out', 'leaking', 'heater', 'taps']
# ['change', 'out', 'leaking', 'hydraulic', 'hose']
# ['change', 'out', 'leaking', 'implement', 'pump']
# ['change', 'out', 'leaking', 'relay', 'valve']
# ['change', 'out', 'leaking', 'steering', 'hose']
# ['change', 'out', 'left', 'hand', 'steering', 'cylinder', 'leaking']
# ['change', 'out', 'position', 'and', 'tyre', 'worn', 'out']
# ['change', 'out', 'position', 'tyre', 'sensor', 'not', 'reading']
# ['change', 'out', 'position', 'tyre', 'damage']
# ['change', 'out', 'unserviceable', 'jacket', 'water', 'pump']
# ['change', 'out', 'unserviceable', 'left', 'hand', 'bucket', 'cylinder', 'hose']
# ['change', 'out', 'unserviceable', 'position', 'tyre']
# ['change', 'out', 'unserviceable', 'right', 'hand', 'clam', 'cylinder', 'hose']
# ['change', 'out', 'unserviceable', 'right', 'hand', 'tilt', 'cylinder']
# ['change', 'out', 'unserviceable', 'swing', 'brake', 'cylinder']
# ['change', 'out', 'weeping', 'boom', 'cylinder', 'hose']
# ['change', 'out', 'worn', 'position', 'tyre']
# ['change', 'out', 'leaking', 'transmission', 'hose']
# ['change', 'out', 'position', 'tyre', 'worn']
# ['change', 'out', 'blown', 'hose']
# ['change', 'out', 'broken', 'grease', 'lines']
# ['change', 'out', 'leaking', 'transmission', 'hose']
# ['change', 'out', 'number', 'faulty', 'injector', 'assembly']
# ['change', 'out', 'plugged', 'fuel', 'filters']
# ['change', 'out', 'worn', 'ripper', 'tip', 'ripper', 'tip']
# ['GET', 'change', 'out', 'worn', 'cutting', 'edges']
#
# Cluster  4
# ['differential', 'lock', 'broken']
# ['electrical', 'harness', 'fault']
# ['VIMS', 'keypad', 'light', 'out']
# ['fuel', 'leak']
# ['ignition', 'switch', 'broken', 'replace']
# ['ignition', 'switch', 'sticking']
#
# Cluster  5
# ['alarm', 'on', 'VIMS', 'does', 'not', 'work']
# ['beacon', 'mount', 'is', 'broken']
# ['boarding', 'ladder', 'not', 'working']
# ['broken', 'weld', 'on', 'handrail']
# ['broken', 'proximity', 'sensor', 'tag', 'carousel']
#
# Cluster  6
# ['failed', 'PTO', 'and', 'auxiliary', 'drive', 'PO']
# ['repair', 'brake', 'fault']
# ['walk', 'motor', 'brake', 'fault']
# ['CW', 'PTO', 'universal', 'joint', 'failed']
# ['investigate', 'main', 'transformer', 'overload', 'fault']
#
# Cluster  7
# ['replace', 'unserviceable', 'differential', 'drain', 'plugs']
# ['Bradken', 'to', 'repair', 'broken', 'clam']
# ['<sensitive>', 'depth', 'counter', 'not', 'working']
# ['replace', 'unserviceable', 'grease', 'distributor']
# ['replace', 'unserviceable', 'chip', 'indicators']
# ['replace', 'unserviceable', 'ignition', 'switch']
# ['replace', 'unserviceable', 'transmission', 'screen', 'and', 'magnet']
# ['will', 'not', 'start', 'batteries', 'unserviceable']
#
# Cluster  8
# ['air', 'horn', 'disconnected']
# ['air', 'horn', 'does', 'not', 'work']
# ['air', 'horn', 'fault']
# ['air', 'horn', 'not', 'working']
# ['air', 'horn', 'not', 'working', 'compressor', 'awaiting']
# ['air', 'horn', 'stuck', 'on']
# ['air', 'horn', 'unserviceable']
# ['air', 'horn', 'working', 'intermittently']
# ['compressor', 'oil', 'pressure', 'switch', 'unserviceable']
# ['air', 'horn', 'not', 'working']
#
# Cluster  9
# ['blown', 'steering', 'hose']
# ['blown', 'steering', 'pump', 'hose']
# ['bottom', 'steering', 'shaft', 'universal', 'joint', 'worn']
#
# Cluster  10
# ['cabin', 'seat', 'needs', 'replacing']
# ['crack', 'in', 'blade', 'liner', 'left', 'hand', 'side']
# ['crack', 'in', 'boom', 'chord']
# ['crack', 'in', 'fuel', 'tank']
# ['crack', 'in', 'headboard']
# ['crack', 'in', 'lower', 'centre', 'of', 'windscreen']
# ['crack', 'in', 'windscreen']
# ['cabin', 'seat', 'unserviceable', 'needs', 'replacing']
#
# Cluster  11
# ['broken', 'right', 'hand', 'side', 'door', 'window']
# ['repair', 'cracked', 'steering', 'tank', 'mo']
# ['number', 'right', 'hand', 'air', 'brake', 'line', 'needs', 'replacing']
# ['repair', 'cracked', 'baffle', 'in', 'hydraulic', 'tank']
# ['repair', 'cracked', 'roof', 'skin', 'left', 'hand', 'side', 'exhaust']
#
# Cluster  12
# ['differential', 'oil', 'leak']
# ['oil', 'leak', 'at', 'air', 'compressor']
# ['oil', 'leak', 'swingbox']
# ['oil', 'leak', 'from', 'behind', 'water', 'pump']
# ['differential', 'oil', 'leak']
# ['hydraulic', 'oil', 'leak', 'from', 'environmental']
# ['investigate', 'torque', 'converter', 'fan', 'pump', 'oil', 'leak']
# ['oil', 'leak', 'pilot', 'filter', 'text']
# ['oil', 'leak', 'at', 'diverter', 'valve']
# ['oil', 'leak', 'inlet', 'to', 'oil', 'burner', 'cover', 'plate']
#
# Cluster  13
# ['check', '/', 'repair', 'engine', 'oil', 'leak']
# ['investigate', 'and', 'repair', 'oil', 'leak']
# ['investigate', 'engine', 'oil', 'leak']
# ['repair', 'oil', 'leak', 'position', 'wheel', 'end']
#
# Cluster  14
# ['auto-lube', 'error', 'PO']
# ['batteries', 'unserviceable']
# ['grease', 'pump', 'unserviceable']
# ['grease', 'pump', 'is', 'bypassing', 'air']
# ['grease', 'gauges', 'requires', 'replacing']
# ['parts', 'washer', 'pump', 'broken']
# ['fuel', 'cap', 'is', 'missing']
# ['injector', 'error']
# ['number', 'pump', 'contamination', 'switch', 'on']
#
# Cluster  15
# ['right', 'hand', 'bobbin', 'roller', 'unserviceable']
# ['left', 'hand', 'side', 'pinion', 'change', 'out', 'cover', 'cracking']
# ['left', 'hand', 'rear', 'brake', 'cooling', 'hose', 'leaking']
# ['left', 'hand', 'boom', 'cylinder', 'hose', 'leaking', 'PO']
# ['left', 'hand', 'corner', 'bonnet', 'cracked']
# ['left', 'hand', 'side', 'boom', 'foot', 'crack', 'repair']
# ['left', 'hand', 'chain', 'guide', 'unserviceable']
# ['left', 'hand', 'chain', 'guide', 'worn', 'at', 'the', 'top']
# ['left', 'hand', 'PTO', 'pump', 'chip', 'sensor', 'harness', 'unserviceable']
# ['right', 'hand', 'PTO', 'cavity', 'emptying']
#
# Cluster  16
# ['transmission', 'fill', '/', 'drain', 'plug', 'unserviceable']
# ['repair', 'leaking', 'swing', 'pedestal', 'seals']
# ['replace', 'transmission', 'cracked']
# ['repair', 'gear', 'fault']
# ['repair', 'leaking', 'centrifugal', 'filter']
# ['repair', 'transmission', 'fault']
# ['repair', 'transmission', 'oil', 'leak', 'text']
#
# Cluster  17
# ['broken', 'grease', 'plug']
# ['broken', 'joystick', 'PO']
# ['broken', 'ripper', 'tooth']
# ['cracked', 'fuel', 'tank']
# ['dash', 'broken']
# ['broken', 'wire', 'on', 'speaker']
# ['collect', 'broken', 'tooth']
# ['key', 'broken', 'in', 'ignition', 'switch']
#
# Cluster  18
# ['blown', 'hose', 'in', 'hitch']
# ['blown', 'hose', 'on', 'boom']
# ['repair', 'blown', 'air', 'conditioner', 'hose']
#
# Cluster  19
# ['differential', 'cooler', 'fan', 'hose', 'leaking']
# ['differential', 'cooler', 'hose', 'leaking']
# ['differential', 'cooler', 'pump', 'leaking']
# ['differential', 'lube', 'pump', 'leaking']
# ['differential', 'lube', 'pump', 'leaking', 'PO']
# ['differential', 'pump', 'motor', 'hose', 'leaking']
# ['differential', 'lube', 'hose', 'leaking']

# %% [markdown]
# ## Hierachical Clustering

# %%
def silhouette(type, embeddings):
    silhouette_scores = []
    test_k = list(range(5, 105, 5))
    linkage_data = linkage(embeddings, method=type)
    for i in test_k:
        # print(i, "/", 100)
        cluster_labels = fcluster(linkage_data, i, criterion='maxclust')
        silhouette_scores.append(silhouette_score(embeddings, cluster_labels))
    plt.plot(test_k, silhouette_scores)
    plt.title("Silhouette Scores")
    plt.show()

# %% [markdown]
# ### Average clustering

# %%
silhouette('average', cluster_embeddings)

# %%
linkage_data = linkage(cluster_embeddings, method='average')
fig = plt.figure(figsize=(25, 10))
dn = dendrogram(linkage_data)
plt.show()

# %%
k=12
cluster_labels = fcluster(linkage_data, k, criterion='maxclust')
for i in range(1,k+1):
    print("Cluster",i,":")
    cluster_words = {}
    for j in range(len(cluster_labels)):
        if cluster_labels[j]==i:
            print(" ".join(dataset2[j]))
            for word in set(dataset2[j]):
                if word in cluster_words:
                    cluster_words[word]+=1
                else:
                    cluster_words[word]=1
    print("Top words:")
    sorted_cluster_words = sorted(cluster_words, key=cluster_words.get, reverse=True)
    for j in range(min(len(sorted_cluster_words), 5)):
        print(sorted_cluster_words[j])
    print()
# Out:
# Cluster 1 :
# change out blown o-ring on steering pump generating covering controlling
# change out blown position tyre guiding
# change out blown steering hose guiding controlling
# change out broken bolt on brake pump holding restricting generating
# change out broken prelube bracket holding protecting
# change out broken stabilizer bar holding
# change out cracked pipe on valve bank guiding controlling
# change out cracked position adaptor and tooth matterprocessing holding
# change out exhaust clamp broken on left hand side [t |] guiding holding
# change out front upper window cracked controlling
# change out leak slew motor hose driving guiding
# change out leaking HMU on next driving
# change out leaking fan hoses generating guiding
# change out leaking heater taps emitting controlling
# change out leaking hydraulic hose guiding
# change out leaking implement pump generating
# change out leaking relay valve controlling
# change out leaking steering hose guiding controlling
# change out left hand steering cylinder leaking driving
# change out position and tyre worn out guiding
# change out position tyre sensor not reading guiding sensing
# change out position tyre damage guiding
# change out unserviceable jacket water pump generating
# change out unserviceable left hand bucket cylinder hose driving guiding
# change out unserviceable position tyre guiding
# change out unserviceable right hand clam cylinder hose driving guiding
# change out unserviceable right hand tilt cylinder driving
# change out unserviceable swing brake cylinder driving
# change out weeping boom cylinder hose driving guiding
# change out worn position tyre guiding
# cutting edges loose matterprocessing
# cutting edges need change out matterprocessing
# change out leaking transmission hose transforming guiding
# change out position tyre worn guiding
# change out blown hose guiding
# change out broken grease lines guiding
# change out leaking transmission hose guiding transforming
# change out number faulty injector assembly generating
# change out plugged fuel filters matterprocessing
# change out worn ripper tip ripper tip matterprocessing
# GET change out worn cutting edges matterprocessing
# Top words:
# out
# change
# guiding
# hose
# leaking
#
# Cluster 2 :
# air conditioner thermostat not working emitting sensing
# air conditioner thermostat unserviceable emitting sensing
# air conditioner unserviceable emitting
# air conditioner unserviceable when stationary emitting
# air conditioner warm emitting
# air filters plugged matterprocessing
# air horn disconnected presenting
# air horn does not work presenting
# air horn fault presenting
# air horn not working presenting
# air horn not working compressor awaiting presenting generating
# air horn stuck on presenting
# air horn unserviceable presenting
# air horn working intermittently presenting
# broken air conditioner guard emitting protecting
# compressor oil pressure switch unserviceable generating sensing
# dragline air conditioner units need cleaning emitting
# repair air conditioner and wiring fault emitting guiding
# air conditioner compressor corroded emitting generating
# air conditioner compressor unserviceable emitting generating
# air conditioner fault emitting
# air conditioner no good emitting
# air conditioner system leaking emitting
# air horn not working presenting
# engine bay light blown emitting holding
# air conditioner accessory drive leaking oil emitting protecting transforming driving
# air conditioner belt broken emitting guiding
# air conditioner compressor not working emitting generating
# air conditioner compressor tripping out emitting generating
# air conditioner drive leaking emitting driving
# air conditioner drive leaking oil emitting protecting driving
# air conditioner fan unserviceable fit new emitting generating
# air conditioner fault emitting
# air conditioner needs a boost not cold emitting
# air conditioner not cold PO emitting
# air conditioner not cold electrical faults emitting
# air conditioner pressure switch unserviceable emitting sensing
# air conditioner fan speed resistor not working and emitting restricting generating
# air pressure safety valve exhausting protecting
# keeps blowing starter / horn fuse protecting presenting driving
# repair air leak at air tank safety valve storing protecting
# siren unserviceable emitting
# Top words:
# air
# emitting
# conditioner
# not
# presenting
#
# Cluster 3 :
# bearing on air conditioner compressor unserviceable holding emitting generating
# check / repair engine oil leak protecting driving
# coolant leak protecting
# coolant leak at engine oil cooler protecting emitting driving
# coolant leak at jacket water pump protecting generating
# differential oil leak protecting transforming
# oil found in revolving frame protecting holding
# investigate and repair oil leak protecting
# handrail above battery box cracked protecting storing
# investigate engine oil leak protecting driving
# oil leak at air compressor protecting generating
# oil leak swingbox protecting transforming
# engine oil leaks right hand side protecting driving
# repair oil leak position wheel end protecting
# inspect bad engine oil leak protecting driving
# oil leak from behind water pump protecting generating
# coolant leak protecting
# differential oil leak protecting transforming
# engine oil leak protecting driving
# engine oil leak inspection plate protecting driving presenting
# hydraulic oil leak from environmental protecting
# investigate torque converter fan pump oil leak generating protecting transforming
# minor transmission oil leak protecting transforming
# repair engine oil leak and protecting driving
# repair engine oil leaking protecting driving
# oil leak pilot filter text matterprocessing protecting
# repair engine oil leak text protecting driving
# engine oil blender running constantly matterprocessing driving
# oil leak at diverter valve controlling protecting
# oil leak inlet to oil burner cover plate covering protecting emitting
# repair leak in pilot valve solenoid informationprocessing driving
# Top words:
# protecting
# leak
# oil
# driving
# engine
#
# Cluster 4 :
# alarm on VIMS does not work presenting
# battery cover hinges seized generating covering holding
# beacon mount is broken holding emitting
# bearings are shot holding
# belly plate bolt missing holding
# bent belly plate holding
# boarding ladder not working interfacing
# broken fuel cooler mounts emitting holding
# broken hinge holding
# bucket cracked in arch near cancelled storing holding
# cabin door window cracked holding controlling
# cabin needs resealing holding
# cabin seat needs replacing holding storing
# cabin window needs resealing holding controlling
# carousel popped bolt needs Loctite holding storing
# centrifugal oil filter fault matterprocessing
# centrifugal oil filter leaking matterprocessing
# chord leaking air found holding
# chord pressure fault holding
# cords cracked at and holding
# crack in blade liner left hand side matterprocessing protecting
# crack in boom chord holding
# crack in fuel tank storing
# crack in headboard holding
# crack in lower centre of windscreen controlling
# crack in windscreen controlling
# crack onside rock deflector protecting
# cracked walkway and handrails holding protecting
# cracks in back right hand side handrail protecting
# cracks in decking holding
# cracks in diagonal braces in front holding
# cracks in fire suppression mounts protecting holding
# cracks in headboard holding
# cracks in the dirt chute guiding
# crankcase error holding
# dogbone pin out holding interfacing
# drill out broken bolt see text holding
# driver's door top hinge broken controlling holding
# electrical harness fault holding
# repair cracks in mud bucket storing
# cable gantry crack repairs holding
# fire extinguisher out of date protecting
# crane not working generating
# repair cracks on stick driving
# VIMS keypad light out presenting emitting humaninteraction
# fire extinguisher bracket on deck loose protecting holding
# tray fault holding
# bulk fuel tank cracked and leaking storing
# headboard welds broken / cracked holding covering
# cabin seat unserviceable needs replacing holding storing
# fuel breather missing matterprocessing
# ladder fault interfacing
# operators seat worn padding storing protecting
# chord is leaking air from crack holding
# broken proximity sensor tag carousel sensing presenting holding
# cabin smoke detector missing holding sensing
# cracked power point in cabin holding interfacing
# dust flap on cabin side of mast needs extending protecting holding
# fuel filter water separator housing broken matterprocessing holding
# grease distributor leaking protecting
# hole in door frame holding
# ignition switch broken replace sensing
# ignition switch sticking sensing
# position pressure compensator weeping protecting
# pilot valve leaking oil protecting informationprocessing
# power step control cable broken guiding holding
# pressure control valve in cabin leaking holding protecting
# repair cracks in mast cross braces holding
# rock breaker cracked matterprocessing
# rock breaker in bucket cracked at base holding storing matterprocessing
# window frame needs repair holding
# Top words:
# holding
# in
# protecting
# broken
# storing
#
# Cluster 5 :
# alternator drive leaking driving generating
# alternator failed generating
# alternator not charging generating
# alternator overcharge fault generating
# alternator overcharged generating
# analyse failed driveline component transforming
# and lube system faults protecting
# armrest unserviceable storing
# auto-greaser leaking oil generating protecting
# auto-greaser unserviceable generating
# auto-lube error PO generating
# auto-spray feature not working generating
# axle temperature fault transforming
# axle temperature sensor fault sensing transforming
# backup alarm not working presenting
# batteries discharging generating
# batteries out of service generating
# batteries unserviceable generating
# beacon unserviceable emitting
# blade skin cracked protecting matterprocessing
# blade wear plates cracked and worn matterprocessing protecting
# both stick cylinders leaking driving
# brake cooling hose leaking restricting guiding
# brake cooling hose leaking rear restricting guiding
# brake cooling return hose leaking restricting guiding
# brake release fault restricting
# brake temperature error restricting
# broken clamp on crowd cylinder hose TBC holding driving guiding
# broken mirror guiding
# broken weld on handrail covering protecting
# camera fault sensing
# contactor fault controlling
# coolant pipe clamps needs fitting TBC guiding holding
# cracked suction tube guiding
# crowd cylinder creeping replace driving
# diagnose and repair spray faults generating
# diagnose and repair torque converter temperature error transforming
# diagnose engine fault driving
# differential cooler fan hose leaking transforming emitting generating guiding
# differential cooler hose leaking transforming emitting guiding
# differential cooler pump leaking transforming emitting generating
# differential leak transforming
# differential lube pump leaking transforming generating
# differential lube pump leaking PO transforming generating
# differential pump motor hose leaking transforming generating driving guiding
# duo-cone seals leaking number swing covering
# dust leak operators side window controlling
# speedometer not working sensing
# drag tripped on electrical generating
# hoist motor RTD wired incorrectly driving sensing generating
# possible minor leak on fuel tank storing
# grease pump unserviceable generating
# bearing noisy holding
# IOV fault on drag package generating presenting
# rear wiper motor unserviceable driving
# park brake alarm sounds continuously restricting presenting
# system pump pressure gauge not working generating presenting
# grease pump is bypassing air generating
# park brake alarm fault restricting
# diagnose and repair ladder fault interfacing
# ground fault welding board holding
# grease gauges requires replacing presenting
# swing brake pressure fault restricting transforming
# coolant leaking protecting
# ground fault in propel driving
# drag generator fault generating
# parts washer pump broken generating interfacing
# grease system fault protecting
# investigate auto-lube fault protecting
# brake warning light on restricting emitting
# leaking brake cooling hose restricting guiding
# faulty fuel pressure sensor sensing
# synchronous motor trip driving
# walk motor brake fault driving restricting
# drag chain fault guiding generating
# hoist brake switches need adjusting restricting humaninteraction generating
# cabin jacking cylinder ends unserviceable holding driving
# park brake indicator light going on and off restricting emitting
# tracks need adjusting guiding
# no excitation on hoist generating
# diagnose VIMS error presenting
# stick cylinder leaking driving
# hoist brake number position out of adjustment generating restricting
# CW radiator core leak emitting
# Tele-Remote camera fault sensing humaninteraction
# Tele-Remote cameras fault text sensing humaninteraction
# Tele-Remote fault humaninteraction
# Tele-Remote faults humaninteraction
# Tele-Remote issues humaninteraction
# differential lube hose leaking guiding transforming
# engine fan hose weeping driving generating guiding
# engine overheating driving
# engine shutdown fault driving
# engine vibration <num>-<num> RPM driving
# fan hose leaking generating guiding
# fuel cap is missing covering
# fuel leak
# grease system fail protecting
# grease system fault protecting
# hoist drum cracking generating transforming
# lube fault protecting
# modular does not self assign
# no reception on AM / FM radio transforming
# noisy hydraulic lift cylinder driving
# park brake fault restricting
# repaired x broken lines guiding
# set-up Tele-Remote bogging humaninteraction
# stick cracks driving
# transmission charge hose leaking guiding transforming
# engine shutdown fault driving
# grease system has intermittent fault protecting
# injector error generating
# CW engine oil leaks x protecting driving
# CW engine water pump snapped shaft driving generating guiding
# CW top radiator tank leak again storing
# Tele-Remote fault humaninteraction
# VIMS fuel filter plugged matterprocessing presenting
# aftercooler temperature error emitting
# [ shutdown ] vinyl flooring unserviceable covering
# batteries have no charge storing
# battery unserviceable dropped cell replace storing
# blade control cable tight matterprocessing guiding
# compressor safety valve leaking generating protecting
# constant voltage transformer melted transforming
# dry cell not working properly storing
# depth counter unserviceable sensing
# equipment damaged ( terminal box ) interfacing
# flag missing presenting
# generator flow regulator unserviceable restricting generating
# heater hose in cabin roof unserviceable holding emitting guiding covering
# inverter earthing out transforming
# investigate main transformer overload fault transforming
# microwave oven unserviceable emitting
# number pump contamination switch on sensing generating
# number slew pump contamination switch unserviceable sensing generating driving
# pressure compensator leaking protecting
# pump drive box coupling and shaft unserviceable interfacing transforming generating driving
# radiator blocked with grass transforming emitting
# remove unserviceable air separator matterprocessing
# safety flag missing presenting
# slip ring overgreasing transforming
# start motorvator and set limits
# troubleshoot smart meter not communicating sensing
# transformer trip transforming
# TV monitor does not turn on presenting
# TV monitor has no signal presenting
# voltage regulator fuse fault protecting restricting
# weightometer display on trailer unserviceable sensing presenting storing
# wiper fuse unserviceable protecting matterprocessing
# Top words:
# generating
# fault
# driving
# transforming
# leaking
#
# Cluster 6 :
# air leak
# air leak near side of door controlling
# airhorn not working presenting
# all dash lights on emitting
# back rest unserviceable handle broken humaninteraction storing
# backhoe windscreen to be fixed controlling matterprocessing
# backlight on dash unserviceable emitting presenting
# backlights on dash blown emitting presenting
# beacon not working emitting
# blade light blown needs replacing emitting matterprocessing
# blown lift cylinder o-ring driving covering
# blown steering hose guiding controlling
# blown steering pump hose generating guiding controlling
# boarding gate hinge broken controlling holding
# boarding gate latch not working controlling
# broken grease plug controlling
# broken joystick PO humaninteraction
# broken ripper tooth matterprocessing
# cabin seals leaking dust PO holding covering
# cabin seals leaking dust bad holding covering
# control valve unserviceable see long text controlling
# cracked front window controlling
# cracked fuel tank storing
# cracked hydraulic pipe guiding
# cracked steering tank suction tube storing guiding controlling
# dash broken presenting
# differential lock broken transforming controlling
# drivers window fault controlling
# ripper control valve falling off controlling
# replace faulty brake sensor task restricting sensing
# replace leaking transfer pipe guiding
# position brake temperature error restricting
# front revolving light not working emitting
# machine will not start
# rear steering accumulator leak storing controlling
# replace oil leaks protecting
# rear through shaft universal joint unserviceable guiding
# all lighting requires testing and tagging emitting
# main isolator needs clean out controlling
# front window cracked replace controlling
# rear door struts require replacing controlling holding
# replace leaking scavenge pump generating
# tail pulley has no grease lines guiding
# replace missing cutting edge matterprocessing
# movement on steering column transforming controlling
# replace x cracked windows controlling
# middle air drain tap leaking controlling interfacing
# bottom steering shaft universal joint worn guiding controlling
# fitting leaking out of main air tanks interfacing storing
# repair centre hitch oil leaks interfacing protecting
# steering hub caps require replacing covering controlling
# replace damage auto-greaser door generating controlling
# replace cracked transmission dropbox transforming
# front window roller blind broken controlling restricting
# replace position tyre damaged guiding
# replace position tyre mismatched guiding
# missing poppet valve controlling
# air leak
# emergency gate latch broken controlling
# exhaust leak guiding
# front headlight blown emitting
# radiator relief valves leaking controlling emitting
# rear steering accumulator leaking storing controlling
# replace blocked dryer matterprocessing
# replace broken onside mirror guiding
# replace cracked exhaust shield protecting
# replace failed air conditioner compressor emitting generating
# replace leaking steering cylinder driving
# ripper shank broken matterprocessing
# replace hydraulic oil leak text
# steering pin no grease text holding protecting controlling
# adaptor leaking at implement valve controlling
# aftercooler tank gauge broken emitting presenting storing
# air brake line blown requires replacing controlling restricting guiding
# broken wire on speaker emitting guiding
# cabin side weightometer not working sensing
# collect broken tooth matterprocessing
# contamination alarm coming up sensing
# contamination alarm on sensing
# electric propel siren not working driving emitting
# earth wire broken on bottom of radiator controlling emitting
# flow battery power storing
# front lights keep blowing fuse protecting emitting
# high voltage slip ring inspection grease leak protecting transforming
# key broken in ignition switch sensing humaninteraction
# glass window has large crack restricting
# position chip sensor alarm sensing
# position pump cavity low interfacing generating
# radiator sight glasses unserviceable emitting presenting
# repair faulty safety valve protecting
# replace broken earth terminal controlling
# replace chip indicators ( leaking ) sensing
# replace cracked glass in entry door controlling interfacing
# replace cracked water separator matterprocessing
# replace shorted diode RPC restricting
# water separator filter leaking see photo matterprocessing
# water separator leaking fuel matterprocessing
# Top words:
# controlling
# replace
# broken
# emitting
# guiding
#
# Cluster 7 :
# blown crowd cylinder hose driving guiding
# blown right hand bucket cylinder hose driving guiding
# Top words:
# guiding
# blown
# cylinder
# driving
# hose
#
# Cluster 8 :
# air leaking from line outside guiding
# blown air conditioner hose emitting guiding
# blown air conditioner hose to radiator emitting guiding
# blown brake hose restricting guiding
# blown extension line from position guiding
# blown hose in hitch guiding interfacing
# blown hose on boom guiding holding
# blown light on boom emitting holding
# blown o-ring off steering hose guiding covering controlling
# blown o-ring on left hand lift cylinder driving covering
# blown o-ring on steering hose guiding covering controlling
# blown oil cooler hose x metre emitting guiding
# blown position tyre guiding
# change position flat tyre guiding
# change position tyre damage text guiding
# coolant hose leaking at right hand bottom guiding
# cooler return pipe coupling leak emitting guiding interfacing
# damage to position tyre guiding
# damaged position tyre guiding
# damaged position tyre and rim guiding holding
# replace blown implement hose guiding
# replace blown right hand steering hose guiding controlling
# replace damaged position tyre and position guiding
# position tyre blown guiding
# replace damaged tyre on position guiding
# hydraulic hose leaking in centre of machine guiding
# replace blown main pump hose generating guiding
# repair exhaust leaks guiding
# HMU hose weeping guiding driving
# brake hose needs to be replaced guiding restricting
# hose leak developing guiding
# repair blown air conditioner hose emitting guiding
# replace blown hose guiding
# replace blown work lights emitting
# replaced leaking steering hose guiding
# blown air conditioner fuse emitting protecting
# centrifuge hose leaking replace matterprocessing guiding
# heat up locked steels guiding
# replace seized air conditioner control cable emitting guiding
# Top words:
# guiding
# hose
# blown
# position
# emitting
#
# Cluster 9 :
# steering cylinder bearings have excess play driving holding
# movement found right hand engine mount driving holding
# replace right hand lift cylinder leaking driving
# CW left hand hoist cylinder leaking plug controlling driving
# CW right hand hoist cylinder leaking driving
# oil centrifuge gasket leaking right hand engine matterprocessing driving covering
# Top words:
# driving
# hand
# cylinder
# right
# leaking
#
# Cluster 10 :
# diagnose transmission overheat fault transforming
# diagnose transmission slipping fault transforming
# failed PTO and auxiliary drive PO transforming
# transmission fill / drain plug unserviceable transforming controlling
# repair leaking swing pedestal seals holding covering transforming
# replace transmission cracked transforming
# mechanical PTO not meshing transforming
# repair brake fault restricting
# swing resolver not counting transforming sensing
# repair gear fault transforming
# swing resolver fault transforming sensing
# PTO shaft requires replacing transforming guiding
# PTO shaft input seal leaking covering guiding transforming
# repair leaking centrifugal filter matterprocessing
# repair transmission fault transforming
# repair transmission oil leak text protecting transforming
# transmission temperature fault transforming
# CW PTO universal joint failed transforming
# CW transmission failed transforming
# PTO input seal leaking covering transforming
# repair worn centrifuge filter matterprocessing
# Top words:
# transforming
# transmission
# fault
# repair
# PTO
#
# Cluster 11 :
# replace unserviceable differential drain plugs transforming controlling
# right hand bobbin roller unserviceable holding
# left hand side pinion change out cover cracking transforming covering
# left hand rear brake cooling hose leaking restricting guiding
# AM / FM radio needs new aerial transforming
# left hand boom cylinder hose leaking PO driving guiding
# left hand corner bonnet cracked covering
# left hand side boom foot crack repair holding
# lower left hand headlight blown emitting
# Bradken to repair broken clam storing
# <sensitive> depth counter not working sensing
# left hand chain guide unserviceable guiding
# left hand chain guide worn at the top guiding
# left hand PTO pump chip sensor harness unserviceable sensing transforming generating holding
# right hand PTO cavity emptying interfacing transforming
# replace unserviceable grease distributor protecting
# replace unserviceable chip indicators sensing
# replace unserviceable ignition switch sensing
# replace unserviceable transmission screen and magnet driving transforming matterprocessing
# will not start batteries unserviceable storing
# Top words:
# hand
# unserviceable
# left
# transforming
# replace
#
# Cluster 12 :
# broken left hand side mirror guiding
# broken right hand side door window controlling
# diagnose / repair slow steering controlling
# front right hand roller need to be fitted holding
# repair right hand fuel tank crack storing
# repair boom cracks left hand side holding
# investigate / repair no gear fault transforming
# investigate / repair joystick needs repair humaninteraction
# repair movement in left hand steering pin holding controlling
# repair cracked steering tank mo storing controlling
# repair right hand track frame crack holding
# number right hand air brake line needs replacing controlling restricting guiding
# crack repairs left hand window frame holding
# diagnose / repair right hand scoreboard not working presenting
# repair crack in right hand side of rear cross member holding
# repair chassis crack at right hand rear cross member holding
# repair crack in rear cross member holding
# repair crack on left hand front heat shield guiding
# repair cracked baffle in hydraulic tank controlling storing
# repair cracked roof skin left hand side exhaust guiding covering
# repair left hand scoreboard base cracked holding presenting
# Top words:
# repair
# hand
# holding
# right
# left

# %% [markdown]
# ### ward clustering

# %%
silhouette('ward', cluster_embeddings)

# %%
linkage_data = linkage(cluster_embeddings, method='ward')
fig = plt.figure(figsize=(25, 10))
dn = dendrogram(linkage_data)
plt.show()

# %%
k=13
cluster_labels = fcluster(linkage_data, k, criterion='maxclust')
for i in range(1,k+1):
    print("Cluster",i,":")
    cluster_words = {}
    for j in range(len(cluster_labels)):
        if cluster_labels[j]==i:
            print(" ".join(dataset_not_padded[j]))
            for word in dataset_not_padded[j]:
                if word in cluster_words:
                    cluster_words[word]+=1
                else:
                    cluster_words[word]=1
    print("Top words:")
    sorted_cluster_words = sorted(cluster_words, key=cluster_words.get, reverse=True)
    for j in range(min(len(sorted_cluster_words), 5)):
        print(sorted_cluster_words[j])
    print()
# Out:
# Cluster 1 :
# change out blown o-ring on steering pump
# change out blown position tyre
# change out blown steering hose
# change out broken bolt on brake pump
# change out broken prelube bracket
# change out broken stabilizer bar
# change out cracked pipe on valve bank
# change out cracked position adaptor and tooth
# change out exhaust clamp broken on left hand side [t |]
# change out front upper window cracked
# change out leak slew motor hose
# change out leaking HMU on next
# change out leaking fan hoses
# change out leaking heater taps
# change out leaking hydraulic hose
# change out leaking implement pump
# change out leaking relay valve
# change out leaking steering hose
# change out left hand steering cylinder leaking
# change out position and tyre worn out
# change out position tyre sensor not reading
# change out position tyre damage
# change out unserviceable jacket water pump
# change out unserviceable left hand bucket cylinder hose
# change out unserviceable position tyre
# change out unserviceable right hand clam cylinder hose
# change out unserviceable right hand tilt cylinder
# change out unserviceable swing brake cylinder
# change out weeping boom cylinder hose
# change out worn position tyre
# cutting edges loose
# cutting edges need change out
# change out leaking transmission hose
# change out position tyre worn
# change out blown hose
# change out broken grease lines
# change out leaking transmission hose
# change out number faulty injector assembly
# change out plugged fuel filters
# change out worn ripper tip ripper tip
# GET change out worn cutting edges
# Top words:
# out
# change
# hose
# leaking
# position
#
# Cluster 2 :
# air conditioner thermostat not working
# air conditioner thermostat unserviceable
# air conditioner unserviceable
# air conditioner unserviceable when stationary
# air conditioner warm
# air conditioner compressor corroded
# air conditioner compressor unserviceable
# air conditioner fault
# air conditioner no good
# air conditioner system leaking
# air conditioner accessory drive leaking oil
# air conditioner belt broken
# air conditioner compressor not working
# air conditioner compressor tripping out
# air conditioner drive leaking
# air conditioner drive leaking oil
# air conditioner fan unserviceable fit new
# air conditioner fault
# air conditioner needs a boost not cold
# air conditioner not cold PO
# air conditioner not cold electrical faults
# air conditioner pressure switch unserviceable
# air conditioner fan speed resistor not working and
# Top words:
# air
# conditioner
# not
# unserviceable
# compressor
#
# Cluster 3 :
# coolant leak
# coolant leak at engine oil cooler
# coolant leak at jacket water pump
# differential oil leak
# oil leak at air compressor
# oil leak swingbox
# oil leak from behind water pump
# coolant leak
# differential oil leak
# hydraulic oil leak from environmental
# investigate torque converter fan pump oil leak
# minor transmission oil leak
# oil leak pilot filter text
# oil leak at diverter valve
# oil leak inlet to oil burner cover plate
# repair leak in pilot valve solenoid
# Top words:
# leak
# oil
# coolant
# at
# pump
#
# Cluster 4 :
# air filters plugged
# air horn disconnected
# air horn does not work
# air horn fault
# air horn not working
# air horn not working compressor awaiting
# air horn stuck on
# air horn unserviceable
# air horn working intermittently
# bearing on air conditioner compressor unserviceable
# broken air conditioner guard
# check / repair engine oil leak
# dragline air conditioner units need cleaning
# oil found in revolving frame
# investigate and repair oil leak
# handrail above battery box cracked
# investigate engine oil leak
# engine oil leaks right hand side
# repair oil leak position wheel end
# repair air conditioner and wiring fault
# inspect bad engine oil leak
# air horn not working
# engine bay light blown
# engine oil leak
# engine oil leak inspection plate
# repair engine oil leak and
# repair engine oil leaking
# repair engine oil leak text
# air pressure safety valve exhausting
# engine oil blender running constantly
# keeps blowing starter / horn fuse
# repair air leak at air tank safety valve
# Top words:
# air
# oil
# engine
# horn
# leak
#
# Cluster 5 :
# armrest unserviceable
# battery cover hinges seized
# beacon mount is broken
# bearings are shot
# belly plate bolt missing
# bent belly plate
# boarding ladder not working
# broken fuel cooler mounts
# broken hinge
# broken weld on handrail
# bucket cracked in arch near cancelled
# cabin door window cracked
# cabin needs resealing
# cabin seat needs replacing
# cabin window needs resealing
# carousel popped bolt needs Loctite
# centrifugal oil filter fault
# centrifugal oil filter leaking
# chord leaking air found
# chord pressure fault
# coolant pipe clamps needs fitting TBC
# cords cracked at and
# crack in blade liner left hand side
# crack in boom chord
# crack in fuel tank
# crack in headboard
# crack in lower centre of windscreen
# crack in windscreen
# crack onside rock deflector
# cracked walkway and handrails
# cracks in back right hand side handrail
# cracks in decking
# cracks in diagonal braces in front
# cracks in fire suppression mounts
# cracks in headboard
# cracks in the dirt chute
# crankcase error
# dogbone pin out
# drill out broken bolt see text
# driver's door top hinge broken
# electrical harness fault
# cable gantry crack repairs
# fire extinguisher out of date
# crane not working
# VIMS keypad light out
# fire extinguisher bracket on deck loose
# tray fault
# bulk fuel tank cracked and leaking
# headboard welds broken / cracked
# repair movement in left hand steering pin
# cabin seat unserviceable needs replacing
# fuel breather missing
# ladder fault
# operators seat worn padding
# stick cracks
# chord is leaking air from crack
# broken proximity sensor tag carousel
# cabin smoke detector missing
# cracked power point in cabin
# dust flap on cabin side of mast needs extending
# flow battery power
# fuel filter water separator housing broken
# heater hose in cabin roof unserviceable
# hole in door frame
# ignition switch broken replace
# ignition switch sticking
# position pressure compensator weeping
# pilot valve leaking oil
# power step control cable broken
# pressure control valve in cabin leaking
# rock breaker cracked
# rock breaker in bucket cracked at base
# window frame needs repair
# Top words:
# in
# broken
# cabin
# cracked
# crack
#
# Cluster 6 :
# broken left hand side mirror
# broken right hand side door window
# diagnose / repair slow steering
# repair cracks in mud bucket
# front right hand roller need to be fitted
# repair right hand fuel tank crack
# repair cracks on stick
# repair boom cracks left hand side
# investigate / repair no gear fault
# investigate / repair joystick needs repair
# repair cracked steering tank mo
# repair right hand track frame crack
# number right hand air brake line needs replacing
# crack repairs left hand window frame
# diagnose / repair right hand scoreboard not working
# repair crack in right hand side of rear cross member
# repair chassis crack at right hand rear cross member
# repair crack in rear cross member
# repair crack on left hand front heat shield
# repair cracked baffle in hydraulic tank
# repair cracked roof skin left hand side exhaust
# repair cracks in mast cross braces
# repair left hand scoreboard base cracked
# Top words:
# repair
# hand
# right
# crack
# left
#
# Cluster 7 :
# replace unserviceable differential drain plugs
# right hand bobbin roller unserviceable
# left hand side pinion change out cover cracking
# left hand rear brake cooling hose leaking
# AM / FM radio needs new aerial
# left hand boom cylinder hose leaking PO
# left hand corner bonnet cracked
# left hand side boom foot crack repair
# Bradken to repair broken clam
# <sensitive> depth counter not working
# left hand chain guide unserviceable
# left hand chain guide worn at the top
# left hand PTO pump chip sensor harness unserviceable
# right hand PTO cavity emptying
# replace unserviceable grease distributor
# replace unserviceable chip indicators
# replace unserviceable ignition switch
# replace unserviceable transmission screen and magnet
# will not start batteries unserviceable
# Top words:
# hand
# unserviceable
# left
# replace
# right
#
# Cluster 8 :
# alarm on VIMS does not work
# analyse failed driveline component
# auto-greaser unserviceable
# auto-lube error PO
# batteries out of service
# batteries unserviceable
# blade skin cracked
# broken clamp on crowd cylinder hose TBC
# broken joystick PO
# broken mirror
# camera fault
# compressor oil pressure switch unserviceable
# contactor fault
# cracked suction tube
# dash broken
# diagnose and repair spray faults
# diagnose and repair torque converter temperature error
# speedometer not working
# machine will not start
# grease pump unserviceable
# IOV fault on drag package
# system pump pressure gauge not working
# grease pump is bypassing air
# diagnose and repair ladder fault
# ground fault welding board
# grease gauges requires replacing
# ground fault in propel
# parts washer pump broken
# brake warning light on
# faulty fuel pressure sensor
# hoist brake switches need adjusting
# tracks need adjusting
# diagnose VIMS error
# hoist brake number position out of adjustment
# Tele-Remote fault
# Tele-Remote faults
# Tele-Remote issues
# fuel cap is missing
# repaired x broken lines
# set-up Tele-Remote bogging
# injector error
# Tele-Remote fault
# aftercooler temperature error
# battery unserviceable dropped cell replace
# blade control cable tight
# compressor safety valve leaking
# contamination alarm coming up
# contamination alarm on
# depth counter unserviceable
# equipment damaged ( terminal box )
# flag missing
# inverter earthing out
# microwave oven unserviceable
# number pump contamination switch on
# position pump cavity low
# pressure compensator leaking
# radiator blocked with grass
# safety flag missing
# siren unserviceable
# start motorvator and set limits
# troubleshoot smart meter not communicating
# TV monitor does not turn on
# TV monitor has no signal
# weightometer display on trailer unserviceable
# Top words:
# unserviceable
# on
# fault
# not
# broken
#
# Cluster 9 :
# brake cooling hose leaking
# brake cooling hose leaking rear
# brake cooling return hose leaking
# brake temperature error
# differential cooler fan hose leaking
# differential cooler hose leaking
# differential cooler pump leaking
# differential lube pump leaking
# differential lube pump leaking PO
# differential pump motor hose leaking
# failed PTO and auxiliary drive PO
# transmission fill / drain plug unserviceable
# repair leaking swing pedestal seals
# replace transmission cracked
# park brake alarm sounds continuously
# park brake alarm fault
# mechanical PTO not meshing
# repair brake fault
# walk motor brake fault
# repair gear fault
# park brake indicator light going on and off
# PTO shaft requires replacing
# PTO shaft input seal leaking
# differential lube hose leaking
# park brake fault
# repair leaking centrifugal filter
# repair transmission fault
# transmission charge hose leaking
# repair transmission oil leak text
# CW PTO universal joint failed
# PTO input seal leaking
# investigate main transformer overload fault
# repair worn centrifuge filter
# Top words:
# leaking
# brake
# hose
# differential
# repair
#
# Cluster 10 :
# alternator drive leaking
# alternator failed
# alternator not charging
# alternator overcharge fault
# alternator overcharged
# and lube system faults
# auto-greaser leaking oil
# auto-spray feature not working
# axle temperature fault
# axle temperature sensor fault
# backup alarm not working
# batteries discharging
# beacon unserviceable
# blade wear plates cracked and worn
# both stick cylinders leaking
# brake release fault
# crowd cylinder creeping replace
# diagnose engine fault
# diagnose transmission overheat fault
# diagnose transmission slipping fault
# differential leak
# duo-cone seals leaking number swing
# dust leak operators side window
# drag tripped on electrical
# hoist motor RTD wired incorrectly
# possible minor leak on fuel tank
# bearing noisy
# steering cylinder bearings have excess play
# movement found right hand engine mount
# rear wiper motor unserviceable
# replace right hand lift cylinder leaking
# swing brake pressure fault
# coolant leaking
# drag generator fault
# grease system fault
# investigate auto-lube fault
# synchronous motor trip
# swing resolver not counting
# swing resolver fault
# drag chain fault
# cabin jacking cylinder ends unserviceable
# no excitation on hoist
# stick cylinder leaking
# CW left hand hoist cylinder leaking plug
# CW right hand hoist cylinder leaking
# Tele-Remote camera fault
# Tele-Remote cameras fault text
# engine fan hose weeping
# engine overheating
# engine shutdown fault
# engine vibration <num>-<num> RPM
# fuel leak
# grease system fail
# grease system fault
# hoist drum cracking
# lube fault
# modular does not self assign
# no reception on AM / FM radio
# noisy hydraulic lift cylinder
# engine shutdown fault
# grease system has intermittent fault
# transmission temperature fault
# CW engine oil leaks x
# CW engine water pump snapped shaft
# CW transmission failed
# VIMS fuel filter plugged
# batteries have no charge
# constant voltage transformer melted
# dry cell not working properly
# electric propel siren not working
# generator flow regulator unserviceable
# grease distributor leaking
# number slew pump contamination switch unserviceable
# oil centrifuge gasket leaking right hand engine
# pump drive box coupling and shaft unserviceable
# remove unserviceable air separator
# slip ring overgreasing
# transformer trip
# voltage regulator fuse fault
# wiper fuse unserviceable
# Top words:
# fault
# leaking
# engine
# unserviceable
# cylinder
#
# Cluster 11 :
# air leaking from line outside
# blown air conditioner hose
# blown air conditioner hose to radiator
# blown brake hose
# blown crowd cylinder hose
# blown extension line from position
# blown hose in hitch
# blown hose on boom
# blown light on boom
# blown o-ring off steering hose
# blown o-ring on left hand lift cylinder
# blown o-ring on steering hose
# blown oil cooler hose x metre
# blown position tyre
# blown right hand bucket cylinder hose
# change position flat tyre
# change position tyre damage text
# coolant hose leaking at right hand bottom
# cooler return pipe coupling leak
# cracked hydraulic pipe
# damage to position tyre
# damaged position tyre
# damaged position tyre and rim
# replace blown implement hose
# replace blown right hand steering hose
# replace damaged position tyre and position
# tail pulley has no grease lines
# position tyre blown
# leaking brake cooling hose
# replace damaged tyre on position
# hydraulic hose leaking in centre of machine
# replace blown main pump hose
# replace position tyre damaged
# replace position tyre mismatched
# repair exhaust leaks
# HMU hose weeping
# brake hose needs to be replaced
# exhaust leak
# fan hose leaking
# hose leak developing
# lower left hand headlight blown
# repair blown air conditioner hose
# replace blown hose
# replace blown work lights
# replaced leaking steering hose
# [ shutdown ] vinyl flooring unserviceable
# blown air conditioner fuse
# centrifuge hose leaking replace
# heat up locked steels
# replace seized air conditioner control cable
# replace shorted diode RPC
# Top words:
# hose
# blown
# position
# replace
# tyre
#
# Cluster 12 :
# back rest unserviceable handle broken
# backhoe windscreen to be fixed
# boarding gate hinge broken
# boarding gate latch not working
# broken grease plug
# broken ripper tooth
# cabin seals leaking dust PO
# cabin seals leaking dust bad
# control valve unserviceable see long text
# cracked front window
# cracked fuel tank
# differential lock broken
# drivers window fault
# ripper control valve falling off
# replace faulty brake sensor task
# replace leaking transfer pipe
# position brake temperature error
# front revolving light not working
# rear through shaft universal joint unserviceable
# main isolator needs clean out
# front window cracked replace
# rear door struts require replacing
# replace leaking scavenge pump
# replace missing cutting edge
# movement on steering column
# replace x cracked windows
# fitting leaking out of main air tanks
# replace damage auto-greaser door
# replace cracked transmission dropbox
# front window roller blind broken
# missing poppet valve
# emergency gate latch broken
# replace blocked dryer
# replace broken onside mirror
# replace cracked exhaust shield
# replace leaking steering cylinder
# ripper shank broken
# adaptor leaking at implement valve
# broken wire on speaker
# cabin side weightometer not working
# collect broken tooth
# key broken in ignition switch
# glass window has large crack
# position chip sensor alarm
# replace broken earth terminal
# replace chip indicators ( leaking )
# replace cracked glass in entry door
# replace cracked water separator
# water separator filter leaking see photo
# water separator leaking fuel
# Top words:
# replace
# broken
# leaking
# cracked
# window
#
# Cluster 13 :
# air leak
# air leak near side of door
# airhorn not working
# all dash lights on
# backlight on dash unserviceable
# backlights on dash blown
# beacon not working
# blade light blown needs replacing
# blown lift cylinder o-ring
# blown steering hose
# blown steering pump hose
# cracked steering tank suction tube
# rear steering accumulator leak
# replace oil leaks
# all lighting requires testing and tagging
# middle air drain tap leaking
# bottom steering shaft universal joint worn
# repair centre hitch oil leaks
# steering hub caps require replacing
# CW radiator core leak
# air leak
# front headlight blown
# radiator relief valves leaking
# rear steering accumulator leaking
# replace failed air conditioner compressor
# replace hydraulic oil leak text
# steering pin no grease text
# CW top radiator tank leak again
# aftercooler tank gauge broken
# air brake line blown requires replacing
# earth wire broken on bottom of radiator
# front lights keep blowing fuse
# high voltage slip ring inspection grease leak
# radiator sight glasses unserviceable
# repair faulty safety valve
# Top words:
# leak
# steering
# blown
# air
# radiator

# %% [markdown]
# ### centroid clustering

# %%
silhouette('centroid', cluster_embeddings)

# %%
linkage_data = linkage(cluster_embeddings, method='centroid')
fig = plt.figure(figsize=(25, 10))
dn = dendrogram(linkage_data)
plt.show()

# %%
k=40
cluster_labels = fcluster(linkage_data, k, criterion='maxclust')
for i in range(1,k+1):
    print("Cluster",i,":")
    cluster_words = {}
    for j in range(len(cluster_labels)):
        if cluster_labels[j]==i:
            print(" ".join(dataset_not_padded[j]))
            for word in dataset_not_padded[j]:
                if word in cluster_words:
                    cluster_words[word]+=1
                else:
                    cluster_words[word]=1
    print("Top words:")
    sorted_cluster_words = sorted(cluster_words, key=cluster_words.get, reverse=True)
    for j in range(min(len(sorted_cluster_words), 5)):
        print(sorted_cluster_words[j])
    print()
# Out:
# Cluster 1 :
# change out blown o-ring on steering pump
# change out blown position tyre
# change out blown steering hose
# change out broken bolt on brake pump
# change out broken prelube bracket
# change out broken stabilizer bar
# change out cracked pipe on valve bank
# change out cracked position adaptor and tooth
# change out exhaust clamp broken on left hand side [t |]
# change out front upper window cracked
# change out leak slew motor hose
# change out leaking HMU on next
# change out leaking fan hoses
# change out leaking heater taps
# change out leaking hydraulic hose
# change out leaking implement pump
# change out leaking relay valve
# change out leaking steering hose
# change out left hand steering cylinder leaking
# change out position and tyre worn out
# change out position tyre sensor not reading
# change out position tyre damage
# change out unserviceable jacket water pump
# change out unserviceable left hand bucket cylinder hose
# change out unserviceable position tyre
# change out unserviceable right hand clam cylinder hose
# change out unserviceable right hand tilt cylinder
# change out unserviceable swing brake cylinder
# change out weeping boom cylinder hose
# change out worn position tyre
# cutting edges loose
# cutting edges need change out
# change out leaking transmission hose
# change out position tyre worn
# change out blown hose
# change out broken grease lines
# change out leaking transmission hose
# change out number faulty injector assembly
# change out plugged fuel filters
# change out worn ripper tip ripper tip
# GET change out worn cutting edges
# Top words:
# out
# change
# hose
# leaking
# position
#
# Cluster 2 :
# repair air conditioner and wiring fault
# repair air leak at air tank safety valve
# Top words:
# air
# repair
# conditioner
# and
# wiring
#
# Cluster 3 :
# air conditioner thermostat not working
# air conditioner thermostat unserviceable
# air conditioner unserviceable
# air conditioner unserviceable when stationary
# air conditioner warm
# air conditioner compressor corroded
# air conditioner compressor unserviceable
# air conditioner fault
# air conditioner no good
# air conditioner system leaking
# air conditioner accessory drive leaking oil
# air conditioner belt broken
# air conditioner compressor not working
# air conditioner compressor tripping out
# air conditioner drive leaking
# air conditioner drive leaking oil
# air conditioner fan unserviceable fit new
# air conditioner fault
# air conditioner needs a boost not cold
# air conditioner not cold PO
# air conditioner not cold electrical faults
# air conditioner pressure switch unserviceable
# air conditioner fan speed resistor not working and
# Top words:
# air
# conditioner
# not
# unserviceable
# compressor
#
# Cluster 4 :
# compressor oil pressure switch unserviceable
# Top words:
# compressor
# oil
# pressure
# switch
# unserviceable
#
# Cluster 5 :
# CW engine oil leaks x
# CW engine water pump snapped shaft
# Top words:
# CW
# engine
# oil
# leaks
# x
#
# Cluster 6 :
# diagnose engine fault
# engine shutdown fault
# engine shutdown fault
# Top words:
# engine
# fault
# shutdown
# diagnose
#
# Cluster 7 :
# analyse failed driveline component
# Top words:
# analyse
# failed
# driveline
# component
#
# Cluster 8 :
# check / repair engine oil leak
# investigate and repair oil leak
# investigate engine oil leak
# engine oil leaks right hand side
# repair oil leak position wheel end
# inspect bad engine oil leak
# engine oil leak
# engine oil leak inspection plate
# repair engine oil leak and
# repair engine oil leaking
# repair engine oil leak text
# engine oil blender running constantly
# Top words:
# oil
# engine
# leak
# repair
# investigate
#
# Cluster 9 :
# coolant leak
# coolant leak at engine oil cooler
# coolant leak at jacket water pump
# differential oil leak
# replace oil leaks
# oil leak at air compressor
# oil leak swingbox
# repair centre hitch oil leaks
# oil leak from behind water pump
# coolant leak
# differential oil leak
# hydraulic oil leak from environmental
# investigate torque converter fan pump oil leak
# minor transmission oil leak
# oil leak pilot filter text
# replace hydraulic oil leak text
# oil leak at diverter valve
# oil leak inlet to oil burner cover plate
# repair leak in pilot valve solenoid
# Top words:
# leak
# oil
# coolant
# at
# pump
#
# Cluster 10 :
# change position flat tyre
# change position tyre damage text
# Top words:
# change
# position
# tyre
# flat
# damage
#
# Cluster 11 :
# blown o-ring off steering hose
# blown o-ring on left hand lift cylinder
# blown o-ring on steering hose
# replace seized air conditioner control cable
# Top words:
# blown
# o-ring
# steering
# hose
# on
#
# Cluster 12 :
# blown crowd cylinder hose
# Top words:
# blown
# crowd
# cylinder
# hose
#
# Cluster 13 :
# blown right hand bucket cylinder hose
# Top words:
# blown
# right
# hand
# bucket
# cylinder
#
# Cluster 14 :
# repair blown air conditioner hose
# Top words:
# repair
# blown
# air
# conditioner
# hose
#
# Cluster 15 :
# replace unserviceable differential drain plugs
# AM / FM radio needs new aerial
# Bradken to repair broken clam
# <sensitive> depth counter not working
# replace unserviceable grease distributor
# replace unserviceable chip indicators
# replace unserviceable ignition switch
# replace unserviceable transmission screen and magnet
# will not start batteries unserviceable
# Top words:
# unserviceable
# replace
# not
# differential
# drain
#
# Cluster 16 :
# air leak
# air leak near side of door
# air leak
# Top words:
# air
# leak
# near
# side
# of
#
# Cluster 17 :
# replace failed air conditioner compressor
# Top words:
# replace
# failed
# air
# conditioner
# compressor
#
# Cluster 18 :
# alternator drive leaking
# pump drive box coupling and shaft unserviceable
# Top words:
# drive
# alternator
# leaking
# pump
# box
#
# Cluster 19 :
# compressor safety valve leaking
# pressure compensator leaking
# Top words:
# leaking
# compressor
# safety
# valve
# pressure
#
# Cluster 20 :
# cabin door window cracked
# cabin window needs resealing
# driver's door top hinge broken
# Top words:
# cabin
# door
# window
# cracked
# needs
#
# Cluster 21 :
# auto-greaser leaking oil
# battery cover hinges seized
# bearings are shot
# belly plate bolt missing
# bent belly plate
# boarding ladder not working
# broken fuel cooler mounts
# broken hinge
# bucket cracked in arch near cancelled
# cabin needs resealing
# cabin seat needs replacing
# carousel popped bolt needs Loctite
# centrifugal oil filter fault
# centrifugal oil filter leaking
# chord leaking air found
# chord pressure fault
# cords cracked at and
# crack in blade liner left hand side
# crack in boom chord
# crack in fuel tank
# crack in headboard
# crack in lower centre of windscreen
# crack in windscreen
# crack onside rock deflector
# cracked walkway and handrails
# cracks in back right hand side handrail
# cracks in decking
# cracks in diagonal braces in front
# cracks in fire suppression mounts
# cracks in headboard
# cracks in the dirt chute
# crankcase error
# dogbone pin out
# drill out broken bolt see text
# electrical harness fault
# repair cracks in mud bucket
# cable gantry crack repairs
# fire extinguisher out of date
# crane not working
# bearing noisy
# repair cracks on stick
# VIMS keypad light out
# fire extinguisher bracket on deck loose
# coolant leaking
# tray fault
# bulk fuel tank cracked and leaking
# headboard welds broken / cracked
# cabin seat unserviceable needs replacing
# fuel breather missing
# ladder fault
# operators seat worn padding
# chord is leaking air from crack
# broken proximity sensor tag carousel
# cabin smoke detector missing
# cracked power point in cabin
# dust flap on cabin side of mast needs extending
# fuel filter water separator housing broken
# grease distributor leaking
# hole in door frame
# ignition switch broken replace
# ignition switch sticking
# position pressure compensator weeping
# pilot valve leaking oil
# power step control cable broken
# pressure control valve in cabin leaking
# repair cracks in mast cross braces
# rock breaker cracked
# rock breaker in bucket cracked at base
# window frame needs repair
# Top words:
# in
# leaking
# crack
# cracks
# broken
#
# Cluster 22 :
# diagnose transmission overheat fault
# diagnose transmission slipping fault
# failed PTO and auxiliary drive PO
# transmission fill / drain plug unserviceable
# repair leaking swing pedestal seals
# replace transmission cracked
# mechanical PTO not meshing
# repair brake fault
# repair gear fault
# PTO shaft requires replacing
# PTO shaft input seal leaking
# repair leaking centrifugal filter
# repair transmission fault
# repair transmission oil leak text
# transmission temperature fault
# CW PTO universal joint failed
# CW transmission failed
# PTO input seal leaking
# repair worn centrifuge filter
# Top words:
# transmission
# repair
# fault
# PTO
# leaking
#
# Cluster 23 :
# brake cooling hose leaking
# brake cooling hose leaking rear
# brake cooling return hose leaking
# brake temperature error
# differential cooler fan hose leaking
# differential cooler hose leaking
# differential cooler pump leaking
# differential lube pump leaking
# differential lube pump leaking PO
# differential pump motor hose leaking
# duo-cone seals leaking number swing
# differential lube hose leaking
# transmission charge hose leaking
# Top words:
# leaking
# hose
# differential
# brake
# pump
#
# Cluster 24 :
# broken clamp on crowd cylinder hose TBC
# broken mirror
# speedometer not working
# parts washer pump broken
# repaired x broken lines
# equipment damaged ( terminal box )
# flag missing
# radiator blocked with grass
# TV monitor does not turn on
# TV monitor has no signal
# weightometer display on trailer unserviceable
# Top words:
# broken
# on
# not
# TV
# monitor
#
# Cluster 25 :
# air filters plugged
# air horn disconnected
# air horn does not work
# air horn fault
# air horn not working
# air horn not working compressor awaiting
# air horn stuck on
# air horn unserviceable
# air horn working intermittently
# alarm on VIMS does not work
# alternator failed
# alternator not charging
# alternator overcharge fault
# alternator overcharged
# and lube system faults
# armrest unserviceable
# auto-greaser unserviceable
# auto-lube error PO
# auto-spray feature not working
# axle temperature fault
# axle temperature sensor fault
# backup alarm not working
# batteries discharging
# batteries out of service
# batteries unserviceable
# beacon mount is broken
# beacon unserviceable
# bearing on air conditioner compressor unserviceable
# blade light blown needs replacing
# blade skin cracked
# blade wear plates cracked and worn
# both stick cylinders leaking
# brake release fault
# broken air conditioner guard
# broken weld on handrail
# camera fault
# contactor fault
# crowd cylinder creeping replace
# diagnose and repair spray faults
# diagnose and repair torque converter temperature error
# differential leak
# dragline air conditioner units need cleaning
# drag tripped on electrical
# hoist motor RTD wired incorrectly
# possible minor leak on fuel tank
# grease pump unserviceable
# IOV fault on drag package
# rear wiper motor unserviceable
# park brake alarm sounds continuously
# system pump pressure gauge not working
# grease pump is bypassing air
# park brake alarm fault
# handrail above battery box cracked
# diagnose and repair ladder fault
# ground fault welding board
# grease gauges requires replacing
# swing brake pressure fault
# ground fault in propel
# drag generator fault
# grease system fault
# investigate auto-lube fault
# brake warning light on
# faulty fuel pressure sensor
# synchronous motor trip
# walk motor brake fault
# swing resolver not counting
# swing resolver fault
# drag chain fault
# hoist brake switches need adjusting
# cabin jacking cylinder ends unserviceable
# park brake indicator light going on and off
# tracks need adjusting
# no excitation on hoist
# diagnose VIMS error
# stick cylinder leaking
# hoist brake number position out of adjustment
# Tele-Remote camera fault
# Tele-Remote cameras fault text
# Tele-Remote fault
# Tele-Remote faults
# Tele-Remote issues
# air horn not working
# engine bay light blown
# engine fan hose weeping
# engine overheating
# engine vibration <num>-<num> RPM
# fuel cap is missing
# fuel leak
# grease system fail
# grease system fault
# hoist drum cracking
# lube fault
# modular does not self assign
# no reception on AM / FM radio
# noisy hydraulic lift cylinder
# park brake fault
# set-up Tele-Remote bogging
# stick cracks
# grease system has intermittent fault
# injector error
# Tele-Remote fault
# VIMS fuel filter plugged
# aftercooler tank gauge broken
# aftercooler temperature error
# air pressure safety valve exhausting
# batteries have no charge
# battery unserviceable dropped cell replace
# blade control cable tight
# constant voltage transformer melted
# dry cell not working properly
# depth counter unserviceable
# generator flow regulator unserviceable
# investigate main transformer overload fault
# keeps blowing starter / horn fuse
# microwave oven unserviceable
# number pump contamination switch on
# number slew pump contamination switch unserviceable
# remove unserviceable air separator
# safety flag missing
# siren unserviceable
# slip ring overgreasing
# start motorvator and set limits
# troubleshoot smart meter not communicating
# transformer trip
# voltage regulator fuse fault
# wiper fuse unserviceable
# Top words:
# fault
# unserviceable
# air
# not
# on
#
# Cluster 26 :
# airhorn not working
# all dash lights on
# back rest unserviceable handle broken
# backhoe windscreen to be fixed
# backlight on dash unserviceable
# backlights on dash blown
# beacon not working
# blown steering hose
# blown steering pump hose
# boarding gate hinge broken
# boarding gate latch not working
# broken grease plug
# broken joystick PO
# broken ripper tooth
# cabin seals leaking dust PO
# cabin seals leaking dust bad
# control valve unserviceable see long text
# cracked front window
# cracked fuel tank
# cracked steering tank suction tube
# damaged position tyre
# damaged position tyre and rim
# dash broken
# drivers window fault
# dust leak operators side window
# ripper control valve falling off
# replace faulty brake sensor task
# replace leaking transfer pipe
# position brake temperature error
# front revolving light not working
# machine will not start
# rear steering accumulator leak
# rear through shaft universal joint unserviceable
# all lighting requires testing and tagging
# main isolator needs clean out
# front window cracked replace
# rear door struts require replacing
# replace leaking scavenge pump
# replace missing cutting edge
# movement on steering column
# replace x cracked windows
# middle air drain tap leaking
# bottom steering shaft universal joint worn
# steering hub caps require replacing
# replace damage auto-greaser door
# replace cracked transmission dropbox
# front window roller blind broken
# replace position tyre damaged
# replace position tyre mismatched
# repair exhaust leaks
# missing poppet valve
# CW radiator core leak
# emergency gate latch broken
# front headlight blown
# radiator relief valves leaking
# rear steering accumulator leaking
# replace blocked dryer
# replace broken onside mirror
# replace cracked exhaust shield
# replace leaking steering cylinder
# ripper shank broken
# CW top radiator tank leak again
# broken wire on speaker
# cabin side weightometer not working
# collect broken tooth
# contamination alarm coming up
# contamination alarm on
# electric propel siren not working
# earth wire broken on bottom of radiator
# front lights keep blowing fuse
# high voltage slip ring inspection grease leak
# key broken in ignition switch
# glass window has large crack
# position chip sensor alarm
# position pump cavity low
# radiator sight glasses unserviceable
# repair faulty safety valve
# replace broken earth terminal
# replace chip indicators ( leaking )
# replace cracked glass in entry door
# replace cracked water separator
# replace shorted diode RPC
# water separator filter leaking see photo
# water separator leaking fuel
# Top words:
# replace
# broken
# leaking
# steering
# cracked
#
# Cluster 27 :
# air leaking from line outside
# blown air conditioner hose
# blown air conditioner hose to radiator
# blown brake hose
# blown extension line from position
# blown hose in hitch
# blown hose on boom
# blown lift cylinder o-ring
# blown light on boom
# blown oil cooler hose x metre
# blown position tyre
# coolant hose leaking at right hand bottom
# cooler return pipe coupling leak
# cracked hydraulic pipe
# cracked suction tube
# damage to position tyre
# replace blown implement hose
# replace blown right hand steering hose
# replace damaged position tyre and position
# tail pulley has no grease lines
# position tyre blown
# leaking brake cooling hose
# replace damaged tyre on position
# hydraulic hose leaking in centre of machine
# replace blown main pump hose
# HMU hose weeping
# brake hose needs to be replaced
# exhaust leak
# fan hose leaking
# hose leak developing
# replace blown hose
# replace blown work lights
# replaced leaking steering hose
# [ shutdown ] vinyl flooring unserviceable
# air brake line blown requires replacing
# blown air conditioner fuse
# centrifuge hose leaking replace
# heat up locked steels
# Top words:
# hose
# blown
# replace
# leaking
# position
#
# Cluster 28 :
# steering cylinder bearings have excess play
# Top words:
# steering
# cylinder
# bearings
# have
# excess
#
# Cluster 29 :
# differential lock broken
# adaptor leaking at implement valve
# Top words:
# differential
# lock
# broken
# adaptor
# leaking
#
# Cluster 30 :
# fitting leaking out of main air tanks
# Top words:
# fitting
# leaking
# out
# of
# main
#
# Cluster 31 :
# coolant pipe clamps needs fitting TBC
# heater hose in cabin roof unserviceable
# Top words:
# coolant
# pipe
# clamps
# needs
# fitting
#
# Cluster 32 :
# inverter earthing out
# Top words:
# inverter
# earthing
# out
#
# Cluster 33 :
# steering pin no grease text
# Top words:
# steering
# pin
# no
# grease
# text
#
# Cluster 34 :
# replace right hand lift cylinder leaking
# CW left hand hoist cylinder leaking plug
# CW right hand hoist cylinder leaking
# Top words:
# hand
# cylinder
# leaking
# right
# CW
#
# Cluster 35 :
# movement found right hand engine mount
# oil centrifuge gasket leaking right hand engine
# Top words:
# right
# hand
# engine
# movement
# found
#
# Cluster 36 :
# investigate / repair no gear fault
# investigate / repair joystick needs repair
# Top words:
# repair
# investigate
# /
# no
# gear
#
# Cluster 37 :
# broken left hand side mirror
# broken right hand side door window
# diagnose / repair slow steering
# front right hand roller need to be fitted
# repair right hand fuel tank crack
# repair boom cracks left hand side
# repair movement in left hand steering pin
# repair cracked steering tank mo
# repair right hand track frame crack
# number right hand air brake line needs replacing
# crack repairs left hand window frame
# diagnose / repair right hand scoreboard not working
# repair crack in right hand side of rear cross member
# repair chassis crack at right hand rear cross member
# repair crack in rear cross member
# repair crack on left hand front heat shield
# repair cracked baffle in hydraulic tank
# repair cracked roof skin left hand side exhaust
# repair left hand scoreboard base cracked
# Top words:
# hand
# repair
# right
# left
# crack
#
# Cluster 38 :
# right hand bobbin roller unserviceable
# left hand side pinion change out cover cracking
# left hand rear brake cooling hose leaking
# left hand boom cylinder hose leaking PO
# left hand corner bonnet cracked
# left hand side boom foot crack repair
# lower left hand headlight blown
# left hand chain guide unserviceable
# left hand chain guide worn at the top
# left hand PTO pump chip sensor harness unserviceable
# right hand PTO cavity emptying
# Top words:
# hand
# left
# unserviceable
# right
# side
#
# Cluster 39 :
# flow battery power
# Top words:
# flow
# battery
# power
#
# Cluster 40 :
# oil found in revolving frame
# Top words:
# oil
# found
# in
# revolving
# frame

# %% [markdown]
# # maintIE inherent function clusters

# %% [markdown]
# #### analysing exceptions with inherent functions

# %%
def analyse_inherent_function_exceptions(row, exception_type=None):

    # list of tuples of head and tail indices
    hasPart_heads = []
    hasPart_tails = []
    contains_heads =[]
    contains_tails =[]
    isA_relations_indices = []

    for r in row["relations"]:
        if r["type"] == "hasPart":
            hasPart_heads.append(r["head"])
            hasPart_tails.append(r["tail"])
        if r["type"] == "contains":
            contains_heads.append(r["head"])
            contains_tails.append(r["tail"])
        if r["type"] == "isA":
            isA_relations_indices.append((r["head"], r["tail"]))

    # remove any repeats
    hasPart_heads = list(set(hasPart_heads))
    hasPart_tails = list(set(hasPart_tails))
    
    # list of physical object indices not in a hasPart or isA relation
    physical_object_indices = []
    
    # get all physical object indices
    for i in range(len(row["entities"])):
        if row["entities"][i]["type"].split("/")[0] == "PhysicalObject":
            physical_object_indices.append(i)
    
    inherent_function_index = []
    for i in hasPart_tails:
        # if tail is not a head of a hasPart relation
        if i not in hasPart_heads:
            inherent_function_index.append(i)
        # remove tail from the physical object indices
        if i in physical_object_indices:
            physical_object_indices.remove(i)
    
    for i in hasPart_heads:
        # remove head from the physical object indices
        if i in physical_object_indices:
            physical_object_indices.remove(i)

    for i in isA_relations_indices:
        # remove physical objects that are part of an isA relation
        if i[0] in physical_object_indices:
            physical_object_indices.remove(i[0])
        if i[1] in physical_object_indices:
            physical_object_indices.remove(i[1])

    # EXCEPTION 1: if there are physical objects that are not part of a hasPart or isA relation
    if exception_type == "1":
        if physical_object_indices and inherent_function_index:
            print(row)
            for i in physical_object_indices:
                print(row["entities"][i])
            print()
    # EXCEPTION 2: if there is zero, or more than one physical object and no hasPart relation
    elif exception_type == "2":
        # count how many non substance physical objects there are
        ob = []
        for e in row["entities"]:
            if e["type"].split("/")[0] == "PhysicalObject" and (len(e["type"].split("/")) == 1 or (len(e["type"].split("/"))>1 and e["type"].split("/")[1]  != "Substance")):
                ob.append(e)

        if (len(inherent_function_index) == 0) and len(ob)!=1 and not isA_relations_indices:
            print(row)
            print("Number of non-substance Physical Objects:", len(ob))
            if ob:
                print(ob)
            print()
    # EXCEPTION 3: if there are more than one leftover tail from hasPart relations
    if exception_type == "3":
        if (len(inherent_function_index) > 1):
            print(row)
    # EXCEPTION 4: if the head and tail of an isA relation are not the same type
    if exception_type == "4":
        for i in isA_relations_indices:
            if row["entities"][i[0]]["type"] != row["entities"][i[1]]["type"]:
                print(row)
    return

f = open("../data/gold_release.json", "r")
# returns JSON object as a dictionary
data = json.load(f)
f.close()

except_type = input("Enter exception type: ")
MWO_by_function = {}

for datum in data:
    types = [e["type"].split("/")[0] for e in datum["entities"]]
    if ("State" in types or "Process" in types or "Property" in types) and "PhysicalObject" in types:
        analyse_inherent_function_exceptions(datum, exception_type=except_type)
# Out:
# {'text': '<id> air leak', 'tokens': ['<id>', 'air', 'leak'], 'entities': [{'start': 1, 'end': 2, 'type': 'PhysicalObject/Substance/Gas'}, {'start': 2, 'end': 3, 'type': 'Process/UndesirableProcess'}], 'relations': [{'head': 1, 'tail': 0, 'type': 'hasParticipant/hasPatient'}]}
# Number of non-substance Physical Objects: 0
#
# {'text': '<id> auto-greaser leaking oil', 'tokens': ['<id>', 'auto-greaser', 'leaking', 'oil'], 'entities': [{'start': 1, 'end': 2, 'type': 'PhysicalObject/GeneratingObject/LiquidFlowGeneratingObject'}, {'start': 2, 'end': 3, 'type': 'Process/UndesirableProcess'}, {'start': 3, 'end': 4, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}], 'relations': [{'head': 1, 'tail': 2, 'type': 'hasParticipant/hasPatient'}, {'head': 1, 'tail': 0, 'type': 'hasParticipant/hasAgent'}]}
# Number of non-substance Physical Objects: 2
# [{'start': 1, 'end': 2, 'type': 'PhysicalObject/GeneratingObject/LiquidFlowGeneratingObject'}, {'start': 3, 'end': 4, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}]
#
# {'text': '<id> back rest unserviceable handle broken', 'tokens': ['<id>', 'back', 'rest', 'unserviceable', 'handle', 'broken'], 'entities': [{'start': 3, 'end': 4, 'type': 'State/UndesirableState/FailedState'}, {'start': 5, 'end': 6, 'type': 'State/UndesirableState/FailedState'}, {'start': 4, 'end': 5, 'type': 'PhysicalObject/HumanInteractionObject/HandInteractionObject'}, {'start': 1, 'end': 3, 'type': 'PhysicalObject/StoringObject/OpenStationaryStoringObject'}], 'relations': [{'head': 0, 'tail': 3, 'type': 'hasParticipant/hasPatient'}, {'head': 1, 'tail': 2, 'type': 'hasParticipant/hasPatient'}]}
# Number of non-substance Physical Objects: 2
# [{'start': 4, 'end': 5, 'type': 'PhysicalObject/HumanInteractionObject/HandInteractionObject'}, {'start': 1, 'end': 3, 'type': 'PhysicalObject/StoringObject/OpenStationaryStoringObject'}]
#
# {'text': '<id> change out cracked position <num> adaptor and tooth', 'tokens': ['<id>', 'change', 'out', 'cracked', 'position', '<num>', 'adaptor', 'and', 'tooth'], 'entities': [{'start': 1, 'end': 3, 'type': 'Activity/MaintenanceActivity/Replace'}, {'start': 3, 'end': 4, 'type': 'State/UndesirableState/FailedState'}, {'start': 8, 'end': 9, 'type': 'PhysicalObject/MatterProcessingObject/GrindingAndCrushingObject'}, {'start': 6, 'end': 7, 'type': 'PhysicalObject/HoldingObject/FasteningObject'}], 'relations': [{'head': 0, 'tail': 2, 'type': 'hasParticipant/hasPatient'}, {'head': 1, 'tail': 3, 'type': 'hasParticipant/hasPatient'}, {'head': 1, 'tail': 2, 'type': 'hasParticipant/hasPatient'}, {'head': 0, 'tail': 3, 'type': 'hasParticipant/hasPatient'}]}
# Number of non-substance Physical Objects: 2
# [{'start': 8, 'end': 9, 'type': 'PhysicalObject/MatterProcessingObject/GrindingAndCrushingObject'}, {'start': 6, 'end': 7, 'type': 'PhysicalObject/HoldingObject/FasteningObject'}]
#
# {'text': '<id> check / repair engine oil leak', 'tokens': ['<id>', 'check', '/', 'repair', 'engine', 'oil', 'leak'], 'entities': [{'start': 3, 'end': 4, 'type': 'Activity/MaintenanceActivity/Repair'}, {'start': 5, 'end': 6, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 6, 'end': 7, 'type': 'Process/UndesirableProcess'}, {'start': 1, 'end': 2, 'type': 'Activity/MaintenanceActivity/Inspect'}, {'start': 4, 'end': 5, 'type': 'PhysicalObject/DrivingObject/CombustionEngine'}], 'relations': [{'head': 4, 'tail': 1, 'type': 'contains'}, {'head': 3, 'tail': 4, 'type': 'hasParticipant/hasPatient'}, {'head': 0, 'tail': 4, 'type': 'hasParticipant/hasPatient'}, {'head': 2, 'tail': 4, 'type': 'hasParticipant/hasAgent'}, {'head': 2, 'tail': 1, 'type': 'hasParticipant/hasPatient'}]}
# Number of non-substance Physical Objects: 2
# [{'start': 5, 'end': 6, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 4, 'end': 5, 'type': 'PhysicalObject/DrivingObject/CombustionEngine'}]
#
# {'text': '<id> cracked walkway and handrails', 'tokens': ['<id>', 'cracked', 'walkway', 'and', 'handrails'], 'entities': [{'start': 2, 'end': 3, 'type': 'PhysicalObject/HoldingObject/CarryingObject'}, {'start': 4, 'end': 5, 'type': 'PhysicalObject/ProtectingObject/PreventiveProtectingObject'}, {'start': 1, 'end': 2, 'type': 'State/UndesirableState/DegradedState'}], 'relations': [{'head': 2, 'tail': 0, 'type': 'hasParticipant/hasPatient'}, {'head': 2, 'tail': 1, 'type': 'hasParticipant/hasPatient'}]}
# Number of non-substance Physical Objects: 2
# [{'start': 2, 'end': 3, 'type': 'PhysicalObject/HoldingObject/CarryingObject'}, {'start': 4, 'end': 5, 'type': 'PhysicalObject/ProtectingObject/PreventiveProtectingObject'}]
#
# {'text': '<id> damaged position <num> tyre and rim', 'tokens': ['<id>', 'damaged', 'position', '<num>', 'tyre', 'and', 'rim'], 'entities': [{'start': 1, 'end': 2, 'type': 'State/UndesirableState/DegradedState'}, {'start': 4, 'end': 5, 'type': 'PhysicalObject/GuidingObject/MechanicalEnergyGuidingObject'}, {'start': 6, 'end': 7, 'type': 'PhysicalObject/HoldingObject/StructuralSupportingObject'}], 'relations': [{'head': 0, 'tail': 1, 'type': 'hasParticipant/hasPatient'}, {'head': 0, 'tail': 2, 'type': 'hasParticipant/hasPatient'}]}
# Number of non-substance Physical Objects: 2
# [{'start': 4, 'end': 5, 'type': 'PhysicalObject/GuidingObject/MechanicalEnergyGuidingObject'}, {'start': 6, 'end': 7, 'type': 'PhysicalObject/HoldingObject/StructuralSupportingObject'}]
#
# {'text': '<id> differential oil leak', 'tokens': ['<id>', 'differential', 'oil', 'leak'], 'entities': [{'start': 2, 'end': 3, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 3, 'end': 4, 'type': 'Process/UndesirableProcess'}, {'start': 1, 'end': 2, 'type': 'PhysicalObject/TransformingObject/MechanicalEnergyTransformingObject'}], 'relations': [{'head': 1, 'tail': 2, 'type': 'hasParticipant/hasAgent'}, {'head': 2, 'tail': 0, 'type': 'contains'}, {'head': 1, 'tail': 0, 'type': 'hasParticipant/hasPatient'}]}
# Number of non-substance Physical Objects: 2
# [{'start': 2, 'end': 3, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 1, 'end': 2, 'type': 'PhysicalObject/TransformingObject/MechanicalEnergyTransformingObject'}]
#
# {'text': '<id> failed PTO and auxiliary drive PO', 'tokens': ['<id>', 'failed', 'PTO', 'and', 'auxiliary', 'drive', 'PO'], 'entities': [{'start': 1, 'end': 2, 'type': 'State/UndesirableState/FailedState'}, {'start': 2, 'end': 3, 'type': 'PhysicalObject/TransformingObject/MechanicalEnergyTransformingObject'}, {'start': 4, 'end': 6, 'type': 'PhysicalObject/TransformingObject/MechanicalEnergyTransformingObject'}], 'relations': [{'head': 0, 'tail': 1, 'type': 'hasParticipant/hasPatient'}, {'head': 0, 'tail': 2, 'type': 'hasParticipant/hasPatient'}]}
# Number of non-substance Physical Objects: 2
# [{'start': 2, 'end': 3, 'type': 'PhysicalObject/TransformingObject/MechanicalEnergyTransformingObject'}, {'start': 4, 'end': 6, 'type': 'PhysicalObject/TransformingObject/MechanicalEnergyTransformingObject'}]
#
# {'text': 'handrail above battery box cracked', 'tokens': ['handrail', 'above', 'battery', 'box', 'cracked'], 'entities': [{'start': 0, 'end': 1, 'type': 'PhysicalObject/ProtectingObject/PreventiveProtectingObject'}, {'start': 4, 'end': 5, 'type': 'State/UndesirableState/FailedState'}, {'start': 2, 'end': 4, 'type': 'PhysicalObject/StoringObject/EnclosedStationaryStoringObject'}], 'relations': [{'head': 1, 'tail': 0, 'type': 'hasParticipant/hasPatient'}]}
# Number of non-substance Physical Objects: 2
# [{'start': 0, 'end': 1, 'type': 'PhysicalObject/ProtectingObject/PreventiveProtectingObject'}, {'start': 2, 'end': 4, 'type': 'PhysicalObject/StoringObject/EnclosedStationaryStoringObject'}]
#
# {'text': '<id> investigate engine oil leak', 'tokens': ['<id>', 'investigate', 'engine', 'oil', 'leak'], 'entities': [{'start': 1, 'end': 2, 'type': 'Activity/MaintenanceActivity/Diagnose'}, {'start': 3, 'end': 4, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 4, 'end': 5, 'type': 'Process/UndesirableProcess'}, {'start': 2, 'end': 3, 'type': 'PhysicalObject/DrivingObject/CombustionEngine'}], 'relations': [{'head': 0, 'tail': 3, 'type': 'hasParticipant/hasPatient'}, {'head': 3, 'tail': 1, 'type': 'contains'}, {'head': 2, 'tail': 1, 'type': 'hasParticipant/hasPatient'}, {'head': 2, 'tail': 3, 'type': 'hasParticipant/hasAgent'}]}
# Number of non-substance Physical Objects: 2
# [{'start': 3, 'end': 4, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 2, 'end': 3, 'type': 'PhysicalObject/DrivingObject/CombustionEngine'}]
#
# {'text': 'oil leak swingbox <num>', 'tokens': ['oil', 'leak', 'swingbox', '<num>'], 'entities': [{'start': 0, 'end': 1, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 1, 'end': 2, 'type': 'Process/UndesirableProcess'}, {'start': 2, 'end': 3, 'type': 'PhysicalObject/TransformingObject/MechanicalEnergyTransformingObject'}], 'relations': [{'head': 1, 'tail': 0, 'type': 'hasParticipant/hasPatient'}, {'head': 1, 'tail': 2, 'type': 'hasParticipant/hasAgent'}, {'head': 2, 'tail': 0, 'type': 'contains'}]}
# Number of non-substance Physical Objects: 2
# [{'start': 0, 'end': 1, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 2, 'end': 3, 'type': 'PhysicalObject/TransformingObject/MechanicalEnergyTransformingObject'}]
#
# {'text': '<id> engine oil leaks right hand side', 'tokens': ['<id>', 'engine', 'oil', 'leaks', 'right', 'hand', 'side'], 'entities': [{'start': 2, 'end': 3, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 3, 'end': 4, 'type': 'Process/UndesirableProcess'}, {'start': 1, 'end': 2, 'type': 'PhysicalObject/DrivingObject/CombustionEngine'}], 'relations': [{'head': 1, 'tail': 0, 'type': 'hasParticipant/hasPatient'}, {'head': 1, 'tail': 2, 'type': 'hasParticipant/hasAgent'}, {'head': 2, 'tail': 0, 'type': 'contains'}]}
# Number of non-substance Physical Objects: 2
# [{'start': 2, 'end': 3, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 1, 'end': 2, 'type': 'PhysicalObject/DrivingObject/CombustionEngine'}]
#
# {'text': '<id> repair centre hitch oil leaks', 'tokens': ['<id>', 'repair', 'centre', 'hitch', 'oil', 'leaks'], 'entities': [{'start': 1, 'end': 2, 'type': 'Activity/MaintenanceActivity/Repair'}, {'start': 2, 'end': 4, 'type': 'PhysicalObject/InterfacingObject/DetachableCoupling'}, {'start': 4, 'end': 5, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 5, 'end': 6, 'type': 'Process/UndesirableProcess'}], 'relations': [{'head': 3, 'tail': 2, 'type': 'hasParticipant/hasPatient'}, {'head': 0, 'tail': 1, 'type': 'hasParticipant/hasPatient'}, {'head': 1, 'tail': 2, 'type': 'contains'}, {'head': 3, 'tail': 1, 'type': 'hasParticipant/hasAgent'}]}
# Number of non-substance Physical Objects: 2
# [{'start': 2, 'end': 4, 'type': 'PhysicalObject/InterfacingObject/DetachableCoupling'}, {'start': 4, 'end': 5, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}]
#
# {'text': '<id> repair air conditioner and wiring fault', 'tokens': ['<id>', 'repair', 'air', 'conditioner', 'and', 'wiring', 'fault'], 'entities': [{'start': 1, 'end': 2, 'type': 'Activity/MaintenanceActivity/Repair'}, {'start': 2, 'end': 4, 'type': 'PhysicalObject/EmittingObject/ElectricCoolingObject'}, {'start': 5, 'end': 6, 'type': 'PhysicalObject/GuidingObject/ElectricEnergyGuidingObject'}, {'start': 6, 'end': 7, 'type': 'State/UndesirableState'}], 'relations': [{'head': 0, 'tail': 2, 'type': 'hasParticipant/hasPatient'}, {'head': 0, 'tail': 1, 'type': 'hasParticipant/hasPatient'}, {'head': 3, 'tail': 2, 'type': 'hasParticipant/hasPatient'}]}
# Number of non-substance Physical Objects: 2
# [{'start': 2, 'end': 4, 'type': 'PhysicalObject/EmittingObject/ElectricCoolingObject'}, {'start': 5, 'end': 6, 'type': 'PhysicalObject/GuidingObject/ElectricEnergyGuidingObject'}]
#
# {'text': 'inspect bad engine oil leak', 'tokens': ['inspect', 'bad', 'engine', 'oil', 'leak'], 'entities': [{'start': 0, 'end': 1, 'type': 'Activity/MaintenanceActivity/Inspect'}, {'start': 3, 'end': 4, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 4, 'end': 5, 'type': 'Process/UndesirableProcess'}, {'start': 2, 'end': 3, 'type': 'PhysicalObject/DrivingObject/CombustionEngine'}], 'relations': [{'head': 0, 'tail': 3, 'type': 'hasParticipant/hasPatient'}, {'head': 2, 'tail': 1, 'type': 'hasParticipant/hasPatient'}, {'head': 2, 'tail': 3, 'type': 'hasParticipant/hasAgent'}, {'head': 3, 'tail': 1, 'type': 'contains'}]}
# Number of non-substance Physical Objects: 2
# [{'start': 3, 'end': 4, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 2, 'end': 3, 'type': 'PhysicalObject/DrivingObject/CombustionEngine'}]
#
# {'text': '<id> - air leak', 'tokens': ['<id>', '-', 'air', 'leak'], 'entities': [{'start': 2, 'end': 3, 'type': 'PhysicalObject/Substance/Gas'}, {'start': 3, 'end': 4, 'type': 'Process/UndesirableProcess'}], 'relations': [{'head': 1, 'tail': 0, 'type': 'hasParticipant/hasPatient'}]}
# Number of non-substance Physical Objects: 0
#
# {'text': '<id> - differential oil leak', 'tokens': ['<id>', '-', 'differential', 'oil', 'leak'], 'entities': [{'start': 3, 'end': 4, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 4, 'end': 5, 'type': 'Process/UndesirableProcess'}, {'start': 2, 'end': 3, 'type': 'PhysicalObject/TransformingObject/MechanicalEnergyTransformingObject'}], 'relations': [{'head': 2, 'tail': 0, 'type': 'contains'}, {'head': 1, 'tail': 0, 'type': 'hasParticipant/hasPatient'}, {'head': 1, 'tail': 2, 'type': 'hasParticipant/hasAgent'}]}
# Number of non-substance Physical Objects: 2
# [{'start': 3, 'end': 4, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 2, 'end': 3, 'type': 'PhysicalObject/TransformingObject/MechanicalEnergyTransformingObject'}]
#
# {'text': '<id> - engine oil leak', 'tokens': ['<id>', '-', 'engine', 'oil', 'leak'], 'entities': [{'start': 3, 'end': 4, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 4, 'end': 5, 'type': 'Process/UndesirableProcess'}, {'start': 2, 'end': 3, 'type': 'PhysicalObject/DrivingObject/CombustionEngine'}], 'relations': [{'head': 1, 'tail': 0, 'type': 'hasParticipant/hasPatient'}, {'head': 2, 'tail': 0, 'type': 'contains'}, {'head': 1, 'tail': 2, 'type': 'hasParticipant/hasAgent'}]}
# Number of non-substance Physical Objects: 2
# [{'start': 3, 'end': 4, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 2, 'end': 3, 'type': 'PhysicalObject/DrivingObject/CombustionEngine'}]
#
# {'text': '<id> - fuel leak', 'tokens': ['<id>', '-', 'fuel', 'leak'], 'entities': [{'start': 2, 'end': 3, 'type': 'PhysicalObject/Substance/Liquid'}, {'start': 3, 'end': 4, 'type': 'Process/UndesirableProcess'}], 'relations': [{'head': 1, 'tail': 0, 'type': 'hasParticipant/hasPatient'}]}
# Number of non-substance Physical Objects: 0
#
# {'text': '<id> - minor transmission oil leak', 'tokens': ['<id>', '-', 'minor', 'transmission', 'oil', 'leak'], 'entities': [{'start': 4, 'end': 5, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 5, 'end': 6, 'type': 'Process/UndesirableProcess'}, {'start': 3, 'end': 4, 'type': 'PhysicalObject/TransformingObject/MechanicalEnergyTransformingObject'}], 'relations': [{'head': 2, 'tail': 0, 'type': 'contains'}, {'head': 1, 'tail': 0, 'type': 'hasParticipant/hasPatient'}, {'head': 1, 'tail': 2, 'type': 'hasParticipant/hasAgent'}]}
# Number of non-substance Physical Objects: 2
# [{'start': 4, 'end': 5, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 3, 'end': 4, 'type': 'PhysicalObject/TransformingObject/MechanicalEnergyTransformingObject'}]
#
# {'text': '<id> - repair engine oil leak and', 'tokens': ['<id>', '-', 'repair', 'engine', 'oil', 'leak', 'and'], 'entities': [{'start': 2, 'end': 3, 'type': 'Activity/MaintenanceActivity/Repair'}, {'start': 4, 'end': 5, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 5, 'end': 6, 'type': 'Process/UndesirableProcess'}, {'start': 3, 'end': 4, 'type': 'PhysicalObject/DrivingObject/CombustionEngine'}], 'relations': [{'head': 3, 'tail': 1, 'type': 'contains'}, {'head': 2, 'tail': 1, 'type': 'hasParticipant/hasPatient'}, {'head': 2, 'tail': 3, 'type': 'hasParticipant/hasAgent'}, {'head': 0, 'tail': 3, 'type': 'hasParticipant/hasPatient'}]}
# Number of non-substance Physical Objects: 2
# [{'start': 4, 'end': 5, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 3, 'end': 4, 'type': 'PhysicalObject/DrivingObject/CombustionEngine'}]
#
# {'text': '<id> - repair engine oil leaking', 'tokens': ['<id>', '-', 'repair', 'engine', 'oil', 'leaking'], 'entities': [{'start': 2, 'end': 3, 'type': 'Activity/MaintenanceActivity/Repair'}, {'start': 4, 'end': 5, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 5, 'end': 6, 'type': 'Process/UndesirableProcess'}, {'start': 3, 'end': 4, 'type': 'PhysicalObject/DrivingObject/CombustionEngine'}], 'relations': [{'head': 2, 'tail': 3, 'type': 'hasParticipant/hasAgent'}, {'head': 2, 'tail': 1, 'type': 'hasParticipant/hasPatient'}, {'head': 0, 'tail': 3, 'type': 'hasParticipant/hasPatient'}, {'head': 3, 'tail': 1, 'type': 'contains'}]}
# Number of non-substance Physical Objects: 2
# [{'start': 4, 'end': 5, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 3, 'end': 4, 'type': 'PhysicalObject/DrivingObject/CombustionEngine'}]
#
# {'text': '<id> <id> repair engine oil leak text', 'tokens': ['<id>', '<id>', 'repair', 'engine', 'oil', 'leak', 'text'], 'entities': [{'start': 2, 'end': 3, 'type': 'Activity/MaintenanceActivity/Repair'}, {'start': 4, 'end': 5, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 5, 'end': 6, 'type': 'Process/UndesirableProcess'}, {'start': 3, 'end': 4, 'type': 'PhysicalObject/DrivingObject/CombustionEngine'}], 'relations': [{'head': 0, 'tail': 3, 'type': 'hasParticipant/hasPatient'}, {'head': 3, 'tail': 1, 'type': 'contains'}, {'head': 2, 'tail': 1, 'type': 'hasParticipant/hasPatient'}, {'head': 2, 'tail': 3, 'type': 'hasParticipant/hasAgent'}]}
# Number of non-substance Physical Objects: 2
# [{'start': 4, 'end': 5, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 3, 'end': 4, 'type': 'PhysicalObject/DrivingObject/CombustionEngine'}]
#
# {'text': '<id> <id> repair transmission oil leak text', 'tokens': ['<id>', '<id>', 'repair', 'transmission', 'oil', 'leak', 'text'], 'entities': [{'start': 2, 'end': 3, 'type': 'Activity/MaintenanceActivity/Repair'}, {'start': 4, 'end': 5, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 5, 'end': 6, 'type': 'Process/UndesirableProcess'}, {'start': 3, 'end': 4, 'type': 'PhysicalObject/TransformingObject/MechanicalEnergyTransformingObject'}], 'relations': [{'head': 0, 'tail': 3, 'type': 'hasParticipant/hasPatient'}, {'head': 3, 'tail': 1, 'type': 'contains'}, {'head': 2, 'tail': 1, 'type': 'hasParticipant/hasPatient'}, {'head': 2, 'tail': 3, 'type': 'hasParticipant/hasAgent'}]}
# Number of non-substance Physical Objects: 2
# [{'start': 4, 'end': 5, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 3, 'end': 4, 'type': 'PhysicalObject/TransformingObject/MechanicalEnergyTransformingObject'}]
#
# {'text': '<id> <id> replace hydraulic oil leak text', 'tokens': ['<id>', '<id>', 'replace', 'hydraulic', 'oil', 'leak', 'text'], 'entities': [{'start': 2, 'end': 3, 'type': 'Activity/MaintenanceActivity/Replace'}, {'start': 5, 'end': 6, 'type': 'Process/UndesirableProcess'}, {'start': 3, 'end': 5, 'type': 'PhysicalObject/Substance/Liquid'}], 'relations': [{'head': 1, 'tail': 2, 'type': 'hasParticipant/hasPatient'}, {'head': 0, 'tail': 2, 'type': 'hasParticipant/hasPatient'}]}
# Number of non-substance Physical Objects: 0
#
# {'text': '<id> CW engine oil leaks x <num>', 'tokens': ['<id>', 'CW', 'engine', 'oil', 'leaks', 'x', '<num>'], 'entities': [{'start': 3, 'end': 4, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 4, 'end': 5, 'type': 'Process/UndesirableProcess'}, {'start': 2, 'end': 3, 'type': 'PhysicalObject/DrivingObject/CombustionEngine'}], 'relations': [{'head': 2, 'tail': 0, 'type': 'contains'}, {'head': 1, 'tail': 0, 'type': 'hasParticipant/hasPatient'}, {'head': 1, 'tail': 2, 'type': 'hasParticipant/hasAgent'}]}
# Number of non-substance Physical Objects: 2
# [{'start': 3, 'end': 4, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 2, 'end': 3, 'type': 'PhysicalObject/DrivingObject/CombustionEngine'}]
#
# {'text': 'oil leak at diverter valve', 'tokens': ['oil', 'leak', 'at', 'diverter', 'valve'], 'entities': [{'start': 3, 'end': 5, 'type': 'PhysicalObject/ControllingObject/SolidSubstanceFlowVaryingObject'}, {'start': 1, 'end': 2, 'type': 'Process/UndesirableProcess'}, {'start': 0, 'end': 1, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}], 'relations': [{'head': 1, 'tail': 2, 'type': 'hasParticipant/hasPatient'}, {'head': 1, 'tail': 0, 'type': 'hasParticipant/hasAgent'}]}
# Number of non-substance Physical Objects: 2
# [{'start': 3, 'end': 5, 'type': 'PhysicalObject/ControllingObject/SolidSubstanceFlowVaryingObject'}, {'start': 0, 'end': 1, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}]
#
# {'text': 'pilot valve leaking oil', 'tokens': ['pilot', 'valve', 'leaking', 'oil'], 'entities': [{'start': 3, 'end': 4, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 0, 'end': 2, 'type': 'PhysicalObject/InformationProcessingObject/FluidSignallingObject'}, {'start': 2, 'end': 3, 'type': 'Process/UndesirableProcess'}], 'relations': [{'head': 2, 'tail': 0, 'type': 'hasParticipant/hasPatient'}, {'head': 2, 'tail': 1, 'type': 'hasParticipant/hasAgent'}]}
# Number of non-substance Physical Objects: 2
# [{'start': 3, 'end': 4, 'type': 'PhysicalObject/ProtectingObject/WearProtectingObject'}, {'start': 0, 'end': 2, 'type': 'PhysicalObject/InformationProcessingObject/FluidSignallingObject'}]
#
# {'text': 'radiator blocked with grass', 'tokens': ['radiator', 'blocked', 'with', 'grass'], 'entities': [{'start': 1, 'end': 2, 'type': 'State/UndesirableState'}, {'start': 3, 'end': 4, 'type': 'PhysicalObject/TransformingObject/OrganicPlant'}, {'start': 0, 'end': 1, 'type': 'PhysicalObject/EmittingObject/ThermalCoolingObject'}], 'relations': [{'head': 0, 'tail': 2, 'type': 'hasParticipant/hasAgent'}, {'head': 0, 'tail': 1, 'type': 'hasParticipant/hasPatient'}]}
# Number of non-substance Physical Objects: 2
# [{'start': 3, 'end': 4, 'type': 'PhysicalObject/TransformingObject/OrganicPlant'}, {'start': 0, 'end': 1, 'type': 'PhysicalObject/EmittingObject/ThermalCoolingObject'}]
#
# {'text': 'repair cracked roof skin left hand side exhaust', 'tokens': ['repair', 'cracked', 'roof', 'skin', 'left', 'hand', 'side', 'exhaust'], 'entities': [{'start': 1, 'end': 2, 'type': 'State/UndesirableState/DegradedState'}, {'start': 7, 'end': 8, 'type': 'PhysicalObject/GuidingObject/ClosedEnclosureGuidingObject'}, {'start': 0, 'end': 1, 'type': 'Activity/MaintenanceActivity/Repair'}, {'start': 2, 'end': 4, 'type': 'PhysicalObject/CoveringObject/FinishingObject'}], 'relations': [{'head': 2, 'tail': 3, 'type': 'hasParticipant/hasPatient'}, {'head': 0, 'tail': 3, 'type': 'hasParticipant/hasPatient'}]}
# Number of non-substance Physical Objects: 2
# [{'start': 7, 'end': 8, 'type': 'PhysicalObject/GuidingObject/ClosedEnclosureGuidingObject'}, {'start': 2, 'end': 4, 'type': 'PhysicalObject/CoveringObject/FinishingObject'}]

# %% [markdown]
# #### inherent function clustering

# %%
def extract_function_from_entity_index(row, index, equipment_dict=None):
    if equipment_dict:
        start = row["entities"][index]["start"]
        end = row["entities"][index]["end"]
        equipment = " ".join([row["tokens"][i] for i in range(start, end)])
        if equipment not in equipment_dict.keys():
            return None
        return equipment_dict[equipment][:-6].lower()
    types = row["entities"][index]["type"].split("/")
    if len(types) > 1:
        return types[1][:-6].lower()
    else:
        return None
    
def get_inherent_function(row, equipment_dict=None):

    # list of tuples of head and tail indices
    hasPart_heads = []
    hasPart_tails = []
    contains_heads =[]
    contains_tails =[]
    isA_relations_indices = []

    for r in row["relations"]:
        if r["type"] == "hasPart":
            hasPart_heads.append(r["head"])
            hasPart_tails.append(r["tail"])
        if r["type"] == "contains":
            contains_heads.append(r["head"])
            contains_tails.append(r["tail"])
        if r["type"] == "isA":
            isA_relations_indices.append((r["head"], r["tail"]))

    # remove any repeats
    hasPart_heads = list(set(hasPart_heads))
    hasPart_tails = list(set(hasPart_tails))
    
    # list of physical object indices not in a hasPart or isA relation
    physical_object_indices = []
    
    # get all physical object indices
    for i in range(len(row["entities"])):
        if row["entities"][i]["type"].split("/")[0] == "PhysicalObject" and (equipment_dict or len(row["entities"][i]["type"].split("/")) == 1 or (row["entities"][i]["type"].split("/")[1]  != "Substance")):
            physical_object_indices.append(i)
    
    inherent_function_index = []
    for i in hasPart_tails:
        # if tail is not a head of a hasPart relation
        if i not in hasPart_heads:
            inherent_function_index.append(i)
        # remove tail from the physical object indices
        if i in physical_object_indices:
            physical_object_indices.remove(i)
    
    for i in hasPart_heads:
        # remove head from the physical object indices
        if i in physical_object_indices:
            physical_object_indices.remove(i)

    for i in isA_relations_indices:
        # remove physical objects that are part of an isA relation
        if i[0] in physical_object_indices:
            physical_object_indices.remove(i[0])
        if i[1] in physical_object_indices:
            physical_object_indices.remove(i[1])

    # EXCEPTION 1: if there are physical objects that are not part of a hasPart or isA relation, and there is a hasPart relation
    if physical_object_indices and inherent_function_index:
        # in general, ignore additional physical objects 
        if len(inherent_function_index) ==1:
            isA_tails = [i[1] for i in isA_relations_indices]
            # if there is a more specific (head) object in an isA relation
            if inherent_function_index[0] in isA_tails:
                isA_head_index = isA_relations_indices[isA_tails.index(inherent_function_index[0])][0]
                func = extract_function_from_entity_index(row, isA_head_index, equipment_dict)
                return func
            else:
                func = extract_function_from_entity_index(row, inherent_function_index[0], equipment_dict)
                return func


    # EXCEPTION 2: if there is zero or more than one physical object and no hasPart relations
    if (len(inherent_function_index) == 0) and len(physical_object_indices)!=1 and not isA_relations_indices:
        # if there are no physical objects, remove the row
        if len(physical_object_indices) == 0:
            print("remove:",row, "\n")
            return None
        physical_object_not_substance = []
        for i in physical_object_indices:
            start = row["entities"][i]["start"]
            end = row["entities"][i]["end"]
            # if the physical object is not a substance
            if end == len(row["tokens"]) and " ".join(row["tokens"][start:]) != "oil":
                physical_object_not_substance.append(i)
            elif " ".join(row["tokens"][start:end]) != "oil":
                physical_object_not_substance.append(i)

        # if there is only one non-substance physical object, extract its function
        if len(physical_object_not_substance) == 1:
            func = extract_function_from_entity_index(row, physical_object_not_substance[0], equipment_dict)
            return func
        else:
            # !!! CHECK !!!
            # print(row)
            # print("Manually assign inherent function.")
            # print()
            # return "CHECK"
            func = extract_function_from_entity_index(row, physical_object_indices[0], equipment_dict)
            return func
            
                

    # EXCEPTION 3: if there are more than one leftover tail from hasPart relations
    if (len(inherent_function_index) > 1):
        # manually assign inherent function
        if row["text"] == "replace unserviceable transmission screen and magnet":
            return "transforming"
        elif row["text"] == "pump drive box coupling and shaft unserviceable":
            return "driving"
        else:
            return None
            # print(row)
            # raise Exception("Manually assign inherent function in Exception 3.")
    

    # get entities
    if len(inherent_function_index) == 1 and len(physical_object_indices) == 0:
        func = extract_function_from_entity_index(row, inherent_function_index[0], equipment_dict)
        return func
    elif len(inherent_function_index) == 0 and len(physical_object_indices) == 1:
        func = extract_function_from_entity_index(row, physical_object_indices[0], equipment_dict)
        return func
    elif all(i in [x for xs in isA_relations_indices for x in xs] for i in physical_object_indices):
        isA_heads = [i[0] for i in isA_relations_indices]
        isA_tails = [i[1] for i in isA_relations_indices]
        isA_specific_indices = []
        for i in isA_heads:
            if i not in isA_tails:
                isA_specific_indices.append(i)
        if len(isA_specific_indices) == 1:
            func = extract_function_from_entity_index(row, isA_specific_indices[0], equipment_dict)
            return func
        
        else:
            if row["text"] == "<id> park brake alarm fault":
                return "restricting"
            else:
                return None
                # print(row)
                # print("Manually assign inherent function.")
                # return "CHECK"
    elif len(inherent_function_index)>1:
        return None
        # print("SASDKDHAA")
        # return "CHECK"
    else:
        return None
        # print(row)
        # print("Manually assign inherent function.")
        # print()
        # return "CHECK"
    
    # for e in row["entities"]:
    #     entity_type = e["type"].split("/")
    #     if entity_type[0] == "PhysicalObject":
    #         if len(entity_type) > 1 and entity_type[1] not in ["Substance", "Organism"]:
    #             if entity_type[1][:-6].lower() not in functions:
    #                 functions.append(entity_type[1][:-6].lower())
    # functions = ",".join(sorted(functions))
    # return functions

    # # EXCEPTION 4: if the head and tail of an isA relation are not the same type
    # if exception_type == 4:
    #     for i in isA_relations_indices:
    #         if row["entities"][i[0]]["type"] != row["entities"][i[1]]["type"]:
    #             print(row)


def get_gold_dataset(dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO):
    f = open("../data/gold_release.json", "r")
    # returns JSON object as a dictionary
    data = json.load(f)
    f.close()


    for datum in data:
        types = [e["type"].split("/")[0] for e in datum["entities"]]
        if ("State" in types or "Process" in types or "Property" in types) and "PhysicalObject" in types:
            inherent_function = get_inherent_function(datum)
            if not inherent_function:
                continue

            tokens = datum["tokens"].copy()

            # remove activity tokens
            if "Activity" in types:
                activity_indices = []
                for e in datum["entities"]:
                    if e["type"].split("/")[0] == "Activity":
                        for i in range(e["start"], e["end"]):
                            activity_indices.append(i)
                activity_indices = sorted(set(activity_indices), reverse=True)
                for i in activity_indices:
                    tokens.pop(i)
                

            tokens = clean_tokens(tokens)
            dataset.append(tokens)
            if inherent_function not in class_list:
                labels.append(len(class_list))
                class_list.append(inherent_function)
            else:
                labels.append(class_list.index(inherent_function))
            
            # add MWO tokens to dictionary with key inherent function
            if inherent_function in MWO_by_function:
                MWO_by_function[inherent_function].append(tokens)
            else:
                MWO_by_function[inherent_function] = [tokens]
            
            # add state, equipment, and inherent function to dictionary with key MWO
            mwo = " ".join(tokens)
            if mwo not in state_equipment_inherentfunction_by_MWO:
                states = []
                equip = []
                for i in range(len(types)):
                    if types[i] in ["State", "Process", "Property"]:
                        start = datum["entities"][i]["start"]
                        end = datum["entities"][i]["end"]
                        states.append(" ".join([datum["tokens"][j] for j in range(start, end)]))
                    elif types[i] == "PhysicalObject":
                        start = datum["entities"][i]["start"]
                        end = datum["entities"][i]["end"]
                        equip.append(" ".join([datum["tokens"][j] for j in range(start, end)]))
                state_equipment_inherentfunction_by_MWO[mwo]=[states, equip, inherent_function]

    print("Number of Inherent function clusters:", len(MWO_by_function.keys()))
    for i in MWO_by_function.keys():
        print(i, len(MWO_by_function[i]))
        if len(MWO_by_function[i]) == 1:
            print("   ", MWO_by_function[i])
    print()
    return dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO

# %%
def create_equipment_dictionary():
    f = open("../data/gold_release.json", "r")
    # returns JSON object as a dictionary
    data = json.load(f)
    f.close()

    
    # exception multiple types for the same equipment
    ignored_equipment = {"auto-lube":"ProtectingObject", "axle":"GuidingObject", "drag":"MatterProcessingObject", "universal joint":"GuidingObject", "adaptor":"InterfacingObject", "batteries":"StoringObject", "carousel":"StoringObject", "window":"RestrictingObject", "shaft":"GuidingObject", "input shaft":"GuidingObject"}
    equipment = ignored_equipment.copy()
    
    for datum in data:
        for e in datum["entities"]:
            entity_type = e["type"].split("/")
            if entity_type[0] == "PhysicalObject" and len(entity_type) > 1 and entity_type[1] not in ["Substance", "Organism"]:
                start = int(e["start"])
                end = int(e["end"])
                equipment_text = " ".join([datum["tokens"][t] for t in range(start, end)])
                
                if equipment_text in ignored_equipment:
                    continue
                if equipment_text not in equipment:
                    equipment[equipment_text] = entity_type[1]
                # elif equipment[equipment_text] != entity_type[1]:
                #     del equipment[equipment_text]
                    # ignored_equipment.append(equipment_text)
                    
                    # print("ERROR: Equipment text has multiple types")
                    # print(equipment_text)
                    # print(equipment[equipment_text])
                    # print(entity_type[1])
                    # print()
    return equipment

def get_synthetic_dataset(filename, dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO):
    import csv


    with open(filename, 'r') as csvfile:
        # creating a csv reader object
        csvreader = csv.reader(csvfile)
        counter = 0
        for row in csvreader:
            tokens = row[0].split()
            if len(row[1].split("/")) == 1 or row[1].split("/")[1] in ["Substance", "Organism", "GuidingObject","HoldingObject"] or "leak" in row[3]:
                counter+=1
                continue
            inherent_function = row[1].split("/")[1][:-6].lower()

            # # remove activity tokens
            # if "Activity" in types:
            #     activity_indices = []
            #     for e in datum["entities"]:
            #         if e["type"].split("/")[0] == "Activity":
            #             for i in range(e["start"], e["end"]):
            #                 activity_indices.append(i)
            #     activity_indices = sorted(set(activity_indices), reverse=True)
            #     for i in activity_indices:
            #         tokens.pop(i)
            
            tokens = clean_tokens(tokens)
            dataset.append(tokens)
            if inherent_function not in class_list:
                labels.append(len(class_list))
                class_list.append(inherent_function)
            else:
                labels.append(class_list.index(inherent_function))
            
            # add MWO tokens to dictionary with key inherent function
            if inherent_function in MWO_by_function:
                MWO_by_function[inherent_function].append(tokens)
            else:
                MWO_by_function[inherent_function] = [tokens]
            
            mwo= " ".join(tokens)
            # add state, equipment, inherent function to dictionary with key tokens
            if mwo not in state_equipment_inherentfunction_by_MWO:
                states = []
                equip = []
                states.append(row[3])
                equip.append(row[2])
                state_equipment_inherentfunction_by_MWO[mwo]=[states, equip, inherent_function]

    print("Number of Inherent function clusters:", len(MWO_by_function.keys()))
    for i in MWO_by_function.keys():
        print(i, len(MWO_by_function[i]))
        if len(MWO_by_function[i]) == 1:
            print("   ", MWO_by_function[i])
    print()

    return dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO
            
    
def get_silver_dataset(dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO):
    equipment_dict = create_equipment_dictionary()
    
    f = open("../data/silver_release.json", "r")
    # returns JSON object as a dictionary
    data = json.load(f)
    f.close()

    for datum in data:
        types = [e["type"].split("/")[0] for e in datum["entities"]]
        if ("State" in types or "Process" in types or "Property" in types) and "PhysicalObject" in types:
            inherent_function = get_inherent_function(datum, equipment_dict)
            if not inherent_function:
                continue
            
            tokens = datum["tokens"].copy()

            # remove activity tokens
            if "Activity" in types:
                activity_indices = []
                for e in datum["entities"]:
                    if e["type"].split("/")[0] == "Activity":
                        for i in range(e["start"], e["end"]):
                            activity_indices.append(i)
                activity_indices = sorted(set(activity_indices), reverse=True)
                for i in activity_indices:
                    tokens.pop(i)
            
            tokens = clean_tokens(tokens)
            dataset.append(tokens)
            if inherent_function not in class_list:
                labels.append(len(class_list))
                class_list.append(inherent_function)
            else:
                labels.append(class_list.index(inherent_function))
            
            # add MWO tokens to dictionary with key inherent function
            if inherent_function in MWO_by_function:
                MWO_by_function[inherent_function].append(tokens)
            else:
                MWO_by_function[inherent_function] = [tokens]
            
            mwo= " ".join(tokens)
            # add state, equipment, inherent function to dictionary with key tokens
            if mwo not in state_equipment_inherentfunction_by_MWO:
                states = []
                equip = []
                for i in range(len(types)):
                    if types[i] in ["State", "Process", "Property"]:
                        start = datum["entities"][i]["start"]
                        end = datum["entities"][i]["end"]
                        states.append(" ".join([datum["tokens"][j] for j in range(start, end)]))
                    elif types[i] == "PhysicalObject":
                        start = datum["entities"][i]["start"]
                        end = datum["entities"][i]["end"]
                        equip.append(" ".join([datum["tokens"][j] for j in range(start, end)]))
                state_equipment_inherentfunction_by_MWO[mwo]=[states, equip, inherent_function]


    print("Number of Inherent function clusters:", len(MWO_by_function.keys()))
    for i in MWO_by_function.keys():
        print(i, len(MWO_by_function[i]))
        if len(MWO_by_function[i]) == 1:
            print("   ", MWO_by_function[i])
    print()
    return dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO

# %%
def create_dataset():
    MWO_by_function = {}
    dataset = []
    labels = []
    class_list = []
    state_equipment_inherentfunction_by_MWO = {}

    dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO = get_gold_dataset(dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO)
    # dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO = get_synthetic_dataset("../data/synthetic.csv", dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO)
    dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO = get_synthetic_dataset("../data/synthetic2.csv",dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO)
    dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO = get_silver_dataset(dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO)

    return dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO

# %%
dataset, labels, class_list, MWO_by_function, state_equipment_inherentfunction_by_MWO = create_dataset()

# # balanced dataset 
# dataset = []
# labels = []
# random.seed(42)
# for i in range(17):
#     if class_list[i] == "informationprocessing": # CHECK INDEX class_list[i]
#         continue
#     dataset += random.sample(MWO_by_function[class_list[i]], min(len(MWO_by_function[class_list[i]]), 108))
#     labels += [i for j in range(min(len(MWO_by_function[class_list[i]]), 108))]


# remove information processing
for i in MWO_by_function["informationprocessing"]:
    if i in dataset:
        print("Removed")
        dataset.remove(i)
labels = [i for i in labels if i != 16] 

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dataset, labels, random_state=42, shuffle=True, test_size=0.2)
y_train = np.array(y_train)
y_test = np.array(y_test)
X = X_train + X_test

print("training set length:",len( X_train))
print("test set length:", len(X_test))
print("dataset length:",len( dataset))
# Out:
# remove: {'text': '<id> air leak', 'tokens': ['<id>', 'air', 'leak'], 'entities': [{'start': 1, 'end': 2, 'type': 'PhysicalObject/Substance/Gas'}, {'start': 2, 'end': 3, 'type': 'Process/UndesirableProcess'}], 'relations': [{'head': 1, 'tail': 0, 'type': 'hasParticipant/hasPatient'}]}
#
# remove: {'text': '<id> - air leak', 'tokens': ['<id>', '-', 'air', 'leak'], 'entities': [{'start': 2, 'end': 3, 'type': 'PhysicalObject/Substance/Gas'}, {'start': 3, 'end': 4, 'type': 'Process/UndesirableProcess'}], 'relations': [{'head': 1, 'tail': 0, 'type': 'hasParticipant/hasPatient'}]}
#
# remove: {'text': '<id> - fuel leak', 'tokens': ['<id>', '-', 'fuel', 'leak'], 'entities': [{'start': 2, 'end': 3, 'type': 'PhysicalObject/Substance/Liquid'}, {'start': 3, 'end': 4, 'type': 'Process/UndesirableProcess'}], 'relations': [{'head': 1, 'tail': 0, 'type': 'hasParticipant/hasPatient'}]}
#
# remove: {'text': '<id> <id> replace hydraulic oil leak text', 'tokens': ['<id>', '<id>', 'replace', 'hydraulic', 'oil', 'leak', 'text'], 'entities': [{'start': 2, 'end': 3, 'type': 'Activity/MaintenanceActivity/Replace'}, {'start': 5, 'end': 6, 'type': 'Process/UndesirableProcess'}, {'start': 3, 'end': 5, 'type': 'PhysicalObject/Substance/Liquid'}], 'relations': [{'head': 1, 'tail': 2, 'type': 'hasParticipant/hasPatient'}, {'head': 0, 'tail': 2, 'type': 'hasParticipant/hasPatient'}]}
#
# Number of Inherent function clusters: 17
# sensing 30
# emitting 34
# matterprocessing 23
# presenting 28
# generating 35
# controlling 36
# guiding 98
# driving 35
# transforming 33
# protecting 45
# storing 19
# humaninteraction 10
# holding 61
# covering 20
# interfacing 11
# restricting 14
# informationprocessing 1
#     [['pilot', 'valve', 'leaking', 'oil']]
#
# Number of Inherent function clusters: 17
# sensing 85
# emitting 114
# matterprocessing 38
# presenting 48
# generating 115
# controlling 96
# guiding 98
# driving 50
# transforming 68
# protecting 175
# storing 54
# humaninteraction 20
# holding 61
# covering 50
# interfacing 36
# restricting 44
# informationprocessing 1
#     [['pilot', 'valve', 'leaking', 'oil']]
#
# Number of Inherent function clusters: 17
# sensing 117
# emitting 353
# matterprocessing 120
# presenting 69
# generating 262
# controlling 194
# guiding 462
# driving 199
# transforming 151
# protecting 324
# storing 112
# humaninteraction 40
# holding 408
# covering 130
# interfacing 87
# restricting 123
# informationprocessing 5
#
# Removed
# Removed
# Removed
# Removed
# Removed
# training set length: 2520
# test set length: 631
# dataset length: 3151

# %%
def w2v_embed(xtrain,xtest, max_len):
    # Word2Vec embeddings as input
    x_copy_train = copy.deepcopy(xtrain)
    x_copy_test = copy.deepcopy(xtest)
    padded_x_train = pad_sequence(x_copy_train, max_len)
    padded_x_test = pad_sequence(x_copy_test, max_len)
    padded_x = padded_x_train + padded_x_test

    w2vmodel = gensim.models.Word2Vec(padded_x, min_count=1, vector_size=100,
                                    window=5, sg=1)


    w2v_embeddings_train = []
    for sentence in padded_x_train:
        row = []
        for word in sentence:
            row.append(w2vmodel.wv[word])
        w2v_embeddings_train.append(row)
    w2v_embeddings_train = np.array(w2v_embeddings_train)

    w2v_embeddings_test = []
    for sentence in padded_x_test:
        row = []
        for word in sentence:
            row.append(w2vmodel.wv[word])
        w2v_embeddings_test.append(row)
    w2v_embeddings_test = np.array(w2v_embeddings_test)
    return w2v_embeddings_train, w2v_embeddings_test

max_len = len(max(dataset, key=len))
w2v_embeddings_X_train, w2v_embeddings_X_test = w2v_embed(X_train, X_test, max_len)

print(w2v_embeddings_X_train.shape)
print(w2v_embeddings_X_test.shape)
# Out:
# ['air', 'conditioner', 'thermostat', 'not', 'working']
# max length of MWO: 10
# max length of MWO: 10
# (2520, 10, 100)
# (631, 10, 100)
# ['air', 'conditioner', 'thermostat', 'not', 'working']

# %%
# SBERT embeddings
sbert = SentenceTransformer("all-mpnet-base-v2")
SBERT_embeddings_train = sbert.encode(X_train)
SBERT_embeddings_test = sbert.encode(X_test)

print(SBERT_embeddings_train.shape)
print(SBERT_embeddings_test.shape)
# Out:
# /opt/miniconda3/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# (2520, 768)
# (631, 768)
# (3151, 768)

# %%
def LSI_ebed(x):
    # LSI embeddings as output
    dictionary = gensim.corpora.Dictionary(x)
    doc_term_matrix = [dictionary.doc2bow(doc) for doc in x]
    lsamodel = LsiModel(doc_term_matrix, num_topics=10, id2word = dictionary)  # train model
    concepts = list(lsamodel[doc_term_matrix])
    lsa_embeddings=[]
    for i in concepts:
        row = []
        for j in i:
            row.append(j[1])
        lsa_embeddings.append(row)

    for i in range(len(lsa_embeddings)):
        if len(lsa_embeddings[i]) != 10:
            print(x[i])
    lsa_embeddings = np.array(lsa_embeddings)
    return lsa_embeddings

# %% [markdown]
# #### w2v -> Inherent Function

# %%
# model = tf.keras.Sequential([
#     tf.keras.layers.Input(shape=(10,100)),
#     tf.keras.layers.Conv1D(128, 3, activation='relu'),
#     tf.keras.layers.MaxPool1D(3),
#     tf.keras.layers.Conv1D(128, 3, activation='relu'),
#     tf.keras.layers.MaxPool1D(3),
#     tf.keras.layers.Conv1D(128, 3, activation='relu'),
#     tf.keras.layers.GlobalMaxPool1D(),
#     tf.keras.layers.Dense(10, activation='relu'),
#     tf.keras.layers.Dense(16, activation='softmax')
# ])

# model.summary()
# model = tf.keras.Sequential([
#     tf.keras.layers.Conv2D(32, (2,2), padding="same", input_shape=(10,100,1), use_bias=False),
#     tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.Activation("relu"),
#     tf.keras.layers.MaxPool2D(pool_size=2),
#     # tf.keras.layers.Conv2D(8, (2,2), padding="same", use_bias=False),
#     # tf.keras.layers.BatchNormalization(),
#     # tf.keras.layers.Activation("relu"),
#     # tf.keras.layers.MaxPool2D(pool_size=2),
    
#     tf.keras.layers.Flatten(),
#     # tf.keras.layers.Dense(units=128),
#     # tf.keras.layers.Activation("tanh"),
#     tf.keras.layers.Dense(units=10),
#     tf.keras.layers.Activation("tanh"),
#     tf.keras.layers.Dense(units=17, activation="softmax")
# ])
# model = tf.keras.Sequential([
#     tf.keras.layers.Conv2D(32, (2,2), padding="same", input_shape=(10,100,1), use_bias=False),
#     tf.keras.layers.Flatten(),
#     tf.keras.layers.Dense(units=64, activation="tanh"),
    
#     tf.keras.layers.Dense(units=10, activation="tanh"),
#     tf.keras.layers.Dense(units=16, activation="softmax")
# ])

# model = tf.keras.Sequential([
#     # tf.keras.layers.LSTM(64, input_shape=(10,100)),
#     tf.keras.layers.Input(shape=(10,100)),
#     tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True)),
#     tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
#     tf.keras.layers.Dense(64, activation='relu'), 
#     tf.keras.layers.Dense(units=16, activation="softmax")
# ])
# model.summary()
w2v_if_model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(16, (2, 2), activation='relu', padding="same", input_shape=(10,100,1)),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.Conv2D(8, (2, 2), activation='relu', padding="same"),
    tf.keras.layers.MaxPool2D(pool_size=2),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=10, activation="tanh"),
    tf.keras.layers.Dense(units=16, activation="softmax")
])

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
class_weight = {}
for i in MWO_by_function.keys():
    class_weight[class_list.index(i)] = len(MWO_by_function[i])/len(dataset)

w2v_if_model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])
early_stopping = tf.keras.callbacks.EarlyStopping(patience=20, monitor='val_loss', restore_best_weights=True)
history = w2v_if_model.fit(w2v_embeddings_X_train, y_train, epochs=200, validation_data=(w2v_embeddings_X_test, y_test), callbacks=[early_stopping], class_weight=class_weight)

# run predictions
pred_train = w2v_if_model.predict(w2v_embeddings_X_train)
pred_train = pred_train.argmax(axis=-1)
print("Final train accuracy:", w2v_if_model.evaluate(w2v_embeddings_X_train, y_train)[1])

pred_test = w2v_if_model.predict(w2v_embeddings_X_test)
pred_test = pred_test.argmax(axis=-1)
print("Final test accuracy:", w2v_if_model.evaluate(w2v_embeddings_X_test, y_test)[1])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy TF-Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/200
# 79/79 [==============================] - 1s 6ms/step - loss: 0.2090 - accuracy: 0.1544 - val_loss: 2.6219 - val_accuracy: 0.1553
# Epoch 2/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.1881 - accuracy: 0.1813 - val_loss: 2.5316 - val_accuracy: 0.1933
# Epoch 3/200
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1722 - accuracy: 0.2702 - val_loss: 2.4250 - val_accuracy: 0.2995
# Epoch 4/200
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1591 - accuracy: 0.3250 - val_loss: 2.3200 - val_accuracy: 0.3344
# Epoch 5/200
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1483 - accuracy: 0.3591 - val_loss: 2.2327 - val_accuracy: 0.3756
# Epoch 6/200
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1408 - accuracy: 0.3786 - val_loss: 2.1677 - val_accuracy: 0.3883
# Epoch 7/200
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1333 - accuracy: 0.4028 - val_loss: 2.0648 - val_accuracy: 0.4105
# Epoch 8/200
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1275 - accuracy: 0.4266 - val_loss: 2.0438 - val_accuracy: 0.4200
# Epoch 9/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.1225 - accuracy: 0.4512 - val_loss: 1.9824 - val_accuracy: 0.4358
# Epoch 10/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.1183 - accuracy: 0.4599 - val_loss: 1.9549 - val_accuracy: 0.4485
# Epoch 11/200
# 79/79 [==============================] - 1s 7ms/step - loss: 0.1149 - accuracy: 0.4706 - val_loss: 1.8955 - val_accuracy: 0.4485
# Epoch 12/200
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1107 - accuracy: 0.4845 - val_loss: 1.8673 - val_accuracy: 0.4548
# Epoch 13/200
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1082 - accuracy: 0.4937 - val_loss: 1.8501 - val_accuracy: 0.4897
# Epoch 14/200
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1059 - accuracy: 0.5083 - val_loss: 1.8320 - val_accuracy: 0.4628
# Epoch 15/200
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1041 - accuracy: 0.5111 - val_loss: 1.8291 - val_accuracy: 0.4675
# Epoch 16/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.1013 - accuracy: 0.5175 - val_loss: 1.8017 - val_accuracy: 0.4818
# Epoch 17/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0991 - accuracy: 0.5234 - val_loss: 1.7703 - val_accuracy: 0.5103
# Epoch 18/200
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0970 - accuracy: 0.5310 - val_loss: 1.7669 - val_accuracy: 0.5055
# Epoch 19/200
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0950 - accuracy: 0.5397 - val_loss: 1.7897 - val_accuracy: 0.4992
# Epoch 20/200
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0937 - accuracy: 0.5437 - val_loss: 1.7345 - val_accuracy: 0.4834
# Epoch 21/200
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0927 - accuracy: 0.5464 - val_loss: 1.7374 - val_accuracy: 0.5008
# Epoch 22/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0910 - accuracy: 0.5579 - val_loss: 1.6897 - val_accuracy: 0.5087
# Epoch 23/200
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0886 - accuracy: 0.5647 - val_loss: 1.6668 - val_accuracy: 0.5055
# Epoch 24/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0875 - accuracy: 0.5647 - val_loss: 1.6567 - val_accuracy: 0.5166
# Epoch 25/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0856 - accuracy: 0.5762 - val_loss: 1.6643 - val_accuracy: 0.5182
# Epoch 26/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0845 - accuracy: 0.5778 - val_loss: 1.6470 - val_accuracy: 0.5261
# Epoch 27/200
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0837 - accuracy: 0.5853 - val_loss: 1.6459 - val_accuracy: 0.5246
# Epoch 28/200
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0826 - accuracy: 0.5901 - val_loss: 1.6421 - val_accuracy: 0.5261
# Epoch 29/200
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0807 - accuracy: 0.5972 - val_loss: 1.6203 - val_accuracy: 0.5230
# Epoch 30/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0804 - accuracy: 0.6024 - val_loss: 1.6530 - val_accuracy: 0.5214
# Epoch 31/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0783 - accuracy: 0.6028 - val_loss: 1.5963 - val_accuracy: 0.5325
# Epoch 32/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0782 - accuracy: 0.6107 - val_loss: 1.6423 - val_accuracy: 0.5277
# Epoch 33/200
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0773 - accuracy: 0.6087 - val_loss: 1.6282 - val_accuracy: 0.5404
# Epoch 34/200
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0754 - accuracy: 0.6198 - val_loss: 1.6016 - val_accuracy: 0.5388
# Epoch 35/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0744 - accuracy: 0.6187 - val_loss: 1.5544 - val_accuracy: 0.5515
# Epoch 36/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0728 - accuracy: 0.6337 - val_loss: 1.5682 - val_accuracy: 0.5547
# Epoch 37/200
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0734 - accuracy: 0.6302 - val_loss: 1.6002 - val_accuracy: 0.5420
# Epoch 38/200
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0721 - accuracy: 0.6302 - val_loss: 1.5446 - val_accuracy: 0.5578
# Epoch 39/200
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0705 - accuracy: 0.6456 - val_loss: 1.5773 - val_accuracy: 0.5357
# Epoch 40/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0700 - accuracy: 0.6484 - val_loss: 1.5554 - val_accuracy: 0.5626
# Epoch 41/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0685 - accuracy: 0.6504 - val_loss: 1.5374 - val_accuracy: 0.5642
# Epoch 42/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0679 - accuracy: 0.6496 - val_loss: 1.5571 - val_accuracy: 0.5610
# Epoch 43/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0682 - accuracy: 0.6484 - val_loss: 1.5700 - val_accuracy: 0.5578
# Epoch 44/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0668 - accuracy: 0.6607 - val_loss: 1.5583 - val_accuracy: 0.5658
# Epoch 45/200
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0652 - accuracy: 0.6663 - val_loss: 1.5949 - val_accuracy: 0.5420
# Epoch 46/200
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0654 - accuracy: 0.6671 - val_loss: 1.5491 - val_accuracy: 0.5642
# Epoch 47/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0654 - accuracy: 0.6671 - val_loss: 1.5368 - val_accuracy: 0.5626
# Epoch 48/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0653 - accuracy: 0.6651 - val_loss: 1.5702 - val_accuracy: 0.5674
# Epoch 49/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0657 - accuracy: 0.6571 - val_loss: 1.5642 - val_accuracy: 0.5674
# Epoch 50/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0628 - accuracy: 0.6806 - val_loss: 1.5494 - val_accuracy: 0.5753
# Epoch 51/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0619 - accuracy: 0.6746 - val_loss: 1.5344 - val_accuracy: 0.5721
# Epoch 52/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0605 - accuracy: 0.6869 - val_loss: 1.6227 - val_accuracy: 0.5436
# Epoch 53/200
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0609 - accuracy: 0.6853 - val_loss: 1.5325 - val_accuracy: 0.5895
# Epoch 54/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0600 - accuracy: 0.6853 - val_loss: 1.5286 - val_accuracy: 0.5864
# Epoch 55/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0588 - accuracy: 0.6897 - val_loss: 1.5377 - val_accuracy: 0.5816
# Epoch 56/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0593 - accuracy: 0.6837 - val_loss: 1.5352 - val_accuracy: 0.5864
# Epoch 57/200
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0586 - accuracy: 0.6929 - val_loss: 1.5532 - val_accuracy: 0.5769
# Epoch 58/200
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0577 - accuracy: 0.6925 - val_loss: 1.5399 - val_accuracy: 0.5848
# Epoch 59/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0573 - accuracy: 0.6944 - val_loss: 1.5759 - val_accuracy: 0.5864
# Epoch 60/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0574 - accuracy: 0.6964 - val_loss: 1.5650 - val_accuracy: 0.5895
# Epoch 61/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0584 - accuracy: 0.6956 - val_loss: 1.5528 - val_accuracy: 0.5784
# Epoch 62/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0553 - accuracy: 0.7056 - val_loss: 1.5495 - val_accuracy: 0.5800
# Epoch 63/200
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0553 - accuracy: 0.7087 - val_loss: 1.5818 - val_accuracy: 0.5784
# Epoch 64/200
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0554 - accuracy: 0.7024 - val_loss: 1.5425 - val_accuracy: 0.5975
# Epoch 65/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0537 - accuracy: 0.7183 - val_loss: 1.5644 - val_accuracy: 0.5816
# Epoch 66/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0538 - accuracy: 0.7175 - val_loss: 1.5434 - val_accuracy: 0.5895
# Epoch 67/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0529 - accuracy: 0.7194 - val_loss: 1.5655 - val_accuracy: 0.5753
# Epoch 68/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0529 - accuracy: 0.7167 - val_loss: 1.6075 - val_accuracy: 0.5800
# Epoch 69/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0521 - accuracy: 0.7246 - val_loss: 1.5474 - val_accuracy: 0.5832
# Epoch 70/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0520 - accuracy: 0.7250 - val_loss: 1.5379 - val_accuracy: 0.5895
# Epoch 71/200
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0513 - accuracy: 0.7286 - val_loss: 1.5872 - val_accuracy: 0.5800
# Epoch 72/200
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0509 - accuracy: 0.7250 - val_loss: 1.5475 - val_accuracy: 0.5880
# Epoch 73/200
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0505 - accuracy: 0.7345 - val_loss: 1.6276 - val_accuracy: 0.5721
# Epoch 74/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0511 - accuracy: 0.7258 - val_loss: 1.5862 - val_accuracy: 0.5816
# 79/79 [==============================] - 0s 2ms/step
# 79/79 [==============================] - 0s 1ms/step - loss: 1.0356 - accuracy: 0.7004
# train accuracy: 0.7003968358039856
# 20/20 [==============================] - 0s 1ms/step
# 20/20 [==============================] - 0s 2ms/step - loss: 1.5286 - accuracy: 0.5864
# test accuracy: 0.5863708257675171

# %%
# get hidden layer model 
w2v_if_model_embedding = tf.keras.Sequential([
    
    tf.keras.layers.Conv2D(16, (2, 2), activation='relu', padding="same", input_shape=(10,100,1)),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.Conv2D(8, (2, 2), activation='relu', padding="same"),
    tf.keras.layers.MaxPool2D(pool_size=2),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=10, activation="tanh"),
])


w2v_if_model_embedding.layers[0].set_weights(w2v_if_model.layers[0].get_weights())
w2v_if_model_embedding.layers[2].set_weights(w2v_if_model.layers[2].get_weights())
w2v_if_model_embedding.layers[5].set_weights(w2v_if_model.layers[5].get_weights())


w2v_embeddings = np.concatenate((w2v_embeddings_X_train, w2v_embeddings_X_test))
cluster_embeddings = w2v_if_model_embedding.predict(w2v_embeddings)
print(cluster_embeddings.shape)
# Out:
# 99/99 [==============================] - 0s 5ms/step
# (3151, 10)

# %% [markdown]
# #### SBERT -> Inherent Function

# %%
sbert_if_model = tf.keras.Sequential([
    
    tf.keras.layers.Dense(units=128, activation="tanh", input_shape=(384,)),
    tf.keras.layers.Dense(units=64, activation="tanh"),
    tf.keras.layers.Dense(units=32, activation="tanh"),

    tf.keras.layers.Dense(units=10, activation="tanh"),
    tf.keras.layers.Dense(units=16, activation="softmax")
])

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
class_weight = {}
for i in MWO_by_function.keys():
    class_weight[class_list.index(i)] = len(MWO_by_function[i])/len(dataset)

sbert_if_model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])
early_stopping = tf.keras.callbacks.EarlyStopping(patience=20, monitor='val_loss', restore_best_weights=True)
history = sbert_if_model.fit(SBERT_embeddings_train, y_train, epochs=200, validation_data=(SBERT_embeddings_test, y_test), callbacks=[early_stopping], class_weight=class_weight)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy TF-Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/200
# 79/79 [==============================] - 2s 7ms/step - loss: 0.1947 - accuracy: 0.2480 - val_loss: 2.4222 - val_accuracy: 0.2615
# Epoch 2/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.1608 - accuracy: 0.3278 - val_loss: 2.3343 - val_accuracy: 0.2948
# Epoch 3/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.1453 - accuracy: 0.3782 - val_loss: 2.2369 - val_accuracy: 0.3534
# Epoch 4/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.1344 - accuracy: 0.4167 - val_loss: 2.1809 - val_accuracy: 0.3677
# Epoch 5/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.1263 - accuracy: 0.4560 - val_loss: 2.1119 - val_accuracy: 0.3899
# Epoch 6/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.1210 - accuracy: 0.4782 - val_loss: 2.1008 - val_accuracy: 0.4089
# Epoch 7/200
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1146 - accuracy: 0.5052 - val_loss: 2.0943 - val_accuracy: 0.3994
# Epoch 8/200
# 79/79 [==============================] - 0s 3ms/step - loss: 0.1114 - accuracy: 0.5230 - val_loss: 2.0504 - val_accuracy: 0.4342
# Epoch 9/200
# 79/79 [==============================] - 0s 3ms/step - loss: 0.1069 - accuracy: 0.5306 - val_loss: 2.0053 - val_accuracy: 0.4358
# Epoch 10/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.1044 - accuracy: 0.5508 - val_loss: 1.9941 - val_accuracy: 0.4580
# Epoch 11/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.1006 - accuracy: 0.5560 - val_loss: 2.0575 - val_accuracy: 0.4311
# Epoch 12/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0990 - accuracy: 0.5599 - val_loss: 1.9452 - val_accuracy: 0.4628
# Epoch 13/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0963 - accuracy: 0.5687 - val_loss: 1.9741 - val_accuracy: 0.4659
# Epoch 14/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0939 - accuracy: 0.5853 - val_loss: 1.9937 - val_accuracy: 0.4532
# Epoch 15/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0925 - accuracy: 0.5849 - val_loss: 2.0436 - val_accuracy: 0.4501
# Epoch 16/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0911 - accuracy: 0.5925 - val_loss: 1.9845 - val_accuracy: 0.4739
# Epoch 17/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0893 - accuracy: 0.5929 - val_loss: 1.9670 - val_accuracy: 0.4786
# Epoch 18/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0880 - accuracy: 0.6060 - val_loss: 1.9629 - val_accuracy: 0.4707
# Epoch 19/200
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0866 - accuracy: 0.6079 - val_loss: 1.9944 - val_accuracy: 0.4675
# Epoch 20/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0856 - accuracy: 0.6179 - val_loss: 1.9427 - val_accuracy: 0.4770
# Epoch 21/200
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0833 - accuracy: 0.6262 - val_loss: 1.9465 - val_accuracy: 0.4881
# Epoch 22/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0830 - accuracy: 0.6218 - val_loss: 1.9224 - val_accuracy: 0.4992
# Epoch 23/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0820 - accuracy: 0.6270 - val_loss: 1.9304 - val_accuracy: 0.4865
# Epoch 24/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0804 - accuracy: 0.6290 - val_loss: 1.9661 - val_accuracy: 0.4913
# Epoch 25/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0801 - accuracy: 0.6377 - val_loss: 1.9739 - val_accuracy: 0.4929
# Epoch 26/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0782 - accuracy: 0.6413 - val_loss: 1.9335 - val_accuracy: 0.4945
# Epoch 27/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0779 - accuracy: 0.6405 - val_loss: 1.9488 - val_accuracy: 0.4976
# Epoch 28/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0776 - accuracy: 0.6468 - val_loss: 1.9704 - val_accuracy: 0.4929
# Epoch 29/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0766 - accuracy: 0.6444 - val_loss: 1.9449 - val_accuracy: 0.5103
# Epoch 30/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0750 - accuracy: 0.6520 - val_loss: 1.9535 - val_accuracy: 0.5071
# Epoch 31/200
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0746 - accuracy: 0.6536 - val_loss: 1.9626 - val_accuracy: 0.5055
# Epoch 32/200
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0741 - accuracy: 0.6548 - val_loss: 1.9354 - val_accuracy: 0.5182
# Epoch 33/200
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0729 - accuracy: 0.6639 - val_loss: 1.9451 - val_accuracy: 0.5008
# Epoch 34/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0719 - accuracy: 0.6667 - val_loss: 1.9601 - val_accuracy: 0.4992
# Epoch 35/200
# 79/79 [==============================] - 1s 7ms/step - loss: 0.0717 - accuracy: 0.6698 - val_loss: 1.9657 - val_accuracy: 0.5087
# Epoch 36/200
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0709 - accuracy: 0.6738 - val_loss: 1.9645 - val_accuracy: 0.5024
# Epoch 37/200
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0710 - accuracy: 0.6778 - val_loss: 1.9652 - val_accuracy: 0.5071
# Epoch 38/200
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0692 - accuracy: 0.6821 - val_loss: 2.0101 - val_accuracy: 0.5024
# Epoch 39/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0692 - accuracy: 0.6806 - val_loss: 2.0181 - val_accuracy: 0.5008
# Epoch 40/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0691 - accuracy: 0.6821 - val_loss: 1.9642 - val_accuracy: 0.5119
# Epoch 41/200
# 79/79 [==============================] - 0s 3ms/step - loss: 0.0684 - accuracy: 0.6829 - val_loss: 1.9669 - val_accuracy: 0.5151
# Epoch 42/200
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0687 - accuracy: 0.6865 - val_loss: 1.9826 - val_accuracy: 0.5166

# %%
pred_train = sbert_if_model.predict(SBERT_embeddings_train)
pred_train = pred_train.argmax(axis=-1)
print(sbert_if_model.evaluate(SBERT_embeddings_train, y_train))

print(pred_train[0:100])
print(y_train[0:100])

pred_test = sbert_if_model.predict(SBERT_embeddings_test)
pred_test = pred_test.argmax(axis=-1)
print(sbert_if_model.evaluate(SBERT_embeddings_test, y_test))

print(pred_test)
print(y_test)
# Out:
# 79/79 [==============================] - 0s 940us/step
# 79/79 [==============================] - 0s 1ms/step - loss: 1.3303 - accuracy: 0.6484
# [1.33025324344635, 0.6484127044677734]
# [ 6 12  8 12  1 12 12 10  5  9  6  6 12  5 15  4  4 12  6  0  5  9  9  1
#   6  6 12  3  9 12  7  6 12  8  4  6 12  1  4  4  6 14  6 12  1 12  6  8
#  12  4  9  9 12  1  7  4  3 12 12  6 12  8  6 12 12  9  9  9  5  7  6  1
#   1  5  6 12  4  1  1  5  6  1 12  3  1  1  5  1  1  4  1  1 12  4  9 12
#   9  6  0  5]
# [ 6  8  8 12  1 12 10 10  5  9  2  6 12 15  2 15  4  8  6  0  8  6  9  1
#   6  6  9  2  9 12  7  6  8  8  4  6 14  1  4  4 13 14  6 12  1  6 13  8
#  12  0  7 10 12  1  7  4  2 14  7  6  6  8  6 12  2  9  9  9 15 15  6  0
#   1  5  5  8  4  1 12  5  6  2  0  3  1  1  5  8 13  4  1  1 12  4 10 10
#   9  6  0 12]
# 20/20 [==============================] - 0s 852us/step
# 20/20 [==============================] - 0s 789us/step - loss: 1.9224 - accuracy: 0.4992
# [1.9224315881729126, 0.49920761585235596]
# [12  0  4  6  9  5  8  4  6  8  9 12  1  5  6 12  8 12  1  9  5 12 14  4
#   7  7 13  9 15  9  0  6  6  1 12  9  6  6  9  8  8  1 12  6  4  9  8  5
#   9 12  6  4 12  6  9  1  5 12  1  9  6  1 12  9  6  6 12  6 12  6  1  7
#   8  8 12  1  6  5 12  9  6  7  1  1  4  6  9  4  9  4 12 12  9  6  9 12
#   7  7  9  1  6  9  0  1  9  9 12  6  6  1 12  9 12 13 12  7  9  1  4  4
#   6  9 12  1  3 14 12 12 12 10  6  9  9  5  5  6 12  1 12  8 12  5  8 12
#   4  6 12  6  7 12 12  6  8 15  6  7  9  4  1 12 15  8  1 12  6  7 12 15
#   7  1  5 12  9  5  6 12  1  9  1 12  5  9  9  1  4  9 12 12  6 12 12  6
#   6  9  5  9  6  6 12 12 10 12  9  1  8 12  8  1 12  4  9  5 14  6  1 12
#   9 12  1  6 12  1  9  0  4  6  9  4  8  7  6  5 12  0  6  1  6  6  9  1
#   0  9  6 12  9 12  1 15 12 12  0  0 12  6  1  8  9  9 12  4  0  6  6  4
#  12  0 12 12 12 12  9  6  6 12 12  7  9  6 12 12  9  9  5  5  5  0  7  1
#   6  6  6  4  6  7  7  5  1 12  9 12 12  6  9  1  1  1  6  4 12 12  1  8
#   9 15  1  4  1  1 12  1  6 14  4 15  6  6  6  9  9 12 12  6  6  5  9 12
#  12 12  9  6  2  6  9  9  1  1  9  4  1  5  5  9  4  1 12 14 12 12  8  1
#   6 12 15  6  6  1 15 12 12  6  9  4  1  1  5  9  5  1  6  6 12 12 12  7
#   1 12  5 12  9  7 12 12  2  9 12  9  6  1  7  5  6  8  5 12 12  6 15  4
#   0  9  9  4  0  9  1 12  5  6 12  6  4 14  8  6  9 12 12 13  1  4  1 12
#  12  1 12  9  9  8  4 10  9 15  5  9 12 12  1  1  9  5  1  6  1  1 12  4
#   1  5 10 12  7  6  4 12  7 12 12  1  4  6  0  6  9 12  9  4  9  6 12  6
#  12  8  6  8 12  1  1  1  8 12 12 12  7  9  6  1  9  4 12  1  7  1  0  6
#   9  9  1  6  1  0  6 12  1  1  9  5 12  1  6  9  9  7  5  9  9  4 12 12
#   6  6  1  9  4 12  1  9  9  1  6  1  6  5 10  6  6  1  1 12  9  1  9  6
#   9  7  6 12  6 13  0  5 13  1  6  1  4  5 12  9 12  1 12  1  6  6  6  5
#   6  7  4 15  6  4  5  0 15  7  9  1  1  5 12  9 12  6 12  6  8 12  4  3
#   4  6  1 12  1  9  3  8 12 12  7 12  1 12 12  9  0  1  6 12  6  5 12  4
#   6  6  6 12  9  6  1]
# [ 1  0 13  6  9  2  6  4  6  8  8  7  0  5 12 14  8  6  1  9  5  1 14  4
#   7  7 13  7 15 15  3  6  6  5  6  9  6  6  9  8 13  1  6  6  4  0  2 12
#   9 12  6  4 12  6 12  1  5  5  0  9  7  0  9 13 12  6 12  0 10  1  9  7
#   8 13  2  1  9 12  6  7  6  7  1  1 14 12  8  6 10  4  2 12  9  6  9  6
#  12  7 12  1  6  9  0  1  8  9  6  6 15  1  0  9 12 13  1  7  9  1  4  7
#   6  8 14  1  0  7  0  5 10 10  6  1  9  5  8 13 12  1  6  3 10  3 13  4
#  10  9  6  1  7 14 12  6 11 15  9  6  9  4  4 12 15  8  1  6 12  7 12  0
#   7  6  4 12  2  5  4  8  2  9  0 12  5 10  2  1  9  5  8 13 12  0  4  6
#   5 13 12  4  6 13  5  8  2  2  4  4  8 12 11  1  6 12  4  9 14  6  1 15
#   1 15 13  7  4  2  6  0 12  6  9  8 12 12  0  5  6  3  6  3  6  6  9  0
#   0  1 12 12  6  1  1 11  6 12 14  0 10  6 14  8 12  9 12  1  3 14  6  4
#  12  0  2 12  1  6  9  4  6 13  2  7  9  1  3 12  9  8  2 15 11  0  7  6
#   9  6  6  4  6  7  8 15  1  4  9 10 13 13 13  1  4 15  6  4  5 13  1  7
#   9 15  7  9  1  1 12  1  6 14  4 11  6  6  6  9 14  8  6 15  6  5  9  6
#   1 12  5 14  2  6  6  9  1  7  0  8  1  2 10  1 12  1 12 14  6  3  8  1
#  10  7 15  2  8  1 15 12  2 13  9  1  1  4  5  9  5 15  6 12  7 12 14  7
#   7 12 15 12  9  7  6 12  2 14  9 10 15  6  7  1  4  8  5  7  1  7  7  4
#   0  4  9  4  0  9  3 12  5  6 12  6  4 12  8 13  5 12 14 13  1 10  1  1
#   9  1  2  9 13  6  4 10 12 15  6  4 12 12  4  1 14 14  1  6  1 13 12 12
#   1  1  2 12  7  6 12 12  7 14  2  1  6  6  7  6 10  7  9  4  4  6 12  6
#  12 12  6  8 10  1  9  2 11  2  3 12  9  9  6  1  9  4 12 12  7  1  0  6
#   9  4  1 12  1  0  6 12  1  1  1  5  8  4 12  1 14  7 13  8  9  4 12  6
#   6  6  1  9  7 12  6  9  9  1 13  1 12  3 10  6  6 11 13  6  8  0  9  2
#   9 15  6 12  6 13  2 12 13  2  3  1  5 12  4 10  5 15  0  1  7  7  6  5
#   6  7  4 11  6  9  5  0 15  7  9  1 15  5  6  0  4  6 12  6  8 15  4 12
#   4  6  4 13  7  1 12  1  2 12  7  9  1 13  2 13  3  1 12  9  9  5 12  4
#   6  6  6 12  9  9  1]

# %%
# get hidden layer model 
sbert_if_model_embedding = tf.keras.Sequential([
    
    tf.keras.layers.Dense(units=128, activation="tanh", input_shape=(384,)),
    tf.keras.layers.Dense(units=64, activation="tanh"),
    tf.keras.layers.Dense(units=32, activation="tanh"),

    tf.keras.layers.Dense(units=10, activation="tanh"),
    # tf.keras.layers.Dense(units=16, activation="softmax")
])


sbert_if_model_embedding.layers[0].set_weights(sbert_if_model.layers[0].get_weights())
sbert_if_model_embedding.layers[1].set_weights(sbert_if_model.layers[1].get_weights())
sbert_if_model_embedding.layers[2].set_weights(sbert_if_model.layers[2].get_weights())
sbert_if_model_embedding.layers[3].set_weights(sbert_if_model.layers[3].get_weights())
# sbert_if_model_embedding.layers[4].set_weights(sbert_if_model.layers[4].get_weights())


SBERT_embeddings = np.concatenate((SBERT_embeddings_train, SBERT_embeddings_test))
cluster_embeddings = sbert_if_model_embedding.predict(SBERT_embeddings)
print(cluster_embeddings.shape)
# Out:
# 99/99 [==============================] - 0s 798us/step
# (3151, 16)

# %% [markdown]
# #### kmeans

# %%
def perform_kmeans(cluster_embeddings):
    # PCA reduction
    pca = PCA(n_components=2)
    pca_embedding = pca.fit_transform(cluster_embeddings)
    plt.scatter(pca_embedding[:,0], pca_embedding[:,1])
    plt.title("PCA")
    plt.show()

    # tsne reduction
    tsne = TSNE(n_components=2).fit_transform(cluster_embeddings)
    plt.scatter(tsne[:,0], tsne[:,1])
    plt.title("TSNE")
    plt.show()


    # Perform kmean clustering
    silhouette_scores = []
    test_k = list(range(5, 30))
    for i in test_k:
        print(i, "/", 30)
        kmeans = KMeans(n_clusters=i, random_state=42, n_init=100).fit(cluster_embeddings)
        labels = kmeans.labels_
        silhouette_scores.append(silhouette_score(cluster_embeddings, labels))
    plt.plot(test_k, silhouette_scores)
    plt.title("Silhouette Scores")
    plt.show()
    
perform_kmeans(cluster_embeddings)
# Out:
# 5 / 30
# 6 / 30
# 7 / 30
# 8 / 30
# 9 / 30
# 10 / 30
# 11 / 30
# 12 / 30
# 13 / 30
# 14 / 30
# 15 / 30
# 16 / 30
# 17 / 30
# 18 / 30
# 19 / 30
# 20 / 30
# 21 / 30
# 22 / 30
# 23 / 30
# 24 / 30
# 25 / 30
# 26 / 30
# 27 / 30
# 28 / 30
# 29 / 30

# %%
def run_kmeans_best_k(k, cluster_embeddings):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=100).fit(cluster_embeddings)
    cluster_labels = kmeans.labels_

    nmi = normalized_mutual_info_score(cluster_labels, y_train.tolist()+y_test.tolist())
    print("NMI:",nmi)

    for i in range(1,k+1):
        print("Cluster",i,":")
        cluster_words = {}
        cluster_states={}
        cluster_equip={}
        cluster_inherentfunc={}
        for j in range(len(cluster_labels)):
            if cluster_labels[j]==i:
                # print(" ".join(X[j]))
                for word in X[j]:
                    if word in cluster_words:
                        cluster_words[word]+=1
                    else:
                        cluster_words[word]=1
                mwo = " ".join(X[j])
                state_equip_inherfunc = state_equipment_inherentfunction_by_MWO[mwo]
                for state in state_equip_inherfunc[0]:
                    if state in cluster_states:
                        cluster_states[state]+=1
                    else:
                        cluster_states[state]=1
                for equip in state_equip_inherfunc[1]:
                    if equip in cluster_equip:
                        cluster_equip[equip]+=1
                    else:
                        cluster_equip[equip]=1
                if state_equip_inherfunc[2] in cluster_inherentfunc:
                    cluster_inherentfunc[state_equip_inherfunc[2]]+=1
                else:
                    cluster_inherentfunc[state_equip_inherfunc[2]]=1
        
        # get top words
        print("Cluster Size:", len(cluster_labels[cluster_labels==i]))
        print("Top words:")
        sorted_cluster_words = sorted(cluster_words, key=cluster_words.get, reverse=True)
        for j in range(min(len(sorted_cluster_words), 5)):
            print("  ",sorted_cluster_words[j])
        print()
        sorted_cluster_states = sorted(cluster_states, key=cluster_states.get, reverse=True)
        print("Top states:")
        for j in range(min(len(sorted_cluster_states), 5)):
            print("  ", sorted_cluster_states[j])
        print()

        sorted_cluster_equip = sorted(cluster_equip, key=cluster_equip.get, reverse=True)
        print("Top equipment:")
        for j in range(min(len(sorted_cluster_equip), 5)):
            print("  ", sorted_cluster_equip[j])
        print()

        sorted_cluster_inherentfunc = sorted(cluster_inherentfunc, key=cluster_inherentfunc.get, reverse=True)
        print("Inherent functions in order:")
        for j in range(len(sorted_cluster_inherentfunc)):
            print("  ",sorted_cluster_inherentfunc[j], cluster_inherentfunc[sorted_cluster_inherentfunc[j]])
        print("=========================")

run_kmeans_best_k(16, cluster_embeddings)
# Out:
# NMI: 0.4731252320639139
# Cluster 1 :
# Cluster Size: 191
# Top words:
#    leaking
#    unserviceable
#    seal
#    steering
#    drive
#
# Top states:
#    leaking
#    unserviceable
#    failed
#    fault
#    leak
#
# Top equipment:
#    seal
#    shaft
#    PTO
#    fan
#    cylinder
#
# Inherent functions in order:
#    guiding 35
#    covering 33
#    transforming 31
#    controlling 23
#    driving 23
#    generating 16
#    holding 11
#    matterprocessing 4
#    storing 4
#    restricting 3
#    sensing 3
#    protecting 2
#    emitting 2
#    humaninteraction 1
# =========================
# Cluster 2 :
# Cluster Size: 157
# Top words:
#    leak
#    oil
#    pump
#    filter
#    air
#
# Top states:
#    leak
#    unserviceable
#    error
#    found
#    plugged
#
# Top equipment:
#    pump
#    oil
#    filter
#    filters
#    grease pump
#
# Inherent functions in order:
#    generating 40
#    protecting 34
#    matterprocessing 28
#    controlling 12
#    interfacing 10
#    holding 10
#    presenting 6
#    sensing 4
#    transforming 4
#    storing 3
#    covering 2
#    restricting 2
#    emitting 2
# =========================
# Cluster 3 :
# Cluster Size: 244
# Top words:
#    not
#    working
#    unserviceable
#    pump
#    switch
#
# Top states:
#    not working
#    unserviceable
#    fault
#    faulty
#    on
#
# Top equipment:
#    horn
#    air horn
#    swing
#    ladder
#    camera
#
# Inherent functions in order:
#    sensing 91
#    presenting 44
#    generating 22
#    emitting 19
#    interfacing 17
#    transforming 15
#    humaninteraction 11
#    restricting 6
#    driving 6
#    storing 4
#    holding 3
#    matterprocessing 3
#    protecting 2
#    controlling 1
# =========================
# Cluster 4 :
# Cluster Size: 168
# Top words:
#    cabin
#    hand
#    seat
#    needs
#    right
#
# Top states:
#    cracks
#    unserviceable
#    damaged
#    crack
#    needs loctite
#
# Top equipment:
#    cabin
#    cabin seat
#    bucket
#    seat
#    mud bucket
#
# Inherent functions in order:
#    holding 55
#    storing 48
#    interfacing 17
#    protecting 10
#    covering 7
#    controlling 6
#    transforming 6
#    humaninteraction 4
#    restricting 3
#    presenting 3
#    matterprocessing 2
#    guiding 2
#    emitting 2
#    sensing 2
#    driving 1
# =========================
# Cluster 5 :
# Cluster Size: 131
# Top words:
#    engine
#    oil
#    leak
#    fault
#    motor
#
# Top states:
#    leak
#    fault
#    overheating
#    vibration
#    unserviceable
#
# Top equipment:
#    engine
#    oil
#    motor
#    coolant
#    starter motor
#
# Inherent functions in order:
#    driving 109
#    protecting 7
#    guiding 6
#    sensing 3
#    emitting 2
#    covering 2
#    generating 1
#    matterprocessing 1
# =========================
# Cluster 6 :
# Cluster Size: 226
# Top words:
#    hand
#    cylinder
#    left
#    broken
#    in
#
# Top states:
#    broken
#    damaged
#    unserviceable
#    cracked
#    missing
#
# Top equipment:
#    cylinder
#    guard
#    lift cylinder
#    steering
#    door
#
# Inherent functions in order:
#    holding 82
#    guiding 32
#    driving 27
#    protecting 26
#    covering 19
#    controlling 12
#    transforming 7
#    storing 7
#    interfacing 6
#    humaninteraction 3
#    matterprocessing 3
#    restricting 1
#    sensing 1
# =========================
# Cluster 7 :
# Cluster Size: 251
# Top words:
#    broken
#    missing
#    bolts
#    pin
#    hand
#
# Top states:
#    broken
#    missing
#    loose
#    unserviceable
#    out
#
# Top equipment:
#    bolts
#    pin
#    bolt
#    bearing
#    pulley
#
# Inherent functions in order:
#    holding 199
#    guiding 15
#    covering 12
#    protecting 6
#    matterprocessing 5
#    storing 4
#    controlling 3
#    generating 3
#    presenting 2
#    interfacing 1
#    humaninteraction 1
# =========================
# Cluster 8 :
# Cluster Size: 180
# Top words:
#    air
#    conditioner
#    out
#    lights
#    light
#
# Top states:
#    out
#    fault
#    unserviceable
#    not working
#    faults
#
# Top equipment:
#    air conditioner
#    lights
#    engine air conditioner
#    light
#    vims keypad light
#
# Inherent functions in order:
#    emitting 163
#    covering 4
#    protecting 3
#    generating 3
#    matterprocessing 3
#    sensing 2
#    guiding 1
#    driving 1
# =========================
# Cluster 9 :
# Cluster Size: 175
# Top words:
#    light
#    hand
#    out
#    unserviceable
#    right
#
# Top states:
#    unserviceable
#    out
#    blown
#    broken
#    not working
#
# Top equipment:
#    light
#    lights
#    headlight
#    boom
#    cabin
#
# Inherent functions in order:
#    emitting 135
#    guiding 15
#    holding 11
#    covering 3
#    sensing 3
#    humaninteraction 2
#    interfacing 2
#    generating 1
#    restricting 1
#    presenting 1
#    storing 1
# =========================
# Cluster 10 :
# Cluster Size: 162
# Top words:
#    window
#    door
#    valve
#    broken
#    control
#
# Top states:
#    broken
#    fault
#    cracked
#    unserviceable
#    falling off
#
# Top equipment:
#    window
#    door
#    control valve
#    isolator
#    drivers window
#
# Inherent functions in order:
#    controlling 112
#    restricting 23
#    interfacing 9
#    covering 5
#    humaninteraction 5
#    holding 3
#    protecting 2
#    driving 2
#    presenting 1
# =========================
# Cluster 11 :
# Cluster Size: 373
# Top words:
#    hose
#    blown
#    position
#    tyre
#    leaking
#
# Top states:
#    blown
#    leaking
#    unserviceable
#    broken
#    damaged
#
# Top equipment:
#    hose
#    tyre
#    brake
#    steering
#    hydraulic hose
#
# Inherent functions in order:
#    guiding 327
#    covering 28
#    interfacing 5
#    matterprocessing 5
#    holding 4
#    transforming 2
#    emitting 1
#    generating 1
# =========================
# Cluster 12 :
# Cluster Size: 113
# Top words:
#    brake
#    hoist
#    temperature
#    brakes
#    fault
#
# Top states:
#    fault
#    temperature error
#    need cleaning
#    out of adjustment
#    not releasing
#
# Top equipment:
#    brake
#    brakes
#    hoist
#    park brake
#    hoist brake
#
# Inherent functions in order:
#    restricting 75
#    humaninteraction 12
#    transforming 7
#    sensing 5
#    emitting 3
#    storing 2
#    presenting 2
#    generating 1
#    driving 1
#    matterprocessing 1
#    controlling 1
#    interfacing 1
#    guiding 1
#    holding 1
# =========================
# Cluster 13 :
# Cluster Size: 131
# Top words:
#    fault
#    transmission
#    leak
#    oil
#    drag
#
# Top states:
#    fault
#    leak
#    earthing out
#    slipping fault
#    failed
#
# Top equipment:
#    transmission
#    oil
#    differential
#    motor
#    pump
#
# Inherent functions in order:
#    transforming 74
#    driving 17
#    generating 13
#    guiding 4
#    protecting 4
#    holding 4
#    controlling 3
#    storing 3
#    sensing 3
#    presenting 3
#    matterprocessing 2
#    emitting 1
# =========================
# Cluster 14 :
# Cluster Size: 226
# Top words:
#    compressor
#    air
#    conditioner
#    unserviceable
#    pump
#
# Top states:
#    unserviceable
#    leaking
#    no charge
#    not working
#    fault
#
# Top equipment:
#    compressor
#    pump
#    air conditioner
#    battery
#    radiator
#
# Inherent functions in order:
#    generating 159
#    emitting 21
#    driving 9
#    storing 6
#    guiding 5
#    matterprocessing 4
#    transforming 4
#    holding 3
#    restricting 3
#    interfacing 3
#    controlling 3
#    protecting 2
#    covering 2
#    presenting 2
# =========================
# Cluster 15 :
# Cluster Size: 258
# Top words:
#    leak
#    oil
#    fuse
#    system
#    crack
#
# Top states:
#    leak
#    crack
#    fault
#    cracked
#    keeps blowing
#
# Top equipment:
#    oil
#    coolant
#    grease system
#    liner
#    exhaust shield
#
# Inherent functions in order:
#    protecting 208
#    controlling 14
#    interfacing 10
#    storing 6
#    holding 6
#    presenting 3
#    transforming 3
#    guiding 2
#    driving 2
#    covering 1
#    emitting 1
#    generating 1
#    humaninteraction 1
# =========================
# Cluster 16 :
# Cluster Size: 0
# Top words:
#
# Top states:
#
# Top equipment:
#
# Inherent functions in order:
# =========================

# %% [markdown]
# #### ave hierachical

# %%
def perform_hierarchical_clustering(cluster_embeddings, method):
    linkage_data = linkage(cluster_embeddings, method=method)
    fig = plt.figure(figsize=(25, 10))
    dn = dendrogram(linkage_data)
    plt.show()

    # calculate sihouette score on different k values
    silhouette_scores = []
    test_k = list(range(5, 30))
    nmi = 0
    for i in test_k:
        cluster_labels = fcluster(linkage_data, i, criterion='maxclust')
        silhouette_scores.append(silhouette_score(cluster_embeddings, cluster_labels))
        if i == 16:
            nmi = normalized_mutual_info_score(cluster_labels, y_train.tolist()+y_test.tolist())
    plt.plot(test_k, silhouette_scores, marker='o')
    plt.title("Silhouette Scores")
    plt.show()

    print("NMI:",nmi)

    return linkage_data


linkage_data_ave = perform_hierarchical_clustering(cluster_embeddings, "average")
# Out:
# NMI: 0.46027174601511234

# %%
def get_hierarchical_clusters(k, linkage_data):
    cluster_labels = fcluster(linkage_data, k, criterion='maxclust')
    for i in range(1,k+1):
        print("Cluster",i,":")
        cluster_words = {}
        cluster_states={}
        cluster_equip={}
        cluster_inherentfunc={}
        for j in range(len(cluster_labels)):
            if cluster_labels[j]==i:
                for word in X[j]:
                    if word in cluster_words:
                        cluster_words[word]+=1
                    else:
                        cluster_words[word]=1
                mwo = " ".join(X[j])
                state_equip_inherfunc = state_equipment_inherentfunction_by_MWO[mwo]
                for state in state_equip_inherfunc[0]:
                    if state in cluster_states:
                        cluster_states[state]+=1
                    else:
                        cluster_states[state]=1
                for equip in state_equip_inherfunc[1]:
                    if equip in cluster_equip:
                        cluster_equip[equip]+=1
                    else:
                        cluster_equip[equip]=1
                if state_equip_inherfunc[2] in cluster_inherentfunc:
                    cluster_inherentfunc[state_equip_inherfunc[2]]+=1
                else:
                    cluster_inherentfunc[state_equip_inherfunc[2]]=1
        
        # get top words
        print("Cluster Size:", len(cluster_labels[cluster_labels==i]))
        print("Top words:")
        sorted_cluster_words = sorted(cluster_words, key=cluster_words.get, reverse=True)
        for j in range(min(len(sorted_cluster_words), 5)):
            print("  ",sorted_cluster_words[j])
        print()
        sorted_cluster_states = sorted(cluster_states, key=cluster_states.get, reverse=True)
        print("Top states:")
        for j in range(min(len(sorted_cluster_states), 5)):
            print("  ", sorted_cluster_states[j])
        print()

        sorted_cluster_equip = sorted(cluster_equip, key=cluster_equip.get, reverse=True)
        print("Top equipment:")
        for j in range(min(len(sorted_cluster_equip), 5)):
            print("  ", sorted_cluster_equip[j])
        print()

        sorted_cluster_inherentfunc = sorted(cluster_inherentfunc, key=cluster_inherentfunc.get, reverse=True)
        print("Inherent functions in order:")
        for j in range(len(sorted_cluster_inherentfunc)):
            print("  ",sorted_cluster_inherentfunc[j], cluster_inherentfunc[sorted_cluster_inherentfunc[j]])
        print("=========================")
get_hierarchical_clusters(15, linkage_data_ave)
# Out:
# Cluster 1 :
# Cluster Size: 162
# Top words:
#    window
#    valve
#    broken
#    door
#    control
#
# Top states:
#    broken
#    cracked
#    unserviceable
#    fault
#    falling off
#
# Top equipment:
#    window
#    door
#    control valve
#    isolator
#    drivers window
#
# Inherent functions in order:
#    controlling 109
#    restricting 24
#    interfacing 9
#    covering 8
#    humaninteraction 5
#    protecting 4
#    sensing 1
#    matterprocessing 1
#    storing 1
# =========================
# Cluster 2 :
# Cluster Size: 99
# Top words:
#    brake
#    hoist
#    temperature
#    brakes
#    error
#
# Top states:
#    temperature error
#    fault
#    out of adjustment
#    need cleaning
#    not releasing
#
# Top equipment:
#    brake
#    brakes
#    park brake
#    hoist brake
#    hoist
#
# Inherent functions in order:
#    restricting 74
#    humaninteraction 11
#    sensing 5
#    transforming 2
#    storing 2
#    interfacing 2
#    presenting 1
#    emitting 1
#    holding 1
# =========================
# Cluster 3 :
# Cluster Size: 45
# Top words:
#    unserviceable
#    brake
#    need
#    seat
#    requires
#
# Top states:
#    unserviceable
#    need
#    blown
#    needs
#    needs aerial
#
# Top equipment:
#    brake
#    seat
#    driveline
#    screen
#    light
#
# Inherent functions in order:
#    transforming 12
#    guiding 9
#    matterprocessing 6
#    storing 5
#    emitting 5
#    holding 3
#    humaninteraction 2
#    restricting 2
#    sensing 1
# =========================
# Cluster 4 :
# Cluster Size: 165
# Top words:
#    leaking
#    cylinder
#    hand
#    unserviceable
#    fault
#
# Top states:
#    leaking
#    unserviceable
#    fault
#    noisy
#    noise
#
# Top equipment:
#    cylinder
#    lift cylinder
#    motor
#    engine
#    hose
#
# Inherent functions in order:
#    driving 56
#    guiding 33
#    controlling 18
#    covering 17
#    holding 14
#    transforming 10
#    generating 8
#    storing 3
#    interfacing 2
#    humaninteraction 1
#    presenting 1
#    sensing 1
#    protecting 1
# =========================
# Cluster 5 :
# Cluster Size: 474
# Top words:
#    hose
#    blown
#    leaking
#    position
#    tyre
#
# Top states:
#    blown
#    leaking
#    unserviceable
#    broken
#    leak
#
# Top equipment:
#    hose
#    tyre
#    brake
#    steering
#    lines
#
# Inherent functions in order:
#    guiding 355
#    covering 49
#    transforming 18
#    matterprocessing 15
#    holding 10
#    storing 7
#    interfacing 5
#    generating 3
#    controlling 3
#    protecting 2
#    sensing 2
#    restricting 2
#    emitting 1
#    presenting 1
#    driving 1
# =========================
# Cluster 6 :
# Cluster Size: 106
# Top words:
#    worn
#    missing
#    bucket
#    fuel
#    tooth
#
# Top states:
#    worn
#    missing
#    cracked
#    crack
#    fell off
#
# Top equipment:
#    bucket
#    tooth
#    fuel tank
#    tank
#    teeth
#
# Inherent functions in order:
#    matterprocessing 49
#    storing 17
#    holding 12
#    protecting 9
#    covering 7
#    guiding 4
#    interfacing 4
#    controlling 2
#    restricting 1
#    presenting 1
# =========================
# Cluster 7 :
# Cluster Size: 390
# Top words:
#    broken
#    missing
#    hand
#    pin
#    bolts
#
# Top states:
#    broken
#    missing
#    loose
#    unserviceable
#    damaged
#
# Top equipment:
#    bolts
#    pin
#    bolt
#    bearing
#    guard
#
# Inherent functions in order:
#    holding 253
#    protecting 29
#    guiding 28
#    controlling 23
#    covering 20
#    matterprocessing 8
#    interfacing 7
#    transforming 6
#    storing 6
#    humaninteraction 3
#    driving 2
#    generating 2
#    presenting 1
#    restricting 1
#    sensing 1
# =========================
# Cluster 8 :
# Cluster Size: 157
# Top words:
#    cabin
#    hand
#    seat
#    right
#    bucket
#
# Top states:
#    unserviceable
#    cracks
#    broken
#    damaged
#    needs loctite
#
# Top equipment:
#    cabin
#    cabin seat
#    bucket
#    seat
#    mud bucket
#
# Inherent functions in order:
#    holding 66
#    storing 43
#    interfacing 10
#    controlling 7
#    emitting 7
#    presenting 5
#    covering 5
#    sensing 4
#    humaninteraction 3
#    protecting 3
#    restricting 2
#    transforming 1
#    driving 1
# =========================
# Cluster 9 :
# Cluster Size: 295
# Top words:
#    light
#    air
#    conditioner
#    out
#    lights
#
# Top states:
#    out
#    unserviceable
#    fault
#    not working
#    blown
#
# Top equipment:
#    light
#    air conditioner
#    lights
#    headlight
#    boom
#
# Inherent functions in order:
#    emitting 269
#    guiding 8
#    holding 5
#    covering 4
#    sensing 4
#    humaninteraction 2
#    generating 1
#    presenting 1
#    driving 1
# =========================
# Cluster 10 :
# Cluster Size: 183
# Top words:
#    engine
#    fault
#    oil
#    motor
#    leak
#
# Top states:
#    fault
#    leak
#    overheating
#    unserviceable
#    vibration
#
# Top equipment:
#    engine
#    oil
#    motor
#    hoist
#    swing
#
# Inherent functions in order:
#    driving 120
#    sensing 12
#    generating 12
#    protecting 10
#    storing 5
#    humaninteraction 5
#    transforming 4
#    presenting 4
#    matterprocessing 2
#    emitting 2
#    interfacing 2
#    guiding 2
#    restricting 1
#    controlling 1
#    covering 1
# =========================
# Cluster 11 :
# Cluster Size: 26
# Top words:
#    needs
#    dust
#    flap
#    radio
#    aerial
#
# Top states:
#    needs aerial
#    needs repair
#    needs
#    needs replaced
#    broken
#
# Top equipment:
#    am / fm radio
#    dust flap
#    mast dust flap
#    key
#    ignition switch
#
# Inherent functions in order:
#    protecting 9
#    transforming 8
#    humaninteraction 3
#    presenting 2
#    covering 1
#    storing 1
#    emitting 1
#    generating 1
# =========================
# Cluster 12 :
# Cluster Size: 352
# Top words:
#    leak
#    oil
#    crack
#    in
#    cracked
#
# Top states:
#    leak
#    crack
#    cracked
#    fault
#    cracks
#
# Top equipment:
#    oil
#    coolant
#    handrail
#    grease system
#    hydraulic oil
#
# Inherent functions in order:
#    protecting 233
#    holding 27
#    controlling 20
#    interfacing 16
#    storing 14
#    transforming 8
#    generating 7
#    covering 7
#    emitting 6
#    driving 5
#    guiding 3
#    presenting 2
#    matterprocessing 2
#    restricting 1
#    humaninteraction 1
# =========================
# Cluster 13 :
# Cluster Size: 55
# Top words:
#    filter
#    leak
#    oil
#    fuel
#    error
#
# Top states:
#    leak
#    error
#    plugged
#    unserviceable
#    blocked
#
# Top equipment:
#    filter
#    oil
#    filters
#    differential
#    housing
#
# Inherent functions in order:
#    matterprocessing 24
#    holding 7
#    generating 5
#    transforming 5
#    presenting 3
#    emitting 3
#    restricting 2
#    protecting 2
#    interfacing 1
#    controlling 1
#    sensing 1
#    storing 1
# =========================
# Cluster 14 :
# Cluster Size: 289
# Top words:
#    not
#    working
#    pump
#    unserviceable
#    air
#
# Top states:
#    not working
#    unserviceable
#    faulty
#    fault
#    on
#
# Top equipment:
#    pump
#    horn
#    ladder
#    air conditioner
#    compressor
#
# Inherent functions in order:
#    sensing 83
#    generating 54
#    presenting 46
#    interfacing 26
#    emitting 23
#    protecting 20
#    transforming 9
#    matterprocessing 6
#    restricting 5
#    controlling 5
#    humaninteraction 4
#    holding 3
#    storing 2
#    driving 2
#    covering 1
# =========================
# Cluster 15 :
# Cluster Size: 353
# Top words:
#    air
#    conditioner
#    unserviceable
#    compressor
#    pump
#
# Top states:
#    unserviceable
#    leak
#    leaking
#    fault
#    no charge
#
# Top equipment:
#    transmission
#    compressor
#    pump
#    air conditioner
#    oil
#
# Inherent functions in order:
#    generating 168
#    transforming 70
#    emitting 35
#    guiding 18
#    driving 11
#    covering 10
#    controlling 9
#    matterprocessing 7
#    holding 7
#    storing 6
#    restricting 4
#    interfacing 3
#    protecting 2
#    sensing 2
#    presenting 1
# =========================

# %%
get_hierarchical_clusters(27, linkage_data_ave)
# Out:
# Cluster 1 :
# Cluster Size: 162
# Top words:
#    air
#    conditioner
#    hand
#    leaking
#    out
#
# Top states:
#    leaking
#    unserviceable
#    missing
#    leak
#    broken
#
# Top equipment:
#    air conditioner
#    oil
#    hose
#    pump
#    brake
#
# Inherent functions in order:
#    emitting 28
#    guiding 26
#    protecting 17
#    holding 12
#    generating 12
#    transforming 10
#    driving 9
#    covering 8
#    sensing 8
#    controlling 7
#    restricting 7
#    matterprocessing 6
#    presenting 4
#    humaninteraction 4
#    storing 4
# =========================
# Cluster 2 :
# Cluster Size: 3
# Top words:
#    unserviceable
#    position
#    brake
#    cooling
#    hose
#
# Top states:
#    unserviceable
#    overvoltage alarm
#    alarm
#
# Top equipment:
#    brake
#    cooling hose
#    hose
#    coolant pump
#    pump
#
# Inherent functions in order:
#    generating 2
#    guiding 1
# =========================
# Cluster 3 :
# Cluster Size: 96
# Top words:
#    unserviceable
#    hose
#    hand
#    leaking
#    oil
#
# Top states:
#    unserviceable
#    leaking
#    leak
#    blown
#    broken
#
# Top equipment:
#    hose
#    engine
#    oil
#    cylinder
#    pump
#
# Inherent functions in order:
#    guiding 13
#    holding 12
#    protecting 12
#    driving 10
#    emitting 9
#    generating 8
#    transforming 7
#    controlling 5
#    restricting 4
#    interfacing 4
#    covering 4
#    humaninteraction 3
#    matterprocessing 2
#    sensing 1
#    storing 1
#    presenting 1
# =========================
# Cluster 4 :
# Cluster Size: 24
# Top words:
#    loose
#    left
#    bucket
#    hand
#    unserviceable
#
# Top states:
#    loose
#    unserviceable
#    missing
#    needs
#    leak
#
# Top equipment:
#    bucket
#    bolts
#    strut
#    air conditioner
#    cover plate
#
# Inherent functions in order:
#    holding 6
#    emitting 3
#    covering 3
#    generating 3
#    guiding 3
#    protecting 2
#    driving 2
#    sensing 1
#    matterprocessing 1
# =========================
# Cluster 5 :
# Cluster Size: 21
# Top words:
#    broken
#    not
#    leaking
#    air
#    conditioner
#
# Top states:
#    broken
#    leaking
#    unserviceable
#    missing
#    damaged
#
# Top equipment:
#    cabin
#    VIMS
#    alarm
#    boarding gate
#    gate
#
# Inherent functions in order:
#    controlling 3
#    holding 3
#    transforming 2
#    covering 2
#    emitting 2
#    generating 2
#    interfacing 2
#    presenting 1
#    matterprocessing 1
#    guiding 1
#    protecting 1
#    storing 1
# =========================
# Cluster 6 :
# Cluster Size: 165
# Top words:
#    oil
#    leak
#    on
#    air
#    unserviceable
#
# Top states:
#    leak
#    missing
#    unserviceable
#    cracked
#    broken
#
# Top equipment:
#    oil
#    hose
#    steering
#    boom
#    tyre
#
# Inherent functions in order:
#    guiding 26
#    holding 25
#    protecting 22
#    controlling 16
#    emitting 14
#    covering 9
#    transforming 8
#    matterprocessing 7
#    generating 6
#    sensing 6
#    interfacing 6
#    restricting 6
#    storing 5
#    driving 5
#    humaninteraction 2
#    presenting 2
# =========================
# Cluster 7 :
# Cluster Size: 436
# Top words:
#    unserviceable
#    air
#    hand
#    out
#    leak
#
# Top states:
#    unserviceable
#    leak
#    fault
#    blown
#    broken
#
# Top equipment:
#    hose
#    engine
#    oil
#    air conditioner
#    light
#
# Inherent functions in order:
#    emitting 66
#    holding 61
#    guiding 58
#    generating 36
#    protecting 33
#    driving 30
#    controlling 26
#    matterprocessing 26
#    transforming 23
#    sensing 16
#    interfacing 14
#    storing 12
#    restricting 11
#    presenting 10
#    covering 10
#    humaninteraction 4
# =========================
# Cluster 8 :
# Cluster Size: 19
# Top words:
#    not
#    hoist
#    bolt
#    needs
#    fuse
#
# Top states:
#    missing
#    popped
#    needs
#    not working
#    keeps blowing
#
# Top equipment:
#    bolt
#    hoist brake
#    carousel
#    Loctite
#    speedometer
#
# Inherent functions in order:
#    holding 4
#    driving 3
#    protecting 2
#    restricting 2
#    emitting 2
#    generating 2
#    sensing 1
#    controlling 1
#    guiding 1
#    transforming 1
# =========================
# Cluster 9 :
# Cluster Size: 19
# Top words:
#    air
#    oil
#    error
#    engine
#    is
#
# Top states:
#    error
#    unserviceable
#    fault
#    damaged
#    leak
#
# Top equipment:
#    oil
#    motor
#    RTD
#    hoist
#    aftercooler
#
# Inherent functions in order:
#    protecting 7
#    sensing 3
#    matterprocessing 2
#    generating 2
#    holding 2
#    emitting 1
#    driving 1
#    restricting 1
# =========================
# Cluster 10 :
# Cluster Size: 106
# Top words:
#    air
#    not
#    conditioner
#    unserviceable
#    broken
#
# Top states:
#    unserviceable
#    broken
#    leaking
#    leak
#    not working
#
# Top equipment:
#    air conditioner
#    compressor
#    engine
#    hose
#    cooler
#
# Inherent functions in order:
#    guiding 14
#    protecting 14
#    generating 13
#    emitting 13
#    holding 11
#    controlling 10
#    storing 8
#    driving 5
#    covering 4
#    interfacing 4
#    sensing 3
#    matterprocessing 3
#    presenting 1
#    restricting 1
#    humaninteraction 1
#    transforming 1
# =========================
# Cluster 11 :
# Cluster Size: 390
# Top words:
#    unserviceable
#    oil
#    on
#    out
#    air
#
# Top states:
#    unserviceable
#    leaking
#    fault
#    leak
#    broken
#
# Top equipment:
#    oil
#    engine
#    hose
#    air conditioner
#    pump
#
# Inherent functions in order:
#    holding 52
#    guiding 46
#    protecting 43
#    emitting 39
#    generating 39
#    controlling 22
#    transforming 21
#    driving 21
#    sensing 20
#    matterprocessing 17
#    covering 16
#    storing 15
#    presenting 13
#    restricting 11
#    interfacing 11
#    humaninteraction 4
# =========================
# Cluster 12 :
# Cluster Size: 52
# Top words:
#    leak
#    pressure
#    leaking
#    broken
#    hand
#
# Top states:
#    leak
#    leaking
#    broken
#    unserviceable
#    cracked
#
# Top equipment:
#    coolant
#    tyre
#    cylinder
#    transmission
#    pressure compensator
#
# Inherent functions in order:
#    protecting 11
#    guiding 10
#    holding 6
#    sensing 4
#    generating 4
#    presenting 3
#    driving 3
#    emitting 3
#    controlling 2
#    covering 2
#    transforming 1
#    storing 1
#    matterprocessing 1
#    restricting 1
# =========================
# Cluster 13 :
# Cluster Size: 105
# Top words:
#    air
#    hand
#    in
#    unserviceable
#    not
#
# Top states:
#    unserviceable
#    fault
#    missing
#    leak
#    crack
#
# Top equipment:
#    hose
#    window
#    compressor
#    bolts
#    bolt
#
# Inherent functions in order:
#    holding 15
#    guiding 14
#    emitting 14
#    protecting 11
#    generating 9
#    controlling 7
#    sensing 6
#    interfacing 5
#    transforming 4
#    storing 4
#    covering 4
#    restricting 4
#    driving 4
#    presenting 3
#    matterprocessing 1
# =========================
# Cluster 14 :
# Cluster Size: 295
# Top words:
#    unserviceable
#    hand
#    broken
#    air
#    not
#
# Top states:
#    unserviceable
#    broken
#    leaking
#    leak
#    fault
#
# Top equipment:
#    air conditioner
#    hose
#    brake
#    engine
#    oil
#
# Inherent functions in order:
#    guiding 44
#    holding 33
#    emitting 31
#    protecting 30
#    controlling 24
#    driving 22
#    generating 21
#    transforming 15
#    storing 14
#    matterprocessing 13
#    restricting 10
#    covering 10
#    interfacing 10
#    presenting 7
#    sensing 6
#    humaninteraction 5
# =========================
# Cluster 15 :
# Cluster Size: 84
# Top words:
#    hand
#    unserviceable
#    air
#    out
#    not
#
# Top states:
#    unserviceable
#    missing
#    not working
#    fault
#    leak
#
# Top equipment:
#    engine
#    oil
#    tyre
#    motor
#    light
#
# Inherent functions in order:
#    guiding 17
#    holding 14
#    driving 10
#    generating 7
#    protecting 6
#    controlling 4
#    matterprocessing 4
#    covering 4
#    emitting 4
#    interfacing 3
#    sensing 3
#    restricting 3
#    transforming 2
#    storing 2
#    presenting 1
# =========================
# Cluster 16 :
# Cluster Size: 99
# Top words:
#    hand
#    in
#    unserviceable
#    hose
#    crack
#
# Top states:
#    unserviceable
#    crack
#    leaking
#    leak
#    blown
#
# Top equipment:
#    hose
#    engine
#    brake
#    oil
#    fuel tank
#
# Inherent functions in order:
#    guiding 18
#    protecting 12
#    holding 12
#    generating 7
#    storing 7
#    driving 7
#    restricting 6
#    covering 6
#    emitting 6
#    presenting 4
#    controlling 4
#    matterprocessing 3
#    transforming 2
#    sensing 2
#    humaninteraction 2
#    interfacing 1
# =========================
# Cluster 17 :
# Cluster Size: 26
# Top words:
#    cabin
#    blown
#    engine
#    hose
#    leak
#
# Top states:
#    blown
#    leak
#    unserviceable
#    not working
#    overgreasing
#
# Top equipment:
#    oil
#    engine
#    cabin
#    hose
#    air horn
#
# Inherent functions in order:
#    protecting 4
#    guiding 4
#    controlling 3
#    holding 3
#    transforming 2
#    storing 2
#    covering 2
#    emitting 2
#    driving 2
#    presenting 1
#    generating 1
# =========================
# Cluster 18 :
# Cluster Size: 22
# Top words:
#    oil
#    hose
#    in
#    engine
#    not
#
# Top states:
#    leaking
#    blown
#    unserviceable
#    weeping
#    cracks
#
# Top equipment:
#    hose
#    engine
#    transmission
#    cooler
#    air conditioner
#
# Inherent functions in order:
#    guiding 4
#    holding 4
#    emitting 4
#    protecting 2
#    driving 2
#    matterprocessing 1
#    generating 1
#    restricting 1
#    covering 1
#    storing 1
#    transforming 1
# =========================
# Cluster 19 :
# Cluster Size: 128
# Top words:
#    air
#    unserviceable
#    hand
#    leak
#    conditioner
#
# Top states:
#    unserviceable
#    leak
#    broken
#    blown
#    fault
#
# Top equipment:
#    hose
#    brake
#    oil
#    air conditioner
#    engine
#
# Inherent functions in order:
#    holding 19
#    emitting 18
#    guiding 17
#    protecting 12
#    driving 11
#    restricting 10
#    transforming 8
#    generating 8
#    controlling 6
#    interfacing 4
#    sensing 3
#    presenting 3
#    matterprocessing 3
#    covering 3
#    storing 2
#    humaninteraction 1
# =========================
# Cluster 20 :
# Cluster Size: 202
# Top words:
#    leaking
#    air
#    hose
#    fault
#    hand
#
# Top states:
#    leaking
#    fault
#    leak
#    unserviceable
#    broken
#
# Top equipment:
#    hose
#    brake
#    air conditioner
#    oil
#    hoist
#
# Inherent functions in order:
#    guiding 33
#    emitting 24
#    holding 21
#    generating 16
#    controlling 16
#    covering 15
#    driving 15
#    transforming 13
#    protecting 11
#    matterprocessing 8
#    sensing 8
#    restricting 7
#    storing 5
#    interfacing 4
#    presenting 3
#    humaninteraction 3
# =========================
# Cluster 21 :
# Cluster Size: 21
# Top words:
#    leaking
#    air
#    oil
#    in
#    right
#
# Top states:
#    leaking
#    broken
#    blown
#    missing
#    cracks
#
# Top equipment:
#    air
#    line
#    auto-greaser
#    oil
#    handrail
#
# Inherent functions in order:
#    generating 3
#    emitting 3
#    holding 3
#    guiding 2
#    protecting 2
#    controlling 2
#    transforming 1
#    restricting 1
#    presenting 1
#    covering 1
#    sensing 1
#    matterprocessing 1
# =========================
# Cluster 22 :
# Cluster Size: 34
# Top words:
#    leak
#    air
#    not
#    unserviceable
#    in
#
# Top states:
#    leak
#    unserviceable
#    not working
#    broken
#    blown
#
# Top equipment:
#    mounts
#    oil
#    engine
#    differential
#    cabin
#
# Inherent functions in order:
#    generating 5
#    holding 5
#    guiding 4
#    protecting 4
#    driving 3
#    emitting 3
#    controlling 2
#    interfacing 2
#    sensing 2
#    matterprocessing 1
#    restricting 1
#    transforming 1
#    storing 1
# =========================
# Cluster 23 :
# Cluster Size: 70
# Top words:
#    unserviceable
#    not
#    brake
#    fault
#    leak
#
# Top states:
#    unserviceable
#    leak
#    not working
#    fault
#    faulty
#
# Top equipment:
#    hose
#    brake
#    engine
#    oil
#    tyre
#
# Inherent functions in order:
#    guiding 12
#    protecting 9
#    holding 7
#    controlling 6
#    generating 6
#    driving 5
#    restricting 5
#    emitting 5
#    transforming 4
#    sensing 3
#    interfacing 2
#    presenting 2
#    storing 2
#    humaninteraction 1
#    covering 1
# =========================
# Cluster 24 :
# Cluster Size: 219
# Top words:
#    air
#    unserviceable
#    conditioner
#    fault
#    leak
#
# Top states:
#    unserviceable
#    fault
#    leak
#    leaking
#    broken
#
# Top equipment:
#    hose
#    air conditioner
#    brake
#    light
#    oil
#
# Inherent functions in order:
#    guiding 35
#    emitting 30
#    holding 26
#    protecting 25
#    generating 18
#    driving 16
#    controlling 10
#    transforming 10
#    restricting 9
#    storing 8
#    interfacing 6
#    matterprocessing 6
#    covering 6
#    sensing 6
#    humaninteraction 5
#    presenting 3
# =========================
# Cluster 25 :
# Cluster Size: 57
# Top words:
#    pump
#    unserviceable
#    out
#    leak
#    position
#
# Top states:
#    unserviceable
#    leak
#    missing
#    broken
#    not working
#
# Top equipment:
#    tyre
#    pump
#    oil
#    batteries
#    compressor
#
# Inherent functions in order:
#    generating 10
#    protecting 9
#    guiding 9
#    holding 6
#    sensing 4
#    driving 4
#    storing 3
#    controlling 3
#    restricting 3
#    emitting 3
#    covering 1
#    presenting 1
#    matterprocessing 1
# =========================
# Cluster 26 :
# Cluster Size: 75
# Top words:
#    fault
#    air
#    leak
#    leaking
#    broken
#
# Top states:
#    fault
#    leak
#    leaking
#    broken
#    unserviceable
#
# Top equipment:
#    hose
#    PTO
#    oil
#    air conditioner
#    tank
#
# Inherent functions in order:
#    holding 9
#    guiding 9
#    generating 7
#    controlling 6
#    sensing 6
#    emitting 5
#    covering 5
#    interfacing 5
#    storing 4
#    protecting 4
#    transforming 4
#    restricting 4
#    matterprocessing 3
#    driving 3
#    humaninteraction 1
# =========================
# Cluster 27 :
# Cluster Size: 221
# Top words:
#    broken
#    hand
#    air
#    right
#    hose
#
# Top states:
#    broken
#    missing
#    blown
#    leaking
#    unserviceable
#
# Top equipment:
#    hose
#    oil
#    bolts
#    air conditioner
#    pulley
#
# Inherent functions in order:
#    guiding 39
#    holding 37
#    emitting 21
#    protecting 19
#    generating 13
#    covering 13
#    controlling 13
#    transforming 12
#    storing 11
#    restricting 11
#    matterprocessing 9
#    driving 6
#    presenting 5
#    sensing 4
#    interfacing 4
#    humaninteraction 4
# =========================

# %% [markdown]
# #### ward heriarchical

# %%
linkage_data_ward = perform_hierarchical_clustering(cluster_embeddings, "ward")
# Out:
# NMI: 0.4515083374946283

# %%
get_hierarchical_clusters(15, linkage_data_ward)
# Out:
# Cluster 1 :
# Cluster Size: 285
# Top words:
#    unserviceable
#    broken
#    hand
#    leaking
#    brake
#
# Top states:
#    unserviceable
#    broken
#    leaking
#    leak
#    fault
#
# Top equipment:
#    hose
#    brake
#    air conditioner
#    oil
#    engine
#
# Inherent functions in order:
#    guiding 47
#    holding 33
#    emitting 30
#    protecting 29
#    controlling 22
#    generating 20
#    driving 20
#    storing 15
#    transforming 13
#    restricting 11
#    covering 10
#    matterprocessing 10
#    interfacing 9
#    presenting 7
#    sensing 5
#    humaninteraction 4
# =========================
# Cluster 2 :
# Cluster Size: 104
# Top words:
#    hand
#    unserviceable
#    in
#    hose
#    crack
#
# Top states:
#    unserviceable
#    crack
#    blown
#    leaking
#    leak
#
# Top equipment:
#    hose
#    brake
#    engine
#    fuel tank
#    coolant
#
# Inherent functions in order:
#    guiding 18
#    holding 15
#    protecting 12
#    generating 7
#    storing 7
#    driving 6
#    restricting 6
#    covering 6
#    emitting 6
#    presenting 5
#    controlling 4
#    matterprocessing 3
#    sensing 3
#    humaninteraction 3
#    transforming 2
#    interfacing 1
# =========================
# Cluster 3 :
# Cluster Size: 165
# Top words:
#    hand
#    unserviceable
#    engine
#    not
#    air
#
# Top states:
#    unserviceable
#    missing
#    leaking
#    broken
#    fault
#
# Top equipment:
#    engine
#    oil
#    tyre
#    brake
#    bucket
#
# Inherent functions in order:
#    guiding 26
#    holding 24
#    generating 18
#    protecting 16
#    driving 15
#    covering 10
#    storing 10
#    emitting 8
#    controlling 7
#    restricting 7
#    sensing 7
#    matterprocessing 6
#    interfacing 6
#    transforming 3
#    presenting 2
# =========================
# Cluster 4 :
# Cluster Size: 142
# Top words:
#    unserviceable
#    not
#    air
#    leak
#    oil
#
# Top states:
#    unserviceable
#    leak
#    blown
#    fault
#    not working
#
# Top equipment:
#    oil
#    hose
#    engine
#    brake
#    transmission
#
# Inherent functions in order:
#    guiding 19
#    generating 16
#    holding 16
#    protecting 15
#    controlling 12
#    emitting 12
#    restricting 9
#    driving 8
#    transforming 8
#    interfacing 7
#    sensing 6
#    matterprocessing 4
#    presenting 3
#    covering 3
#    storing 3
#    humaninteraction 1
# =========================
# Cluster 5 :
# Cluster Size: 156
# Top words:
#    broken
#    air
#    unserviceable
#    missing
#    conditioner
#
# Top states:
#    broken
#    unserviceable
#    missing
#    fault
#    leak
#
# Top equipment:
#    hose
#    oil
#    air conditioner
#    pulley
#    engine
#
# Inherent functions in order:
#    guiding 32
#    holding 22
#    emitting 13
#    controlling 12
#    transforming 10
#    protecting 10
#    generating 9
#    storing 8
#    restricting 7
#    matterprocessing 7
#    covering 7
#    sensing 6
#    driving 5
#    interfacing 4
#    presenting 2
#    humaninteraction 2
# =========================
# Cluster 6 :
# Cluster Size: 195
# Top words:
#    air
#    unserviceable
#    leak
#    conditioner
#    oil
#
# Top states:
#    unserviceable
#    leak
#    fault
#    broken
#    not working
#
# Top equipment:
#    oil
#    hose
#    air conditioner
#    engine
#    pump
#
# Inherent functions in order:
#    holding 28
#    protecting 26
#    guiding 21
#    emitting 20
#    generating 17
#    sensing 11
#    driving 10
#    controlling 10
#    covering 10
#    matterprocessing 10
#    transforming 10
#    restricting 8
#    interfacing 5
#    presenting 4
#    storing 3
#    humaninteraction 2
# =========================
# Cluster 7 :
# Cluster Size: 169
# Top words:
#    air
#    leaking
#    hand
#    out
#    conditioner
#
# Top states:
#    leaking
#    unserviceable
#    leak
#    missing
#    broken
#
# Top equipment:
#    hose
#    pump
#    brake
#    oil
#    engine
#
# Inherent functions in order:
#    guiding 31
#    emitting 25
#    protecting 18
#    holding 17
#    generating 15
#    transforming 10
#    driving 8
#    sensing 8
#    controlling 7
#    covering 7
#    restricting 6
#    presenting 5
#    storing 5
#    humaninteraction 4
#    matterprocessing 3
# =========================
# Cluster 8 :
# Cluster Size: 99
# Top words:
#    unserviceable
#    hose
#    hand
#    leaking
#    oil
#
# Top states:
#    unserviceable
#    leaking
#    leak
#    blown
#    broken
#
# Top equipment:
#    hose
#    engine
#    pump
#    oil
#    cylinder
#
# Inherent functions in order:
#    guiding 14
#    protecting 13
#    holding 12
#    driving 10
#    generating 10
#    emitting 9
#    transforming 6
#    controlling 5
#    restricting 4
#    interfacing 4
#    covering 4
#    humaninteraction 3
#    matterprocessing 2
#    sensing 1
#    storing 1
#    presenting 1
# =========================
# Cluster 9 :
# Cluster Size: 203
# Top words:
#    air
#    unserviceable
#    conditioner
#    hand
#    fault
#
# Top states:
#    unserviceable
#    leak
#    fault
#    broken
#    leaking
#
# Top equipment:
#    hose
#    air conditioner
#    light
#    oil
#    brake
#
# Inherent functions in order:
#    guiding 30
#    holding 26
#    emitting 25
#    protecting 22
#    generating 16
#    controlling 13
#    driving 11
#    transforming 11
#    storing 9
#    matterprocessing 8
#    restricting 8
#    covering 7
#    interfacing 5
#    humaninteraction 5
#    sensing 5
#    presenting 2
# =========================
# Cluster 10 :
# Cluster Size: 253
# Top words:
#    unserviceable
#    not
#    hand
#    out
#    air
#
# Top states:
#    unserviceable
#    leak
#    blown
#    broken
#    fault
#
# Top equipment:
#    hose
#    light
#    engine
#    oil
#    air conditioner
#
# Inherent functions in order:
#    holding 42
#    emitting 39
#    guiding 36
#    generating 18
#    controlling 17
#    protecting 14
#    driving 14
#    transforming 13
#    matterprocessing 13
#    sensing 11
#    interfacing 8
#    covering 7
#    storing 7
#    restricting 7
#    presenting 5
#    humaninteraction 2
# =========================
# Cluster 11 :
# Cluster Size: 269
# Top words:
#    oil
#    leak
#    unserviceable
#    hand
#    fault
#
# Top states:
#    leak
#    unserviceable
#    fault
#    blown
#    missing
#
# Top equipment:
#    oil
#    hose
#    engine
#    cabin
#    air conditioner
#
# Inherent functions in order:
#    guiding 42
#    holding 36
#    protecting 31
#    emitting 29
#    generating 19
#    driving 18
#    controlling 15
#    covering 13
#    sensing 11
#    matterprocessing 11
#    transforming 11
#    storing 10
#    interfacing 8
#    restricting 7
#    presenting 5
#    humaninteraction 3
# =========================
# Cluster 12 :
# Cluster Size: 299
# Top words:
#    air
#    leak
#    unserviceable
#    conditioner
#    hand
#
# Top states:
#    leak
#    unserviceable
#    leaking
#    fault
#    blown
#
# Top equipment:
#    hose
#    engine
#    oil
#    brake
#    air conditioner
#
# Inherent functions in order:
#    guiding 42
#    emitting 42
#    holding 34
#    driving 28
#    protecting 25
#    transforming 21
#    generating 20
#    covering 17
#    restricting 17
#    controlling 15
#    matterprocessing 10
#    storing 8
#    sensing 7
#    presenting 5
#    interfacing 5
#    humaninteraction 3
# =========================
# Cluster 13 :
# Cluster Size: 268
# Top words:
#    not
#    unserviceable
#    air
#    conditioner
#    hand
#
# Top states:
#    unserviceable
#    leak
#    broken
#    leaking
#    not working
#
# Top equipment:
#    air conditioner
#    engine
#    compressor
#    hose
#    steering
#
# Inherent functions in order:
#    emitting 31
#    guiding 31
#    holding 29
#    generating 28
#    protecting 26
#    controlling 23
#    driving 18
#    storing 14
#    sensing 11
#    interfacing 11
#    matterprocessing 11
#    covering 9
#    transforming 8
#    restricting 8
#    presenting 6
#    humaninteraction 4
# =========================
# Cluster 14 :
# Cluster Size: 331
# Top words:
#    unserviceable
#    oil
#    air
#    out
#    fault
#
# Top states:
#    unserviceable
#    fault
#    leaking
#    broken
#    leak
#
# Top equipment:
#    oil
#    air conditioner
#    hose
#    engine
#    lights
#
# Inherent functions in order:
#    holding 45
#    protecting 43
#    emitting 41
#    guiding 36
#    generating 30
#    controlling 19
#    transforming 19
#    driving 17
#    matterprocessing 16
#    sensing 13
#    covering 12
#    presenting 11
#    restricting 9
#    storing 9
#    interfacing 8
#    humaninteraction 3
# =========================
# Cluster 15 :
# Cluster Size: 213
# Top words:
#    hand
#    air
#    leak
#    broken
#    conditioner
#
# Top states:
#    leak
#    broken
#    fault
#    leaking
#    unserviceable
#
# Top equipment:
#    hose
#    air conditioner
#    oil
#    transmission
#    motor
#
# Inherent functions in order:
#    guiding 35
#    holding 29
#    protecting 24
#    emitting 23
#    generating 18
#    controlling 17
#    sensing 12
#    driving 11
#    transforming 8
#    covering 8
#    presenting 6
#    matterprocessing 6
#    interfacing 6
#    restricting 5
#    storing 4
#    humaninteraction 1
# =========================

# %%
get_hierarchical_clusters(24, linkage_data_ward)
# Out:
# Cluster 1 :
# Cluster Size: 104
# Top words:
#    unserviceable
#    hand
#    broken
#    brake
#    leak
#
# Top states:
#    unserviceable
#    broken
#    leak
#    leaking
#    not working
#
# Top equipment:
#    hose
#    air conditioner
#    brake
#    drag
#    oil
#
# Inherent functions in order:
#    guiding 16
#    holding 16
#    protecting 12
#    emitting 10
#    controlling 9
#    generating 8
#    driving 7
#    matterprocessing 6
#    storing 5
#    restricting 5
#    covering 3
#    transforming 3
#    humaninteraction 2
#    sensing 1
#    interfacing 1
# =========================
# Cluster 2 :
# Cluster Size: 181
# Top words:
#    broken
#    fault
#    unserviceable
#    leaking
#    brake
#
# Top states:
#    broken
#    fault
#    unserviceable
#    leaking
#    leak
#
# Top equipment:
#    brake
#    hose
#    engine
#    oil
#    light
#
# Inherent functions in order:
#    guiding 31
#    emitting 20
#    holding 17
#    protecting 17
#    driving 13
#    controlling 13
#    generating 12
#    transforming 10
#    storing 10
#    interfacing 8
#    presenting 7
#    covering 7
#    restricting 6
#    sensing 4
#    matterprocessing 4
#    humaninteraction 2
# =========================
# Cluster 3 :
# Cluster Size: 104
# Top words:
#    hand
#    unserviceable
#    in
#    hose
#    crack
#
# Top states:
#    unserviceable
#    crack
#    blown
#    leaking
#    leak
#
# Top equipment:
#    hose
#    brake
#    engine
#    fuel tank
#    coolant
#
# Inherent functions in order:
#    guiding 18
#    holding 15
#    protecting 12
#    generating 7
#    storing 7
#    driving 6
#    restricting 6
#    covering 6
#    emitting 6
#    presenting 5
#    controlling 4
#    matterprocessing 3
#    sensing 3
#    humaninteraction 3
#    transforming 2
#    interfacing 1
# =========================
# Cluster 4 :
# Cluster Size: 71
# Top words:
#    engine
#    pump
#    broken
#    in
#    not
#
# Top states:
#    broken
#    missing
#    unserviceable
#    leaking
#    cracks
#
# Top equipment:
#    bolts
#    tyre
#    bucket
#    engine
#    brake
#
# Inherent functions in order:
#    guiding 11
#    holding 10
#    generating 9
#    protecting 9
#    storing 7
#    covering 5
#    restricting 5
#    driving 4
#    emitting 3
#    sensing 3
#    matterprocessing 2
#    presenting 1
#    interfacing 1
#    controlling 1
# =========================
# Cluster 5 :
# Cluster Size: 94
# Top words:
#    hand
#    unserviceable
#    out
#    left
#    air
#
# Top states:
#    unserviceable
#    missing
#    leaking
#    not working
#    fault
#
# Top equipment:
#    engine
#    oil
#    tyre
#    motor
#    light
#
# Inherent functions in order:
#    guiding 15
#    holding 14
#    driving 11
#    generating 9
#    protecting 7
#    controlling 6
#    covering 5
#    interfacing 5
#    emitting 5
#    matterprocessing 4
#    sensing 4
#    transforming 3
#    storing 3
#    restricting 2
#    presenting 1
# =========================
# Cluster 6 :
# Cluster Size: 142
# Top words:
#    unserviceable
#    not
#    air
#    leak
#    oil
#
# Top states:
#    unserviceable
#    leak
#    blown
#    fault
#    not working
#
# Top equipment:
#    oil
#    hose
#    engine
#    brake
#    transmission
#
# Inherent functions in order:
#    guiding 19
#    generating 16
#    holding 16
#    protecting 15
#    controlling 12
#    emitting 12
#    restricting 9
#    driving 8
#    transforming 8
#    interfacing 7
#    sensing 6
#    matterprocessing 4
#    presenting 3
#    covering 3
#    storing 3
#    humaninteraction 1
# =========================
# Cluster 7 :
# Cluster Size: 156
# Top words:
#    broken
#    air
#    unserviceable
#    missing
#    conditioner
#
# Top states:
#    broken
#    unserviceable
#    missing
#    fault
#    leak
#
# Top equipment:
#    hose
#    oil
#    air conditioner
#    pulley
#    engine
#
# Inherent functions in order:
#    guiding 32
#    holding 22
#    emitting 13
#    controlling 12
#    transforming 10
#    protecting 10
#    generating 9
#    storing 8
#    restricting 7
#    matterprocessing 7
#    covering 7
#    sensing 6
#    driving 5
#    interfacing 4
#    presenting 2
#    humaninteraction 2
# =========================
# Cluster 8 :
# Cluster Size: 92
# Top words:
#    air
#    unserviceable
#    fault
#    conditioner
#    leaking
#
# Top states:
#    unserviceable
#    fault
#    leaking
#    leak
#    broken
#
# Top equipment:
#    hose
#    oil
#    air conditioner
#    engine
#    seal
#
# Inherent functions in order:
#    holding 11
#    guiding 9
#    generating 8
#    emitting 8
#    covering 8
#    protecting 8
#    controlling 7
#    sensing 6
#    transforming 5
#    interfacing 5
#    matterprocessing 5
#    driving 4
#    restricting 4
#    storing 2
#    presenting 1
#    humaninteraction 1
# =========================
# Cluster 9 :
# Cluster Size: 103
# Top words:
#    air
#    leak
#    oil
#    not
#    conditioner
#
# Top states:
#    leak
#    unserviceable
#    not working
#    broken
#    damaged
#
# Top equipment:
#    oil
#    hose
#    cabin
#    engine
#    air conditioner
#
# Inherent functions in order:
#    protecting 18
#    holding 17
#    guiding 12
#    emitting 12
#    generating 9
#    driving 6
#    sensing 5
#    matterprocessing 5
#    transforming 5
#    restricting 4
#    controlling 3
#    presenting 3
#    covering 2
#    humaninteraction 1
#    storing 1
# =========================
# Cluster 10 :
# Cluster Size: 81
# Top words:
#    air
#    conditioner
#    unserviceable
#    hand
#    not
#
# Top states:
#    unserviceable
#    fault
#    leak
#    leaking
#    missing
#
# Top equipment:
#    air conditioner
#    hose
#    brake
#    oil
#    engine
#
# Inherent functions in order:
#    emitting 14
#    protecting 12
#    guiding 10
#    generating 8
#    driving 5
#    covering 5
#    holding 5
#    transforming 4
#    sensing 4
#    restricting 4
#    presenting 3
#    controlling 3
#    humaninteraction 2
#    storing 2
# =========================
# Cluster 11 :
# Cluster Size: 88
# Top words:
#    leaking
#    hand
#    out
#    air
#    on
#
# Top states:
#    leaking
#    broken
#    leak
#    crack
#    missing
#
# Top equipment:
#    pump
#    hose
#    brake
#    oil
#    cylinder
#
# Inherent functions in order:
#    guiding 21
#    holding 12
#    emitting 11
#    generating 7
#    transforming 6
#    protecting 6
#    controlling 4
#    sensing 4
#    storing 3
#    matterprocessing 3
#    driving 3
#    presenting 2
#    restricting 2
#    humaninteraction 2
#    covering 2
# =========================
# Cluster 12 :
# Cluster Size: 99
# Top words:
#    unserviceable
#    hose
#    hand
#    leaking
#    oil
#
# Top states:
#    unserviceable
#    leaking
#    leak
#    blown
#    broken
#
# Top equipment:
#    hose
#    engine
#    pump
#    oil
#    cylinder
#
# Inherent functions in order:
#    guiding 14
#    protecting 13
#    holding 12
#    driving 10
#    generating 10
#    emitting 9
#    transforming 6
#    controlling 5
#    restricting 4
#    interfacing 4
#    covering 4
#    humaninteraction 3
#    matterprocessing 2
#    sensing 1
#    storing 1
#    presenting 1
# =========================
# Cluster 13 :
# Cluster Size: 203
# Top words:
#    air
#    unserviceable
#    conditioner
#    hand
#    fault
#
# Top states:
#    unserviceable
#    leak
#    fault
#    broken
#    leaking
#
# Top equipment:
#    hose
#    air conditioner
#    light
#    oil
#    brake
#
# Inherent functions in order:
#    guiding 30
#    holding 26
#    emitting 25
#    protecting 22
#    generating 16
#    controlling 13
#    driving 11
#    transforming 11
#    storing 9
#    matterprocessing 8
#    restricting 8
#    covering 7
#    interfacing 5
#    humaninteraction 5
#    sensing 5
#    presenting 2
# =========================
# Cluster 14 :
# Cluster Size: 253
# Top words:
#    unserviceable
#    not
#    hand
#    out
#    air
#
# Top states:
#    unserviceable
#    leak
#    blown
#    broken
#    fault
#
# Top equipment:
#    hose
#    light
#    engine
#    oil
#    air conditioner
#
# Inherent functions in order:
#    holding 42
#    emitting 39
#    guiding 36
#    generating 18
#    controlling 17
#    protecting 14
#    driving 14
#    transforming 13
#    matterprocessing 13
#    sensing 11
#    interfacing 8
#    covering 7
#    storing 7
#    restricting 7
#    presenting 5
#    humaninteraction 2
# =========================
# Cluster 15 :
# Cluster Size: 136
# Top words:
#    oil
#    leak
#    on
#    unserviceable
#    hose
#
# Top states:
#    leak
#    unserviceable
#    fault
#    cracked
#    missing
#
# Top equipment:
#    oil
#    hose
#    steering
#    cabin
#    boom
#
# Inherent functions in order:
#    guiding 23
#    holding 20
#    protecting 18
#    controlling 12
#    emitting 11
#    generating 7
#    transforming 7
#    sensing 6
#    driving 6
#    storing 5
#    matterprocessing 5
#    covering 4
#    restricting 4
#    humaninteraction 3
#    interfacing 3
#    presenting 2
# =========================
# Cluster 16 :
# Cluster Size: 133
# Top words:
#    hand
#    unserviceable
#    engine
#    oil
#    leak
#
# Top states:
#    unserviceable
#    leak
#    fault
#    blown
#    leaking
#
# Top equipment:
#    oil
#    engine
#    hose
#    air conditioner
#    cylinder
#
# Inherent functions in order:
#    guiding 19
#    emitting 18
#    holding 16
#    protecting 13
#    driving 12
#    generating 12
#    covering 9
#    matterprocessing 6
#    storing 5
#    sensing 5
#    interfacing 5
#    transforming 4
#    presenting 3
#    restricting 3
#    controlling 3
# =========================
# Cluster 17 :
# Cluster Size: 154
# Top words:
#    leaking
#    air
#    unserviceable
#    conditioner
#    fault
#
# Top states:
#    leaking
#    unserviceable
#    leak
#    fault
#    blown
#
# Top equipment:
#    hose
#    engine
#    brake
#    air conditioner
#    oil
#
# Inherent functions in order:
#    guiding 22
#    emitting 21
#    holding 14
#    generating 13
#    covering 13
#    driving 13
#    transforming 10
#    protecting 9
#    controlling 8
#    restricting 8
#    matterprocessing 7
#    sensing 5
#    interfacing 4
#    storing 3
#    humaninteraction 3
#    presenting 1
# =========================
# Cluster 18 :
# Cluster Size: 145
# Top words:
#    leak
#    air
#    hand
#    engine
#    hose
#
# Top states:
#    leak
#    unserviceable
#    blown
#    fault
#    broken
#
# Top equipment:
#    hose
#    engine
#    oil
#    brake
#    light
#
# Inherent functions in order:
#    emitting 21
#    guiding 20
#    holding 20
#    protecting 16
#    driving 15
#    transforming 11
#    restricting 9
#    controlling 7
#    generating 7
#    storing 5
#    presenting 4
#    covering 4
#    matterprocessing 3
#    sensing 2
#    interfacing 1
# =========================
# Cluster 19 :
# Cluster Size: 107
# Top words:
#    air
#    not
#    unserviceable
#    conditioner
#    broken
#
# Top states:
#    unserviceable
#    broken
#    leaking
#    leak
#    fault
#
# Top equipment:
#    air conditioner
#    compressor
#    engine
#    hose
#    cooler
#
# Inherent functions in order:
#    guiding 14
#    protecting 14
#    generating 13
#    emitting 12
#    holding 10
#    controlling 10
#    storing 8
#    matterprocessing 5
#    driving 5
#    covering 4
#    interfacing 4
#    presenting 2
#    transforming 2
#    sensing 2
#    restricting 1
#    humaninteraction 1
# =========================
# Cluster 20 :
# Cluster Size: 161
# Top words:
#    unserviceable
#    not
#    air
#    out
#    fault
#
# Top states:
#    unserviceable
#    leak
#    not working
#    fault
#    cracked
#
# Top equipment:
#    engine
#    door
#    air conditioner
#    bolts
#    oil
#
# Inherent functions in order:
#    emitting 19
#    holding 19
#    guiding 17
#    generating 15
#    controlling 13
#    driving 13
#    protecting 12
#    sensing 9
#    interfacing 7
#    restricting 7
#    transforming 6
#    storing 6
#    matterprocessing 6
#    covering 5
#    presenting 4
#    humaninteraction 3
# =========================
# Cluster 21 :
# Cluster Size: 159
# Top words:
#    unserviceable
#    oil
#    pump
#    hand
#    hose
#
# Top states:
#    unserviceable
#    fault
#    broken
#    blown
#    leaking
#
# Top equipment:
#    oil
#    hose
#    engine
#    air conditioner
#    pump
#
# Inherent functions in order:
#    protecting 25
#    holding 21
#    guiding 18
#    emitting 15
#    generating 14
#    controlling 12
#    transforming 11
#    driving 7
#    restricting 6
#    sensing 6
#    covering 5
#    presenting 5
#    interfacing 5
#    matterprocessing 5
#    storing 4
# =========================
# Cluster 22 :
# Cluster Size: 172
# Top words:
#    unserviceable
#    out
#    air
#    oil
#    conditioner
#
# Top states:
#    unserviceable
#    fault
#    leaking
#    leak
#    out
#
# Top equipment:
#    air conditioner
#    lights
#    oil
#    hose
#    engine
#
# Inherent functions in order:
#    emitting 26
#    holding 24
#    protecting 18
#    guiding 18
#    generating 16
#    matterprocessing 11
#    driving 10
#    transforming 8
#    sensing 7
#    covering 7
#    controlling 7
#    presenting 6
#    storing 5
#    restricting 3
#    humaninteraction 3
#    interfacing 3
# =========================
# Cluster 23 :
# Cluster Size: 108
# Top words:
#    air
#    leak
#    hand
#    conditioner
#    not
#
# Top states:
#    leak
#    missing
#    fault
#    unserviceable
#    crack
#
# Top equipment:
#    air conditioner
#    motor
#    window
#    compressor
#    bolts
#
# Inherent functions in order:
#    emitting 15
#    protecting 13
#    guiding 13
#    holding 13
#    generating 10
#    controlling 8
#    interfacing 6
#    transforming 5
#    driving 5
#    restricting 5
#    sensing 4
#    matterprocessing 3
#    covering 3
#    presenting 2
#    storing 2
#    humaninteraction 1
# =========================
# Cluster 24 :
# Cluster Size: 105
# Top words:
#    hand
#    leaking
#    leak
#    broken
#    air
#
# Top states:
#    leaking
#    leak
#    broken
#    fault
#    unserviceable
#
# Top equipment:
#    hose
#    oil
#    tyre
#    transmission
#    air conditioner
#
# Inherent functions in order:
#    guiding 22
#    holding 16
#    protecting 11
#    controlling 9
#    sensing 8
#    generating 8
#    emitting 8
#    driving 6
#    covering 5
#    presenting 4
#    matterprocessing 3
#    transforming 3
#    storing 2
# =========================

# %% [markdown]
# ### Sbert

# %%
# SBERT embeddings
# sbert = SentenceTransformer("all-MiniLM-L6-v2")
sbert = SentenceTransformer("all-mpnet-base-v2")

SBERT_embeddings_train = sbert.encode(X_train)
SBERT_embeddings_test = sbert.encode(X_test)
print(SBERT_embeddings_train.shape)
cluster_embeddings= np.concatenate((SBERT_embeddings_train, SBERT_embeddings_test))
# Out:
# /opt/miniconda3/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# (2520, 768)

# %%
sbert_test_model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=128, activation="relu", input_shape=(768,)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(units=64, activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(units=32, activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(units=10, activation="tanh"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(units=16, activation="softmax")
])

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
sbert_test_model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])
early_stopping = tf.keras.callbacks.EarlyStopping(patience=20, monitor='val_loss', restore_best_weights=True)
history = sbert_test_model.fit(SBERT_embeddings_train, y_train, epochs=100, validation_data=(SBERT_embeddings_test, y_test), callbacks=[early_stopping])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy TF-Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/100
# 79/79 [==============================] - 2s 4ms/step - loss: 2.4480 - accuracy: 0.2849 - val_loss: 2.7818 - val_accuracy: 0.0428
# Epoch 2/100
# 79/79 [==============================] - 0s 2ms/step - loss: 1.9493 - accuracy: 0.4774 - val_loss: 2.7878 - val_accuracy: 0.1046
# Epoch 3/100
# 79/79 [==============================] - 0s 2ms/step - loss: 1.6912 - accuracy: 0.5448 - val_loss: 2.7349 - val_accuracy: 0.1680
# Epoch 4/100
# 79/79 [==============================] - 0s 2ms/step - loss: 1.5065 - accuracy: 0.6091 - val_loss: 2.6427 - val_accuracy: 0.1997
# Epoch 5/100
# 79/79 [==============================] - 0s 2ms/step - loss: 1.3988 - accuracy: 0.6254 - val_loss: 2.3904 - val_accuracy: 0.2805
# Epoch 6/100
# 79/79 [==============================] - 0s 2ms/step - loss: 1.2956 - accuracy: 0.6472 - val_loss: 2.0469 - val_accuracy: 0.4453
# Epoch 7/100
# 79/79 [==============================] - 0s 2ms/step - loss: 1.1787 - accuracy: 0.6790 - val_loss: 1.8688 - val_accuracy: 0.5008
# Epoch 8/100
# 79/79 [==============================] - 0s 2ms/step - loss: 1.1034 - accuracy: 0.6992 - val_loss: 1.8324 - val_accuracy: 0.5151
# Epoch 9/100
# 79/79 [==============================] - 0s 2ms/step - loss: 1.0596 - accuracy: 0.7071 - val_loss: 1.7991 - val_accuracy: 0.5372
# Epoch 10/100
# 79/79 [==============================] - 0s 2ms/step - loss: 1.0093 - accuracy: 0.7175 - val_loss: 1.8066 - val_accuracy: 0.5325
# Epoch 11/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.9218 - accuracy: 0.7401 - val_loss: 1.8560 - val_accuracy: 0.5341
# Epoch 12/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.9307 - accuracy: 0.7401 - val_loss: 1.8203 - val_accuracy: 0.5372
# Epoch 13/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.8949 - accuracy: 0.7488 - val_loss: 1.8814 - val_accuracy: 0.5293
# Epoch 14/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.8327 - accuracy: 0.7746 - val_loss: 1.8904 - val_accuracy: 0.5135
# Epoch 15/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.8304 - accuracy: 0.7607 - val_loss: 1.8509 - val_accuracy: 0.5261
# Epoch 16/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.8048 - accuracy: 0.7710 - val_loss: 1.8247 - val_accuracy: 0.5483
# Epoch 17/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.7691 - accuracy: 0.7821 - val_loss: 1.9341 - val_accuracy: 0.5293
# Epoch 18/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.7545 - accuracy: 0.7782 - val_loss: 1.9264 - val_accuracy: 0.5420
# Epoch 19/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.7506 - accuracy: 0.7810 - val_loss: 1.9313 - val_accuracy: 0.5404
# Epoch 20/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.7346 - accuracy: 0.7897 - val_loss: 1.8983 - val_accuracy: 0.5674
# Epoch 21/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.7019 - accuracy: 0.7956 - val_loss: 2.0222 - val_accuracy: 0.5452
# Epoch 22/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.7182 - accuracy: 0.7885 - val_loss: 1.9799 - val_accuracy: 0.5531
# Epoch 23/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6918 - accuracy: 0.7861 - val_loss: 1.9915 - val_accuracy: 0.5515
# Epoch 24/100
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7077 - accuracy: 0.7845 - val_loss: 2.0377 - val_accuracy: 0.5452
# Epoch 25/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6795 - accuracy: 0.7913 - val_loss: 1.9960 - val_accuracy: 0.5499
# Epoch 26/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6765 - accuracy: 0.7917 - val_loss: 2.0366 - val_accuracy: 0.5547
# Epoch 27/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6600 - accuracy: 0.7917 - val_loss: 1.9693 - val_accuracy: 0.5515
# Epoch 28/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6491 - accuracy: 0.8020 - val_loss: 1.9780 - val_accuracy: 0.5483
# Epoch 29/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6536 - accuracy: 0.7909 - val_loss: 2.0067 - val_accuracy: 0.5388

# %%
pred_train = sbert_test_model.predict(SBERT_embeddings_train)
pred_train = pred_train.argmax(axis=-1)
print(sbert_test_model.evaluate(SBERT_embeddings_train, y_train))

print(pred_train[0:100])
print(y_train[0:100])

pred_test = sbert_test_model.predict(SBERT_embeddings_test)
pred_test = pred_test.argmax(axis=-1)
print(sbert_test_model.evaluate(SBERT_embeddings_test, y_test))

print(pred_test)
print(y_test)
# Out:
# 79/79 [==============================] - 0s 661us/step
# 79/79 [==============================] - 0s 694us/step - loss: 0.8900 - accuracy: 0.7643
# [0.8899883031845093, 0.7642857432365417]
# [ 6  8  8 13  1 12 12 10  5  9  2  6  6 13 15  4  4  8  6  0  8  6  9  1
#   6  6  9  2  2 12  7  6  8  8  4  6 14  1  4  4  6 14  6 12  1 12  6  8
#  12  4  2  2 12  1  7  8  2 12  7  6  9  8  6 12 12  9  2  9  5  9  6  4
#   1  5  5  8  4  1  1  5  6  2  0  3  1  1  5  1  1  4  1  1 12  4  2 12
#   6  6  0  2]
# [ 6  8  8 12  1 12 10 10  5  9  2  6 12 15  2 15  4  8  6  0  8  6  9  1
#   6  6  9  2  9 12  7  6  8  8  4  6 14  1  4  4 13 14  6 12  1  6 13  8
#  12  0  7 10 12  1  7  4  2 14  7  6  6  8  6 12  2  9  9  9 15 15  6  0
#   1  5  5  8  4  1 12  5  6  2  0  3  1  1  5  8 13  4  1  1 12  4 10 10
#   9  6  0 12]
# 20/20 [==============================] - 0s 734us/step
# 20/20 [==============================] - 0s 550us/step - loss: 1.7991 - accuracy: 0.5372
# [1.7990766763687134, 0.5372424721717834]
# [12  0 12  6  9  2  8  4  6  8  2  7  1  5  6  2  8  5  1  9  5 12 14  4
#   7  7 13  6 15  0  7  6  7  1  6  9  6  6  7  8  8  9 12  6  4  6 13 12
#   2 12  6  4 12  6  9  1  5 12  5  9  7  4 12 12  2  6 12  6 12  6  1  7
#   8  2  2  1  9 12 12  9  6  7 15  1  4  7  8  4  6  4  2 12  9  9  9  9
#   4  7  2  1  6  9  0  1  2  9  6  6  6  1  0  9 12 13 12  7  9  1  6  7
#   6  4 15  4 14  4 12 12 10 10  6  9 10 13  4  4 12  1  6  3 10  9  8 12
#   4  6 13  6  7 14 12  6 11 15  2  4  9  4  1 12 15 12  1  9 12  7 12  0
#   7  1  0 12  9 15  6  8  5  5  1 12 15 10  2  1  4  9 12 12  6  6  4  6
#   6 12 13  4  6  4 12 12 10  2  7  1  8 14 11  1 12  4  4  6 14  6  1  9
#   7 12  1  4  6  1  6  0  4  6  9  4  8  7  6  5  0  0  6  4  6  6  9  1
#   0  9 12 12  6  5  1  6 12 12  4  0 10  6  2  8  9  2 12  2  4  2 13  4
#  12  0  2 12 12 12  9  6  6 12  2  7  9  9 12 12  9  2  2  5 15  0  7  9
#   6  6  6  4  6  7  8 15  4 12  9 12 12 13 13  4  4 15  6  4 12  2  1  7
#   9 15  0  9  1  6 12  1  6 14  4 15  6  6  6  9  9  6 12  6  6  5  9  5
#  12 12  9 14  2  7  4  9  1  1  1  4  1  2 10  9 10  1 12 14  8 14  8  1
#   7 12 15  6  8  1 15  5  2  6  9  4  1  4 12  9  5 15  6  6  1 12  2  7
#   7  7 15 12  9  7 12 12  2  2 12 10 15  1  7  1  5  8 15 12  1 12  7  4
#   4  7  9  4  0  2 10  6  5  9  6  6  4 12  8  9  9 12 12 13  1  4  1 12
#   6  1  9  9  9  8  4 10  9 15  6  4  9  6  1 10  2  6  1  6  1  1 12  6
#  13 10  2 12  7  6  4 12  7 10 12  1  4  6  9  6 12 12  9  4  4  6 15  6
#  12  9  6 12 10  1  4  1 15  9 12 12  7  2  6  1  9  4 12 12  7  1  0  6
#   9  2  1  4  1  0  6 12  9  1  9  5  2  4  6  9  9  7  5  8  6  4 12 12
#   6  6  1  9  4 12  1  9  9  1  6  4 12  5 10  6  6  5  1  8  6  0  2  6
#   5  4  8 12  6 13  0 13 13  1 14  1  4 12 12  5 12 15  0  1  6  6  6 13
#   6  7  2  6  6 13  5  0 15  7  1  1 15  5 12  4 12  6 12  6  8 14  9  9
#   4  6  5  6  1  6  2  8 12  6  7  6  4  8  9 13  4  1  7 12  2  5 12  7
#   6  6  6 12  9  7  1]
# [ 1  0 13  6  9  2  6  4  6  8  8  7  0  5 12 14  8  6  1  9  5  1 14  4
#   7  7 13  7 15 15  3  6  6  5  6  9  6  6  9  8 13  1  6  6  4  0  2 12
#   9 12  6  4 12  6 12  1  5  5  0  9  7  0  9 13 12  6 12  0 10  1  9  7
#   8 13  2  1  9 12  6  7  6  7  1  1 14 12  8  6 10  4  2 12  9  6  9  6
#  12  7 12  1  6  9  0  1  8  9  6  6 15  1  0  9 12 13  1  7  9  1  4  7
#   6  8 14  1  0  7  0  5 10 10  6  1  9  5  8 13 12  1  6  3 10  3 13  4
#  10  9  6  1  7 14 12  6 11 15  9  6  9  4  4 12 15  8  1  6 12  7 12  0
#   7  6  4 12  2  5  4  8  2  9  0 12  5 10  2  1  9  5  8 13 12  0  4  6
#   5 13 12  4  6 13  5  8  2  2  4  4  8 12 11  1  6 12  4  9 14  6  1 15
#   1 15 13  7  4  2  6  0 12  6  9  8 12 12  0  5  6  3  6  3  6  6  9  0
#   0  1 12 12  6  1  1 11  6 12 14  0 10  6 14  8 12  9 12  1  3 14  6  4
#  12  0  2 12  1  6  9  4  6 13  2  7  9  1  3 12  9  8  2 15 11  0  7  6
#   9  6  6  4  6  7  8 15  1  4  9 10 13 13 13  1  4 15  6  4  5 13  1  7
#   9 15  7  9  1  1 12  1  6 14  4 11  6  6  6  9 14  8  6 15  6  5  9  6
#   1 12  5 14  2  6  6  9  1  7  0  8  1  2 10  1 12  1 12 14  6  3  8  1
#  10  7 15  2  8  1 15 12  2 13  9  1  1  4  5  9  5 15  6 12  7 12 14  7
#   7 12 15 12  9  7  6 12  2 14  9 10 15  6  7  1  4  8  5  7  1  7  7  4
#   0  4  9  4  0  9  3 12  5  6 12  6  4 12  8 13  5 12 14 13  1 10  1  1
#   9  1  2  9 13  6  4 10 12 15  6  4 12 12  4  1 14 14  1  6  1 13 12 12
#   1  1  2 12  7  6 12 12  7 14  2  1  6  6  7  6 10  7  9  4  4  6 12  6
#  12 12  6  8 10  1  9  2 11  2  3 12  9  9  6  1  9  4 12 12  7  1  0  6
#   9  4  1 12  1  0  6 12  1  1  1  5  8  4 12  1 14  7 13  8  9  4 12  6
#   6  6  1  9  7 12  6  9  9  1 13  1 12  3 10  6  6 11 13  6  8  0  9  2
#   9 15  6 12  6 13  2 12 13  2  3  1  5 12  4 10  5 15  0  1  7  7  6  5
#   6  7  4 11  6  9  5  0 15  7  9  1 15  5  6  0  4  6 12  6  8 15  4 12
#   4  6  4 13  7  1 12  1  2 12  7  9  1 13  2 13  3  1 12  9  9  5 12  4
#   6  6  6 12  9  9  1]

# %%
sbert_test_model_embedding = tf.keras.Sequential([
    
    tf.keras.layers.Dense(units=128, activation="relu", input_shape=(768,)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(units=64, activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(units=32, activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(units=10, activation="tanh"),
])


sbert_test_model_embedding.layers[0].set_weights(sbert_test_model.layers[0].get_weights())
sbert_test_model_embedding.layers[1].set_weights(sbert_test_model.layers[1].get_weights())
sbert_test_model_embedding.layers[2].set_weights(sbert_test_model.layers[2].get_weights())
sbert_test_model_embedding.layers[3].set_weights(sbert_test_model.layers[3].get_weights())
sbert_test_model_embedding.layers[4].set_weights(sbert_test_model.layers[4].get_weights())


SBERT_embeddings = np.concatenate((SBERT_embeddings_train, SBERT_embeddings_test))
cluster_embeddings = sbert_test_model_embedding.predict(SBERT_embeddings)
print(cluster_embeddings.shape)
# Out:
# 99/99 [==============================] - 0s 524us/step
# (3151, 10)

# %% [markdown]
# ### cnn w2v LSA

# %%
lsa_embeddings_X_test = LSI_ebed(dataset)
X_train, X_test, y_train, y_test = train_test_split(dataset, lsa_embeddings_X_test, random_state=42, shuffle=True, test_size=0.2)
w2v_embeddings_X_train = w2v_embed(X_train)
w2v_embeddings_X_test = w2v_embed(X_test)
# Out:
# max length of MWO: 9
# max length of MWO: 9

# %%
dr = 10
cnn_model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(16, (2, 2), activation='relu', padding="same", input_shape=(9,100,1)),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.Conv2D(8, (2, 2), activation='relu', padding="same"),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=dr, activation="tanh"),
    tf.keras.layers.Dense(units=10, activation="tanh")
])

opt = tf.keras.optimizers.Adam(learning_rate=0.001)

cnn_model.compile(optimizer=opt,
              loss=tf.keras.losses.MeanSquaredLogarithmicError("sum_over_batch_size"),
              metrics=['accuracy'])

early_stopping = tf.keras.callbacks.EarlyStopping(patience=20, monitor='val_loss', restore_best_weights=True)

history = cnn_model.fit(w2v_embeddings_X_train, y_train, epochs=200, validation_data=(w2v_embeddings_X_test, y_test), callbacks=[early_stopping])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy TF-Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/200
# 4/4 [==============================] - 1s 44ms/step - loss: 0.1498 - accuracy: 0.1953 - val_loss: 0.1253 - val_accuracy: 0.1562
# Epoch 2/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1386 - accuracy: 0.1641 - val_loss: 0.1164 - val_accuracy: 0.0625
# Epoch 3/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1301 - accuracy: 0.0781 - val_loss: 0.1179 - val_accuracy: 0.0938
# Epoch 4/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1308 - accuracy: 0.1953 - val_loss: 0.1169 - val_accuracy: 0.1250
# Epoch 5/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1291 - accuracy: 0.1953 - val_loss: 0.1146 - val_accuracy: 0.1250
# Epoch 6/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1291 - accuracy: 0.1953 - val_loss: 0.1140 - val_accuracy: 0.1250
# Epoch 7/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1290 - accuracy: 0.1953 - val_loss: 0.1138 - val_accuracy: 0.1250
# Epoch 8/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1285 - accuracy: 0.1953 - val_loss: 0.1139 - val_accuracy: 0.1250
# Epoch 9/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1283 - accuracy: 0.1953 - val_loss: 0.1143 - val_accuracy: 0.1250
# Epoch 10/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1283 - accuracy: 0.1953 - val_loss: 0.1142 - val_accuracy: 0.1250
# Epoch 11/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1283 - accuracy: 0.1953 - val_loss: 0.1142 - val_accuracy: 0.1250
# Epoch 12/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1282 - accuracy: 0.1953 - val_loss: 0.1140 - val_accuracy: 0.1250
# Epoch 13/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1281 - accuracy: 0.1953 - val_loss: 0.1139 - val_accuracy: 0.1250
# Epoch 14/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1282 - accuracy: 0.1953 - val_loss: 0.1140 - val_accuracy: 0.1250
# Epoch 15/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1280 - accuracy: 0.1953 - val_loss: 0.1140 - val_accuracy: 0.1250
# Epoch 16/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1280 - accuracy: 0.1953 - val_loss: 0.1142 - val_accuracy: 0.1250
# Epoch 17/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1279 - accuracy: 0.1953 - val_loss: 0.1141 - val_accuracy: 0.1250
# Epoch 18/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1277 - accuracy: 0.1953 - val_loss: 0.1138 - val_accuracy: 0.1250
# Epoch 19/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1275 - accuracy: 0.1953 - val_loss: 0.1137 - val_accuracy: 0.1250
# Epoch 20/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1274 - accuracy: 0.1953 - val_loss: 0.1138 - val_accuracy: 0.1250
# Epoch 21/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1274 - accuracy: 0.1953 - val_loss: 0.1139 - val_accuracy: 0.1250
# Epoch 22/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1271 - accuracy: 0.1953 - val_loss: 0.1137 - val_accuracy: 0.1250
# Epoch 23/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1269 - accuracy: 0.1953 - val_loss: 0.1136 - val_accuracy: 0.1250
# Epoch 24/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1267 - accuracy: 0.1953 - val_loss: 0.1136 - val_accuracy: 0.1250
# Epoch 25/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1264 - accuracy: 0.1953 - val_loss: 0.1138 - val_accuracy: 0.1250
# Epoch 26/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1262 - accuracy: 0.1953 - val_loss: 0.1138 - val_accuracy: 0.1250
# Epoch 27/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1259 - accuracy: 0.1953 - val_loss: 0.1136 - val_accuracy: 0.1250
# Epoch 28/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1256 - accuracy: 0.1953 - val_loss: 0.1134 - val_accuracy: 0.1250
# Epoch 29/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1252 - accuracy: 0.1953 - val_loss: 0.1135 - val_accuracy: 0.1250
# Epoch 30/200
# 4/4 [==============================] - 0s 39ms/step - loss: 0.1249 - accuracy: 0.1953 - val_loss: 0.1137 - val_accuracy: 0.0938
# Epoch 31/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1244 - accuracy: 0.1953 - val_loss: 0.1133 - val_accuracy: 0.0938
# Epoch 32/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1240 - accuracy: 0.1953 - val_loss: 0.1131 - val_accuracy: 0.0938
# Epoch 33/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1235 - accuracy: 0.2031 - val_loss: 0.1134 - val_accuracy: 0.1562
# Epoch 34/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1232 - accuracy: 0.2188 - val_loss: 0.1137 - val_accuracy: 0.0938
# Epoch 35/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1223 - accuracy: 0.2188 - val_loss: 0.1131 - val_accuracy: 0.0938
# Epoch 36/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1215 - accuracy: 0.2188 - val_loss: 0.1130 - val_accuracy: 0.1250
# Epoch 37/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1209 - accuracy: 0.2422 - val_loss: 0.1131 - val_accuracy: 0.1250
# Epoch 38/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1200 - accuracy: 0.2578 - val_loss: 0.1131 - val_accuracy: 0.1250
# Epoch 39/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1187 - accuracy: 0.3125 - val_loss: 0.1116 - val_accuracy: 0.1875
# Epoch 40/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1167 - accuracy: 0.3203 - val_loss: 0.1111 - val_accuracy: 0.1250
# Epoch 41/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1151 - accuracy: 0.2969 - val_loss: 0.1090 - val_accuracy: 0.1250
# Epoch 42/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1138 - accuracy: 0.2578 - val_loss: 0.1077 - val_accuracy: 0.1250
# Epoch 43/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1129 - accuracy: 0.2656 - val_loss: 0.1075 - val_accuracy: 0.1250
# Epoch 44/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1118 - accuracy: 0.3047 - val_loss: 0.1082 - val_accuracy: 0.1250
# Epoch 45/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1107 - accuracy: 0.3594 - val_loss: 0.1092 - val_accuracy: 0.0938
# Epoch 46/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1097 - accuracy: 0.3828 - val_loss: 0.1095 - val_accuracy: 0.0938
# Epoch 47/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1086 - accuracy: 0.3984 - val_loss: 0.1099 - val_accuracy: 0.1250
# Epoch 48/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1076 - accuracy: 0.4062 - val_loss: 0.1105 - val_accuracy: 0.1875
# Epoch 49/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1064 - accuracy: 0.4297 - val_loss: 0.1110 - val_accuracy: 0.1875
# Epoch 50/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1056 - accuracy: 0.4062 - val_loss: 0.1109 - val_accuracy: 0.1875
# Epoch 51/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1043 - accuracy: 0.4219 - val_loss: 0.1114 - val_accuracy: 0.1875
# Epoch 52/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1036 - accuracy: 0.4453 - val_loss: 0.1125 - val_accuracy: 0.1562
# Epoch 53/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1024 - accuracy: 0.4297 - val_loss: 0.1121 - val_accuracy: 0.1562
# Epoch 54/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1015 - accuracy: 0.4453 - val_loss: 0.1128 - val_accuracy: 0.1562
# Epoch 55/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1007 - accuracy: 0.4531 - val_loss: 0.1138 - val_accuracy: 0.1562
# Epoch 56/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0998 - accuracy: 0.4375 - val_loss: 0.1138 - val_accuracy: 0.1562
# Epoch 57/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0990 - accuracy: 0.4688 - val_loss: 0.1150 - val_accuracy: 0.1562
# Epoch 58/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0981 - accuracy: 0.4922 - val_loss: 0.1156 - val_accuracy: 0.1562
# Epoch 59/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0974 - accuracy: 0.4922 - val_loss: 0.1157 - val_accuracy: 0.1562
# Epoch 60/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0965 - accuracy: 0.4922 - val_loss: 0.1170 - val_accuracy: 0.1562
# Epoch 61/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0953 - accuracy: 0.4844 - val_loss: 0.1160 - val_accuracy: 0.2500
# Epoch 62/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0928 - accuracy: 0.5156 - val_loss: 0.1135 - val_accuracy: 0.2500
# Epoch 63/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0906 - accuracy: 0.5078 - val_loss: 0.1120 - val_accuracy: 0.2812

# %%
pred_train = cnn_model.predict(w2v_embeddings_X_train)
print(cnn_model.evaluate(w2v_embeddings_X_train, y_train))
print(cnn_model.evaluate(w2v_embeddings_X_test, y_test))

print(pred_train[0])
print(y_train[0])
# Out:
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1122 - accuracy: 0.3047
# [0.11224724352359772, 0.3046875]
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1075 - accuracy: 0.1250
# [0.10753166675567627, 0.125]
# [ 0.2729801  -0.32353553 -0.1861186   0.23202688 -0.31970528  0.09729026
#   0.09758251  0.31919488  0.2819055   0.14479837]
# [ 0.00688159 -0.06182593  0.32433874  0.09975192  0.01193748 -0.09656224
#   0.7382632   0.1584699   0.16000169 -0.26760458]

# %% [markdown]
# #### clustering

# %%
cnn_model_embedding = tf.keras.Sequential([
    tf.keras.layers.Conv2D(16, (2, 2), activation='relu', padding="same", input_shape=(9,100,1)),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.Conv2D(8, (2, 2), activation='relu', padding="same"),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=dr, activation="tanh"),
])

cnn_model_embedding.layers[0].set_weights(cnn_model.layers[0].get_weights())
cnn_model_embedding.layers[2].set_weights(cnn_model.layers[2].get_weights())
cnn_model_embedding.layers[4].set_weights(cnn_model.layers[4].get_weights())


w2v_embeddings = np.concatenate((w2v_embeddings_X_train, w2v_embeddings_X_test))
cluster_embeddings = cnn_model_embedding.predict(w2v_embeddings)
print(cluster_embeddings.shape)
# Out:
# 5/5 [==============================] - 0s 2ms/step
# (160, 10)

# %%
dataset_not_padded = full_dataset("../data/gold_release.json")

from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.metrics import silhouette_score


# PCA reduction
pca = PCA(n_components=2)
pca_embedding = pca.fit_transform(cluster_embeddings)
plt.scatter(pca_embedding[:,0], pca_embedding[:,1])
plt.title("PCA")
plt.show()

# tsne reduction
tsne = TSNE(n_components=2).fit_transform(cluster_embeddings)
plt.scatter(tsne[:,0], tsne[:,1])
plt.title("TSNE")
plt.show()


# Perform kmean clustering
silhouette_scores = []
test_k = list(range(5, 105, 5))
for i in test_k:
    print(i, "/", 100)
    kmeans = KMeans(n_clusters=i, random_state=42, n_init=100).fit(cluster_embeddings)
    labels = kmeans.labels_
    silhouette_scores.append(silhouette_score(cluster_embeddings, labels))
plt.plot(test_k, silhouette_scores)
plt.title("Silhouette Scores")
plt.show()
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 5 / 100
# 10 / 100
# 15 / 100
# 20 / 100
# 25 / 100
# 30 / 100
# 35 / 100
# 40 / 100
# 45 / 100
# 50 / 100
# 55 / 100
# 60 / 100
# 65 / 100
# 70 / 100
# 75 / 100
# 80 / 100
# 85 / 100
# 90 / 100
# 95 / 100
# 100 / 100

# %%
# best k
k = 25
kmeans = KMeans(n_clusters=k, random_state=42, n_init=100).fit(cluster_embeddings)
cluster_labels = kmeans.labels_

for i in range(k):
    print("Cluster ", i)
    for j in range(len(cluster_labels)):
        if cluster_labels[j] == i:
            print(dataset_not_padded[j])
            
    print()
# Out:
# Cluster  0
# ['alternator', 'drive', 'leaking']
# ['alternator', 'overcharge', 'fault']
# ['backlights', 'on', 'dash', 'blown']
# ['blown', 'brake', 'hose']
# ['blown', 'position', 'tyre']
# ['blown', 'steering', 'hose']
# ['blown', 'steering', 'pump', 'hose']
# ['boarding', 'gate', 'latch', 'not', 'working']
# ['boarding', 'ladder', 'not', 'working']
# ['change', 'out', 'blown', 'o-ring', 'on', 'steering', 'pump']
# ['change', 'out', 'broken', 'bolt', 'on', 'brake', 'pump']
# ['change', 'out', 'unserviceable', 'left', 'hand', 'bucket', 'cylinder', 'hose']
# ['change', 'out', 'unserviceable', 'position', 'tyre']
# ['chord', 'pressure', 'fault']
#
# Cluster  1
# ['air', 'horn', 'stuck', 'on']
# ['air', 'leak']
# ['backhoe', 'windscreen', 'to', 'be', 'fixed']
# ['battery', 'cover', 'hinges', 'seized']
# ['blade', 'wear', 'plates', 'cracked', 'worn']
# ['blown', 'air', 'conditioner', 'hose']
# ['blown', 'oil', 'cooler', 'hose', 'x', 'metre']
# ['change', 'out', 'leaking', 'HMU', 'on', 'next']
#
# Cluster  2
# ['air', 'conditioner', 'thermostat', 'not', 'working']
# ['air', 'horn', 'working', 'intermittently']
# ['auto-lube', 'error', 'PO']
# ['back', 'rest', 'unserviceable', 'handle', 'broken']
# ['belly', 'plate', 'bolt', 'missing']
# ['blown', 'air', 'conditioner', 'hose', 'to', 'radiator']
# ['cabin', 'seals', 'leaking', 'dust', 'bad']
# ['camera', 'fault']
# ['centrifugal', 'oil', 'filter', 'fault']
# ['change', 'out', 'weeping', 'boom', 'cylinder', 'hose']
# ['change', 'position', 'flat', 'tyre']
# ['check', 'repair', 'engine', 'oil', 'leak']
#
# Cluster  3
# ['alternator', 'overcharged']
# ['blown', 'hose', 'in', 'hitch']
# ['blown', 'o-ring', 'on', 'left', 'hand', 'lift', 'cylinder']
# ['change', 'out', 'unserviceable', 'right', 'hand', 'clam', 'cylinder', 'hose']
#
# Cluster  4
# ['bent', 'belly', 'plate']
# ['boarding', 'gate', 'hinge', 'broken']
# ['cabin', 'door', 'window', 'cracked']
# ['cords', 'cracked', 'at']
#
# Cluster  5
# ['broken', 'mirror']
# ['change', 'out', 'leak', 'slew', 'motor', 'hose']
# ['change', 'out', 'leaking', 'fan', 'hoses']
# ['change', 'out', 'position', 'tyre', 'worn', 'out']
# ['change', 'position', 'tyre', 'damage', 'text']
# ['coolant', 'pipe', 'clamps', 'needs', 'fitting', 'TBC']
# ['crack', 'in', 'blade', 'liner', 'left', 'hand', 'side']
#
# Cluster  6
# ['air', 'conditioner', 'thermostat', 'unserviceable']
# ['air', 'leaking', 'from', 'line', 'outside']
# ['backlight', 'on', 'dash', 'unserviceable']
# ['batteries', 'out', 'of', 'service']
# ['beacon', 'not', 'working']
# ['blade', 'light', 'blown', 'needs', 'replacing']
# ['change', 'out', 'cracked', 'pipe', 'on', 'valve', 'bank']
# ['change', 'out', 'cracked', 'position', 'adaptor', 'tooth']
# ['change', 'out', 'worn', 'position', 'tyre']
# ['coolant', 'leak', 'at', 'engine', 'oil', 'cooler']
# ['crack', 'in', 'windscreen']
# ['cracked', 'hydraulic', 'pipe']
#
# Cluster  7
# ['air', 'horn', 'disconnected']
# ['airhorn', 'not', 'working']
# ['beacon', 'mount', 'is', 'broken']
# ['carousel', 'popped', 'bolt', 'needs', 'Loctite']
# ['cracked', 'front', 'window']
# ['cracks', 'in', 'back', 'right', 'hand', 'side', 'handrail']
#
# Cluster  8
# ['brake', 'cooling', 'hose', 'leaking']
# ['brake', 'cooling', 'hose', 'leaking', 'rear']
# ['broken', 'air', 'conditioner', 'guard']
# ['broken', 'joystick', 'PO']
# ['cabin', 'seat', 'needs', 'replacing']
# ['change', 'out', 'unserviceable', 'jacket', 'water', 'pump']
#
# Cluster  9
# ['alternator', 'failed']
# ['batteries', 'discharging']
# ['brake', 'cooling', 'return', 'hose', 'leaking']
# ['change', 'out', 'blown', 'steering', 'hose']
# ['compressor', 'oil', 'pressure', 'switch', 'unserviceable']
#
# Cluster  10
# ['brake', 'release', 'fault']
# ['broken', 'left', 'hand', 'side', 'mirror']
# ['change', 'out', 'leaking', 'steering', 'hose']
# ['chord', 'leaking', 'air', 'found']
#
# Cluster  11
# ['air', 'horn', 'fault']
# ['air', 'horn', 'not', 'working', 'compressor', 'awaiting']
# ['air', 'horn', 'unserviceable']
# ['air', 'leak', 'near', 'side', 'of', 'door']
# ['auto-greaser', 'leaking', 'oil']
# ['auto-greaser', 'unserviceable']
# ['blown', 'extension', 'line', 'from', 'position']
# ['blown', 'lift', 'cylinder', 'o-ring']
# ['broken', 'fuel', 'cooler', 'mounts']
# ['bucket', 'cracked', 'in', 'arch', 'near', 'cancelled']
# ['change', 'out', 'leaking', 'implement', 'pump']
# ['cracked', 'suction', 'tube']
#
# Cluster  12
# ['air', 'filters', 'plugged']
# ['analyse', 'failed', 'driveline', 'component']
# ['bearings', 'are', 'shot']
# ['broken', 'grease', 'plug']
# ['change', 'out', 'leaking', 'hydraulic', 'hose']
# ['coolant', 'leak']
#
# Cluster  13
# ['lube', 'system', 'faults']
# ['axle', 'temperature', 'sensor', 'fault']
# ['blown', 'right', 'hand', 'bucket', 'cylinder', 'hose']
# ['broken', 'hinge']
# ['centrifugal', 'oil', 'filter', 'leaking']
#
# Cluster  14
# ['air', 'conditioner', 'unserviceable']
# ['blown', 'crowd', 'cylinder', 'hose']
# ['blown', 'o-ring', 'on', 'steering', 'hose']
# ['control', 'valve', 'unserviceable', 'see', 'long', 'text']
# ['crack', 'in', 'headboard']
# ['crack', 'in', 'lower', 'centre', 'of', 'windscreen']
#
# Cluster  15
# ['beacon', 'unserviceable']
# ['broken', 'ripper', 'tooth']
# ['broken', 'weld', 'on', 'handrail']
#
# Cluster  16
# ['change', 'out', 'unserviceable', 'swing', 'brake', 'cylinder']
# ['coolant', 'leak', 'at', 'jacket', 'water', 'pump']
# ['cooler', 'return', 'pipe', 'coupling', 'leak']
# ['crack', 'in', 'fuel', 'tank']
# ['cracked', 'fuel', 'tank']
# ['cracked', 'steering', 'tank', 'suction', 'tube']
#
# Cluster  17
# ['both', 'stick', 'cylinders', 'leaking']
# ['change', 'out', 'blown', 'position', 'tyre']
# ['change', 'out', 'exhaust', 'clamp', 'broken', 'on', 'left', 'hand', 'side', '[t', '|]']
# ['change', 'out', 'position', 'tyre', 'sensor', 'not', 'reading']
#
# Cluster  18
# ['broken', 'clamp', 'on', 'crowd', 'cylinder', 'hose', 'TBC']
# ['coolant', 'hose', 'leaking', 'at', 'right', 'hand', 'bottom']
#
# Cluster  19
# ['all', 'dash', 'lights', 'on']
# ['backup', 'alarm', 'not', 'working']
# ['batteries', 'unserviceable']
# ['blown', 'light', 'on', 'boom']
# ['cabin', 'seals', 'leaking', 'dust', 'PO']
#
# Cluster  20
# ['air', 'horn', 'does', 'not', 'work']
# ['alarm', 'on', 'VIMS', 'does', 'not', 'work']
# ['axle', 'temperature', 'fault']
# ['change', 'out', 'broken', 'prelube', 'bracket']
# ['change', 'out', 'front', 'upper', 'window', 'cracked']
# ['change', 'out', 'leaking', 'heater', 'taps']
# ['crack', 'onside', 'rock', 'deflector']
# ['cracked', 'walkway', 'handrails']
#
# Cluster  21
# ['air', 'conditioner', 'unserviceable', 'when', 'stationary']
# ['auto-spray', 'feature', 'not', 'working']
# ['bearing', 'on', 'air', 'conditioner', 'compressor', 'unserviceable']
# ['blown', 'o-ring', 'off', 'steering', 'hose']
# ['change', 'out', 'broken', 'stabilizer', 'bar']
# ['change', 'out', 'left', 'hand', 'steering', 'cylinder', 'leaking']
#
# Cluster  22
# ['crack', 'in', 'boom', 'chord']
#
# Cluster  23
# ['air', 'conditioner', 'warm']
# ['armrest', 'unserviceable']
# ['blade', 'skin', 'cracked']
# ['blown', 'hose', 'on', 'boom']
# ['broken', 'right', 'hand', 'side', 'door', 'window']
# ['change', 'out', 'position', 'tyre', 'damage']
#
# Cluster  24
# ['air', 'horn', 'not', 'working']
# ['alternator', 'not', 'charging']
# ['brake', 'temperature', 'error']
# ['cabin', 'needs', 'resealing']
# ['cabin', 'window', 'needs', 'resealing']
# ['change', 'out', 'leaking', 'relay', 'valve']
# ['change', 'out', 'unserviceable', 'right', 'hand', 'tilt', 'cylinder']
# ['contactor', 'fault']

# %%
from sklearn.metrics import normalized_mutual_info_score

nmi = normalized_mutual_info_score(cluster_labels, labels)
print(nmi)
# Out:
# 0.37128471665791263
